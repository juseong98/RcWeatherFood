# %%
# 최종 코드
# 블로그 검색 api
# 한 번에 가져오는 개수인 display는 최대 100까지 가능
# start변수 값을 바꿔야 다른 값을 불러옴, 최대 1000까지
# display=100이면 start변수 값을 1, 101, 201, ..., 1000으로 바꿔주면서 해야함
# start는 최대 1000까지 제공하기 때문에, start=1일때랑 start=1001일때랑 결과가 같음


import os
import sys
import urllib.request
def naver_blog(start):
    client_id = "8kZT6kfb83vNesnBvjwj"  # 본인 클라이언트 아이디 넣기
    client_secret = "bj39JaQzAp"  # 본인 클라이언트 시크릿 넣기
    encText = urllib.parse.quote("추천 메뉴")

    url = "https://openapi.naver.com/v1/search/blog?query="+encText+"&display=100"+"&start=" + start # json 결과

    file=open("./naver_api_dessert11.json","w+",encoding='UTF8')  # 파일로 저장하기
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        print(response_body.decode('utf-8'))
        file.write(response_body.decode('utf-8'))
        file.close()
    else:
        print("Error Code:" + rescode)
    return response_body.decode('utf-8')

# %%
body = ""
for i in range(1,1000,100) :
    body += naver_blog(str(i))
# Out:
# {
# 	"lastBuildDate":"Wed, 30 Aug 2023 12:52:04 +0900",
# 	"total":17886004,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"텐진 맛집 이치란 라멘 후쿠오카 웨이팅 주문 방법 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/lemonic119\/223184202740",
# 			"description":"일본 후쿠오카 맛집 이치란 라멘 텐진 웨이팅 주문 방법 메뉴 추천 스시 오마카세와 야끼니꾸 우니가... 후기와 <b>추천 메뉴<\/b> 소개, 그리고 주문 방법까지 공유해볼게요 24시간 운영하는 이치란라멘 본점은... ",
# 			"bloggername":"푸드 인플루언서 율무밍 일상 기록",
# 			"bloggerlink":"blog.naver.com\/lemonic119",
# 			"postdate":"20230815"
# 		},
# 		{
# 			"title":"베트남 다낭 맛집 한시장 주변 안토이 VS 벱꿰 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/nau2001\/223170190952",
# 			"description":"나만의 <b>추천메뉴<\/b> 가지볶음. 토마토소스두부완자조림, 황금새우 3. 안토이 베트남 요리를 한번에... 모든 메뉴를 맛 볼 수 있고 무엇보다 이쁜 인테리어와 쾌적한 환경이 좋아 주변 살마들에게 많이 추천하는... ",
# 			"bloggername":"와그잡의 트래블홀릭",
# 			"bloggerlink":"blog.naver.com\/nau2001",
# 			"postdate":"20230730"
# 		},
# 		{
# 			"title":"구로디지털단지역점 :: 갈비 <b>메뉴<\/b> 다 맛있음!! 구디 맛집 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/luuuuuucy\/223193685270",
# 			"description":"매장 밖에 <b>메뉴<\/b>판이 크게 있어서 좋았어요 매장도 깔끔 그 잡채 회식하기에도 넓은 공간이라 구디 직장인 분들에게 <b>추천<\/b>드립니다. #구디맛집 #구디술집 #구디고기집 #구로디지털단지역맛집... ",
# 			"bloggername":"Lucete✨",
# 			"bloggerlink":"blog.naver.com\/luuuuuucy",
# 			"postdate":"20230825"
# 		},
# 		{
# 			"title":"카페 오설록 티하우스 해운대점 오픈 행사 정보와 <b>추천 메뉴<\/b> 소개",
# 			"link":"https:\/\/blog.naver.com\/asdl93\/223194020698",
# 			"description":"여러분께 해운대 신상 카페 <b>추천<\/b> 정보 자세히 소개해드리고 싶어서 인테리어, <b>메뉴<\/b>, 오픈 행사 정보까지 자세히 보고 담아 왔으니, 해운대 카페 오설록 티하우스 해운대점 방문 전 참고하시길 바랄게요 :) 외관... ",
# 			"bloggername":"Spirit's Wood",
# 			"bloggerlink":"blog.naver.com\/asdl93",
# 			"postdate":"20230826"
# 		},
# 		{
# 			"title":"분모자로제떡볶이 내돈내산 솔직후기 (Feat. BHC <b>추천메뉴<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/sangyun1106\/223194102585",
# 			"description":"근데 같이 먹는걸 추천하고 싶진 않아요. 드시다보면 느끼는 거지만, 분모자로제떡볶이가 가성비는... 제 기준에서 BHC <b>추천메뉴<\/b>는 정말... 치킨메뉴 기준으로는 뿌링클, 커리퀸, 맛초킹 정도인 것 같습니다.... ",
# 			"bloggername":"N잡러민초파의 쩝쩝박사 도전기",
# 			"bloggerlink":"blog.naver.com\/sangyun1106",
# 			"postdate":"20230826"
# 		},
# 		{
# 			"title":"파타야 맛집 비프이터 스테이크 하우스 예약방법 및 <b>추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/swe_2tpotato\/223194067673",
# 			"description":"직원분에게 <b>메뉴<\/b> <b>추천<\/b>을 요청드리니 요 <b>메뉴<\/b>를 <b>추천<\/b>해 주셨다!! 크림색 브랜디 맛의 페퍼 소스를 곁들인 페퍼 스테이크 스테이크 위에는 튀긴 야채와 사이드로 감자 오그라탕이 함께 제공되는데 이... ",
# 			"bloggername":"스윗포타토킴의 다이어트&먹로드 이야기 '-'",
# 			"bloggerlink":"blog.naver.com\/swe_2tpotato",
# 			"postdate":"20230826"
# 		},
# 		{
# 			"title":"바르셀로나 비니투스 <b>메뉴<\/b><b>추천<\/b>&amp;가격표 feat.VINITUS 파산잼",
# 			"link":"https:\/\/blog.naver.com\/sophisticated-\/223194545116",
# 			"description":"Cerveseria Catalana 세르베세리아 카탈라나 같은 체인이라 맛,분위기가 비슷해요 메뉴판,가격도... Catalana 추천 부과세10% 붙었더니 지갑이... 여자2명이서 <b>추천 메뉴<\/b> 다 시키고 배부르게 먹은 가격이 이... ",
# 			"bloggername":"롤링의 Teenage Dream.",
# 			"bloggerlink":"blog.naver.com\/sophisticated-",
# 			"postdate":"20230827"
# 		},
# 		{
# 			"title":"제주 오일장 feat. 춘향이네 <b>추천 메뉴<\/b> 제주민속오일시장",
# 			"link":"https:\/\/blog.naver.com\/7633974\/223195157638",
# 			"description":"춘향이네 <b>메뉴<\/b>에요 다 맛있을 것 같은 <b>메뉴<\/b>들이에요 드시는 걸 봤는데 순대국밥, 비빔밥, 꼼장어... 순대는 <b>추천<\/b>해요 ! 글 읽어주셔서 감사합니다 모두 즐거운 오일장되세요  #제주오일장 #춘향이네... ",
# 			"bloggername":"주연 블로그",
# 			"bloggerlink":"blog.naver.com\/7633974",
# 			"postdate":"20230828"
# 		},
# 		{
# 			"title":"리스카페 정자 (주차, 웨이팅,<b>추천메뉴<\/b>) - 찐 브런치 맛집!!",
# 			"link":"https:\/\/blog.naver.com\/94yjung\/223191159266",
# 			"description":"기분 째져~~~ 가게 앞에 크게 인쇄된 <b>메뉴<\/b>판이 있어서 열심히 보면서 <b>메뉴<\/b>를 정했다 근데 진짜 하나부터... 이용을 <b>추천<\/b>드린다! (파라곤 지하주차장 2시간 지원된다고 함) 판교 사는 후배 <b>추천<\/b>으로 다녀온만큼 진짜... ",
# 			"bloggername":"Blog_yun",
# 			"bloggerlink":"blog.naver.com\/94yjung",
# 			"postdate":"20230823"
# 		},
# 		{
# 			"title":

# 			"postdate":"20230824"
# 		},
# 		{
# 			"title":"저녁<b>메뉴<\/b> <b>추천<\/b> 더미식 우렁된장찌개 신혼부부 간단한 국물요리",
# 			"link":"https:\/\/blog.naver.com\/lemonic119\/223189239200",
# 			"description":"저녁메뉴 추천 더미식 우렁된장찌개 신혼부부 간단한 국물요리 퇴근 후 오늘 저녁메뉴 뭐 먹을지... 저녁<b>추천메뉴<\/b>에요 보통 밀키트하면 냉장이나 냉동보관을 하는 경우가 많은데 더미식만의 열처리 기술을 통해... ",
# 			"bloggername":"푸드 인플루언서 율무밍 일상 기록",
# 			"bloggerlink":"blog.naver.com\/lemonic119",
# 			"postdate":"20230821"
# 		},
# 		{
# 			"title":"베트남 다낭 맛집 <b>추천<\/b> 다낭쌀국수 티엔킴 <b>메뉴<\/b> 할인 받기",
# 			"link":"https:\/\/blog.naver.com\/wkwmd81\/223180776064",
# 			"description":"<b>추천 메뉴<\/b>는 크게 사진도 있으니 크게 사진이 함께 실려있는 메뉴 위주로 주문하시는 거 추천합니다. 다낭쌀국수 필수로 주문하시고요 반쎄오, 파인애플 볶음밥도 좋아해요. 망고 샐러드도 맛있어서 여러 번... ",
# 			"bloggername":"해외여행 고고씽",
# 			"bloggerlink":"blog.naver.com\/wkwmd81",
# 			"postdate":"20230812"
# 		},
# 		{
# 			"title":"타타스베이글 대전 빵나오는시간 <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/keeping_on\/223175653852",
# 			"description":"타타스베이글 대전 빵나오는시간 <b>추천 메뉴<\/b> 아기랑 실내 놀이터 가기 전에 타타스베이글을 들렀다.... 마늘이 들어가서 느끼하지 않고 포만감이 있어서 브런치 메뉴로 추천 ~ 모카슈크림 모카만 있었다면... ",
# 			"bloggername":"시트콤라이프",
# 			"bloggerlink":"blog.naver.com\/keeping_on",
# 			"postdate":"20230805"
# 		},
# 		{
# 			"title":"함덕 예약부터 주차 <b>메뉴<\/b>, 제주도 흑돼지 맛집으로 <b>추천<\/b>하는 이유!",
# 			"link":"https:\/\/blog.naver.com\/jiny1445\/223180761954",
# 			"description":"지점마다 <b>추천 메뉴<\/b>와 한정 메뉴가 조금씩 다릅니다. 중복은 960숙성뼈등심이고 함덕점은 1일 80인분만 판매를 하기 때문에 먼저 주문을 하시는 걸 추천드려요. 저희는 960 숙성 뼈등심과 720 숙성 뼈목살 그리고... ",
# 			"bloggername":"즐거운하민",
# 			"bloggerlink":"blog.naver.com\/jiny1445",
# 			"postdate":"20230811"
# 		},
# 		{
# 			"title":"광주 첨단 라운지 OIC <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/psm_1230\/223180332842",
# 			"description":"다양한 메뉴가 있는데 우리는 이미 다녀와본 동생의 <b>추천메뉴<\/b>로 시오세트로 토마호크스테이크와 시그니처샐러드 메인메뉴는 트러플 까르보나라에 스테이크 김치라이스를 추가로 주문하였다! 시오 세트에... ",
# 			"bloggername":"찬둥",
# 			"bloggerlink":"blog.naver.com\/psm_1230",
# 			"postdate":"20230810"
# 		},
# 		{
# 			"title":"파리바게트 <b>추천메뉴<\/b> 애플망고 생크림빵, 에그베이컨 토스트... ",
# 			"link":"https:\/\/blog.naver.com\/sangyun1106\/223193499353",
# 			"description":"그래서 2개 메뉴를 모두 <b>추천메뉴<\/b>라고 적어 포스팅하게 되었습니다! 파리바게트 에그베이컨토스트도, 파리바게트 애플망고 생크림빵도, 저에게 있어서 가성비 좋게 맛있었고, 재구매의사도 매우... ",
# 			"bloggername":"N잡러민초파의 쩝쩝박사 도전기",
# 			"bloggerlink":"blog.naver.com\/sangyun1106",
# 			"postdate":"20230825"
# 		},
# 		{
# 			"title":

# 			"postdate":"20230816"
# 		},
# 		{
# 			"title":"캠핑음식<b>추천 메뉴<\/b>로 꼽은 서택기 쪽갈비 후기",
# 			"link":"https:\/\/blog.naver.com\/liz_kang\/223194756538",
# 			"description":"캠핑음식추천 가격: 32,900원 용량: 1.5kg 글, 사진 ⓒ 맛, 그리고 여행 by 리즈 오늘은 캠핑음식<b>추천메뉴<\/b>로... 에어프라이기에 사용해 굽는것도 맛있었지만 캠핑갈 때 메뉴를 찾는 다면 서택기 쪽갈비 추천해요.... ",
# 			"bloggername":"맛 그리고 여행, 리즈✈",
# 			"bloggerlink":"blog.naver.com\/liz_kang",
# 			"postdate":"20230827"
# 		},
# 		{
# 			"title":"탄탄면공방 인천 청라 점심 <b>추천 메뉴<\/b> 후기",
# 			"link":"https:\/\/blog.naver.com\/tyamo1126\/223173282243",
# 			"description":"메뉴 추천 옆으로 넘겨서 보세요 요즘은 주문을 다 키오스크로 하죠! 요리가 어느 정도 매운 거로 유명한데요. 보시다시피 맵기 조절이 가능합니다! 맵기 가이드가 나와 있으니 참고하시기 바랍니다. <b>추천 메뉴<\/b>... ",
# 			"bloggername":"소개 손님 NO1 안심설계사, 치즈보험",
# 			"bloggerlink":"blog.naver.com\/tyamo1126",
# 			"postdate":"20230803"
# 		},
# 		{
# 			"title":"가창 룰리커피 <b>추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/ggomz2\/223189164232",
# 			"description":"룰리커피 <b>추천메뉴<\/b>는 아이스크림 커피다. 아이스크림도 쫀득한데 커피가 쫀득해.. 아이스크림을 엄청 좋아하는데 이 날은 커피부터 다 먹어버림. 진짜 맛있었다. 디카페인 아이스크림 커피 추천합니다. 저는... ",
# 			"bloggername":"healing",
# 			"bloggerlink":"blog.naver.com\/ggomz2",
# 			"postdate":"20230821"
# 		},
# 		{
# 			"title":"쉑쉑버거 강력 <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/talesoff\/223165028837",
# 			"description":"쉑쉑버거의 강력 <b>추천 메뉴<\/b>중의 하나인 바닐라쉐이크. 진하고 녹진한 맛이 다른 쉐이크를 압도한다.... 진리라고 생각하는 분들께 쉑스택버거를 강력 추천하며 포스팅을 마친다. #쉑쉑버거 #쉑스택 #<b>추천<\/b> #<b>메뉴<\/b>",
# 			"bloggername":"Balance",
# 			"bloggerlink":"blog.naver.com\/talesoff",
# 			"postdate":"20230724"
# 		},
# 		{
# 			"title":"렌지쿠캣 <b>추천메뉴<\/b> 직화삼겹살 바베큐족발 찰순대 간단하게... ",
# 			"link":"https:\/\/blog.naver.com\/westside1472\/223196533510",
# 			"description":"나머지 <b>메뉴<\/b>들은 렌지업으로 간편하게 조리할 수 있어서 주말<b>메뉴<\/b>로 딱 좋았어요. 집에서 족발 먹을 때는 무조건 뼈없는족발을 선호하는데 렌지쿠캣 바베큐족발 쫀득하니 양념까지 넘 맛있어서 진심 반해버린.... ",
# 			"bloggername":"선물같은 하루. Recipe",
# 			"bloggerlink":"blog.naver.com\/westside1472",
# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"bhc 핫후라이드, 마법클 먹어봄! <b>추천 메뉴<\/b>는?",
# 			"link":"https:\/\/blog.naver.com\/whitehousez\/223193208634",
# 			"description":"bhc 마법클, 핫후라이드 둘 다 먹어보고 남기는 <b>추천 메뉴<\/b> 저번 주말 낮에 놀러나갔는데 밥을 안 해두고... 배민에서 마법클 신메뉴 할인 중이라 4천원 할인에 포장 할인 1천원까지 해서 16,000원에 사 왔다.... ",
# 			"bloggername":"뽀기 일상",
# 			"bloggerlink":"blog.naver.com\/whitehousez",
# 			"postdate":"20230825"
# 		},
# 		{
# 			"title":
<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/jungwun113\/223195115883",
# 			"description":"유아식 메뉴 추천합니다 같이 보면 좋은 글 한그릇 뚝딱 유아식 <b>추천 메뉴<\/b> ▼아기 잔치국수 만들기▼ https:\/\/blog.naver.com\/jungwun113\/222741256376 ▼닭다리 삼계탕 만들기▼ https:\/\/blog.naver.com\/jungwun113\/222808033159",
# 			"bloggername":"하얀솜구름의 구름공방",
# 			"bloggerlink":"blog.naver.com\/jungwun113",
# 			"postdate":"20230827"
# 		},
# 		{
# 			"title":"[서현 맛집\/샌드위치] 써브웨이 <b>추천 메뉴<\/b> 치킨데리야끼 서브웨이",
# 			"link":"https:\/\/blog.naver.com\/ncoco1989\/223181414793",
# 			"description":"<b>추천 메뉴<\/b> 치킨데리야키 맛있는 건강한 맛 #써브웨이서현 #서현써브웨이 #써브웨이가격 #써브웨이<b>추천메뉴<\/b> #써브웨이메뉴추천 #분당써브웨이 #써브웨이메뉴 #치킨데리야키 #치킨데리야끼 #써브웨이치킨데리야키",
# 			"bloggername":"비만소년의 밥",
# 			"bloggerlink":"blog.naver.com\/ncoco1989",
# 			"postdate":"20230811"
# 		},
# 		{
# 			"title":"홍콩 맛집 - 남기분면 | <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/sowon7531\/223183847868",
# 			"description":"들어간 <b>메뉴<\/b> 무조건 <b>추천<\/b>합니다. 개인적으로 돼지 고기 들어간 게 맛있더라고요. 탕은 사우어 앤 스파이시, 시고 매운 탕 <b>추천<\/b> 합니다. 실패 없는 가게니... ",
# 			"bloggername":"in the midnight with bergamot",
# 			"bloggerlink":"blog.naver.com\/sowon7531",
# 			"postdate":"20230815"
# 		},
# 		{
# 			"title":"대전 시청 맛집 친절하고 맛있는 기봉이김밥 <b>추천 메뉴<\/b> 가격",
# 			"link":"https:\/\/blog.naver.com\/onlyone328\/223197402781",
# 			"description":"식사하고싶을때 <b>추천<\/b>하고싶은 대전 맛집 기봉이김밥 오후에 이것저것먹어서 간단히 기봉이김밥... 기봉이김밥 기봉이김밥 <b>메뉴<\/b> 및 가격 맛있는 김밥 기본 셋팅셀프바에 국이랑 김치 단무지 배치 국에 이런... ",
# 			"bloggername":"Become a better you.",
# 			"bloggerlink":"blog.naver.com\/onlyone328",
# 			"postdate":"20230830"
# 		},
# 		{
# 			"title":"여름음식 <b>추천<\/b> 점심 회식<b>메뉴<\/b> 고민 해결",
# 			"link":"https:\/\/blog.naver.com\/sfiscbrai582\/223186845565",
# 			"description":"점심 뿐 아니라 회식 <b>추천 메뉴<\/b>로 오늘 점심 메뉴로 시원 칼칼한 여름철 보양식부터 속까지 시원한 음식까지 추천해 볼게요. 여름음식으로 추천하는 점심 콩국수 여름철 한정 메뉴로 많이 볼 수 있는 콩국수는... ",
# 			"bloggername":"blue holic\"s story",
# 			"bloggerlink":"blog.naver.com\/sfiscbrai582",
# 			"postdate":"20230818"
# 		},
# 		{
# 			"title":"(대구\/중구\/동성로\/반월당\/맛집) 한끼 <b>추천 메뉴<\/b> 낙지볶음",
# 			"link":"https:\/\/blog.naver.com\/ssugidapgae\/223196934660",
# 			"description":"낙지볶음은 점심 또는 저녁 한끼 식사로 <b>추천<\/b>하는 <b>메뉴<\/b>이다. 같이 간 친구는 그냥 그렇다고 하는 데 나는 맛있게 먹었다. 매콤해서 나는 더 마음에 들었다. 그런데 좀 많이 맵긴했다. 매운 걸 못먹는 사람은... ",
# 			"bloggername":"놀자~ 쑥!",
# 			"bloggerlink":"blog.naver.com\/ssugidapgae",
# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"에그드랍 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/wqongs90312.tistory.com\/949",
# 			"description":"에그드랍에서 맛있는 샌드위치를 먹어보고 싶다면, 아래의 <b>추천 메뉴<\/b>들을 한 번 시도해보세요! 1.... 담백하고 베이직한 맛을 선호한다면 이 메뉴를 추천드립니다. 6. 데리야끼 바베큐: 4700원 돼지고기... ",
# 			"bloggername":"굳은살",
# 			"bloggerlink":"https:\/\/wqongs90312.tistory.com\/",
# 			"postdate":"20230817"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Wed, 30 Aug 2023 12:52:04 +0900",
# 	"total":17886004,
# 	"start":101,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"서면국물닭발로 유명한 옥탑방 두얼간이 서면점 <b>추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/beautifulsun_\/223186912713",
# 			"description":"부분 <b>메뉴<\/b>를 <b>추천<\/b>하는데 서면국물닭발로 유명한 집 답게 국물닭발이 이 가게의 대표<b>메뉴<\/b>지만 난 궁극의 마라순두부 픽했다 마라탕이나 마라전골 먹고 싶으면 이젠 이것부터 생각날 듯 궁극이 붙어서... ",
# 			"bloggername":"해야, 고운 해야",
# 			"bloggerlink":"blog.naver.com\/beautifulsun_",
# 			"postdate":"20230818"
# 		},
# 		{
# 			"title":"휘닉스평창 블루캐니언 푸드코트 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/dreamingsoy\/223173137029",
# 			"description":"강원도 휘닉스평창 워터파크 블루캐니언 푸드코트 <b>추천 메뉴<\/b> &amp; 후기 올 봄에 블루캐니언 연회원권을... 13,000원 #메뉴추천 이것저것 시켜먹어본 결과 개인적으로는 돈까스(프리미엄 등심카츠)는 무조건 기본... ",
# 			"bloggername":"주말엔 캠핑 :)",
# 			"bloggerlink":"blog.naver.com\/dreamingsoy",
# 			"postdate":"20230802"
# 		},
# 		{
# 			"title":"bhc치킨 <b>추천메뉴<\/b> 뿌링클콤보 식후감뿌링",
# 			"link":"https:\/\/blog.naver.com\/prettystaarlove\/223183402897",
# 			"description":"애들 입맛은 비슷비슷하지않을까 치즈가루맛이 굉장히 센데 요즘 뭐 마라탕도 탕후루도 그렇고 극강의 맛이 중독적이긴 하니까요 한번 드셔보세요+_+ 내돈내산리뷰:) #뿌링클콤보가격 #BHC<b>메뉴<\/b><b>추천<\/b> #뿌링클치킨",
# 			"bloggername":"Simple is the best",
# 			"bloggerlink":"blog.naver.com\/prettystaarlove",
# 			"postdate":"20230814"
# 		},
# 		{
# 			"title":"bhc치킨 <b>메뉴<\/b> <b>추천<\/b> 골드킹 콤보 뿌링클 세트로",
# 			"link":"https:\/\/blog.naver.com\/ssung0904\/223176360930",
# 			"description":"베스트 <b>추천 메뉴<\/b> 맛있는 치킨 두마리 깁콘 받았어요 안 그래도 초등 고학년 저학년 아이들 1인 1닭... 대표 메뉴 추천하는 이유인즉슨 시즈닝 독특한 뿌링뿌링클 단짠 달달하면서 짭쪼로미하니 치토스 서타일... ",
# 			"bloggername":"효로롱 푸드로그",
# 			"bloggerlink":"blog.naver.com\/ssung0904",
# 			"postdate":"20230806"
# 		},
# 		{
# 			"title":"태국 방콕여행 왓아룬 야경 맛집\/ 더데크 예약 <b>추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\
뉴<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/a_reumzz\/223184547372",
# 			"description":"호우섬 <b>메뉴<\/b> 및 가격 올때마다 시키게되는 블랙하가우랑 라구짜장 도삭면은 필수 <b>메뉴<\/b> 다섯개... 향한 아기새의 손 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 갈때마다 만족하는 호우섬 딤섬이 먹고싶을때 <b>추천<\/b>합니다 &amp; &amp;",
# 			"bloggername":"뚜비뚜비의 하루♩",
# 			"bloggerlink":"blog.naver.com\/a_reumzz",
# 			"postdate":"20230815"
# 		},
# 		{
# 			"title":"찐만족한 세트<b>메뉴<\/b> <b>추천<\/b> 제주공항 근처 갈치구이 솔직후기",
# 			"link":"https:\/\/blog.naver.com\/abbbbbb123\/223197076631",
# 			"description":"저희는 자리에 앉아, 다양한 구성의 세트<b>메뉴<\/b>들이 눈에 띄어서 <b>메뉴<\/b>판을 살펴보다가 맛있어 보이는... 다른분들도 만족도 높은 식사를 하길 바라며 <b>추천<\/b>해 봅니다 #제주공항근처갈치구이 #갈치음식점 궁서체",
# 			"bloggername":"비글맘과 꼬꼬마아빠의 육아일상",
# 			"bloggerlink":"blog.naver.com\/abbbbbb123",
# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"운양동 맛집 부글식당 <b>추천메뉴<\/b>곱창사발!",
# 			"link":"https:\/\/blog.naver.com\/sin0788\/223165637406",
# 			"description":"운양동 맛집 부글식당 <b>추천메뉴<\/b> 곱창사발! 저희는 다른메뉴도 같이 먹고 싶어서 곱창사발이라는... 부글식당 배달도 되니 집에서 야식으로도 추천 곱창 오동통한거 보이시나요? 곱이 가득 들어있는데 잡내... ",
# 			"bloggername":"Happily Ever After",
# 			"bloggerlink":"blog.naver.com\/sin0788",
# 			"postdate":"20230725"
# 		},
# 		{
# 			"title":"소하염전 경주 : 황리단길에 들어온 소금빵 맛집 카페 <b>추천메뉴<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/psybobo11\/223190411032",
# 			"description":"전체적인 <b>메뉴<\/b> 베이커리는 소금빵이 주이고, 음료는 많지는 않고 딱 적당했다. &lt;주문<b>메뉴<\/b>&gt; -쪽파... 나는 내가 픽한 두 소금빵 완전 <b>추천<\/b>한다. 그런데 한가지 아쉬운건... 경주에서 일정 끝내고 집에 올 때 소금빵... ",
# 			"bloggername":"✿아람의 사계절 여행일기✿",
# 			"bloggerlink":"blog.naver.com\/psybobo11",
# 			"postdate":"20230822"
# 		},
# 		{
# 			"title":"서울여행 :: 석촌 야끼소바 니주마루 <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/nayuarmu\/223170133514",
# 			"description":"줄을 서서 기다리고 있다가 우리 차례 근처가 되면 미리 메뉴판을 주는데, 우리는 <b>추천 메뉴<\/b>를 둘 다 주문해서 먹어 보기로 했다. <b>추천 메뉴<\/b>인 소금 + 오징어, 새우 \/ 소스 + 치즈 + 비엔나의 두 종류 야끼소바와... ",
# 			"bloggername":"Memoria, 여행더하기",
# 			"bloggerlink":"blog.naver.com\/nayuarmu",
# 			"postdate":"20230730"
# 		},
# 		{
# 			"title":"판교맛집 에그슬럿분당정자 오픈 <b>메뉴<\/b><b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\
# 			"title":"정자동영커피 <b>추천<\/b>하는 영커피<b>메뉴<\/b>",
# ...
# 			"bloggername":"Simple is the best",
# 			"bloggerlink":"blog.naver.com\/prettystaarlove",
# 			"postdate":"20230808"
# 		},
# 		{
# 			"title":"차이나타운 맛집, 해산물 없는 게 없는 &lt;fikeaw&gt; <b>추천 메뉴<\/b>!!",
# 			"link":"https:\/\/blog.naver.com\/wndufmiju\/223076392649",
# 			"description":"방콕 차이나타운 맛집 해산물 가득한 fikeaw 파이커우 별 3개 ★★★ 모험심이 강하신 분들 이미 한국인분들의 <b>추천 메뉴<\/b>들 말고 다른 메뉴들을 먹어보시길 추천드린다^^ #방콕차이나타운 #방콕차이나타운맛집... ",
# 			"bloggername":"니니의 맛있는 여행 이야기",
# 			"bloggerlink":"blog.naver.com\/wndufmiju",
# 			"postdate":"20230416"
# 		},
# 		{
# 			"title":"춘천 점심<b>메뉴<\/b> <b>추천<\/b> 카츠탄탄에서 파스타와 돈까스",
# 			"link":"https:\/\/blog.naver.com\/7812woor\/223177222487",
# 			"description":"춘천 점심<b>메뉴<\/b> <b>추천<\/b> 카츠탄탄에서 파스타와 돈까스 오늘 점심은 방학중인 첫째와 함께 카츠탄탄에 다녀왔어요 갑자기 파스타가 먹고 싶다고 하는데 더워서 멀리는 못 가겠고 집 주변에 찾다 보니 카츠탄탄이... ",
# 			"bloggername":"윰슐랭 가이드 ⚆_⚆ ♡",
# 			"bloggerlink":"blog.naver.com\/7812woor",
# 			"postdate":"20230807"
# 		},
# 		{
# 			"title":"[BHC치킨] <b>추천 메뉴<\/b> 골드킹 · 맛초킹 사이드 메뉴 뿌링소떡과... ",
# 			"link":"https:\/\/blog.naver.com\/food-bloger\/223119634188",
# 			"description":"프랜차이즈랑 <b>메뉴<\/b> <b>추천<\/b>하면 항상 먼저 언급되는 BHC치킨의 맛초킹 강력 <b>추천<\/b>드리고 싶네요 지금까지 치킨 프랜차이즈 1위 bhc 골드킹 &amp; 맛초킹 치킨 외 사이드 <b>메뉴<\/b> 내돈내산 솔직 후기였습니다 감사합니다... ",
# 			"bloggername":"TAE IN Daily",
# 			"bloggerlink":"blog.naver.com\/food-bloger",
# 			"postdate":"20230608"
# 		},
# 		{
# 			"title":"이색 넓적 우동 맛집 요미우돈 교자 연남점 <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/gaoxing22\/223189138885",
# 			"description":"이색 넓적 우동 맛집 요미우돈교자 연남점 <b>추천 메뉴<\/b> 요미우돈교자 연남점 주소: 서울 마포구 동교로... 요기 대표메뉴는 넓적 우동이고요. 간판에 교자가 들어가니 교자도 많이들 드시더라구요. 주문은... ",
# 			"bloggername":"중국어 손쌤 블로그",
# 			"bloggerlink":"blog.naver.com\/gaoxing22",
# 			"postdate":"20230821"
# 		},
# 		{
# 			"title":"신용산 맛집 아모레퍼시픽 근처 화양연화 <b>추천메뉴<\/b> 공유할게요",
# 			"link":"https:\/\/blog.naver.com\/mippeumi\/223101966112",
# 			"description":"왔으니 <b>추천 메뉴<\/b>도 귀띔해 드릴게요 저희는 이태원쪽에 데이트를 하러 갔다가 산책(?)도 할 겸... 이 메뉴 역시 양념에 재워진 상태로 나온 모습이 더 먹음직스러워보였네요 그리고 진짜 강력 추천하고 싶은... ",
# 			"bloggername":"솔직한 여자 미쁘미의 맛집 여행",
# 			"bloggerlink":"blog.naver.com\/mippeumi",
# 			"postdate":"20230514"
# 		},
# 		{
# 			"title":"대만 위스키 카발란 바 <b>추천메뉴<\/b>, 예약방법",
# 			"link":"https:\/\/blog.naver.com\/cornjini\/223196323638",
# 			"description":"카발란 바 예약방법 저는 예약없이 방문했지만 워낙 인기가 좋은곳이라 예약하고 방문하길 추천드려... <b>추천 메뉴<\/b>로는 &quot; KAVALAN TRIO FLGHT &quot; 위스키 3종세트로 오크통에 있는 위스키를 맛볼수 있는 샘플러에요... ",
# 			"bloggername":"트래블리콘지니 CORNJINILOG",
# 			"bloggerlink":"blog.naver.com\/cornjini",
# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"복날에 뭐 먹지? 삼복 더위 이기는 복날 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.hyosung.com\/m\/5945",
# 			"description":"삼복 더위 이기는 복날 <b>메뉴<\/b> <b>추천<\/b> 효성blog 2023. 7. 11. 17:35 올해는 엘리뇨 현상으로 인해 평년보다 강수량이 많을 것이라는 예측이 있죠. 무더운 장마 시즌의 시작, 초복이 찾아왔어요! 계절상 초복은 삼복 중 첫... ",
# 			"bloggername":"미디어 효성 블로그",
# 			"bloggerlink":"https:\/\/blog.hyosung.com\/",
# 			"postdate":"20230711"
# 		},
# 		{
# 			"title":"순천분식 [명인만두] 새벽영업, 종류 다양한 밥집 <b>추천<\/b> \/ <b>메뉴<\/b>추천",
# 			"link":"https:\/\/blog.naver.com\/angelrlaaltn\/223188440105",
# 			"description":"맛있었던 <b>메뉴<\/b> <b>추천<\/b>해드릴게요 갈비만두 명인만두는 찐만두, 튀긴만두가 따로 있더라구요! 갈비만두는 촉촉하게 먹는게 좋으니까 찐만두로 주문했어요 먹기 좋은 사이즈의 만두가 10개 나오는데 갈비만두는... ",
# 			"bloggername":"스누미 일기장",
# 			"bloggerlink":"blog.naver.com\/angelrlaaltn",
# 			"postdate":"20230820"
# 		},
# 		{
# 			"title":"문정동 카페 히치 Hitch by 커피와이컴퍼니 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/ybnver\/223195505276",
# 			"description":"문정동 카페 히치 Hitch by 커피와이컴퍼니 <b>메뉴<\/b> <b>추천<\/b> 집 근처에 있는 문정동 카페 히치 Hitch 커피와이컴퍼니였을 시절에는 자주갔지만 히치로 리뉴얼 되고나 서는 한번도 안가봤다 외부부터 넘 귀엽고... ",
# 			"bloggername":"Bon voyage.",
# 			"bloggerlink":"blog.naver.com\/ybnver",
# 			"postdate":"20230828"
# 		},
# 		{
# 			"title":"[꼬리치는남자\/돼지꼬리족발] 야식<b>메뉴<\/b><b>추천<\/b>! 간단한안주... ",
# 			"link":"https:\/\/blog.naver.com\/mint990608\/223192578890",
# 			"description":"그럴 때 딱인 혼술안주<b>추천<\/b>! 돼지꼬리족발 돼지꼬리는 껍데기와 지방 살코기가 고르게 섞여있는... 쟁여놓고 생각날 때 마다 먹어야지 ㅠㅠㅠ 간단한 혼술안주, 야식<b>메뉴<\/b>, 캠핑요리로 강추! 저는 건강한 리뷰... ",
# 			"bloggername":"따뚜의 돼지런한 먹로그",
# 			"bloggerlink":"blog.naver.com\/mint990608",
# 			"postdate":"20230824"
# 		},
# 		{
# 			"title":
# 			"title":"치킨 <b>추천<\/b> 땅땅불갈비 후왕 세트<b>메뉴<\/b> 땅땅치킨 선부점 (feat... ",
# 			"link":"https:\/\/blog.naver.com\/winterainy\/223143182368",
# 			"description":"사실 야외에서 먹으면 어떤 치킨이라도 <b>추천 메뉴<\/b>로 등극시킬 수 있지요. 실내 분위기는 파스텔 동화풍... 땅땅불갈비 치킨으로 다음 메뉴 추천은 뭐다? 치밥이다! 냉장고에서 잠들어있던 찬밥 한공기. 땅땅... ",
# 			"bloggername":"제이원 & 제이은 's life",
# 			"bloggerlink":"blog.naver.com\/winterainy",
# 			"postdate":"20230630"
# 		},
# 		{
# 			"title":"양재 카페 투썸플레이스 <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/annnz0\/223185515692",
# 			"description":"오늘은 투썸플레이스에서 식사 대용으로 <b>추천<\/b>하는 <b>메뉴<\/b>를 소개할게요! 투썸플레이스 포이DI점은 양재천과 가까워서 뷰도 좋고 주차까지 가능해요! 주차장 이용 안내 투썸플레이스 영수증 1장당 1대... ",
# 			"bloggername":"서울언니",
# 			"bloggerlink":"blog.naver.com\/annnz0",
# 			"postdate":"20230816"
# 		},
# 		{
# 			"title":"레시피 요리 맛보장 고추장 제육볶음 양념장 오늘 저녁<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/baby0817\/223150258432",
# 			"description":"바로 먹을 수 있을때까지 볶아 오늘저녁<b>메뉴<\/b><b>추천<\/b> 고추장제육볶음 만들어 주세요. 사실 진짜 귀찮을 때는 이렇게 대패삼겹살을 볶아서 한 쌈 즐기면 든든한 한 끼를 드실 수 있죠. 기름이 충분해서 볶고 나면... ",
# 			"bloggername":"축복받은 유전자 완소남매의 엄마표 먹거리",
# 			"bloggerlink":"blog.naver.com\/baby0817",
# 			"postdate":"20230708"
# 		},
# 		{
# 			"title":"복날에 뭐 먹지? 삼복 더위 이기는 복날 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.hyosung.com\/5945",
# 			"description":"삼복 더위 이기는 복날 <b>메뉴<\/b> <b>추천<\/b> 스토리\/효성 2023. 7. 11. 올해는 엘리뇨 현상으로 인해 평년보다 강수량이 많을 것이라는 예측이 있죠. 무더운 장마 시즌의 시작, 초복이 찾아왔어요! 계절상 초복은 삼복 중 첫... ",
# 			"bloggername":"미디어 효성 블로그",
# 			"bloggerlink":"https:\/\/blog.hyosung.com\/",
# 			"postdate":"20230711"
# 		},
# 		{
# 			"title":"[안산 사동] 사리역 근처 족발 맛집 , 사리역 배달 <b>추천 메뉴<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/nan2510\/223197381408",
# 			"description":"<b>메뉴<\/b>는 당연히 족발 보쌈이 주<b>메뉴<\/b>고 술한잔하면서 먹을 수 있는 사이드 <b>메뉴<\/b>들이 준비가... 드시는것도 <b>추천<\/b>드립니다. 오늘 완미족발에서 족발을 먹었는데요 족발집중에서는 그래도 맛있는편이라 근처에... ",
# 			"bloggername":"피브이",
# 			"bloggerlink":"blog.naver.com\/nan2510",
# 			"postdate":"20230830"
# 		},
# 		{
# 			"title":"냉우동 소스 육수 레시피 냉우동 만들기 주말 점심<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\
<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/hhyejjin0810\/223185888715",
# 			"description":"가게 들어올 때 부터 뭔가 버터에 오징어 냄새가 났는데 ( 그 영화관에서 파는 버터구이 냄새!) 파스타 면도 생각보다 부드럽고 오징어도 엄청 부드러워서 이거는 꼭 <b>추천<\/b>하는 <b>메뉴<\/b>. 재방문해도 재주문... ",
# 			"bloggername":"366일 유지어터의 일상",
# 			"bloggerlink":"blog.naver.com\/hhyejjin0810",
# 			"postdate":"20230817"
# 		},
# 		{
# 			"title":"베스킨라빈스 <b>메뉴<\/b> <b>추천<\/b> 가격 영업시간 케이크 베라<b>메뉴<\/b> 맛종류.",
# 			"link":"https:\/\/blog.naver.com\/rivertour\/223107562044",
# 			"description":"#베스킨라빈스메뉴 #베라맛추천 #베스킨라빈스가격 #베스킨라빈스케이크 #베라메뉴 #베라맛종류... 개인적으로 베스킨라빈스 <b>추천 메뉴<\/b>는 슈팅스타, 체리쥬빌레, 엄마는외계인 레인보우샤베트... ",
# 			"bloggername":"방랑 그리고 그날을 기다리며...",
# 			"bloggerlink":"blog.naver.com\/rivertour",
# 			"postdate":"20230521"
# 		},
# 		{
# 			"title":"돈가츠 하남미사점 : 촉촉한 일식 돈가츠 <b>추천<\/b> (<b>메뉴<\/b>\/정식\/후기)",
# 			"link":"https:\/\/blog.naver.com\/chaeyeon_park\/223197413983",
# 			"description":"먹을수 있어 좋았다 돈가츠도 바삭바삭 맛있었고, 냉모밀도 시원해서 여름에 딱이었던 <b>메뉴<\/b>! 간단하게 점심이나, 혼밥 하기도 좋았던 미사역맛집 삼백돈 돈가츠 <b>추천<\/b>!  열심히 먹방찍는 포스트 더 보려면 아래로!",
# 			"bloggername":"뚝딱거리는 한국생활",
# 			"bloggerlink":"blog.naver.com\/chaeyeon_park",
# 			"postdate":"20230830"
# 		},
# 		{
# 			"title":"에어프라이어 돈가스 나베 요리 쯔유활용 집밥 저녁<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/aza1104\/223195440551",
# 			"description":"돈까스 김치나베 레시피 김치가츠나베 만들기 에어프라이어 돈가스 나베 요리 쯔유활용 집밥 저녁<b>메뉴<\/b> <b>추천<\/b> 안녕하세요~ 푸드 인플루언서 쿡쿡이 입니다:) 바삭하고 고소한 맛의 돈까스 좋아하시는 분들... ",
# 			"bloggername":"쿡쿡이의 홈쿡 레시피",
# 			"bloggerlink":"blog.naver.com\/aza1104",
# 			"postdate":"20230828"
# 		},
# 		{
# 			"title":"인계동 맛집 점심<b>메뉴<\/b><b>추천<\/b> 쭈꾸미덮밥",
# 			"link":"https:\/\/blog.naver.com\/hyeona0304\/223167741630",
# 			"description":"&lt;인계동 맛집 점심<b>메뉴<\/b><b>추천<\/b> 쭈꾸미덮밥&gt; (테이블에서 <b>메뉴<\/b>주문하고 결제까지 가능한 시스템) 아직까지 이런 시스템이 적응이 안되서인지 너무 맛있게 먹어서인지 나올때 또 결제하러 카운터로 감 ㅋㅋㅋ... ",
# 			"bloggername":"☞♥☜탐나는부동산☆＊＊＊",
# 			"bloggerlink":"blog.naver.com\/hyeona0304",
# 			"postdate":"20230727"
# 		},
# 		{
# 			"title":"서브웨이 꿀조합 에그마요 <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/brightenedu\/223027487767",
# 			"description":"오늘은 간단한 점심으로 먹은 서브웨이 꿀조합 에그마요 <b>추천 메뉴<\/b> 후기를 써보려고 해요. 가장 기본... 이왕이면 5가지 채소를 다 넣어 달달한 채즙 버퍼 활용해야 에그마요 꿀조합으로 서브웨이 메뉴 추천할... ",
# 			"bloggername":"김원장의 탐구생활",
# 			"bloggerlink":"blog.naver.com\/brightenedu",
# 			"postdate":"20230225"
# 		},
# 		{
# 			"title":"가산테라타워 본점 :: 가산맛집 혼밥<b>메뉴<\/b> 토마토스튜 찜닭 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/luuuuuucy\/223140902214",
# 			"description":"16:00  <b>추천 메뉴<\/b> 토마토 스튜 찜닭애 비가 한바탕 쏟아지고 난 뒤 잠깐 안 오는 틈을 타 방문해서 먹고... 메뉴 토마토 스튜 찜닭애 순살 곤드레 나물밥 건강한 흑미밥 돈까스 토핑 서비스❤️ 묵은지와... ",
# 			"bloggername":"Lucete✨",
# 			"bloggerlink":"blog.naver.com\/luuuuuucy",
# 			"postdate":"20230628"
# 		},
# 		{
# 			"title":"샐러디 <b>메뉴<\/b> <b>추천<\/b>! 칠리베이컨 웜볼, 바질치킨 랩",
# 			"link":"https:\/\/blog.naver.com\/sy900523\/223183952160",
# 			"description":"샐러디 <b>메뉴<\/b> <b>추천<\/b>! 칠리베이컨 웜볼, 바질치킨 랩 안녕하세요. 오반짝입니다 : ) 개인 피티 끝나고 동네친구랑 톡해서 급 점심 먹으러 왔어요. 둘다 나름~ 다이어트중이라 어디갈까 하다가 샐러디 왔어요. 원래는... ",
# 			"bloggername":"오반짝양의 반짝반짝일상",
# 			"bloggerlink":"blog.naver.com\/sy900523",
# 			"postdate":"20230815"
# 		},
# 		{
# 			"title":"이삭토스트 <b>메뉴<\/b> <b>추천<\/b> 허니갈릭햄치즈 소스 맛있어요",
# 			"link":"https:\/\/blog.naver.com\/don219\/223181176303",
# 			"description":"이삭토스트 <b>메뉴<\/b> <b>추천<\/b> 주말에는 뭐먹지? 하루세끼 집밥을 만들어서 챙겨먹기 쉽지않은데요 잠깐외출하러 나갔다가 이삭토스트 가 눈에 보이길래 오늘의아침은 이거다!! 반가워서 들어갔어요 햄치즈야채와... ",
# 			"bloggername":"먀+돈=우수형제❤",
# 			"bloggerlink":"blog.naver.com\/don219",
# 			"postdate":"20230811"
# 		},
# 		{
# 			"title":"맛집 물회가 맛있는 보재기집(짠내투어 방송 출연, <b>추천 메뉴<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/kim4993300\/223110859408",
# 			"description":"저의 <b>추천 메뉴<\/b>는 보재기 해물 물회입니다. 가격은 5천 원 차이인데 물회보다는 해물이 추가된 해물 물회가 더 푸짐하고 맛나요. 거제 보재기집 메뉴 &amp; 가격 정보 푸짐한 한상의 보재기 해물 물회가... ",
# 			"bloggername":"네이버 여행 인플루언서_일상도 여행처럼",
# 			"bloggerlink":"blog.naver.com\/kim4993300",
# 			"postdate":"20230524"
# 		},
# 		{
# 			"title":"오랜만에 올리는 저희 부부 일상 집밥 점심 저녁 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/jungceo_blog\/223179875898",
# 			"description":"ㅋㅋ 이렇게 최근 맛있게 먹었던 일상 점심 저녁 <b>메뉴<\/b> <b>추천<\/b> 포스팅도 전부 마무리 되네요. 정말 오랜만에 올리는 저희 부부 일상 집밥 <b>메뉴<\/b> 후기인데요. 집에서 점심 저녁 <b>메뉴<\/b> 고민되실때 한 번 <b>추천<\/b>드리고... ",
# 			"bloggername":"정사장 부부 맛집투어",
# 			"bloggerlink":"blog.naver.com\/jungceo_blog",
# 			"postdate":"20230810"
# 		},
# 		{
# 			"title":"직장인 수제 도시락 <b>메뉴<\/b> <b>추천<\/b> &lt;도시락파는삼촌&gt; 든든한 점심",
# 			"link":"https:\/\/blog.naver.com\/enduq743\/223182784205",
# 			"description":"점심 <b>메뉴<\/b>가 고민이신 여러분께 <b>추천<\/b>할 수 있는 &lt;도시락파는삼촌&gt; 저렴한 세트 구성으로 다양하게 즐길 수 있어 점심시간이 매일 즐거울 수 있었어요 저는 재주문 의사 31285% 정도...? 세트로 사서 냉동고에... ",
# 			"bloggername":"서울 소시민 햄찌의 삶",
# 			"bloggerlink":"blog.naver.com\/enduq743",
# 			"postdate":"20230813"
# 		},
# 		{
# 			"title":"스테이크맛집 <b>메뉴<\/b><b>추천<\/b> 내돈내산 솔직후기",
# 			"link":"https:\/\/blog.naver.com\/jejeje8294\/223191531068",
# 			"description":"이러고 다 집어 먹게 됩니다 엔둘리쉬림프파스타 입니다 치킨비비큐와 파스타 사이에서 고민 했는데요 친절한 직원분이, 고기류는 많으니 신<b>메뉴<\/b>인 파스타는 어떻냐고 <b>추천<\/b> 해주시더라구요 &gt;_&lt; 이런 센스 넘... ",
# 			"bloggername":"예비 인플루언서>_<",
# 			"bloggerlink":"blog.naver.com\/jejeje8294",
# 			"postdate":"20230823"
# 		},
# 		{
# 			"title":"지점 비교, 쉽게 찾아 가는 법, <b>추천메뉴<\/b> 그리고 굿즈가격",
# 			"link":"https:\/\/blog.naver.com\/bmclub27\/223161040938",
# 			"description":"있는데 <b>추천<\/b>하는 <b>메뉴<\/b>는 에스프레소초콜렛칩쿠키 블루베리머핀 랄프스 에스프레소 티라미수 뺑오쇼콜라, 크로와상은 무난하고 주변에서도 많이 시켜 먹는 것들 은근 케이크 먹는 사람은 잘 없었던 것 같은?... ",
# 			"bloggername":"Hong Kong Diary:)",
# 			"bloggerlink":"blog.naver.com\/bmclub27",
# 			"postdate":"20230720"
# 		},
# 		{
# 			"title":"bhc치킨 마법처럼 끌리는 마법클 야식 치킨<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/jsk3514\/223167894597",
# 			"description":"bhc치킨 신<b>메뉴<\/b> 마법처럼 끌리는 마법클 야식 치킨<b>메뉴<\/b> <b>추천<\/b> 한국인이라면 누구나 다 좋아하는 치킨 이웃님들은 어떤 치킨을 좋아하시나요. ? 치킨의 종류가 워낙 다양해져서 골라 먹는 재미도 좋지만 입맛에... ",
# 			"bloggername":"행주치마의 정겨운 집밥",
# 			"bloggerlink":"blog.naver.com\/jsk3514",
# 			"postdate":"20230810"
# 		},
# 		{
# 			"title":"용인 이케아 기흥점 맛집 레스토랑 식당 <b>추천 메뉴<\/b> 소프트콘 후기",
# 			"link":"https:\/\/blog.naver.com\/ddltnfka\/223185799893",
# 			"description":"이케아 <b>추천메뉴<\/b>는 닭고기 스테이크랑 라구 파스타 김치볶음밥입니다 돈까스 8,900원 불고기 볶음밥 5,900원 연어 필레 10,900원 미트볼 12개 8,900원도 있으니 원하시는 메뉴로 주문해서 가성비 좋으니 푸짐하게... ",
# 			"bloggername":"홈바리스타 푸디라미의 맛있는 방구석 레시피",
# 			"bloggerlink":"blog.naver.com\/ddltnfka",
# 			"postdate":"20230817"
# 		}
# 	]
# }

# %%
type(body)
# Out:
# str

# %%
body = body.replace('"','')
body
# Out:
# "{\n\tlastBuildDate:Wed, 30 Aug 2023 12:52:04 +0900,\n\ttotal:17886004,\n\tstart:1,\n\tdisplay:100,\n\titems:[\n\t\t{\n\t\t\ttitle:텐진 맛집 이치란 라멘 후쿠오카 웨이팅 주문 방법 <b>메뉴<\\/b> <b>추천<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/
<b>추천메뉴<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/swe_2tpotato\\/223194067673,\n\t\t\tdescription:직원분에게 <b>메뉴<\\/b> <b>추천<\\/b>을 요청드리니 요 <b>메뉴<\\/b>를 <b>추천<\\/b>해 주셨다!! 크림색 브랜디 맛의 페퍼 소스를 곁들인 페퍼 스테이크 스테이크 위에는 튀긴 야채와 사이드로 감자 오그라탕이 함께 제공되는데 이... ,\n\t\t\tbloggername:스윗포타토킴의 다이어트&먹로드 이야기 '-',\n\t\t\tbloggerlink:blog.naver.com\\/swe_2tpotato,\n\t\t\tpostdate:20230826\n\t\t},\n\t\t{\n\t\t\ttitle:바르셀로나 비니투스 <b>메뉴<\\/b><b>추천<\\/b>&amp;가격표 feat.VINITUS 파산잼,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/sophisticated-\\/223194545116,\n\t\t\tdescription:Cerveseria Catalana 세르베세리아 카탈라나 같은 체인이라 맛,분위기가 비슷해요 메뉴판,가격도... Catalana 추천 부과세10% 붙었더니 지갑이... 여자2명이서 <b>추천 메뉴<\\/b> 다 시키고 배부르게 먹은 가격이 이... ,\n\t\t\tbloggername:롤링의 Teenage Dream.,\n\t\t\tbloggerlink:blog.naver.com\\/sophisticated-,\n\t\t\tpostdate:20230827\n\t\t},\n\t\t{\n\t\t\ttitle:제주 오일장 feat. 춘향이네 <b>추천 메뉴<\\/b> 제주민속오일시장,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/7633974\\/223195157638,\n\t\t\tdescription:춘향이네 <b>메뉴<\\/b>에요 다 맛있을 것 같은 <b>메뉴<\\/b>들이에요 드시는 걸 봤는데 순대국밥, 비빔밥, 꼼장어... 순대는 <b>추천<\\/b>해요 ! 글 읽어주셔서 감사합니다 모두 즐거운 오일장되세요  #제주오일장 #춘향이네... ,\n\t\t\tbloggername:주연 블로그,\n\t\t\tbloggerlink:blog.naver.com\\/7633974,\n\t\t\tpostdate:20230828\n\t\t},\n\t\t{\n\t\t\ttitle:리스카페 정자 (주차, 웨이팅,<b>추천메뉴<\\/b>) - 찐 브런치 맛집!!,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/94yjung\\/223191159266,\n\t\t\tdescription:기분 째져~~~ 가게 앞에 크게 인쇄된 <b>메뉴<\\/b>판이 있어서 열심히 보면서 <b>메뉴<\\/b>를 정했다 근데 진짜 하나부터... 이용을 <b>추천<\\/b>드린다! (파라곤 지하주차장 2시간 지원된다고 함) 판교 사는 후배 <b>추천<\\/b>으로 다녀온만큼 진짜... ,\n\t\t\tbloggername:Blog_yun,\n\t\t\tbloggerlink:blog.naver.com\\/94yjung,\n\t\t\tpostdate:20230823\n\t\t},\n\t\t{\n\t\t\ttitle:[런던 한식당 맛집] ‘Olle’ <b>추천메뉴<\\/b> 꼭 보고 방문하세요.,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/taeh_v\\/223195270672,\n\t\t\tdescription:오늘은 런던 한식당 맛집으로 추천하는 Olle를 포스팅한다. <b>추천 메뉴<\\/b>를 꼭 보고 드시길! 이전 런던 맛집... 그리고  ...

# %%
list1 = body.split('\n\t\t{\n\t\t\t')
#naver블로그 글만 가져오기
list1 = [i for i in list1 if 'naver' in i]
list1
# Out:
# ['title:텐진 맛집 이치란 라멘 후쿠오카 웨이팅 주문 방법 <b>메뉴<\\/b> <b>추천<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/
<b>추천 메뉴<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/keeping_on\\/223175653852,\n\t\t\tdescription:타타스베이글 대전 빵나오는시간 <b>추천 메뉴<\\/b> 아기랑 실내 놀이터 가기 전에 타타스베이글을 들렀다.... 마늘이 들어가서 느끼하지 않고 포만감이 있어서 브런치 메뉴로 추천 ~ 모카슈크림 모카만 있었다면... ,\n\t\t\tbloggername:시트콤라이프,\n\t\t\tbloggerlink:blog.naver.com\\/keeping_on,\n\t\t\tpostdate:20230805\n\t\t},',
#  'title:함덕 예약부터 주차 <b>메뉴<\\/b>, 제주도 흑돼지 맛집으로 <b>추천<\\/b>하는 이유!,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/jiny1445\\/223180761954,\n\t\t\tdescription:지점마다 <b>추천 메뉴<\\/b>와 한정 메뉴가 조금씩 다릅니다. 중복은 960숙성뼈등심이고 함덕점은 1일 80인분만 판매를 하기 때문에 먼저 주문을 하시는 걸 추천드려요. 저희는 960 숙성 뼈등심과 720 숙성 뼈목살 그리고... ,\n\t\t\tbloggername:즐거운하민,\n\t\t\tbloggerlink:blog.naver.com\\/jiny1445,\n\t\t\tpostdate:20230811\n\t\t},',
#  'title:광주 첨단 라운지 OIC <b>추천 메뉴<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/psm_1230\\/223180332842,\n\t\t\tdescription:다양한 메뉴가 있는데 우리는 이미 다녀와본 동생의 <b>추천메뉴<\\/b>로 시오세트로 토마호크스테이크와 시그니처샐러드 메인메뉴는 트러플 까르보나라에 스테이크 김치라이스를 추가로 주문하였다! 시오 세트에... ,\n\t\t\tbloggername:찬둥,\n\t\t\tbloggerlink:blog.naver.com\\/psm_1230,\n\t\t\tpostdate:20230810\n\t\t},',
#  'title:파리바게트 <b>추천메뉴<\\/b> 애플망고 생크림빵, 에그베이컨 토스트... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/sangyun1106\\/223193499353,\n\t\t\tdescription:그래서 2개 메뉴를 모두 <b>추천메뉴<\\/b>라고 적어 포스팅하게 되었습니다! 파리바게트 에그베이컨토스트도, 파리바게트 애플망고 생크림빵도, 저에게 있어서 가성비 좋게 맛있었고, 재구매의사도 매우... ,\n\t\t\tbloggername:N잡러민초파의 쩝쩝박사 도전기,\n\t\t\tbloggerlink:blog.naver.com\\/sangyun1106,\n\t\t\tpostdate:20230825\n\t\t},',
#  'title:괌 리틀피카스 <b>추천메뉴<\\/b> 맛있는 로꼬모꼬,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/cocovely40\\/223187268708,\n\t\t\tdescription:조식 메뉴인데요, 에그베네딕트는 여기서 안 먹어도 될꺼 같아요. 진짜 그냥 그랬답니다. 괌 리틀피카스 <b>추천메뉴<\\/b>를 많이들 검색하시던데 저는 로꼬모꼬를 추천합니다. 보니까 또 가고 싶다요. #괌리틀피카스... ,\n\t\t\tbloggername:신난다영,\n\t\t\tbloggerlink:blog.naver.com\\/cocovely40,\n\t\t\tpostdate:20230818\n\t\t},',
#  "title:분당맛집 포시즌키친,  판교브런치 <b>메뉴<\\/b> <b>추천<\\/b>해요 feat.뇨끼맛집,\n\t\t\tlink:https:\\/\\/blog.naver.com\\
\n\t\t\tlink:https:\\/\\/blog.naver.com\\/gossip831\\/223185574900,\n\t\t\tdescription:덕분에 저는 메뉴 고민이 많았지만! <b>추천 메뉴<\\/b>로 즐겨보았습니다. 한줄 리뷰 : 입에서 살살 녹은 제주 딱새우회 추천 방이동 맛집 : 동래별장 (1) 방이동 먹자골목 : 방이동 이자카야 한식 느낌 맛집 동래별장 (2)... ,\n\t\t\tbloggername:꿈꾸는 월드의 세상,\n\t\t\tbloggerlink:blog.naver.com\\/gossip831,\n\t\t\tpostdate:20230817\n\t\t},',
#  "title:태릉입구 술집 금별맥주 묵동자이점 <b>메뉴<\\/b> <b>추천<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/asdl93\\/223173164934,\n\t\t\tdescription:살얼음이 얼만큼 차가운 생맥주와 금별맥주의 특색 있는 안주 메뉴 추천드려요. 가격대도 부담 없고... 있는 메뉴들인데요. 세 가지를 한번에 조합해서 누구나 좋아할만한 금별맥주 대표 <b>추천 메뉴<\\/b>로... ,\n\t\t\tbloggername:Spirit's Wood,\n\t\t\tbloggerlink:blog.naver.com\\/asdl93,\n\t\t\tpostdate:20230802\n\t\t},",
#  'title:배곧 점심 <b>메뉴<\\/b> <b>추천<\\/b> 삼겹살 맛집 조선부뚜막 고기집,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/uniquefabric24\\/223183499176,\n\t\t\tdescription:배곧 삼겹살 맛집 <b>추천 메뉴<\\/b>로는 부뚜막 한상 소와 대 메인 메뉴가 있고요. 저희는 넷이 왔기 때문에... 쌈무, 파절임, 차돌박이 조합도 추천해 드리고 싶은 조합이에요. 흡족한 맛이기 때문이랍니다. 배곧... ,\n\t\t\tbloggername:찰나의순간,\n\t\t\tbloggerlink:blog.naver.com\\/uniquefabric24,\n\t\t\tpostdate:20230814\n\t\t},',
#  'title:본죽 삼계죽 <b>메뉴<\\/b> <b>추천<\\/b> 든든하고 건강한 한 끼 먹은 느낌이유,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/caubaba\\/223177701915,\n\t\t\tdescription:든든하고 맛나유 본죽메뉴 추천 :) 푹푹 찌는 날씨 모든 게 녹아버릴 듯한 이 더위 살짝 정신이 나가는 날씨지만 그래도 내 몸 내가 제대로 챙겨야지 거의 몸보신(?) 든든히 하러 본죽 <b>추천 메뉴<\\/b> 먹으러 왔다요... ,\n\t\t\tbloggername:배배공 :: 배배의 배부른 공간,\n\t\t\tbloggerlink:blog.naver.com\\/caubaba,\n\t\t\tpostdate:20230808\n\t\t},',
#  'title:하남 스타필드 ebt 솔직 후기 <b>추천메뉴<\\/b> 트러플 풍기피자... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/zhyewon\\/223190786665,\n\t\t\tdescription:남은 피자를 포장해서 차에 싣고 가는데 포장 박스를 뚫고 나오는 트러플 향 그리고 집에 와서도 집안에 풍기는 트러플 향 이비티가면 꼭 먹어야하는 <b>메뉴<\\/b>라고 감히 말하고 싶네요 ㅎㅎ 이비티 총평 <b>추천<\\/b>과... ,\n\t\t\tbloggername:데일리원스,\n\t\t\tbloggerlink:blog.naver.com\\/zhyewon,\n\t\t\tpostdate:20230822\n\t\t},',
#  'title:카페, 산뜻 정갈한 런치 뷔페 맛집, 사적리뷰 내돈내산, <b>추천 메뉴<\\/b>.,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
from wordcloud import WordCloud

# %%
Twitter = Twitter()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
df = pd.read_csv('foodinfo1.csv')
df
df_word = list(df['대표식품명'])
Twitter.add_dictionary(df_word, 'Noun')

# %%
#블로그 데이터 형태소 분석
an = []
for i in range(0,len(list1)) :
    nouns =  Twitter.nouns(list1[i])
    an.append(nouns)
print(an[2])
# Out:
# ['구로디지털단지역', '점', '갈비', '메뉴', '디', '맛집', '추천', '매장', '메뉴', '판이', '크게', '어서', '어요', '매장', '그', '잡채', '회식', '공간', '디', '직장인', '추천', '드립', '맛집', '술집', '고기', '집', '구로디지털단지역', '맛집']

# %%
an
# Out:
# [['텐진',
#   '맛집',
#   '이치란',
#   '라멘',
#   '후쿠오카',
#   '웨이',
#   '팅',
#   '주문',
#   '방법',
#   '메뉴',
#   '추천',
#   '일본',
#   '후쿠오카',
#   '맛집',
#   '이치란',
#   '라멘',
#   '텐진',
#   '웨이',
#   '팅',
#   '주문',
#   '방법',
#   '메뉴',
#   '추천',
#   '스시',
#   '오',
#   '마카',
#   '세',
#   '끼니',
#   '후기',
#   '추천',
#   '메뉴',
#   '소개',
#   '고',
#   '주문',
#   '방법',
#   '까지',
#   '공유',
#   '시간',
#   '운',
#   '영하',
#   '이치란',
#   '라멘',
#   '본점',
#   '푸드',
#   '인',
#   '플루',
#   '율무',
#   '밍',
#   '일상',
#   '기록'],
#  ['베트남',
#   '다낭',
#   '맛집',
#   '한시',
#   '장',
#   '주변',
#   '안',
#   '토이',
#   '벱꿰',
#   '메뉴',
#   '추천',
#   '나',
#   '추천',
#   '메뉴',
#   '가지볶음',
#   '토마토소스',
#   '두부',
#   '완자',
#   '조림',
#   '황금새',
#   '안',
#   '토이',
#   '베트남',
#   '요리',
#   '한번',
#   '모든',
#   '메뉴',
#   '맛',
#   '볼',
#   '수',
#   '무엇',
#   '인테리어',
#   '쾌적',
#   '환경',
#   '주변',
#   '추',
#   '천하',
#   '잡',
#   '트래블',
#   '홀릭'],
#  ['구로디지털단지역',
#   '점',
#   '갈비',
#   '메뉴',
#   '디',
#   '맛집',
#   '추천',
#   '매장',
#   '메뉴',
#   '판이',
#   '크게',
#   '어서',
#   '어요',
#   '매장',
#   '그',
#   '잡채',
#   '회식',
#   '공간',
#   '디',
#   '직장인',
#   '추천',
#   '드립',
#   '맛집',
#   '술집',
#   '고기',
#   '집',
#   '구로디지털단지역',
#   '맛집'],
#  ['카페',
#   '오설록',
#   '티',
#   '하우스',
#   '해운대',
#   '점',
#   '오픈',
#   '행사',
#   '정보',
#   '추천',
#   '메뉴',
#   '소개',
#   '여러분',
#   '해운대',
#   '신상',
#   '카페',
#   '추천',
#   '정보',
#   '자세',
#   '소개',
#   '어서',
#   '인테리어',
#   '메뉴',
#   '오픈',
#   '행사',
#   '정보',
#   '까지',
#   '자세',
#   '보고',
#   '해운대',
#   '카페',
#   '오설록',
#   '티',
#   '하우스',
#   '해운대',
#   '점',
#   '방문',
#   '전',
#   '참고',
#   '외관'],
#  ['분모',
#   '자로',
#   '제',
#   '떡볶이',
#   '돈',
#   '산',
#   '솔직',
#   '후기',
#   '추천',
#   '메뉴',
#   '는걸',
#   '추천',
#   '거지',
#   '분모',
#   '자로',
#   '제',
#   '떡볶이',
#   '성비',
#   '제',
#   '기준',
#   '추천',
#   '메뉴',
#   '정말',
#   '치킨',
#   '메뉴',
#   '기준',
#   '뿌',
#   '링클',
#   '커리',
#   '퀸',
#   '맛초킹',
#   '정도',
#   '것',
#   '민초',
#   '파의',
#   '박사',
#   '도전',
#   '기'],
#  ['파타야',
#   '맛집',
#   '비프',
#   '터',
#   '스테이크',
#   '하우스',
#   '예약',
#   '방법',
#   '및',
#   '추천',
#   '메뉴',
#   '직원',
#   '분',
#   '메뉴',
#   '추천',
#   '요청',
#   '요',
#   '메뉴',
#   '를',
#   '추천',
#   '해',
#   '크림',
#   '색',
#   '브랜디',
#   '맛',
#   '페퍼',
#   '소스',
#   '페퍼',
#   '스테이크',
#   '스테이크',
#   '위',
#   '야채',
#   '사이드',
#   '감자',
#   '오',
#   '그라탕',
#   '제공',
#   '이',
#   '스윗',
#   '포타토킴',
#   '다이어트',
#   '로드',
#   '이야기'],
#  ['바르셀로나',
#   '비니',
#   '투스',
#   '메뉴',
#   '추천',
#   '가격표',
#   '파산',
#   '잼',
#   '세르',
#   '베',
#   '세리',
#   '카탈',
#   '라나',
#   '체인',
#   '맛',
#   '분위기',
#   '메뉴판',
#   '가격',
#   '추천',
#   '부과',
#   '세',
#   '더니',
#   '지갑',
#   '여자',
#   '명',
#   '이서',
#   '추천',
#   '메뉴',
#   '배부',
#   '르',
#   '가격',
#   '이',
#   '롤링'],
#  ['제주',
#   '오일장',
#   '향',
#   '추천',
#   '메뉴',
#   '제주',
#   '민속',
#   '오일',
#   '시장',
#   '향',
#   '메뉴',
#   '것',
#   '메뉴',
#   '걸',
#   '순대국',
#   '밥',
#   '비빔밥',
#   '꼼장어',
#   '순대',
#   '추천',
#   '해',
#   '글',
#   '감사',
#   '모두',
#   '오일장',
#   '제주',
#   '오일장',
#   '주연',
#   '블로그'],
#  ['리스',
#   '카페',
#   '정자',
#   '주차',
#   '웨이',
#   '팅',
#   '추천',
#   '메뉴',
#   '브런치',
#   '맛집',
#   '기분',
#   '가게',
#   '앞',
#   '크게',
#   '인쇄',
#   '메뉴',
#   '판이',
#   '어서',
#   '열심',
#   '보',
#   '면서',
#   '메뉴',
#   '를',
#   '정',
#   '진짜',
#   '하나',
#   '부터',
#   '이용',
#   '추천',
#   '드',
#   '린다',
#   '파라',
#   '곤',
#   '지하',
#   '주차장',
#   '시간',
#   '지원',
#   '함',
#   '판교',
#   '후배',
#   '추천',
#   '만큼',
#   '진짜'],
#  ['런던',
#   '한식당',
#   '맛집',
#   '추천',
#   '메뉴',
#   '꼭',
#   '보고',
#   '방문',
#   '오늘',
#   '런던',
#   '한식당',
#   '맛집',
#   '추',
#   '천하',
#   '를',
#   '포스팅',
#   '추천',
#   '메뉴',
#   '를',
#   '꼭',
#   '보고',
#   '이전',
#   '런던',
#   '맛집',
#   '고',
#   '마지막',
#   '가장',
#   '추',
#   '천하',
#   '메뉴인',
#   '차돌',
#   '된장찌개',
#   '친',
#   '구들',
#   '된장찌개',
#   '맛',
#   '보고',
#   '이',
#   '젤',
#   '화려',
#   '정',
#   '결하',
#   '삶'],
#  ['파리크라상',
#   '브런치',
#   '메뉴',
#   '추천',
#   '빵',
#   '파리',
#   '크로와상',
#   '분위기',
#   '이제',
#   '언제',
#   '다시',
#   '또',
#   '유럽',
#   '파리크라상',
#   '답',
#   '다양',
#   '종류',
#   '빵',
#   '추천',
#   '메뉴',
#   '또',
#   '파리크라상',
#   '브런치',
#   '파리크라상',
#   '메뉴',
#   '파리크라상',
#   '추천',
#   '빵',
#   '파리',
#   '크로와상',
#   '마음',
#   '쏙',
#   '베이커리',
#   '카페',
#   '방랑',
#   '고',
#   '그날',
#   '기',
#   '다리'],
#  ['양배추',
#   '국',
#   '양배추',
#   '된장국',
#   '간단',
#   '아침',
#   '국',
#   '추천',
#   '메뉴',
#   '양배추',
#   '통',
#   '사면',
#   '다양',
#   '요리',
#   '수',
#   '오늘',
#   '간단',
#   '아침',
#   '국',
#   '추천',
#   '양배추',
#   '국',
#   '양배추',
#   '된장국',
#   '어요',
#   '양배추',
#   '위',
#   '건강',
#   '도움',
#   '속',
#   '편안',
#   '해주',
#   '기',
#   '때문',
#   '아침',
#   '국',
#   '메뉴',
#   '로',
#   '초록',
#   '스토리'],
#  ['강남',
#   '슈퍼',
#   '버거',
#   '위치',
#   '추천',
#   '메뉴',
#   '후기',
#   '가장',
#   '추천',
#   '메뉴',
#   '고구마튀김',
#   '초콜릿',
#   '쉐이크',
#   '고구마튀김',
#   '달짝',
#   '지근',
#   '하니',
#   '먹기',
#   '식',
#   '어도',
#   '초콜릿',
#   '쉐이크',
#   '정말',
#   '초코',
#   '덕후',
#   '대만',
#   '족',
#   '살',
#   '느낌',
#   '아리',
#   '노트'],
#  ['살',
#   '만공',
#   '격',
#   '추천',
#   '메뉴',
#   '바삭',
#   '치',
#   '파포',
#   '세트',
#   '살',
#   '만공',
#   '격',
#   '추천',
#   '메뉴',
#   '바삭',
#   '치',
#   '파포',
#   '세트',
#   '제시',
#   '아하',
#   '편이',
#   '살',
#   '만공',
#   '격',
#   '광고',
#   '질색',
#   '바삭',
#   '치',
#   '파포',
#   '세트',
#   '메뉴',
#   '동일',
#   '구성',
#   '마리',
#   '양',
#   '던데',
#   '려면',
#   '이',
#   '메뉴',
#   '추천',
#   '합',
#   '호랑이',
#   '담배',
#   '시절'],
#  ['저녁',
#   '메뉴',
#   '추천',
#   '더미',
#   '식',
#   '우렁',
#   '된장찌개',
#   '신혼부부',
#   '간단',
#   '국물',
#   '요리',
#   '저녁',
#   '메뉴',
#   '추천',
#   '더미',
#   '식',
#   '우렁',
#   '된장찌개',
#   '신혼부부',
#   '간단',
#   '국물',
#   '요리',
#   '퇴근',
#   '후',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '뭐',
#   '을지',
#   '저녁',
#   '추천',
#   '메뉴',
#   '보통',
#   '밀키',
#   '트하',
#   '냉장',
#   '이나',
#   '냉동',
#   '보관',
#   '경우',
#   '더',
#   '미식',
#   '열처리',
#   '기술',
#   '통해',
#   '푸드',
#   '인',
#   '플루',
#   '율무',
#   '밍',
#   '일상',
#   '기록'],
#  ['베트남',
#   '다낭',
#   '맛집',
#   '추천',
#   '다낭',
#   '쌀국수',
#   '티엔',
#   '킴',
#   '메뉴',
#   '할인',
#   '추천',
#   '메뉴',
#   '크게',
#   '사진',
#   '크게',
#   '사진',
#   '메뉴',
#   '위주',
#   '주문',
#   '거',
#   '추천',
#   '다낭',
#   '쌀국수',
#   '필수',
#   '주문',
#   '고요',
#   '반',
#   '파인애플',
#   '볶음밥',
#   '아해',
#   '망고',
#   '샐러드',
#   '어서',
#   '여러',
#   '번',
#   '해외여행',
#   '고고씽'],
#  ['타타',
#   '스',
#   '베이글',
#   '대전',
#   '빵',
#   '시간',
#   '추천',
#   '메뉴',
#   '타타',
#   '스',
#   '베이글',
#   '대전',
#   '빵',
#   '시간',
#   '추천',
#   '메뉴',
#   '아기',
#   '실내',
#   '놀이터',
#   '가기',
#   '전',
#   '타타',
#   '스',
#   '베이글',
#   '마늘',
#   '어가',
#   '포만',
#   '감',
#   '어서',
#   '브런치',
#   '메뉴',
#   '추천',
#   '모카',
#   '슈크림',
#   '모카',
#   '시트콤',
#   '라이프'],
#  ['함덕',
#   '예약',
#   '부터',
#   '주차',
#   '메뉴',
#   '제주도',
#   '돼지',
#   '맛집',
#   '추천',
#   '이유',
#   '지점',
#   '마다',
#   '추천',
#   '메뉴',
#   '한정',
#   '메뉴',
#   '조금',
#   '중복',
#   '숙성',
#   '뼈',
#   '등심',
#   '함덕',
#   '점',
#   '인분',
#   '판매',
#   '때문',
#   '먼저',
#   '주문',
#   '걸',
#   '추천',
#   '저희',
#   '숙성',
#   '뼈',
#   '등심',
#   '숙성',
#   '뼈목살',
#   '고',
#   '운하',
#   '민'],
#  ['광주',
#   '첨단',
#   '라운지',
#   '추천',
#   '메뉴',
#   '다양',
#   '메뉴',
#   '우리',
#   '동생',
#   '추천',
#   '메뉴',
#   '로',
#   '시오',
#   '세트',
#   '토마호크',
#   '스테이크',
#   '시',
#   '그니',
#   '처',
#   '샐러드',
#   '메인',
#   '메뉴',
#   '트러플',
#   '까르보나라',
#   '스테이크',
#   '김치',
#   '라이스',
#   '추가',
#   '주문',
#   '시오',
#   '세트',
#   '찬둥'],
#  ['파리바게트',
#   '추천',
#   '메뉴',
#   '애플',
#   '망고',
#   '생크림',
#   '빵',
#   '베이컨',
#   '토스트',
#   '그',
#   '래서',
#   '개',
#   '메뉴',
#   '모두',
#   '추천',
#   '메뉴',
#   '포스팅',
#   '파리바게트',
#   '베이컨',
#   '토스트',
#   '파리바게트',
#   '애플',
#   '망고',
#   '생',
#   '크림빵',
#   '저',
#   '어서',
#   '가성',
#   '비',
#   '재',
#   '구매',
#   '의사',
#   '매우',
#   '민초',
#   '파의',
#   '박사',
#   '도전',
#   '기'],
#  ['괌',
#   '리틀',
#   '피카',
#   '스',
#   '추천',
#   '메뉴',
#   '로꼬',
#   '모꼬',
#   '조식',
#   '메뉴인',
#   '에그베네딕트',
#   '여기',
#   '안',
#   '어도',
#   '진짜',
#   '그냥',
#   '괌',
#   '리틀',
#   '피카',
#   '스',
#   '추천',
#   '메뉴',
#   '를',
#   '검색',
#   '던데',
#   '저',
#   '로꼬',
#   '모꼬',
#   '추천',
#   '보',
#   '또',
#   '리틀',
#   '피카',
#   '스',
#   '영'],
#  ['분당',
#   '맛집',
#   '포',
#   '시즌',
#   '키친',
#   '판교',
#   '브런치',
#   '메뉴',
#   '추천',
#   '해',
#   '뇨끼',
#   '맛집',
#   '정말',
#   '정말',
#   '추천',
#   '곳',
#   '포',
#   '시즌',
#   '키친',
#   '분당',
#   '직영',
#   '점',
#   '분당',
#   '브런치',
#   '맛집',
#   '강추',
#   '경기',
#   '성남시',
#   '분당구',
#   '포',
#   '시즌',
#   '키친',
#   '추천',
#   '메뉴',
#   '꼭',
#   '뇨끼',
#   '문어',
#   '콩피',
#   '강추',
#   '스파클링',
#   '와인',
#   '브런치',
#   '메뉴',
#   '뇨끼',
#   '구성'],
#  ['맛집',
#   '부모님',
#   '모시',
#   '식사',
#   '늘',
#   '푸른',
#   '염소',
#   '가든',
#   '추천',
#   '메뉴',
#   '주차',
#   '정보',
#   '추천',
#   '메뉴',
#   '까지',
#   '소개',
#   '드릴',
#   '테',
#   '부모님',
#   '식사',
#   '장소',
#   '고민',
#   '계시',
#   '분',
#   '시기',
#   '추천',
#   '드릴',
#   '요',
#   '메뉴',
#   '광주',
#   '염소',
#   '맛집',
#   '늘',
#   '푸른',
#   '가든',
#   '메뉴',
#   '본점',
#   '마찬가지',
#   '탕',
#   '수육',
#   '방',
#   '방곡',
#   '꼭',
#   '여행기'],
#  ['체코',
#   '프라하',
#   '여행',
#   '맛집',
#   '추천',
#   '메뉴',
#   '스테이크',
#   '주문',
#   '방법',
#   '체코',
#   '프라하',
#   '맛집',
#   '추천',
#   '메뉴',
#   '및',
#   '주문',
#   '방법',
#   '줌',
#   '안녕하십니까',
#   '여행',
#   '패션',
#   '쁠뤈',
#   '제',
#   '여기',
#   '고온',
#   '메뉴',
#   '가지',
#   '추천',
#   '면서',
#   '곳',
#   '오시',
#   '분',
#   '우왕좌왕',
#   '당',
#   '황하',
#   '도록',
#   '음식',
#   '세상',
#   '중심'],
#  ['얼스',
#   '어스',
#   '치아바타',
#   '전문',
#   '세컨',
#   '브랜드',
#   '추천',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '베이컨',
#   '토마토',
#   '샌드위치',
#   '수프',
#   '포장',
#   '가능',
#   '주차',
#   '불가',
#   '주말',
#   '시정',
#   '부지런',
#   '회전',
#   '율',
#   '아무',
#   '도',
#   '신선',
#   '한편',
#   '삭',
#   '하니',
#   '식',
#   '조합',
#   '맛',
#   '요',
#   '메뉴',
#   '추천',
#   '합'],
#  ['압구정로',
#   '데오',
#   '맛집',
#   '여름',
#   '메뉴',
#   '추천',
#   '냉',
#   '모밀',
#   '후기',
#   '하루',
#   '메뉴',
#   '추',
#   '천하',
#   '메뉴',
#   '저',
#   '때',
#   '마다',
#   '어요',
#   '다음',
#   '오늘',
#   '강력',
#   '추천',
#   '메뉴',
#   '냉',
#   '모밀',
#   '리뷰',
#   '왼쪽',
#   '사진',
#   '그냥',
#   '기본',
#   '오른쪽',
#   '곱빼기',
#   '보통',
#   '남',
#   '여',
#   '가시',
#   '분',
#   '인'],
#  ['아웃백',
#   '스테이크',
#   '하우스',
#   '추천',
#   '메뉴',
#   '메뉴',
#   '변경',
#   '팁',
#   '할인',
#   '방법',
#   '런치',
#   '메뉴',
#   '시간',
#   '오픈',
#   '오후',
#   '평일',
#   '주말',
#   '동일',
#   '개',
#   '인적',
#   '추천',
#   '메뉴',
#   '갈릭',
#   '립',
#   '아이',
#   '스테이크',
#   '통신사',
#   '할인',
#   '아웃백',
#   '할인',
#   '아웃백',
#   '주문',
#   '할인',
#   '카드',
#   '아기',
#   '의자',
#   '외식',
#   '장소',
#   '추천',
#   '부시맨',
#   '빵',
#   '기록',
#   '용'],
#  ['미사',
#   '성수역',
#   '번',
#   '출구',
#   '맛집',
#   '전',
#   '외',
#   '추천',
#   '메뉴',
#   '추가',
#   '보심',
#   '추천',
#   '호선',
#   '성수역',
#   '번',
#   '출구',
#   '오픈',
#   '일요일',
#   '휴무',
#   '듯',
#   '개',
#   '인적',
#   '추천',
#   '메뉴',
#   '고추전',
#   '해물파전',
#   '오징어',
#   '데침',
#   '돈',
#   '산',
#   '회비',
#   '정산',
#   '만요',
#   '개인',
#   '적',
#   '입맛',
#   '전집'],
#  ['세종',
#   '맛집',
#   '줄',
#   '서서',
#   '빵집',
#   '셀레슈크레',
#   '추천',
#   '메뉴',
#   '다른',
#   '블로그',
#   '추천',
#   '리스트',
#   '식빵',
#   '소금',
#   '빵',
#   '치아바타',
#   '에그타르트',
#   '바스',
#   '트',
#   '치즈케이크',
#   '듯',
#   '내',
#   '구매',
#   '메뉴',
#   '소금',
#   '빵',
#   '퀸',
#   '망',
#   '순',
#   '우유',
#   '식빵',
#   '크루아상',
#   '뺑오',
#   '쇼콜라',
#   '치아바타',
#   '치즈',
#   '치아바타',
#   '바닐라',
#   '주옥',
#   '나날'],
#  ['신촌',
#   '맛집',
#   '너',
#   '진짜',
#   '구나',
#   '소바',
#   '연구소',
#   '추천',
#   '메뉴',
#   '메뉴',
#   '추천',
#   '끝',
#   '까지',
#   '보시',
#   '길',
#   '이전',
#   '맛집',
#   '포스팅',
#   '참고',
#   '출발',
#   '호선',
#   '소바',
#   '연구소',
#   '추천',
#   '메뉴',
#   '중',
#   '하나',
#   '설명',
#   '폰',
#   '소스',
#   '미가',
#   '배',
#   '화려',
#   '정',
#   '결하',
#   '삶'],
#  ['보라카이',
#   '디',
#   '맛집',
#   '졸리',
#   '비',
#   '메뉴',
#   '추천',
#   '및',
#   '가격',
#   '정보',
#   '저희',
#   '일반',
#   '치킨',
#   '메뉴',
#   '선택',
#   '몇',
#   '페소',
#   '정도',
#   '추',
#   '가금',
#   '불하',
#   '스파이',
#   '시',
#   '치킨',
#   '변경',
#   '수',
#   '이',
#   '더',
#   '졸리',
#   '비',
#   '추천',
#   '메뉴',
#   '로',
#   '꼽으',
#   '시더',
#   '요',
#   '메뉴',
#   '치밥',
#   '닭다리',
#   '밥',
#   '마음'],
#  ['경복궁역',
#   '촌',
#   '돈',
#   '산',
#   '맛집',
#   '솔솥',
#   '추천',
#   '메뉴',
#   '웨이',
#   '팅',
#   '이',
#   '메뉴',
#   '무난',
#   '무난',
#   '맛',
#   '굳이',
#   '이',
#   '메뉴',
#   '추천',
#   '왜냐면',
#   '솔솥',
#   '다른',
#   '솥밥',
#   '메뉴',
#   '더',
#   '때문',
#   '그냥',
#   '상상',
#   '스테이크',
#   '덮밥',
#   '맛',
#   '랄',
#   '고',
#   '나',
#   '추천',
#   '메뉴'],
#  ['롯데리아',
#   '신',
#   '메뉴',
#   '저녁',
#   '메뉴',
#   '추천',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '시식',
#   '후기',
#   '롯데리아',
#   '음원',
#   '롯데리아',
#   '이벤트',
#   '점심',
#   '메뉴',
#   '추천',
#   '저녁',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '추천',
#   '롯데리아',
#   '새우',
#   '베이',
#   '건',
#   '새우',
#   '베이',
#   '건',
#   '새우',
#   '익스트림',
#   '이',
#   '포스팅',
#   '롯데리아',
#   '로부터',
#   '원고료',
#   '제공',
#   '주관',
#   '적',
#   '작성',
#   '글',
#   '말',
#   '염',
#   '방구'],
#  ['판교',
#   '중국요리',
#   '시추',
#   '안',
#   '하우스',
#   '사천요리',
#   '움',
#   '추천',
#   '메뉴',
#   '시추',
#   '안',
#   '피셜',
#   '추천',
#   '리스트',
#   '에피',
#   '타이',
#   '징',
#   '스프',
#   '야채',
#   '요리',
#   '사이드',
#   '메뉴',
#   '향가',
#   '지도',
#   '꽤',
#   '맛',
#   '함',
#   '육류',
#   '돼지',
#   '소',
#   '닭',
#   '요리',
#   '동파육',
#   '진짜',
#   '단연',
#   '최고',
#   '완전',
#   '추천',
#   '동행',
#   '말로',
#   '소고기',
#   '전골',
#   '투탑',
#   '오늘',
#   '책장'],
#  ['충장로',
#   '월계수',
#   '식당',
#   '그',
#   '자리',
#   '그대로',
#   '오래',
#   '맛집',
#   '메뉴',
#   '추천',
#   '월계수',
#   '식당',
#   '메뉴',
#   '돈까스',
#   '볶음밥',
#   '짬뽕',
#   '국밥',
#   '제육',
#   '덮밥',
#   '잡채',
#   '잡채밥',
#   '등',
#   '사이드',
#   '물만두',
#   '월계수',
#   '식당',
#   '추천',
#   '메뉴',
#   '삼선',
#   '볶음밥',
#   '짬뽕',
#   '국밥',
#   '돈까스',
#   '우삼겹',
#   '짬뽕',
#   '다음',
#   '우삼겹',
#   '짬뽕',
#   '가야',
#   '딩'],
#  ['곡성',
#   '맛집',
#   '곡성',
#   '가든',
#   '추천',
#   '메뉴',
#   '방문자',
#   '단골',
#   '입장',
#   '추천',
#   '드',
#   '리자',
#   '곡성',
#   '가든',
#   '모든',
#   '스테이크',
#   '메뉴',
#   '를',
#   '맛',
#   '보고',
#   '분',
#   '평일',
#   '한정',
#   '판매',
#   '스폐셜',
#   '를',
#   '추천',
#   '고요',
#   '조금',
#   '것',
#   '것',
#   '것',
#   '메인',
#   '하나',
#   '방',
#   '방곡',
#   '꼭',
#   '여행기'],
#  ['또',
#   '동대문',
#   '에베레스트',
#   '추천',
#   '메뉴',
#   '비',
#   '추천',
#   '메뉴',
#   '아하',
#   '시',
#   '추천',
#   '하나',
#   '제',
#   '친',
#   '구들',
#   '입',
#   '더니',
#   '아주',
#   '혐',
#   '바보',
#   '추천',
#   '메뉴',
#   '커리',
#   '치킨',
#   '티카',
#   '머설',
#   '각',
#   '갈릭',
#   '버터',
#   '각',
#   '맛',
#   '살',
#   '아가',
#   '빙고'],
#  ['포',
#   '이자카야',
#   '하이',
#   '볼',
#   '맛집',
#   '추천',
#   '메뉴',
#   '메뉴',
#   '포',
#   '이자카야',
#   '세트',
#   '메뉴',
#   '추천',
#   '품',
#   '메뉴',
#   '부터',
#   '세트',
#   '메뉴',
#   '까지',
#   '일본주',
#   '준비',
#   '어요',
#   '분위기',
#   '맛집',
#   '포',
#   '이자카야',
#   '문',
#   '어가',
#   '순간',
#   '여기',
#   '일본인',
#   '나',
#   '순간이동',
#   '러블리썬',
#   '여행',
#   '날'],
#  ['정자동',
#   '맛집',
#   '솔솥',
#   '솥밥',
#   '추천',
#   '메뉴',
#   '가시',
#   '길',
#   '추천',
#   '인',
#   '이상',
#   '정도',
#   '전화',
#   '예약',
#   '가능',
#   '정자동',
#   '맛집',
#   '메뉴',
#   '판',
#   '정독',
#   '해산물',
#   '위주',
#   '솥밥',
#   '도미',
#   '관자',
#   '전복',
#   '민물장어',
#   '연어',
#   '꼬막',
#   '갈치구이',
#   '솥밥',
#   '고기',
#   '위주',
#   '솥밥',
#   '스테이크',
#   '솥밥'],
#  ['찜',
#   '찜닭',
#   '메뉴',
#   '가격',
#   '시래기',
#   '찜닭',
#   '추천',
#   '맵',
#   '보통',
#   '맛',
#   '단계',
#   '로제',
#   '찜닭',
#   '평',
#   '음번',
#   '찜닭',
#   '찜닭',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '가격',
#   '가격',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '시래기',
#   '찜닭',
#   '시래기',
#   '찜닭',
#   '추천',
#   '보통',
#   '맛',
#   '박',
#   '순대',
#   '소',
#   '소한',
#   '일상'],
#  ['성수동',
#   '카페',
#   '오로라',
#   '베이커리',
#   '카페',
#   '위치',
#   '영업',
#   '시간',
#   '메뉴',
#   '추천',
#   '정리',
#   '과연',
#   '추천',
#   '메뉴',
#   '무엇',
#   '네이버',
#   '지도',
#   '메뉴',
#   '소개',
#   '가장',
#   '추',
#   '천하',
#   '메뉴',
#   '소금',
#   '빵',
#   '소금',
#   '빵',
#   '잠봉뵈르',
#   '소금',
#   '빵',
#   '라우',
#   '겐',
#   '소금',
#   '빵',
#   '개',
#   '인적',
#   '경제',
#   '적',
#   '자유',
#   '향',
#   '삶',
#   '기록'],
#  ['상무지구',
#   '다이어트',
#   '때',
#   '가기',
#   '맛집',
#   '디',
#   '추천',
#   '메뉴',
#   '네가지',
#   '완전',
#   '추',
#   '천하',
#   '메뉴',
#   '처음',
#   '보시',
#   '분',
#   '오',
#   '거',
#   '완전',
#   '추천',
#   '메뉴',
#   '인',
#   '이유',
#   '어요',
#   '샐러드',
#   '아하',
#   '시',
#   '분',
#   '요건',
#   '아하',
#   '실거',
#   '부들',
#   '근로',
#   '그'],
#  ['경복궁역',
#   '맛집',
#   '단골',
#   '사발',
#   '돈',
#   '산',
#   '추천',
#   '메뉴',
#   '사발',
#   '추천',
#   '메뉴',
#   '또',
#   '하나',
#   '추천',
#   '메뉴',
#   '멍게',
#   '간장',
#   '비빔밥',
#   '국밥',
#   '밥',
#   '메뉴',
#   '모두',
#   '미니',
#   '국수',
#   '주신',
#   '걸',
#   '추천',
#   '화려',
#   '정',
#   '결하',
#   '삶'],
#  ['들기름',
#   '깻잎',
#   '페스',
#   '토',
#   '간장',
#   '비빔',
#   '통',
#   '밀국수',
#   '야식',
#   '추천',
#   '메뉴',
#   '들기름',
#   '깻잎',
#   '페스',
#   '토',
#   '활용',
#   '요리',
#   '자',
#   '야식',
#   '추천',
#   '요리',
#   '사실',
#   '야식',
#   '안',
#   '정답',
#   '꼭',
#   '야식',
#   '메뉴',
#   '의',
#   '덕목',
#   '만들기',
#   '간단',
#   '지나',
#   '친',
#   '포만',
#   '감',
#   '등',
#   '부담',
#   '아야',
#   '재미',
#   '마미',
#   '집'],
#  ['소공동',
#   '조선',
#   '호텔',
#   '중식',
#   '당',
#   '홍연',
#   '탕수육',
#   '맛집',
#   '추천',
#   '메뉴',
#   '오늘',
#   '한결',
#   '웨스',
#   '틴',
#   '조선',
#   '홍연',
#   '언제',
#   '강추',
#   '메뉴',
#   '탕수육',
#   '저',
#   '웨스',
#   '틴',
#   '조선',
#   '아하',
#   '편이',
#   '강력',
#   '추천',
#   '아주',
#   '편안',
#   '언제',
#   '친절',
#   '이전',
#   '홍연',
#   '포스팅',
#   '바니',
#   '티',
#   '블로그'],
#  ['그랜드',
#   '조선',
#   '부산',
#   '맛집',
#   '팔레',
#   '메뉴',
#   '추천',
#   '팔레',
#   '추천',
#   '메뉴',
#   '바로',
#   '칠리',
#   '새우',
#   '코스',
#   '주',
#   '문하',
#   '알',
#   '정도',
#   '아주',
#   '맛',
#   '그',
#   '래서',
#   '품',
#   '주문',
#   '메뉴',
#   '튀김',
#   '옷',
#   '양념',
#   '코팅',
#   '탕후루',
#   '식감',
#   '보',
#   '라이프'],
#  ['북촌',
#   '추천',
#   '맛집',
#   '태국',
#   '음식점',
#   '화양연화',
#   '추천',
#   '메뉴',
#   '쏨땀',
#   '타이',
#   '첫',
#   '메뉴',
#   '등장',
#   '쏨땀',
#   '생김새',
#   '부터',
#   '심상',
#   '찮다',
#   '콤함',
#   '이루',
#   '말',
#   '입맛',
#   '사이드',
#   '강력',
#   '추천',
#   '드',
#   '린다',
#   '전',
#   '반적',
#   '음식',
#   '훌륭',
#   '다음',
#   '가게',
#   '음식',
#   '귤',
#   '의',
#   '욤뇸',
#   '로그'],
#  ['대하',
#   '포장',
#   '서영수',
#   '산',
#   '대하',
#   '법',
#   '추천',
#   '메뉴',
#   '까지',
#   '오늘',
#   '파티',
#   '요리',
#   '대하',
#   '소금',
#   '구이',
#   '갈릭',
#   '버터',
#   '새우',
#   '라면',
#   '까지',
#   '가지',
#   '메뉴',
#   '로',
#   '준비',
#   '것',
#   '추천',
#   '드릴',
#   '요',
#   '사',
#   '보기',
#   '집',
#   '포장',
#   '요리',
#   '건',
#   '처음',
#   '었는데',
#   '사',
#   '방',
#   '방곡',
#   '꼭',
#   '여행기'],
#  ['안산',
#   '안주',
#   '한식',
#   '요리',
#   '재',
#   '해석',
#   '안주',
#   '히든',
#   '메뉴',
#   '추천',
#   '안주',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '안주',
#   '일품',
#   '요리',
#   '추천',
#   '항',
#   '정숙',
#   '회',
#   '항정',
#   '냉소',
#   '시즌',
#   '메뉴',
#   '꼬막',
#   '육회',
#   '트러플',
#   '감자',
#   '가지',
#   '튀김',
#   '전통주',
#   '막걸리',
#   '삼천포',
#   '쩐쭈',
#   '맹글어',
#   '오늘',
#   '책장'],
#  ['최대',
#   '할인',
#   '크리',
#   '지기',
#   '추천',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '겹겹이',
#   '맛',
#   '품격',
#   '치즈',
#   '크레이프',
#   '샌드',
#   '피자',
#   '일명',
#   '치',
#   '피자',
#   '나폴리',
#   '도우',
#   '씬',
#   '도우',
#   '두',
#   '가지',
#   '도우',
#   '바삭',
#   '쫄깃',
#   '맛',
#   '두',
#   '배',
#   '신',
#   '메뉴',
#   '도미노피자',
#   '공식',
#   '블로그'],
#  ['광장',
#   '코',
#   '중국집',
#   '개화',
#   '추천',
#   '메뉴',
#   '계절',
#   '메뉴',
#   '콩국수',
#   '현수막',
#   '예전',
#   '마',
#   '차이',
#   '짬뽕',
#   '때',
#   '번',
#   '적',
#   '상호',
#   '광장',
#   '코',
#   '중국집',
#   '개화',
#   '추천',
#   '메뉴',
#   '로',
#   '볶음밥',
#   '탕수육',
#   '호호',
#   '렐라',
#   '거림'],
#  ['운정',
#   '산내',
#   '마을',
#   '술집',
#   '금별',
#   '맥주',
#   '오픈',
#   '추천',
#   '메뉴',
#   '운정',
#   '금별',
#   '맥주',
#   '메뉴판',
#   '야외',
#   '테이블',
#   '이용',
#   '시',
#   '탕',
#   '메뉴',
#   '버너',
#   '주문',
#   '불가',
#   '남편',
#   '차로',
#   '회식',
#   '사모님',
#   '추천',
#   '메뉴',
#   '중',
#   '백합',
#   '조개',
#   '버터',
#   '술찜',
#   '주문',
#   '안주',
#   '안주',
#   '안주',
#   '부터',
#   '일품',
#   '한식',
#   '슈',
#   '니슈',
#   '의',
#   '행복',
#   '일상'],
#  ['잠실',
#   '노티',
#   '드',
#   '도넛',
#   '가격',
#   '추천',
#   '메뉴',
#   '송리단길',
#   '카페',
#   '노티',
#   '드',
#   '도넛',
#   '강력',
#   '추천',
#   '스트로베리',
#   '크림',
#   '도넛',
#   '노티',
#   '드',
#   '도넛',
#   '추천',
#   '메뉴',
#   '라즈베리',
#   '도넛',
#   '크림',
#   '잼',
#   '더',
#   '아하',
#   '개인',
#   '취향',
#   '때문',
#   '인지',
#   '크림',
#   '묵',
#   '직하',
#   '노티',
#   '드',
#   '도넛',
#   '메뉴',
#   '더',
#   '삼삼',
#   '진땅'],
#  ['커먼그라운드',
#   '맛집',
#   '건대',
#   '혼밥',
#   '로스',
#   '핫도그',
#   '메뉴',
#   '추천',
#   '커먼그라운드',
#   '핫도그',
#   '맛집',
#   '로스',
#   '핫도그',
#   '건대',
#   '혼밥',
#   '메뉴',
#   '추천',
#   '건대',
#   '혼밥',
#   '직장인',
#   '거나',
#   '로스',
#   '핫도그',
#   '추천',
#   '메뉴',
#   '치즈',
#   '스테이크',
#   '핫도그',
#   '핫',
#   '치토스',
#   '엘',
#   '떼',
#   '옥수수',
#   '밀크쉐이크',
#   '소',
#   '소하',
#   '화려',
#   '일상'],
#  ['삼성역',
#   '맛집',
#   '피',
#   '인더',
#   '가든',
#   '코엑스',
#   '점',
#   '샐러드',
#   '맛집',
#   '추천',
#   '메뉴',
#   '등',
#   '추천',
#   '메뉴',
#   '시즌',
#   '메뉴',
#   '추천',
#   '반짝',
#   '다가',
#   '사라',
#   '시즌',
#   '메뉴',
#   '때문',
#   '의외',
#   '운',
#   '메뉴',
#   '꽤',
#   '때문',
#   '시즌',
#   '메뉴',
#   '부터',
#   '게',
#   '주문',
#   '방법',
#   '매장',
#   '입구',
#   '어서',
#   '샐러드',
#   '줄',
#   '팬더',
#   '나들이'],
#  ['제주',
#   '애월',
#   '랜',
#   '디스',
#   '도넛',
#   '추천',
#   '메뉴',
#   '주차',
#   '이',
#   '메뉴',
#   '조',
#   '이맘',
#   '추천',
#   '메뉴',
#   '날',
#   '애플',
#   '프리터',
#   '품절',
#   '글레이',
#   '버터크림',
#   '경우',
#   '인기',
#   '도넛',
#   '품절',
#   '꼭',
#   '일찍',
#   '방문',
#   '추천',
#   '조',
#   '이맘',
#   '또',
#   '다른',
#   '포스팅',
#   '조이'],
#  ['왕가',
#   '탕후루',
#   '추천',
#   '메뉴',
#   '신',
#   '메뉴',
#   '탕후루',
#   '빙수',
#   '동두천',
#   '점',
#   '여태',
#   '까지',
#   '제일',
#   '왕가',
#   '탕후루',
#   '추천',
#   '메뉴',
#   '신',
#   '메뉴',
#   '탕후루',
#   '빙수',
#   '가장',
#   '자주',
#   '방',
#   '문하',
#   '동두천',
#   '행점',
#   '왕가',
#   '탕후루',
#   '의정부',
#   '점',
#   '번',
#   '노맛',
#   '다시',
#   '안',
#   '가요',
#   '왕가',
#   '탕후루',
#   '너',
#   '리',
#   '세',
#   '상'],
#  ['수원',
#   '폴바',
#   '셋',
#   '커피',
#   '추천',
#   '메뉴',
#   '베이커리',
#   '직원',
#   '직접',
#   '주문',
#   '어요',
#   '추천',
#   '메뉴',
#   '룽',
#   '아이스',
#   '아메리카노',
#   '상하이',
#   '목장',
#   '우유',
#   '아이스크림',
#   '어요',
#   '토핑',
#   '추가',
#   '아이스크림',
#   '라떼',
#   '추천',
#   '오늘',
#   '배',
#   '라스',
#   '달달',
#   '일상'],
#  ['집들이',
#   '음식',
#   '메뉴',
#   '추천',
#   '집',
#   '굽',
#   '기만',
#   '돼지갈비',
#   '밀키',
#   '트',
#   '집들이',
#   '음식',
#   '메뉴',
#   '추천',
#   '돼지갈비',
#   '밀키',
#   '트',
#   '정인',
#   '푸드',
#   '집들이',
#   '음식',
#   '메뉴',
#   '추천',
#   '갈비',
#   '요리',
#   '집들이',
#   '음식',
#   '추천',
#   '메뉴',
#   '돼지갈비',
#   '밀',
#   '키트',
#   '고기',
#   '법',
#   '안내서',
#   '저',
#   '베블',
#   '식탁'],
#  ['연남동',
#   '맛집',
#   '윤성용',
#   '레스토랑',
#   '연남동',
#   '데이트',
#   '추천',
#   '메뉴',
#   '주문',
#   '메뉴',
#   '윤성용',
#   '특선',
#   '둥지',
#   '샐러드',
#   '엔초',
#   '비',
#   '새우',
#   '파스타',
#   '콰트로',
#   '포르마',
#   '레몬에이드',
#   '콜라',
#   '연남동',
#   '맛집',
#   '연남동',
#   '데이트',
#   '홍대',
#   '데이트',
#   '추천',
#   '합',
#   '홍진',
#   '맛집',
#   '리뷰'],
#  ['방배역',
#   '맛집',
#   '백',
#   '소정',
#   '마제',
#   '소바',
#   '냉소',
#   '바',
#   '추천',
#   '메뉴',
#   '메뉴',
#   '개인',
#   '취향',
#   '대로',
#   '선택',
#   '마제',
#   '소바',
#   '한번',
#   '보시',
#   '길',
#   '추천',
#   '주문',
#   '역',
#   '후기',
#   '냉소',
#   '바',
#   '에비덴',
#   '개',
#   '자루',
#   '소바',
#   '돈카츠',
#   '마제',
#   '소바',
#   '주문',
#   '냉',
#   '소바',
#   '에비덴',
#   '의',
#   '맛집',
#   '탐방'],
#  ['심해',
#   '연어',
#   '사시미',
#   '훌리',
#   '훌리',
#   '치킨',
#   '추천',
#   '메뉴',
#   '먹기',
#   '손질',
#   '해주시',
#   '치킨',
#   '최애',
#   '메뉴',
#   '인',
#   '연어',
#   '사시미',
#   '두툼',
#   '하니',
#   '입안',
#   '사르르',
#   '음식',
#   '음료',
#   '하이',
#   '볼',
#   '수',
#   '심해',
#   '추천'],
#  ['롯데리아',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '신상',
#   '메뉴',
#   '추천',
#   '이번',
#   '포스팅',
#   '롯데리아',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '메뉴',
#   '추천',
#   '후',
#   '기입',
#   '이번',
#   '더욱',
#   '저',
#   '홍대역',
#   '근처',
#   '홍대',
#   '롯데리아',
#   '매장',
#   '이번',
#   '롯데리아',
#   '추천',
#   '메뉴',
#   '를',
#   '어보',
#   '았',
#   '나',
#   '세상',
#   '생각',
#   '잡',
#   '동사'],
#  ['매드',
#   '포',
#   '갈릭',
#   '추천',
#   '메뉴',
#   '크랩',
#   '앤',
#   '랍스터',
#   '파스타',
#   '존맛',
#   '매드',
#   '포',
#   '갈릭',
#   '추천',
#   '메뉴',
#   '크랩',
#   '앤',
#   '랍스터',
#   '파스타',
#   '존맛',
#   '은',
#   '여러분',
#   '안녕',
#   '주말',
#   '친구',
#   '부부',
#   '메뉴',
#   '어서',
#   '추천',
#   '어서',
#   '포스팅',
#   '전인',
#   '매드',
#   '포',
#   '갈릭',
#   '크랩',
#   '파스타',
#   '반짝',
#   '반짝',
#   '작',
#   '은별'],
#  ['부다페스트',
#   '한인식',
#   '당',
#   '비빔밥',
#   '추천',
#   '메뉴',
#   '얼마',
#   '전',
#   '드라큘라',
#   '성',
#   '축구',
#   '시합',
#   '장소',
#   '아이',
#   '부다페스트',
#   '한인식',
#   '당',
#   '부다페스트',
#   '한식당',
#   '부다페스트',
#   '식당',
#   '추천',
#   '비빔밥',
#   '메뉴',
#   '부다페스트',
#   '가나',
#   '영화',
#   '드림',
#   '박서준',
#   '더후',
#   '녀드성'],
#  ['캠핑',
#   '음식',
#   '추천',
#   '메뉴',
#   '로',
#   '꼽',
#   '서택기',
#   '쪽',
#   '갈비',
#   '후기',
#   '캠핑',
#   '음식',
#   '추천',
#   '가격',
#   '용량',
#   '글',
#   '사진',
#   '맛',
#   '고',
#   '여행',
#   '리즈',
#   '오늘',
#   '캠핑',
#   '음식',
#   '추천',
#   '메뉴',
#   '로',
#   '에어',
#   '프라이',
#   '사용',
#   '캠핑',
#   '때',
#   '메뉴',
#   '서택기',
#   '쪽',
#   '갈비',
#   '추천',
#   '요',
#   '맛',
#   '고',
#   '여행',
#   '리즈'],
#  ['탄탄면',
#   '방',
#   '인천',
#   '청라',
#   '점심',
#   '추천',
#   '메뉴',
#   '후기',
#   '메뉴',
#   '추천',
#   '옆',
#   '요즘',
#   '주문',
#   '키오',
#   '스크',
#   '요리',
#   '정도',
#   '거',
#   '유명',
#   '보시',
#   '다시피',
#   '조절',
#   '가능',
#   '가이드',
#   '고하',
#   '시기',
#   '추천',
#   '메뉴',
#   '소개',
#   '손님',
#   '안심',
#   '설계',
#   '사',
#   '치즈',
#   '보험'],
#  ['가창',
#   '룰리',
#   '커피',
#   '추천',
#   '메뉴',
#   '룰리',
#   '커피',
#   '추천',
#   '메뉴',
#   '아이스크림',
#   '커피',
#   '아이스크림',
#   '쫀득한데',
#   '커피',
#   '쫀득해',
#   '아이스크림',
#   '아하',
#   '데',
#   '이',
#   '날',
#   '커피',
#   '부터',
#   '진짜',
#   '디',
#   '카페인',
#   '아이스크림',
#   '커피',
#   '추천',
#   '저'],
#  ['쉑쉑',
#   '버거',
#   '강력',
#   '추천',
#   '메뉴',
#   '쉑쉑',
#   '버거',
#   '강력',
#   '추천',
#   '메뉴',
#   '중',
#   '하나',
#   '바닐라',
#   '쉐이크',
#   '진',
#   '맛',
#   '다른',
#   '쉐이크',
#   '압도',
#   '진리',
#   '생',
#   '각하',
#   '분',
#   '쉑',
#   '스택',
#   '버거',
#   '강력',
#   '추',
#   '천하',
#   '포스팅',
#   '버거',
#   '스택',
#   '추천',
#   '메뉴'],
#  ['렌',
#   '지쿠',
#   '캣',
#   '추천',
#   '메뉴',
#   '직화',
#   '삼겹살',
#   '바베큐',
#   '족발',
#   '찰',
#   '순대',
#   '간단',
#   '나머지',
#   '메뉴',
#   '렌지업',
#   '간편',
#   '조리',
#   '수',
#   '어서',
#   '주말',
#   '메뉴',
#   '로',
#   '어요',
#   '집',
#   '족발',
#   '때',
#   '무조건',
#   '뼈',
#   '족발',
#   '선호',
#   '렌',
#   '지쿠',
#   '캣',
#   '바베큐',
#   '족발',
#   '쫀득',
#   '하니',
#   '양념',
#   '까지',
#   '어서',
#   '진심',
#   '선물',
#   '하루'],
#  ['핫',
#   '후라이드',
#   '마법',
#   '봄',
#   '추천',
#   '메뉴',
#   '마법',
#   '핫',
#   '후라이드',
#   '둘',
#   '어보',
#   '추천',
#   '메뉴',
#   '저번',
#   '주말',
#   '낮',
#   '밥',
#   '안',
#   '해',
#   '배민',
#   '마법',
#   '신',
#   '메뉴',
#   '할인',
#   '중이',
#   '천원',
#   '할인',
#   '포장',
#   '할인',
#   '천원',
#   '까지',
#   '사',
#   '뽀기',
#   '일상'],
#  ['성식',
#   '영',
#   '맛집',
#   '이탈리안',
#   '맥',
#   '모닝',
#   '주차',
#   '정보',
#   '추천',
#   '메뉴',
#   '느낌',
#   '메뉴',
#   '거',
#   '고',
#   '사진',
#   '중',
#   '햄',
#   '판매',
#   '대요',
#   '모야',
#   '스페셜',
#   '추천',
#   '추천',
#   '메뉴',
#   '오리',
#   '널',
#   '판',
#   '체다',
#   '트러플',
#   '리코',
#   '타',
#   '스페셜',
#   '어서',
#   '재료',
#   '보고',
#   '취향'],
#  ['운동',
#   '후',
#   '음식',
#   '신체',
#   '회복',
#   '영양',
#   '보충',
#   '위',
#   '메뉴',
#   '추천',
#   '운동',
#   '후',
#   '음식',
#   '신체',
#   '회복',
#   '영양',
#   '보충',
#   '위',
#   '메뉴',
#   '추천',
#   '운동',
#   '후',
#   '신체',
#   '회복',
#   '영양',
#   '보충',
#   '위해',
#   '이',
#   '추천',
#   '메뉴',
#   '운동',
#   '후의',
#   '신체',
#   '회복',
#   '영양',
#   '보충',
#   '돕기',
#   '위해',
#   '참고',
#   '수',
#   '옵션',
#   '건강'],
#  ['맥도날드',
#   '가격',
#   '추천',
#   '메뉴',
#   '맥',
#   '모닝',
#   '맥런치',
#   '이용',
#   '시간',
#   '구리',
#   '추천',
#   '맥도날드',
#   '아이스크림',
#   '라떼',
#   '맥',
#   '모닝',
#   '종류',
#   '양하',
#   '정말',
#   '꼬맹이',
#   '메뉴',
#   '항상',
#   '해피밀',
#   '사이드',
#   '메뉴',
#   '매번',
#   '장난감',
#   '늘',
#   '신중',
#   '항상',
#   '제이',
#   '블로그'],
#  ['발산역',
#   '이자카야',
#   '단토',
#   '리',
#   '추천',
#   '메뉴',
#   '전자',
#   '메뉴판',
#   '이용',
#   '메뉴',
#   '주문',
#   '주문',
#   '접수',
#   '후',
#   '전자',
#   '메뉴판',
#   '주문',
#   '단토',
#   '리',
#   '가성',
#   '비',
#   '안주',
#   '공유',
#   '고',
#   '제일',
#   '단토',
#   '리',
#   '추천',
#   '메뉴',
#   '도',
#   '드릴',
#   '요',
#   '단토',
#   '리',
#   '취향',
#   '단편',
#   '집'],
#  ['퍼센트',
#   '커피',
#   '추천',
#   '메뉴',
#   '및',
#   '가격',
#   '정보공',
#   '유',
#   '효',
#   '천지',
#   '구',
#   '카페',
#   '서도',
#   '커피',
#   '메뉴',
#   '확인가능',
#   '도록',
#   '메뉴',
#   '판이',
#   '준비',
#   '어요',
#   '저',
#   '마시기',
#   '기분',
#   '단맛',
#   '수',
#   '어서',
#   '어요',
#   '퍼센트',
#   '커피',
#   '방문',
#   '라떼',
#   '추천'],
#  ['울산',
#   '남구',
#   '신정동',
#   '점심',
#   '추천',
#   '메뉴',
#   '로',
#   '스테이크',
#   '파스타',
#   '매장',
#   '휴무',
#   '유동',
#   '적',
#   '매장',
#   '방문',
#   '식사',
#   '미리',
#   '예약',
#   '준비',
#   '방문',
#   '식사',
#   '수',
#   '있오욤',
#   '울산',
#   '신정동',
#   '점심',
#   '메뉴',
#   '추천',
#   '울산',
#   '신정동',
#   '파스타',
#   '집',
#   '울산',
#   '맛집',
#   '추천'],
#  ['뚜레쥬르',
#   '빵',
#   '추천',
#   '메뉴',
#   '마담',
#   '얼그레이',
#   '크림',
#   '번',
#   '진짜',
#   '메뉴',
#   '발견',
#   '빵',
#   '추천',
#   '고요',
#   '총',
#   '가지',
#   '메뉴',
#   '를',
#   '저',
#   '마담',
#   '얼그레이',
#   '크림',
#   '번',
#   '소금',
#   '빵',
#   '초딩',
#   '입맛',
#   '짝꿍',
#   '피자빵',
#   '모닝빵',
#   '어요',
#   '이중',
#   '빵',
#   '추천',
#   '건',
#   '여행',
#   '일상'],
#  ['맛집',
#   '양재천',
#   '카페',
#   '거리',
#   '최애',
#   '맛집',
#   '카페',
#   '비밀',
#   '웨이',
#   '팅',
#   '추천',
#   '메뉴',
#   '누군가',
#   '양재천',
#   '카페',
#   '거리',
#   '브런치',
#   '맛집',
#   '물어',
#   '무조건',
#   '카페',
#   '비밀',
#   '추천',
#   '남자친구',
#   '집',
#   '아하',
#   '메뉴',
#   '가격',
#   '만원',
#   '카인',
#   '드',
#   '두번째',
#   '추천',
#   '메뉴',
#   '수비드',
#   '계란',
#   '매콤'],
#  ['가족',
#   '외식',
#   '메뉴',
#   '추천',
#   '만',
#   '조합',
#   '해도',
#   '성공',
#   '률',
#   '외식',
#   '메뉴',
#   '첫',
#   '추천',
#   '메뉴',
#   '명불허전',
#   '포',
#   '메인',
#   '쌈',
#   '월남쌈',
#   '포',
#   '메인',
#   '월남쌈',
#   '채소',
#   '고기',
#   '더',
#   '불어',
#   '닭고기',
#   '단백질',
#   '듬뿍',
#   '섭취',
#   '수',
#   '어서',
#   '성장기',
#   '아이',
#   '추천',
#   '메뉴',
#   '쌀국수',
#   '포',
#   '메인'],
#  ['국물',
#   '요리',
#   '차돌',
#   '육개장',
#   '저녁',
#   '메뉴',
#   '추천',
#   '국물',
#   '요리',
#   '차돌',
#   '육개장',
#   '저녁',
#   '메뉴',
#   '추천',
#   '신랑',
#   '국물',
#   '요리',
#   '워낙',
#   '아해',
#   '밥',
#   '때',
#   '꼬',
#   '옥',
#   '저녁',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '로',
#   '챙',
#   '기고',
#   '더미',
#   '식',
#   '상온',
#   '국물',
#   '요리',
#   '설렁탕',
#   '소고기',
#   '미역국',
#   '닭개장',
#   '사골곰탕',
#   '시크',
#   '도도',
#   '토깽',
#   '살',
#   '효'],
#  ['알고리즘',
#   '주문',
#   '방법',
#   '영업',
#   '시간',
#   '메뉴',
#   '추천',
#   '월부',
#   '턴',
#   '월',
#   '화요일',
#   '휴무',
#   '방문',
#   '참고',
#   '곳',
#   '한철',
#   '꽈배기',
#   '의',
#   '메뉴판',
#   '저',
#   '한철',
#   '꽈배기',
#   '추천',
#   '메뉴',
#   '인',
#   '백',
#   '바치',
#   '토',
#   '안',
#   '바질',
#   '선',
#   '드라이',
#   '토마토',
#   '페퍼로니',
#   '등',
#   '어요',
#   '피자빵',
#   '소',
#   '소한',
#   '하늘'],
#  ['메',
#   '커피',
#   '알바생',
#   '메뉴',
#   '추천',
#   '나주',
#   '럼',
#   '코트',
#   '스무디',
#   '신',
#   '메뉴',
#   '안',
#   '제',
#   '아하',
#   '메뉴인',
#   '데',
#   '추천',
#   '메뉴',
#   '기분',
#   '고요',
#   '여름',
#   '신',
#   '메뉴',
#   '더더',
#   '욱',
#   '추천',
#   '해주',
#   '셨는데',
#   '스무디',
#   '부터',
#   '하이',
#   '볼',
#   '콤부',
#   '에이드',
#   '까지',
#   '비주',
#   '얼',
#   '상큼',
#   '어요',
#   '주',
#   '문하',
#   '자마자'],
#  ['컴',
#   '포즈',
#   '메뉴',
#   '추천',
#   '아이',
#   '캔디',
#   '소',
#   '밀크쉐이크',
#   '와플',
#   '컴',
#   '포즈',
#   '메뉴',
#   '추천',
#   '캔디',
#   '소',
#   '밀크쉐이크',
#   '와플',
#   '아침',
#   '간단',
#   '토마토',
#   '셋',
#   '이서',
#   '수영강',
#   '산책',
#   '포즈',
#   '메뉴판',
#   '포즈',
#   '추천',
#   '메뉴',
#   '포즈',
#   '메뉴',
#   '포즈',
#   '와플',
#   '컴',
#   '포즈',
#   '커피',
#   '안락',
#   '점',
#   '내부',
#   '테이블',
#   '꽤',
#   '광안',
#   '둥이',
#   '아이',
#   '행복',
#   '일상'],
#  ['고깃집',
#   '평일',
#   '웨이',
#   '팅',
#   '육즙',
#   '가득',
#   '목살',
#   '추천',
#   '메뉴',
#   '코쿠미',
#   '쌀밥',
#   '파스타',
#   '개존맛',
#   '메뉴',
#   '주문',
#   '메뉴',
#   '목살',
#   '인분',
#   '삼겹살',
#   '인분',
#   '쿠',
#   '티크',
#   '파스타',
#   '개',
#   '강변',
#   '외할머니',
#   '된장찌개',
#   '목살',
#   '추천',
#   '쿠',
#   '티크',
#   '트러플',
#   '파스타',
#   '삼양',
#   '쿠',
#   '티크',
#   '트러플',
#   '파스타',
#   '인증',
#   '이벤트',
#   '융',
#   '여의',
#   '심심',
#   '풀이',
#   '땅콩'],
#  ['롯데리아',
#   '신',
#   '메뉴',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '상큼',
#   '점심',
#   '메뉴',
#   '추천',
#   '롯데리아',
#   '롯데리아',
#   '신',
#   '메뉴',
#   '롯데리아',
#   '새우',
#   '버거',
#   '롯데리아',
#   '햄버거',
#   '햄버거',
#   '새우',
#   '버거',
#   '롯데리아',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '롯데리아',
#   '팍',
#   '롯데리아',
#   '음원',
#   '롯데리아',
#   '이벤트',
#   '점심',
#   '메뉴',
#   '추천',
#   '푸드',
#   '섹',
#   '라이언',
#   '정보',
#   '창고'],
#  ['롯데',
#   '호텔',
#   '제주',
#   '아이',
#   '룸서비스',
#   '추천',
#   '메뉴',
#   '치킨',
#   '갈비탕',
#   '롯데',
#   '호텔',
#   '제주',
#   '룸서비스',
#   '추천',
#   '메뉴',
#   '롯데',
#   '호텔',
#   '첫날',
#   '수영장',
#   '주문',
#   '치킨',
#   '치킨',
#   '솔직',
#   '가격',
#   '대가',
#   '어서',
#   '메뉴',
#   '정독',
#   '분한',
#   '거',
#   '뭐',
#   '윤아',
#   '까지',
#   '먹이',
#   '면서',
#   '나',
#   '누나'],
#  ['치킨',
#   '메뉴',
#   '추천',
#   '신',
#   '메뉴',
#   '마법',
#   '포테킹',
#   '돈',
#   '산',
#   '주문',
#   '후기',
#   '치킨',
#   '추천',
#   '메뉴',
#   '포테킹',
#   '마법',
#   '줄',
#   '요약',
#   '튀김',
#   '옷',
#   '바삭',
#   '후라이드',
#   '아하',
#   '시',
#   '분들껜',
#   '포테킹',
#   '닭강정',
#   '양념',
#   '치킨',
#   '아하',
#   '분',
#   '마법',
#   '추천',
#   '포테킹',
#   '후기',
#   '샤로',
#   '블로그'],
#  ['찹쌀',
#   '이유식',
#   '맛',
#   '영양',
#   '유아',
#   '안성맞춤',
#   '추천',
#   '메뉴',
#   '찹쌀',
#   '이유식',
#   '활용',
#   '제공',
#   '수',
#   '다양',
#   '메뉴',
#   '찹쌀',
#   '이유식',
#   '첫',
#   '추천',
#   '메뉴',
#   '찹쌀',
#   '이유식',
#   '찹쌀',
#   '이유식',
#   '물',
#   '우유',
#   '아이',
#   '먹기',
#   '죽',
#   '박쌤',
#   '육아',
#   '로그'],
#  ['말복',
#   '메뉴',
#   '추천',
#   '찜',
#   '찜닭',
#   '복날',
#   '메뉴',
#   '추천',
#   '찜',
#   '슈퍼',
#   '팝',
#   '세트',
#   '찜닭',
#   '세트',
#   '기본',
#   '가격',
#   '마리',
#   '찜닭',
#   '콜라',
#   '찜',
#   '찜닭',
#   '추천',
#   '복날',
#   '추천',
#   '메뉴',
#   '찜닭',
#   '초복',
#   '중복',
#   '말복',
#   '찜닭'],
#  ['롯데리아',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '신',
#   '메뉴',
#   '점심',
#   '메뉴',
#   '추천',
#   '오늘',
#   '점심',
#   '메뉴',
#   '추천',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '가요',
#   '롯데리아',
#   '롯데리아',
#   '신',
#   '메뉴',
#   '롯데리아',
#   '새우',
#   '버거',
#   '롯데리아',
#   '햄버거',
#   '햄버거',
#   '새우',
#   '버거',
#   '롯데리아',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '남쪽',
#   '구슬'],
#  ['신촌',
#   '술집',
#   '추천',
#   '신촌',
#   '분위기',
#   '술집',
#   '메뉴',
#   '판',
#   '베스트',
#   '메뉴',
#   '신촌',
#   '안주',
#   '맛집',
#   '신촌',
#   '술집',
#   '추천',
#   '신촌',
#   '포차',
#   '신촌',
#   '보드카',
#   '술집',
#   '신촌',
#   '분위기',
#   '술집',
#   '신촌',
#   '단체',
#   '술집',
#   '신촌',
#   '안주',
#   '보스',
#   '포차',
#   '추천',
#   '메뉴',
#   '및',
#   '주문',
#   '메뉴',
#   '닭볶음탕',
#   '닭볶음탕',
#   '닭볶음탕',
#   '감자',
#   '해'],
#  ['김포',
#   '구래동',
#   '맛집',
#   '점심',
#   '추천',
#   '메뉴',
#   '석기',
#   '정',
#   '돌솥',
#   '부대찌개',
#   '소',
#   '곱창',
#   '부대찌개',
#   '유혹',
#   '첫',
#   '방문',
#   '시',
#   '그니',
#   '처',
#   '메뉴',
#   '를',
#   '갤럭시',
#   '울트라',
#   '김포시',
#   '구래동',
#   '맛집',
#   '석기',
#   '정',
#   '부대찌개',
#   '강력',
#   '추천',
#   '이유',
#   '우선',
#   '응대',
#   '친절',
#   '가격',
#   '미리',
#   '렌트카',
#   '오토',
#   '리스',
#   '장기',
#   '렌트카',
#   '수수료'],
#  ['그릇',
#   '뚝딱',
#   '유아식',
#   '소고기',
#   '콩나물밥',
#   '간편',
#   '유아식',
#   '메뉴',
#   '추천',
#   '유아식',
#   '메뉴',
#   '추천',
#   '글',
#   '그릇',
#   '뚝딱',
#   '유아식',
#   '추천',
#   '메뉴',
#   '아기',
#   '잔치국수',
#   '만들기',
#   '닭다리',
#   '삼계탕',
#   '만들기',
#   '솜',
#   '구름',
#   '구름',
#   '방'],
#  ['서현',
#   '맛집',
#   '샌드위치',
#   '써브웨이',
#   '추천',
#   '메뉴',
#   '치킨데리야끼',
#   '서브웨이',
#   '추천',
#   '메뉴',
#   '치킨',
#   '데리야키',
#   '건강',
#   '맛',
#   '써브웨이',
#   '서현',
#   '서현',
#   '써브웨이',
#   '써브웨이',
#   '가격',
#   '써브웨이',
#   '추천',
#   '메뉴',
#   '써브웨이',
#   '메뉴',
#   '추천',
#   '분당',
#   '써브웨이',
#   '써브웨이',
#   '메뉴',
#   '치킨',
#   '데리야키',
#   '치킨데리야끼',
#   '써브웨이',
#   '치킨',
#   '데리야키',
#   '비만',
#   '소년',
#   '밥'],
#  ['홍콩',
#   '맛집',
#   '남',
#   '기분',
#   '추천',
#   '메뉴',
#   '어간',
#   '메뉴',
#   '무조건',
#   '추천',
#   '개',
#   '인적',
#   '돼지',
#   '고기',
#   '어간',
#   '게',
#   '고요',
#   '탕',
#   '사우',
#   '앤',
#   '스파이',
#   '시',
#   '시',
#   '탕',
#   '추천',
#   '실패',
#   '가게'],
#  ['대전',
#   '시청',
#   '맛집',
#   '친절',
#   '봉',
#   '김밥',
#   '추천',
#   '메뉴',
#   '가격',
#   '식사',
#   '때',
#   '추천',
#   '대전',
#   '맛집',
#   '봉',
#   '김밥',
#   '오후',
#   '것',
#   '것',
#   '어서',
#   '간단',
#   '봉',
#   '김밥',
#   '봉',
#   '김밥',
#   '봉',
#   '김밥',
#   '메뉴',
#   '및',
#   '가격',
#   '김밥',
#   '기본',
#   '셋팅',
#   '셀프',
#   '바',
#   '국',
#   '김치',
#   '단무지',
#   '배치',
#   '국'],
#  ['여름',
#   '음식',
#   '추천',
#   '점심',
#   '회식',
#   '메뉴',
#   '고민',
#   '해결',
#   '점심',
#   '뿐',
#   '회식',
#   '추천',
#   '메뉴',
#   '로',
#   '오늘',
#   '점심',
#   '메뉴',
#   '시원',
#   '여름철',
#   '보양식',
#   '부터',
#   '속',
#   '까지',
#   '시원',
#   '음식',
#   '까지',
#   '추천',
#   '여름',
#   '음식',
#   '추',
#   '천하',
#   '점심',
#   '콩국수',
#   '여름철',
#   '한정',
#   '메뉴',
#   '볼',
#   '수',
#   '콩국수'],
#  ['대구',
#   '중구',
#   '동성로',
#   '반월당',
#   '맛집',
#   '끼',
#   '추천',
#   '메뉴',
#   '낙지볶음',
#   '낙지볶음',
#   '점심',
#   '저녁',
#   '끼',
#   '식사',
#   '추천',
#   '메뉴',
#   '간',
#   '친구',
#   '그냥',
#   '데',
#   '나',
#   '매콤',
#   '나',
#   '더',
#   '마음',
#   '좀',
#   '걸',
#   '사람',
#   '쑥'],
#  ['서면',
#   '국물',
#   '닭발',
#   '유명',
#   '옥탑방',
#   '두',
#   '얼간이',
#   '서면',
#   '점',
#   '추천',
#   '메뉴',
#   '부분',
#   '메뉴',
#   '를',
#   '추천',
#   '서면',
#   '국물',
#   '닭발',
#   '유명',
#   '집',
#   '답',
#   '국물',
#   '닭발',
#   '이',
#   '가게',
#   '대표',
#   '메뉴',
#   '난',
#   '궁극',
#   '순두부',
#   '픽했다',
#   '마라탕',
#   '이나',
#   '전골',
#   '젠',
#   '것',
#   '부터',
#   '생각',
#   '날',
#   '듯',
#   '궁극',
#   '어서'],
#  ['휘닉스',
#   '평창',
#   '블루',
#   '푸드코트',
#   '메뉴',
#   '추천',
#   '강원도',
#   '휘닉스',
#   '평창',
#   '워터파크',
#   '블루',
#   '푸드코트',
#   '추천',
#   '메뉴',
#   '후기',
#   '봄',
#   '블루',
#   '연회',
#   '권',
#   '메뉴',
#   '추천',
#   '것',
#   '것',
#   '결과',
#   '개',
#   '인적',
#   '돈까스',
#   '프리미엄',
#   '등심',
#   '카츠',
#   '무조건',
#   '기본',
#   '주말',
#   '캠핑'],
#  ['치킨',
#   '추천',
#   '메뉴',
#   '뿌',
#   '링클',
#   '콤보',
#   '식후감뿌링',
#   '애',
#   '입맛',
#   '비슷',
#   '치즈',
#   '가루',
#   '맛',
#   '요즘',
#   '뭐',
#   '마라탕',
#   '탕후루',
#   '강의',
#   '맛',
#   '중독',
#   '하니',
#   '한번',
#   '돈',
#   '산',
#   '리뷰',
#   '링클',
#   '콤보',
#   '격',
#   '메뉴',
#   '추천',
#   '링클',
#   '치킨'],
#  ['치킨',
#   '메뉴',
#   '추천',
#   '골드',
#   '킹',
#   '콤보',
#   '뿌',
#   '링클',
#   '세트',
#   '베스트',
#   '추천',
#   '메뉴',
#   '치킨',
#   '두마',
#   '리',
#   '깁콘',
#   '어요',
#   '안',
#   '초등',
#   '고학년',
#   '저학년',
#   '아이',
#   '인',
#   '닭',
#   '대표',
#   '메뉴',
#   '추',
#   '천하',
#   '이유',
#   '닝',
#   '독특',
#   '뿌링뿌',
#   '링클',
#   '단',
#   '달달',
#   '면서',
#   '짭쪼',
#   '로미',
#   '하니',
#   '치토스',
#   '타일',
#   '효로',
#   '롱',
#   '푸드',
#   '로그'],
#  ['태국',
#   '방콕여행',
#   '왓아룬',
#   '야경',
#   '맛집',
#   '더데',
#   '예약',
#   '추천',
#   '메뉴',
#   '다이렉트',
#   '온라인',
#   '예약',
#   '불가',
#   '대행',
#   '업체',
#   '통해',
#   '전화',
#   '는걸',
#   '추천',
#   '운',
#   '처럼',
#   '메뉴',
#   '우왕',
#   '느낌',
#   '년전',
#   '땐',
#   '엘리'],
#  ['쉐이크',
#   '쉑',
#   '용산',
#   '아이파크몰',
#   '쉑쉑',
#   '버거',
#   '추천',
#   '메뉴',
#   '가격',
#   '버거',
#   '때',
#   '버거',
#   '감',
#   '쉐이크',
#   '조합',
#   '보시',
#   '길',
#   '추천',
#   '쉐이크',
#   '쉑',
#   '쉐이크',
#   '쉑',
#   '용산',
#   '버거',
#   '버거',
#   '용산',
#   '버거',
#   '가격',
#   '버거',
#   '메뉴',
#   '쉐이크',
#   '쉑',
#   '가격',
#   '쉐이크',
#   '쉑',
#   '메뉴',
#   '버거',
#   '메뉴',
#   '추천'],
#  ['괌',
#   '비치',
#   '쉬',
#   '림프',
#   '메뉴',
#   '추천',
#   '마이크로네시아',
#   '키즈',
#   '메뉴',
#   '하나',
#   '더',
#   '추가',
#   '치킨',
#   '너겟',
#   '추천',
#   '어요',
#   '그',
#   '래서',
#   '마지막',
#   '치킨',
#   '너겟',
#   '까지',
#   '추가',
#   '치킨',
#   '너겟',
#   '괌',
#   '비치',
#   '쉬',
#   '림프',
#   '추천',
#   '메뉴',
#   '인',
#   '코코넛',
#   '쉬',
#   '림프',
#   '채',
#   '여행',
#   '기록'],
#  ['삼각지',
#   '카페',
#   '테디',
#   '뵈르',
#   '하우스',
#   '메뉴',
#   '추천',
#   '용산',
#   '핫',
#   '크룽',
#   '등',
#   '시',
#   '그니',
#   '처',
#   '메뉴',
#   '추천',
#   '까지',
#   '소개',
#   '테디',
#   '뵈르',
#   '하우스',
#   '위치',
#   '서울시',
#   '용산구',
#   '한강대로',
#   '피스타치오',
#   '추천',
#   '메뉴',
#   '중',
#   '하나',
#   '피스타치오',
#   '아이스크림',
#   '피스타치오',
#   '뀐아망',
#   '피스타치오',
#   '여행',
#   '일상',
#   '여행'],
#  ['이자카야',
#   '숙성',
#   '회',
#   '제주',
#   '딱새',
#   '우회',
#   '세트',
#   '메뉴',
#   '추천',
#   '동래',
#   '별장',
#   '덕분',
#   '저',
#   '메뉴',
#   '고민',
#   '추천',
#   '메뉴',
#   '로',
#   '줄',
#   '리뷰',
#   '입',
#   '살살',
#   '제주',
#   '딱새',
#   '우회',
#   '추천',
#   '방이동',
#   '맛집',
#   '동래',
#   '별장',
#   '방이동',
#   '골목',
#   '방이동',
#   '이자카야',
#   '한식',
#   '느낌',
#   '맛집',
#   '동래',
#   '별장',
#   '월드',
#   '세상'],
#  ['태릉',
#   '입구',
#   '술집',
#   '금별',
#   '맥주',
#   '묵',
#   '동자',
#   '이점',
#   '메뉴',
#   '추천',
#   '살얼음',
#   '얼',
#   '만큼',
#   '차',
#   '가운',
#   '생맥주',
#   '금별',
#   '맥주',
#   '특색',
#   '안주',
#   '메뉴',
#   '추천',
#   '가격',
#   '대도',
#   '부담',
#   '메뉴',
#   '요',
#   '세',
#   '가지',
#   '한번',
#   '조합',
#   '누구',
#   '금별',
#   '맥주',
#   '대표',
#   '추천',
#   '메뉴',
#   '로'],
#  ['배곧',
#   '점심',
#   '메뉴',
#   '추천',
#   '삼겹살',
#   '맛집',
#   '조선',
#   '부뚜막',
#   '고기',
#   '집',
#   '배곧',
#   '삼겹살',
#   '맛집',
#   '추천',
#   '메뉴',
#   '부뚜막',
#   '상',
#   '소',
#   '메인',
#   '메뉴',
#   '고요',
#   '저희',
#   '넷',
#   '때문',
#   '쌈무',
#   '파',
#   '절임',
#   '차돌박이',
#   '조합',
#   '추천',
#   '조합',
#   '흡족',
#   '맛',
#   '이기',
#   '때문',
#   '배곧',
#   '찰나',
#   '의순',
#   '간'],
#  ['죽',
#   '삼계',
#   '죽',
#   '메뉴',
#   '추천',
#   '건강',
#   '끼',
#   '느낌',
#   '이유',
#   '맛',
#   '나유',
#   '죽',
#   '메뉴',
#   '추천',
#   '날씨',
#   '모든',
#   '게',
#   '녹',
#   '아버',
#   '릴',
#   '듯',
#   '이',
#   '더위',
#   '살짝',
#   '정신',
#   '날씨',
#   '내',
#   '몸',
#   '내',
#   '제대로',
#   '거의',
#   '몸',
#   '보신',
#   '죽',
#   '추천',
#   '메뉴',
#   '배배공',
#   '배배',
#   '배부',
#   '른',
#   '공간'],
#  ['하남',
#   '스타',
#   '필드',
#   '솔직',
#   '후기',
#   '추천',
#   '메뉴',
#   '트러플',
#   '풍기',
#   '피자',
#   '피자',
#   '포장',
#   '차',
#   '포장',
#   '박스',
#   '트러플',
#   '향',
#   '고',
#   '집',
#   '서도',
#   '집안',
#   '풍기',
#   '트러플',
#   '향',
#   '이비',
#   '티',
#   '가면',
#   '꼭',
#   '메뉴',
#   '감히',
#   '말',
#   '이비',
#   '티',
#   '평',
#   '추천',
#   '과',
#   '데',
#   '일리',
#   '원스'],
#  ['카페',
#   '산뜻',
#   '런치',
#   '뷔페',
#   '맛집',
#   '사적',
#   '리뷰',
#   '돈',
#   '산',
#   '추천',
#   '메뉴',
#   '평일',
#   '주말',
#   '런치',
#   '디너',
#   '운영',
#   '가격',
#   '출처',
#   '홈페이지',
#   '주중',
#   '주말',
#   '가격',
#   '메뉴',
#   '도',
#   '나',
#   '커피',
#   '아메리카노',
#   '한번',
#   '더',
#   '라떼',
#   '아메리카노',
#   '추천',
#   '호텔',
#   '호텔',
#   '정',
#   '맛',
#   '어제',
#   '나',
#   '조금',
#   '나은',
#   '내'],
#  ['신세계',
#   '백화점',
#   '홍콩',
#   '음식',
#   '전문점',
#   '딤섬',
#   '맛집',
#   '호우',
#   '섬',
#   '추천',
#   '메뉴',
#   '호우',
#   '섬',
#   '메뉴',
#   '및',
#   '가격',
#   '때',
#   '마다',
#   '블랙',
#   '가우',
#   '구',
#   '짜장',
#   '도삭',
#   '은',
#   '필수',
#   '메뉴',
#   '다섯',
#   '개',
#   '향',
#   '아기',
#   '새',
#   '손',
#   '때',
#   '마다',
#   '만',
#   '족하',
#   '호우',
#   '섬',
#   '딤섬',
#   '때',
#   '추천',
#   '뚜비',
#   '뚜비',
#   '하루'],
#  ['만족',
#   '세트',
#   '메뉴',
#   '추천',
#   '제주',
#   '공항',
#   '근처',
#   '갈치구이',
#   '솔직',
#   '후기',
#   '저희',
#   '자리',
#   '다양',
#   '구성',
#   '세트',
#   '메뉴',
#   '눈',
#   '어서',
#   '메뉴',
#   '판',
#   '다가',
#   '보이',
#   '다른',
#   '분',
#   '만족도',
#   '식사',
#   '바',
#   '라며',
#   '추천',
#   '해',
#   '제주',
#   '공항',
#   '근처',
#   '갈치구이',
#   '갈치',
#   '음식점',
#   '궁서체',
#   '비글',
#   '맘',
#   '꼬',
#   '꼬마',
#   '아빠',
#   '육아',
#   '일상'],
#  ['운',
#   '양동',
#   '맛집',
#   '부글',
#   '식당',
#   '추천',
#   '메뉴',
#   '곱창',
#   '사발',
#   '운',
#   '양동',
#   '맛집',
#   '부글',
#   '식당',
#   '추천',
#   '메뉴',
#   '곱창',
#   '사발',
#   '저희',
#   '다른',
#   '메뉴',
#   '어서',
#   '곱창',
#   '사발',
#   '부글',
#   '식당',
#   '배달',
#   '집',
#   '야식',
#   '추천',
#   '곱창',
#   '오동',
#   '통한',
#   '거',
#   '보이시',
#   '요',
#   '곱',
#   '가득'],
#  ['소하',
#   '염전',
#   '경주',
#   '황리',
#   '길',
#   '소금',
#   '빵',
#   '맛집',
#   '카페',
#   '추천',
#   '메뉴',
#   '전',
#   '체적',
#   '메뉴',
#   '베이커리',
#   '소금',
#   '빵',
#   '주',
#   '음료',
#   '적당',
#   '주문',
#   '메뉴',
#   '쪽파',
#   '나',
#   '내',
#   '픽',
#   '두',
#   '소금',
#   '빵',
#   '완전',
#   '추천',
#   '한가지',
#   '경주',
#   '일정',
#   '끝내',
#   '집',
#   '때',
#   '소금',
#   '빵',
#   '아람',
#   '사계절',
#   '여행',
#   '일기'],
#  ['서울',
#   '여행',
#   '석촌',
#   '야끼소바',
#   '니',
#   '주마',
#   '루',
#   '추천',
#   '메뉴',
#   '줄',
#   '서서',
#   '기',
#   '다리',
#   '다가',
#   '우리',
#   '차례',
#   '근처',
#   '미리',
#   '메뉴판',
#   '우리',
#   '추천',
#   '메뉴',
#   '를',
#   '둘',
#   '주문',
#   '보기',
#   '추천',
#   '메뉴',
#   '인',
#   '소금',
#   '오징어',
#   '새우',
#   '소스',
#   '치즈',
#   '비엔나',
#   '두',
#   '종류',
#   '야끼소바',
#   '여행',
#   '더하기'],
#  ['판교',
#   '맛집',
#   '에그슬럿',
#   '분당',
#   '정자',
#   '오픈',
#   '메뉴',
#   '추천',
#   '원픽',
#   '추천',
#   '메뉴',
#   '저',
#   '프리타타',
#   '신선',
#   '하니',
#   '고요',
#   '신상',
#   '핫',
#   '아하',
#   '스타',
#   '다양',
#   '메뉴',
#   '선',
#   '보이',
#   '에그슬럿',
#   '대표',
#   '육류',
#   '앵거스',
#   '비프',
#   '패티',
#   '애플',
#   '우드',
#   '훈제',
#   '베이컨'],
#  ['용산',
#   '맛집',
#   '쌤쌤쌤',
#   '브런치',
#   '맛집',
#   '웨이',
#   '팅',
#   '메뉴',
#   '추천',
#   '예약',
#   '웨이',
#   '팅',
#   '메뉴',
#   '추천',
#   '쌤쌤쌤',
#   '메뉴',
#   '추천',
#   '날',
#   '이지',
#   '실내',
#   '꽉',
#   '차고',
#   '웨이',
#   '팅',
#   '쌤쌤쌤',
#   '쌤쌤쌤',
#   '메뉴',
#   '별',
#   '표시',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '기',
#   '다리',
#   '동안',
#   '메뉴',
#   '요',
#   '청하면',
#   '미리',
#   '볼',
#   '수',
#   '어요',
#   '별표',
#   '시',
#   '주우'],
#  ['세부',
#   '맛집',
#   '번',
#   '방문',
#   '오',
#   '이스터',
#   '베이',
#   '추천',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '까지',
#   '콕',
#   '찝어드',
#   '리도',
#   '록',
#   '욧',
#   '메뉴판',
#   '사진',
#   '주의',
#   '오',
#   '이스터',
#   '베이',
#   '씨',
#   '푸드',
#   '레스토랑',
#   '세부',
#   '맛집',
#   '추천',
#   '아보',
#   '신',
#   '분',
#   '라면',
#   '번',
#   '곳',
#   '한국',
#   '수',
#   '알리',
#   '망오',
#   '비글',
#   '비글',
#   '하루'],
#  ['더',
#   '현대',
#   '서울',
#   '팝업',
#   '스토어',
#   '브',
#   '레디',
#   '포스트',
#   '진지희',
#   '프레첼',
#   '추천',
#   '메뉴',
#   '쥰',
#   '대장',
#   '추천',
#   '메뉴',
#   '초콜렛',
#   '씨앗',
#   '호떡',
#   '베이컨',
#   '부추',
#   '토마',
#   '콘',
#   '갠',
#   '베이컨',
#   '부추',
#   '토마',
#   '콘',
#   '완전',
#   '강추',
#   '브',
#   '레디',
#   '포스트',
#   '팝업',
#   '방문',
#   '꼭',
#   '한번',
#   '맛',
#   '보시',
#   '길',
#   '추천'],
#  ['번',
#   '여행',
#   '내',
#   '인정',
#   '씨',
#   '푸드',
#   '맛집',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '보라카이',
#   '푸드',
#   '맛집',
#   '소개',
#   '마사지',
#   '마사지',
#   '사',
#   '장님',
#   '도',
#   '해룡',
#   '왕',
#   '추천',
#   '해',
#   '주',
#   '시더',
#   '요',
#   '해룡',
#   '왕',
#   '메뉴',
#   '해룡',
#   '왕',
#   '메뉴',
#   '확인',
#   '한국인',
#   '사',
#   '장님',
#   '마음',
#   '면서',
#   '하루'],
#  ['판교',
#   '오리',
#   '널',
#   '팬케이크',
#   '하우스',
#   '후기',
#   '메뉴',
#   '추천',
#   '주말',
#   '오픈',
#   '런',
#   '추천',
#   '메뉴',
#   '장',
#   '팬케이크',
#   '과일',
#   '토핑',
#   '걸',
#   '주문',
#   '에그베네딕트',
#   '하나',
#   '어요',
#   '포테이토',
#   '메뉴',
#   '다가',
#   '에그베네딕트',
#   '결론',
#   '적',
#   '추천',
#   '즐거움',
#   '블로그'],
#  ['정자동',
#   '영',
#   '커피',
#   '추천',
#   '영',
#   '커피',
#   '메뉴',
#   '저',
#   '처럼',
#   '처음',
#   '오신',
#   '면',
#   '베스트',
#   '영',
#   '커피',
#   '메뉴',
#   '식후떼',
#   '추천',
#   '요',
#   '아메리카노',
#   '가격',
#   '식후떼',
#   '여름',
#   '마시기',
#   '수박',
#   '주스',
#   '맛',
#   '식혜',
#   '추천',
#   '메뉴',
#   '어요',
#   '고',
#   '아침',
#   '식사',
#   '대용',
#   '여행가',
#   '세라',
#   '여행',
#   '블로그'],
#  ['금별',
#   '맥주',
#   '추천',
#   '메뉴',
#   '메뉴판',
#   '가득',
#   '추천',
#   '메뉴',
#   '곳',
#   '라면',
#   '간단',
#   '한잔',
#   '곳',
#   '맥주',
#   '안주',
#   '추천',
#   '만하',
#   '소주',
#   '안주',
#   '튀김',
#   '국물',
#   '안주',
#   '양하',
#   '어서',
#   '손님',
#   '별',
#   '여행',
#   '주식회사'],
#  ['용산',
#   '맛집',
#   '로스트',
#   '홍콩',
#   '인기',
#   '메뉴',
#   '추천',
#   '추천',
#   '해주',
#   '메뉴',
#   '오랜만',
#   '친구',
#   '약속',
#   '인기',
#   '맛집',
#   '기분',
#   '어요',
#   '잠깐',
#   '동안',
#   '홍콩',
#   '현지',
#   '음식',
#   '느낌',
#   '어서',
#   '여행',
#   '온',
#   '수험',
#   '중'],
#  ['후기',
#   '추천',
#   '메뉴',
#   '가격',
#   '위치',
#   '아기',
#   '가기',
#   '맛집',
#   '아기',
#   '의자',
#   '콘',
#   '타이',
#   '위례',
#   '스타',
#   '필드',
#   '점',
#   '메뉴',
#   '가격',
#   '톰얌',
#   '쌀국수',
#   '팟',
#   '씨유',
#   '새우볶음',
#   '밥',
#   '이',
#   '날',
#   '위례콘',
#   '타이',
#   '추천',
#   '메뉴',
#   '타이가',
#   '격',
#   '타이가',
#   '격',
#   '타이',
#   '추천',
#   '메뉴',
#   '타이',
#   '똠얌',
#   '쌀국수',
#   '똠얌',
#   '쌀국수',
#   '복',
#   '편살',
#   '단디',
#   '맘'],
#  ['부평',
#   '저스트',
#   '텐동',
#   '평리',
#   '점심',
#   '데이트',
#   '추천',
#   '메뉴',
#   '텐동',
#   '맛집',
#   '부평',
#   '저스트',
#   '텐동',
#   '평리',
#   '점심',
#   '데이트',
#   '추천',
#   '메뉴',
#   '텐동',
#   '맛집',
#   '안녕',
#   '욧',
#   '최근',
#   '개봉',
#   '영화',
#   '밀수',
#   '냉',
#   '우동',
#   '맛집',
#   '부평',
#   '냉',
#   '우동',
#   '부평',
#   '시장',
#   '맛집',
#   '텐동',
#   '추천',
#   '일상',
#   '주차장',
#   '영화',
#   '데이트',
#   '메뉴',
#   '점심',
#   '메뉴',
#   '리얀',
#   '기억',
#   '저장',
#   '소'],
#  ['수원',
#   '광교',
#   '딤섬',
#   '맛집',
#   '티엔',
#   '바오',
#   '추천',
#   '메뉴',
#   '메뉴',
#   '추천',
#   '드릴',
#   '요',
#   '수원',
#   '맛집',
#   '티엔',
#   '바오',
#   '추천',
#   '메뉴',
#   '가지',
#   '딤섬',
#   '겉바',
#   '촉',
#   '가지',
#   '새우',
#   '어간',
#   '가지',
#   '딤섬',
#   '제',
#   '원픽',
#   '메뉴',
#   '식감',
#   '가지',
#   '새우',
#   '조합',
#   '박력'],
#  ['당산',
#   '브런치',
#   '빈',
#   '후기',
#   '메뉴',
#   '추천',
#   '주차',
#   '브런치',
#   '메뉴',
#   '층',
#   '수',
#   '층',
#   '손님',
#   '다음',
#   '혼자',
#   '층',
#   '커피',
#   '브런치',
#   '빈',
#   '최고',
#   '추천',
#   '메뉴',
#   '스파이스',
#   '쉬',
#   '림프',
#   '파스타',
#   '이',
#   '파스타',
#   '진짜',
#   '인기',
#   '리조또',
#   '어차피',
#   '미쯔루',
#   '이야기'],
#  ['내',
#   '기준',
#   '살',
#   '만공',
#   '격',
#   '추천',
#   '메뉴',
#   '살',
#   '만공',
#   '격',
#   '추천',
#   '메뉴',
#   '를',
#   '거',
#   '강',
#   '추하',
#   '와사비',
#   '크림',
#   '것',
#   '내',
#   '선택',
#   '주문',
#   '세',
#   '가지',
#   '메뉴',
#   '중',
#   '하나',
#   '그냥',
#   '무난',
#   '무난',
#   '이름',
#   '와사비',
#   '어가',
#   '어서',
#   '좀',
#   '더',
#   '강렬',
#   '맛'],
#  ['커피',
#   '리터',
#   '백억',
#   '커피',
#   '동묘앞역',
#   '점',
#   '추천',
#   '메뉴',
#   '완전',
#   '빨',
#   '제',
#   '주문',
#   '메뉴',
#   '백억',
#   '커피',
#   '수',
#   '추천',
#   '메뉴',
#   '리터',
#   '아메리카노',
#   '캬라멜',
#   '팝콘',
#   '고',
#   '요즘',
#   '칸',
#   '슈',
#   '크로칸슈',
#   '오',
#   '자마자',
#   '바로',
#   '냉동',
#   '에프',
#   '살짝'],
#  ['대전',
#   '역',
#   '성심당',
#   '위치',
#   '부추',
#   '빵',
#   '튀김',
#   '소보',
#   '가격',
#   '추천',
#   '메뉴',
#   '그',
#   '중',
#   '서도',
#   '필수',
#   '추천',
#   '메뉴',
#   '부추',
#   '빵',
#   '튀김',
#   '소보',
#   '이야기',
#   '본점',
#   '사람',
#   '대전',
#   '역',
#   '성심당',
#   '메뉴',
#   '중',
#   '추천',
#   '것',
#   '어요',
#   '걸',
#   '보고',
#   '분',
#   '보시',
#   '사나',
#   '여행'],
#  ['런던',
#   '베이글',
#   '뮤지',
#   '엄',
#   '도산',
#   '주말',
#   '웨이',
#   '팅',
#   '후기',
#   '추천',
#   '메뉴',
#   '식사',
#   '대용',
#   '보이',
#   '베스트',
#   '메뉴',
#   '런던',
#   '베이글',
#   '뮤지',
#   '엄',
#   '추천',
#   '메뉴',
#   '시',
#   '그니',
#   '처',
#   '치즈',
#   '꿀',
#   '브릭레인',
#   '저',
#   '치즈',
#   '완전',
#   '추천',
#   '여행',
#   '일상',
#   '여행'],
#  ['안국',
#   '런던',
#   '베이글',
#   '뮤지',
#   '엄',
#   '평일',
#   '웨이',
#   '팅',
#   '포장',
#   '추천',
#   '메뉴',
#   '집',
#   '고고',
#   '참고',
#   '현대',
#   '계동',
#   '사옥',
#   '주',
#   '차비',
#   '천원',
#   '런던',
#   '베이글',
#   '뮤지',
#   '엄',
#   '추천',
#   '메뉴',
#   '향',
#   '얼그레이',
#   '향',
#   '진해',
#   '브릭레인',
#   '샌드위치',
#   '런던',
#   '베이글',
#   '뮤',
#   '지엄',
#   '시',
#   '그니',
#   '처',
#   '메뉴',
#   '문',
#   '나',
#   '서면',
#   '여행',
#   '시작'],
#  ['유후인',
#   '식당',
#   '코',
#   '하루',
#   '우동',
#   '웨이',
#   '팅',
#   '추천',
#   '메뉴',
#   '맛',
#   '유후인',
#   '여행',
#   '수',
#   '맛집',
#   '코',
#   '하루',
#   '우동',
#   '안녕',
#   '후쿠오카',
#   '여행',
#   '빠',
#   '지지',
#   '추천',
#   '대충',
#   '메뉴',
#   '뭐',
#   '보고',
#   '검색',
#   '추천',
#   '메뉴',
#   '기보',
#   '단',
#   '행복',
#   '아가',
#   '블로그'],
#  ['컴',
#   '포즈',
#   '커피',
#   '메뉴',
#   '추천',
#   '쿠키',
#   '밀크쉐이크',
#   '팥',
#   '절미',
#   '추천',
#   '포즈',
#   '커피',
#   '포즈',
#   '커피',
#   '메뉴',
#   '포즈',
#   '커피',
#   '추천',
#   '포즈',
#   '메뉴',
#   '포즈',
#   '커피',
#   '추천',
#   '메뉴',
#   '포즈',
#   '커피',
#   '메뉴',
#   '추천',
#   '포즈',
#   '쿠키',
#   '밀크쉐이크',
#   '오렌지',
#   '당근',
#   '주스',
#   '절미',
#   '절미',
#   '밀크쉐이크',
#   '푸드',
#   '반짝',
#   '반짝',
#   '작',
#   '은별'],
#  ['서울',
#   '딤섬',
#   '맛집',
#   '호우',
#   '섬',
#   '용산',
#   '아이파크몰',
#   '맛집',
#   '메뉴',
#   '추천',
#   '추천',
#   '메뉴',
#   '정보',
#   '여름',
#   '시즌',
#   '신',
#   '메뉴',
#   '대한',
#   '솔직',
#   '후',
#   '기입',
#   '호우',
#   '섬',
#   '용산',
#   '위치',
#   '용산',
#   '아이파크몰',
#   '맛집',
#   '호우',
#   '섬',
#   '메뉴',
#   '추천',
#   '주문',
#   '한참',
#   '고민',
#   '끝',
#   '우선',
#   '신',
#   '메뉴',
#   '종은',
#   '홍련화'],
#  ['리스',
#   '카페',
#   '판교',
#   '주차',
#   '웨이',
#   '팅',
#   '메뉴',
#   '추천',
#   '제뉴픽',
#   '이',
#   '번',
#   '메뉴',
#   '추천',
#   '대표',
#   '사진',
#   '쓸거얌',
#   '위',
#   '토핑',
#   '까지',
#   '아주',
#   '메뉴',
#   '직원',
#   '분',
#   '친절',
#   '공간',
#   '재',
#   '방문',
#   '거',
#   '혹시',
#   '다른',
#   '추천',
#   '메뉴'],
#  ['장안동',
#   '초밥',
#   '맛집',
#   '적정',
#   '온도',
#   '숙성',
#   '회',
#   '초밥',
#   '실장',
#   '추천',
#   '메뉴',
#   '먹기',
#   '실',
#   '장님',
#   '추',
#   '천하',
#   '메뉴',
#   '얼마나',
#   '초밥',
#   '나',
#   '오기',
#   '전',
#   '장국',
#   '물',
#   '장국',
#   '먼저',
#   '장안동',
#   '맛집',
#   '장안',
#   '돈스',
#   '시',
#   '장안동',
#   '초밥',
#   '집',
#   '맛집',
#   '가성',
#   '비',
#   '오',
#   '마카',
#   '세',
#   '장님',
#   '친절',
#   '실장',
#   '추천',
#   '메뉴',
#   '귤잉',
#   '이의',
#   '일상',
#   '프로젝트'],
#  ['오키나와',
#   '모토',
#   '부',
#   '점심',
#   '현지',
#   '추천',
#   '메뉴',
#   '카운터',
#   '메뉴판',
#   '나',
#   '간',
#   '일본인',
#   '친',
#   '구들',
#   '메뉴',
#   '추천',
#   '주문',
#   '오키나와',
#   '모토',
#   '부',
#   '점심',
#   '현지',
#   '추천',
#   '메뉴',
#   '인도네시아',
#   '레스토랑',
#   '커리',
#   '모습',
#   '위',
#   '인포',
#   '알리',
#   '뷰티',
#   '정보'],
#  ['안주',
#   '직화',
#   '불',
#   '막창',
#   '안주',
#   '직화',
#   '무뼈',
#   '닭발',
#   '간단',
#   '술안주',
#   '추천',
#   '메뉴',
#   '청정',
#   '원',
#   '안주',
#   '직화',
#   '불',
#   '막창',
#   '안주',
#   '직화',
#   '무뼈',
#   '닭발',
#   '간단',
#   '술안주',
#   '추천',
#   '메뉴',
#   '청정',
#   '원',
#   '청정',
#   '원',
#   '라이프',
#   '푸드',
#   '디터',
#   '편의점',
#   '닭발',
#   '편의점',
#   '막창',
#   '간편',
#   '야식',
#   '야식',
#   '추천',
#   '메뉴',
#   '주야',
#   '직화',
#   '불',
#   '막창',
#   '주야',
#   '직화',
#   '무뼈',
#   '닭발',
#   '달콤',
#   '콤',
#   '행복',
#   '나',
#   '하루'],
#  ['모임',
#   '메뉴',
#   '장소',
#   '추천',
#   '강남',
#   '타워',
#   '점',
#   '메뉴',
#   '설명',
#   '추천',
#   '메뉴',
#   '가라아게',
#   '개',
#   '인적',
#   '추천',
#   '품',
#   '안주',
#   '메뉴',
#   '야마',
#   '강남',
#   '타워',
#   '점',
#   '가라아게',
#   '야마',
#   '후쿠오카',
#   '하카타',
#   '지역',
#   '모티브',
#   '가지',
#   '자산',
#   '내세',
#   '외식',
#   '브랜드',
#   '첫',
#   '번',
#   '도',
#   '모츠',
#   '나베',
#   '병셤',
#   '하우스'],
#  ['청주',
#   '동남',
#   '지구',
#   '맛집',
#   '키',
#   '이로',
#   '추천',
#   '메뉴',
#   '동남',
#   '지구',
#   '맛집',
#   '키',
#   '이로',
#   '추천',
#   '메뉴',
#   '거',
#   '다시',
#   '방',
#   '문하',
#   '또',
#   '다시',
#   '주문',
#   '거',
#   '아래',
#   '영상',
#   '보시',
#   '사이드',
#   '메뉴',
#   '계란',
#   '샐러드',
#   '요것',
#   '추천',
#   '요',
#   '또',
#   '하나',
#   '것',
#   '사케',
#   '잔',
#   '직접',
#   '수',
#   '어요',
#   '요게',
#   '콩',
#   '블로거'],
#  ['소',
#   '노벨',
#   '비발디',
#   '파크',
#   '푸드코트',
#   '추천',
#   '메뉴',
#   '강남',
#   '교자',
#   '교자',
#   '만두',
#   '떡갈비',
#   '초초강추',
#   '비발디',
#   '파크',
#   '푸드코트',
#   '추천',
#   '메뉴',
#   '강남',
#   '교자',
#   '떡갈비',
#   '홍천',
#   '비발디',
#   '파크',
#   '푸드코트',
#   '파크',
#   '푸드코트',
#   '푸드코트',
#   '맛집',
#   '비발디',
#   '파크',
#   '맛집',
#   '비발디',
#   '파크',
#   '추천',
#   '추천',
#   '메뉴',
#   '강남',
#   '교자',
#   '떡갈비',
#   '떡갈비',
#   '강남',
#   '교자',
#   '두',
#   '비만',
#   '소년',
#   '밥'],
#  ['메',
#   '커피',
#   '빽',
#   '다방',
#   '디저트',
#   '컴',
#   '포즈',
#   '메뉴',
#   '추천',
#   '가격',
#   '비교',
#   '오늘',
#   '진짜',
#   '가지',
#   '브랜드',
#   '한번',
#   '비교',
#   '최애',
#   '메뉴',
#   '추천',
#   '느낌',
#   '솔',
#   '직하',
#   '후기',
#   '요즘',
#   '쇼츠',
#   '알바생',
#   '추천',
#   '메뉴',
#   '다양',
#   '입소',
#   '타',
#   '것',
#   '저',
#   '직접',
#   '어요',
#   '이슈',
#   '붐',
#   '패션',
#   '뷰티',
#   '그'],
#  ['체크',
#   '스타벅스',
#   '추천',
#   '메뉴',
#   '트렌타',
#   '텀블러',
#   '말차',
#   '저',
#   '녹차',
#   '아하',
#   '가능',
#   '점',
#   '스타벅스',
#   '추천',
#   '메뉴',
#   '스타벅스',
#   '추천',
#   '레시피',
#   '스타벅스',
#   '녹차',
#   '프라푸치노',
#   '스타벅스',
#   '말차',
#   '프라푸치노',
#   '레시피',
#   '위',
#   '영수증',
#   '보시',
#   '아시',
#   '주문',
#   '메뉴',
#   '스타벅스',
#   '말차',
#   '외계',
#   '공간'],
#  ['명랑',
#   '핫도그',
#   '추천',
#   '메뉴',
#   '명랑',
#   '감자',
#   '핫도그',
#   '안녕',
#   '오늘',
#   '자매',
#   '명랑',
#   '핫도그',
#   '메뉴',
#   '소개',
#   '드릴',
#   '요',
#   '딸',
#   '래미',
#   '여름',
#   '성경학',
#   '교',
#   '온',
#   '리뷰',
#   '명랑',
#   '핫도그',
#   '아차산역',
#   '맛집',
#   '명랑',
#   '핫도그',
#   '추천',
#   '메뉴',
#   '명랑',
#   '감자',
#   '핫도그'],
#  ['총',
#   '고기',
#   '덮밥',
#   '인천',
#   '간석동',
#   '생활의달인',
#   '맛집',
#   '추천',
#   '메뉴',
#   '표적',
#   '메뉴',
#   '사실',
#   '삼선',
#   '고추',
#   '짬뽕',
#   '양장피',
#   '이번',
#   '생활',
#   '달인',
#   '소개',
#   '것',
#   '총',
#   '표적',
#   '메뉴',
#   '육',
#   '덮밥',
#   '다양',
#   '한요',
#   '리',
#   '메뉴',
#   '기도',
#   '육',
#   '덮밥',
#   '일',
#   '반적',
#   '제육',
#   '맛',
#   '뷰',
#   '스타',
#   '카민',
#   '뷰티',
#   '패션',
#   '일상'],
#  ['하와이',
#   '맛집',
#   '치즈',
#   '케익',
#   '팩토리',
#   '메뉴',
#   '추천',
#   '치즈',
#   '케익',
#   '팩토리',
#   '추천',
#   '메뉴',
#   '하와이',
#   '안',
#   '칵테일',
#   '알콜',
#   '강하',
#   '달콤',
#   '프라이드',
#   '칼라',
#   '마리',
#   '질',
#   '기지',
#   '하와이',
#   '신혼여행',
#   '맛집',
#   '하와이',
#   '와이키키',
#   '맛집',
#   '치즈',
#   '케익',
#   '팩토리',
#   '메뉴',
#   '추천',
#   '여행사',
#   '신혼여행',
#   '썸머',
#   '링',
#   '리빙',
#   '노트'],
#  ['레시피',
#   '양념',
#   '만들기',
#   '가지',
#   '요리',
#   '오징어',
#   '요리',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '추천',
#   '오징어볶음',
#   '레시피',
#   '양념',
#   '만들기',
#   '가지',
#   '요리',
#   '오징어',
#   '요리',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '추천',
#   '리즈',
#   '마켓',
#   '하루',
#   '날',
#   '마트',
#   '가기',
#   '냉동고',
#   '냉동',
#   '오징어',
#   '후다닥',
#   '보통',
#   '오징어볶음',
#   '가지',
#   '양배추',
#   '듬뿍',
#   '리즈',
#   '쿡',
#   '한식',
#   '제철',
#   '밥상'],
#  ['씨유',
#   '편의점',
#   '추천',
#   '메뉴',
#   '자이언트',
#   '인삼',
#   '닭백숙',
#   '여름',
#   '기전',
#   '생각',
#   '의외',
#   '사람',
#   '어보',
#   '난리',
#   '메뉴',
#   '고',
#   '자이언트',
#   '평',
#   '진짜',
#   '밥',
#   '대충',
#   '거',
#   '건강',
#   '상태',
#   '때',
#   '추천',
#   '인',
#   '이서',
#   '배부',
#   '르',
#   '솔',
#   '블로그'],
#  ['서브웨이',
#   '데리야끼',
#   '치킨',
#   '다이어트',
#   '추천',
#   '메뉴',
#   '주문',
#   '방법',
#   '신월',
#   '성',
#   '어요',
#   '메뉴',
#   '골',
#   '라서',
#   '주',
#   '문하',
#   '방법',
#   '추천',
#   '메뉴',
#   '추천',
#   '소스',
#   '드릴',
#   '요',
#   '월성',
#   '점',
#   '월성',
#   '네거리',
#   '방향',
#   '조금',
#   '오시',
#   '층',
#   '초록색',
#   '간판',
#   '보',
#   '여요',
#   '어가',
#   '자리',
#   '차근차근',
#   '엄마',
#   '일기장'],
#  ['돈내',
#   '입맛',
#   '때',
#   '추천',
#   '메뉴',
#   '서울대',
#   '입구',
#   '역',
#   '샤',
#   '길',
#   '태국',
#   '음식점',
#   '꼭',
#   '음료',
#   '다음',
#   '주문',
#   '아무',
#   '날씨',
#   '상콤',
#   '먹기',
#   '팟타이',
#   '똠얌',
#   '쌀국수',
#   '입맛',
#   '날',
#   '메뉴',
#   '로',
#   '추천',
#   '무진',
#   '의',
#   '공유',
#   '일기장'],
#  ['보쌈',
#   '동네',
#   '사랑방',
#   '밀우',
#   '추천',
#   '메뉴',
#   '가격',
#   '위치',
#   '아기',
#   '의자',
#   '남편',
#   '밀우',
#   '칼국수',
#   '한번',
#   '생각',
#   '각종',
#   '지류',
#   '상품권',
#   '사용',
#   '가능',
#   '요',
#   '모든',
#   '메뉴',
#   '포장',
#   '가능',
#   '칼국수',
#   '비조',
# ...
#   '서면',
#   '홍콩',
#   '음식',
#   '서면',
#   '탄탄면',
#   '서면',
#   '우육',
#   '굿모닝',
#   '홍콩',
#   '주차',
#   '굿모닝',
#   '홍콩',
#   '웨이',
#   '팅',
#   '굿모닝',
#   '홍콩',
#   '메뉴',
#   '추천',
#   '행복',
#   '저장',
#   '소'],
#  ['용산',
#   '삼각지',
#   '와인',
#   '바',
#   '심',
#   '퍼티',
#   '쿠시',
#   '예약',
#   '메뉴',
#   '추천',
#   '뇨끼',
#   '아하',
#   '시',
#   '분',
#   '라면',
#   '보시',
#   '길',
#   '친',
#   '구들',
#   '운',
#   '관자',
#   '디너',
#   '메뉴',
#   '관자',
#   '미니',
#   '양배추',
#   '국화',
#   '뵈르',
#   '블',
#   '새우',
#   '오일',
#   '펜넬',
#   '잎',
#   '주문',
#   '메뉴',
#   '중',
#   '하나',
#   '추천',
#   '하자',
#   '무조건',
#   '맛',
#   '멋'],
#  ['삼정',
#   '밥집',
#   '서면',
#   '밥집',
#   '서면',
#   '삼정',
#   '타워',
#   '한식',
#   '추천',
#   '솥밥',
#   '메뉴',
#   '솥',
#   '삼정',
#   '밥집',
#   '서면',
#   '밥집',
#   '서면',
#   '삼정',
#   '타워',
#   '한식',
#   '추천',
#   '솥밥',
#   '메뉴',
#   '솥',
#   '서면',
#   '점',
#   '이거슨',
#   '달',
#   '쯤',
#   '리뷰',
#   '곳',
#   '이나',
#   '새',
#   '음식점',
#   '등등',
#   '사진',
#   '두기',
#   '해',
#   '업로드',
#   '미정',
#   '컨텐츠',
#   '윤플',
#   '웨딩',
#   '품격'],
#  ['법',
#   '탕',
#   '생선',
#   '매운탕',
#   '법',
#   '재료',
#   '저녁',
#   '메뉴',
#   '추천',
#   '저녁',
#   '메뉴',
#   '추천',
#   '면서',
#   '간단',
#   '광어',
#   '매운탕',
#   '법',
#   '소개',
#   '생선',
#   '매운탕',
#   '재료',
#   '광어',
#   '팩',
#   '매운탕',
#   '양념',
#   '포함',
#   '무',
#   '된장',
#   '술',
#   '양파',
#   '개',
#   '대파',
#   '청양고추',
#   '개',
#   '홍',
#   '고추',
#   '개',
#   '배',
#   '화의',
#   '집밥'],
#  ['서브웨이',
#   '꿀',
#   '조합',
#   '메뉴',
#   '추천',
#   '총',
#   '정리',
#   '요즘',
#   '써브웨이',
#   '메뉴',
#   '추천',
#   '꿀',
#   '조합',
#   '인기',
#   '서브웨이',
#   '꿀',
#   '조합',
#   '게',
#   '써브웨이',
#   '써브웨이',
#   '추천',
#   '메뉴',
#   '뭐',
#   '서브웨이',
#   '꿀',
#   '조합',
#   '알',
#   '아보',
#   '도록',
#   '로스트비프',
#   '디종',
#   '문화',
#   '텍스트'],
#  ['광양',
#   '맛집',
#   '광양',
#   '브런치',
#   '카페',
#   '브런치',
#   '빈',
#   '메뉴',
#   '메뉴',
#   '추천',
#   '주문',
#   '방법',
#   '진동',
#   '벨',
#   '식사',
#   '식사',
#   '후',
#   '카운터',
#   '반납',
#   '추천',
#   '메뉴',
#   '제',
#   '결과',
#   '추천',
#   '파스타',
#   '메뉴',
#   '해',
#   '드릴',
#   '요',
#   '쉬',
#   '림프',
#   '알리오',
#   '리오',
#   '스파이',
#   '쉬',
#   '쉬',
#   '림프',
#   '파스타',
#   '김치볶음밥',
#   '클래식',
#   '플래터',
#   '콥',
#   '샐러드',
#   '전라도',
#   '여행자'],
#  ['김밥',
#   '뚠뚠',
#   '뚠뚠',
#   '김밥',
#   '분당',
#   '점',
#   '위치',
#   '추천',
#   '메뉴',
#   '정기',
#   '휴무',
#   '전화',
#   '주문',
#   '배민',
#   '포장',
#   '주문',
#   '가능',
#   '답니',
#   '김밥',
#   '메뉴',
#   '김밥',
#   '추천',
#   '메뉴',
#   '김밥',
#   '가격',
#   '수내역',
#   '맛집',
#   '김밥',
#   '김밥',
#   '맛집',
#   '묵은지',
#   '김밥',
#   '밥물',
#   '쫄면',
#   '쫄면',
#   '분당',
#   '내',
#   '맛집',
#   '수내동',
#   '맛집',
#   '복',
#   '편살',
#   '단디',
#   '맘'],
#  ['괌',
#   '햄버거',
#   '맛집',
#   '도스',
#   '버거',
#   '추천',
#   '메뉴',
#   '할인',
#   '방법',
#   '새우',
#   '패티',
#   '걸',
#   '쉬',
#   '림프',
#   '버거',
#   '추천',
#   '도스',
#   '버거',
#   '햄버거',
#   '감자튀김',
#   '괌',
#   '도스',
#   '버거',
#   '메뉴',
#   '도스',
#   '버거',
#   '추천',
#   '메뉴',
#   '도스',
#   '버거',
#   '대표',
#   '메뉴',
#   '괌도',
#   '스',
#   '버거',
#   '주차장',
#   '도스',
#   '버거',
#   '호점'],
#  ['맛집',
#   '피쉬',
#   '맨',
#   '강추',
#   '이나연',
#   '커플',
#   '추천',
#   '맛집',
#   '추천',
#   '메뉴',
#   '공유',
#   '최종',
#   '정리',
#   '추천',
#   '메뉴',
#   '계단',
#   '사시미',
#   '필수',
#   '양',
#   '케이크',
#   '모양',
#   '감자',
#   '고기',
#   '메뉴',
#   '강추',
#   '진짜',
#   '푸딩',
#   '생각',
#   '흑설탕',
#   '맛',
#   '강',
#   '조금',
#   '아쉬움',
#   '전',
#   '체적',
#   '헤롱',
#   '이의',
#   '여행',
#   '나눔'],
#  ['지지',
#   '가격',
#   '메뉴',
#   '추천',
#   '대구',
#   '동천동',
#   '맛집',
#   '성비',
#   '굿',
#   '먹기',
#   '추천',
#   '토핑',
#   '분모',
#   '자',
#   '콘치',
#   '모든',
#   '메뉴',
#   '기',
#   '본적',
#   '매콤',
#   '때문',
#   '기본',
#   '주문',
#   '해도',
#   '매콤',
#   '맛',
#   '아하',
#   '우리',
#   '중간',
#   '맛',
#   '선택',
#   '그',
#   '외',
#   '메뉴',
#   '사진',
#   '적당',
#   '리듬'],
#  ['안국',
#   '런던',
#   '베이글',
#   '뮤지',
#   '엄',
#   '메뉴',
#   '추천',
#   '및',
#   '주말',
#   '웨이',
#   '팅',
#   '후기',
#   '안국',
#   '런던',
#   '베이글',
#   '뮤지',
#   '엄',
#   '메뉴',
#   '추천',
#   '및',
#   '주말',
#   '웨이',
#   '팅',
#   '후기',
#   '안녕',
#   '안국',
#   '런던',
#   '베이글',
#   '뮤지',
#   '엄',
#   '후기',
#   '추천',
#   '메뉴',
#   '걸',
#   '최대한',
#   '어요',
#   '런던',
#   '베이글',
#   '크림',
#   '치즈',
#   '종류',
#   '꽤',
#   '다양'],
#  ['도미노피자',
#   '추천',
#   '메뉴',
#   '베이컨',
#   '체다',
#   '치즈',
#   '제일',
#   '맛',
#   '날로',
#   '주의',
#   '꺄항',
#   '짐',
#   '디너',
#   '어른',
#   '맥주',
#   '애',
#   '콜라',
#   '만족',
#   '식사',
#   '도미노피자',
#   '배달',
#   '돈',
#   '산',
#   '리뷰',
#   '도미노피자',
#   '메뉴',
#   '추천',
#   '베이컨',
#   '체다',
#   '치즈',
#   '피자',
#   '도미노피자',
#   '추천',
#   '피자',
#   '맛집'],
#  ['차이나타운',
#   '맛집',
#   '해산물',
#   '게',
#   '추천',
#   '메뉴',
#   '방콕',
#   '차이나타운',
#   '맛집',
#   '해산물',
#   '가득',
#   '파이',
#   '별',
#   '개',
#   '모험심',
#   '강하',
#   '신',
#   '한국인',
#   '분',
#   '추천',
#   '메뉴',
#   '다른',
#   '메뉴',
#   '어보',
#   '길',
#   '추천',
#   '드',
#   '린다',
#   '방콕',
#   '차이나타운',
#   '방콕',
#   '차이나타운',
#   '맛집',
#   '니니',
#   '여행',
#   '이야기'],
#  ['춘천',
#   '점심',
#   '메뉴',
#   '추천',
#   '카츠',
#   '탄탄',
#   '파스타',
#   '돈까스',
#   '춘천',
#   '점심',
#   '메뉴',
#   '추천',
#   '카츠',
#   '탄탄',
#   '파스타',
#   '돈까스',
#   '오늘',
#   '점심',
#   '방학',
#   '중인',
#   '첫째',
#   '카츠',
#   '탄탄',
#   '어요',
#   '갑자기',
#   '파스타',
#   '멀리',
#   '못',
#   '집',
#   '주변',
#   '카츠',
#   '탄탄',
#   '윰슐랭',
#   '가이드'],
#  ['치킨',
#   '추천',
#   '메뉴',
#   '골드',
#   '킹',
#   '맛초킹',
#   '사이드',
#   '메뉴',
#   '뿌링소떡',
#   '프랜차이즈',
#   '메뉴',
#   '추천',
#   '항상',
#   '먼저',
#   '언급',
#   '치킨',
#   '맛초킹',
#   '강력',
#   '추천',
#   '지금',
#   '까지',
#   '치킨',
#   '프랜차이즈',
#   '위',
#   '골드',
#   '킹',
#   '맛초킹',
#   '치킨',
#   '외',
#   '사이드',
#   '메뉴',
#   '돈',
#   '산',
#   '솔직',
#   '후기',
#   '감사'],
#  ['이색',
#   '적',
#   '우동',
#   '맛집',
#   '요미',
#   '돈',
#   '교자',
#   '연남',
#   '점',
#   '추천',
#   '메뉴',
#   '이색',
#   '적',
#   '우동',
#   '맛집',
#   '요미',
#   '돈교',
#   '자',
#   '연남',
#   '점',
#   '추천',
#   '메뉴',
#   '요미',
#   '돈교',
#   '자',
#   '연남',
#   '점',
#   '주소',
#   '서울',
#   '마포구',
#   '교',
#   '요기',
#   '대표',
#   '메뉴',
#   '적',
#   '우동',
#   '요',
#   '간판',
#   '교자',
#   '어가',
#   '교자',
#   '드',
#   '시더',
#   '주문',
#   '중국어',
#   '손쌤',
#   '블로그'],
#  ['신용산',
#   '맛집',
#   '아모레퍼시픽',
#   '근처',
#   '화양연화',
#   '추천',
#   '메뉴',
#   '공유',
#   '추천',
#   '메뉴',
#   '도',
#   '귀띔',
#   '드릴',
#   '요',
#   '저희',
#   '이태원',
#   '쪽',
#   '데이트',
#   '다가',
#   '산책',
#   '도',
#   '겸',
#   '이',
#   '메뉴',
#   '역시',
#   '양념',
#   '상태',
#   '모습',
#   '더',
#   '먹음',
#   '직스',
#   '러워',
#   '고',
#   '진짜',
#   '강력',
#   '추천',
#   '솔직',
#   '여자',
#   '미쁘미',
#   '맛집',
#   '여행'],
#  ['대만',
#   '위스키',
#   '카발',
#   '란',
#   '바',
#   '추천',
#   '메뉴',
#   '예약',
#   '방법',
#   '카발',
#   '란',
#   '바',
#   '예약',
#   '방법',
#   '저',
#   '예약',
#   '방문',
#   '워낙',
#   '인기',
#   '곳',
#   '예약',
#   '방문',
#   '추천',
#   '추천',
#   '메뉴',
#   '위스키',
#   '종',
#   '세트',
#   '오크',
#   '통',
#   '위스키',
#   '샘플러',
#   '트래블',
#   '리콘',
#   '지니'],
#  ['순천',
#   '분식',
#   '명인',
#   '만두',
#   '새벽',
#   '영업',
#   '종류',
#   '다양',
#   '밥집',
#   '추천',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '추천',
#   '해',
#   '드릴',
#   '요',
#   '갈비',
#   '만두',
#   '명인',
#   '만두',
#   '만두',
#   '만두',
#   '갈비',
#   '만두',
#   '만두',
#   '주문',
#   '어요',
#   '먹기',
#   '사이즈',
#   '만두',
#   '개',
#   '갈비',
#   '만두',
#   '스누미',
#   '일기장'],
#  ['문정동',
#   '카페',
#   '치',
#   '커피',
#   '이',
#   '컴퍼니',
#   '메뉴',
#   '추천',
#   '문정동',
#   '카페',
#   '치',
#   '커피',
#   '이',
#   '컴퍼니',
#   '메뉴',
#   '추천',
#   '집',
#   '근처',
#   '문정동',
#   '카페',
#   '치',
#   '커피',
#   '이',
#   '컴퍼니',
#   '시절',
#   '자주',
#   '치',
#   '리뉴얼',
#   '한번',
#   '외부',
#   '부터'],
#  ['꼬',
#   '리치',
#   '남자',
#   '돼지',
#   '꼬리',
#   '족발',
#   '야식',
#   '메뉴',
#   '추천',
#   '간단',
#   '한안',
#   '주',
#   '때',
#   '혼',
#   '술안주',
#   '추천',
#   '돼지',
#   '꼬리',
#   '족발',
#   '돼지',
#   '꼬리',
#   '껍데기',
#   '지방',
#   '살코기',
#   '쟁여놓',
#   '생각',
#   '날',
#   '때',
#   '마다',
#   '간단',
#   '혼',
#   '술안주',
#   '야식',
#   '메뉴',
#   '캠핑',
#   '요리',
#   '강추',
#   '저',
#   '건강',
#   '리뷰',
#   '뚜',
#   '돼지',
#   '런',
#   '로그'],
#  ['롯데리아',
#   '메뉴',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '돈',
#   '산',
#   '추천',
#   '후기',
#   '롯데리아',
#   '메뉴',
#   '추천',
#   '새우',
#   '익스트림',
#   '레몬',
#   '크림',
#   '돈',
#   '산',
#   '추천',
#   '새우',
#   '버거',
#   '생각',
#   '롯데리아',
#   '새우',
#   '어간',
#   '신',
#   '메뉴',
#   '고요',
#   '새우',
#   '버거',
#   '아하',
#   '분',
#   '라면',
#   '귀가',
#   '팔랑',
#   '팔랑',
#   '롯데리아',
#   '낭',
#   '주부',
#   '이야기'],
#  ['스타벅스',
#   '신',
#   '메뉴',
#   '시원',
#   '위드',
#   '콜드',
#   '브루',
#   '당',
#   '충전',
#   '추천',
#   '메뉴',
#   '스타벅스',
#   '신',
#   '메뉴',
#   '바닐라',
#   '빈',
#   '푸딩',
#   '블렌디드',
#   '위드',
#   '콜드',
#   '브루',
#   '스타벅스',
#   '푸딩',
#   '블렌디드',
#   '푸딩',
#   '블렌디드',
#   '스타벅스',
#   '쉐이크',
#   '스타벅스',
#   '추천',
#   '메뉴',
#   '스타벅스',
#   '메뉴',
#   '추천',
#   '스타벅스',
#   '콜드',
#   '브루',
#   '추천',
#   '스타벅스',
#   '여름',
#   '신',
#   '메뉴',
#   '일상',
#   '이야기',
#   '중'],
#  ['울산',
#   '언양',
#   '불고기',
#   '맛집',
#   '주차',
#   '웨이',
#   '팅',
#   '추천',
#   '메뉴',
#   '메뉴',
#   '소개',
#   '추천',
#   '메뉴',
#   '언양',
#   '불고기',
#   '돌솥',
#   '정식',
#   '여기',
#   '고기',
#   '진심',
#   '바로',
#   '입구',
#   '정육',
#   '공간',
#   '고요',
#   '거기',
#   '옆',
#   '테이블',
#   '생',
#   '고기',
#   '메뉴',
#   '마블링',
#   '정말',
#   '예술',
#   '어요',
#   '저',
#   '뇸뇸',
#   '박사'],
#  ['코엑스',
#   '맛집',
#   '데블',
#   '스',
#   '도어',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '중',
#   '내',
#   '픽',
#   '데블',
#   '스',
#   '도어',
#   '추천',
#   '메뉴',
#   '세',
#   '가지',
#   '멕시칸',
#   '시저',
#   '샐러드',
#   '입맛',
#   '샐러드',
#   '페퍼로니',
#   '크림',
#   '피자',
#   '맥주',
#   '안주',
#   '매우',
#   '굿',
#   '프라이드',
#   '라마',
#   '리',
#   '맥주',
#   '안주',
#   '매우',
#   '굿굿',
#   '실패',
#   '먹기',
#   '일상',
#   '탐험',
#   '쓔',
#   '로그'],
#  ['교촌치킨',
#   '추천',
#   '메뉴',
#   '대체',
#   '불가',
#   '교촌',
#   '오리',
#   '날',
#   '맛',
#   '치즈볼',
#   '교촌치킨',
#   '추천',
#   '메뉴',
#   '역시',
#   '인생',
#   '치킨',
#   '교촌',
#   '오리',
#   '날',
#   '맛',
#   '음식',
#   '즐거움',
#   '그',
#   '무엇',
#   '과도',
#   '한국인',
#   '가장',
#   '사랑',
#   '메뉴',
#   '이자',
#   '맥주',
#   '단짝',
#   '치킨',
#   '아하',
#   '시',
#   '가족',
#   '모두',
#   '아해',
#   '일주일',
#   '희재',
#   '맘',
#   '희재',
#   '꼬',
#   '추억'],
#  ['치킨',
#   '추천',
#   '땅땅',
#   '불',
#   '갈비',
#   '후왕',
#   '세트',
#   '메뉴',
#   '땅땅치킨',
#   '선부점',
#   '사실',
#   '야외',
#   '치킨',
#   '추천',
#   '메뉴',
#   '로',
#   '등',
#   '극시',
#   '킬',
#   '수',
#   '실내',
#   '분위기',
#   '파스텔',
#   '동화',
#   '땅땅',
#   '불',
#   '갈비',
#   '치킨',
#   '다음',
#   '메뉴',
#   '추천',
#   '뭐',
#   '치밥',
#   '냉장고',
#   '찬밥',
#   '공기',
#   '땅땅',
#   '제이원',
#   '제이'],
#  ['양재',
#   '카페',
#   '투썸플레이스',
#   '추천',
#   '메뉴',
#   '오늘',
#   '투썸플레이스',
#   '식사',
#   '대용',
#   '추천',
#   '메뉴',
#   '를',
#   '소개',
#   '투썸플레이스',
#   '포이',
#   '점',
#   '양재천',
#   '뷰',
#   '주차',
#   '까지',
#   '가능',
#   '요',
#   '주차장',
#   '이용',
#   '안내',
#   '투썸플레이스',
#   '영수증',
#   '장',
#   '서울',
#   '언니'],
#  ['레시피',
#   '요리',
#   '맛',
#   '보장',
#   '고추장',
#   '제육볶음',
#   '양념장',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '추천',
#   '바로',
#   '수',
#   '때',
#   '까지',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '추천',
#   '고추장',
#   '제육볶음',
#   '사실',
#   '진짜',
#   '때',
#   '대패',
#   '삼겹살',
#   '쌈',
#   '즐',
#   '기면',
#   '끼',
#   '수',
#   '기름',
#   '충분',
#   '축복',
#   '유전자',
#   '완소',
#   '남매',
#   '엄마',
#   '표',
#   '먹거리'],
#  ['안산',
#   '사동',
#   '사리역',
#   '근처',
#   '족발',
#   '맛집',
#   '사리역',
#   '배달',
#   '추천',
#   '메뉴',
#   '메뉴',
#   '족발',
#   '보쌈',
#   '주',
#   '메뉴',
#   '고',
#   '술',
#   '한잔',
#   '면서',
#   '수',
#   '사이드',
#   '메뉴',
#   '준비',
#   '추천',
#   '드립',
#   '오늘',
#   '완미',
#   '족발',
#   '족발',
#   '족발',
#   '집중',
#   '편이',
#   '근처',
#   '피',
#   '브이'],
#  ['냉',
#   '우동',
#   '소스',
#   '육수',
#   '레시피',
#   '냉',
#   '우동',
#   '만들기',
#   '주말',
#   '점심',
#   '메뉴',
#   '추천',
#   '주말',
#   '점심',
#   '메뉴',
#   '추천',
#   '여름',
#   '시원',
#   '우동',
#   '레시피',
#   '장마',
#   '더니',
#   '요즘',
#   '정말',
#   '고요',
#   '간단',
#   '점심',
#   '메뉴',
#   '고',
#   '민하',
#   '다가',
#   '얼음',
#   '동동',
#   '우동',
#   '만들기',
#   '냉동',
#   '돈까스',
#   '에어',
#   '프라이어',
#   '버전',
#   '의후다닥',
#   '레시피'],
#  ['어니언',
#   '버섯',
#   '스프',
#   '만들기',
#   '아침식사',
#   '메뉴',
#   '로',
#   '추천',
#   '레시피',
#   '아침식사',
#   '메뉴',
#   '아침식사',
#   '추천',
#   '메뉴',
#   '저희',
#   '집',
#   '초등학생',
#   '둘',
#   '어요',
#   '어른',
#   '아이',
#   '아침',
#   '더',
#   '입맛',
#   '때',
#   '빵',
#   '조각',
#   '어니언',
#   '버섯',
#   '스프',
#   '그릇',
#   '이면',
#   '호로',
#   '록',
#   '기분',
#   '아침',
#   '행복',
#   '날로',
#   '캐리',
#   '정',
#   '블로그'],
#  ['부산',
#   '영도',
#   '점심',
#   '맛집',
#   '수제',
#   '버거',
#   '햄최몇',
#   '메뉴',
#   '추천',
#   '현지',
#   '추천',
#   '주차장',
#   '건물',
#   '층',
#   '가능',
#   '층',
#   '위치',
#   '어서',
#   '계단',
#   '이용',
#   '라가',
#   '수제',
#   '버거',
#   '맛집',
#   '햄최몇',
#   '메뉴',
#   '부산',
#   '영도',
#   '점심',
#   '맛집',
#   '한정',
#   '메뉴',
#   '부터',
#   '판매',
#   '위',
#   '사장',
#   '러블리썬',
#   '여행',
#   '날'],
#  ['쫄면',
#   '양념장',
#   '만들기',
#   '백종원',
#   '쫄면',
#   '양념',
#   '재료',
#   '점심',
#   '메뉴',
#   '추천',
#   '쫄면',
#   '쫄면',
#   '양념장',
#   '만들기',
#   '백종원',
#   '쫄면',
#   '양념',
#   '쫄면',
#   '재료',
#   '점심',
#   '메뉴',
#   '추천',
#   '쫄면',
#   '요리',
#   '여름',
#   '분식',
#   '리하',
#   '쫄면',
#   '학창시절',
#   '부터',
#   '콤',
#   '고추장',
#   '양념장',
#   '면서',
#   '쫄깃쫄깃',
#   '면발',
#   '야채',
#   '식감',
#   '아토피',
#   '집밥',
#   '휴식',
#   '여행',
#   '일기',
#   '사랑',
#   '김수미'],
#  ['광화문',
#   '포시즌스',
#   '호텔',
#   '마루',
#   '추천',
#   '메뉴',
#   '및',
#   '솔직',
#   '후기',
#   '포시즌스',
#   '호텔',
#   '메뉴',
#   '포시즌스',
#   '호텔',
#   '울',
#   '추천',
#   '메뉴',
#   '마루',
#   '식사',
#   '메뉴',
#   '준비',
#   '가격',
#   '포시즌스',
#   '마루',
#   '갈비',
#   '포시즌스',
#   '마루',
#   '샌드위치',
#   '포시즌스',
#   '마루',
#   '메뉴',
#   '추천',
#   '포시즌스',
#   '호텔',
#   '마루',
#   '메뉴'],
#  ['서울역',
#   '만리',
#   '브런치',
#   '양식',
#   '레스토랑',
#   '콤',
#   '바크',
#   '카페',
#   '메뉴',
#   '추천',
#   '가게',
#   '때',
#   '부터',
#   '뭔가',
#   '버터',
#   '오징어',
#   '냄새',
#   '그',
#   '영화관',
#   '버터',
#   '구이',
#   '냄새',
#   '파스타',
#   '면도',
#   '생각',
#   '오징어',
#   '거',
#   '꼭',
#   '추천',
#   '메뉴',
#   '재',
#   '방문',
#   '해도',
#   '재주',
#   '문',
#   '유지',
#   '어터',
#   '일상'],
#  ['베스킨라빈스',
#   '메뉴',
#   '추천',
#   '가격',
#   '영업',
#   '시간',
#   '케이크',
#   '베',
#   '메뉴',
#   '맛',
#   '종류',
#   '베스킨라빈스',
#   '메뉴',
#   '추천',
#   '베스킨라빈스',
#   '가격',
#   '베스킨라빈스',
#   '케이크',
#   '메뉴',
#   '종류',
#   '개',
#   '인적',
#   '베스킨라빈스',
#   '추천',
#   '메뉴',
#   '슈팅',
#   '스타',
#   '체리',
#   '쥬빌레',
#   '엄',
#   '마는',
#   '외계인',
#   '레인보우',
#   '샤베트',
#   '방랑',
#   '고',
#   '그날',
#   '기',
#   '다리'],
#  ['돈가츠',
#   '하남',
#   '미사',
#   '점',
#   '일식',
#   '돈가츠',
#   '추천',
#   '메뉴',
#   '정식',
#   '후기',
#   '돈가츠',
#   '바삭',
#   '바삭',
#   '냉',
#   '모밀',
#   '시원',
#   '여름',
#   '메뉴',
#   '간단',
#   '점심',
#   '이나',
#   '혼밥',
#   '기도',
#   '미사',
#   '역',
#   '맛집',
#   '돈',
#   '돈가츠',
#   '추천',
#   '열심',
#   '먹방',
#   '포스트',
#   '더',
#   '보',
#   '려면',
#   '아래',
#   '뚝딱',
#   '거리',
#   '한국',
#   '생활'],
#  ['에어',
#   '프라이어',
#   '돈가스',
#   '나베',
#   '요리',
#   '쯔유',
#   '활용',
#   '집밥',
#   '저녁',
#   '메뉴',
#   '추천',
#   '돈까스',
#   '김치',
#   '나베',
#   '레시피',
#   '김치',
#   '츠',
#   '나베',
#   '만들기',
#   '에어',
#   '프라이어',
#   '돈가스',
#   '나베',
#   '요리',
#   '쯔유',
#   '활용',
#   '집밥',
#   '저녁',
#   '메뉴',
#   '추천',
#   '안녕',
#   '푸드',
#   '인',
#   '플루',
#   '이',
#   '바삭',
#   '고소',
#   '맛',
#   '돈까스',
#   '아하',
#   '시',
#   '이의',
#   '홈쿡',
#   '레시피'],
#  ['인계동',
#   '맛집',
#   '점심',
#   '메뉴',
#   '추천',
#   '쭈꾸미',
#   '덮밥',
#   '인계동',
#   '맛집',
#   '점심',
#   '메뉴',
#   '추천',
#   '쭈꾸미',
#   '덮밥',
#   '테이블',
#   '메뉴',
#   '주문',
#   '결제',
#   '까지',
#   '가능',
#   '시스템',
#   '아직까지',
#   '시스템',
#   '적응',
#   '서인',
#   '어서',
#   '인지',
#   '때',
#   '또',
#   '결제',
#   '카운터',
#   '감',
#   '부동산'],
#  ['서브웨이',
#   '꿀',
#   '조합',
#   '마',
#   '추천',
#   '메뉴',
#   '오늘',
#   '간단',
#   '점심',
#   '서브웨이',
#   '꿀',
#   '조합',
#   '마',
#   '추천',
#   '메뉴',
#   '후기',
#   '보',
#   '려고',
#   '해',
#   '가장',
#   '기본',
#   '이왕이면',
#   '가지',
#   '채소',
#   '달달',
#   '채즙',
#   '버퍼',
#   '활용',
#   '마',
#   '꿀',
#   '조합',
#   '서브웨이',
#   '메뉴',
#   '추천',
#   '김원',
#   '장의',
#   '탐구생활'],
#  ['가산',
#   '테라',
#   '타워',
#   '본점',
#   '가산',
#   '맛집',
#   '혼밥',
#   '메뉴',
#   '토마토',
#   '스튜',
#   '찜닭',
#   '추천',
#   '추천',
#   '메뉴',
#   '토마토',
#   '스튜',
#   '찜닭',
#   '애',
#   '비',
#   '한바탕',
#   '아지',
#   '난',
#   '뒤',
#   '잠깐',
#   '안',
#   '틈',
#   '타',
#   '방문',
#   '메뉴',
#   '토마토',
#   '스튜',
#   '찜닭',
#   '애',
#   '살',
#   '나물',
#   '밥',
#   '건강',
#   '밥',
#   '돈까스',
#   '토핑',
#   '서비스',
#   '묵은지'],
#  ['디',
#   '메뉴',
#   '추천',
#   '칠리',
#   '베이컨',
#   '웜볼',
#   '바질',
#   '치킨',
#   '랩',
#   '디',
#   '메뉴',
#   '추천',
#   '칠리',
#   '베이컨',
#   '웜볼',
#   '바질',
#   '치킨',
#   '랩',
#   '안녕',
#   '오반',
#   '짝',
#   '개인',
#   '피티',
#   '동네',
#   '친구',
#   '톡',
#   '급',
#   '점심',
#   '어요',
#   '나름',
#   '다이어트',
#   '중이',
#   '어디',
#   '다가',
#   '디',
#   '어요',
#   '원래',
#   '오반',
#   '짝',
#   '반짝',
#   '반짝',
#   '일상'],
#  ['이삭',
#   '토스트',
#   '메뉴',
#   '추천',
#   '허니',
#   '갈릭',
#   '햄',
#   '치즈',
#   '소스',
#   '어요',
#   '이삭',
#   '토스트',
#   '메뉴',
#   '추천',
#   '주말',
#   '뭐',
#   '하루',
#   '끼',
#   '집밥',
#   '어서',
#   '먹기',
#   '잠깐',
#   '외출',
#   '다가',
#   '이삭',
#   '토스트',
#   '눈',
#   '보이',
#   '오늘',
#   '의아',
#   '침',
#   '거',
#   '어요',
#   '햄',
#   '치즈',
#   '야채',
#   '먀',
#   '돈',
#   '우수',
#   '형제'],
#  ['맛집',
#   '물회',
#   '보재',
#   '집',
#   '투어',
#   '방송',
#   '출연',
#   '추천',
#   '메뉴',
#   '저',
#   '추천',
#   '메뉴',
#   '보재',
#   '기',
#   '해물',
#   '물회',
#   '가격',
#   '원',
#   '차이',
#   '물회',
#   '해물',
#   '추가',
#   '해물',
#   '물회',
#   '더',
#   '짐',
#   '맛',
#   '요',
#   '거제',
#   '보재',
#   '집',
#   '메뉴',
#   '가격',
#   '정보',
#   '짐',
#   '상의',
#   '보재',
#   '기',
#   '해물',
#   '물회',
#   '네이버',
#   '여행',
#   '인',
#   '플루',
#   '일상',
#   '여행',
#   '처럼'],
#  ['오랜만',
#   '저희',
#   '부부',
#   '일상',
#   '집밥',
#   '점심',
#   '저녁',
#   '메뉴',
#   '추천',
#   '최근',
#   '일상',
#   '점심',
#   '저녁',
#   '메뉴',
#   '추천',
#   '포스팅',
#   '전부',
#   '마무리',
#   '정말',
#   '오랜만',
#   '저희',
#   '부부',
#   '일상',
#   '집밥',
#   '메뉴',
#   '후기',
#   '요',
#   '집',
#   '점심',
#   '저녁',
#   '메뉴',
#   '고민',
#   '때',
#   '번',
#   '추천',
#   '정사',
#   '장',
#   '부부',
#   '맛집',
#   '투어'],
#  ['직장인',
#   '수제',
#   '도시락',
#   '메뉴',
#   '추천',
#   '도시락',
#   '삼촌',
#   '점심',
#   '점심',
#   '메뉴',
#   '고민',
#   '이신',
#   '여러분',
#   '추천',
#   '수',
#   '도시락',
#   '삼촌',
#   '저렴',
#   '세트',
#   '구성',
#   '양하',
#   '수',
#   '점심시간',
#   '매일',
#   '즐',
#   '거울',
#   '수',
#   '어요',
#   '저',
#   '재주',
#   '문',
#   '의사',
#   '정도',
#   '세트',
#   '사서',
#   '냉동고',
#   '서울',
#   '소시민',
#   '햄찌',
#   '삶'],
#  ['스테이크',
#   '맛집',
#   '메뉴',
#   '추천',
#   '돈',
#   '산',
#   '솔직',
#   '후기',
#   '둘리',
#   '쉬',
#   '림프',
#   '파스타',
#   '치킨',
#   '비비큐',
#   '파스타',
#   '사이',
#   '고민',
#   '친절',
#   '직원',
#   '분',
#   '고',
#   '기류',
#   '신',
#   '메뉴',
#   '인',
#   '파스타',
#   '추천',
#   '해주시',
#   '센스',
#   '예비',
#   '인',
#   '플루'],
#  ['지점',
#   '비교',
#   '법',
#   '추천',
#   '메뉴',
#   '고',
#   '굿',
#   '가격',
#   '추천',
#   '메뉴',
#   '에스프레소',
#   '초콜렛',
#   '칩',
#   '쿠키',
#   '블루베리',
#   '머핀',
#   '랄프',
#   '스',
#   '에스프레소',
#   '티라미수',
#   '뺑오',
#   '쇼콜라',
#   '크로와상',
#   '무난',
#   '주변',
#   '것',
#   '은근',
#   '케이크',
#   '사람',
#   '것'],
#  ['치킨',
#   '마법',
#   '처럼',
#   '마법',
#   '야식',
#   '치킨',
#   '메뉴',
#   '추천',
#   '치킨',
#   '신',
#   '메뉴',
#   '마법',
#   '처럼',
#   '마법',
#   '야식',
#   '치킨',
#   '메뉴',
#   '추천',
#   '한국인',
#   '면',
#   '누구',
#   '아하',
#   '치킨',
#   '이웃',
#   '님들',
#   '치킨',
#   '아하',
#   '시나',
#   '치킨',
#   '종류',
#   '워낙',
#   '다양',
#   '재미',
#   '입맛',
#   '행주치마',
#   '정겨운',
#   '집밥'],
#  ['용인',
#   '이케아',
#   '기흥',
#   '점',
#   '맛집',
#   '레스토랑',
#   '식당',
#   '추천',
#   '메뉴',
#   '소프트',
#   '콘',
#   '후기',
#   '이케아',
#   '추천',
#   '메뉴',
#   '닭고기',
#   '스테이크',
#   '구',
#   '파스타',
#   '김치볶음밥',
#   '돈까스',
#   '불고기',
#   '볶음밥',
#   '연어',
#   '필레',
#   '미트볼',
#   '개',
#   '원도',
#   '메뉴',
#   '주문',
#   '가성',
#   '비',
#   '홈',
#   '바리스타',
#   '라미',
#   '방구',
#   '석',
#   '레시피']]

# %%
#본문 마다 단어와 갯수 구하기 

for i in range(0,len(an)) :
    count = Counter(an[i])
    
    an[i] = count.most_common()

# %%
an
# Out:
# [[('이치란', 3),
#   ('라멘', 3),
#   ('주문', 3),
#   ('방법', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('텐진', 2),
#   ('맛집', 2),
#   ('후쿠오카', 2),
#   ('웨이', 2),
#   ('팅', 2),
#   ('일본', 1),
#   ('스시', 1),
#   ('오', 1),
#   ('마카', 1),
#   ('세', 1),
#   ('끼니', 1),
#   ('후기', 1),
#   ('소개', 1),
#   ('고', 1),
#   ('까지', 1),
#   ('공유', 1),
#   ('시간', 1),
#   ('운', 1),
#   ('영하', 1),
#   ('본점', 1),
#   ('푸드', 1),
#   ('인', 1),
#   ('플루', 1),
#   ('율무', 1),
#   ('밍', 1),
#   ('일상', 1),
#   ('기록', 1)],
#  [('메뉴', 3),
#   ('베트남', 2),
#   ('주변', 2),
#   ('안', 2),
#   ('토이', 2),
#   ('추천', 2),
#   ('다낭', 1),
#   ('맛집', 1),
#   ('한시', 1),
#   ('장', 1),
#   ('벱꿰', 1),
#   ('나', 1),
#   ('가지볶음', 1),
#   ('토마토소스', 1),
#   ('두부', 1),
#   ('완자', 1),
#   ('조림', 1),
#   ('황금새', 1),
#   ('요리', 1),
#   ('한번', 1),
#   ('모든', 1),
#   ('맛', 1),
#   ('볼', 1),
#   ('수', 1),
#   ('무엇', 1),
#   ('인테리어', 1),
#   ('쾌적', 1),
#   ('환경', 1),
#   ('추', 1),
#   ('천하', 1),
#   ('잡', 1),
#   ('트래블', 1),
#   ('홀릭', 1)],
#  [('맛집', 3),
#   ('구로디지털단지역', 2),
#   ('메뉴', 2),
#   ('디', 2),
#   ('추천', 2),
#   ('매장', 2),
#   ('점', 1),
#   ('갈비', 1),
#   ('판이', 1),
#   ('크게', 1),
#   ('어서', 1),
#   ('어요', 1),
#   ('그', 1),
#   ('잡채', 1),
#   ('회식', 1),
#   ('공간', 1),
#   ('직장인', 1),
#   ('드립', 1),
#   ('술집', 1),
#   ('고기', 1),
#   ('집', 1)],
#  [('해운대', 4),
#   ('카페', 3),
#   ('정보', 3),
#   ('오설록', 2),
#   ('티', 2),
#   ('하우스', 2),
#   ('점', 2),
#   ('오픈', 2),
#   ('행사', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('소개', 2),
#   ('자세', 2),
#   ('여러분', 1),
#   ('신상', 1),
#   ('어서', 1),
#   ('인테리어', 1),
#   ('까지', 1),
#   ('보고', 1),
#   ('방문', 1),
#   ('전', 1),
#   ('참고', 1),
#   ('외관', 1)],
#  [('제', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('분모', 2),
#   ('자로', 2),
#   ('떡볶이', 2),
#   ('기준', 2),
#   ('돈', 1),
#   ('산', 1),
#   ('솔직', 1),
#   ('후기', 1),
#   ('는걸', 1),
#   ('거지', 1),
#   ('성비', 1),
#   ('정말', 1),
#   ('치킨', 1),
#   ('뿌', 1),
#   ('링클', 1),
#   ('커리', 1),
#   ('퀸', 1),
#   ('맛초킹', 1),
#   ('정도', 1),
#   ('것', 1),
#   ('민초', 1),
#   ('파의', 1),
#   ('박사', 1),
#   ('도전', 1),
#   ('기', 1)],
#  [('스테이크', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('페퍼', 2),
#   ('파타야', 1),
#   ('맛집', 1),
#   ('비프', 1),
#   ('터', 1),
#   ('하우스', 1),
#   ('예약', 1),
#   ('방법', 1),
#   ('및', 1),
#   ('직원', 1),
#   ('분', 1),
#   ('요청', 1),
#   ('요', 1),
#   ('를', 1),
#   ('해', 1),
#   ('크림', 1),
#   ('색', 1),
#   ('브랜디', 1),
#   ('맛', 1),
#   ('소스', 1),
#   ('위', 1),
#   ('야채', 1),
#   ('사이드', 1),
#   ('감자', 1),
#   ('오', 1),
#   ('그라탕', 1),
#   ('제공', 1),
#   ('이', 1),
#   ('스윗', 1),
#   ('포타토킴', 1),
#   ('다이어트', 1),
#   ('로드', 1),
#   ('이야기', 1)],
#  [('추천', 3),
#   ('메뉴', 2),
#   ('가격', 2),
#   ('바르셀로나', 1),
#   ('비니', 1),
#   ('투스', 1),
#   ('가격표', 1),
#   ('파산', 1),
#   ('잼', 1),
#   ('세르', 1),
#   ('베', 1),
#   ('세리', 1),
#   ('카탈', 1),
#   ('라나', 1),
#   ('체인', 1),
#   ('맛', 1),
#   ('분위기', 1),
#   ('메뉴판', 1),
#   ('부과', 1),
#   ('세', 1),
#   ('더니', 1),
#   ('지갑', 1),
#   ('여자', 1),
#   ('명', 1),
#   ('이서', 1),
#   ('배부', 1),
#   ('르', 1),
#   ('이', 1),
#   ('롤링', 1)],
#  [('제주', 3),
#   ('오일장', 3),
#   ('메뉴', 3),
#   ('향', 2),
#   ('추천', 2),
#   ('민속', 1),
#   ('오일', 1),
#   ('시장', 1),
#   ('것', 1),
#   ('걸', 1),
#   ('순대국', 1),
#   ('밥', 1),
#   ('비빔밥', 1),
#   ('꼼장어', 1),
#   ('순대', 1),
#   ('해', 1),
#   ('글', 1),
#   ('감사', 1),
#   ('모두', 1),
#   ('주연', 1),
#   ('블로그', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('진짜', 2),
#   ('리스', 1),
#   ('카페', 1),
#   ('정자', 1),
#   ('주차', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('브런치', 1),
#   ('맛집', 1),
#   ('기분', 1),
#   ('가게', 1),
#   ('앞', 1),
#   ('크게', 1),
#   ('인쇄', 1),
#   ('판이', 1),
#   ('어서', 1),
#   ('열심', 1),
#   ('보', 1),
#   ('면서', 1),
#   ('를', 1),
#   ('정', 1),
#   ('하나', 1),
#   ('부터', 1),
#   ('이용', 1),
#   ('드', 1),
#   ('린다', 1),
#   ('파라', 1),
#   ('곤', 1),
#   ('지하', 1),
#   ('주차장', 1),
#   ('시간', 1),
#   ('지원', 1),
#   ('함', 1),
#   ('판교', 1),
#   ('후배', 1),
#   ('만큼', 1)],
#  [('런던', 3),
#   ('맛집', 3),
#   ('보고', 3),
#   ('한식당', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('꼭', 2),
#   ('추', 2),
#   ('천하', 2),
#   ('를', 2),
#   ('된장찌개', 2),
#   ('방문', 1),
#   ('오늘', 1),
#   ('포스팅', 1),
#   ('이전', 1),
#   ('고', 1),
#   ('마지막', 1),
#   ('가장', 1),
#   ('메뉴인', 1),
#   ('차돌', 1),
#   ('친', 1),
#   ('구들', 1),
#   ('맛', 1),
#   ('이', 1),
#   ('젤', 1),
#   ('화려', 1),
#   ('정', 1),
#   ('결하', 1),
#   ('삶', 1)],
#  [('파리크라상', 5),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('빵', 3),
#   ('브런치', 2),
#   ('파리', 2),
#   ('크로와상', 2),
#   ('또', 2),
#   ('분위기', 1),
#   ('이제', 1),
#   ('언제', 1),
#   ('다시', 1),
#   ('유럽', 1),
#   ('답', 1),
#   ('다양', 1),
#   ('종류', 1),
#   ('마음', 1),
#   ('쏙', 1),
#   ('베이커리', 1),
#   ('카페', 1),
#   ('방랑', 1),
#   ('고', 1),
#   ('그날', 1),
#   ('기', 1),
#   ('다리', 1)],
#  [('양배추', 6),
#   ('국', 5),
#   ('아침', 3),
#   ('된장국', 2),
#   ('간단', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('통', 1),
#   ('사면', 1),
#   ('다양', 1),
#   ('요리', 1),
#   ('수', 1),
#   ('오늘', 1),
#   ('어요', 1),
#   ('위', 1),
#   ('건강', 1),
#   ('도움', 1),
#   ('속', 1),
#   ('편안', 1),
#   ('해주', 1),
#   ('기', 1),
#   ('때문', 1),
#   ('로', 1),
#   ('초록', 1),
#   ('스토리', 1)],
#  [('추천', 2),
#   ('메뉴', 2),
#   ('고구마튀김', 2),
#   ('초콜릿', 2),
#   ('쉐이크', 2),
#   ('강남', 1),
#   ('슈퍼', 1),
#   ('버거', 1),
#   ('위치', 1),
#   ('후기', 1),
#   ('가장', 1),
#   ('달짝', 1),
#   ('지근', 1),
#   ('하니', 1),
#   ('먹기', 1),
#   ('식', 1),
#   ('어도', 1),
#   ('정말', 1),
#   ('초코', 1),
#   ('덕후', 1),
#   ('대만', 1),
#   ('족', 1),
#   ('살', 1),
#   ('느낌', 1),
#   ('아리', 1),
#   ('노트', 1)],
#  [('메뉴', 4),
#   ('살', 3),
#   ('만공', 3),
#   ('격', 3),
#   ('추천', 3),
#   ('바삭', 3),
#   ('치', 3),
#   ('파포', 3),
#   ('세트', 3),
#   ('제시', 1),
#   ('아하', 1),
#   ('편이', 1),
#   ('광고', 1),
#   ('질색', 1),
#   ('동일', 1),
#   ('구성', 1),
#   ('마리', 1),
#   ('양', 1),
#   ('던데', 1),
#   ('려면', 1),
#   ('이', 1),
#   ('합', 1),
#   ('호랑이', 1),
#   ('담배', 1),
#   ('시절', 1)],
#  [('저녁', 4),
#   ('메뉴', 4),
#   ('추천', 3),
#   ('더미', 2),
#   ('식', 2),
#   ('우렁', 2),
#   ('된장찌개', 2),
#   ('신혼부부', 2),
#   ('간단', 2),
#   ('국물', 2),
#   ('요리', 2),
#   ('퇴근', 1),
#   ('후', 1),
#   ('오늘', 1),
#   ('뭐', 1),
#   ('을지', 1),
#   ('보통', 1),
#   ('밀키', 1),
#   ('트하', 1),
#   ('냉장', 1),
#   ('이나', 1),
#   ('냉동', 1),
#   ('보관', 1),
#   ('경우', 1),
#   ('더', 1),
#   ('미식', 1),
#   ('열처리', 1),
#   ('기술', 1),
#   ('통해', 1),
#   ('푸드', 1),
#   ('인', 1),
#   ('플루', 1),
#   ('율무', 1),
#   ('밍', 1),
#   ('일상', 1),
#   ('기록', 1)],
#  [('다낭', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('쌀국수', 2),
#   ('크게', 2),
#   ('사진', 2),
#   ('주문', 2),
#   ('베트남', 1),
#   ('맛집', 1),
#   ('티엔', 1),
#   ('킴', 1),
#   ('할인', 1),
#   ('위주', 1),
#   ('거', 1),
#   ('필수', 1),
#   ('고요', 1),
#   ('반', 1),
#   ('파인애플', 1),
#   ('볶음밥', 1),
#   ('아해', 1),
#   ('망고', 1),
#   ('샐러드', 1),
#   ('어서', 1),
#   ('여러', 1),
#   ('번', 1),
#   ('해외여행', 1),
#   ('고고씽', 1)],
#  [('타타', 3),
#   ('스', 3),
#   ('베이글', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('대전', 2),
#   ('빵', 2),
#   ('시간', 2),
#   ('모카', 2),
#   ('아기', 1),
#   ('실내', 1),
#   ('놀이터', 1),
#   ('가기', 1),
#   ('전', 1),
#   ('마늘', 1),
#   ('어가', 1),
#   ('포만', 1),
#   ('감', 1),
#   ('어서', 1),
#   ('브런치', 1),
#   ('슈크림', 1),
#   ('시트콤', 1),
#   ('라이프', 1)],
#  [('메뉴', 3),
#   ('추천', 3),
#   ('숙성', 3),
#   ('함덕', 2),
#   ('뼈', 2),
#   ('등심', 2),
#   ('예약', 1),
#   ('부터', 1),
#   ('주차', 1),
#   ('제주도', 1),
#   ('돼지', 1),
#   ('맛집', 1),
#   ('이유', 1),
#   ('지점', 1),
#   ('마다', 1),
#   ('한정', 1),
#   ('조금', 1),
#   ('중복', 1),
#   ('점', 1),
#   ('인분', 1),
#   ('판매', 1),
#   ('때문', 1),
#   ('먼저', 1),
#   ('주문', 1),
#   ('걸', 1),
#   ('저희', 1),
#   ('뼈목살', 1),
#   ('고', 1),
#   ('운하', 1),
#   ('민', 1)],
#  [('메뉴', 4),
#   ('추천', 2),
#   ('시오', 2),
#   ('세트', 2),
#   ('스테이크', 2),
#   ('광주', 1),
#   ('첨단', 1),
#   ('라운지', 1),
#   ('다양', 1),
#   ('우리', 1),
#   ('동생', 1),
#   ('로', 1),
#   ('토마호크', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('샐러드', 1),
#   ('메인', 1),
#   ('트러플', 1),
#   ('까르보나라', 1),
#   ('김치', 1),
#   ('라이스', 1),
#   ('추가', 1),
#   ('주문', 1),
#   ('찬둥', 1)],
#  [('파리바게트', 3),
#   ('메뉴', 3),
#   ('추천', 2),
#   ('애플', 2),
#   ('망고', 2),
#   ('베이컨', 2),
#   ('토스트', 2),
#   ('생크림', 1),
#   ('빵', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('개', 1),
#   ('모두', 1),
#   ('포스팅', 1),
#   ('생', 1),
#   ('크림빵', 1),
#   ('저', 1),
#   ('어서', 1),
#   ('가성', 1),
#   ('비', 1),
#   ('재', 1),
#   ('구매', 1),
#   ('의사', 1),
#   ('매우', 1),
#   ('민초', 1),
#   ('파의', 1),
#   ('박사', 1),
#   ('도전', 1),
#   ('기', 1)],
#  [('리틀', 3),
#   ('피카', 3),
#   ('스', 3),
#   ('추천', 3),
#   ('괌', 2),
#   ('메뉴', 2),
#   ('로꼬', 2),
#   ('모꼬', 2),
#   ('조식', 1),
#   ('메뉴인', 1),
#   ('에그베네딕트', 1),
#   ('여기', 1),
#   ('안', 1),
#   ('어도', 1),
#   ('진짜', 1),
#   ('그냥', 1),
#   ('를', 1),
#   ('검색', 1),
#   ('던데', 1),
#   ('저', 1),
#   ('보', 1),
#   ('또', 1),
#   ('영', 1)],
#  [('분당', 3),
#   ('맛집', 3),
#   ('포', 3),
#   ('시즌', 3),
#   ('키친', 3),
#   ('브런치', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('뇨끼', 3),
#   ('정말', 2),
#   ('강추', 2),
#   ('판교', 1),
#   ('해', 1),
#   ('곳', 1),
#   ('직영', 1),
#   ('점', 1),
#   ('경기', 1),
#   ('성남시', 1),
#   ('분당구', 1),
#   ('꼭', 1),
#   ('문어', 1),
#   ('콩피', 1),
#   ('스파클링', 1),
#   ('와인', 1),
#   ('구성', 1)],
#  [('메뉴', 4),
#   ('추천', 3),
#   ('맛집', 2),
#   ('부모님', 2),
#   ('식사', 2),
#   ('늘', 2),
#   ('푸른', 2),
#   ('염소', 2),
#   ('가든', 2),
#   ('드릴', 2),
#   ('모시', 1),
#   ('주차', 1),
#   ('정보', 1),
#   ('까지', 1),
#   ('소개', 1),
#   ('테', 1),
#   ('장소', 1),
#   ('고민', 1),
#   ('계시', 1),
#   ('분', 1),
#   ('시기', 1),
#   ('요', 1),
#   ('광주', 1),
#   ('본점', 1),
#   ('마찬가지', 1),
#   ('탕', 1),
#   ('수육', 1),
#   ('방', 1),
#   ('방곡', 1),
#   ('꼭', 1),
#   ('여행기', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('체코', 2),
#   ('프라하', 2),
#   ('여행', 2),
#   ('맛집', 2),
#   ('주문', 2),
#   ('방법', 2),
#   ('스테이크', 1),
#   ('및', 1),
#   ('줌', 1),
#   ('안녕하십니까', 1),
#   ('패션', 1),
#   ('쁠뤈', 1),
#   ('제', 1),
#   ('여기', 1),
#   ('고온', 1),
#   ('가지', 1),
#   ('면서', 1),
#   ('곳', 1),
#   ('오시', 1),
#   ('분', 1),
#   ('우왕좌왕', 1),
#   ('당', 1),
#   ('황하', 1),
#   ('도록', 1),
#   ('음식', 1),
#   ('세상', 1),
#   ('중심', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('얼스', 1),
#   ('어스', 1),
#   ('치아바타', 1),
#   ('전문', 1),
#   ('세컨', 1),
#   ('브랜드', 1),
#   ('베이컨', 1),
#   ('토마토', 1),
#   ('샌드위치', 1),
#   ('수프', 1),
#   ('포장', 1),
#   ('가능', 1),
#   ('주차', 1),
#   ('불가', 1),
#   ('주말', 1),
#   ('시정', 1),
#   ('부지런', 1),
#   ('회전', 1),
#   ('율', 1),
#   ('아무', 1),
#   ('도', 1),
#   ('신선', 1),
#   ('한편', 1),
#   ('삭', 1),
#   ('하니', 1),
#   ('식', 1),
#   ('조합', 1),
#   ('맛', 1),
#   ('요', 1),
#   ('합', 1)],
#  [('메뉴', 4),
#   ('추천', 2),
#   ('냉', 2),
#   ('모밀', 2),
#   ('압구정로', 1),
#   ('데오', 1),
#   ('맛집', 1),
#   ('여름', 1),
#   ('후기', 1),
#   ('하루', 1),
#   ('추', 1),
#   ('천하', 1),
#   ('저', 1),
#   ('때', 1),
#   ('마다', 1),
#   ('어요', 1),
#   ('다음', 1),
#   ('오늘', 1),
#   ('강력', 1),
#   ('리뷰', 1),
#   ('왼쪽', 1),
#   ('사진', 1),
#   ('그냥', 1),
#   ('기본', 1),
#   ('오른쪽', 1),
#   ('곱빼기', 1),
#   ('보통', 1),
#   ('남', 1),
#   ('여', 1),
#   ('가시', 1),
#   ('분', 1),
#   ('인', 1)],
#  [('메뉴', 4),
#   ('할인', 4),
#   ('아웃백', 3),
#   ('추천', 3),
#   ('스테이크', 2),
#   ('하우스', 1),
#   ('변경', 1),
#   ('팁', 1),
#   ('방법', 1),
#   ('런치', 1),
#   ('시간', 1),
#   ('오픈', 1),
#   ('오후', 1),
#   ('평일', 1),
#   ('주말', 1),
#   ('동일', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('갈릭', 1),
#   ('립', 1),
#   ('아이', 1),
#   ('통신사', 1),
#   ('주문', 1),
#   ('카드', 1),
#   ('아기', 1),
#   ('의자', 1),
#   ('외식', 1),
#   ('장소', 1),
#   ('부시맨', 1),
#   ('빵', 1),
#   ('기록', 1),
#   ('용', 1)],
#  [('추천', 3),
#   ('성수역', 2),
#   ('번', 2),
#   ('출구', 2),
#   ('메뉴', 2),
#   ('미사', 1),
#   ('맛집', 1),
#   ('전', 1),
#   ('외', 1),
#   ('추가', 1),
#   ('보심', 1),
#   ('호선', 1),
#   ('오픈', 1),
#   ('일요일', 1),
#   ('휴무', 1),
#   ('듯', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('고추전', 1),
#   ('해물파전', 1),
#   ('오징어', 1),
#   ('데침', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('회비', 1),
#   ('정산', 1),
#   ('만요', 1),
#   ('개인', 1),
#   ('적', 1),
#   ('입맛', 1),
#   ('전집', 1)],
#  [('치아바타', 3),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('식빵', 2),
#   ('소금', 2),
#   ('빵', 2),
#   ('세종', 1),
#   ('맛집', 1),
#   ('줄', 1),
#   ('서서', 1),
#   ('빵집', 1),
#   ('셀레슈크레', 1),
#   ('다른', 1),
#   ('블로그', 1),
#   ('리스트', 1),
#   ('에그타르트', 1),
#   ('바스', 1),
#   ('트', 1),
#   ('치즈케이크', 1),
#   ('듯', 1),
#   ('내', 1),
#   ('구매', 1),
#   ('퀸', 1),
#   ('망', 1),
#   ('순', 1),
#   ('우유', 1),
#   ('크루아상', 1),
#   ('뺑오', 1),
#   ('쇼콜라', 1),
#   ('치즈', 1),
#   ('바닐라', 1),
#   ('주옥', 1),
#   ('나날', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('맛집', 2),
#   ('소바', 2),
#   ('연구소', 2),
#   ('신촌', 1),
#   ('너', 1),
#   ('진짜', 1),
#   ('구나', 1),
#   ('끝', 1),
#   ('까지', 1),
#   ('보시', 1),
#   ('길', 1),
#   ('이전', 1),
#   ('포스팅', 1),
#   ('참고', 1),
#   ('출발', 1),
#   ('호선', 1),
#   ('중', 1),
#   ('하나', 1),
#   ('설명', 1),
#   ('폰', 1),
#   ('소스', 1),
#   ('미가', 1),
#   ('배', 1),
#   ('화려', 1),
#   ('정', 1),
#   ('결하', 1),
#   ('삶', 1)],
#  [('메뉴', 4),
#   ('졸리', 2),
#   ('비', 2),
#   ('추천', 2),
#   ('치킨', 2),
#   ('보라카이', 1),
#   ('디', 1),
#   ('맛집', 1),
#   ('및', 1),
#   ('가격', 1),
#   ('정보', 1),
#   ('저희', 1),
#   ('일반', 1),
#   ('선택', 1),
#   ('몇', 1),
#   ('페소', 1),
#   ('정도', 1),
#   ('추', 1),
#   ('가금', 1),
#   ('불하', 1),
#   ('스파이', 1),
#   ('시', 1),
#   ('변경', 1),
#   ('수', 1),
#   ('이', 1),
#   ('더', 1),
#   ('로', 1),
#   ('꼽으', 1),
#   ('시더', 1),
#   ('요', 1),
#   ('치밥', 1),
#   ('닭다리', 1),
#   ('밥', 1),
#   ('마음', 1)],
#  [('메뉴', 5),
#   ('추천', 3),
#   ('솔솥', 2),
#   ('이', 2),
#   ('무난', 2),
#   ('맛', 2),
#   ('경복궁역', 1),
#   ('촌', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('맛집', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('굳이', 1),
#   ('왜냐면', 1),
#   ('다른', 1),
#   ('솥밥', 1),
#   ('더', 1),
#   ('때문', 1),
#   ('그냥', 1),
#   ('상상', 1),
#   ('스테이크', 1),
#   ('덮밥', 1),
#   ('랄', 1),
#   ('고', 1),
#   ('나', 1)],
#  [('롯데리아', 5),
#   ('메뉴', 5),
#   ('추천', 4),
#   ('새우', 4),
#   ('저녁', 2),
#   ('익스트림', 2),
#   ('베이', 2),
#   ('건', 2),
#   ('신', 1),
#   ('레몬', 1),
#   ('크림', 1),
#   ('시식', 1),
#   ('후기', 1),
#   ('음원', 1),
#   ('이벤트', 1),
#   ('점심', 1),
#   ('이', 1),
#   ('포스팅', 1),
#   ('로부터', 1),
#   ('원고료', 1),
#   ('제공', 1),
#   ('주관', 1),
#   ('적', 1),
#   ('작성', 1),
#   ('글', 1),
#   ('말', 1),
#   ('염', 1),
#   ('방구', 1)],
#  [('추천', 3),
#   ('시추', 2),
#   ('안', 2),
#   ('메뉴', 2),
#   ('요리', 2),
#   ('판교', 1),
#   ('중국요리', 1),
#   ('하우스', 1),
#   ('사천요리', 1),
#   ('움', 1),
#   ('피셜', 1),
#   ('리스트', 1),
#   ('에피', 1),
#   ('타이', 1),
#   ('징', 1),
#   ('스프', 1),
#   ('야채', 1),
#   ('사이드', 1),
#   ('향가', 1),
#   ('지도', 1),
#   ('꽤', 1),
#   ('맛', 1),
#   ('함', 1),
#   ('육류', 1),
#   ('돼지', 1),
#   ('소', 1),
#   ('닭', 1),
#   ('동파육', 1),
#   ('진짜', 1),
#   ('단연', 1),
#   ('최고', 1),
#   ('완전', 1),
#   ('동행', 1),
#   ('말로', 1),
#   ('소고기', 1),
#   ('전골', 1),
#   ('투탑', 1),
#   ('오늘', 1),
#   ('책장', 1)],
#  [('짬뽕', 4),
#   ('월계수', 3),
#   ('식당', 3),
#   ('메뉴', 3),
#   ('추천', 2),
#   ('돈까스', 2),
#   ('볶음밥', 2),
#   ('국밥', 2),
#   ('우삼겹', 2),
#   ('충장로', 1),
#   ('그', 1),
#   ('자리', 1),
#   ('그대로', 1),
#   ('오래', 1),
#   ('맛집', 1),
#   ('제육', 1),
#   ('덮밥', 1),
#   ('잡채', 1),
#   ('잡채밥', 1),
#   ('등', 1),
#   ('사이드', 1),
#   ('물만두', 1),
#   ('삼선', 1),
#   ('다음', 1),
#   ('가야', 1),
#   ('딩', 1)],
#  [('곡성', 3),
#   ('추천', 3),
#   ('것', 3),
#   ('가든', 2),
#   ('메뉴', 2),
#   ('를', 2),
#   ('맛집', 1),
#   ('방문자', 1),
#   ('단골', 1),
#   ('입장', 1),
#   ('드', 1),
#   ('리자', 1),
#   ('모든', 1),
#   ('스테이크', 1),
#   ('맛', 1),
#   ('보고', 1),
#   ('분', 1),
#   ('평일', 1),
#   ('한정', 1),
#   ('판매', 1),
#   ('스폐셜', 1),
#   ('고요', 1),
#   ('조금', 1),
#   ('메인', 1),
#   ('하나', 1),
#   ('방', 1),
#   ('방곡', 1),
#   ('꼭', 1),
#   ('여행기', 1)],
#  [('추천', 4),
#   ('메뉴', 3),
#   ('각', 2),
#   ('또', 1),
#   ('동대문', 1),
#   ('에베레스트', 1),
#   ('비', 1),
#   ('아하', 1),
#   ('시', 1),
#   ('하나', 1),
#   ('제', 1),
#   ('친', 1),
#   ('구들', 1),
#   ('입', 1),
#   ('더니', 1),
#   ('아주', 1),
#   ('혐', 1),
#   ('바보', 1),
#   ('커리', 1),
#   ('치킨', 1),
#   ('티카', 1),
#   ('머설', 1),
#   ('갈릭', 1),
#   ('버터', 1),
#   ('맛', 1),
#   ('살', 1),
#   ('아가', 1),
#   ('빙고', 1)],
#  [('메뉴', 5),
#   ('포', 3),
#   ('이자카야', 3),
#   ('맛집', 2),
#   ('추천', 2),
#   ('세트', 2),
#   ('하이', 1),
#   ('볼', 1),
#   ('품', 1),
#   ('부터', 1),
#   ('까지', 1),
#   ('일본주', 1),
#   ('준비', 1),
#   ('어요', 1),
#   ('분위기', 1),
#   ('문', 1),
#   ('어가', 1),
#   ('순간', 1),
#   ('여기', 1),
#   ('일본인', 1),
#   ('나', 1),
#   ('순간이동', 1),
#   ('러블리썬', 1),
#   ('여행', 1),
#   ('날', 1)],
#  [('솥밥', 5),
#   ('정자동', 2),
#   ('맛집', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('위주', 2),
#   ('솔솥', 1),
#   ('가시', 1),
#   ('길', 1),
#   ('인', 1),
#   ('이상', 1),
#   ('정도', 1),
#   ('전화', 1),
#   ('예약', 1),
#   ('가능', 1),
#   ('판', 1),
#   ('정독', 1),
#   ('해산물', 1),
#   ('도미', 1),
#   ('관자', 1),
#   ('전복', 1),
#   ('민물장어', 1),
#   ('연어', 1),
#   ('꼬막', 1),
#   ('갈치구이', 1),
#   ('고기', 1),
#   ('스테이크', 1)],
#  [('찜닭', 7),
#   ('메뉴', 5),
#   ('추천', 4),
#   ('가격', 3),
#   ('시래기', 3),
#   ('보통', 2),
#   ('맛', 2),
#   ('찜', 1),
#   ('맵', 1),
#   ('단계', 1),
#   ('로제', 1),
#   ('평', 1),
#   ('음번', 1),
#   ('박', 1),
#   ('순대', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('일상', 1)],
#  [('메뉴', 4),
#   ('소금', 4),
#   ('빵', 4),
#   ('카페', 2),
#   ('추천', 2),
#   ('성수동', 1),
#   ('오로라', 1),
#   ('베이커리', 1),
#   ('위치', 1),
#   ('영업', 1),
#   ('시간', 1),
#   ('정리', 1),
#   ('과연', 1),
#   ('무엇', 1),
#   ('네이버', 1),
#   ('지도', 1),
#   ('소개', 1),
#   ('가장', 1),
#   ('추', 1),
#   ('천하', 1),
#   ('잠봉뵈르', 1),
#   ('라우', 1),
#   ('겐', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('경제', 1),
#   ('적', 1),
#   ('자유', 1),
#   ('향', 1),
#   ('삶', 1),
#   ('기록', 1)],
#  [('메뉴', 3),
#   ('추천', 2),
#   ('완전', 2),
#   ('분', 2),
#   ('아하', 2),
#   ('상무지구', 1),
#   ('다이어트', 1),
#   ('때', 1),
#   ('가기', 1),
#   ('맛집', 1),
#   ('디', 1),
#   ('네가지', 1),
#   ('추', 1),
#   ('천하', 1),
#   ('처음', 1),
#   ('보시', 1),
#   ('오', 1),
#   ('거', 1),
#   ('인', 1),
#   ('이유', 1),
#   ('어요', 1),
#   ('샐러드', 1),
#   ('시', 1),
#   ('요건', 1),
#   ('실거', 1),
#   ('부들', 1),
#   ('근로', 1),
#   ('그', 1)],
#  [('추천', 4),
#   ('메뉴', 4),
#   ('사발', 2),
#   ('경복궁역', 1),
#   ('맛집', 1),
#   ('단골', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('또', 1),
#   ('하나', 1),
#   ('멍게', 1),
#   ('간장', 1),
#   ('비빔밥', 1),
#   ('국밥', 1),
#   ('밥', 1),
#   ('모두', 1),
#   ('미니', 1),
#   ('국수', 1),
#   ('주신', 1),
#   ('걸', 1),
#   ('화려', 1),
#   ('정', 1),
#   ('결하', 1),
#   ('삶', 1)],
#  [('야식', 4),
#   ('들기름', 2),
#   ('깻잎', 2),
#   ('페스', 2),
#   ('토', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('요리', 2),
#   ('간장', 1),
#   ('비빔', 1),
#   ('통', 1),
#   ('밀국수', 1),
#   ('활용', 1),
#   ('자', 1),
#   ('사실', 1),
#   ('안', 1),
#   ('정답', 1),
#   ('꼭', 1),
#   ('의', 1),
#   ('덕목', 1),
#   ('만들기', 1),
#   ('간단', 1),
#   ('지나', 1),
#   ('친', 1),
#   ('포만', 1),
#   ('감', 1),
#   ('등', 1),
#   ('부담', 1),
#   ('아야', 1),
#   ('재미', 1),
#   ('마미', 1),
#   ('집', 1)],
#  [('조선', 3),
#   ('홍연', 3),
#   ('탕수육', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('웨스', 2),
#   ('틴', 2),
#   ('언제', 2),
#   ('소공동', 1),
#   ('호텔', 1),
#   ('중식', 1),
#   ('당', 1),
#   ('맛집', 1),
#   ('오늘', 1),
#   ('한결', 1),
#   ('강추', 1),
#   ('저', 1),
#   ('아하', 1),
#   ('편이', 1),
#   ('강력', 1),
#   ('아주', 1),
#   ('편안', 1),
#   ('친절', 1),
#   ('이전', 1),
#   ('포스팅', 1),
#   ('바니', 1),
#   ('티', 1),
#   ('블로그', 1)],
#  [('메뉴', 3),
#   ('팔레', 2),
#   ('추천', 2),
#   ('그랜드', 1),
#   ('조선', 1),
#   ('부산', 1),
#   ('맛집', 1),
#   ('바로', 1),
#   ('칠리', 1),
#   ('새우', 1),
#   ('코스', 1),
#   ('주', 1),
#   ('문하', 1),
#   ('알', 1),
#   ('정도', 1),
#   ('아주', 1),
#   ('맛', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('품', 1),
#   ('주문', 1),
#   ('튀김', 1),
#   ('옷', 1),
#   ('양념', 1),
#   ('코팅', 1),
#   ('탕후루', 1),
#   ('식감', 1),
#   ('보', 1),
#   ('라이프', 1)],
#  [('추천', 3),
#   ('메뉴', 2),
#   ('쏨땀', 2),
#   ('음식', 2),
#   ('북촌', 1),
#   ('맛집', 1),
#   ('태국', 1),
#   ('음식점', 1),
#   ('화양연화', 1),
#   ('타이', 1),
#   ('첫', 1),
#   ('등장', 1),
#   ('생김새', 1),
#   ('부터', 1),
#   ('심상', 1),
#   ('찮다', 1),
#   ('콤함', 1),
#   ('이루', 1),
#   ('말', 1),
#   ('입맛', 1),
#   ('사이드', 1),
#   ('강력', 1),
#   ('드', 1),
#   ('린다', 1),
#   ('전', 1),
#   ('반적', 1),
#   ('훌륭', 1),
#   ('다음', 1),
#   ('가게', 1),
#   ('귤', 1),
#   ('의', 1),
#   ('욤뇸', 1),
#   ('로그', 1)],
#  [('대하', 3),
#   ('포장', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('까지', 2),
#   ('요리', 2),
#   ('사', 2),
#   ('서영수', 1),
#   ('산', 1),
#   ('법', 1),
#   ('오늘', 1),
#   ('파티', 1),
#   ('소금', 1),
#   ('구이', 1),
#   ('갈릭', 1),
#   ('버터', 1),
#   ('새우', 1),
#   ('라면', 1),
#   ('가지', 1),
#   ('로', 1),
#   ('준비', 1),
#   ('것', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('보기', 1),
#   ('집', 1),
#   ('건', 1),
#   ('처음', 1),
#   ('었는데', 1),
#   ('방', 1),
#   ('방곡', 1),
#   ('꼭', 1),
#   ('여행기', 1)],
#  [('안주', 4),
#   ('메뉴', 4),
#   ('추천', 3),
#   ('요리', 2),
#   ('안산', 1),
#   ('한식', 1),
#   ('재', 1),
#   ('해석', 1),
#   ('히든', 1),
#   ('일품', 1),
#   ('항', 1),
#   ('정숙', 1),
#   ('회', 1),
#   ('항정', 1),
#   ('냉소', 1),
#   ('시즌', 1),
#   ('꼬막', 1),
#   ('육회', 1),
#   ('트러플', 1),
#   ('감자', 1),
#   ('가지', 1),
#   ('튀김', 1),
#   ('전통주', 1),
#   ('막걸리', 1),
#   ('삼천포', 1),
#   ('쩐쭈', 1),
#   ('맹글어', 1),
#   ('오늘', 1),
#   ('책장', 1)],
#  [('메뉴', 3),
#   ('도우', 3),
#   ('추천', 2),
#   ('맛', 2),
#   ('피자', 2),
#   ('두', 2),
#   ('최대', 1),
#   ('할인', 1),
#   ('크리', 1),
#   ('지기', 1),
#   ('겹겹이', 1),
#   ('품격', 1),
#   ('치즈', 1),
#   ('크레이프', 1),
#   ('샌드', 1),
#   ('일명', 1),
#   ('치', 1),
#   ('나폴리', 1),
#   ('씬', 1),
#   ('가지', 1),
#   ('바삭', 1),
#   ('쫄깃', 1),
#   ('배', 1),
#   ('신', 1),
#   ('도미노피자', 1),
#   ('공식', 1),
#   ('블로그', 1)],
#  [('메뉴', 3),
#   ('광장', 2),
#   ('코', 2),
#   ('중국집', 2),
#   ('개화', 2),
#   ('추천', 2),
#   ('계절', 1),
#   ('콩국수', 1),
#   ('현수막', 1),
#   ('예전', 1),
#   ('마', 1),
#   ('차이', 1),
#   ('짬뽕', 1),
#   ('때', 1),
#   ('번', 1),
#   ('적', 1),
#   ('상호', 1),
#   ('로', 1),
#   ('볶음밥', 1),
#   ('탕수육', 1),
#   ('호호', 1),
#   ('렐라', 1),
#   ('거림', 1)],
#  [('메뉴', 3),
#   ('안주', 3),
#   ('운정', 2),
#   ('금별', 2),
#   ('맥주', 2),
#   ('추천', 2),
#   ('주문', 2),
#   ('산내', 1),
#   ('마을', 1),
#   ('술집', 1),
#   ('오픈', 1),
#   ('메뉴판', 1),
#   ('야외', 1),
#   ('테이블', 1),
#   ('이용', 1),
#   ('시', 1),
#   ('탕', 1),
#   ('버너', 1),
#   ('불가', 1),
#   ('남편', 1),
#   ('차로', 1),
#   ('회식', 1),
#   ('사모님', 1),
#   ('중', 1),
#   ('백합', 1),
#   ('조개', 1),
#   ('버터', 1),
#   ('술찜', 1),
#   ('부터', 1),
#   ('일품', 1),
#   ('한식', 1),
#   ('슈', 1),
#   ('니슈', 1),
#   ('의', 1),
#   ('행복', 1),
#   ('일상', 1)],
#  [('도넛', 6),
#   ('노티', 4),
#   ('드', 4),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('크림', 3),
#   ('더', 2),
#   ('잠실', 1),
#   ('가격', 1),
#   ('송리단길', 1),
#   ('카페', 1),
#   ('강력', 1),
#   ('스트로베리', 1),
#   ('라즈베리', 1),
#   ('잼', 1),
#   ('아하', 1),
#   ('개인', 1),
#   ('취향', 1),
#   ('때문', 1),
#   ('인지', 1),
#   ('묵', 1),
#   ('직하', 1),
#   ('삼삼', 1),
#   ('진땅', 1)],
#  [('핫도그', 5),
#   ('건대', 3),
#   ('혼밥', 3),
#   ('로스', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('커먼그라운드', 2),
#   ('맛집', 2),
#   ('직장인', 1),
#   ('거나', 1),
#   ('치즈', 1),
#   ('스테이크', 1),
#   ('핫', 1),
#   ('치토스', 1),
#   ('엘', 1),
#   ('떼', 1),
#   ('옥수수', 1),
#   ('밀크쉐이크', 1),
#   ('소', 1),
#   ('소하', 1),
#   ('화려', 1),
#   ('일상', 1)],
#  [('메뉴', 6),
#   ('추천', 3),
#   ('시즌', 3),
#   ('맛집', 2),
#   ('샐러드', 2),
#   ('때문', 2),
#   ('삼성역', 1),
#   ('피', 1),
#   ('인더', 1),
#   ('가든', 1),
#   ('코엑스', 1),
#   ('점', 1),
#   ('등', 1),
#   ('반짝', 1),
#   ('다가', 1),
#   ('사라', 1),
#   ('의외', 1),
#   ('운', 1),
#   ('꽤', 1),
#   ('부터', 1),
#   ('게', 1),
#   ('주문', 1),
#   ('방법', 1),
#   ('매장', 1),
#   ('입구', 1),
#   ('어서', 1),
#   ('줄', 1),
#   ('팬더', 1),
#   ('나들이', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('도넛', 2),
#   ('조', 2),
#   ('이맘', 2),
#   ('품절', 2),
#   ('제주', 1),
#   ('애월', 1),
#   ('랜', 1),
#   ('디스', 1),
#   ('주차', 1),
#   ('이', 1),
#   ('날', 1),
#   ('애플', 1),
#   ('프리터', 1),
#   ('글레이', 1),
#   ('버터크림', 1),
#   ('경우', 1),
#   ('인기', 1),
#   ('꼭', 1),
#   ('일찍', 1),
#   ('방문', 1),
#   ('또', 1),
#   ('다른', 1),
#   ('포스팅', 1),
#   ('조이', 1)],
#  [('탕후루', 6),
#   ('왕가', 4),
#   ('메뉴', 4),
#   ('추천', 2),
#   ('신', 2),
#   ('빙수', 2),
#   ('동두천', 2),
#   ('점', 2),
#   ('여태', 1),
#   ('까지', 1),
#   ('제일', 1),
#   ('가장', 1),
#   ('자주', 1),
#   ('방', 1),
#   ('문하', 1),
#   ('행점', 1),
#   ('의정부', 1),
#   ('번', 1),
#   ('노맛', 1),
#   ('다시', 1),
#   ('안', 1),
#   ('가요', 1),
#   ('너', 1),
#   ('리', 1),
#   ('세', 1),
#   ('상', 1)],
#  [('추천', 3),
#   ('메뉴', 2),
#   ('어요', 2),
#   ('아이스크림', 2),
#   ('수원', 1),
#   ('폴바', 1),
#   ('셋', 1),
#   ('커피', 1),
#   ('베이커리', 1),
#   ('직원', 1),
#   ('직접', 1),
#   ('주문', 1),
#   ('룽', 1),
#   ('아이스', 1),
#   ('아메리카노', 1),
#   ('상하이', 1),
#   ('목장', 1),
#   ('우유', 1),
#   ('토핑', 1),
#   ('추가', 1),
#   ('라떼', 1),
#   ('오늘', 1),
#   ('배', 1),
#   ('라스', 1),
#   ('달달', 1),
#   ('일상', 1)],
#  [('집들이', 4),
#   ('음식', 4),
#   ('메뉴', 4),
#   ('추천', 4),
#   ('돼지갈비', 3),
#   ('밀키', 2),
#   ('트', 2),
#   ('집', 1),
#   ('굽', 1),
#   ('기만', 1),
#   ('정인', 1),
#   ('푸드', 1),
#   ('갈비', 1),
#   ('요리', 1),
#   ('밀', 1),
#   ('키트', 1),
#   ('고기', 1),
#   ('법', 1),
#   ('안내서', 1),
#   ('저', 1),
#   ('베블', 1),
#   ('식탁', 1)],
#  [('연남동', 4),
#   ('맛집', 3),
#   ('데이트', 3),
#   ('윤성용', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('레스토랑', 1),
#   ('주문', 1),
#   ('특선', 1),
#   ('둥지', 1),
#   ('샐러드', 1),
#   ('엔초', 1),
#   ('비', 1),
#   ('새우', 1),
#   ('파스타', 1),
#   ('콰트로', 1),
#   ('포르마', 1),
#   ('레몬에이드', 1),
#   ('콜라', 1),
#   ('홍대', 1),
#   ('합', 1),
#   ('홍진', 1),
#   ('리뷰', 1)],
#  [('소바', 5),
#   ('마제', 3),
#   ('맛집', 2),
#   ('냉소', 2),
#   ('바', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('주문', 2),
#   ('에비덴', 2),
#   ('방배역', 1),
#   ('백', 1),
#   ('소정', 1),
#   ('개인', 1),
#   ('취향', 1),
#   ('대로', 1),
#   ('선택', 1),
#   ('한번', 1),
#   ('보시', 1),
#   ('길', 1),
#   ('역', 1),
#   ('후기', 1),
#   ('개', 1),
#   ('자루', 1),
#   ('돈카츠', 1),
#   ('냉', 1),
#   ('의', 1),
#   ('탐방', 1)],
#  [('심해', 2),
#   ('연어', 2),
#   ('사시미', 2),
#   ('훌리', 2),
#   ('치킨', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('먹기', 1),
#   ('손질', 1),
#   ('해주시', 1),
#   ('최애', 1),
#   ('인', 1),
#   ('두툼', 1),
#   ('하니', 1),
#   ('입안', 1),
#   ('사르르', 1),
#   ('음식', 1),
#   ('음료', 1),
#   ('하이', 1),
#   ('볼', 1),
#   ('수', 1)],
#  [('롯데리아', 4),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('이번', 3),
#   ('새우', 2),
#   ('익스트림', 2),
#   ('레몬', 2),
#   ('크림', 2),
#   ('신상', 1),
#   ('포스팅', 1),
#   ('후', 1),
#   ('기입', 1),
#   ('더욱', 1),
#   ('저', 1),
#   ('홍대역', 1),
#   ('근처', 1),
#   ('홍대', 1),
#   ('매장', 1),
#   ('를', 1),
#   ('어보', 1),
#   ('았', 1),
#   ('나', 1),
#   ('세상', 1),
#   ('생각', 1),
#   ('잡', 1),
#   ('동사', 1)],
#  [('매드', 3),
#   ('포', 3),
#   ('갈릭', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('크랩', 3),
#   ('파스타', 3),
#   ('앤', 2),
#   ('랍스터', 2),
#   ('존맛', 2),
#   ('어서', 2),
#   ('반짝', 2),
#   ('은', 1),
#   ('여러분', 1),
#   ('안녕', 1),
#   ('주말', 1),
#   ('친구', 1),
#   ('부부', 1),
#   ('포스팅', 1),
#   ('전인', 1),
#   ('작', 1),
#   ('은별', 1)],
#  [('부다페스트', 5),
#   ('한인식', 2),
#   ('당', 2),
#   ('비빔밥', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('얼마', 1),
#   ('전', 1),
#   ('드라큘라', 1),
#   ('성', 1),
#   ('축구', 1),
#   ('시합', 1),
#   ('장소', 1),
#   ('아이', 1),
#   ('한식당', 1),
#   ('식당', 1),
#   ('가나', 1),
#   ('영화', 1),
#   ('드림', 1),
#   ('박서준', 1),
#   ('더후', 1),
#   ('녀드성', 1)],
#  [('캠핑', 4),
#   ('추천', 4),
#   ('음식', 3),
#   ('메뉴', 3),
#   ('로', 2),
#   ('서택기', 2),
#   ('쪽', 2),
#   ('갈비', 2),
#   ('맛', 2),
#   ('고', 2),
#   ('여행', 2),
#   ('리즈', 2),
#   ('꼽', 1),
#   ('후기', 1),
#   ('가격', 1),
#   ('용량', 1),
#   ('글', 1),
#   ('사진', 1),
#   ('오늘', 1),
#   ('에어', 1),
#   ('프라이', 1),
#   ('사용', 1),
#   ('때', 1),
#   ('요', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('탄탄면', 1),
#   ('방', 1),
#   ('인천', 1),
#   ('청라', 1),
#   ('점심', 1),
#   ('후기', 1),
#   ('옆', 1),
#   ('요즘', 1),
#   ('주문', 1),
#   ('키오', 1),
#   ('스크', 1),
#   ('요리', 1),
#   ('정도', 1),
#   ('거', 1),
#   ('유명', 1),
#   ('보시', 1),
#   ('다시피', 1),
#   ('조절', 1),
#   ('가능', 1),
#   ('가이드', 1),
#   ('고하', 1),
#   ('시기', 1),
#   ('소개', 1),
#   ('손님', 1),
#   ('안심', 1),
#   ('설계', 1),
#   ('사', 1),
#   ('치즈', 1),
#   ('보험', 1)],
#  [('커피', 6),
#   ('아이스크림', 4),
#   ('추천', 3),
#   ('룰리', 2),
#   ('메뉴', 2),
#   ('가창', 1),
#   ('쫀득한데', 1),
#   ('쫀득해', 1),
#   ('아하', 1),
#   ('데', 1),
#   ('이', 1),
#   ('날', 1),
#   ('부터', 1),
#   ('진짜', 1),
#   ('디', 1),
#   ('카페인', 1),
#   ('저', 1)],
#  [('버거', 4),
#   ('강력', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('쉑쉑', 2),
#   ('쉐이크', 2),
#   ('스택', 2),
#   ('중', 1),
#   ('하나', 1),
#   ('바닐라', 1),
#   ('진', 1),
#   ('맛', 1),
#   ('다른', 1),
#   ('압도', 1),
#   ('진리', 1),
#   ('생', 1),
#   ('각하', 1),
#   ('분', 1),
#   ('쉑', 1),
#   ('추', 1),
#   ('천하', 1),
#   ('포스팅', 1)],
#  [('족발', 4),
#   ('메뉴', 3),
#   ('렌', 2),
#   ('지쿠', 2),
#   ('캣', 2),
#   ('바베큐', 2),
#   ('어서', 2),
#   ('추천', 1),
#   ('직화', 1),
#   ('삼겹살', 1),
#   ('찰', 1),
#   ('순대', 1),
#   ('간단', 1),
#   ('나머지', 1),
#   ('렌지업', 1),
#   ('간편', 1),
#   ('조리', 1),
#   ('수', 1),
#   ('주말', 1),
#   ('로', 1),
#   ('어요', 1),
#   ('집', 1),
#   ('때', 1),
#   ('무조건', 1),
#   ('뼈', 1),
#   ('선호', 1),
#   ('쫀득', 1),
#   ('하니', 1),
#   ('양념', 1),
#   ('까지', 1),
#   ('진심', 1),
#   ('선물', 1),
#   ('하루', 1)],
#  [('마법', 3),
#   ('메뉴', 3),
#   ('할인', 3),
#   ('핫', 2),
#   ('후라이드', 2),
#   ('추천', 2),
#   ('천원', 2),
#   ('봄', 1),
#   ('둘', 1),
#   ('어보', 1),
#   ('저번', 1),
#   ('주말', 1),
#   ('낮', 1),
#   ('밥', 1),
#   ('안', 1),
#   ('해', 1),
#   ('배민', 1),
#   ('신', 1),
#   ('중이', 1),
#   ('포장', 1),
#   ('까지', 1),
#   ('사', 1),
#   ('뽀기', 1),
#   ('일상', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('스페셜', 2),
#   ('성식', 1),
#   ('영', 1),
#   ('맛집', 1),
#   ('이탈리안', 1),
#   ('맥', 1),
#   ('모닝', 1),
#   ('주차', 1),
#   ('정보', 1),
#   ('느낌', 1),
#   ('거', 1),
#   ('고', 1),
#   ('사진', 1),
#   ('중', 1),
#   ('햄', 1),
#   ('판매', 1),
#   ('대요', 1),
#   ('모야', 1),
#   ('오리', 1),
#   ('널', 1),
#   ('판', 1),
#   ('체다', 1),
#   ('트러플', 1),
#   ('리코', 1),
#   ('타', 1),
#   ('어서', 1),
#   ('재료', 1),
#   ('보고', 1),
#   ('취향', 1)],
#  [('운동', 4),
#   ('신체', 4),
#   ('회복', 4),
#   ('영양', 4),
#   ('보충', 4),
#   ('후', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('음식', 2),
#   ('위', 2),
#   ('위해', 2),
#   ('이', 1),
#   ('후의', 1),
#   ('돕기', 1),
#   ('참고', 1),
#   ('수', 1),
#   ('옵션', 1),
#   ('건강', 1)],
#  [('메뉴', 3),
#   ('맥도날드', 2),
#   ('추천', 2),
#   ('맥', 2),
#   ('모닝', 2),
#   ('항상', 2),
#   ('가격', 1),
#   ('맥런치', 1),
#   ('이용', 1),
#   ('시간', 1),
#   ('구리', 1),
#   ('아이스크림', 1),
#   ('라떼', 1),
#   ('종류', 1),
#   ('양하', 1),
#   ('정말', 1),
#   ('꼬맹이', 1),
#   ('해피밀', 1),
#   ('사이드', 1),
#   ('매번', 1),
#   ('장난감', 1),
#   ('늘', 1),
#   ('신중', 1),
#   ('제이', 1),
#   ('블로그', 1)],
#  [('단토', 4),
#   ('리', 4),
#   ('메뉴', 3),
#   ('주문', 3),
#   ('추천', 2),
#   ('전자', 2),
#   ('메뉴판', 2),
#   ('발산역', 1),
#   ('이자카야', 1),
#   ('이용', 1),
#   ('접수', 1),
#   ('후', 1),
#   ('가성', 1),
#   ('비', 1),
#   ('안주', 1),
#   ('공유', 1),
#   ('고', 1),
#   ('제일', 1),
#   ('도', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('취향', 1),
#   ('단편', 1),
#   ('집', 1)],
#  [('커피', 3),
#   ('메뉴', 3),
#   ('퍼센트', 2),
#   ('추천', 2),
#   ('어요', 2),
#   ('및', 1),
#   ('가격', 1),
#   ('정보공', 1),
#   ('유', 1),
#   ('효', 1),
#   ('천지', 1),
#   ('구', 1),
#   ('카페', 1),
#   ('서도', 1),
#   ('확인가능', 1),
#   ('도록', 1),
#   ('판이', 1),
#   ('준비', 1),
#   ('저', 1),
#   ('마시기', 1),
#   ('기분', 1),
#   ('단맛', 1),
#   ('수', 1),
#   ('어서', 1),
#   ('방문', 1),
#   ('라떼', 1)],
#  [('울산', 4),
#   ('신정동', 3),
#   ('추천', 3),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('파스타', 2),
#   ('매장', 2),
#   ('방문', 2),
#   ('식사', 2),
#   ('남구', 1),
#   ('로', 1),
#   ('스테이크', 1),
#   ('휴무', 1),
#   ('유동', 1),
#   ('적', 1),
#   ('미리', 1),
#   ('예약', 1),
#   ('준비', 1),
#   ('수', 1),
#   ('있오욤', 1),
#   ('집', 1),
#   ('맛집', 1)],
#  [('빵', 4),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('마담', 2),
#   ('얼그레이', 2),
#   ('크림', 2),
#   ('번', 2),
#   ('뚜레쥬르', 1),
#   ('진짜', 1),
#   ('발견', 1),
#   ('고요', 1),
#   ('총', 1),
#   ('가지', 1),
#   ('를', 1),
#   ('저', 1),
#   ('소금', 1),
#   ('초딩', 1),
#   ('입맛', 1),
#   ('짝꿍', 1),
#   ('피자빵', 1),
#   ('모닝빵', 1),
#   ('어요', 1),
#   ('이중', 1),
#   ('건', 1),
#   ('여행', 1),
#   ('일상', 1)],
#  [('카페', 4),
#   ('맛집', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('양재천', 2),
#   ('거리', 2),
#   ('비밀', 2),
#   ('최애', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('누군가', 1),
#   ('브런치', 1),
#   ('물어', 1),
#   ('무조건', 1),
#   ('남자친구', 1),
#   ('집', 1),
#   ('아하', 1),
#   ('가격', 1),
#   ('만원', 1),
#   ('카인', 1),
#   ('드', 1),
#   ('두번째', 1),
#   ('수비드', 1),
#   ('계란', 1),
#   ('매콤', 1)],
#  [('메뉴', 4),
#   ('추천', 3),
#   ('포', 3),
#   ('메인', 3),
#   ('외식', 2),
#   ('월남쌈', 2),
#   ('가족', 1),
#   ('만', 1),
#   ('조합', 1),
#   ('해도', 1),
#   ('성공', 1),
#   ('률', 1),
#   ('첫', 1),
#   ('명불허전', 1),
#   ('쌈', 1),
#   ('채소', 1),
#   ('고기', 1),
#   ('더', 1),
#   ('불어', 1),
#   ('닭고기', 1),
#   ('단백질', 1),
#   ('듬뿍', 1),
#   ('섭취', 1),
#   ('수', 1),
#   ('어서', 1),
#   ('성장기', 1),
#   ('아이', 1),
#   ('쌀국수', 1)],
#  [('국물', 4),
#   ('요리', 4),
#   ('메뉴', 4),
#   ('저녁', 3),
#   ('추천', 3),
#   ('차돌', 2),
#   ('육개장', 2),
#   ('신랑', 1),
#   ('워낙', 1),
#   ('아해', 1),
#   ('밥', 1),
#   ('때', 1),
#   ('꼬', 1),
#   ('옥', 1),
#   ('로', 1),
#   ('챙', 1),
#   ('기고', 1),
#   ('더미', 1),
#   ('식', 1),
#   ('상온', 1),
#   ('설렁탕', 1),
#   ('소고기', 1),
#   ('미역국', 1),
#   ('닭개장', 1),
#   ('사골곰탕', 1),
#   ('시크', 1),
#   ('도도', 1),
#   ('토깽', 1),
#   ('살', 1),
#   ('효', 1)],
#  [('메뉴', 2),
#   ('추천', 2),
#   ('한철', 2),
#   ('꽈배기', 2),
#   ('알고리즘', 1),
#   ('주문', 1),
#   ('방법', 1),
#   ('영업', 1),
#   ('시간', 1),
#   ('월부', 1),
#   ('턴', 1),
#   ('월', 1),
#   ('화요일', 1),
#   ('휴무', 1),
#   ('방문', 1),
#   ('참고', 1),
#   ('곳', 1),
#   ('의', 1),
#   ('메뉴판', 1),
#   ('저', 1),
#   ('인', 1),
#   ('백', 1),
#   ('바치', 1),
#   ('토', 1),
#   ('안', 1),
#   ('바질', 1),
#   ('선', 1),
#   ('드라이', 1),
#   ('토마토', 1),
#   ('페퍼로니', 1),
#   ('등', 1),
#   ('어요', 1),
#   ('피자빵', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('하늘', 1)],
#  [('메뉴', 4),
#   ('추천', 3),
#   ('스무디', 2),
#   ('신', 2),
#   ('메', 1),
#   ('커피', 1),
#   ('알바생', 1),
#   ('나주', 1),
#   ('럼', 1),
#   ('코트', 1),
#   ('안', 1),
#   ('제', 1),
#   ('아하', 1),
#   ('메뉴인', 1),
#   ('데', 1),
#   ('기분', 1),
#   ('고요', 1),
#   ('여름', 1),
#   ('더더', 1),
#   ('욱', 1),
#   ('해주', 1),
#   ('셨는데', 1),
#   ('부터', 1),
#   ('하이', 1),
#   ('볼', 1),
#   ('콤부', 1),
#   ('에이드', 1),
#   ('까지', 1),
#   ('비주', 1),
#   ('얼', 1),
#   ('상큼', 1),
#   ('어요', 1),
#   ('주', 1),
#   ('문하', 1),
#   ('자마자', 1)],
#  [('포즈', 7),
#   ('메뉴', 4),
#   ('컴', 3),
#   ('추천', 3),
#   ('와플', 3),
#   ('아이', 2),
#   ('캔디', 2),
#   ('소', 2),
#   ('밀크쉐이크', 2),
#   ('아침', 1),
#   ('간단', 1),
#   ('토마토', 1),
#   ('셋', 1),
#   ('이서', 1),
#   ('수영강', 1),
#   ('산책', 1),
#   ('메뉴판', 1),
#   ('커피', 1),
#   ('안락', 1),
#   ('점', 1),
#   ('내부', 1),
#   ('테이블', 1),
#   ('꽤', 1),
#   ('광안', 1),
#   ('둥이', 1),
#   ('행복', 1),
#   ('일상', 1)],
#  [('파스타', 4),
#   ('목살', 3),
#   ('메뉴', 3),
#   ('쿠', 3),
#   ('티크', 3),
#   ('추천', 2),
#   ('인분', 2),
#   ('트러플', 2),
#   ('고깃집', 1),
#   ('평일', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('육즙', 1),
#   ('가득', 1),
#   ('코쿠미', 1),
#   ('쌀밥', 1),
#   ('개존맛', 1),
#   ('주문', 1),
#   ('삼겹살', 1),
#   ('개', 1),
#   ('강변', 1),
#   ('외할머니', 1),
#   ('된장찌개', 1),
#   ('삼양', 1),
#   ('인증', 1),
#   ('이벤트', 1),
#   ('융', 1),
#   ('여의', 1),
#   ('심심', 1),
#   ('풀이', 1),
#   ('땅콩', 1)],
#  [('롯데리아', 9),
#   ('새우', 5),
#   ('메뉴', 4),
#   ('익스트림', 3),
#   ('레몬', 3),
#   ('크림', 3),
#   ('신', 2),
#   ('점심', 2),
#   ('추천', 2),
#   ('버거', 2),
#   ('햄버거', 2),
#   ('상큼', 1),
#   ('팍', 1),
#   ('음원', 1),
#   ('이벤트', 1),
#   ('푸드', 1),
#   ('섹', 1),
#   ('라이언', 1),
#   ('정보', 1),
#   ('창고', 1)],
#  [('롯데', 3),
#   ('호텔', 3),
#   ('메뉴', 3),
#   ('치킨', 3),
#   ('제주', 2),
#   ('룸서비스', 2),
#   ('추천', 2),
#   ('아이', 1),
#   ('갈비탕', 1),
#   ('첫날', 1),
#   ('수영장', 1),
#   ('주문', 1),
#   ('솔직', 1),
#   ('가격', 1),
#   ('대가', 1),
#   ('어서', 1),
#   ('정독', 1),
#   ('분한', 1),
#   ('거', 1),
#   ('뭐', 1),
#   ('윤아', 1),
#   ('까지', 1),
#   ('먹이', 1),
#   ('면서', 1),
#   ('나', 1),
#   ('누나', 1)],
#  [('포테킹', 4),
#   ('치킨', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('마법', 3),
#   ('후기', 2),
#   ('아하', 2),
#   ('신', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('주문', 1),
#   ('줄', 1),
#   ('요약', 1),
#   ('튀김', 1),
#   ('옷', 1),
#   ('바삭', 1),
#   ('후라이드', 1),
#   ('시', 1),
#   ('분들껜', 1),
#   ('닭강정', 1),
#   ('양념', 1),
#   ('분', 1),
#   ('샤로', 1),
#   ('블로그', 1)],
#  [('찹쌀', 5),
#   ('이유식', 5),
#   ('메뉴', 3),
#   ('추천', 2),
#   ('맛', 1),
#   ('영양', 1),
#   ('유아', 1),
#   ('안성맞춤', 1),
#   ('활용', 1),
#   ('제공', 1),
#   ('수', 1),
#   ('다양', 1),
#   ('첫', 1),
#   ('물', 1),
#   ('우유', 1),
#   ('아이', 1),
#   ('먹기', 1),
#   ('죽', 1),
#   ('박쌤', 1),
#   ('육아', 1),
#   ('로그', 1)],
#  [('찜닭', 6),
#   ('추천', 4),
#   ('메뉴', 3),
#   ('찜', 3),
#   ('말복', 2),
#   ('복날', 2),
#   ('세트', 2),
#   ('슈퍼', 1),
#   ('팝', 1),
#   ('기본', 1),
#   ('가격', 1),
#   ('마리', 1),
#   ('콜라', 1),
#   ('초복', 1),
#   ('중복', 1)],
#  [('롯데리아', 6),
#   ('새우', 6),
#   ('익스트림', 4),
#   ('레몬', 4),
#   ('크림', 4),
#   ('메뉴', 4),
#   ('신', 2),
#   ('점심', 2),
#   ('추천', 2),
#   ('버거', 2),
#   ('햄버거', 2),
#   ('오늘', 1),
#   ('가요', 1),
#   ('남쪽', 1),
#   ('구슬', 1)],
#  [('신촌', 9),
#   ('술집', 6),
#   ('메뉴', 4),
#   ('추천', 3),
#   ('닭볶음탕', 3),
#   ('분위기', 2),
#   ('안주', 2),
#   ('포차', 2),
#   ('판', 1),
#   ('베스트', 1),
#   ('맛집', 1),
#   ('보드카', 1),
#   ('단체', 1),
#   ('보스', 1),
#   ('및', 1),
#   ('주문', 1),
#   ('감자', 1),
#   ('해', 1)],
#  [('부대찌개', 3),
#   ('구래동', 2),
#   ('맛집', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('석기', 2),
#   ('정', 2),
#   ('렌트카', 2),
#   ('김포', 1),
#   ('점심', 1),
#   ('돌솥', 1),
#   ('소', 1),
#   ('곱창', 1),
#   ('유혹', 1),
#   ('첫', 1),
#   ('방문', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('를', 1),
#   ('갤럭시', 1),
#   ('울트라', 1),
#   ('김포시', 1),
#   ('강력', 1),
#   ('이유', 1),
#   ('우선', 1),
#   ('응대', 1),
#   ('친절', 1),
#   ('가격', 1),
#   ('미리', 1),
#   ('오토', 1),
#   ('리스', 1),
#   ('장기', 1),
#   ('수수료', 1)],
#  [('유아식', 4),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('그릇', 2),
#   ('뚝딱', 2),
#   ('만들기', 2),
#   ('구름', 2),
#   ('소고기', 1),
#   ('콩나물밥', 1),
#   ('간편', 1),
#   ('글', 1),
#   ('아기', 1),
#   ('잔치국수', 1),
#   ('닭다리', 1),
#   ('삼계탕', 1),
#   ('솜', 1),
#   ('방', 1)],
#  [('써브웨이', 9),
#   ('메뉴', 5),
#   ('추천', 4),
#   ('서현', 3),
#   ('치킨', 3),
#   ('데리야키', 3),
#   ('치킨데리야끼', 2),
#   ('맛집', 1),
#   ('샌드위치', 1),
#   ('서브웨이', 1),
#   ('건강', 1),
#   ('맛', 1),
#   ('가격', 1),
#   ('분당', 1),
#   ('비만', 1),
#   ('소년', 1),
#   ('밥', 1)],
#  [('추천', 3),
#   ('메뉴', 2),
#   ('어간', 2),
#   ('탕', 2),
#   ('시', 2),
#   ('홍콩', 1),
#   ('맛집', 1),
#   ('남', 1),
#   ('기분', 1),
#   ('무조건', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('돼지', 1),
#   ('고기', 1),
#   ('게', 1),
#   ('고요', 1),
#   ('사우', 1),
#   ('앤', 1),
#   ('스파이', 1),
#   ('실패', 1),
#   ('가게', 1)],
#  [('김밥', 6),
#   ('봉', 5),
#   ('대전', 2),
#   ('맛집', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('가격', 2),
#   ('것', 2),
#   ('국', 2),
#   ('시청', 1),
#   ('친절', 1),
#   ('식사', 1),
#   ('때', 1),
#   ('오후', 1),
#   ('어서', 1),
#   ('간단', 1),
#   ('및', 1),
#   ('기본', 1),
#   ('셋팅', 1),
#   ('셀프', 1),
#   ('바', 1),
#   ('김치', 1),
#   ('단무지', 1),
#   ('배치', 1)],
#  [('점심', 4),
#   ('메뉴', 4),
#   ('음식', 3),
#   ('추천', 3),
#   ('여름', 2),
#   ('회식', 2),
#   ('시원', 2),
#   ('여름철', 2),
#   ('까지', 2),
#   ('콩국수', 2),
#   ('고민', 1),
#   ('해결', 1),
#   ('뿐', 1),
#   ('로', 1),
#   ('오늘', 1),
#   ('보양식', 1),
#   ('부터', 1),
#   ('속', 1),
#   ('추', 1),
#   ('천하', 1),
#   ('한정', 1),
#   ('볼', 1),
#   ('수', 1)],
#  [('끼', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('낙지볶음', 2),
#   ('나', 2),
#   ('대구', 1),
#   ('중구', 1),
#   ('동성로', 1),
#   ('반월당', 1),
#   ('맛집', 1),
#   ('점심', 1),
#   ('저녁', 1),
#   ('식사', 1),
#   ('간', 1),
#   ('친구', 1),
#   ('그냥', 1),
#   ('데', 1),
#   ('매콤', 1),
#   ('더', 1),
#   ('마음', 1),
#   ('좀', 1),
#   ('걸', 1),
#   ('사람', 1),
#   ('쑥', 1)],
#  [('서면', 3),
#   ('국물', 3),
#   ('닭발', 3),
#   ('메뉴', 3),
#   ('유명', 2),
#   ('추천', 2),
#   ('궁극', 2),
#   ('옥탑방', 1),
#   ('두', 1),
#   ('얼간이', 1),
#   ('점', 1),
#   ('부분', 1),
#   ('를', 1),
#   ('집', 1),
#   ('답', 1),
#   ('이', 1),
#   ('가게', 1),
#   ('대표', 1),
#   ('난', 1),
#   ('순두부', 1),
#   ('픽했다', 1),
#   ('마라탕', 1),
#   ('이나', 1),
#   ('전골', 1),
#   ('젠', 1),
#   ('것', 1),
#   ('부터', 1),
#   ('생각', 1),
#   ('날', 1),
#   ('듯', 1),
#   ('어서', 1)],
#  [('블루', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('휘닉스', 2),
#   ('평창', 2),
#   ('푸드코트', 2),
#   ('것', 2),
#   ('강원도', 1),
#   ('워터파크', 1),
#   ('후기', 1),
#   ('봄', 1),
#   ('연회', 1),
#   ('권', 1),
#   ('결과', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('돈까스', 1),
#   ('프리미엄', 1),
#   ('등심', 1),
#   ('카츠', 1),
#   ('무조건', 1),
#   ('기본', 1),
#   ('주말', 1),
#   ('캠핑', 1)],
#  [('링클', 3),
#   ('치킨', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('콤보', 2),
#   ('맛', 2),
#   ('뿌', 1),
#   ('식후감뿌링', 1),
#   ('애', 1),
#   ('입맛', 1),
#   ('비슷', 1),
#   ('치즈', 1),
#   ('가루', 1),
#   ('요즘', 1),
#   ('뭐', 1),
#   ('마라탕', 1),
#   ('탕후루', 1),
#   ('강의', 1),
#   ('중독', 1),
#   ('하니', 1),
#   ('한번', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('리뷰', 1),
#   ('격', 1)],
#  [('메뉴', 3),
#   ('치킨', 2),
#   ('추천', 2),
#   ('링클', 2),
#   ('골드', 1),
#   ('킹', 1),
#   ('콤보', 1),
#   ('뿌', 1),
#   ('세트', 1),
#   ('베스트', 1),
#   ('두마', 1),
#   ('리', 1),
#   ('깁콘', 1),
#   ('어요', 1),
#   ('안', 1),
#   ('초등', 1),
#   ('고학년', 1),
#   ('저학년', 1),
#   ('아이', 1),
#   ('인', 1),
#   ('닭', 1),
#   ('대표', 1),
#   ('추', 1),
#   ('천하', 1),
#   ('이유', 1),
#   ('닝', 1),
#   ('독특', 1),
#   ('뿌링뿌', 1),
#   ('단', 1),
#   ('달달', 1),
#   ('면서', 1),
#   ('짭쪼', 1),
#   ('로미', 1),
#   ('하니', 1),
#   ('치토스', 1),
#   ('타일', 1),
#   ('효로', 1),
#   ('롱', 1),
#   ('푸드', 1),
#   ('로그', 1)],
#  [('예약', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('태국', 1),
#   ('방콕여행', 1),
#   ('왓아룬', 1),
#   ('야경', 1),
#   ('맛집', 1),
#   ('더데', 1),
#   ('다이렉트', 1),
#   ('온라인', 1),
#   ('불가', 1),
#   ('대행', 1),
#   ('업체', 1),
#   ('통해', 1),
#   ('전화', 1),
#   ('는걸', 1),
#   ('운', 1),
#   ('처럼', 1),
#   ('우왕', 1),
#   ('느낌', 1),
#   ('년전', 1),
#   ('땐', 1),
#   ('엘리', 1)],
#  [('버거', 8),
#   ('쉐이크', 6),
#   ('쉑', 5),
#   ('메뉴', 4),
#   ('용산', 3),
#   ('추천', 3),
#   ('가격', 3),
#   ('아이파크몰', 1),
#   ('쉑쉑', 1),
#   ('때', 1),
#   ('감', 1),
#   ('조합', 1),
#   ('보시', 1),
#   ('길', 1)],
#  [('쉬', 3),
#   ('림프', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('치킨', 3),
#   ('너겟', 3),
#   ('괌', 2),
#   ('비치', 2),
#   ('추가', 2),
#   ('마이크로네시아', 1),
#   ('키즈', 1),
#   ('하나', 1),
#   ('더', 1),
#   ('어요', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('마지막', 1),
#   ('까지', 1),
#   ('인', 1),
#   ('코코넛', 1),
#   ('채', 1),
#   ('여행', 1),
#   ('기록', 1)],
#  [('피스타치오', 4),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('테디', 2),
#   ('뵈르', 2),
#   ('하우스', 2),
#   ('여행', 2),
#   ('삼각지', 1),
#   ('카페', 1),
#   ('용산', 1),
#   ('핫', 1),
#   ('크룽', 1),
#   ('등', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('까지', 1),
#   ('소개', 1),
#   ('위치', 1),
#   ('서울시', 1),
#   ('용산구', 1),
#   ('한강대로', 1),
#   ('중', 1),
#   ('하나', 1),
#   ('아이스크림', 1),
#   ('뀐아망', 1),
#   ('일상', 1)],
#  [('메뉴', 3),
#   ('추천', 3),
#   ('동래', 3),
#   ('별장', 3),
#   ('방이동', 3),
#   ('이자카야', 2),
#   ('제주', 2),
#   ('딱새', 2),
#   ('우회', 2),
#   ('맛집', 2),
#   ('숙성', 1),
#   ('회', 1),
#   ('세트', 1),
#   ('덕분', 1),
#   ('저', 1),
#   ('고민', 1),
#   ('로', 1),
#   ('줄', 1),
#   ('리뷰', 1),
#   ('입', 1),
#   ('살살', 1),
#   ('골목', 1),
#   ('한식', 1),
#   ('느낌', 1),
#   ('월드', 1),
#   ('세상', 1)],
#  [('메뉴', 4),
#   ('금별', 3),
#   ('맥주', 3),
#   ('추천', 3),
#   ('태릉', 1),
#   ('입구', 1),
#   ('술집', 1),
#   ('묵', 1),
#   ('동자', 1),
#   ('이점', 1),
#   ('살얼음', 1),
#   ('얼', 1),
#   ('만큼', 1),
#   ('차', 1),
#   ('가운', 1),
#   ('생맥주', 1),
#   ('특색', 1),
#   ('안주', 1),
#   ('가격', 1),
#   ('대도', 1),
#   ('부담', 1),
#   ('요', 1),
#   ('세', 1),
#   ('가지', 1),
#   ('한번', 1),
#   ('조합', 1),
#   ('누구', 1),
#   ('대표', 1),
#   ('로', 1)],
#  [('배곧', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('삼겹살', 2),
#   ('맛집', 2),
#   ('부뚜막', 2),
#   ('때문', 2),
#   ('조합', 2),
#   ('점심', 1),
#   ('조선', 1),
#   ('고기', 1),
#   ('집', 1),
#   ('상', 1),
#   ('소', 1),
#   ('메인', 1),
#   ('고요', 1),
#   ('저희', 1),
#   ('넷', 1),
#   ('쌈무', 1),
#   ('파', 1),
#   ('절임', 1),
#   ('차돌박이', 1),
#   ('흡족', 1),
#   ('맛', 1),
#   ('이기', 1),
#   ('찰나', 1),
#   ('의순', 1),
#   ('간', 1)],
#  [('죽', 4),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('날씨', 2),
#   ('내', 2),
#   ('몸', 2),
#   ('삼계', 1),
#   ('건강', 1),
#   ('끼', 1),
#   ('느낌', 1),
#   ('이유', 1),
#   ('맛', 1),
#   ('나유', 1),
#   ('모든', 1),
#   ('게', 1),
#   ('녹', 1),
#   ('아버', 1),
#   ('릴', 1),
#   ('듯', 1),
#   ('이', 1),
#   ('더위', 1),
#   ('살짝', 1),
#   ('정신', 1),
#   ('제대로', 1),
#   ('거의', 1),
#   ('보신', 1),
#   ('배배공', 1),
#   ('배배', 1),
#   ('배부', 1),
#   ('른', 1),
#   ('공간', 1)],
#  [('트러플', 3),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('풍기', 2),
#   ('피자', 2),
#   ('포장', 2),
#   ('향', 2),
#   ('이비', 2),
#   ('티', 2),
#   ('하남', 1),
#   ('스타', 1),
#   ('필드', 1),
#   ('솔직', 1),
#   ('후기', 1),
#   ('차', 1),
#   ('박스', 1),
#   ('고', 1),
#   ('집', 1),
#   ('서도', 1),
#   ('집안', 1),
#   ('가면', 1),
#   ('꼭', 1),
#   ('감히', 1),
#   ('말', 1),
#   ('평', 1),
#   ('과', 1),
#   ('데', 1),
#   ('일리', 1),
#   ('원스', 1)],
#  [('런치', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('주말', 2),
#   ('가격', 2),
#   ('나', 2),
#   ('아메리카노', 2),
#   ('호텔', 2),
#   ('카페', 1),
#   ('산뜻', 1),
#   ('뷔페', 1),
#   ('맛집', 1),
#   ('사적', 1),
#   ('리뷰', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('평일', 1),
#   ('디너', 1),
#   ('운영', 1),
#   ('출처', 1),
#   ('홈페이지', 1),
#   ('주중', 1),
#   ('도', 1),
#   ('커피', 1),
#   ('한번', 1),
#   ('더', 1),
#   ('라떼', 1),
#   ('정', 1),
#   ('맛', 1),
#   ('어제', 1),
#   ('조금', 1),
#   ('나은', 1),
#   ('내', 1)],
#  [('호우', 3),
#   ('섬', 3),
#   ('메뉴', 3),
#   ('때', 3),
#   ('딤섬', 2),
#   ('추천', 2),
#   ('마다', 2),
#   ('뚜비', 2),
#   ('신세계', 1),
#   ('백화점', 1),
#   ('홍콩', 1),
#   ('음식', 1),
#   ('전문점', 1),
#   ('맛집', 1),
#   ('및', 1),
#   ('가격', 1),
#   ('블랙', 1),
#   ('가우', 1),
#   ('구', 1),
#   ('짜장', 1),
#   ('도삭', 1),
#   ('은', 1),
#   ('필수', 1),
#   ('다섯', 1),
#   ('개', 1),
#   ('향', 1),
#   ('아기', 1),
#   ('새', 1),
#   ('손', 1),
#   ('만', 1),
#   ('족하', 1),
#   ('하루', 1)],
#  [('메뉴', 3),
#   ('세트', 2),
#   ('추천', 2),
#   ('제주', 2),
#   ('공항', 2),
#   ('근처', 2),
#   ('갈치구이', 2),
#   ('만족', 1),
#   ('솔직', 1),
#   ('후기', 1),
#   ('저희', 1),
#   ('자리', 1),
#   ('다양', 1),
#   ('구성', 1),
#   ('눈', 1),
#   ('어서', 1),
#   ('판', 1),
#   ('다가', 1),
#   ('보이', 1),
#   ('다른', 1),
#   ('분', 1),
#   ('만족도', 1),
#   ('식사', 1),
#   ('바', 1),
#   ('라며', 1),
#   ('해', 1),
#   ('갈치', 1),
#   ('음식점', 1),
#   ('궁서체', 1),
#   ('비글', 1),
#   ('맘', 1),
#   ('꼬', 1),
#   ('꼬마', 1),
#   ('아빠', 1),
#   ('육아', 1),
#   ('일상', 1)],
#  [('곱창', 4),
#   ('부글', 3),
#   ('식당', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('사발', 3),
#   ('운', 2),
#   ('양동', 2),
#   ('맛집', 2),
#   ('저희', 1),
#   ('다른', 1),
#   ('어서', 1),
#   ('배달', 1),
#   ('집', 1),
#   ('야식', 1),
#   ('오동', 1),
#   ('통한', 1),
#   ('거', 1),
#   ('보이시', 1),
#   ('요', 1),
#   ('곱', 1),
#   ('가득', 1)],
#  [('소금', 4),
#   ('빵', 4),
#   ('메뉴', 3),
#   ('경주', 2),
#   ('추천', 2),
#   ('소하', 1),
#   ('염전', 1),
#   ('황리', 1),
#   ('길', 1),
#   ('맛집', 1),
#   ('카페', 1),
#   ('전', 1),
#   ('체적', 1),
#   ('베이커리', 1),
#   ('주', 1),
#   ('음료', 1),
#   ('적당', 1),
#   ('주문', 1),
#   ('쪽파', 1),
#   ('나', 1),
#   ('내', 1),
#   ('픽', 1),
#   ('두', 1),
#   ('완전', 1),
#   ('한가지', 1),
#   ('일정', 1),
#   ('끝내', 1),
#   ('집', 1),
#   ('때', 1),
#   ('아람', 1),
#   ('사계절', 1),
#   ('여행', 1),
#   ('일기', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('여행', 2),
#   ('야끼소바', 2),
#   ('우리', 2),
#   ('서울', 1),
#   ('석촌', 1),
#   ('니', 1),
#   ('주마', 1),
#   ('루', 1),
#   ('줄', 1),
#   ('서서', 1),
#   ('기', 1),
#   ('다리', 1),
#   ('다가', 1),
#   ('차례', 1),
#   ('근처', 1),
#   ('미리', 1),
#   ('메뉴판', 1),
#   ('를', 1),
#   ('둘', 1),
#   ('주문', 1),
#   ('보기', 1),
#   ('인', 1),
#   ('소금', 1),
#   ('오징어', 1),
#   ('새우', 1),
#   ('소스', 1),
#   ('치즈', 1),
#   ('비엔나', 1),
#   ('두', 1),
#   ('종류', 1),
#   ('더하기', 1)],
#  [('메뉴', 3),
#   ('에그슬럿', 2),
#   ('추천', 2),
#   ('판교', 1),
#   ('맛집', 1),
#   ('분당', 1),
#   ('정자', 1),
#   ('오픈', 1),
#   ('원픽', 1),
#   ('저', 1),
#   ('프리타타', 1),
#   ('신선', 1),
#   ('하니', 1),
#   ('고요', 1),
#   ('신상', 1),
#   ('핫', 1),
#   ('아하', 1),
#   ('스타', 1),
#   ('다양', 1),
#   ('선', 1),
#   ('보이', 1),
#   ('대표', 1),
#   ('육류', 1),
#   ('앵거스', 1),
#   ('비프', 1),
#   ('패티', 1),
#   ('애플', 1),
#   ('우드', 1),
#   ('훈제', 1),
#   ('베이컨', 1)],
#  [('메뉴', 7),
#   ('쌤쌤쌤', 4),
#   ('추천', 4),
#   ('웨이', 3),
#   ('팅', 3),
#   ('맛집', 2),
#   ('용산', 1),
#   ('브런치', 1),
#   ('예약', 1),
#   ('날', 1),
#   ('이지', 1),
#   ('실내', 1),
#   ('꽉', 1),
#   ('차고', 1),
#   ('별', 1),
#   ('표시', 1),
#   ('기', 1),
#   ('다리', 1),
#   ('동안', 1),
#   ('요', 1),
#   ('청하면', 1),
#   ('미리', 1),
#   ('볼', 1),
#   ('수', 1),
#   ('어요', 1),
#   ('별표', 1),
#   ('시', 1),
#   ('주우', 1)],
#  [('추천', 3),
#   ('세부', 2),
#   ('맛집', 2),
#   ('번', 2),
#   ('오', 2),
#   ('이스터', 2),
#   ('베이', 2),
#   ('메뉴', 2),
#   ('비글', 2),
#   ('방문', 1),
#   ('까지', 1),
#   ('콕', 1),
#   ('찝어드', 1),
#   ('리도', 1),
#   ('록', 1),
#   ('욧', 1),
#   ('메뉴판', 1),
#   ('사진', 1),
#   ('주의', 1),
#   ('씨', 1),
#   ('푸드', 1),
#   ('레스토랑', 1),
#   ('아보', 1),
#   ('신', 1),
#   ('분', 1),
#   ('라면', 1),
#   ('곳', 1),
#   ('한국', 1),
#   ('수', 1),
#   ('알리', 1),
#   ('망오', 1),
#   ('하루', 1)],
#  [('추천', 3),
#   ('팝업', 2),
#   ('브', 2),
#   ('레디', 2),
#   ('포스트', 2),
#   ('메뉴', 2),
#   ('베이컨', 2),
#   ('부추', 2),
#   ('토마', 2),
#   ('콘', 2),
#   ('더', 1),
#   ('현대', 1),
#   ('서울', 1),
#   ('스토어', 1),
#   ('진지희', 1),
#   ('프레첼', 1),
#   ('쥰', 1),
#   ('대장', 1),
#   ('초콜렛', 1),
#   ('씨앗', 1),
#   ('호떡', 1),
#   ('갠', 1),
#   ('완전', 1),
#   ('강추', 1),
#   ('방문', 1),
#   ('꼭', 1),
#   ('한번', 1),
#   ('맛', 1),
#   ('보시', 1),
#   ('길', 1)],
#  [('메뉴', 4),
#   ('해룡', 3),
#   ('왕', 3),
#   ('푸드', 2),
#   ('맛집', 2),
#   ('추천', 2),
#   ('마사지', 2),
#   ('사', 2),
#   ('장님', 2),
#   ('번', 1),
#   ('여행', 1),
#   ('내', 1),
#   ('인정', 1),
#   ('씨', 1),
#   ('보라카이', 1),
#   ('소개', 1),
#   ('도', 1),
#   ('해', 1),
#   ('주', 1),
#   ('시더', 1),
#   ('요', 1),
#   ('확인', 1),
#   ('한국인', 1),
#   ('마음', 1),
#   ('면서', 1),
#   ('하루', 1)],
#  [('메뉴', 3),
#   ('추천', 3),
#   ('팬케이크', 2),
#   ('에그베네딕트', 2),
#   ('판교', 1),
#   ('오리', 1),
#   ('널', 1),
#   ('하우스', 1),
#   ('후기', 1),
#   ('주말', 1),
#   ('오픈', 1),
#   ('런', 1),
#   ('장', 1),
#   ('과일', 1),
#   ('토핑', 1),
#   ('걸', 1),
#   ('주문', 1),
#   ('하나', 1),
#   ('어요', 1),
#   ('포테이토', 1),
#   ('다가', 1),
#   ('결론', 1),
#   ('적', 1),
#   ('즐거움', 1),
#   ('블로그', 1)],
#  [('영', 3),
#   ('커피', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('식후떼', 2),
#   ('정자동', 1),
#   ('저', 1),
#   ('처럼', 1),
#   ('처음', 1),
#   ('오신', 1),
#   ('면', 1),
#   ('베스트', 1),
#   ('요', 1),
#   ('아메리카노', 1),
#   ('가격', 1),
#   ('여름', 1),
#   ('마시기', 1),
#   ('수박', 1),
#   ('주스', 1),
#   ('맛', 1),
#   ('식혜', 1),
#   ('어요', 1),
#   ('고', 1),
#   ('아침', 1),
#   ('식사', 1),
#   ('대용', 1),
#   ('여행가', 1),
#   ('세라', 1),
#   ('여행', 1),
#   ('블로그', 1)],
#  [('추천', 3),
#   ('안주', 3),
#   ('맥주', 2),
#   ('메뉴', 2),
#   ('곳', 2),
#   ('금별', 1),
#   ('메뉴판', 1),
#   ('가득', 1),
#   ('라면', 1),
#   ('간단', 1),
#   ('한잔', 1),
#   ('만하', 1),
#   ('소주', 1),
#   ('튀김', 1),
#   ('국물', 1),
#   ('양하', 1),
#   ('어서', 1),
#   ('손님', 1),
#   ('별', 1),
#   ('여행', 1),
#   ('주식회사', 1)],
#  [('맛집', 2),
#   ('홍콩', 2),
#   ('인기', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('용산', 1),
#   ('로스트', 1),
#   ('해주', 1),
#   ('오랜만', 1),
#   ('친구', 1),
#   ('약속', 1),
#   ('기분', 1),
#   ('어요', 1),
#   ('잠깐', 1),
#   ('동안', 1),
#   ('현지', 1),
#   ('음식', 1),
#   ('느낌', 1),
#   ('어서', 1),
#   ('여행', 1),
#   ('온', 1),
#   ('수험', 1),
#   ('중', 1)],
#  [('메뉴', 4),
#   ('타이', 4),
#   ('추천', 3),
#   ('쌀국수', 3),
#   ('가격', 2),
#   ('아기', 2),
#   ('타이가', 2),
#   ('격', 2),
#   ('똠얌', 2),
#   ('후기', 1),
#   ('위치', 1),
#   ('가기', 1),
#   ('맛집', 1),
#   ('의자', 1),
#   ('콘', 1),
#   ('위례', 1),
#   ('스타', 1),
#   ('필드', 1),
#   ('점', 1),
#   ('톰얌', 1),
#   ('팟', 1),
#   ('씨유', 1),
#   ('새우볶음', 1),
#   ('밥', 1),
#   ('이', 1),
#   ('날', 1),
#   ('위례콘', 1),
#   ('복', 1),
#   ('편살', 1),
#   ('단디', 1),
#   ('맘', 1)],
#  [('텐동', 5),
#   ('부평', 4),
#   ('메뉴', 4),
#   ('맛집', 4),
#   ('점심', 3),
#   ('데이트', 3),
#   ('추천', 3),
#   ('저스트', 2),
#   ('평리', 2),
#   ('영화', 2),
#   ('냉', 2),
#   ('우동', 2),
#   ('안녕', 1),
#   ('욧', 1),
#   ('최근', 1),
#   ('개봉', 1),
#   ('밀수', 1),
#   ('시장', 1),
#   ('일상', 1),
#   ('주차장', 1),
#   ('리얀', 1),
#   ('기억', 1),
#   ('저장', 1),
#   ('소', 1)],
#  [('메뉴', 4),
#   ('가지', 4),
#   ('딤섬', 3),
#   ('추천', 3),
#   ('수원', 2),
#   ('맛집', 2),
#   ('티엔', 2),
#   ('바오', 2),
#   ('새우', 2),
#   ('광교', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('겉바', 1),
#   ('촉', 1),
#   ('어간', 1),
#   ('제', 1),
#   ('원픽', 1),
#   ('식감', 1),
#   ('조합', 1),
#   ('박력', 1)],
#  [('브런치', 3),
#   ('메뉴', 3),
#   ('층', 3),
#   ('빈', 2),
#   ('추천', 2),
#   ('파스타', 2),
#   ('당산', 1),
#   ('후기', 1),
#   ('주차', 1),
#   ('수', 1),
#   ('손님', 1),
#   ('다음', 1),
#   ('혼자', 1),
#   ('커피', 1),
#   ('최고', 1),
#   ('스파이스', 1),
#   ('쉬', 1),
#   ('림프', 1),
#   ('이', 1),
#   ('진짜', 1),
#   ('인기', 1),
#   ('리조또', 1),
#   ('어차피', 1),
#   ('미쯔루', 1),
#   ('이야기', 1)],
#  [('메뉴', 3),
#   ('내', 2),
#   ('살', 2),
#   ('만공', 2),
#   ('격', 2),
#   ('추천', 2),
#   ('와사비', 2),
#   ('무난', 2),
#   ('기준', 1),
#   ('를', 1),
#   ('거', 1),
#   ('강', 1),
#   ('추하', 1),
#   ('크림', 1),
#   ('것', 1),
#   ('선택', 1),
#   ('주문', 1),
#   ('세', 1),
#   ('가지', 1),
#   ('중', 1),
#   ('하나', 1),
#   ('그냥', 1),
#   ('이름', 1),
#   ('어가', 1),
#   ('어서', 1),
#   ('좀', 1),
#   ('더', 1),
#   ('강렬', 1),
#   ('맛', 1)],
#  [('커피', 3),
#   ('메뉴', 3),
#   ('리터', 2),
#   ('백억', 2),
#   ('추천', 2),
#   ('동묘앞역', 1),
#   ('점', 1),
#   ('완전', 1),
#   ('빨', 1),
#   ('제', 1),
#   ('주문', 1),
#   ('수', 1),
#   ('아메리카노', 1),
#   ('캬라멜', 1),
#   ('팝콘', 1),
#   ('고', 1),
#   ('요즘', 1),
#   ('칸', 1),
#   ('슈', 1),
#   ('크로칸슈', 1),
#   ('오', 1),
#   ('자마자', 1),
#   ('바로', 1),
#   ('냉동', 1),
#   ('에프', 1),
#   ('살짝', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('대전', 2),
#   ('역', 2),
#   ('성심당', 2),
#   ('부추', 2),
#   ('빵', 2),
#   ('튀김', 2),
#   ('소보', 2),
#   ('중', 2),
#   ('위치', 1),
#   ('가격', 1),
#   ('그', 1),
#   ('서도', 1),
#   ('필수', 1),
#   ('이야기', 1),
#   ('본점', 1),
#   ('사람', 1),
#   ('것', 1),
#   ('어요', 1),
#   ('걸', 1),
#   ('보고', 1),
#   ('분', 1),
#   ('보시', 1),
#   ('사나', 1),
#   ('여행', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('런던', 2),
#   ('베이글', 2),
#   ('뮤지', 2),
#   ('엄', 2),
#   ('치즈', 2),
#   ('여행', 2),
#   ('도산', 1),
#   ('주말', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('후기', 1),
#   ('식사', 1),
#   ('대용', 1),
#   ('보이', 1),
#   ('베스트', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('꿀', 1),
#   ('브릭레인', 1),
#   ('저', 1),
#   ('완전', 1),
#   ('일상', 1)],
#  [('런던', 3),
#   ('베이글', 3),
#   ('메뉴', 3),
#   ('뮤지', 2),
#   ('엄', 2),
#   ('추천', 2),
#   ('향', 2),
#   ('안국', 1),
#   ('평일', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('포장', 1),
#   ('집', 1),
#   ('고고', 1),
#   ('참고', 1),
#   ('현대', 1),
#   ('계동', 1),
#   ('사옥', 1),
#   ('주', 1),
#   ('차비', 1),
#   ('천원', 1),
#   ('얼그레이', 1),
#   ('진해', 1),
#   ('브릭레인', 1),
#   ('샌드위치', 1),
#   ('뮤', 1),
#   ('지엄', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('문', 1),
#   ('나', 1),
#   ('서면', 1),
#   ('여행', 1),
#   ('시작', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('유후인', 2),
#   ('코', 2),
#   ('하루', 2),
#   ('우동', 2),
#   ('여행', 2),
#   ('식당', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('맛', 1),
#   ('수', 1),
#   ('맛집', 1),
#   ('안녕', 1),
#   ('후쿠오카', 1),
#   ('빠', 1),
#   ('지지', 1),
#   ('대충', 1),
#   ('뭐', 1),
#   ('보고', 1),
#   ('검색', 1),
#   ('기보', 1),
# ...
#   ('결과', 1),
#   ('해', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('알리오', 1),
#   ('리오', 1),
#   ('스파이', 1),
#   ('김치볶음밥', 1),
#   ('클래식', 1),
#   ('플래터', 1),
#   ('콥', 1),
#   ('샐러드', 1),
#   ('전라도', 1),
#   ('여행자', 1)],
#  [('김밥', 8),
#   ('맛집', 4),
#   ('메뉴', 3),
#   ('뚠뚠', 2),
#   ('분당', 2),
#   ('추천', 2),
#   ('주문', 2),
#   ('쫄면', 2),
#   ('점', 1),
#   ('위치', 1),
#   ('정기', 1),
#   ('휴무', 1),
#   ('전화', 1),
#   ('배민', 1),
#   ('포장', 1),
#   ('가능', 1),
#   ('답니', 1),
#   ('가격', 1),
#   ('수내역', 1),
#   ('묵은지', 1),
#   ('밥물', 1),
#   ('내', 1),
#   ('수내동', 1),
#   ('복', 1),
#   ('편살', 1),
#   ('단디', 1),
#   ('맘', 1)],
#  [('버거', 8),
#   ('도스', 6),
#   ('메뉴', 4),
#   ('추천', 3),
#   ('괌', 2),
#   ('햄버거', 2),
#   ('맛집', 1),
#   ('할인', 1),
#   ('방법', 1),
#   ('새우', 1),
#   ('패티', 1),
#   ('걸', 1),
#   ('쉬', 1),
#   ('림프', 1),
#   ('감자튀김', 1),
#   ('대표', 1),
#   ('괌도', 1),
#   ('스', 1),
#   ('주차장', 1),
#   ('호점', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('맛집', 2),
#   ('강추', 2),
#   ('피쉬', 1),
#   ('맨', 1),
#   ('이나연', 1),
#   ('커플', 1),
#   ('공유', 1),
#   ('최종', 1),
#   ('정리', 1),
#   ('계단', 1),
#   ('사시미', 1),
#   ('필수', 1),
#   ('양', 1),
#   ('케이크', 1),
#   ('모양', 1),
#   ('감자', 1),
#   ('고기', 1),
#   ('진짜', 1),
#   ('푸딩', 1),
#   ('생각', 1),
#   ('흑설탕', 1),
#   ('맛', 1),
#   ('강', 1),
#   ('조금', 1),
#   ('아쉬움', 1),
#   ('전', 1),
#   ('체적', 1),
#   ('헤롱', 1),
#   ('이의', 1),
#   ('여행', 1),
#   ('나눔', 1)],
#  [('메뉴', 3),
#   ('추천', 2),
#   ('매콤', 2),
#   ('맛', 2),
#   ('지지', 1),
#   ('가격', 1),
#   ('대구', 1),
#   ('동천동', 1),
#   ('맛집', 1),
#   ('성비', 1),
#   ('굿', 1),
#   ('먹기', 1),
#   ('토핑', 1),
#   ('분모', 1),
#   ('자', 1),
#   ('콘치', 1),
#   ('모든', 1),
#   ('기', 1),
#   ('본적', 1),
#   ('때문', 1),
#   ('기본', 1),
#   ('주문', 1),
#   ('해도', 1),
#   ('아하', 1),
#   ('우리', 1),
#   ('중간', 1),
#   ('선택', 1),
#   ('그', 1),
#   ('외', 1),
#   ('사진', 1),
#   ('적당', 1),
#   ('리듬', 1)],
#  [('런던', 4),
#   ('베이글', 4),
#   ('안국', 3),
#   ('뮤지', 3),
#   ('엄', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('후기', 3),
#   ('및', 2),
#   ('주말', 2),
#   ('웨이', 2),
#   ('팅', 2),
#   ('안녕', 1),
#   ('걸', 1),
#   ('최대한', 1),
#   ('어요', 1),
#   ('크림', 1),
#   ('치즈', 1),
#   ('종류', 1),
#   ('꽤', 1),
#   ('다양', 1)],
#  [('도미노피자', 4),
#   ('추천', 3),
#   ('메뉴', 2),
#   ('베이컨', 2),
#   ('체다', 2),
#   ('치즈', 2),
#   ('피자', 2),
#   ('제일', 1),
#   ('맛', 1),
#   ('날로', 1),
#   ('주의', 1),
#   ('꺄항', 1),
#   ('짐', 1),
#   ('디너', 1),
#   ('어른', 1),
#   ('맥주', 1),
#   ('애', 1),
#   ('콜라', 1),
#   ('만족', 1),
#   ('식사', 1),
#   ('배달', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('리뷰', 1),
#   ('맛집', 1)],
#  [('차이나타운', 4),
#   ('맛집', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('방콕', 3),
#   ('해산물', 2),
#   ('게', 1),
#   ('가득', 1),
#   ('파이', 1),
#   ('별', 1),
#   ('개', 1),
#   ('모험심', 1),
#   ('강하', 1),
#   ('신', 1),
#   ('한국인', 1),
#   ('분', 1),
#   ('다른', 1),
#   ('어보', 1),
#   ('길', 1),
#   ('드', 1),
#   ('린다', 1),
#   ('니니', 1),
#   ('여행', 1),
#   ('이야기', 1)],
#  [('카츠', 4),
#   ('탄탄', 4),
#   ('점심', 3),
#   ('파스타', 3),
#   ('춘천', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('돈까스', 2),
#   ('오늘', 1),
#   ('방학', 1),
#   ('중인', 1),
#   ('첫째', 1),
#   ('어요', 1),
#   ('갑자기', 1),
#   ('멀리', 1),
#   ('못', 1),
#   ('집', 1),
#   ('주변', 1),
#   ('윰슐랭', 1),
#   ('가이드', 1)],
#  [('치킨', 4),
#   ('메뉴', 4),
#   ('추천', 3),
#   ('맛초킹', 3),
#   ('골드', 2),
#   ('킹', 2),
#   ('사이드', 2),
#   ('프랜차이즈', 2),
#   ('뿌링소떡', 1),
#   ('항상', 1),
#   ('먼저', 1),
#   ('언급', 1),
#   ('강력', 1),
#   ('지금', 1),
#   ('까지', 1),
#   ('위', 1),
#   ('외', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('솔직', 1),
#   ('후기', 1),
#   ('감사', 1)],
#  [('적', 3),
#   ('우동', 3),
#   ('요미', 3),
#   ('교자', 3),
#   ('연남', 3),
#   ('점', 3),
#   ('메뉴', 3),
#   ('이색', 2),
#   ('맛집', 2),
#   ('추천', 2),
#   ('돈교', 2),
#   ('자', 2),
#   ('돈', 1),
#   ('주소', 1),
#   ('서울', 1),
#   ('마포구', 1),
#   ('교', 1),
#   ('요기', 1),
#   ('대표', 1),
#   ('요', 1),
#   ('간판', 1),
#   ('어가', 1),
#   ('드', 1),
#   ('시더', 1),
#   ('주문', 1),
#   ('중국어', 1),
#   ('손쌤', 1),
#   ('블로그', 1)],
#  [('추천', 3),
#   ('메뉴', 3),
#   ('맛집', 2),
#   ('도', 2),
#   ('신용산', 1),
#   ('아모레퍼시픽', 1),
#   ('근처', 1),
#   ('화양연화', 1),
#   ('공유', 1),
#   ('귀띔', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('저희', 1),
#   ('이태원', 1),
#   ('쪽', 1),
#   ('데이트', 1),
#   ('다가', 1),
#   ('산책', 1),
#   ('겸', 1),
#   ('이', 1),
#   ('역시', 1),
#   ('양념', 1),
#   ('상태', 1),
#   ('모습', 1),
#   ('더', 1),
#   ('먹음', 1),
#   ('직스', 1),
#   ('러워', 1),
#   ('고', 1),
#   ('진짜', 1),
#   ('강력', 1),
#   ('솔직', 1),
#   ('여자', 1),
#   ('미쁘미', 1),
#   ('여행', 1)],
#  [('예약', 4),
#   ('위스키', 3),
#   ('추천', 3),
#   ('카발', 2),
#   ('란', 2),
#   ('바', 2),
#   ('메뉴', 2),
#   ('방법', 2),
#   ('방문', 2),
#   ('대만', 1),
#   ('저', 1),
#   ('워낙', 1),
#   ('인기', 1),
#   ('곳', 1),
#   ('종', 1),
#   ('세트', 1),
#   ('오크', 1),
#   ('통', 1),
#   ('샘플러', 1),
#   ('트래블', 1),
#   ('리콘', 1),
#   ('지니', 1)],
#  [('만두', 9),
#   ('추천', 3),
#   ('갈비', 3),
#   ('명인', 2),
#   ('메뉴', 2),
#   ('순천', 1),
#   ('분식', 1),
#   ('새벽', 1),
#   ('영업', 1),
#   ('종류', 1),
#   ('다양', 1),
#   ('밥집', 1),
#   ('해', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('주문', 1),
#   ('어요', 1),
#   ('먹기', 1),
#   ('사이즈', 1),
#   ('개', 1),
#   ('스누미', 1),
#   ('일기장', 1)],
#  [('치', 4),
#   ('문정동', 3),
#   ('카페', 3),
#   ('커피', 3),
#   ('이', 3),
#   ('컴퍼니', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('집', 1),
#   ('근처', 1),
#   ('시절', 1),
#   ('자주', 1),
#   ('리뉴얼', 1),
#   ('한번', 1),
#   ('외부', 1),
#   ('부터', 1)],
#  [('돼지', 4),
#   ('꼬리', 3),
#   ('족발', 2),
#   ('야식', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('간단', 2),
#   ('때', 2),
#   ('혼', 2),
#   ('술안주', 2),
#   ('꼬', 1),
#   ('리치', 1),
#   ('남자', 1),
#   ('한안', 1),
#   ('주', 1),
#   ('껍데기', 1),
#   ('지방', 1),
#   ('살코기', 1),
#   ('쟁여놓', 1),
#   ('생각', 1),
#   ('날', 1),
#   ('마다', 1),
#   ('캠핑', 1),
#   ('요리', 1),
#   ('강추', 1),
#   ('저', 1),
#   ('건강', 1),
#   ('리뷰', 1),
#   ('뚜', 1),
#   ('런', 1),
#   ('로그', 1)],
#  [('새우', 5),
#   ('롯데리아', 4),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('익스트림', 2),
#   ('레몬', 2),
#   ('크림', 2),
#   ('돈', 2),
#   ('산', 2),
#   ('버거', 2),
#   ('팔랑', 2),
#   ('후기', 1),
#   ('생각', 1),
#   ('어간', 1),
#   ('신', 1),
#   ('고요', 1),
#   ('아하', 1),
#   ('분', 1),
#   ('라면', 1),
#   ('귀가', 1),
#   ('낭', 1),
#   ('주부', 1),
#   ('이야기', 1)],
#  [('스타벅스', 8),
#   ('메뉴', 6),
#   ('추천', 4),
#   ('신', 3),
#   ('콜드', 3),
#   ('브루', 3),
#   ('푸딩', 3),
#   ('블렌디드', 3),
#   ('위드', 2),
#   ('시원', 1),
#   ('당', 1),
#   ('충전', 1),
#   ('바닐라', 1),
#   ('빈', 1),
#   ('쉐이크', 1),
#   ('여름', 1),
#   ('일상', 1),
#   ('이야기', 1),
#   ('중', 1)],
#  [('메뉴', 4),
#   ('언양', 2),
#   ('불고기', 2),
#   ('추천', 2),
#   ('고기', 2),
#   ('울산', 1),
#   ('맛집', 1),
#   ('주차', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('소개', 1),
#   ('돌솥', 1),
#   ('정식', 1),
#   ('여기', 1),
#   ('진심', 1),
#   ('바로', 1),
#   ('입구', 1),
#   ('정육', 1),
#   ('공간', 1),
#   ('고요', 1),
#   ('거기', 1),
#   ('옆', 1),
#   ('테이블', 1),
#   ('생', 1),
#   ('마블링', 1),
#   ('정말', 1),
#   ('예술', 1),
#   ('어요', 1),
#   ('저', 1),
#   ('뇸뇸', 1),
#   ('박사', 1)],
#  [('메뉴', 3),
#   ('데블', 2),
#   ('스', 2),
#   ('도어', 2),
#   ('추천', 2),
#   ('샐러드', 2),
#   ('맥주', 2),
#   ('안주', 2),
#   ('매우', 2),
#   ('코엑스', 1),
#   ('맛집', 1),
#   ('중', 1),
#   ('내', 1),
#   ('픽', 1),
#   ('세', 1),
#   ('가지', 1),
#   ('멕시칸', 1),
#   ('시저', 1),
#   ('입맛', 1),
#   ('페퍼로니', 1),
#   ('크림', 1),
#   ('피자', 1),
#   ('굿', 1),
#   ('프라이드', 1),
#   ('라마', 1),
#   ('리', 1),
#   ('굿굿', 1),
#   ('실패', 1),
#   ('먹기', 1),
#   ('일상', 1),
#   ('탐험', 1),
#   ('쓔', 1),
#   ('로그', 1)],
#  [('메뉴', 3),
#   ('교촌치킨', 2),
#   ('추천', 2),
#   ('교촌', 2),
#   ('오리', 2),
#   ('날', 2),
#   ('맛', 2),
#   ('치킨', 2),
#   ('희재', 2),
#   ('대체', 1),
#   ('불가', 1),
#   ('치즈볼', 1),
#   ('역시', 1),
#   ('인생', 1),
#   ('음식', 1),
#   ('즐거움', 1),
#   ('그', 1),
#   ('무엇', 1),
#   ('과도', 1),
#   ('한국인', 1),
#   ('가장', 1),
#   ('사랑', 1),
#   ('이자', 1),
#   ('맥주', 1),
#   ('단짝', 1),
#   ('아하', 1),
#   ('시', 1),
#   ('가족', 1),
#   ('모두', 1),
#   ('아해', 1),
#   ('일주일', 1),
#   ('맘', 1),
#   ('꼬', 1),
#   ('추억', 1)],
#  [('치킨', 3),
#   ('추천', 3),
#   ('땅땅', 3),
#   ('메뉴', 3),
#   ('불', 2),
#   ('갈비', 2),
#   ('후왕', 1),
#   ('세트', 1),
#   ('땅땅치킨', 1),
#   ('선부점', 1),
#   ('사실', 1),
#   ('야외', 1),
#   ('로', 1),
#   ('등', 1),
#   ('극시', 1),
#   ('킬', 1),
#   ('수', 1),
#   ('실내', 1),
#   ('분위기', 1),
#   ('파스텔', 1),
#   ('동화', 1),
#   ('다음', 1),
#   ('뭐', 1),
#   ('치밥', 1),
#   ('냉장고', 1),
#   ('찬밥', 1),
#   ('공기', 1),
#   ('제이원', 1),
#   ('제이', 1)],
#  [('투썸플레이스', 4),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('양재', 1),
#   ('카페', 1),
#   ('오늘', 1),
#   ('식사', 1),
#   ('대용', 1),
#   ('를', 1),
#   ('소개', 1),
#   ('포이', 1),
#   ('점', 1),
#   ('양재천', 1),
#   ('뷰', 1),
#   ('주차', 1),
#   ('까지', 1),
#   ('가능', 1),
#   ('요', 1),
#   ('주차장', 1),
#   ('이용', 1),
#   ('안내', 1),
#   ('영수증', 1),
#   ('장', 1),
#   ('서울', 1),
#   ('언니', 1)],
#  [('고추장', 2),
#   ('제육볶음', 2),
#   ('오늘', 2),
#   ('저녁', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('수', 2),
#   ('때', 2),
#   ('레시피', 1),
#   ('요리', 1),
#   ('맛', 1),
#   ('보장', 1),
#   ('양념장', 1),
#   ('바로', 1),
#   ('까지', 1),
#   ('사실', 1),
#   ('진짜', 1),
#   ('대패', 1),
#   ('삼겹살', 1),
#   ('쌈', 1),
#   ('즐', 1),
#   ('기면', 1),
#   ('끼', 1),
#   ('기름', 1),
#   ('충분', 1),
#   ('축복', 1),
#   ('유전자', 1),
#   ('완소', 1),
#   ('남매', 1),
#   ('엄마', 1),
#   ('표', 1),
#   ('먹거리', 1)],
#  [('족발', 5),
#   ('메뉴', 4),
#   ('사리역', 2),
#   ('근처', 2),
#   ('추천', 2),
#   ('안산', 1),
#   ('사동', 1),
#   ('맛집', 1),
#   ('배달', 1),
#   ('보쌈', 1),
#   ('주', 1),
#   ('고', 1),
#   ('술', 1),
#   ('한잔', 1),
#   ('면서', 1),
#   ('수', 1),
#   ('사이드', 1),
#   ('준비', 1),
#   ('드립', 1),
#   ('오늘', 1),
#   ('완미', 1),
#   ('집중', 1),
#   ('편이', 1),
#   ('피', 1),
#   ('브이', 1)],
#  [('우동', 4),
#   ('레시피', 3),
#   ('점심', 3),
#   ('메뉴', 3),
#   ('냉', 2),
#   ('만들기', 2),
#   ('주말', 2),
#   ('추천', 2),
#   ('소스', 1),
#   ('육수', 1),
#   ('여름', 1),
#   ('시원', 1),
#   ('장마', 1),
#   ('더니', 1),
#   ('요즘', 1),
#   ('정말', 1),
#   ('고요', 1),
#   ('간단', 1),
#   ('고', 1),
#   ('민하', 1),
#   ('다가', 1),
#   ('얼음', 1),
#   ('동동', 1),
#   ('냉동', 1),
#   ('돈까스', 1),
#   ('에어', 1),
#   ('프라이어', 1),
#   ('버전', 1),
#   ('의후다닥', 1)],
#  [('아침식사', 3),
#   ('메뉴', 3),
#   ('어니언', 2),
#   ('버섯', 2),
#   ('스프', 2),
#   ('추천', 2),
#   ('아침', 2),
#   ('만들기', 1),
#   ('로', 1),
#   ('레시피', 1),
#   ('저희', 1),
#   ('집', 1),
#   ('초등학생', 1),
#   ('둘', 1),
#   ('어요', 1),
#   ('어른', 1),
#   ('아이', 1),
#   ('더', 1),
#   ('입맛', 1),
#   ('때', 1),
#   ('빵', 1),
#   ('조각', 1),
#   ('그릇', 1),
#   ('이면', 1),
#   ('호로', 1),
#   ('록', 1),
#   ('기분', 1),
#   ('행복', 1),
#   ('날로', 1),
#   ('캐리', 1),
#   ('정', 1),
#   ('블로그', 1)],
#  [('맛집', 3),
#   ('메뉴', 3),
#   ('부산', 2),
#   ('영도', 2),
#   ('점심', 2),
#   ('수제', 2),
#   ('버거', 2),
#   ('햄최몇', 2),
#   ('추천', 2),
#   ('층', 2),
#   ('현지', 1),
#   ('주차장', 1),
#   ('건물', 1),
#   ('가능', 1),
#   ('위치', 1),
#   ('어서', 1),
#   ('계단', 1),
#   ('이용', 1),
#   ('라가', 1),
#   ('한정', 1),
#   ('부터', 1),
#   ('판매', 1),
#   ('위', 1),
#   ('사장', 1),
#   ('러블리썬', 1),
#   ('여행', 1),
#   ('날', 1)],
#  [('쫄면', 8),
#   ('양념장', 3),
#   ('만들기', 2),
#   ('백종원', 2),
#   ('양념', 2),
#   ('재료', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('요리', 1),
#   ('여름', 1),
#   ('분식', 1),
#   ('리하', 1),
#   ('학창시절', 1),
#   ('부터', 1),
#   ('콤', 1),
#   ('고추장', 1),
#   ('면서', 1),
#   ('쫄깃쫄깃', 1),
#   ('면발', 1),
#   ('야채', 1),
#   ('식감', 1),
#   ('아토피', 1),
#   ('집밥', 1),
#   ('휴식', 1),
#   ('여행', 1),
#   ('일기', 1),
#   ('사랑', 1),
#   ('김수미', 1)],
#  [('포시즌스', 7),
#   ('마루', 6),
#   ('메뉴', 6),
#   ('호텔', 4),
#   ('추천', 3),
#   ('광화문', 1),
#   ('및', 1),
#   ('솔직', 1),
#   ('후기', 1),
#   ('울', 1),
#   ('식사', 1),
#   ('준비', 1),
#   ('가격', 1),
#   ('갈비', 1),
#   ('샌드위치', 1)],
#  [('메뉴', 2),
#   ('추천', 2),
#   ('버터', 2),
#   ('오징어', 2),
#   ('냄새', 2),
#   ('서울역', 1),
#   ('만리', 1),
#   ('브런치', 1),
#   ('양식', 1),
#   ('레스토랑', 1),
#   ('콤', 1),
#   ('바크', 1),
#   ('카페', 1),
#   ('가게', 1),
#   ('때', 1),
#   ('부터', 1),
#   ('뭔가', 1),
#   ('그', 1),
#   ('영화관', 1),
#   ('구이', 1),
#   ('파스타', 1),
#   ('면도', 1),
#   ('생각', 1),
#   ('거', 1),
#   ('꼭', 1),
#   ('재', 1),
#   ('방문', 1),
#   ('해도', 1),
#   ('재주', 1),
#   ('문', 1),
#   ('유지', 1),
#   ('어터', 1),
#   ('일상', 1)],
#  [('베스킨라빈스', 5),
#   ('메뉴', 5),
#   ('추천', 3),
#   ('가격', 2),
#   ('케이크', 2),
#   ('종류', 2),
#   ('영업', 1),
#   ('시간', 1),
#   ('베', 1),
#   ('맛', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('슈팅', 1),
#   ('스타', 1),
#   ('체리', 1),
#   ('쥬빌레', 1),
#   ('엄', 1),
#   ('마는', 1),
#   ('외계인', 1),
#   ('레인보우', 1),
#   ('샤베트', 1),
#   ('방랑', 1),
#   ('고', 1),
#   ('그날', 1),
#   ('기', 1),
#   ('다리', 1)],
#  [('돈가츠', 4),
#   ('미사', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('바삭', 2),
#   ('하남', 1),
#   ('점', 1),
#   ('일식', 1),
#   ('정식', 1),
#   ('후기', 1),
#   ('냉', 1),
#   ('모밀', 1),
#   ('시원', 1),
#   ('여름', 1),
#   ('간단', 1),
#   ('점심', 1),
#   ('이나', 1),
#   ('혼밥', 1),
#   ('기도', 1),
#   ('역', 1),
#   ('맛집', 1),
#   ('돈', 1),
#   ('열심', 1),
#   ('먹방', 1),
#   ('포스트', 1),
#   ('더', 1),
#   ('보', 1),
#   ('려면', 1),
#   ('아래', 1),
#   ('뚝딱', 1),
#   ('거리', 1),
#   ('한국', 1),
#   ('생활', 1)],
#  [('나베', 4),
#   ('에어', 2),
#   ('프라이어', 2),
#   ('돈가스', 2),
#   ('요리', 2),
#   ('쯔유', 2),
#   ('활용', 2),
#   ('집밥', 2),
#   ('저녁', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('돈까스', 2),
#   ('김치', 2),
#   ('레시피', 2),
#   ('츠', 1),
#   ('만들기', 1),
#   ('안녕', 1),
#   ('푸드', 1),
#   ('인', 1),
#   ('플루', 1),
#   ('이', 1),
#   ('바삭', 1),
#   ('고소', 1),
#   ('맛', 1),
#   ('아하', 1),
#   ('시', 1),
#   ('이의', 1),
#   ('홈쿡', 1)],
#  [('메뉴', 3),
#   ('인계동', 2),
#   ('맛집', 2),
#   ('점심', 2),
#   ('추천', 2),
#   ('쭈꾸미', 2),
#   ('덮밥', 2),
#   ('결제', 2),
#   ('시스템', 2),
#   ('테이블', 1),
#   ('주문', 1),
#   ('까지', 1),
#   ('가능', 1),
#   ('아직까지', 1),
#   ('적응', 1),
#   ('서인', 1),
#   ('어서', 1),
#   ('인지', 1),
#   ('때', 1),
#   ('또', 1),
#   ('카운터', 1),
#   ('감', 1),
#   ('부동산', 1)],
#  [('서브웨이', 3),
#   ('꿀', 3),
#   ('조합', 3),
#   ('마', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('오늘', 1),
#   ('간단', 1),
#   ('점심', 1),
#   ('후기', 1),
#   ('보', 1),
#   ('려고', 1),
#   ('해', 1),
#   ('가장', 1),
#   ('기본', 1),
#   ('이왕이면', 1),
#   ('가지', 1),
#   ('채소', 1),
#   ('달달', 1),
#   ('채즙', 1),
#   ('버퍼', 1),
#   ('활용', 1),
#   ('김원', 1),
#   ('장의', 1),
#   ('탐구생활', 1)],
#  [('메뉴', 3),
#   ('토마토', 3),
#   ('스튜', 3),
#   ('찜닭', 3),
#   ('가산', 2),
#   ('추천', 2),
#   ('애', 2),
#   ('밥', 2),
#   ('테라', 1),
#   ('타워', 1),
#   ('본점', 1),
#   ('맛집', 1),
#   ('혼밥', 1),
#   ('비', 1),
#   ('한바탕', 1),
#   ('아지', 1),
#   ('난', 1),
#   ('뒤', 1),
#   ('잠깐', 1),
#   ('안', 1),
#   ('틈', 1),
#   ('타', 1),
#   ('방문', 1),
#   ('살', 1),
#   ('나물', 1),
#   ('건강', 1),
#   ('돈까스', 1),
#   ('토핑', 1),
#   ('서비스', 1),
#   ('묵은지', 1)],
#  [('디', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('칠리', 2),
#   ('베이컨', 2),
#   ('웜볼', 2),
#   ('바질', 2),
#   ('치킨', 2),
#   ('랩', 2),
#   ('오반', 2),
#   ('짝', 2),
#   ('어요', 2),
#   ('반짝', 2),
#   ('안녕', 1),
#   ('개인', 1),
#   ('피티', 1),
#   ('동네', 1),
#   ('친구', 1),
#   ('톡', 1),
#   ('급', 1),
#   ('점심', 1),
#   ('나름', 1),
#   ('다이어트', 1),
#   ('중이', 1),
#   ('어디', 1),
#   ('다가', 1),
#   ('원래', 1),
#   ('일상', 1)],
#  [('이삭', 3),
#   ('토스트', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('햄', 2),
#   ('치즈', 2),
#   ('어요', 2),
#   ('허니', 1),
#   ('갈릭', 1),
#   ('소스', 1),
#   ('주말', 1),
#   ('뭐', 1),
#   ('하루', 1),
#   ('끼', 1),
#   ('집밥', 1),
#   ('어서', 1),
#   ('먹기', 1),
#   ('잠깐', 1),
#   ('외출', 1),
#   ('다가', 1),
#   ('눈', 1),
#   ('보이', 1),
#   ('오늘', 1),
#   ('의아', 1),
#   ('침', 1),
#   ('거', 1),
#   ('야채', 1),
#   ('먀', 1),
#   ('돈', 1),
#   ('우수', 1),
#   ('형제', 1)],
#  [('물회', 5),
#   ('보재', 4),
#   ('해물', 4),
#   ('메뉴', 3),
#   ('집', 2),
#   ('추천', 2),
#   ('기', 2),
#   ('가격', 2),
#   ('짐', 2),
#   ('여행', 2),
#   ('맛집', 1),
#   ('투어', 1),
#   ('방송', 1),
#   ('출연', 1),
#   ('저', 1),
#   ('원', 1),
#   ('차이', 1),
#   ('추가', 1),
#   ('더', 1),
#   ('맛', 1),
#   ('요', 1),
#   ('거제', 1),
#   ('정보', 1),
#   ('상의', 1),
#   ('네이버', 1),
#   ('인', 1),
#   ('플루', 1),
#   ('일상', 1),
#   ('처럼', 1)],
#  [('메뉴', 4),
#   ('부부', 3),
#   ('일상', 3),
#   ('점심', 3),
#   ('저녁', 3),
#   ('추천', 3),
#   ('오랜만', 2),
#   ('저희', 2),
#   ('집밥', 2),
#   ('최근', 1),
#   ('포스팅', 1),
#   ('전부', 1),
#   ('마무리', 1),
#   ('정말', 1),
#   ('후기', 1),
#   ('요', 1),
#   ('집', 1),
#   ('고민', 1),
#   ('때', 1),
#   ('번', 1),
#   ('정사', 1),
#   ('장', 1),
#   ('맛집', 1),
#   ('투어', 1)],
#  [('도시락', 3),
#   ('수', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('삼촌', 2),
#   ('점심', 2),
#   ('세트', 2),
#   ('직장인', 1),
#   ('수제', 1),
#   ('고민', 1),
#   ('이신', 1),
#   ('여러분', 1),
#   ('저렴', 1),
#   ('구성', 1),
#   ('양하', 1),
#   ('점심시간', 1),
#   ('매일', 1),
#   ('즐', 1),
#   ('거울', 1),
#   ('어요', 1),
#   ('저', 1),
#   ('재주', 1),
#   ('문', 1),
#   ('의사', 1),
#   ('정도', 1),
#   ('사서', 1),
#   ('냉동고', 1),
#   ('서울', 1),
#   ('소시민', 1),
#   ('햄찌', 1),
#   ('삶', 1)],
#  [('파스타', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('인', 2),
#   ('스테이크', 1),
#   ('맛집', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('솔직', 1),
#   ('후기', 1),
#   ('둘리', 1),
#   ('쉬', 1),
#   ('림프', 1),
#   ('치킨', 1),
#   ('비비큐', 1),
#   ('사이', 1),
#   ('고민', 1),
#   ('친절', 1),
#   ('직원', 1),
#   ('분', 1),
#   ('고', 1),
#   ('기류', 1),
#   ('신', 1),
#   ('해주시', 1),
#   ('센스', 1),
#   ('예비', 1),
#   ('플루', 1)],
#  [('추천', 2),
#   ('메뉴', 2),
#   ('에스프레소', 2),
#   ('것', 2),
#   ('지점', 1),
#   ('비교', 1),
#   ('법', 1),
#   ('고', 1),
#   ('굿', 1),
#   ('가격', 1),
#   ('초콜렛', 1),
#   ('칩', 1),
#   ('쿠키', 1),
#   ('블루베리', 1),
#   ('머핀', 1),
#   ('랄프', 1),
#   ('스', 1),
#   ('티라미수', 1),
#   ('뺑오', 1),
#   ('쇼콜라', 1),
#   ('크로와상', 1),
#   ('무난', 1),
#   ('주변', 1),
#   ('은근', 1),
#   ('케이크', 1),
#   ('사람', 1)],
#  [('치킨', 7),
#   ('마법', 4),
#   ('메뉴', 3),
#   ('처럼', 2),
#   ('야식', 2),
#   ('추천', 2),
#   ('아하', 2),
#   ('신', 1),
#   ('한국인', 1),
#   ('면', 1),
#   ('누구', 1),
#   ('이웃', 1),
#   ('님들', 1),
#   ('시나', 1),
#   ('종류', 1),
#   ('워낙', 1),
#   ('다양', 1),
#   ('재미', 1),
#   ('입맛', 1),
#   ('행주치마', 1),
#   ('정겨운', 1),
#   ('집밥', 1)],
#  [('메뉴', 3),
#   ('이케아', 2),
#   ('추천', 2),
#   ('용인', 1),
#   ('기흥', 1),
#   ('점', 1),
#   ('맛집', 1),
#   ('레스토랑', 1),
#   ('식당', 1),
#   ('소프트', 1),
#   ('콘', 1),
#   ('후기', 1),
#   ('닭고기', 1),
#   ('스테이크', 1),
#   ('구', 1),
#   ('파스타', 1),
#   ('김치볶음밥', 1),
#   ('돈까스', 1),
#   ('불고기', 1),
#   ('볶음밥', 1),
#   ('연어', 1),
#   ('필레', 1),
#   ('미트볼', 1),
#   ('개', 1),
#   ('원도', 1),
#   ('주문', 1),
#   ('가성', 1),
#   ('비', 1),
#   ('홈', 1),
#   ('바리스타', 1),
#   ('라미', 1),
#   ('방구', 1),
#   ('석', 1),
#   ('레시피', 1)]]

# %%
#중복값을 더하기 위해 딕셔너리 형태로 만들어줌 
df = pd.DataFrame()
for i in range(0,len(an)) :
    en = dict(an[i])
    df = df.append({'sentiment' : en}, ignore_index=True)

df
# Out:
#                                              sentiment
# 0    {'이치란': 3, '라멘': 3, '주문': 3, '방법': 3, '메뉴': 3,...
# 1    {'메뉴': 3, '베트남': 2, '주변': 2, '안': 2, '토이': 2, ...
# 2    {'맛집': 3, '구로디지털단지역': 2, '메뉴': 2, '디': 2, '추천'...
# 3    {'해운대': 4, '카페': 3, '정보': 3, '오설록': 2, '티': 2,...
# 4    {'제': 3, '추천': 3, '메뉴': 3, '분모': 2, '자로': 2, '...
# ..                                                 ...
# 986  {'도시락': 3, '수': 3, '메뉴': 2, '추천': 2, '삼촌': 2, ...
# 987  {'파스타': 3, '메뉴': 2, '추천': 2, '인': 2, '스테이크': 1...
# 988  {'추천': 2, '메뉴': 2, '에스프레소': 2, '것': 2, '지점': 1...
# 989  {'치킨': 7, '마법': 4, '메뉴': 3, '처럼': 2, '야식': 2, ...
# 990  {'메뉴': 3, '이케아': 2, '추천': 2, '용인': 1, '기흥': 1,...
#
# [991 rows x 1 columns]

# %%
#중복 값을 더하는 함수 
from operator import itemgetter
def sum_sentiment(x):
    init_dict = list(x)

    result = {}
    for d in init_dict:
        for k in d.keys():
            result[k] = result.get(k, 0) + d[k]
    return result

# %%
dic_sum = df.agg({'sentiment' : lambda x : sum_sentiment(x)})
type(dic_sum)
# Out:
# pandas.core.series.Series

# %%
#더해진 값이 담긴 데이터프레임을 리스트 형태로 변경
dic_sum = dic_sum.values.tolist()
dic_sum
# Out:
# [{'이치란': 14,
#   '라멘': 25,
#   '주문': 183,
#   '방법': 47,
#   '메뉴': 2935,
#   '추천': 2551,
#   '텐진': 4,
#   '맛집': 618,
#   '후쿠오카': 15,
#   '웨이': 100,
#   '팅': 99,
#   '일본': 14,
#   '스시': 17,
#   '오': 24,
#   '마카': 6,
#   '세': 31,
#   '끼니': 4,
#   '후기': 160,
#   '소개': 50,
#   '고': 101,
#   '까지': 88,
#   '공유': 12,
#   '시간': 68,
#   '운': 17,
#   '영하': 1,
#   '본점': 16,
#   '푸드': 41,
#   '인': 65,
#   '플루': 9,
#   '율무': 2,
#   '밍': 3,
#   '일상': 73,
#   '기록': 23,
#   '베트남': 24,
#   '주변': 7,
#   '안': 52,
#   '토이': 6,
#   '다낭': 38,
#   '한시': 4,
#   '장': 22,
#   '벱꿰': 2,
#   '나': 44,
#   '가지볶음': 1,
#   '토마토소스': 1,
#   '두부': 13,
#   '완자': 1,
#   '조림': 3,
#   '황금새': 1,
#   '요리': 112,
#   '한번': 38,
#   '모든': 27,
#   '맛': 156,
#   '볼': 31,
#   '수': 124,
#   '무엇': 8,
#   '인테리어': 8,
#   '쾌적': 1,
#   '환경': 2,
#   '추': 43,
#   '천하': 38,
#   '잡': 5,
#   '트래블': 3,
#   '홀릭': 2,
#   '구로디지털단지역': 2,
#   '디': 51,
#   '매장': 39,
#   '점': 149,
#   '갈비': 21,
#   '판이': 5,
#   '크게': 7,
#   '어서': 102,
#   '어요': 202,
#   '그': 65,
#   '잡채': 3,
#   '회식': 20,
#   '공간': 18,
#   '직장인': 21,
#   '드립': 28,
#   '술집': 23,
#   '고기': 51,
#   '집': 85,
#   '해운대': 9,
#   '카페': 148,
#   '정보': 44,
#   '오설록': 3,
#   '티': 32,
#   '하우스': 23,
#   '오픈': 28,
#   '행사': 17,
#   '자세': 5,
#   '여러분': 5,
#   '신상': 15,
#   '보고': 26,
#   '방문': 77,
#   '전': 47,
#   '참고': 20,
#   '외관': 1,
#   '제': 67,
#   '분모': 4,
#   '자로': 2,
#   '떡볶이': 30,
#   '기준': 7,
#   '돈': 56,
#   '산': 52,
#   '솔직': 42,
#   '는걸': 14,
#   '거지': 2,
#   '성비': 7,
#   '정말': 48,
#   '치킨': 172,
#   '뿌': 5,
#   '링클': 7,
#   '커리': 13,
#   '퀸': 3,
#   '맛초킹': 4,
#   '정도': 33,
#   '것': 105,
#   '민초': 2,
#   '파의': 2,
#   '박사': 4,
#   '도전': 9,
#   '기': 45,
#   '스테이크': 48,
#   '페퍼': 5,
#   '파타야': 1,
#   '비프': 6,
#   '터': 12,
#   '예약': 71,
#   '및': 47,
#   '직원': 19,
#   '분': 67,
#   '요청': 2,
#   '요': 114,
#   '를': 57,
#   '해': 64,
#   '크림': 72,
#   '색': 3,
#   '브랜디': 1,
#   '소스': 62,
#   '위': 40,
#   '야채': 22,
#   '사이드': 29,
#   '감자': 28,
#   '그라탕': 1,
#   '제공': 14,
#   '이': 95,
#   '스윗': 2,
#   '포타토킴': 1,
#   '다이어트': 22,
#   '로드': 8,
#   '이야기': 48,
#   '가격': 207,
#   '바르셀로나': 1,
#   '비니': 1,
#   '투스': 1,
#   '가격표': 1,
#   '파산': 1,
#   '잼': 5,
#   '세르': 1,
#   '베': 5,
#   '세리': 3,
#   '카탈': 1,
#   '라나': 2,
#   '체인': 1,
#   '분위기': 21,
#   '메뉴판': 52,
#   '부과': 1,
#   '더니': 12,
#   '지갑': 1,
#   '여자': 7,
#   '명': 14,
#   '이서': 13,
#   '배부': 9,
#   '르': 5,
#   '롤링': 6,
#   '제주': 34,
#   '오일장': 3,
#   '향': 39,
#   '민속': 1,
#   '오일': 4,
#   '시장': 10,
#   '걸': 41,
#   '순대국': 2,
#   '밥': 49,
#   '비빔밥': 32,
#   '꼼장어': 1,
#   '순대': 6,
#   '글': 23,
#   '감사': 6,
#   '모두': 31,
#   '주연': 1,
#   '블로그': 56,
#   '진짜': 46,
#   '리스': 6,
#   '정자': 7,
#   '주차': 67,
#   '브런치': 65,
#   '기분': 10,
#   '가게': 18,
#   '앞': 18,
#   '인쇄': 1,
#   '열심': 6,
#   '보': 29,
#   '면서': 31,
#   '정': 20,
#   '하나': 63,
#   '부터': 36,
#   '이용': 15,
#   '드': 41,
#   '린다': 7,
#   '파라': 3,
#   '곤': 2,
#   '지하': 3,
#   '주차장': 16,
#   '지원': 3,
#   '함': 20,
#   '판교': 24,
#   '후배': 1,
#   '만큼': 9,
#   '런던': 46,
#   '한식당': 3,
#   '꼭': 57,
#   '된장찌개': 10,
#   '오늘': 128,
#   '포스팅': 33,
#   '이전': 3,
#   '마지막': 13,
#   '가장': 30,
#   '메뉴인': 21,
#   '차돌': 12,
#   '친': 8,
#   '구들': 7,
#   '젤': 5,
#   '화려': 8,
#   '결하': 5,
#   '삶': 12,
#   '파리크라상': 5,
#   '빵': 82,
#   '파리': 4,
#   '크로와상': 8,
#   '또': 40,
#   '이제': 14,
#   '언제': 14,
#   '다시': 15,
#   '유럽': 3,
#   '답': 11,
#   '다양': 41,
#   '종류': 51,
#   '마음': 15,
#   '쏙': 2,
#   '베이커리': 30,
#   '방랑': 6,
#   '그날': 6,
#   '다리': 17,
#   '양배추': 17,
#   '국': 17,
#   '아침': 38,
#   '된장국': 3,
#   '간단': 86,
#   '통': 18,
#   '사면': 1,
#   '건강': 23,
#   '도움': 4,
#   '속': 7,
#   '편안': 3,
#   '해주': 16,
#   '때문': 20,
#   '로': 68,
#   '초록': 1,
#   '스토리': 11,
#   '고구마튀김': 3,
#   '초콜릿': 7,
#   '쉐이크': 24,
#   '강남': 24,
#   '슈퍼': 11,
#   '버거': 125,
#   '위치': 38,
#   '달짝': 3,
#   '지근': 3,
#   '하니': 25,
#   '먹기': 32,
#   '식': 41,
#   '어도': 20,
#   '초코': 23,
#   '덕후': 3,
#   '대만': 20,
#   '족': 3,
#   '살': 50,
#   '느낌': 19,
#   '아리': 6,
#   '노트': 13,
#   '만공': 7,
#   '격': 12,
#   '바삭': 18,
#   '치': 11,
#   '파포': 3,
#   '세트': 72,
#   '제시': 3,
#   '아하': 73,
#   '편이': 13,
#   '광고': 1,
#   '질색': 1,
#   '동일': 3,
#   '구성': 11,
#   '마리': 10,
#   '양': 23,
#   '던데': 7,
#   '려면': 5,
#   '합': 6,
#   '호랑이': 7,
#   '담배': 3,
#   '시절': 4,
#   '저녁': 137,
#   '더미': 16,
#   '우렁': 7,
#   '신혼부부': 3,
#   '국물': 40,
#   '퇴근': 5,
#   '후': 32,
#   '뭐': 49,
#   '을지': 5,
#   '보통': 9,
#   '밀키': 31,
#   '트하': 1,
#   '냉장': 1,
#   '이나': 21,
#   '냉동': 10,
#   '보관': 8,
#   '경우': 6,
#   '더': 99,
#   '미식': 7,
#   '열처리': 1,
#   '기술': 1,
#   '통해': 5,
#   '쌀국수': 32,
#   '사진': 40,
#   '티엔': 3,
#   '킴': 1,
#   '할인': 52,
#   '위주': 7,
#   '거': 81,
#   '필수': 12,
#   '고요': 40,
#   '반': 31,
#   '파인애플': 4,
#   '볶음밥': 28,
#   '아해': 10,
#   '망고': 12,
#   '샐러드': 61,
#   '여러': 16,
#   '번': 39,
#   '해외여행': 5,
#   '고고씽': 3,
#   '타타': 6,
#   '스': 42,
#   '베이글': 89,
#   '대전': 14,
#   '모카': 3,
#   '아기': 13,
#   '실내': 6,
#   '놀이터': 1,
#   '가기': 10,
#   '마늘': 10,
#   '어가': 24,
#   '포만': 2,
#   '감': 10,
#   '슈크림': 4,
#   '시트콤': 1,
#   '라이프': 23,
#   '숙성': 13,
#   '함덕': 2,
#   '뼈': 6,
#   '등심': 12,
#   '제주도': 13,
#   '돼지': 20,
#   '이유': 14,
#   '지점': 4,
#   '마다': 19,
#   '한정': 12,
#   '조금': 16,
#   '중복': 2,
#   '인분': 7,
#   '판매': 8,
#   '먼저': 14,
#   '저희': 36,
#   '뼈목살': 1,
#   '운하': 1,
#   '민': 1,
#   '시오': 4,
#   '광주': 17,
#   '첨단': 4,
#   '라운지': 3,
#   '우리': 45,
#   '동생': 1,
#   '토마호크': 1,
#   '시': 80,
#   '그니': 36,
#   '처': 34,
#   '메인': 23,
#   '트러플': 25,
#   '까르보나라': 2,
#   '김치': 16,
#   '라이스': 7,
#   '추가': 46,
#   '찬둥': 1,
#   '파리바게트': 12,
#   '애플': 4,
#   '베이컨': 26,
#   '토스트': 25,
#   '생크림': 6,
#   '래서': 30,
#   '개': 71,
#   '생': 23,
#   '크림빵': 5,
#   '저': 80,
#   '가성': 28,
#   '비': 63,
#   '재': 15,
#   '구매': 8,
#   '의사': 4,
#   '매우': 8,
#   '리틀': 4,
#   '피카': 3,
#   '괌': 12,
#   '로꼬': 2,
#   '모꼬': 2,
#   '조식': 6,
#   '에그베네딕트': 4,
#   '여기': 31,
#   '그냥': 24,
#   '검색': 8,
#   '영': 6,
#   '분당': 23,
#   '포': 37,
#   '시즌': 17,
#   '키친': 16,
#   '뇨끼': 8,
#   '강추': 12,
#   '곳': 69,
#   '직영': 2,
#   '경기': 9,
#   '성남시': 4,
#   '분당구': 2,
#   '문어': 10,
#   '콩피': 2,
#   '스파클링': 1,
#   '와인': 15,
#   '부모님': 9,
#   '식사': 35,
#   '늘': 11,
#   '푸른': 3,
#   '염소': 2,
#   '가든': 11,
#   '드릴': 38,
#   '모시': 2,
#   '테': 2,
#   '장소': 23,
#   '고민': 39,
#   '계시': 4,
#   '시기': 6,
#   '마찬가지': 1,
#   '탕': 11,
#   '수육': 2,
#   '방': 18,
#   '방곡': 5,
#   '여행기': 10,
#   '체코': 2,
#   '프라하': 2,
#   '여행': 123,
#   '줌': 1,
#   '안녕하십니까': 1,
#   '패션': 4,
#   '쁠뤈': 1,
#   '고온': 1,
#   '가지': 79,
#   '오시': 4,
#   '우왕좌왕': 1,
#   '당': 25,
#   '황하': 1,
#   '도록': 5,
#   '음식': 91,
#   '세상': 21,
#   '중심': 1,
#   '얼스': 1,
#   '어스': 1,
#   '치아바타': 4,
#   '전문': 3,
#   '세컨': 1,
#   '브랜드': 23,
#   '토마토': 25,
#   '샌드위치': 34,
#   '수프': 13,
#   '포장': 45,
#   '가능': 37,
#   '불가': 5,
#   '주말': 49,
#   '시정': 1,
#   '부지런': 3,
#   '회전': 3,
#   '율': 2,
#   '아무': 7,
#   '도': 45,
#   '신선': 11,
#   '한편': 1,
#   '삭': 10,
#   '조합': 57,
#   '냉': 13,
#   '모밀': 4,
#   '압구정로': 5,
#   '데오': 4,
#   '여름': 36,
#   '하루': 35,
#   '때': 100,
#   '다음': 21,
#   '강력': 26,
#   '리뷰': 42,
#   '왼쪽': 4,
#   '기본': 26,
#   '오른쪽': 4,
#   '곱빼기': 3,
#   '남': 5,
#   '여': 5,
#   '가시': 6,
#   '아웃백': 10,
#   '변경': 3,
#   '팁': 16,
#   '런치': 20,
#   '오후': 9,
#   '평일': 18,
#   '인적': 31,
#   '갈릭': 38,
#   '립': 6,
#   '아이': 52,
#   '통신사': 1,
#   '카드': 6,
#   '의자': 6,
#   '외식': 17,
#   '부시맨': 1,
#   '용': 7,
#   '성수역': 4,
#   '출구': 4,
#   '미사': 6,
#   '외': 15,
#   '보심': 1,
#   '호선': 2,
#   '일요일': 5,
#   '휴무': 9,
#   '듯': 14,
#   '고추전': 1,
#   '해물파전': 2,
#   '오징어': 32,
#   '데침': 1,
#   '회비': 1,
#   '정산': 1,
#   '만요': 4,
#   '개인': 8,
#   '적': 42,
#   '입맛': 22,
#   '전집': 1,
#   '식빵': 8,
#   '소금': 22,
#   '세종': 2,
#   '줄': 20,
#   '서서': 4,
#   '빵집': 29,
#   '셀레슈크레': 1,
#   '다른': 45,
#   '리스트': 17,
#   '에그타르트': 3,
#   '바스': 1,
#   '트': 42,
#   '치즈케이크': 5,
#   '내': 48,
#   '망': 5,
#   '순': 7,
#   '우유': 14,
#   '크루아상': 2,
#   '뺑오': 2,
#   '쇼콜라': 2,
#   '치즈': 90,
#   '바닐라': 18,
#   '주옥': 1,
#   '나날': 4,
#   '소바': 13,
#   '연구소': 2,
#   '신촌': 15,
#   '너': 4,
#   '구나': 2,
#   '끝': 12,
#   '보시': 33,
#   '길': 33,
#   '출발': 1,
#   '중': 74,
#   '설명': 8,
#   '폰': 2,
#   '미가': 2,
#   '배': 16,
#   '졸리': 7,
#   '보라카이': 5,
#   '일반': 5,
#   '선택': 37,
#   '몇': 12,
#   '페소': 4,
#   '가금': 2,
#   '불하': 1,
#   '스파이': 7,
#   '꼽으': 1,
#   '시더': 5,
#   '치밥': 10,
#   '닭다리': 4,
#   '솔솥': 3,
#   '무난': 10,
#   '경복궁역': 4,
#   '촌': 5,
#   '굳이': 3,
#   '왜냐면': 4,
#   '솥밥': 13,
#   '상상': 1,
#   '덮밥': 23,
#   '랄': 2,
#   '롯데리아': 63,
#   '새우': 83,
#   '익스트림': 29,
#   '베이': 6,
#   '건': 20,
#   '신': 70,
#   '레몬': 28,
#   '시식': 1,
#   '음원': 4,
#   '이벤트': 15,
#   '점심': 158,
#   '로부터': 4,
#   '원고료': 5,
#   '주관': 5,
#   '작성': 10,
#   '말': 16,
#   '염': 2,
#   '방구': 2,
#   '시추': 2,
#   '중국요리': 1,
#   '사천요리': 3,
#   '움': 1,
#   '피셜': 1,
#   '에피': 1,
#   '타이': 29,
#   '징': 2,
#   '스프': 14,
#   '향가': 1,
#   '지도': 8,
#   '꽤': 12,
#   '육류': 3,
#   '소': 40,
#   '닭': 24,
#   '동파육': 8,
#   '단연': 3,
#   '최고': 13,
#   '완전': 32,
#   '동행': 1,
#   '말로': 2,
#   '소고기': 16,
#   '전골': 10,
#   '투탑': 1,
#   '책장': 2,
#   '짬뽕': 20,
#   '월계수': 3,
#   '식당': 63,
#   '돈까스': 43,
#   '국밥': 7,
#   '우삼겹': 12,
#   '충장로': 3,
#   '자리': 21,
#   '그대로': 4,
#   '오래': 4,
#   '제육': 3,
#   '잡채밥': 1,
#   '등': 33,
#   '물만두': 3,
#   '삼선': 2,
#   '가야': 3,
#   '딩': 1,
#   '곡성': 3,
#   '방문자': 1,
#   '단골': 9,
#   '입장': 5,
#   '리자': 1,
#   '스폐셜': 1,
#   '각': 9,
#   '동대문': 1,
#   '에베레스트': 1,
#   '입': 14,
#   '아주': 32,
#   '혐': 1,
#   '바보': 1,
#   '티카': 1,
#   '머설': 1,
#   '버터': 22,
#   '아가': 10,
#   '빙고': 2,
#   '이자카야': 16,
#   '하이': 15,
#   '품': 12,
#   '일본주': 1,
#   '준비': 18,
#   '문': 11,
#   '순간': 8,
#   '일본인': 2,
#   '순간이동': 1,
#   '러블리썬': 2,
#   '날': 62,
#   '정자동': 5,
#   '이상': 7,
#   '전화': 7,
#   '판': 48,
#   '정독': 2,
#   '해산물': 13,
#   '도미': 2,
#   '관자': 4,
#   '전복': 4,
#   '민물장어': 1,
#   '연어': 12,
#   '꼬막': 3,
#   '갈치구이': 3,
#   '찜닭': 49,
#   '시래기': 3,
#   '찜': 21,
#   '맵': 5,
#   '단계': 3,
#   '로제': 7,
#   '평': 7,
#   '음번': 1,
#   '박': 5,
#   '소한': 14,
#   '성수동': 2,
#   '오로라': 1,
#   '영업': 23,
#   '정리': 16,
#   '과연': 3,
#   '네이버': 9,
#   '잠봉뵈르': 1,
#   '라우': 2,
#   '겐': 1,
#   '경제': 4,
#   '자유': 6,
#   '상무지구': 1,
#   '네가지': 2,
#   '처음': 19,
#   '요건': 2,
#   '실거': 1,
#   '부들': 2,
#   '근로': 1,
#   '사발': 7,
#   '멍게': 2,
#   '간장': 18,
#   '미니': 11,
#   '국수': 7,
#   '주신': 4,
#   '야식': 31,
#   '들기름': 3,
#   '깻잎': 3,
#   '페스': 9,
#   '토': 14,
#   '비빔': 5,
#   '밀국수': 1,
#   '활용': 6,
#   '자': 17,
#   '사실': 18,
#   '정답': 1,
#   '의': 27,
#   '덕목': 1,
#   '만들기': 43,
#   '지나': 7,
#   '부담': 12,
#   '아야': 2,
#   '재미': 11,
#   '마미': 3,
#   '조선': 8,
#   '홍연': 3,
#   '탕수육': 7,
#   '웨스': 4,
#   '틴': 4,
#   '소공동': 1,
#   '호텔': 15,
#   '중식': 9,
#   '한결': 1,
#   '친절': 11,
#   '바니': 3,
#   '팔레': 2,
#   '그랜드': 1,
#   '부산': 29,
#   '바로': 61,
#   '칠리': 15,
#   '코스': 16,
#   '주': 28,
#   '문하': 19,
#   '알': 21,
#   '튀김': 31,
#   '옷': 3,
#   '양념': 33,
#   '코팅': 1,
#   '탕후루': 10,
#   '식감': 9,
#   '쏨땀': 3,
#   '북촌': 1,
#   '태국': 25,
#   '음식점': 9,
#   '화양연화': 2,
#   '첫': 12,
#   '등장': 1,
#   '생김새': 1,
#   '심상': 1,
#   '찮다': 1,
#   '콤함': 2,
#   '이루': 1,
#   '반적': 6,
#   '훌륭': 3,
#   '귤': 4,
#   '욤뇸': 2,
#   '로그': 25,
#   '대하': 5,
#   '사': 18,
#   '서영수': 1,
#   '법': 29,
#   '파티': 8,
#   '구이': 19,
#   '라면': 17,
#   '보기': 11,
#   '었는데': 4,
#   '안주': 37,
#   '안산': 5,
#   '한식': 25,
#   '해석': 1,
#   '히든': 1,
#   '일품': 3,
#   '항': 2,
#   '정숙': 1,
#   '회': 18,
#   '항정': 1,
#   '냉소': 4,
#   '육회': 5,
#   '전통주': 1,
#   '막걸리': 1,
#   '삼천포': 1,
#   '쩐쭈': 1,
#   '맹글어': 1,
#   '도우': 7,
#   '피자': 108,
#   '두': 25,
#   '최대': 1,
#   '크리': 3,
#   '지기': 3,
#   '겹겹이': 1,
#   '품격': 2,
#   '크레이프': 4,
#   '샌드': 3,
#   '일명': 2,
#   '나폴리': 1,
#   '씬': 1,
#   '쫄깃': 5,
#   '도미노피자': 9,
#   '공식': 6,
#   '광장': 3,
#   '코': 16,
#   '중국집': 2,
#   '개화': 2,
#   '계절': 3,
#   '콩국수': 4,
#   '현수막': 1,
#   '예전': 5,
#   '마': 26,
#   '차이': 4,
#   '상호': 1,
#   '호호': 5,
#   '렐라': 1,
#   '거림': 1,
#   '운정': 3,
#   '금별': 6,
#   '맥주': 30,
#   '산내': 1,
#   '마을': 11,
#   '야외': 2,
#   '테이블': 28,
#   '버너': 1,
#   '남편': 17,
#   '차로': 4,
#   '사모님': 1,
#   '백합': 1,
#   '조개': 5,
#   '술찜': 3,
#   '슈': 2,
#   '니슈': 1,
#   '행복': 28,
#   '도넛': 51,
#   '노티': 21,
#   '잠실': 35,
#   '송리단길': 5,
#   '스트로베리': 1,
#   '라즈베리': 1,
#   '취향': 26,
#   '인지': 8,
#   '묵': 2,
#   '직하': 3,
#   '삼삼': 1,
#   '진땅': 1,
#   '핫도그': 22,
#   '건대': 3,
#   '혼밥': 23,
#   '로스': 5,
#   '커먼그라운드': 2,
#   '거나': 3,
#   '핫': 26,
#   '치토스': 2,
#   '엘': 1,
#   '떼': 8,
#   '옥수수': 10,
#   '밀크쉐이크': 7,
#   '소하': 8,
#   '삼성역': 5,
#   '피': 18,
#   '인더': 3,
#   '코엑스': 13,
#   '반짝': 28,
#   '다가': 32,
#   '사라': 2,
#   '의외': 2,
#   '게': 27,
#   '입구': 19,
#   '팬더': 4,
#   '나들이': 9,
#   '조': 6,
#   '이맘': 7,
#   '품절': 8,
#   '애월': 1,
#   '랜': 11,
#   '디스': 15,
#   '프리터': 1,
#   '글레이': 1,
#   '버터크림': 1,
#   '인기': 53,
#   '일찍': 3,
#   '조이': 1,
#   '왕가': 6,
#   '빙수': 14,
#   '동두천': 2,
#   '여태': 1,
#   '제일': 28,
#   '자주': 13,
#   '행점': 1,
#   '의정부': 6,
#   '노맛': 1,
#   '가요': 4,
#   '리': 42,
#   '상': 13,
#   '아이스크림': 21,
#   '수원': 15,
#   '폴바': 14,
#   '셋': 18,
#   '커피': 147,
#   '직접': 16,
#   '룽': 3,
#   '아이스': 12,
#   '아메리카노': 21,
#   '상하이': 1,
#   '목장': 6,
#   '토핑': 12,
#   '라떼': 41,
#   '라스': 1,
#   '달달': 18,
#   '집들이': 42,
#   '돼지갈비': 11,
#   '굽': 2,
#   '기만': 2,
#   '정인': 5,
#   '밀': 8,
#   '키트': 5,
#   '안내서': 1,
#   '베블': 1,
#   '식탁': 2,
#   '연남동': 24,
#   '데이트': 28,
#   '윤성용': 2,
#   '레스토랑': 29,
#   '특선': 1,
#   '둥지': 3,
#   '엔초': 1,
#   '파스타': 77,
#   '콰트로': 3,
#   '포르마': 1,
#   '레몬에이드': 2,
#   '콜라': 6,
#   '홍대': 34,
#   '홍진': 1,
#   '마제': 3,
#   '바': 29,
#   '에비덴': 2,
#   '방배역': 1,
#   '백': 5,
#   '소정': 9,
#   '대로': 6,
#   '역': 13,
#   '자루': 2,
#   ...}]

# %%
#딕셔너리 형태로 만들어 줌
df = dic_sum[0]
df
# Out:
# {'이치란': 14,
#  '라멘': 25,
#  '주문': 183,
#  '방법': 47,
#  '메뉴': 2935,
#  '추천': 2551,
#  '텐진': 4,
#  '맛집': 618,
#  '후쿠오카': 15,
#  '웨이': 100,
#  '팅': 99,
#  '일본': 14,
#  '스시': 17,
#  '오': 24,
#  '마카': 6,
#  '세': 31,
#  '끼니': 4,
#  '후기': 160,
#  '소개': 50,
#  '고': 101,
#  '까지': 88,
#  '공유': 12,
#  '시간': 68,
#  '운': 17,
#  '영하': 1,
#  '본점': 16,
#  '푸드': 41,
#  '인': 65,
#  '플루': 9,
#  '율무': 2,
#  '밍': 3,
#  '일상': 73,
#  '기록': 23,
#  '베트남': 24,
#  '주변': 7,
#  '안': 52,
#  '토이': 6,
#  '다낭': 38,
#  '한시': 4,
#  '장': 22,
#  '벱꿰': 2,
#  '나': 44,
#  '가지볶음': 1,
#  '토마토소스': 1,
#  '두부': 13,
#  '완자': 1,
#  '조림': 3,
#  '황금새': 1,
#  '요리': 112,
#  '한번': 38,
#  '모든': 27,
#  '맛': 156,
#  '볼': 31,
#  '수': 124,
#  '무엇': 8,
#  '인테리어': 8,
#  '쾌적': 1,
#  '환경': 2,
#  '추': 43,
#  '천하': 38,
#  '잡': 5,
#  '트래블': 3,
#  '홀릭': 2,
#  '구로디지털단지역': 2,
#  '디': 51,
#  '매장': 39,
#  '점': 149,
#  '갈비': 21,
#  '판이': 5,
#  '크게': 7,
#  '어서': 102,
#  '어요': 202,
#  '그': 65,
#  '잡채': 3,
#  '회식': 20,
#  '공간': 18,
#  '직장인': 21,
#  '드립': 28,
#  '술집': 23,
#  '고기': 51,
#  '집': 85,
#  '해운대': 9,
#  '카페': 148,
#  '정보': 44,
#  '오설록': 3,
#  '티': 32,
#  '하우스': 23,
#  '오픈': 28,
#  '행사': 17,
#  '자세': 5,
#  '여러분': 5,
#  '신상': 15,
#  '보고': 26,
#  '방문': 77,
#  '전': 47,
#  '참고': 20,
#  '외관': 1,
#  '제': 67,
#  '분모': 4,
#  '자로': 2,
#  '떡볶이': 30,
#  '기준': 7,
#  '돈': 56,
#  '산': 52,
#  '솔직': 42,
#  '는걸': 14,
#  '거지': 2,
#  '성비': 7,
#  '정말': 48,
#  '치킨': 172,
#  '뿌': 5,
#  '링클': 7,
#  '커리': 13,
#  '퀸': 3,
#  '맛초킹': 4,
#  '정도': 33,
#  '것': 105,
#  '민초': 2,
#  '파의': 2,
#  '박사': 4,
#  '도전': 9,
#  '기': 45,
#  '스테이크': 48,
#  '페퍼': 5,
#  '파타야': 1,
#  '비프': 6,
#  '터': 12,
#  '예약': 71,
#  '및': 47,
#  '직원': 19,
#  '분': 67,
#  '요청': 2,
#  '요': 114,
#  '를': 57,
#  '해': 64,
#  '크림': 72,
#  '색': 3,
#  '브랜디': 1,
#  '소스': 62,
#  '위': 40,
#  '야채': 22,
#  '사이드': 29,
#  '감자': 28,
#  '그라탕': 1,
#  '제공': 14,
#  '이': 95,
#  '스윗': 2,
#  '포타토킴': 1,
#  '다이어트': 22,
#  '로드': 8,
#  '이야기': 48,
#  '가격': 207,
#  '바르셀로나': 1,
#  '비니': 1,
#  '투스': 1,
#  '가격표': 1,
#  '파산': 1,
#  '잼': 5,
#  '세르': 1,
#  '베': 5,
#  '세리': 3,
#  '카탈': 1,
#  '라나': 2,
#  '체인': 1,
#  '분위기': 21,
#  '메뉴판': 52,
#  '부과': 1,
#  '더니': 12,
#  '지갑': 1,
#  '여자': 7,
#  '명': 14,
#  '이서': 13,
#  '배부': 9,
#  '르': 5,
#  '롤링': 6,
#  '제주': 34,
#  '오일장': 3,
#  '향': 39,
#  '민속': 1,
#  '오일': 4,
#  '시장': 10,
#  '걸': 41,
#  '순대국': 2,
#  '밥': 49,
#  '비빔밥': 32,
#  '꼼장어': 1,
#  '순대': 6,
#  '글': 23,
#  '감사': 6,
#  '모두': 31,
#  '주연': 1,
#  '블로그': 56,
#  '진짜': 46,
#  '리스': 6,
#  '정자': 7,
#  '주차': 67,
#  '브런치': 65,
#  '기분': 10,
#  '가게': 18,
#  '앞': 18,
#  '인쇄': 1,
#  '열심': 6,
#  '보': 29,
#  '면서': 31,
#  '정': 20,
#  '하나': 63,
#  '부터': 36,
#  '이용': 15,
#  '드': 41,
#  '린다': 7,
#  '파라': 3,
#  '곤': 2,
#  '지하': 3,
#  '주차장': 16,
#  '지원': 3,
#  '함': 20,
#  '판교': 24,
#  '후배': 1,
#  '만큼': 9,
#  '런던': 46,
#  '한식당': 3,
#  '꼭': 57,
#  '된장찌개': 10,
#  '오늘': 128,
#  '포스팅': 33,
#  '이전': 3,
#  '마지막': 13,
#  '가장': 30,
#  '메뉴인': 21,
#  '차돌': 12,
#  '친': 8,
#  '구들': 7,
#  '젤': 5,
#  '화려': 8,
#  '결하': 5,
#  '삶': 12,
#  '파리크라상': 5,
#  '빵': 82,
#  '파리': 4,
#  '크로와상': 8,
#  '또': 40,
#  '이제': 14,
#  '언제': 14,
#  '다시': 15,
#  '유럽': 3,
#  '답': 11,
#  '다양': 41,
#  '종류': 51,
#  '마음': 15,
#  '쏙': 2,
#  '베이커리': 30,
#  '방랑': 6,
#  '그날': 6,
#  '다리': 17,
#  '양배추': 17,
#  '국': 17,
#  '아침': 38,
#  '된장국': 3,
#  '간단': 86,
#  '통': 18,
#  '사면': 1,
#  '건강': 23,
#  '도움': 4,
#  '속': 7,
#  '편안': 3,
#  '해주': 16,
#  '때문': 20,
#  '로': 68,
#  '초록': 1,
#  '스토리': 11,
#  '고구마튀김': 3,
#  '초콜릿': 7,
#  '쉐이크': 24,
#  '강남': 24,
#  '슈퍼': 11,
#  '버거': 125,
#  '위치': 38,
#  '달짝': 3,
#  '지근': 3,
#  '하니': 25,
#  '먹기': 32,
#  '식': 41,
#  '어도': 20,
#  '초코': 23,
#  '덕후': 3,
#  '대만': 20,
#  '족': 3,
#  '살': 50,
#  '느낌': 19,
#  '아리': 6,
#  '노트': 13,
#  '만공': 7,
#  '격': 12,
#  '바삭': 18,
#  '치': 11,
#  '파포': 3,
#  '세트': 72,
#  '제시': 3,
#  '아하': 73,
#  '편이': 13,
#  '광고': 1,
#  '질색': 1,
#  '동일': 3,
#  '구성': 11,
#  '마리': 10,
#  '양': 23,
#  '던데': 7,
#  '려면': 5,
#  '합': 6,
#  '호랑이': 7,
#  '담배': 3,
#  '시절': 4,
#  '저녁': 137,
#  '더미': 16,
#  '우렁': 7,
#  '신혼부부': 3,
#  '국물': 40,
#  '퇴근': 5,
#  '후': 32,
#  '뭐': 49,
#  '을지': 5,
#  '보통': 9,
#  '밀키': 31,
#  '트하': 1,
#  '냉장': 1,
#  '이나': 21,
#  '냉동': 10,
#  '보관': 8,
#  '경우': 6,
#  '더': 99,
#  '미식': 7,
#  '열처리': 1,
#  '기술': 1,
#  '통해': 5,
#  '쌀국수': 32,
#  '사진': 40,
#  '티엔': 3,
#  '킴': 1,
#  '할인': 52,
#  '위주': 7,
#  '거': 81,
#  '필수': 12,
#  '고요': 40,
#  '반': 31,
#  '파인애플': 4,
#  '볶음밥': 28,
#  '아해': 10,
#  '망고': 12,
#  '샐러드': 61,
#  '여러': 16,
#  '번': 39,
#  '해외여행': 5,
#  '고고씽': 3,
#  '타타': 6,
#  '스': 42,
#  '베이글': 89,
#  '대전': 14,
#  '모카': 3,
#  '아기': 13,
#  '실내': 6,
#  '놀이터': 1,
#  '가기': 10,
#  '마늘': 10,
#  '어가': 24,
#  '포만': 2,
#  '감': 10,
#  '슈크림': 4,
#  '시트콤': 1,
#  '라이프': 23,
#  '숙성': 13,
#  '함덕': 2,
#  '뼈': 6,
#  '등심': 12,
#  '제주도': 13,
#  '돼지': 20,
#  '이유': 14,
#  '지점': 4,
#  '마다': 19,
#  '한정': 12,
#  '조금': 16,
#  '중복': 2,
#  '인분': 7,
#  '판매': 8,
#  '먼저': 14,
#  '저희': 36,
#  '뼈목살': 1,
#  '운하': 1,
#  '민': 1,
#  '시오': 4,
#  '광주': 17,
#  '첨단': 4,
#  '라운지': 3,
#  '우리': 45,
#  '동생': 1,
#  '토마호크': 1,
#  '시': 80,
#  '그니': 36,
#  '처': 34,
#  '메인': 23,
#  '트러플': 25,
#  '까르보나라': 2,
#  '김치': 16,
#  '라이스': 7,
#  '추가': 46,
#  '찬둥': 1,
#  '파리바게트': 12,
#  '애플': 4,
#  '베이컨': 26,
#  '토스트': 25,
#  '생크림': 6,
#  '래서': 30,
#  '개': 71,
#  '생': 23,
#  '크림빵': 5,
#  '저': 80,
#  '가성': 28,
#  '비': 63,
#  '재': 15,
#  '구매': 8,
#  '의사': 4,
#  '매우': 8,
#  '리틀': 4,
#  '피카': 3,
#  '괌': 12,
#  '로꼬': 2,
#  '모꼬': 2,
#  '조식': 6,
#  '에그베네딕트': 4,
#  '여기': 31,
#  '그냥': 24,
#  '검색': 8,
#  '영': 6,
#  '분당': 23,
#  '포': 37,
#  '시즌': 17,
#  '키친': 16,
#  '뇨끼': 8,
#  '강추': 12,
#  '곳': 69,
#  '직영': 2,
#  '경기': 9,
#  '성남시': 4,
#  '분당구': 2,
#  '문어': 10,
#  '콩피': 2,
#  '스파클링': 1,
#  '와인': 15,
#  '부모님': 9,
#  '식사': 35,
#  '늘': 11,
#  '푸른': 3,
#  '염소': 2,
#  '가든': 11,
#  '드릴': 38,
#  '모시': 2,
#  '테': 2,
#  '장소': 23,
#  '고민': 39,
#  '계시': 4,
#  '시기': 6,
#  '마찬가지': 1,
#  '탕': 11,
#  '수육': 2,
#  '방': 18,
#  '방곡': 5,
#  '여행기': 10,
#  '체코': 2,
#  '프라하': 2,
#  '여행': 123,
#  '줌': 1,
#  '안녕하십니까': 1,
#  '패션': 4,
#  '쁠뤈': 1,
#  '고온': 1,
#  '가지': 79,
#  '오시': 4,
#  '우왕좌왕': 1,
#  '당': 25,
#  '황하': 1,
#  '도록': 5,
#  '음식': 91,
#  '세상': 21,
#  '중심': 1,
#  '얼스': 1,
#  '어스': 1,
#  '치아바타': 4,
#  '전문': 3,
#  '세컨': 1,
#  '브랜드': 23,
#  '토마토': 25,
#  '샌드위치': 34,
#  '수프': 13,
#  '포장': 45,
#  '가능': 37,
#  '불가': 5,
#  '주말': 49,
#  '시정': 1,
#  '부지런': 3,
#  '회전': 3,
#  '율': 2,
#  '아무': 7,
#  '도': 45,
#  '신선': 11,
#  '한편': 1,
#  '삭': 10,
#  '조합': 57,
#  '냉': 13,
#  '모밀': 4,
#  '압구정로': 5,
#  '데오': 4,
#  '여름': 36,
#  '하루': 35,
#  '때': 100,
#  '다음': 21,
#  '강력': 26,
#  '리뷰': 42,
#  '왼쪽': 4,
#  '기본': 26,
#  '오른쪽': 4,
#  '곱빼기': 3,
#  '남': 5,
#  '여': 5,
#  '가시': 6,
#  '아웃백': 10,
#  '변경': 3,
#  '팁': 16,
#  '런치': 20,
#  '오후': 9,
#  '평일': 18,
#  '인적': 31,
#  '갈릭': 38,
#  '립': 6,
#  '아이': 52,
#  '통신사': 1,
#  '카드': 6,
#  '의자': 6,
#  '외식': 17,
#  '부시맨': 1,
#  '용': 7,
#  '성수역': 4,
#  '출구': 4,
#  '미사': 6,
#  '외': 15,
#  '보심': 1,
#  '호선': 2,
#  '일요일': 5,
#  '휴무': 9,
#  '듯': 14,
#  '고추전': 1,
#  '해물파전': 2,
#  '오징어': 32,
#  '데침': 1,
#  '회비': 1,
#  '정산': 1,
#  '만요': 4,
#  '개인': 8,
#  '적': 42,
#  '입맛': 22,
#  '전집': 1,
#  '식빵': 8,
#  '소금': 22,
#  '세종': 2,
#  '줄': 20,
#  '서서': 4,
#  '빵집': 29,
#  '셀레슈크레': 1,
#  '다른': 45,
#  '리스트': 17,
#  '에그타르트': 3,
#  '바스': 1,
#  '트': 42,
#  '치즈케이크': 5,
#  '내': 48,
#  '망': 5,
#  '순': 7,
#  '우유': 14,
#  '크루아상': 2,
#  '뺑오': 2,
#  '쇼콜라': 2,
#  '치즈': 90,
#  '바닐라': 18,
#  '주옥': 1,
#  '나날': 4,
#  '소바': 13,
#  '연구소': 2,
#  '신촌': 15,
#  '너': 4,
#  '구나': 2,
#  '끝': 12,
#  '보시': 33,
#  '길': 33,
#  '출발': 1,
#  '중': 74,
#  '설명': 8,
#  '폰': 2,
#  '미가': 2,
#  '배': 16,
#  '졸리': 7,
#  '보라카이': 5,
#  '일반': 5,
#  '선택': 37,
#  '몇': 12,
#  '페소': 4,
#  '가금': 2,
#  '불하': 1,
#  '스파이': 7,
#  '꼽으': 1,
#  '시더': 5,
#  '치밥': 10,
#  '닭다리': 4,
#  '솔솥': 3,
#  '무난': 10,
#  '경복궁역': 4,
#  '촌': 5,
#  '굳이': 3,
#  '왜냐면': 4,
#  '솥밥': 13,
#  '상상': 1,
#  '덮밥': 23,
#  '랄': 2,
#  '롯데리아': 63,
#  '새우': 83,
#  '익스트림': 29,
#  '베이': 6,
#  '건': 20,
#  '신': 70,
#  '레몬': 28,
#  '시식': 1,
#  '음원': 4,
#  '이벤트': 15,
#  '점심': 158,
#  '로부터': 4,
#  '원고료': 5,
#  '주관': 5,
#  '작성': 10,
#  '말': 16,
#  '염': 2,
#  '방구': 2,
#  '시추': 2,
#  '중국요리': 1,
#  '사천요리': 3,
#  '움': 1,
#  '피셜': 1,
#  '에피': 1,
#  '타이': 29,
#  '징': 2,
#  '스프': 14,
#  '향가': 1,
#  '지도': 8,
#  '꽤': 12,
#  '육류': 3,
#  '소': 40,
#  '닭': 24,
#  '동파육': 8,
#  '단연': 3,
#  '최고': 13,
#  '완전': 32,
#  '동행': 1,
#  '말로': 2,
#  '소고기': 16,
#  '전골': 10,
#  '투탑': 1,
#  '책장': 2,
#  '짬뽕': 20,
#  '월계수': 3,
#  '식당': 63,
#  '돈까스': 43,
#  '국밥': 7,
#  '우삼겹': 12,
#  '충장로': 3,
#  '자리': 21,
#  '그대로': 4,
#  '오래': 4,
#  '제육': 3,
#  '잡채밥': 1,
#  '등': 33,
#  '물만두': 3,
#  '삼선': 2,
#  '가야': 3,
#  '딩': 1,
#  '곡성': 3,
#  '방문자': 1,
#  '단골': 9,
#  '입장': 5,
#  '리자': 1,
#  '스폐셜': 1,
#  '각': 9,
#  '동대문': 1,
#  '에베레스트': 1,
#  '입': 14,
#  '아주': 32,
#  '혐': 1,
#  '바보': 1,
#  '티카': 1,
#  '머설': 1,
#  '버터': 22,
#  '아가': 10,
#  '빙고': 2,
#  '이자카야': 16,
#  '하이': 15,
#  '품': 12,
#  '일본주': 1,
#  '준비': 18,
#  '문': 11,
#  '순간': 8,
#  '일본인': 2,
#  '순간이동': 1,
#  '러블리썬': 2,
#  '날': 62,
#  '정자동': 5,
#  '이상': 7,
#  '전화': 7,
#  '판': 48,
#  '정독': 2,
#  '해산물': 13,
#  '도미': 2,
#  '관자': 4,
#  '전복': 4,
#  '민물장어': 1,
#  '연어': 12,
#  '꼬막': 3,
#  '갈치구이': 3,
#  '찜닭': 49,
#  '시래기': 3,
#  '찜': 21,
#  '맵': 5,
#  '단계': 3,
#  '로제': 7,
#  '평': 7,
#  '음번': 1,
#  '박': 5,
#  '소한': 14,
#  '성수동': 2,
#  '오로라': 1,
#  '영업': 23,
#  '정리': 16,
#  '과연': 3,
#  '네이버': 9,
#  '잠봉뵈르': 1,
#  '라우': 2,
#  '겐': 1,
#  '경제': 4,
#  '자유': 6,
#  '상무지구': 1,
#  '네가지': 2,
#  '처음': 19,
#  '요건': 2,
#  '실거': 1,
#  '부들': 2,
#  '근로': 1,
#  '사발': 7,
#  '멍게': 2,
#  '간장': 18,
#  '미니': 11,
#  '국수': 7,
#  '주신': 4,
#  '야식': 31,
#  '들기름': 3,
#  '깻잎': 3,
#  '페스': 9,
#  '토': 14,
#  '비빔': 5,
#  '밀국수': 1,
#  '활용': 6,
#  '자': 17,
#  '사실': 18,
#  '정답': 1,
#  '의': 27,
#  '덕목': 1,
#  '만들기': 43,
#  '지나': 7,
#  '부담': 12,
#  '아야': 2,
#  '재미': 11,
#  '마미': 3,
#  '조선': 8,
#  '홍연': 3,
#  '탕수육': 7,
#  '웨스': 4,
#  '틴': 4,
#  '소공동': 1,
#  '호텔': 15,
#  '중식': 9,
#  '한결': 1,
#  '친절': 11,
#  '바니': 3,
#  '팔레': 2,
#  '그랜드': 1,
#  '부산': 29,
#  '바로': 61,
#  '칠리': 15,
#  '코스': 16,
#  '주': 28,
#  '문하': 19,
#  '알': 21,
#  '튀김': 31,
#  '옷': 3,
#  '양념': 33,
#  '코팅': 1,
#  '탕후루': 10,
#  '식감': 9,
#  '쏨땀': 3,
#  '북촌': 1,
#  '태국': 25,
#  '음식점': 9,
#  '화양연화': 2,
#  '첫': 12,
#  '등장': 1,
#  '생김새': 1,
#  '심상': 1,
#  '찮다': 1,
#  '콤함': 2,
#  '이루': 1,
#  '반적': 6,
#  '훌륭': 3,
#  '귤': 4,
#  '욤뇸': 2,
#  '로그': 25,
#  '대하': 5,
#  '사': 18,
#  '서영수': 1,
#  '법': 29,
#  '파티': 8,
#  '구이': 19,
#  '라면': 17,
#  '보기': 11,
#  '었는데': 4,
#  '안주': 37,
#  '안산': 5,
#  '한식': 25,
#  '해석': 1,
#  '히든': 1,
#  '일품': 3,
#  '항': 2,
#  '정숙': 1,
#  '회': 18,
#  '항정': 1,
#  '냉소': 4,
#  '육회': 5,
#  '전통주': 1,
#  '막걸리': 1,
#  '삼천포': 1,
#  '쩐쭈': 1,
#  '맹글어': 1,
#  '도우': 7,
#  '피자': 108,
#  '두': 25,
#  '최대': 1,
#  '크리': 3,
#  '지기': 3,
#  '겹겹이': 1,
#  '품격': 2,
#  '크레이프': 4,
#  '샌드': 3,
#  '일명': 2,
#  '나폴리': 1,
#  '씬': 1,
#  '쫄깃': 5,
#  '도미노피자': 9,
#  '공식': 6,
#  '광장': 3,
#  '코': 16,
#  '중국집': 2,
#  '개화': 2,
#  '계절': 3,
#  '콩국수': 4,
#  '현수막': 1,
#  '예전': 5,
#  '마': 26,
#  '차이': 4,
#  '상호': 1,
#  '호호': 5,
#  '렐라': 1,
#  '거림': 1,
#  '운정': 3,
#  '금별': 6,
#  '맥주': 30,
#  '산내': 1,
#  '마을': 11,
#  '야외': 2,
#  '테이블': 28,
#  '버너': 1,
#  '남편': 17,
#  '차로': 4,
#  '사모님': 1,
#  '백합': 1,
#  '조개': 5,
#  '술찜': 3,
#  '슈': 2,
#  '니슈': 1,
#  '행복': 28,
#  '도넛': 51,
#  '노티': 21,
#  '잠실': 35,
#  '송리단길': 5,
#  '스트로베리': 1,
#  '라즈베리': 1,
#  '취향': 26,
#  '인지': 8,
#  '묵': 2,
#  '직하': 3,
#  '삼삼': 1,
#  '진땅': 1,
#  '핫도그': 22,
#  '건대': 3,
#  '혼밥': 23,
#  '로스': 5,
#  '커먼그라운드': 2,
#  '거나': 3,
#  '핫': 26,
#  '치토스': 2,
#  '엘': 1,
#  '떼': 8,
#  '옥수수': 10,
#  '밀크쉐이크': 7,
#  '소하': 8,
#  '삼성역': 5,
#  '피': 18,
#  '인더': 3,
#  '코엑스': 13,
#  '반짝': 28,
#  '다가': 32,
#  '사라': 2,
#  '의외': 2,
#  '게': 27,
#  '입구': 19,
#  '팬더': 4,
#  '나들이': 9,
#  '조': 6,
#  '이맘': 7,
#  '품절': 8,
#  '애월': 1,
#  '랜': 11,
#  '디스': 15,
#  '프리터': 1,
#  '글레이': 1,
#  '버터크림': 1,
#  '인기': 53,
#  '일찍': 3,
#  '조이': 1,
#  '왕가': 6,
#  '빙수': 14,
#  '동두천': 2,
#  '여태': 1,
#  '제일': 28,
#  '자주': 13,
#  '행점': 1,
#  '의정부': 6,
#  '노맛': 1,
#  '가요': 4,
#  '리': 42,
#  '상': 13,
#  '아이스크림': 21,
#  '수원': 15,
#  '폴바': 14,
#  '셋': 18,
#  '커피': 147,
#  '직접': 16,
#  '룽': 3,
#  '아이스': 12,
#  '아메리카노': 21,
#  '상하이': 1,
#  '목장': 6,
#  '토핑': 12,
#  '라떼': 41,
#  '라스': 1,
#  '달달': 18,
#  '집들이': 42,
#  '돼지갈비': 11,
#  '굽': 2,
#  '기만': 2,
#  '정인': 5,
#  '밀': 8,
#  '키트': 5,
#  '안내서': 1,
#  '베블': 1,
#  '식탁': 2,
#  '연남동': 24,
#  '데이트': 28,
#  '윤성용': 2,
#  '레스토랑': 29,
#  '특선': 1,
#  '둥지': 3,
#  '엔초': 1,
#  '파스타': 77,
#  '콰트로': 3,
#  '포르마': 1,
#  '레몬에이드': 2,
#  '콜라': 6,
#  '홍대': 34,
#  '홍진': 1,
#  '마제': 3,
#  '바': 29,
#  '에비덴': 2,
#  '방배역': 1,
#  '백': 5,
#  '소정': 9,
#  '대로': 6,
#  '역': 13,
#  '자루': 2,
#  ...}

# %%
#단어와 빈도수를 열 이름으로 사용
df = pd.DataFrame(list(df.items()),
                   columns=['단어', '빈도수'])
df
# Out:
#         단어   빈도수
# 0      이치란    14
# 1       라멘    25
# 2       주문   183
# 3       방법    47
# 4       메뉴  2935
# ...    ...   ...
# 5702    용인     1
# 5703    기흥     1
# 5704    필레     1
# 5705    원도     1
# 5706  바리스타     1
#
# [5707 rows x 2 columns]

# %%
#빈도수 내림차순으로 정력
df = df.sort_values(by='빈도수',ascending=False)
df
# Out:
#         단어   빈도수
# 4       메뉴  2935
# 5       추천  2551
# 7       맛집   618
# 151     가격   207
# 71      어요   202
# ...    ...   ...
# 3437    정강     1
# 3439    리그     1
# 3440     램     1
# 3442    경품     1
# 5706  바리스타     1
#
# [5707 rows x 2 columns]

# %%
df.to_csv('word.csv',

                 sep=',',

                 na_rep='NaN', 

                 float_format = '%.2f', # 2 decimal places

                 columns = ['단어', '빈도수'], # columns to write

                 index = False) # do not write index

# %%
df1 = pd.read_csv('foodinfo1.csv')
df1 = df1.rename(columns={'대표식품명':'단어'})
df1
# Out:
#         식품대분류명     단어  에너지(kcal)  단백질(g)
# 0    곡류, 서류 제품     팝콘        511    8.30
# 1          과일류     과일         43    0.47
# 2          구이류  가자미구이        123   18.70
# 3          구이류   갈치구이        138   21.54
# 4          구이류  고등어구이        340   23.38
# ..         ...    ...        ...     ...
# 719        튀김류    치즈볼        333    9.56
# 720        튀김류   치즈스틱        329   12.59
# 721        튀김류   치킨까스        296   13.96
# 722        튀김류   깐쇼새우        150    7.90
# 723        튀김류   동태까스        273   11.60
#
# [724 rows x 4 columns]

# %%
df2 = pd.read_csv('word.csv')

df2
# Out:
#         단어   빈도수
# 0       메뉴  2935
# 1       추천  2551
# 2       맛집   618
# 3       가격   207
# 4       어요   202
# ...    ...   ...
# 5702    정강     1
# 5703    리그     1
# 5704     램     1
# 5705    경품     1
# 5706  바리스타     1
#
# [5707 rows x 2 columns]

# %%
df3 = pd.merge(df1, df2)
df3
# Out:
#         식품대분류명    단어  에너지(kcal)  단백질(g)  빈도수
# 0    곡류, 서류 제품    팝콘        511    8.30    3
# 1          과일류    과일         43    0.47    7
# 2          구이류  갈치구이        138   21.54    3
# 3          구이류    곱창        184   14.89    8
# 4          구이류    꼬치        245   17.85    1
# ..         ...   ...        ...     ...  ...
# 208        튀김류   깐풍기        295   13.10    1
# 209        튀김류   돈까스        262   14.46   43
# 210        튀김류   치즈볼        333    9.56    4
# 211        튀김류  치즈스틱        329   12.59    1
# 212        튀김류  치킨까스        296   13.96    1
#
# [213 rows x 5 columns]

# %%
df3 = df3.sort_values(by='빈도수',ascending=False)
df3 = df3.set_index('단어')
df3
# Out:
#            식품대분류명  에너지(kcal)  단백질(g)  빈도수
# 단어
# 치킨            튀김류        257   17.17  172
# 커피        음료 및 차류          3    0.33  147
# 버거        빵 및 과자류        208   10.47  125
# 피자        빵 및 과자류        274   10.68  108
# 치즈     유제품류 및 빙과류        273    8.96   90
# ...           ...        ...     ...  ...
# 소세지빵      빵 및 과자류        319   10.37    1
# 해물칼국수     면 및 만두류         77    3.09    1
# 무조림           조림류         48    2.26    1
# 비빔면       면 및 만두류        153    5.70    1
# 치킨까스          튀김류        296   13.96    1
#
# [213 rows x 4 columns]

# %%
df3
# Out:
#            식품대분류명  에너지(kcal)  단백질(g)  빈도수
# 단어
# 치킨            튀김류        257   17.17  172
# 커피        음료 및 차류          3    0.33  147
# 버거        빵 및 과자류        208   10.47  125
# 피자        빵 및 과자류        274   10.68  108
# 치즈     유제품류 및 빙과류        273    8.96   90
# ...           ...        ...     ...  ...
# 소세지빵      빵 및 과자류        319   10.37    1
# 해물칼국수     면 및 만두류         77    3.09    1
# 무조림           조림류         48    2.26    1
# 비빔면       면 및 만두류        153    5.70    1
# 치킨까스          튀김류        296   13.96    1
#
# [213 rows x 4 columns]

# %%
df3 = df3.reset_index()
df3
# Out:
#         단어      식품대분류명  에너지(kcal)  단백질(g)  빈도수
# 0       치킨         튀김류        257   17.17  172
# 1       커피     음료 및 차류          3    0.33  147
# 2       버거     빵 및 과자류        208   10.47  125
# 3       피자     빵 및 과자류        274   10.68  108
# 4       치즈  유제품류 및 빙과류        273    8.96   90
# ..     ...         ...        ...     ...  ...
# 208   소세지빵     빵 및 과자류        319   10.37    1
# 209  해물칼국수     면 및 만두류         77    3.09    1
# 210    무조림         조림류         48    2.26    1
# 211    비빔면     면 및 만두류        153    5.70    1
# 212   치킨까스         튀김류        296   13.96    1
#
# [213 rows x 5 columns]

# %%
df3['날씨구분'] = 'normal'
df3
# Out:
#         단어      식품대분류명  에너지(kcal)  단백질(g)  빈도수    날씨구분
# 0       치킨         튀김류        257   17.17  172  normal
# 1       커피     음료 및 차류          3    0.33  147  normal
# 2       버거     빵 및 과자류        208   10.47  125  normal
# 3       피자     빵 및 과자류        274   10.68  108  normal
# 4       치즈  유제품류 및 빙과류        273    8.96   90  normal
# ..     ...         ...        ...     ...  ...     ...
# 208   소세지빵     빵 및 과자류        319   10.37    1  normal
# 209  해물칼국수     면 및 만두류         77    3.09    1  normal
# 210    무조림         조림류         48    2.26    1  normal
# 211    비빔면     면 및 만두류        153    5.70    1  normal
# 212   치킨까스         튀김류        296   13.96    1  normal
#
# [213 rows x 6 columns]

# %%
df3.to_csv('normal_food.csv',index=False)
