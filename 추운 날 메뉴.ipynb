# %%
# 최종 코드
# 블로그 검색 api
# 한 번에 가져오는 개수인 display는 최대 100까지 가능
# start변수 값을 바꿔야 다른 값을 불러옴, 최대 1000까지
# display=100이면 start변수 값을 1, 101, 201, ..., 1000으로 바꿔주면서 해야함
# start는 최대 1000까지 제공하기 때문에, start=1일때랑 start=1001일때랑 결과가 같음


import os
import sys
import urllib.request
def naver_blog(start):
    client_id = "8kZT6kfb83vNesnBvjwj"  # 본인 클라이언트 아이디 넣기
    client_secret = "bj39JaQzAp"  # 본인 클라이언트 시크릿 넣기
    encText = urllib.parse.quote("추운 날 추천 메뉴")

    url = "https://openapi.naver.com/v1/search/blog?query="+encText+"&display=100"+"&start=" + start # json 결과

    file=open("./naver_api_dessert11.json","w+",encoding='UTF8')  # 파일로 저장하기
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        print(response_body.decode('utf-8'))
        file.write(response_body.decode('utf-8'))
        file.close()
    else:
        print("Error Code:" + rescode)
    return response_body.decode('utf-8')

# %%
body = ""
for i in range(1,1000,100) :
    body += naver_blog(str(i))
# Out:
# {
# 	"lastBuildDate":"Wed, 30 Aug 2023 13:55:36 +0900",
# 	"total":123165,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"<b>추운날<\/b> 국물요리 <b>메뉴<\/b><b>추천<\/b>! 풀무원 가쓰오우동 3종 &lt; 정통... ",
# 			"link":"https:\/\/blog.naver.com\/hee_hee_hee\/222931611513",
# 			"description":"아쿠~ 춥다~~ 따뜻한 국물요리가 절로 생각나는 <b>날<\/b>! 그렇다고 뭘 만들긴 살짜쿵 귀찮고 오늘은... 우동간편식<b>추천<\/b> #유부초밥먹을때 #김밥먹을때 #국물 #겨울<b>추천<\/b>음식 #저녁<b>메뉴<\/b><b>추천<\/b> #<b>추운날<\/b><b>메뉴<\/b><b>추천<\/b>",
# 			"bloggername":"♥ 꾱꾱꾱's 하루하루 ♥",
# 			"bloggerlink":"blog.naver.com\/hee_hee_hee",
# 			"postdate":"20221119"
# 		},
# 		{
# 			"title":"저녁<b>메뉴<\/b><b>추천<\/b>_<b>추운날<\/b>저녁_뜨끈한 순두부찌개 만드는 법",
# 			"link":"https:\/\/blog.naver.com\/hicorea1002\/222632268971",
# 			"description":"오늘도 저희 부천 내비이야기 블로그를 방문해주셔서 감사합니다 :) 저녁<b>메뉴<\/b><b>추천<\/b>_<b>추운날<\/b>저녁 뜨끈한 순두부찌개 만드는 법 매일 저녁상이 고민인데요. 사먹기도 질리고 가끔 확 당기는 음식이 생기더라고요.... ",
# 			"bloggername":"부천 내비이야기의 블박썬팅네비매립",
# 			"bloggerlink":"blog.naver.com\/hicorea1002",
# 			"postdate":"20220126"
# 		},
# 		{
# 			"title":"레시피 <b>추운날<\/b> 먹음 더 맛있는... 육수 호로록 캠핑<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\
b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/bsep0206\/223087141000",
# 			"description":"이리 <b>추운<\/b>지 모르겠어요. 패딩을 넣으려다가 다시 꺼냈습니다... ★ 이렇게 <b>추운 날<\/b>에는 따뜻한 국물이... ㅎㅎ 메인 <b>메뉴<\/b>는 심플해요! (원래 찐 맛집이 몇 가지 <b>메뉴<\/b>에만 집중한다는데) 저희도 부대찌개를... ",
# 			"bloggername":"소소한 일상",
# 			"bloggerlink":"blog.naver.com\/bsep0206",
# 			"postdate":"20230429"
# 		},
# 		{
# 			"title":"[수원 천천동] <b>추운 날 추천메뉴<\/b> 만두전골 ‘평양손만두’",
# 			"link":"https:\/\/blog.naver.com\/threehwa\/222562084637",
# 			"description":"맛있고 <b>추운 날<\/b> 몸도 녹이고 속을 든든하게 해준다 일단 익은 쇠고기부터 질기기 전에 먹는다 만두가... 입맛이 없다면 만두전골 <b>추천<\/b> #천천동맛집 #천천동만두전골 #평양손만두 #입맛없을때<b>메뉴<\/b><b>추천<\/b> #수원만두전골",
# 			"bloggername":"정삼화",
# 			"bloggerlink":"blog.naver.com\/threehwa",
# 			"postdate":"20211108"
# 		},
# 		{
# 			"title":"아이들간식 <b>메뉴<\/b><b>추천<\/b> <b>추운날<\/b> 국물요리로 풀무원 가락 유부우동... ",
# 			"link":"https:\/\/blog.naver.com\/khys963\/222916156026",
# 			"description":"아이들간식 <b>메뉴<\/b><b>추천<\/b> <b>추운날<\/b> 국물요리로 풀무원 가락 유부우동 가락 짬뽕우동 먹방 안녕하세요 - ! 요즘 일교차가 심해지면서 아침 저녁으로 너무 쌀쌀 하더라고요 이렇게 <b>추운 날<\/b>엔 뜨끈한 국물요리가 너무... ",
# 			"bloggername":"라미거니네",
# 			"bloggerlink":"blog.naver.com\/khys963",
# 			"postdate":"20221101"
# 		},
# 		{
# 			"title":"간편식 얼큰 고추장 수제비 만들기 <b>추운날<\/b> 저녁 <b>메뉴<\/b><b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/lwg5926\/222957522153",
# 			"description":"요즘같이 <b>추운 날<\/b> 비 오는 <b>날<\/b> 누구나 별다른 재료 준비 없이도 쉽게 먹을 수 있다는 점이 최고의 매력이었던 제품이었다 #요리하다간편식 #롯데PB상품 #롯데요리하다 #롯데마트PB상품 #고추자수제비... ",
# 			"bloggername":"Haggum2 Love",
# 			"bloggerlink":"blog.naver.com\/lwg5926",
# 			"postdate":"20221222"
# 		},
# 		{
# 			"title":"본죽<b>메뉴<\/b><b>추천<\/b> <b>추운날<\/b> 따뜻하고 든든한 한끼",
# 			"link":"https:\/\/blog.naver.com\/zzanggu_9177\/222629980903",
# 			"description":"이렇게 <b>추운날<\/b>에는 저만 따뜻한 음식들이 땡기나요? 그래서 국밥류를 많이 먹기는 하는데 자극적인거... 본죽<b>메뉴<\/b><b>추천<\/b>을 하려고해요 본죽을 시켜먹거나 포장을 많이해서 가서 직접먹어본적은 별로 없었는데... ",
# 			"bloggername":"짱구밍의 일상 블로그",
# 			"bloggerlink":"blog.naver.com\/zzanggu_9177",
# 			"postdate":"20220124"
# 		},
# 		{
# 			"title":"익선동맛집, <b>추운날<\/b> 국물있는 <b>메뉴<\/b> 샤브샤브 <b>추천<\/b>! 온천집",
# 			"link":"https:\/\/blog.naver.com\/ggulunni\/222649559156",
# 			"description":"매섭게 <b>추운날<\/b> 웨이팅 35분만에 들어갔는데 체감은 한시간 기다림 ㅋㅋㅋㅋㅋㅋ ㅜㅜ 이미 추위에 많이... 벌려 #샤브샤브<b>추천<\/b>맛집 #익선동샤브샤브 여기 꼭 가보셔야 해요~~ 너무나 양껏 먹어서 배부르지만 또... ",
# 			"bloggername":"달콤한 일상이 여행이 되다♥",
# 			"bloggerlink":"blog.naver.com\/ggulunni",
# 			"postdate":"20220216"
# 		},
# 		{
# 			"title":"선유도역 <b>추운날<\/b> 먹기 좋은 설렁탕 맛집 직장인 점심 <b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/fpdl5\/222978916427",
# 			"description":"점심 <b>추천<\/b> [이남장] R E V I E W 선유도역에 생긴지 그리 오래되지 않은 50년 전통 이남장이라고 하는 설렁탕집에 방문해보았다. 점심 식사를 하기에 딱 좋은 <b>메뉴<\/b>기도하고 <b>추운날<\/b> 더 생각다는 국물요리라 좋은 것... ",
# 			"bloggername":"매일이, 여행",
# 			"bloggerlink":"blog.naver.com\/fpdl5",
# 			"postdate":"20230109"
# 		},
# 		{
# 			"title":"울산 | 정칼국수, <b>추운날<\/b>엔... 한사바리 점심<b>메뉴<\/b>로 <b>추천<\/b>해요♬",
# 			"link":"https:\/\/blog.naver.com\/csrryq1636\/222644284123",
# 			"description":"정칼국수 <b>메뉴<\/b>판 정칼국수에서는 바지락 칼국수 밖에 안먹어 봤는데 엄마는 들깨 칼국수도 괜찮았다고 하시더라구요: ) 들깨 좋아하시는 분들이라면 들깨 칼국수도 <b>추천<\/b>! 울산에서는 매운칼국수도 인기가 좋은... ",
# 			"bloggername":"아날로그 졔졔♪",
# 			"bloggerlink":"blog.naver.com\/csrryq1636",
# 			"postdate":"20220210"
# 		},
# 		{
# 			"title":"1인샤브샤브, <b>추운날<\/b> 혼밥<b>메뉴<\/b> 국물요리 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/woandos\/222942125663",
# 			"description":"<b>추운날<\/b> 혼밥<b>메뉴<\/b> 국물요리 <b>추천<\/b> 1인 샤브샤브 어때요 혼자서도 맛있어요 ㅎ #집밥요리 #집밥 #1인샤브샤브 #샤브샤브만들기 #혼밥<b>메뉴<\/b> #국물요리 #1인<b>메뉴<\/b><b>추천<\/b> #혼밥 (C)2022.lulu.All right reserved.",
# 			"bloggername":"쓰리맘마",
# 			"bloggerlink":"blog.naver.com\/woandos",
# 			"postdate":"20221130"
# 		},
# 		{
# 			"title":"국물요리 <b>메뉴<\/b><b>추천<\/b> 풀무원 가락 유부우동 <b>추운날<\/b>엔 우동이지",
# 			"link":"https:\/\/blog.naver.com\/huihuinangnang\/222918543420",
# 			"description":"국물요리 <b>메뉴<\/b><b>추천<\/b> 풀무원 가락 유부우동 나는 봄, 여름, 가을, 겨울 상관없이 사계절 우동을 흡입하는... <b>추운날<\/b>엔 역시 국물요리, 면요리지~ 풀무원 우동면은 냉수마찰하여 쫄깃하고 가늘게 뽑은 수타식... ",
# 			"bloggername":"희희낭낭 일상♬",
# 			"bloggerlink":"blog.naver.com\/huihuinangnang",
# 			"postdate":"20221103"
# 		},
# 		{
# 			"title":"오산맛집 개성손만두 <b>추운날<\/b> 생각나는 <b>메뉴<\/b> <b>추천<\/b>!",
# 			"link":"https:\/\/blog.naver.com\/xkrtkdgh\/222928145433",
# 			"description":"<b>추운<\/b>계절 개성손만두 따끈한 국물 한숫가락 어떠세요? 겨울이면 특히 더 생각나는 <b>메뉴<\/b>! 여러분은... <b>추운날<\/b> 특히 더 생각나는 뜨끈한 뚝배기 개인적으로 아주 좋았습니다^^ 가족들과 함께하거나 친구들과 술한잔... ",
# 			"bloggername":"⭕️비상누수탐지⭕️",
# 			"bloggerlink":"blog.naver.com\/xkrtkdgh",
# 			"postdate":"20221115"
# 		},
# 		{
# 			"title":"[옛날곱창마을 본점] 곱창전골맛집 저녁<b>메뉴<\/b> <b>추운날추천<\/b>음식",
# 			"link":"https:\/\/blog.naver.com\/ham4970\/222903365889",
# 			"description":"안녕하세요 ㅎㅎ 저녁<b>메뉴<\/b>로 이것저것 엄청 생각했는데 이렇게 <b>추운날<\/b>에는 다른거 싹 잊어버리고... 동생에게 <b>추천<\/b>을 해달라고 하니 전골이면 돼지죠... 이래서 옥훼이~~~ 바로 돼지곱창전골로 주문~~!! 돼지곱창... ",
# 			"bloggername":"미미밍님의 이것저것 블로그",
# 			"bloggerlink":"blog.naver.com\/ham4970",
# 			"postdate":"20221018"
# 		},
# 		{
# 			"title":"<b>추운 날<\/b> 국물 <b>메뉴<\/b> 뼈해장국 잘하는 집 - 종로 5가 &quot;조가네... ",
# 			"link":"https:\/\/blog.naver.com\/clare0802\/222954302068",
# 			"description":"같은 <b>날<\/b> 얼큰한 해장국 괜찮지 않나요?? #종로5가맛집#종로5가조가네뼈해장국#종로5가점심<b>메뉴<\/b><b>추천<\/b>... 종로맛집<b>추천<\/b> 종로 3가에는 은근 국물 <b>메뉴<\/b> 먹을만한 곳이 없어서 사무실에서 좀 걸어야 하지만 <b>추운 날<\/b>은... ",
# 			"bloggername":"Moving Forward",
# 			"bloggerlink":"blog.naver.com\/clare0802",
# 			"postdate":"20221213"
# 		},
# 		{
# 			"title":"신림역 <b>추운 날<\/b> 집에서 먹기 좋은 밀키트 <b>추천<\/b> &lt;밥끼&gt;",
# 			"link":"https:\/\/blog.naver.com\/qkfntm1234\/222963343727",
# 			"description":"무섭네요 하루하루 일어나는게 추워서 너무 무서워요 ㅋㅋㅋㅋㅋㅋ 이렇게 <b>추운 날<\/b> 밖에 나가기도... 오늘의 <b>추천메뉴<\/b>를 골라주시네요 ㅎㅎ 만두류가 1,500원.. 저는 하나 샀습니다 확대하기 싫으신 분 들을 위한... ",
# 			"bloggername":"동맨달",
# 			"bloggerlink":"blog.naver.com\/qkfntm1234",
# 			"postdate":"20221223"
# 		},
# 		{
# 			"title":"<b>추운날 추천메뉴<\/b> 추천음식 사골칼국수 드셔보세요",
# 			"link":"https:\/\/blog.naver.com\/kennyg2\/222700531406",
# 			"description":"오늘의 메뉴 사골칼국수 메인 메뉴인 사골칼국수에요. 명동에 있는 명동교자 면 처럼 얇은 면이라... 추운 날씨 뜨끈한 칼국수 추천 해 봅니다. <b>추운날 추천메뉴<\/b> 추천음식 사골칼국수 드셔보세요 #본사구내식당... ",
# 			"bloggername":"아빠는 MD다",
# 			"bloggerlink":"blog.naver.com\/kennyg2",
# 			"postdate":"20220414"
# 		},
# 		{
# 			"title":"찌개지존&quot;, <b>추운 날<\/b> 식사로도 좋고 술 한 잔도 좋은 집 \/<b>메뉴<\/b>O... ",
# 			"link":"https:\/\/blog.naver.com\/g_dori_\/222960439722",
# 			"description":"오늘은 요즘같이 <b>추운<\/b> 한파에서 간단한 식사! 혹은 따끈한 술안주로도 좋은 찌개지존 리뷰... 적극 <b>추천<\/b>드리는 김치찌개 고추장찌개에 닭을 풍덩 끓인 그런 음식! 이 <b>추운 날<\/b> 간단한 식사 대용으로도 강추... ",
# 			"bloggername":"움직이지 않으면,변하는것은 없다",
# 			"bloggerlink":"blog.naver.com\/g_dori_",
# 			"postdate":"20221219"
# 		},
# 		{
# 			"title":"점심 <b>메뉴<\/b> <b>추천<\/b> - <b>추운 날<\/b>에는 짬뽕 점심 식사",
# 			"link":"https:\/\/blog.naver.com\/story8081\/222970171215",
# 			"description":"&lt; 점심 <b>메뉴<\/b> <b>추천<\/b> - <b>추운 날<\/b>에는 짬뽕 점심 식사 &gt; 날씨가 많이 추워져서 점심이면 뜨끈한 음식이 많이 생각납니다. 원래부터 짬뽕을 좋아해서 자주 먹고 있습니다. 하지만, 요즘에는 더 많이 찾고 있네요. <b>추운<\/b>... ",
# 			"bloggername":"카스와 제동이와 사랑하는와이파이...그리고 \"둥이\"",
# 			"bloggerlink":"blog.naver.com\/story8081",
# 			"postdate":"20221230"
# 		},
# 		{
# 			"title":"[인천] 혼밥 <b>메뉴<\/b> <b>추천<\/b>, <b>추운 날<\/b>에 뜨뜻한 국밥 한 그릇... ",
# 			"link":"https:\/\/blog.naver.com\/6ob_e\/222644268953",
# 			"description":"혼밥 <b>메뉴<\/b>로 어떤 음식을 즐겨드시나요 저는 오늘 혼밥 <b>메뉴<\/b> 고민 중에 동네에 갈비찜 맛있다고 들었던 곽만근 갈비탕집에 왔습니다 인천광역시 서구 원당대로 665 완정역 다이소있는 라인에 위치해있어요 매일... ",
# 			"bloggername":"AU PUH",
# 			"bloggerlink":"blog.naver.com\/6ob_e",
# 			"postdate":"20220210"
# 		},
# 		{
# 			"title":"<b>추운날<\/b> 딱인 마곡나루전집 <b>추천<\/b> : 그날전집",
# 			"link":"https:\/\/blog.naver.com\/worklog\/222943009820",
# 			"description":"업무왕입니다:) 날씨가 엄청 <b>추운<\/b> 요즘에 딱 어울리는 전집을 <b>추천<\/b>드려요. 요즘 같은 날씨에는 일반... 마곡나루에는 전집이 많지 않은데 <b>추운날<\/b> 막걸리 한잔 하고 싶을 때 그날전집을 방문해 보세요! P.S... ",
# 			"bloggername":"업무왕의 이것저것",
# 			"bloggerlink":"blog.naver.com\/worklog",
# 			"postdate":"20221201"
# 		},
# 		{
# 			"title":"육간청 : 구디 갈비탕 ! <b>추운날<\/b> 점심 <b>메뉴<\/b>로 <b>추천<\/b>해요",
# 			"link":"https:\/\/blog.naver.com\/panguuin\/222966288843",

# 		},
# 		{
# 			"title":"<b>추운날<\/b> 딱인 스지어묵전골 밀키트<b>추천<\/b>해요 (밀팡 밀키트)",
# 			"link":"https:\/\/blog.naver.com\/pmkhi\/222606815061",
# 			"description":"외식이 걱정되는 시기로 나가서 외식하기 힘들어지니 특별한 <b>메뉴<\/b>가 먹고 싶을때는 밀팡 밀키트에서 주문해보는데요~ 이번에 주문한 밀키트 <b>메뉴<\/b>는 <b>추운날<\/b> 딱인 스지어묵전골 밀키트<b>추천<\/b>해요. 밀팡 밀키트 중... ",
# 			"bloggername":"이웃세상속에서~~",
# 			"bloggerlink":"blog.naver.com\/pmkhi",
# 			"postdate":"20211228"
# 		},
# 		{
# 			"title":"[홍대맛집<b>추천<\/b>] <b>추운날<\/b> 제격이야! 순대만두전골 맛집, 홍대 순만골",
# 			"link":"https:\/\/blog.naver.com\/jijinew\/222996333589",
# 			"description":"<b>추천<\/b> 홍대 순만골 요즘 진짜 너무 춥다......ㅠ_ㅠ 가만히 있어도 몸이 덜덜 떨리는 날씨! 이런 <b>날<\/b>... &lt; 술을 술술 부르는 맛이지만 저는 콜라로^^... <b>추운날<\/b> 제격이었던 순만골이었습니다!!!",
# 			"bloggername":"노는게 제일 좋아 ♥",
# 			"bloggerlink":"blog.naver.com\/jijinew",
# 			"postdate":"20230127"
# 		},
# 		{
# 			"title":"<b>추운날<\/b>엔 김치뚝배기우동에 수제돈까스, 마곡 직장인이 <b>추천<\/b>하... ",
# 			"link":"https:\/\/blog.naver.com\/sinnasbored\/223040412832",
# 			"description":"사장님 센스~ 이렇게 테이블마다 종이컵과 그라인더 소금 &amp; 후추가 준비되어 있어요 <b>메뉴<\/b> Menu... 술 마신 다음날, <b>추운 날<\/b>, 매콤한 게 땡기는날에는 무조건 김치뚝배기우동 <b>추천<\/b>드려요... 국물이 일단 정말... ",
# 			"bloggername":"시나의 Days",
# 			"bloggerlink":"blog.naver.com\/sinnasbored",
# 			"postdate":"20230310"
# 		},
# 		{
# 			"title":"<b>추운날<\/b> 마포 만복국수집 멸치쌀국수 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/rmffhqjftpffj1104\/223022789651",
# 			"description":"직장인점심<b>메뉴<\/b> 강력<b>추천<\/b> <b>추운날<\/b> #만복국수집 #멸치쌀국수 먹으러간날 구내식당 밥이 질리고 바람 휭휭불어~ #레트로식당 같은 만복국수집을 들어갔다. #잔치국수 는 <b>메뉴<\/b>에 없는데 잔치국수의 #멸치육수 와... ",
# 			"bloggername":"오작교 통신의 라이프스토리",
# 			"bloggerlink":"blog.naver.com\/rmffhqjftpffj1104",
# 			"postdate":"20230221"
# 		},
# 		{
# 			"title":"구월동 쌀국수 날이 <b>추운날 추천<\/b>! 포메인 레드 구월점",
# 			"link":"https:\/\/blog.naver.com\/songme00\/222970206603",
# 			"description":"미리 <b>메뉴<\/b>를 보고가시면 좋을거같아서 <b>메뉴<\/b>판 사진도 한번 찍어드립니다! 포메인 레드 구월점... 한번 방문해보시길! 저도 날씨가 <b>추운날<\/b>에는 쌀국수는 자주 즐겨먹는 편인데, 포메인이 정말 1등임용!",
# 			"bloggername":"동쓰",
# 			"bloggerlink":"blog.naver.com\/songme00",
# 			"postdate":"20221230"
# 		},
# 		{
# 			"title":"<b>추운 날<\/b> 차돌 떡볶이 끓여먹기, 청년다방 강원인제점 <b>추천<\/b>!... ",
# 			"link":"https:\/\/blog.naver.com\/harveyjeremy\/222934426640",
# 			"description":"<b>메뉴<\/b>.(슬라이드를 넘겨주세요.) 즉석떡볶이 종류가 아주 많습니다. 치킨이나 사이드도 있어요.... 청년다방 몇 년 전에 가고 오랜만이었는데 아주 만족스러웠습니다. 다들 <b>추운 날<\/b> 뜨끈한 즉석떡볶이 <b>추천<\/b>이에요~",
# 			"bloggername":"체험보고서",
# 			"bloggerlink":"blog.naver.com\/harveyjeremy",
# 			"postdate":"20221121"
# 		},
# 		{
# 			"title":"<b>추운날<\/b>에 저절로 생각나는 샤브샤브, 칼국수 \/ 현지인<b>추천<\/b>맛집... ",
# 			"link":"https:\/\/blog.naver.com\/apricotso\/222998547830",
# 			"description":"<b>추운 날<\/b> 생각나는, 따끈따끈한  동해 등촌샤브칼국수 매주 수요일 정기휴무 고등학생 시절부터 맛있다고 <b>추천<\/b>받은 곳인데 약 .. 10년이 지나서야 <b>추천<\/b>받은 맛집을 가보는 나.. 뭐 늦더라도 가봤으면 된 거지... ",
# 			"bloggername":"라챠챠 우와",
# 			"bloggerlink":"blog.naver.com\/apricotso",
# 			"postdate":"20230130"
# 		},
# 		{
# 			"title":"맛있는 소고기 수육 만들기, <b>추운날<\/b> 어린이 보양식 <b>추천<\/b>✌️",
# 			"link":"https:\/\/blog.naver.com\/440\/223027432524",
# 			"description":"좋은 <b>메뉴<\/b>에요 수육에 육수+참소스 살짝뿌려냠냠 어른용 고기큼직한 육개장 <b>추운날<\/b> 온가족이 맛있게 보양할수있으니 코스트코 가실때 한덩이씩 쟁여놨다가 시간있을때 푹 끓여서 다같이 드시는거 <b>추천<\/b>드려요... ",
# 			"bloggername":"김엄마의 헤롱로그",
# 			"bloggerlink":"blog.naver.com\/440",
# 			"postdate":"20230225"
# 		},
# 		{
# 			"title":"[가디역 맛집 <b>추천<\/b>] <b>추운 날<\/b> 매콤한 짬뽕이 먹고 싶다면... ",
# 			"link":"https:\/\/blog.naver.com\/ksbookup\/222954832936",
# 			"description":"<b>추천<\/b>] <b>추운 날<\/b> 매콤한 짬뽕이 먹고 싶다면♬ &lt;홍콩반점 0410&gt; 안녕하세요 여러분! 급격히 추워진 날씨에 자연스럽게 따뜻한 게 당기는 요즘인데요~ 저는 눈이 오늘 오늘! 지감의 동료들과 함께 중식을 점심 <b>메뉴<\/b>로... ",
# 			"bloggername":"도서출판 지식과감성# 공식블로그",
# 			"bloggerlink":"blog.naver.com\/ksbookup",
# 			"postdate":"20221213"
# 		},
# 		{
# 			"title":"온정손만두호매실점_<b>추운날<\/b>엔 따뜻한 칼국수와 만두<b>추천<\/b>!!",
# 			"link":"https:\/\/blog.naver.com\/bicviruslee\/222586716179",
# 			"description":"겨울에맛있는, #추운날가볼만한 요즘같이 날씨가 추울때, 방문하기 좋은 추천식당입니다.... 만두를 살짝깨서 국물과 함께 드세요~ 그러면 국물이 더더 담백하고 맛나요 ^^ㅋㅋ <b>추운날 추천메뉴<\/b> 따뜻한 &quot;칼국수&quot;",
# 			"bloggername":"행복을 주는 블로그",
# 			"bloggerlink":"blog.naver.com\/bicviruslee",
# 			"postdate":"20211204"
# 		},
# 		{
# 			"title":"[성수완당] <b>추운날<\/b> 더 맛있는... 맛조합 <b>추천<\/b> 내먹내산(+<b>메뉴<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/rin_onme\/222904388413",
# 			"description":"들어가자마자 보이는 키오스크에서 간단하게 주문가능해요 다른 <b>메뉴<\/b>도 도전해볼망 한데 항상 고정픽은 역시 #완당면 입니다 공간이 큰 편은 아니지만, 바테이블도 있고 2인용, 4인용 테이블이 골고루 있어요... ",
# 			"bloggername":"스쳐가는 일상에 이링 더하기+",
# 			"bloggerlink":"blog.naver.com\/rin_onme",
# 			"postdate":"20221019"
# 		},
# 		{
# 			"title":"[강남] <b>추운날<\/b> 직딩 점심<b>메뉴<\/b> 강남교자",
# 			"link":"https:\/\/blog.naver.com\/ssung_d\/223005359766",
# 			"description":"<b>추운<\/b> 겨울 직딩 점심<b>메뉴<\/b>로 픽- #칼국수맛집 #교자맛집 - 시그니처 <b>메뉴<\/b> #칼국수 뿐 아니라 설렁탕... 막내 님들, 강남 점심<b>메뉴<\/b>로 남녀노소 즐길수 있는 강남 교자 <b>추천<\/b>합니다!!! ssungD 내돈내산 스코어 ★★★★☆",
# 			"bloggername":"ssungD Life Harmony",
# 			"bloggerlink":"blog.naver.com\/ssung_d",
# 			"postdate":"20230210"
# 		},
# 		{
# 			"title":"알탕은 <b>추운날 추천메뉴<\/b>로 딱인듯요.바다황제는 알탕도... ",
# 			"link":"https:\/\/blog.naver.com\/daniella713\/222975943064",
# 			"description":"점심 추워진 날씨에 뭔가 뜨끈하고 칼칼한 국물에 듬북 알이 들어간 알탕이 먹고 싶어서 대흥동에 해물요리전문점 바다황제를 선택했어요 알탕 먹으러 갔으니 여기 알탕정식 2인분요~~~^^ 밑반찬이 나오는데요... ",
# 			"bloggername":"다붓다붓솝",
# 			"bloggerlink":"blog.naver.com\/daniella713",
# 			"postdate":"20230105"
# 		},
# 		{
# 			"title":"청라맛집 진지방 순대국, <b>추운 날<\/b> 먹기 좋은 국밥",
# 			"link":"https:\/\/blog.naver.com\/tpdud7690\/222950358032",
# 			"description":"다녀올 수 있었어용 요즘 같이 <b>추운 날<\/b> 따뜻한 국물이 많이 생각 나실 거에요! 청라 맛집, 순대국집을 찾으신다면 진지방 순대국 한 번 <b>추천<\/b> 드려볼게요! #청라순대국 #인천서구맛집 #청라맛집 #서구맛집 #순대국맛집",
# 			"bloggername":"봄이 찾아왔어요",
# 			"bloggerlink":"blog.naver.com\/tpdud7690",
# 			"postdate":"20221209"
# 		},
# 		{
# 			"title":"역삼동 점심<b>메뉴<\/b> <b>추천<\/b>!! <b>추운 날<\/b> 호박불고기에서 따뜻한 쌀국수... ",
# 			"link":"https:\/\/blog.naver.com\/ksunhawk\/220192525998",
# 			"description":"역삼동 점심<b>메뉴<\/b> <b>추천<\/b>!! <b>추운 날<\/b> 호박불고기에서 따뜻한 쌀국수 한 그릇 먹고 왔더니 든든해요~~ ☎ 02-566-3100 점심시간만 되면 무엇을 먹을지 항상 행복한 고민을 하죠^^ 오늘 역시 저도 고민을 했습니다!! 행복한... ",
# 			"bloggername":"거칠지만따뜻한덩치 거따덩",
# 			"bloggerlink":"blog.naver.com\/ksunhawk",
# 			"postdate":"20141126"
# 		},
# 		{
# 			"title":"부산정관맛집 부산옹심이칼국수 <b>추운날<\/b> 딱입니다",
# 			"link":"https:\/\/blog.naver.com\/sujin9848\/222954609081",
# 			"description":"직원분이 <b>추천<\/b>해서 시켜본 <b>메뉴<\/b>입니다 옹심이가 궁금해서 매번 시켜볼려고하다가 그냥 먹던<b>메뉴<\/b> 먹자싶어서 안먹어봤는데 요즘처럼 <b>추운날<\/b>은 뜨끈뜨끈한 <b>메뉴<\/b>가 제일이죠! 칼국수에 들어가는 면도... ",
# 			"bloggername":"러블리수지니의 달달한 하루",
# 			"bloggerlink":"blog.naver.com\/sujin9848",
# 			"postdate":"20221213"
# 		},
# 		{
# 			"title":"<b>추운날<\/b> 만나기 좋은 약속장소 고터맛집 일본가정식 호호식당",
# 			"link":"https:\/\/blog.naver.com\/gamejaki\/222971081105",
# 			"description":"이렇게 <b>추운 날<\/b>은 딱인 장소이고 우리 셋 만나기 중간지점쯤이기도 해요 맛집 리스트 여러 개... 셋이서 <b>메뉴<\/b> 3개를 시켰어요 우나기동 명란파스타 오므라이스 먹다 보니 뭔가 좀 아쉽다? 호호식당은 진짜... ",
# 			"bloggername":"찍찍부인 이야기",
# 			"bloggerlink":"blog.naver.com\/gamejaki",
# 			"postdate":"20221231"
# 		},
# 		{
# 			"title":"알 도루묵구이와 시사모구이 여기가찐 <b>추운 날<\/b> 생각나는 곳",
# 			"link":"https:\/\/blog.naver.com\/zzyongimda\/222941434184",
# 			"description":"냈던 <b>날<\/b> 낮에 방문했는데 낮에도 이미 거의 만석이더라구요 여전한 인기에 깜짝 놀랐습니다... 전문적인 <b>메뉴<\/b> 도루묵구이와 시사모구이를 맛볼 수 있어서 좋은 <b>추운날<\/b> 생각나는 곳 , 을지오뎅 <b>추천<\/b>합니다... ",
# 			"bloggername":"zzyongimda",
# 			"bloggerlink":"blog.naver.com\/zzyongimda",
# 			"postdate":"20221129"
# 		},
# 		{
# 			"title":"<b>추운 날<\/b> 푸짐한 부대찌개 - 간편한 햄 고기 듬뿍 부대찌개",
# 			"link":"https:\/\/blog.naver.com\/sua8044\/222967218477",
# 			"description":"<b>추운 날<\/b> 푸짐한 부대찌개 - 간편한 햄 고기 듬뿍 부대찌개 글, 사진 뚜아 날씨가 추워지고 나서는 자꾸만... 국물요리도 여러 가지가 있지만 아이들도 잘 먹어주는 부대찌개가 우리 집 단골 <b>메뉴<\/b>이다. 진한... ",
# 			"bloggername":"수요일 :: 수아네요리일상",
# 			"bloggerlink":"blog.naver.com\/sua8044",
# 			"postdate":"20221227"
# 		},
# 		{
# 			"title":"<b>추운날<\/b> 점심<b>메뉴<\/b><b>추천<\/b> 종로맛집 칼국수맛집 '대원'",
# 			"link":"https:\/\/blog.naver.com\/jooart_vely\/220601523190",
# 			"description":"겨울에 진짜 이만한 <b>메뉴<\/b>는 없는것같아요 ㅠㅠ 다들오늘 점심으로 어떠신지 ㅎㅎ 이렇게 김치랑 먹으면 최고로 맛있어요! ㅎㅎㅎ 포스팅하면서 보니깐 또 생각나네요~ 다들 엄청<b>추운<\/b>데 따뜻한 국물드셔요ㅜㅜ... ",
# 			"bloggername":"JOOJY의 블로그 : )",
# 			"bloggerlink":"blog.naver.com\/jooart_vely",
# 			"postdate":"20160119"
# 		},
# 		{
# 			"title":"[구리\/갈매동맛집] <b>추운날<\/b> 생각나는 본추어탕(내돈내산)",
# 			"link":"https:\/\/blog.naver.com\/crystal00000\/222955972493",
# 			"description":"날씨 <b>추운날<\/b>에는 따뜻한 보양식이 더 땡기는거 같아요 ㅎㅎ 별내에 탐터추어탕갈까하다가 이날은... 가시길 <b>추천<\/b>해드려요 ㅎㅎ 배고파서 먹을 생각만 하다가 본추어탕 <b>메뉴<\/b>판도 하나 못찍었네여 ㅠㅠ 추어탕... ",
# 			"bloggername":"소소한 일상, 크리슈어",
# 			"bloggerlink":"blog.naver.com\/crystal00000",
# 			"postdate":"20221214"
# 		},
# 		{
# 			"title":"레트로 감성 마포역 술집 ! <b>추운날<\/b> 칼칼한 애호박 칼국수 동리장",
# 			"link":"https:\/\/blog.naver.com\/cks6170837\/222960913296",
# 			"description":"<b>추운날<\/b> 칼칼한 애호박 칼국수 동리장 요즘 같이 <b>추운날<\/b> 따뜻한 국물이 넘 땡기더라고요 너무 맛있던... 동리장의 <b>메뉴<\/b>판이에요!! 주로 애호박찌개와 꼬막비빔밥, 수육, 전이 맛있거든요 칼칼한 애호박 칼국수가... ",
# 			"bloggername":"루나나나나",
# 			"bloggerlink":"blog.naver.com\/cks6170837",
# 			"postdate":"20221220"
# 		},
# 		{
# 			"title":"서초 칼국수 <b>추운 날<\/b> 생각나는 백합이야기",
# 			"link":"https:\/\/blog.naver.com\/2gayoung9\/222942417952",
# 			"description":"ㅎㅎㅋㅋ 지난번 교대쪽에 약속이 있어서 다녀왔는데 오늘 같이 <b>추운 날<\/b> 딱 생각나는 서초 칼국수를... 식사류로는 대표<b>메뉴<\/b>인 백합 칼국수가 있는데 탕도 먹고 싶고, 구이, 볶음을 다 먹고 싶은 분들을 위한... ",
# 			"bloggername":"가용이와 여행가용",
# 			"bloggerlink":"blog.naver.com\/2gayoung9",
# 			"postdate":"20221130"
# 		},
# 		{
# 			"title":"[성남\/분당] 더운날도, <b>추운날<\/b>도 맛있는 :: 평가옥 :: 평냉+온반",
# 			"link":"https:\/\/blog.naver.com\/vanillashu\/223049303760",
# 			"description":"더운날은 평양냉면 <b>추운날<\/b>은 온반(닭고기 <b>추천<\/b>) 봄인데 왜 요즘 쌀쌀하죠? 저녁만 되면 으슬으슬하고..... 예의상 <b>메뉴<\/b>~ 월급받던 시절엔 어복쟁반으로 기분도 내고 그랬는데 ㅋㅋㅋ 이젠 뭐 많이 먹지도 못하고... ",
# 			"bloggername":"serein",
# 			"bloggerlink":"blog.naver.com\/vanillashu",
# 			"postdate":"20230319"
# 		},
# 		{
# 			"postdate":"20220104"
# 		},
# 		{
# 			"title":"<b>추운날 추천메뉴<\/b> 범계만두전골 성경만두요리전문점",
# 			"link":"https:\/\/blog.naver.com\/gag3515\/221192962179",
# 			"description":"많은분들이 <b>추운날 추천메뉴<\/b>로 만두전골을 택하셔서 그런지.. 점심시간 전부터 예약석도 많고 북적북적하네요. 동생이 먼저 다녀오고 너무 맛있다고 해서 추천해준 곳인데요. 저도 이 맛있는걸 먹기 위해... 이... ",
# 			"bloggername":"이쯔모다욧_私の人生はいつもダイエット。",
# 			"bloggerlink":"blog.naver.com\/gag3515",
# 			"postdate":"20180125"
# 		},
# 		{
# 			"title":"죽전 맛집 _ 바다양푼이동태탕 용인죽전점, 섞어탕 <b>추운 날<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/cctv070\/222965006603",
# 			"description":"<b>추운날<\/b> 먹으니 더더 맛있더라구요. 겨울에는 한번씩 먹으면 넘 만족스러울 <b>메뉴<\/b>같아요. 수제비는 같이... 먹고 나오면서 <b>추천<\/b>했던 남편이 으쓱해했던 바다양푼이동태탕 집이었어요. #새터마을맛집 이기도 해서... ",
# 			"bloggername":"냠삐공특공대♡",
# 			"bloggerlink":"blog.naver.com\/cctv070",
# 			"postdate":"20221225"
# 		},
# 		{
# 			"title":"<b>추운날<\/b> 점심<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/sham0089\/220886449780",
# 			"description":"오늘 날이 아주 춥네요 오늘같이 <b>추운 날<\/b>씨에는 매콤하거나, 따뜻한 국물이 생각이 납니다 <b>추운날<\/b> 점심으로 <b>추천<\/b>드릴 <b>메뉴<\/b>는 짜잔~! 낙지볶음이에요^^ 매콤하고, 피로한 몸을 풀어줄 낙지볶음 시원한 냉국과... ",
# 			"bloggername":"연우컴퓨터 1.1",
# 			"bloggerlink":"blog.naver.com\/sham0089",
# 			"postdate":"20161215"
# 		},
# 		{
# 			"title":"여수전집 청담앤전_<b>추운날<\/b> 분위기 좋은 여수 여서동 술집 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/cocobono1\/222964157524",
# 			"description":"안주까지 <b>메뉴<\/b>가 다양한 편이다. 가장 좋았던 부분이 신기한 술이 많았다는 점인데, 전집답게 다양한 막걸리와 전통주, 하이볼, 소주 종류를 갖추고 있다. 우리는 가장 인기가 좋은 <b>메뉴<\/b> 중 하나라는... ",
# 			"bloggername":"오늘도 안녕",
# 			"bloggerlink":"blog.naver.com\/cocobono1",
# 			"postdate":"20221224"
# 		},
# 		{
# 			"title":"회기역 맛집 <b>추운날<\/b>엔 역시 감자탕",
# 			"link":"https:\/\/blog.naver.com\/ohmyjudy\/222945403265",
# 			"description":"<b>추운 날<\/b>에 회기역 맛집에서 감자탕을 먹어볼랍니다. 사람들의 마음은 다 똑같은 지 모두들 감자탕을... 만두도 좋아라하고 칼국수도 좋아라하는 저를 위한 <b>메뉴<\/b> 되시것음다. 사골국에 칼국수와 만두를 담아... ",
# 			"bloggername":"도시로 가다.",
# 			"bloggerlink":"blog.naver.com\/ohmyjudy",
# 			"postdate":"20221204"
# 		},
# 		{
# 			"title":"<b>추운날<\/b>
# 			"bloggerlink":"blog.naver.com\/ahapc1004",
# 			"postdate":"20161230"
# 		},
# 		{
# 			"title":"점심<b>메뉴<\/b><b>추천<\/b> <b>추운날<\/b>에는 뜨끈한 소고기국밥",
# 			"link":"https:\/\/blog.naver.com\/blue_rubi\/220908841250",
# 			"description":"점심<b>메뉴<\/b><b>추천<\/b> <b>추운날<\/b>에는 뜨끈한 소고기국밥 직장 동료들과 함께 먹었던 점심<b>메뉴<\/b>!!! 뜨끈한 소고기국밥!! <b>추운날<\/b>에는 뜨끈한 소고기국밥 완전강추!!!!! 직장인들은 점심시간에 점심<b>메뉴<\/b>로 맛있는 음식을 먹는게... ",
# 			"bloggername":"BLUE RUBI DIARY",
# 			"bloggerlink":"blog.naver.com\/blue_rubi",
# 			"postdate":"20170111"
# 		},
# 		{
# 			"title":"시지맛집 공심옥 <b>추운날<\/b> 뜨끈한 갈비탕 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/jessie0325\/222222393395",
# 			"description":"0 공심옥 <b>메뉴<\/b> 가격 기본찬은 간단합니다. 석박지와 백김치를 주시는데, 삼삼하니 맛있습니다. 항상... 어른들 모시고 가서 식사하기도 좋고, <b>추운날<\/b>에는 갈비탕 <b>추천<\/b>드려요^^ 다른날 찍어놓은 사진과... ",
# 			"bloggername":"3月의 羊 (3월의 양)",
# 			"bloggerlink":"blog.naver.com\/jessie0325",
# 			"postdate":"20210127"
# 		},
# 		{
# 			"title":"점심 <b>메뉴<\/b>로 뭐가 좋을까? <b>추운날<\/b> 점심 <b>추천 메뉴<\/b> 5가지 음식!",
# 			"link":"https:\/\/blog.naver.com\/gogipanda\/220169989076",
# 			"description":"<b>추운날<\/b> 점심 <b>추천 메뉴<\/b> 5가지 음식! 어제 주말, 창문을 뒤 흔드는 칼 바람이 무섭게 몰아 치더니 오늘 아침은 목덜미를 지릿하게 만드는 기온이 가을이 끝나감을 알려주는 것 같습니다. 어제 하룻 동안 외출없이... ",
# 			"bloggername":"GOGI판다",
# 			"bloggerlink":"blog.naver.com\/gogipanda",
# 			"postdate":"20141103"
# 		},
# 		{
# 			"title":"전골 수육 <b>추천<\/b> \/ <b>추운날<\/b> 몸보신 복날 음식 최고 \/ 주차장 정보",
# 			"link":"https:\/\/blog.naver.com\/2nomu_life\/222125588752",
# 			"description":"<b>추운날<\/b> <b>메뉴<\/b> 선택 정말 탁월했지 ㅎㅎ 흑염소 고기도 아낌없이 푸짐하게 들어가 있다. 저 양념장 완전 비법소스야.. 감칠맛 뿜뿜 고기능 그냥 먹어도 맛있고, 저 양념소스랑도 완전 찰떡이었다. 나중에 볶음밥... ",
# 			"bloggername":"y-diary",
# 			"bloggerlink":"blog.naver.com\/2nomu_life",
# 			"postdate":"20201025"
# 		},
# 		{
# 			"title":"뜨끈한 국물이 <b>추운날<\/b>에 좋은 저녁<b>메뉴<\/b> '물갈비 만들기'",
# 			"link":"https:\/\/amyzzung.tistory.com\/1449",
# 			"description":"보글 보글 끓여먹는 돼지갈비라~ <b>추운<\/b> 겨울 따뜻한 저녁<b>메뉴<\/b>로 <b>추천<\/b>합니다. 뜨끈한 국물이 <b>추운날<\/b>에 좋은 저녁<b>메뉴<\/b> '물갈비 만들기' 1. 재료 준비 ( 4인분 ) ▣ 주재료 : 돼지갈비찜용 1.2kg, 당면1줌, 당근(대) 5cm... ",
# 			"bloggername":"언젠간 먹고 말거야",
# 			"bloggerlink":"https:\/\/amyzzung.tistory.com\/",
# 			"postdate":"20181203"
# 		},
# 		{
# 			"title":"점심<b>메뉴<\/b><b>추천<\/b> : <b>추운날<\/b> 점심 뭐먹지 고민말고 너로 정했다.",
# 			"link":"https:\/\/blog.naver.com\/pjkn82\/220902023979",
# 			"description":"점심<b>메뉴<\/b><b>추천<\/b> <b>추운날<\/b> 점심 뭐먹지 고민말고 너로 정했다. ㅇ 점심 뭐먹지???하다가 오늘 점심<b>메뉴<\/b><b>추천<\/b>에 있던 우동한그릇!! 뭔가 따뜻한 국물이 맛있을것같아서 한그릇 먹으러왔다. 요즘은 분식집도 아주... ",
# 			"bloggername":"좌충우돌 부산큰행님의블로그",
# 			"bloggerlink":"blog.naver.com\/pjkn82",
# 			"postdate":"20170103"
# 		},
# 		{
# 			"title":"<b>추운날<\/b> 저녁<b>메뉴<\/b>로 회배달 시켜봤어요~",
# 			"link":"https:\/\/blog.naver.com\/csh10042\/220564451188",
# 			"description":"저녁<b>메뉴<\/b>로 회배달로 먹은 이야기를 해볼까해요~ <b>추운날<\/b> 에는 역시 회도 맛있죠~굴 꼬막 등 급 으로... 하기싫은날은 <b>추천<\/b>해드려요 ~ ^^ 이렇게 한상차려놓으니 나름 집에서 한잔 먹을만 하네요~ 오늘은 비까지... ",
# 			"bloggername":"3남매 일상~",
# 			"bloggerlink":"blog.naver.com\/csh10042",
# 			"postdate":"20151210"
# 		},
# 		{
# 			"title":"요즘 같이 <b>추운 날<\/b> 따끈하고 맛있는 라멘~ 부천 맛집 <b>추천<\/b>!!",
# 			"link":"https:\/\/blog.naver.com\/712gram\/221693150094",
# 			"description":"코이라멘 <b>메뉴<\/b> <b>메뉴<\/b>가 간단해서 좋다! 메인 <b>메뉴<\/b>가 딱 세 가지!! 오리지날과 매운라멘, 그리고 차슈덮밥... 진짜진짜 <b>추천<\/b>! 다음에 또가야쥐... 요즘 같이 <b>추운 날<\/b>, 코이라멘 부천역점에서 뜨끈한 라멘 한 그릇... ",
# 			"bloggername":"오늘도 여행지수 100%",
# 			"bloggerlink":"blog.naver.com\/712gram",
# 			"postdate":"20191030"
# 		},
# 		{
# 			"title":"[오늘뭐먹지] <b>추운날<\/b> 점심<b>메뉴<\/b>... 얼큰한 콩나물동태찌개 <b>추천<\/b>★",
# 			"link":"https:\/\/blog.naver.com\/reviewmoa\/100206822992",
# 			"description":"[오늘뭐먹지] <b>추운날<\/b> 점심<b>메뉴<\/b>로 몸속까지 풀어주는 얼큰한 콩나물동태찌개 <b>추천<\/b> 오늘처럼 찬바람 쌩쌩 부는 날엔 점심<b>메뉴<\/b>를 고르는 것도 고민되지만 밖으로 나가 점심을 먹는 것 또한 직장인들에겐 만만치... ",
# 			"bloggername":"울랄라 일상리뷰",
# 			"bloggerlink":"blog.naver.com\/reviewmoa",
# 			"postdate":"20140306"
# 		},
# 		{
# 			"title":"<b>추운 날<\/b>
\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/nagi96\/220571592328",
# 			"description":"나긍 :: 명동 맛집, 명동 점심<b>메뉴<\/b>로 딱인 안동찜닭에서 <b>추운날<\/b>찜닭 먹고왓슈~ 안녕하세요 나긍입니다 :D 명동 안동찜닭에 가서 저녁을 먹고왓어용 근데 왜 점심<b>메뉴<\/b> <b>추천<\/b>이냐면 점심때는 가격도 저렴하고 누룽지... ",
# 			"bloggername":"나긍쓰 블로그",
# 			"bloggerlink":"blog.naver.com\/nagi96",
# 			"postdate":"20151218"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Wed, 30 Aug 2023 13:55:37 +0900",
# 	"total":123165,
# 	"start":101,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"까치산 술집 울랄라포차 꼬막을 <b>추천<\/b> 합니다!! <b>추운날<\/b> 간단히... ",
# 			"link":"https:\/\/blog.naver.com\/109199\/220217374081",
# 			"description":"이렇게 <b>메뉴<\/b>가 많다보니 대체..어떤걸 선택해야 될지 고민을 하던 순간! 꼬막이 눈에 확~~들어 왔어요!... ㅎㅎ 까치산 술집 울랄라포차 의 꼬막을 <b>추천<\/b>!! 특히 <b>추운날<\/b>에 더욱 좋은것 같아요 꼬막 껍데기는 요렇게... ",
# 			"bloggername":"억수르돈되는부동산",
# 			"bloggerlink":"blog.naver.com\/109199",
# 			"postdate":"20141222"
# 		},
# 		{
# 			"title":"살도 많고 칼칼한 국물 <b>추운 날<\/b>에 많이 찾는 점심 <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/kimjj5777\/222540932139",
# 			"description":"벌교읍 조기매운탕 살도 많고 칼칼한 국물 <b>추운 날<\/b>에 많이 찾는 점심 <b>추천 메뉴<\/b> 날씨가 갑자기 추워졌네요. ㅠㅠ 그런데 춥다고 집에만 있을 수도 없잖아요 이럴 때 몸에 좋은 맛있는 음식으로 보양을 해주면... ",
# 			"bloggername":"벌교맛집을 찾아가는 여정",
# 			"bloggerlink":"blog.naver.com\/kimjj5777",
# 			"postdate":"20211018"
# 		},
# 		{
# 			"title":"천안 신부동 맛집 등촌샤브칼국수 요즘처럼 <b>추운 날<\/b> 딱이에요!",
# 			"link":"https:\/\/blog.naver.com\/jeeinomc\/222930332809",
# 			"description":"천안 맛집 등촌샤브칼국수 <b>메뉴<\/b>판 2인 이상이실 경우 대표 <b>메뉴<\/b>인 버섯칼국수를 드시면 될 것 같구요.... 천안 맛집 등촌샤브칼국수 꼭 한번 방문해서 드셔보시길 <b>추천<\/b>드립니다! <b>추운 날<\/b> 감기, 독감, 몸살... ",
# 			"bloggername":"부천지인한의원 - 정성을 다하겠습니다!",
# 			"bloggerlink":"blog.naver.com\/jeeinomc",
# 			"postdate":"20221117"
# 		},
# 		{
# 			"title":"당감동 맛집 수백당 :: <b>추운날<\/b> 뜨끈한 순곱새전골 호로록",
# 			"link":"https:\/\/blog.naver.com\/mjhlove123\/222929854711",
# 			"description":"간단히 혼밥하는 분도 계시더라구요 포장가능⭕️ 작지만 아늑한 매장입니다:) <b>메뉴<\/b> 강력<b>추천<\/b>... ㅎㅎ 당감동 맛집에서 <b>추운날<\/b> 뜨끈한 전골 배부르게 자알 먹고 왔습니다! 다가오는 겨울은 수백당하세요~ ㅎㅎㅎ",
# 			"bloggername":"먹고, 살림하고 육아하는 둥이네♥",
# 			"bloggerlink":"blog.naver.com\/mjhlove123",
# 			"postdate":"20221116"
# 		},
# 		{
# 			"title":"[광주 맛집] <b>추운날<\/b>은... 샤브샤브 맛집 “유유샤브” 동천점 <b>추천<\/b>!",
# 			"link":"https:\/\/blog.naver.com\/gofls0506\/223000429697",
# 			"description":"유난히 <b>추운<\/b> 이번겨울, 유니스가 꽂힌 <b>메뉴<\/b>가 있다는데…! 바로바로 샤브샤브! 냠냠 개인적으로 저는... <b>추운날<\/b> 샤브샤브 너무 좋잖아요…? 친절하고 깔끔하면 더 좋아…❤️ 유유샤브 동천점 왕 <b>추천<\/b>! 근처에... ",
# 			"bloggername":"Yunie's Daily",
# 			"bloggerlink":"blog.naver.com\/gofls0506",
# 			"postdate":"20230131"
# 		},
# 		{
# 			"title":"시장 맛집 : 장호덕 손만두 <b>추운 날<\/b>에 딱 어울리는 저녁 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/gd_913\/222598291255",
# 			"description":"맛집 <b>추천<\/b> <b>추운 날<\/b> 가장 먹고 싶은 음식들 중 어떤 게 생각나시나요? 저는 호빵, 붕어빵, 만두 종류가 가장 먼저 떠오릅니다 ㅎㅎ 국물도 이따끔 생각나지만 일단 속이 든든하면서 가성비 좋은 <b>메뉴<\/b> 같아서... ",
# 			"bloggername":"란도 멘션",
# 			"bloggerlink":"blog.naver.com\/gd_913",
# 			"postdate":"20211218"
# 		},
# 		{
# 			"title":"가경동 <b>추운날<\/b> 점심<b>메뉴<\/b>는 뼈해장국으로 든든하게",
# 			"link":"https:\/\/blog.naver.com\/ganada1423\/223001756579",
# 			"description":"그래도 여기는 양이 적은 느낌은 아니고 고기도 두툼하게 잘 붙어있습니다 딱 깔끔하게 <b>추운날<\/b> 든든한 점심<b>메뉴<\/b>로 좋은 가경동 뼈해장국 점심<b>메뉴<\/b> 고민중이라면 혹은 해장이 필요하다면 한번쯤 가보시길 <b>추천<\/b>해요",
# 			"bloggername":"GaNaDaRa",
# 			"bloggerlink":"blog.naver.com\/ganada1423",
# 			"postdate":"20230201"
# 		},
# 		{
# 			"title":"용봉동 맛집 <b>추운 날<\/b> 생각나는 착한해물",
# 			"link":"https:\/\/blog.naver.com\/ohjug\/222909434354",
# 			"description":"우리가 주문한 <b>메뉴<\/b>는 세 사람이 갔으니까 해물전골 (중) 3인 58000원을 주문했답니다. 착한해물에서는... 그러나 진심으로 이렇게 <b>추운 날<\/b>에는 포장마차 분위기 물씬 풍기는 착한해물을 <b>추천<\/b>드리고 싶네요.... ",
# 			"bloggername":"드레스를 만드는 집 화니웨딩",
# 			"bloggerlink":"blog.naver.com\/ohjug",
# 			"postdate":"20221024"
# 		},
# 		{
# 			"title":"고속터미널점_ 굴국밥,매생이굴국밥 <b>추운날 추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/stellar0802\/222656479879",
# 			"description":"<b>메뉴<\/b>판 여기오면 그냥 굴국밥이나 매생이 굴굴밥 !! 굴국밥 10,000원 매생이굴국밥 11,000원 여긴 진짜 사람이 항상 많은 것 같다 굴국밥 10,000원 매생이굴국밥 11,000원 주문하면 금방 나온다! 굴이 많이 들어있고... ",
# 			"bloggername":"해맑은 해롱이네",
# 			"bloggerlink":"blog.naver.com\/stellar0802",
# 			"postdate":"20220224"
# 		},
# 		{
# 			"title":"화성 봉담맛집 <b>추천<\/b> '연남물갈비' \/  <b>추운날<\/b> 뜨끈한 국물과 함께... ",
# 			"link":"https:\/\/blog.naver.com\/lialee24\/222963988217",
# 			"description":"<b>추운날<\/b> 제치고 픽한 곳!! '연남물갈비' 운영시간 11:30-22:30(Break time 14:30-16:30) 일요일 정기휴무 주차가능... 산은 산이고 물은 물이로다 고기산더미 연남물갈비에 찰떡비유가 아닌가 싶다 ㅎㅎ 유명한 <b>메뉴<\/b>들에... ",
# 			"bloggername":"욘두집사 리아리",
# 			"bloggerlink":"blog.naver.com\/lialee24",
# 			"postdate":"20221223"
# 		},
# 		{
# 			"title":"[부산 사상맛집 <b>추천<\/b>] 오늘같이 <b>추운날<\/b> 뜨끈한 최뼈다구 해장국... ",
# 			"link":"https:\/\/blog.naver.com\/millionmozzi\/221744554901",
# 			"description":"오늘같이 <b>추운날<\/b>은 생각이나는 음식이 있죠! 뜨끄은 한 국물 음식!ㅋㅋㅋㅋ 오늘 점심<b>메뉴<\/b><b>추천<\/b>으로 부산사상에있는 최뼈다구 해장국집을 소개 드릴려고 해요~~^^  위에 세팅이 기본세팅이구요!! 근접사진... ",
# 			"bloggername":"밀리언모찌 경제이야기",
# 			"bloggerlink":"blog.naver.com\/millionmozzi",
# 			"postdate":"20191221"
# 		},
# 		{
# 			"title":"[의정부맛집 의정부교동짬뽕\/의정부점심<b>메뉴<\/b><b>추천<\/b>] <b>추운날<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/milan0126\/221172068997",
# 			"description":"아이 추워 <b>추운 날<\/b>엔 짬뽕이 생각나네?? 짬뽕먹으러 가볼까? 출처 : 네이버 거리뷰 의정부교동짬뽕 으로... 의정부점심<b>추천<\/b> #의정부짬뽕집 #의정부교동짬뽕 #교동짬뽕짜장밥 #의정부백년교동짬뽕 #교동짬뽕<b>메뉴<\/b>... ",
# 			"bloggername":"오치드림, 나의 행복",
# 			"bloggerlink":"blog.naver.com\/milan0126",
# 			"postdate":"20171229"
# 		},
# 		{
# 			"title":"<b>추운날<\/b> 점심<b>추천 메뉴<\/b> 카레돈까스나베",
# 			"link":"https:\/\/blog.naver.com\/chiroleej\/222204938428",
# 			"description":"면, 연어, 초밥, 핑거돈까스, 튀김류 등등 아주 다양한 맛도 즐기실 수 있어요. 그럼 오늘 하루도 마무리 잘하시고 모두 건강하세요!!! #병점맛집 #병점멘스시천애부 #멘스시천애부 #카레돈까스나베 #병점맛집<b>추천<\/b>",
# 			"bloggername":"웰포스처",
# 			"bloggerlink":"blog.naver.com\/chiroleej",
# 			"postdate":"20210112"
# 		},
# 		{
# 			"title":"<b>추운날<\/b><b>메뉴<\/b>강추! 북한산 온천칼국수+삼송 은희네해장국",
# 			"link":"https:\/\/blog.naver.com\/alaral9\/222970023621",
# 			"description":"겨울에 <b>추운날<\/b>은 지축에서 가까운 온천칼국수와 삼송에서 가까운 제주은희네해장국으로 점심과 저녁을....한번...이조합 <b>추천<\/b>해봅니닼ㅋㅋ쿄쿄 온천 옆에 빨간벽돌인가? 그집이에요! 안쪽으로 쑥~~ 온천쪽으로... ",
# 			"bloggername":"나의 안\/물\/안\/궁\/ 노트",
# 			"bloggerlink":"blog.naver.com\/alaral9",
# 			"postdate":"20221230"
# 		},
# 		{
# 			"title":"‘레드버튼’ \/ 노원놀거리 <b>추운 날<\/b> 실내 데이트 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/jisoo831\/223001148724",
# 			"description":"노원역 보드게임카페 ‘레드버튼’ 노원놀거리 <b>추운 날<\/b> 실내 데이트 <b>추천<\/b>  (+ 2인 보드게임 <b>추천<\/b>까쥐 !)... <b>메뉴<\/b>판 (+<b>추천메뉴<\/b>) 보드게임도 식후경 ( ◠‿◠ ),, 카운터에 가서 이것저것 말할 필요없이 개별 룸마다... ",
# 			"bloggername":"today_zizoo",
# 			"bloggerlink":"blog.naver.com\/jisoo831",
# 			"postdate":"20230131"
# 		},
# 		{
# 			"title":"72420 : 송리단길 <b>추운 날<\/b> 뜨끈한 베트남 쌀국수 맛집 <b>추천<\/b>!",
# 			"link":"https:\/\/blog.naver.com\/dpgus108\/222949242593",
# 			"description":"다들 <b>메뉴<\/b> 결정에 어려움이 있는 편이라... 오늘은 또 멀 먹으러 어딜 가야 하나 고민이 됐었는데 한... 역시 <b>추운 날<\/b>엔 쌀국수!! 출출하고 푸짐하게 먹고 싶을 때 잠실 72420 <b>추천<\/b>합니다 ~! 그럼 오늘 후기도... ",
# 			"bloggername":"어떻게든 굴러가는 일상",
# 			"bloggerlink":"blog.naver.com\/dpgus108",
# 			"postdate":"20221207"
# 		},
# 		{
# 			"title":"[갈산동] <b>추운날 추천<\/b>드리는 불고기전골 맛집 불고기회관",
# 			"link":"https:\/\/blog.naver.com\/dusghzla\/222919035312",
# 			"description":"선선하거나 <b>추운날<\/b>에 <b>추천<\/b>드리고싶은 불고기 전골 집이였어요 고기도 오랫동안 보관하지않았는지 식감도 쫄깃했고 야채들이 많아서 다양하게 즐겨먹을수있었어요 + 직화제육볶음은 고기 <b>메뉴<\/b>가... ",
# 			"bloggername":"연킴의 일상 맛집 기록",
# 			"bloggerlink":"blog.naver.com\/dusghzla",
# 			"postdate":"20221104"
# 		},
# 		{
# 			"title":"더운날도 <b>추운날<\/b>도 좋은 살얼음 동동 메밀국수 -  성수동 소바식당",
# 			"link":"https:\/\/blog.naver.com\/linn0203\/223160038071",
# 			"description":"<b>추천메뉴<\/b> : 전복, 단새우 냉소바 , 연어덮밥, 타마고멘치카츠 개인적으로 성수동에서 좀 좋아라 하는 매장입니다. ^^ 언제가도 편안한 분위기고(늘 웨이팅은 있어요), 테이블 간 간격도 좋고, 접객을 해주시는... ",
# 			"bloggername":"판을 짜는 기획자의 세상읽기",
# 			"bloggerlink":"blog.naver.com\/linn0203",
# 			"postdate":"20230718"
# 		},
# 		{
# 			"title":"학정동] <b>추운 날<\/b> 따끈한 국물이 당길 때 샤브샤브 맛집 <b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/dlgusdud4978\/222962426941",
# 			"description":"ㅠㅠ 이날 진짜 추웠는데 따끈한 샤브샤브 먹으니까 온몸이 풀리더라구요~ <b>추운 날<\/b>엔 이만한 게 없죠... 외식<b>추천<\/b> #저녁<b>메뉴<\/b><b>추천<\/b> #만두전골 #칠곡맛집 #겨울<b>메뉴<\/b><b>추천<\/b> #다이어트 #샐러드 #월남쌈 #쌀국수 #칼국수",
# 			"bloggername":"영이 발자국 이야기",
# 			"bloggerlink":"blog.naver.com\/dlgusdud4978",
# 			"postdate":"20221222"
# 		},
# 		{
# 			"title":"<b>추운날<\/b> 점심으로 딱인 울산곰탕맛집 정담곰탕 다녀왔어요",
# 			"link":"https:\/\/blog.naver.com\/coordisy\/222958606110",
# ...
# 			"description":"베트남 맛집들도 종종 가보았는데 베트남 노상식당만큼 다양한 <b>메뉴<\/b>가 있는 곳은 처음 본 것 같아요... <b>추운 날<\/b>이라 따뜻하게 먹어주니 넘나좋았네용ㅎㅎㅎ 천안 쌍용동 맛집 골목은 많이 안 와서 전 안 받았지만... ",
# 			"bloggername":"설양의 공간",
# 			"bloggerlink":"blog.naver.com\/kseol1223",
# 			"postdate":"20181120"
# 		},
# 		{
# 			"title":"아이간식 순수요거생딸기 설빙 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/sul_hwa\/222594375005",
# 			"description":"아이간식 순수요거 생딸기 설빙 <b>메뉴<\/b> <b>추천<\/b> 안녕하세요 설랑입니다 코로나 확산세거 정말 최고인것... 순수요거생딸기설빙 먹으러 굳이 <b>추운날<\/b>... 싶었지만 막상 먹으니 넘나 좋은거~~~ 연휴 하나 더 추가해서 정말... ",
# 			"bloggername":"개성만점 아이 셋",
# 			"bloggerlink":"blog.naver.com\/sul_hwa",
# 			"postdate":"20211213"
# 		},
# 		{
# 			"title":"김치 수제비 만들기 비오는날 음식 얼큰한 국물요리 레시피",
# 			"link":"https:\/\/blog.naver.com\/blogdanielland\/223195623311",
# 			"description":"다양한 국물요리 레시피 중에서도 수제비는 날이 더워도 비가오면 먹고 싶고 또 <b>추운날<\/b> 뜨끈한 국물이 생각날 때 만들게 되는 한식 <b>메뉴<\/b>가 아닐까 싶습니다. 원래는 바지락 넣은 육수에 감자나 호박을 넣고... ",
# 			"bloggername":"메이플대니얼의 요리공간 다니엘랜드",
# 			"bloggerlink":"blog.naver.com\/blogdanielland",
# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"미사리밀빛초계국수 롯데아울렛광명점 : <b>추운날<\/b>에도 땡기는... ",
# 			"link":"https:\/\/blog.naver.com\/che5465\/223040996304",
# 			"description":"날이 좀 풀렸다고는 하지만 아직 <b>추운날<\/b>씨라 칼국수 먹는 사람이 많은거 같았다 하지만 나는 초계국수... ㅋㅋㅋㅋㅋ 국수집같지는 않은 인테리어다 사람이 많아서 그런지 <b>메뉴<\/b>가 나오기까지는 조금 걸려서 빨리... ",
# 			"bloggername":"재미가 쏠쏠한 일상 블로그",
# 			"bloggerlink":"blog.naver.com\/che5465",
# 			"postdate":"20230310"
# 		},
# 		{
# 			"title":"이색체험 . <b>추운 날<\/b> 카페도자기마을에서 실내데이트해요~",
# 			"link":"https:\/\/blog.naver.com\/pasghetti\/221810738242",
# 			"description":"ㅠㅠ 실내데이트<b>메뉴<\/b>로는 좀 그런가? 사람 없을 때 언능 찍어봤네요. 카페도자기마을에서는 두 가지의... 즐거운 도예체험도 해보시고 인근에 다양한 체험거리도 있으니 어린아이들과 함께하는 것도 <b>추천<\/b>해보... ",
# 			"bloggername":"JolMA's Box",
# 			"bloggerlink":"blog.naver.com\/pasghetti",
# 			"postdate":"20200216"
# 		},
# 		{
# 			"title":"서산호수공원 점심<b>메뉴<\/b><b>추천<\/b> 텐동맛집 온센 서산점",
# 			"link":"https:\/\/blog.naver.com\/3827412\/223170386487",
# 			"description":"새로운 <b>메뉴<\/b>가 많이 생겼다 우동, 소바가 있어서 덥고 <b>추운 날<\/b>에도 가기 좋을 것 같다 나는 바테이블에 앉았다 바테이블 자리는 양쪽에 귀여운 피규어가 있어서 구경하는 재미가 있고 자리에 앉아서도... ",
# 			"bloggername":"김입술 먹고 사는 이야기",
# 			"bloggerlink":"blog.naver.com\/3827412",
# 			"postdate":"20230731"
# 		},
# 		{
# 			"title":"점심,저녁 <b>메뉴<\/b> <b>추천<\/b>해드립니다!",
# 			"link":"https:\/\/blog.naver.com\/main5517\/222968069855",
# 			"description":"안녕하세요 날이 너무 <b>추운<\/b> 하루네요 봄이 벌써 그리워지는 하루네요. 요즘 날이 많이 추워서 그런지... 오늘처럼 <b>추운날<\/b> 겨울에 먹는 전골이 더 맛있더라구요 ^^ 이웃님들 오늘 점심으로 우동어떨까요? ^^ <b>추천<\/b>해... ",
# 			"bloggername":"소중한몸건강",
# 			"bloggerlink":"blog.naver.com\/main5517",
# 			"postdate":"20221228"
# 		},
# 		{
# 			"title":"런치 \/ <b>추운 날<\/b> 수제비가 땡길 때 김치수제비 맛집 <b>추천<\/b>!... ",
# 			"link":"https:\/\/blog.naver.com\/kohakyung92\/222226304093",
# 			"description":"가깝지만 <b>추운날<\/b>에는 그래도 좀 거리가 있는 체부동 옛날국수맛집으로 고고씽함 <b>메뉴<\/b>판을 못찍은게 아쉬움 내가 먹은 김치수제비를 포함해서 밀가루로 만든 <b>메뉴<\/b>들은 거의 다 판매하는 듯했음 내가 주문한... ",
# 			"bloggername":"하디 :: 잘먹고 잘놀고 잘살자",
# 			"bloggerlink":"blog.naver.com\/kohakyung92",
# 			"postdate":"20210131"
# 		},
# 		{
# 			"title":"북촌손만두ㅣ추운 날 뜨끈한 만둣국 죠와^0^\/서창동밥집<b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/janny0621\/222587489966",
# 			"description":"#왕비돈까스 골목, #동궁찜닭 옆 #주차 가능 휴무는 월요일 <b>메뉴<\/b>판 들어와 앉아서 #<b>메뉴<\/b>판 보는데 #셀프... 크진 않지만 간단히 먹으러 오기 좋은듯 #혼밥 으로도 #<b>추천<\/b> 저기 음식나오는 곳에서 셀프로 픽업하면... ",
# 			"bloggername":"애정하는것만 한가득",
# 			"bloggerlink":"blog.naver.com\/janny0621",
# 			"postdate":"20211205"
# 		},
# 		{
# 			"title":"[명지] <b>추운날<\/b> 딱인 샤브샤브 맛집 토리샤브 찐후기!",
# 			"link":"https:\/\/blog.naver.com\/liru01\/222969442894",
# 			"description":"부산 강서구 명지국제11로 53 107호 포장, 배달, 택배 전문 카톡, 배민 주문 가능 요즘 같이 <b>추운날<\/b>엔... 먹기전에 다 펼쳐서 찍어봄 사장님 <b>메뉴<\/b>판에 있는 사진이랑 완전 똑같자나여!!! 요게 토리샤브 <b>메뉴<\/b>... ",
# 			"bloggername":"일상기록",
# 			"bloggerlink":"blog.naver.com\/liru01",
# 			"postdate":"20221229"
# 		},
# 		{
# 			"title":"큰맘가면 꼭 주문해야 하는 먹킷리스트! 큰맘 <b>메뉴<\/b> <b>추천<\/b> 이벤트",
# 			"link":"https:\/\/blog.naver.com\/bigheart__official\/223080510957",
# 			"description":"큰맘 <b>메뉴<\/b>들에 대한 솔직담백한 SNS 리뷰들로 가득 채워진 이번 콘텐츠, 시작해볼게요! 한국인들은 아주... 뼈다귀 해장국 “ 날이 살짝 <b>추운 날<\/b>에는 뜨끈뜨끈한 해장국 한 사발! “ “들깻가루 팍팍 뿌려 오늘도... ",
# 			"bloggername":"큰맘할매순대국 공식블로그",
# 			"bloggerlink":"blog.naver.com\/bigheart__official",
# 			"postdate":"20230421"
# 		},
# 		{
# 			"title":"[수원맛집]<b>추운날<\/b> 더 맛있는 조개찜맛집 포항물회",
# 			"link":"https:\/\/blog.naver.com\/goldab\/222957686053",
# 			"description":"조개찜에 치즈 주는 곳도 저는 여기가 처음이었어요 우리의 주문 <b>메뉴<\/b>: 조개전골 3인 ₩65,000... 확 깨더라고요 ¨̮ 가족 또는 회식등 연말 연초 식사로도 안주로도 괜찮은 조개전골 조심스레 <b>추천<\/b>해보아용",
# 			"bloggername":"손소품공방과 일상",
# 			"bloggerlink":"blog.naver.com\/goldab",
# 			"postdate":"20221216"
# 		},
# 		{
# 			"title":"점심<b>메뉴<\/b> <b>추천<\/b>, 떡라면 끓이는법",
# 			"link":"https:\/\/blog.naver.com\/minkknim\/222945048288",
# 			"description":"그래서 뭐 먹을까 고민이 되는 휴일날 점심으로, 혹은 반찬 하기 싫은 <b>날<\/b> 점심 <b>메뉴<\/b>로, 때로는 <b>추운 날<\/b> 뜨끈한 국물이 먹고 싶은 <b>날<\/b> 점심<b>메뉴<\/b> <b>추천<\/b>해달라고 하면 떡라면이 제일 먼저 생각이 나는 듯해요.",
# 			"bloggername":"꽃피는 산골",
# 			"bloggerlink":"blog.naver.com\/minkknim",
# 			"postdate":"20221203"
# 		},
# 		{
# 			"title":"[상봉역 샤브샤브] ‘삼청동샤브’ <b>추운날<\/b> 뜨끈하게 1인 샤브... ",
# 			"link":"https:\/\/blog.naver.com\/skstlwls28\/222949979028",
# 			"description":"ㅋㅋㅋ 밖에서도 무슨<b>메뉴<\/b>가 있는지 다 확인 가능해요~~ 오전 11시에 열어서 저녁 10시에 닫으니 참고해... 꿀이득이죠~ 겨울에 뜨끈한거 땡기실때 <b>추천<\/b>합네당 #삼청동샤브 #1인샤브샤브 #겨울철음식<b>추천<\/b>... ",
# 			"bloggername":"방그래의 맛집 탐방 ll 솔직 리뷰",
# 			"bloggerlink":"blog.naver.com\/skstlwls28",
# 			"postdate":"20221208"
# 		},
# 		{
# 			"title":"대구 진천동칼국수 \/ <b>추운날<\/b> 먹어줘야하는 자가제면 진주손칼국수",
# 			"link":"https:\/\/blog.naver.com\/sodady\/222541118132",
# 			"description":"대구 진천동칼국수 <b>추운날<\/b> 먹어줘야하는 자가제면 진주손칼국수 요즘 갑자기 너~~~~무 추워졌다 ㅠㅠ... 세트<b>메뉴<\/b>에 함께 포함되어 있던 알밥! 날치알이랑 김이랑 잘 비벼준당 그리고 세 입 컷 ㅋ 에피타이저... ",
# 			"bloggername":"먹기위해 사는 하루살이 집사블로거",
# 			"bloggerlink":"blog.naver.com\/sodady",
# 			"postdate":"20211019"
# 		},
# 		{
# 			"title":"[논현역술집]--<b>추운날<\/b> 안주든든하게 달래해장에서 회식하기",
# 			"link":"https:\/\/blog.naver.com\/whoo51_\/222942016803",
# 			"description":"이랑 버너위에 <b>메뉴<\/b>판이 있었어요 <b>메뉴<\/b>가 진짜 많아요 모듬수육 소짜 하나 해장 전골 하나 시켰습니당... 안주 조합으로 진짜 좋았던거 같아요 친구 <b>추천<\/b> 완전 성공이라 칭찬해줬어요 ㅎㅎ <b>추운날<\/b> 안주 든든하게... ",
# 			"bloggername":"후우의 일상블로그",
# 			"bloggerlink":"blog.naver.com\/whoo51_",
# 			"postdate":"20221130"
# 		},
# 		{
# 			"title":"&lt;을지로 맛집&gt; <b>추운 날<\/b> 황평집에서 따끈한 닭곰탕 한 그릇!",
# 			"link":"https:\/\/blog.naver.com\/gusel09\/221723683570",
# 			"description":"안주<b>메뉴<\/b>도 주문 가능 한 시간! 대신 16-17시 브레이크 타임인 것 참고 마음 속에서 다 먹고 싶은데... 두 명 이상일 경우 <b>추천<\/b>이지만 두 명은 간단하게 곰탕에 닭무침이나 닭찜 중 하나 주문하는 게 좋을 듯!",
# 			"bloggername":"쏭블리의 한조각한조각 :)",
# 			"bloggerlink":"blog.naver.com\/gusel09",
# 			"postdate":"20191201"
# 		},
# 		{
# 			"title":"[포항\/양덕] 맛집 한양곱창전골-<b>추운 날<\/b> 따끈한 국물 호로록",
# 			"link":"https:\/\/blog.naver.com\/jaehee1364\/221401378183",
# 			"description":"<b>메뉴<\/b>구성은 딱 전골만 팔아요! 저희는 아래처럼 주문했어요~ 곱창전골2인분 공기밥2 볶음밥1 음료수1... 잘먹었습니다♀️ #포항 #양덕 #맛집 #맛집<b>추천<\/b> #한양곱창전골 #곱창 #대학생 #일상 #기록",
# 			"bloggername":"재희의 직딩일기",
# 			"bloggerlink":"blog.naver.com\/jaehee1364",
# 			"postdate":"20181119"
# 		},
# 		{
# 			"title":"[홍대\/상수] <b>추운날<\/b> 식사 <b>추천<\/b>! 진한 돈코츠라멘 :: 하카다분코... ",
# 			"link":"https:\/\/blog.naver.com\/deamsgod\/220917078369",
# 			"description":"주력<b>메뉴<\/b>!!!! 들어가는 입구도 완전 라멘집 스러움 원래 차슈덮밥도 먹어보고싶었는데 이거는... 오버하면 동맥경화걸릴 것 같은 국물 맛이지만 진짜 매력 터짐 비린내나 잡내 전혀 안남 <b>추운날<\/b>엔 라멘 드세용!!!",
# 			"bloggername":"*얄짤없는 맛평가블로그* 맛챠 Matcha",
# 			"bloggerlink":"blog.naver.com\/deamsgod",
# 			"postdate":"20170121"
# 		},
# 		{
# 			"title":"미소야 서초점 <b>추운날<\/b> 뜨끈한 우삼겹우동  강추",
# 			"link":"https:\/\/blog.naver.com\/ngh619\/223009189767",
# 			"description":"#미소야 #미소야남부터미널 #미소야서초점 #남부터미널맛집 #미소야<b>메뉴<\/b> #미소야가격 #미소야<b>메뉴<\/b><b>추천<\/b> #우삼겹우동 #부대라면 #남부터미널혼밥 #서초점심 #서초맛집 이곳은 웬만한 <b>메뉴<\/b> 다 맛도리라는 그... ",
# 			"bloggername":"쓰는게 제일 좋아>.<",
# 			"bloggerlink":"blog.naver.com\/ngh619",
# 			"postdate":"20230208"
# 		},
# 		{
# 			"title":"[광주 첨단 맛집] 쭈마담 : <b>추운 날<\/b> 매콤한게 땡길땐 바로 여기",
# 			"link":"https:\/\/blog.naver.com\/mmmkyy3\/222950796437",
# 			"description":"스페셜 <b>메뉴<\/b>가 있어 삼겹,새우,우삼겹을 골라먹을 수 있는 재미가 있음 #첨단맛집 #첨단2지구맛집 #첨단쭈꾸미 #첨단쭈꾸미맛집 #첨단점심<b>추천<\/b> #첨단저녁<b>추천<\/b> #첨단점심맛집 #첨단저녁맛집 #신용동쭈꾸미... ",
# 			"bloggername":"민경쓰의 일상블로그",
# 			"bloggerlink":"blog.naver.com\/mmmkyy3",
# 			"postdate":"20221209"
# 		},
# 		{
# 			"title":"강릉 육반장 주문진 육개장 맛집, 해장 <b>메뉴<\/b> <b>추천<\/b>, 아침식사 가능",
# 			"link":"https:\/\/blog.naver.com\/aldur29\/223123894388",
# 			"description":"일반 육개장도 국물 자체가 녹진해서 <b>추운 날<\/b> 국물 마셔보면 속이 뜨끈해질 것 같더라고요 처음엔... 해장 <b>메뉴<\/b> <b>추천<\/b> 후기 위치상 주문진 여행 후 떠나는 마지막 <b>날<\/b> 먹기 좋은 식사! 오전 08시부터 영업... ",
# 			"bloggername":"며니의 먹지도 ♡",
# 			"bloggerlink":"blog.naver.com\/aldur29",
# 			"postdate":"20230608"
# 		},
# 		{
# 			"title":"등촌샤브칼국수 <b>추운 날<\/b> 뜨끈하게 먹고 왔어요",
# 			"link":"https:\/\/blog.naver.com\/gaonmom0909\/222596714370",
# 			"description":"고팠던 <b>날<\/b> 근처 저녁 거리를 찾아보았습니다~ ✔고기 종류 ✔뜨끈한 국물 ✔보증된 맛 을 원했던 저희... <b>추운 날<\/b> 뜨끈하게! 맛있게 먹고 왔네요~ #등촌 #등촌칼국수 #등촌샤브칼국수 #<b>메뉴<\/b><b>추천<\/b> #먹방 #저녁<b>메뉴<\/b>... ",
# 			"bloggername":"렌느제이&가온맘",
# 			"bloggerlink":"blog.naver.com\/gaonmom0909",
# 			"postdate":"20211216"
# 		},
# 		{
# 			"title":"원주 배달 맛집 관설동 삼부자집 <b>추운날<\/b> 삼계탕 한끼 든든하게",
# 			"link":"https:\/\/blog.naver.com\/wch0408\/222920053409",
# 			"description":"독특한 <b>메뉴<\/b>인 닭만두전골이 인기<b>메뉴<\/b>인데 삼계탕도 많이 주문하는 <b>메뉴<\/b>라서 주문했어요 배달이... 챙겨보시길 <b>추천<\/b>드릴게요~ #원주배달맛집 #원주배달 #원주삼부자집 #원주삼계탕 #삼부자집 #관설동맛집... ",
# 			"bloggername":"툐히의 일상 블로그",
# 			"bloggerlink":"blog.naver.com\/wch0408",
# 			"postdate":"20221104"
# 		},
# 		{
# 			"title":"오문창순대국밥 <b>메뉴<\/b>&amp;가격 \/ 대전 맛집<b>추천<\/b> \/ 내돈내먹",
# 			"link":"https:\/\/blog.naver.com\/yeinmooon\/222976672155",
# 			"description":"그래도 <b>추운날<\/b> 빠르게 나와서 호로록 먹기엔 괜찮은 집인듯 하다. (난 한번 맛본걸로 족함 ㅎㅎㅎㅎ) 그리고 밥이 말아져 나오는 방식이면 같이 더 팔팔 끓여주면 더 맛있지 않았을까 싶다! 06. &lt;위치... ",
# 			"bloggername":"Middle of summer",
# 			"bloggerlink":"blog.naver.com\/yeinmooon",
# 			"postdate":"20230106"
# 		},
# 		{
# 			"title":"역전할머니 <b>메뉴<\/b><b>추천<\/b>으로 이거 이거 이거요!!!!",
# 			"link":"https:\/\/blog.naver.com\/dh8596\/221770242368",
# 			"description":"들었어요 : ) <b>추운 날<\/b> 아이스 맥주를 먹으니까 속이 뻥 뚫리는 기분에, 그리고 잘 취하지 않는 것 같은 느낌적인 느낌이라고 할까요? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 역전할머니 <b>메뉴<\/b><b>추천<\/b>으로는 30센치 돈까스와... ",
# 			"bloggername":"the world is yours!",
# 			"bloggerlink":"blog.naver.com\/dh8596",
# 			"postdate":"20200117"
# 		},
# 		{
# 			"title":"<b>추운 날<\/b>에 최고인 화명동 맛집 왕대구탕",
# 			"link":"https:\/\/blog.naver.com\/jmw18333\/222653372114",
# 			"description":"테이블마다 <b>메뉴<\/b>판도 있어요. 모둠 생선구이도 많이 주문하시더라구요. 저는 뜨끈한 국물이 먹고 싶어서 대구탕으로 주문했답니다. 모둠 생선구이는 다음에 방문하면 먹어야겠어요. #화명동식당<b>추천<\/b> 주문한... ",
# 			"bloggername":"기산홈서비스부산북구점",
# 			"bloggerlink":"blog.naver.com\/jmw18333",
# 			"postdate":"20220221"
# 		},
# 		{
# 			"title":"여의도 맛집 가양칼국수버섯매운탕 <b>추운 날<\/b> 무조건 생각날 찐맛집",
# 			"link":"https:\/\/blog.naver.com\/yun_yeo\/222845529052",
# 			"description":"날이 더워 그렇지 <b>추운 날<\/b> 무조건 생각날 음식이었다. 특히 겨울에는 지금보다 인기가 많을 것 같다. <b>메뉴<\/b> 특성상 눈 오거나 비 오는 <b>날<\/b> 직장인들에게 인기 많을 매운탕! 약간 아쉬웠던 것은 버섯 매운탕인 만큼... ",
# 			"bloggername":"언제나 여행자",
# 			"bloggerlink":"blog.naver.com\/yun_yeo",
# 			"postdate":"20220811"
# 		},
# 		{
# 			"title":"영통맛집 : 호아면, <b>추운날<\/b> 생각나는 쌀국수 맛집",
# 			"link":"https:\/\/blog.naver.com\/o_ath\/222955235135",
# 			"description":"단면 사진은 없지만 쉬림프롤도 야채와 면 그리고 통통한 새우튀김이 꽉 차있어서 <b>추천<\/b>드리는 사이드 <b>메뉴<\/b>에요 <b>추운<\/b> 겨울 따뜻한 <b>메뉴<\/b>가 먹고싶을때 사이드 까지 푸짐하게 맛볼 수 있는 영통 호아면... ",
# 			"bloggername":"콩두의 먹여행로그",
# 			"bloggerlink":"blog.naver.com\/o_ath",
# 			"postdate":"20221214"
# 		},
# 		{
# 			"title":"일산맛집 :: <b>추운날<\/b> 따뜻하게 갈비찜과 조개찜 두마리 토끼를... ",
# 			"link":"https:\/\/blog.naver.com\/thnnne\/223003464497",
# 			"description":"아무래도 이렇게 <b>추운<\/b> 계절에는 시원하고 얼큰한 조개찜 국물에 소주 한 잔 캬~~ 하고 싶어지잖아요?... 시그니처 <b>메뉴<\/b>는 조개갈비찜 일명 조갈찜입니다!! 그리고 대표 <b>메뉴<\/b>는 문어전복 조개갈비찜이라고... ",
# 			"bloggername":"♥ 귤떡이랑 놀아요 ♥",
# 			"bloggerlink":"blog.naver.com\/thnnne",
# 			"postdate":"20230202"
# 		},
# 		{
# 			"title":"[종로\/익선동] 라쿠엔(LAKUEN)_ <b>추운날<\/b>에는 근사한... ",
# 			"link":"https:\/\/blog.naver.com\/dlgksk4121\/222947200602",
# 			"description":"신기하게 이렇게 <b>추운 날<\/b>에는 이자카야 생각이 절로 들게된다(나만 그런가?) 아무튼 웨스틴 조선... 양송이꼬치만으로도 단품<b>메뉴<\/b>가 있던데, 양송이는 꼭 드셔보세융 그리고 이 <b>날<\/b> 내 마음속 1위 전복..&gt;!!!!... ",
# 			"bloggername":"하나뿐이야",
# 			"bloggerlink":"blog.naver.com\/dlgksk4121",
# 			"postdate":"20221205"
# 		},
# 		{
# 			"title":"만들기 간단한 주말 점심 <b>메뉴<\/b> <b>추천<\/b> 다이소 오뎅티백 활용법",
# 			"link":"https:\/\/blog.naver.com\/prban1\/223113188407",
# 			"description":"초간단한 자취생 요리 사각 어묵국 만들기 간단한 주말 점심 <b>메뉴<\/b> <b>추천<\/b> 다이소 오뎅티백 활용법 알려... 오티가 필요할 때 혼술, 캠핑, 해외여행 야식, 숙취해소, 밥 먹을 때 <b>추운 날<\/b> 등산 만드는 과정을 영상에... ",
# 			"bloggername":"해우니의 요리 이야기",
# 			"bloggerlink":"blog.naver.com\/prban1",
# 			"postdate":"20230527"
# 		},
# 		{
# 			"title":"*뭐 먹고사니?|집밥모음 집밥<b>메뉴<\/b><b>추천<\/b> - 떡갈비정식... ",
# 			"link":"https:\/\/blog.naver.com\/icde21\/222963002947",
# 			"description":"오늘은 추워도 너무 <b>추운 날<\/b>입니다. 지하 주차장은 주말인 어제 낮부터 이미 만석입니다. 오늘도... 해장국으로 완전 좋고 <b>추운 날<\/b> 아침국으로 완전완전 좋아요. &quot;어허~~~ 시원하다&quot; 소리가 절로 나옵니다.... ",
# 			"bloggername":"현이네 집밥 & 도시락",
# 			"bloggerlink":"blog.naver.com\/icde21",
# 			"postdate":"20221222"
# 		},
# 		{
# 			"title":"[서면] <b>추운날<\/b> 가기 좋은 카페 <b>추천<\/b> , 코타츠 있는 카페... ",
# 			"link":"https:\/\/blog.naver.com\/diale\/222963849745",
# 			"description":"진짜 <b>추천<\/b>드릴게요 녹아들다 녹카페 서면역 8번 출구에서 도보 7분거리 영업시간 : 13:00 - 22:30 (평일), 12... 드디어 저희가 시킨 <b>메뉴<\/b>들 나왔오용! ✔️당고세트 + 아메리카노 11,500원 ✔️아메리카노 5,000원... ",
# 			"bloggername":"ᰔ으나 맘 대루ᰔ",
# 			"bloggerlink":"blog.naver.com\/diale",
# 			"postdate":"20221223"
# 		},
# 		{
# 			"title":"[강남맛집] <b>추운날<\/b> 모임장소 뜨끈한 국물 <b>추천<\/b> [닭한마리... ",
# 			"link":"https:\/\/blog.naver.com\/mk10066\/222921782187",
# 			"description":"ㅋㅋㅋ) 맛잘알 친구의 <b>추천<\/b>과 우리의 PICK으로 모임 식사<b>메뉴<\/b>는 뜨끈한 국물로 결정했써요!! [닭한마리... 왜이렇게 <b>추운<\/b>가요?!! 저 얼마전에 롱패딩으로 완전무장한 분 봄.. 충격…; 새댁이 1등으로 도착!! 아니... ",
# 			"bloggername":"우당탕밍",
# 			"bloggerlink":"blog.naver.com\/mk10066",
# 			"postdate":"20221106"
# 		},
# 		{
# 			"title":"[부산오빠] 겨울 커피차 \/ 간식 차 세트<b>메뉴<\/b> <b>추천<\/b>, 다 함께... ",
# 			"link":"https:\/\/blog.naver.com\/oppa_busan\/222585885606",
# 			"description":"세트 <b>메뉴<\/b>를 <b>추천<\/b>해 드리겠습니다!! http:\/\/www.giftluck.kr\/103 &lt;따뜻한 겨울 간식 세트 <b>추천<\/b>&gt; 빠빰! 1)... http:\/\/www.giftluck.kr\/103 3) 어떡 SET (어묵+떡볶이) 겨울에 best 간식은 바로 어묵, <b>추운 날<\/b> 언 몸을 녹이기... ",
# 			"bloggername":"부산오빠의 솔직담백한 부산여행\/맛집 리뷰",
# 			"bloggerlink":"blog.naver.com\/oppa_busan",
# 			"postdate":"20211203"
# 		},
# 		{
# 			"title":"서수원 맛집 &quot;장궁순대국&quot; <b>추운날<\/b> 뜨끈한 국물이 최고지!",
# 			"link":"https:\/\/blog.naver.com\/ys150707\/222961040792",
# 			"description":"<b>추운날<\/b>엔 뜨끈한 국밥이 땡기기 마련! 장궁순대국 <b>메뉴<\/b>를 보니 인삼이 들어간 보양식도 있더라... 양이 많은 분들은 특을 주문하는걸 <b>추천<\/b>한다. 그리고 이건 영양순대국 인삼, 헛개, 대추가 들어있어서 딱... ",
# 			"bloggername":"숸댁로그",
# 			"bloggerlink":"blog.naver.com\/ys150707",
# 			"postdate":"20221220"
# 		},
# 		{
# 			"title":"<b>추운 날<\/b> 뜨끈히 몸을 녹일 수 있는 별내 맛집 올리앤 별내점",
# 			"link":"https:\/\/blog.naver.com\/adrianavalos\/222987988877",
# 			"description":"<b>추운 날<\/b>씨에 먹기 딱 좋았던 &quot;항아리 누룽지 해산물 파스타&quot; <b>추천 메뉴<\/b>인 이유가 있더라고요. 아직 안 드셔보신 분들은 꼭 드셔보시길 바랍니다. 본 포스팅은 소정의 원고료를 받아 작성하게 되었습니다.... ",
# 			"bloggername":"adrianavalos님의블로그",
# 			"bloggerlink":"blog.naver.com\/adrianavalos",
# 			"postdate":"20230120"
# 		},
# 		{
# 			"title":"경산 중산점 : 남다른 감자탕 <b>추운날<\/b> 딱!",
# 			"link":"https:\/\/blog.naver.com\/ndwor\/222930756711",
# 			"description":"감자탕 경산점 에서 뚝배기나 감자탕뼈 전골 <b>추천<\/b> <b>추천<\/b>! #감자탕 #경산감자탕 #경산맛집 #정평역감자탕 #경산남다른감자탕 #정평역맛집 #정평역밥집 #중산동맛집 #남다른감자탕중산점 #경산밥집 #남다른감자탕<b>메뉴<\/b>",
# 			"bloggername":"Remember pic",
# 			"bloggerlink":"blog.naver.com\/ndwor",
# 			"postdate":"20221117"
# 		},
# 		{
# 			"title":"<b>추운 날<\/b> 먹기 좋은 경기도 시흥 맛집 고구려 짬뽕(본점)",
# 			"link":"https:\/\/blog.naver.com\/dmsdud7460\/221203172408",
# 			"description":"우리가 시킨 <b>메뉴<\/b>는 산선 짜장 7,000원 차돌박이 짬뽕 10,000원 짬뽕밥 7,500원 아침 일찍부터 움직여서... 가볍게 먹기 좋은 음식으로 <b>추천<\/b> 하지만 점심시간에 간다면 대기가 길어질 수 있다는 것.",
# 			"bloggername":"오목교 미용실 리얼드살롱 부원장 가온",
# 			"bloggerlink":"blog.naver.com\/dmsdud7460",
# 			"postdate":"20180212"
# 		},
# 		{
# 			"title":"방배동해장국 한사바리해장국 서초점 | <b>추운 날<\/b> 생각나는... ",
# 			"link":"https:\/\/blog.naver.com\/1000dmsrud\/223072492584",
# 			"description":"포장 <b>추천<\/b>드려요 : ) 국밥좋아하는 남자친구는 해장돼지국밥 ! 내장탕 좋아하는 저는 내장탕으로다가 ~ 사이드도 종류가 많길래 녹두전으로 골랐네요 ㅎㅎ 와~~ 2명이서 먹는거라 <b>메뉴<\/b> 2개 사이드 1개인데... ",
# 			"bloggername":"천의 천가지 일상",
# 			"bloggerlink":"blog.naver.com\/1000dmsrud",
# 			"postdate":"20230412"
# 		}
# 	]
# }

# %%
type(body)
# Out:
# str

# %%
body = body.replace('"','')
body
# Out:
# "{\n\tlastBuildDate:Wed, 30 Aug 2023 13:55:36 +0900,\n\ttotal:123165,\n\tstart:1,\n\tdisplay:100,\n\titems:[\n\t\t{\n\t\t\ttitle:<b>추운날<\\/b> 국물요리 <b>메뉴<\\/b><b>추천<\\/b>! 풀무원 가쓰오우동 3종 &lt; 정통... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/
\n\t\t\tlink:https:\\/\\/blog.naver.com\\/story8081\\/222970171215,\n\t\t\tdescription:&lt; 점심 <b>메뉴<\\/b> <b>추천<\\/b> - <b>추운 날<\\/b>에는 짬뽕 점심 식사 &gt; 날씨가 많이 추워져서 점심이면 뜨끈한 음식이 많이 생각납니다. 원래부터 짬뽕을 좋아해서 자주 먹고 있습니다. 하지만, 요즘에는 더 많이 찾고 있네요. <b>추운<\\/b>... ,\n\t\t\tbloggername:카스와 제동이와 사랑하는와이파이...그리고 \\둥이\\,\n\t\t\tbloggerlink:blog.naver.com\\/story8081,\n\t\t\tpostdate:20221230\n\t\t},',
#  'title:[인천] 혼밥 <b>메뉴<\\/b> <b>추천<\\/b>, <b>추운 날<\\/b>에 뜨뜻한 국밥 한 그릇... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/6ob_e\\/222644268953,\n\t\t\tdescription:혼밥 <b>메뉴<\\/b>로 어떤 음식을 즐겨드시나요 저는 오늘 혼밥 <b>메뉴<\\/b> 고민 중에 동네에 갈비찜 맛있다고 들었던 곽만근 갈비탕집에 왔습니다 인천광역시 서구 원당대로 665 완정역 다이소있는 라인에 위치해있어요 매일... ,\n\t\t\tbloggername:AU PUH,\n\t\t\tbloggerlink:blog.naver.com\\/6ob_e,\n\t\t\tpostdate:20220210\n\t\t},',
#  'title:<b>추운날<\\/b> 딱인 마곡나루전집 <b>추천<\\/b> : 그날전집,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/worklog\\/222943009820,\n\t\t\tdescription:업무왕입니다:) 날씨가 엄청 <b>추운<\\/b> 요즘에 딱 어울리는 전집을 <b>추천<\\/b>드려요. 요즘 같은 날씨에는 일반... 마곡나루에는 전집이 많지 않은데 <b>추운날<\\/b> 막걸리 한잔 하고 싶을 때 그날전집을 방문해 보세요! P.S... ,\n\t\t\tbloggername:업무왕의 이것저것,\n\t\t\tbloggerlink:blog.naver.com\\/worklog,\n\t\t\tpostdate:20221201\n\t\t},',
#  'title:육간청 : 구디 갈비탕 ! <b>추운날<\\/b> 점심 <b>메뉴<\\/b>로 <b>추천<\\/b>해요,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/panguuin\\/222966288843,\n\t\t\tdescription:요즘 그나마 구디에서 먹을만하다고 느껴지는 갈비탕 집이다! * 겨울에 출근해서 추워진 몸과 마음을 따듯하게 녹여보아요... 구로디지털단지 겨울 점심<b>메뉴<\\/b>로 <b>추천<\\/b>합니다,\n\t\t\tbloggername:뒤뚱뒤뚱,\n\t\t\tbloggerlink:blog.naver.com\\/panguuin,\n\t\t\tpostdate:20221229\n\t\t},',
#  'title:<b>추운날<\\/b> 점심<b>메뉴<\\/b> <b>추천<\\/b>은 등촌샤브칼국수,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/happytoib\\/222959942324,\n\t\t\tdescription:함께~~~ 말해뭐해~~ 시원하면서 칼칼하고 깊은 육수 <b>추운날<\\/b> 점심<b>메뉴<\\/b> 고민이 되면 등촌샤브칼국수로 고고고 또 하나의 매력 바로 볶음밥.... 주저 없이 망설임 없이 설겆이 필요없을만큼 쌱~~~~~ 맛나게 먹고 왔어요,\n\t\t\tbloggername:평택피부과 미앤클린,\n\t\t\tbloggerlink:blog.naver.com\\/happytoib,\n\t\t\tpostdate:20221219\n\t\t},',
#  'title:[광화문\\/종로 맛집] <b>추운 날<\\/b>... (점심<b>메뉴<\\/b><b>추천<\\/b>, 영업시간, <b>메뉴<\\/b>판... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\
\n\t\t\tlink:https:\\/\\/blog.naver.com\\/440\\/223027432524,\n\t\t\tdescription:좋은 <b>메뉴<\\/b>에요 수육에 육수+참소스 살짝뿌려냠냠 어른용 고기큼직한 육개장 <b>추운날<\\/b> 온가족이 맛있게 보양할수있으니 코스트코 가실때 한덩이씩 쟁여놨다가 시간있을때 푹 끓여서 다같이 드시는거 <b>추천<\\/b>드려요... ,\n\t\t\tbloggername:김엄마의 헤롱로그,\n\t\t\tbloggerlink:blog.naver.com\\/440,\n\t\t\tpostdate:20230225\n\t\t},',
#  'title:[가디역 맛집 <b>추천<\\/b>] <b>추운 날<\\/b> 매콤한 짬뽕이 먹고 싶다면... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/ksbookup\\/222954832936,\n\t\t\tdescription:<b>추천<\\/b>] <b>추운 날<\\/b> 매콤한 짬뽕이 먹고 싶다면♬ &lt;홍콩반점 0410&gt; 안녕하세요 여러분! 급격히 추워진 날씨에 자연스럽게 따뜻한 게 당기는 요즘인데요~ 저는 눈이 오늘 오늘! 지감의 동료들과 함께 중식을 점심 <b>메뉴<\\/b>로... ,\n\t\t\tbloggername:도서출판 지식과감성# 공식블로그,\n\t\t\tbloggerlink:blog.naver.com\\/ksbookup,\n\t\t\tpostdate:20221213\n\t\t},',
#  'title:온정손만두호매실점_<b>추운날<\\/b>엔 따뜻한 칼국수와 만두<b>추천<\\/b>!!,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/bicviruslee\\/222586716179,\n\t\t\tdescription:겨울에맛있는, #추운날가볼만한 요즘같이 날씨가 추울때, 방문하기 좋은 추천식당입니다.... 만두를 살짝깨서 국물과 함께 드세요~ 그러면 국물이 더더 담백하고 맛나요 ^^ㅋㅋ <b>추운날 추천메뉴<\\/b> 따뜻한 &quot;칼국수&quot;,\n\t\t\tbloggername:행복을 주는 블로그,\n\t\t\tbloggerlink:blog.naver.com\\/bicviruslee,\n\t\t\tpostdate:20211204\n\t\t},',
#  'title:[성수완당] <b>추운날<\\/b> 더 맛있는... 맛조합 <b>추천<\\/b> 내먹내산(+<b>메뉴<\\/b>... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/rin_onme\\/222904388413,\n\t\t\tdescription:들어가자마자 보이는 키오스크에서 간단하게 주문가능해요 다른 <b>메뉴<\\/b>도 도전해볼망 한데 항상 고정픽은 역시 #완당면 입니다 공간이 큰 편은 아니지만, 바테이블도 있고 2인용, 4인용 테이블이 골고루 있어요... ,\n\t\t\tbloggername:스쳐가는 일상에 이링 더하기+,\n\t\t\tbloggerlink:blog.naver.com\\/rin_onme,\n\t\t\tpostdate:20221019\n\t\t},',
#  'title:[강남] <b>추운날<\\/b> 직딩 점심<b>메뉴<\\/b> 강남교자,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/
\n\t\t\tlink:https:\\/\\/blog.naver.com\\/gamejaki\\/222971081105,\n\t\t\tdescription:이렇게 <b>추운 날<\\/b>은 딱인 장소이고 우리 셋 만나기 중간지점쯤이기도 해요 맛집 리스트 여러 개... 셋이서 <b>메뉴<\\/b> 3개를 시켰어요 우나기동 명란파스타 오므라이스 먹다 보니 뭔가 좀 아쉽다? 호호식당은 진짜... ,\n\t\t\tbloggername:찍찍부인 이야기,\n\t\t\tbloggerlink:blog.naver.com\\/gamejaki,\n\t\t\tpostdate:20221231\n\t\t},',
#  'title:알 도루묵구이와 시사모구이 여기가찐 <b>추운 날<\\/b> 생각나는 곳,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/zzyongimda\\/222941434184,\n\t\t\tdescription:냈던 <b>날<\\/b> 낮에 방문했는데 낮에도 이미 거의 만석이더라구요 여전한 인기에 깜짝 놀랐습니다... 전문적인 <b>메뉴<\\/b> 도루묵구이와 시사모구이를 맛볼 수 있어서 좋은 <b>추운날<\\/b> 생각나는 곳 , 을지오뎅 <b>추천<\\/b>합니다... ,\n\t\t\tbloggername:zzyongimda,\n\t\t\tbloggerlink:blog.naver.com\\/zzyongimda,\n\t\t\tpostdate:20221129\n\t\t},',
#  'title:<b>추운 날<\\/b> 푸짐한 부대찌개 - 간편한 햄 고기 듬뿍 부대찌개,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/sua8044\\/222967218477,\n\t\t\tdescription:<b>추운 날<\\/b> 푸짐한 부대찌개 - 간편한 햄 고기 듬뿍 부대찌개 글, 사진 뚜아 날씨가 추워지고 나서는 자꾸만... 국물요리도 여러 가지가 있지만 아이들도 잘 먹어주는 부대찌개가 우리 집 단골 <b>메뉴<\\/b>이다. 진한... ,\n\t\t\tbloggername:수요일 :: 수아네요리일상,\n\t\t\tbloggerlink:blog.naver.com\\/sua8044,\n\t\t\tpostdate:20221227\n\t\t},',
#  "title:<b>추운날<\\/b> 점심<b>메뉴<\\/b><b>추천<\\/b> 종로맛집 칼국수맛집 '대원',\n\t\t\tlink:https:\\/\\/blog.naver.com\\/jooart_vely\\/220601523190,\n\t\t\tdescription:겨울에 진짜 이만한 <b>메뉴<\\/b>는 없는것같아요 ㅠㅠ 다들오늘 점심으로 어떠신지 ㅎㅎ 이렇게 김치랑 먹으면 최고로 맛있어요! ㅎㅎㅎ 포스팅하면서 보니깐 또 생각나네요~ 다들 엄청<b>추운<\\/b>데 따뜻한 국물드셔요ㅜㅜ... ,\n\t\t\tbloggername:JOOJY의 블로그 : ),\n\t\t\tbloggerlink:blog.naver.com\\/jooart_vely,\n\t\t\tpostdate:20160119\n\t\t},",
#  'title:[구리\\/갈매동맛집] <b>추운날<\\/b> 생각나는 본추어탕(내돈내산),\n\t\t\tlink:https:\\/\\/blog.naver.com\\/crystal00000\\/222955972493,\n\t\t\tdescription:날씨 <b>추운날<\\/b>에는 따뜻한 보양식이 더 땡기는거 같아요 ㅎㅎ 별내에 탐터추어탕갈까하다가 이날은... 가시길 <b>추천<\\/b>해드려요 ㅎㅎ 배고파서 먹을 생각만 하다가 본추어탕 <b>메뉴<\\/b>판도 하나 못찍었네여 ㅠㅠ 추어탕... ,\n\t\t\tbloggername:소소한 일상, 크리슈어,\n\t\t\tbloggerlink:blog.naver.com\\/crystal00000,\n\t\t\tpostdate:20221214\n\t\t},',
#  'title:레트로 감성 마포역 술집 ! <b>추운날<\\/b> 칼칼한 애호박 칼국수 동리장,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/cks6170837\\/222960913296,\n\t\t\tdescription:<b>추운날<\\/b> 칼칼한 애호박 칼국수 동리장 요즘 같이 <b>추운날<\\/b> 따뜻한 국물이 넘 땡기더라고요 너무 맛있던... 동리장의 <b>메뉴<\\/b>판이에요!! 주로 애호박찌개와 꼬막비빔밥, 수육, 전이 맛있거든요 칼칼한 애호박 칼국수가... ,\n\t\t\tbloggername:루나나나나,\n\t\t\tbloggerlink:blog.naver.com\\/cks6170837,\n\t\t\tpostdate:20221220\n\t\t},',
#  'title:서초 칼국수 <b>추운 날<\\/b> 생각나는 백합이야기,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/2gayoung9\\/222942417952,\n\t\t\tdescription:ㅎㅎㅋㅋ 지난번 교대쪽에 약속이 있어서 다녀왔는데 오늘 같이 <b>추운 날<\\/b> 딱 생각나는 서초 칼국수를... 식사류로는 대표<b>메뉴<\\/b>인 백합 칼국수가 있는데 탕도 먹고 싶고, 구이, 볶음을 다 먹고 싶은 분들을 위한... ,\n\t\t\tbloggername:가용이와 여행가용,\n\t\t\tbloggerlink:blog.naver.com\\/2gayoung9,\n\t\t\tpostdate:20221130\n\t\t},',
#  'title:[성남\\/분당] 더운날도, <b>추운날<\\/b>도 맛있는 :: 평가옥 :: 평냉+온반,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/vanillashu\\/223049303760,\n\t\t\tdescription:더운날은 평양냉면 <b>추운날<\\/b>은 온반(닭고기 <b>추천<\\/b>) 봄인데 왜 요즘 쌀쌀하죠? 저녁만 되면 으슬으슬하고..... 예의상 <b>메뉴<\\/b>~ 월급받던 시절엔 어복쟁반으로 기분도 내고 그랬는데 ㅋㅋㅋ 이젠 뭐 많이 먹지도 못하고... ,\n\t\t\tbloggername:serein,\n\t\t\tbloggerlink:blog.naver.com\\/vanillashu,\n\t\t\tpostdate:20230319\n\t\t},',
#  'title:원마운트 맛집 <b>추운날<\\/b> 더 생각나는 대화동 맛집 국밥생각,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/hysz5043\\/222980163239,\n\t\t\tdescription:한식 <b>메뉴<\\/b>인 것 같아요 ~ 저희도 조만간 로운이랑 같이 한번 더 출동할 예정이랍니다 ! ㅎㅎㅎ 대화동맛집, 원마운트 맛집을 찾고 계시는 분들께 국밥생각 원마운트점 <b>추천<\\/b>합니다 !! #국밥생각... ,\n\t\t\tbloggername:행자의 쫄깃한 공간,\n\t\t\tbloggerlink:blog.naver.com\\/hysz5043,\n\t\t\tpostdate:20230110\n\t\t},',
#  'title:<b>추운날<\\/b> 얼큰한 갈치조림(저녁<b>메뉴<\\/b><b>추천<\\/b>!!),\n\t\t\tlink:https:\\/\\/blog.naver.com\\/nike2use\\/10126597778,\n\t\t\tdescription:이웃님들도 <b>추운<\\/b>겨울저녁에 갈치조림 어떠세요~~? 저흰 꽤나 맛나게 먹었어요~갈치가 고소~~한것이- 무는 또 양념이 잘 베어서 달달~하고 아~~~~~~~~~ 저녁<b>메뉴<\\/b> <b>추천<\\/b>입니다!!!,\n\t\t\tbloggername:워너비블링,\n\t\t\tbloggerlink:blog.naver.com\\/nike2use,\n\t\t\tpostdate:20111213\n\t\t},',
#  'title:오뎅국 간단하게 끓이기! <b>추운 날<\\/b>에 최고 <b>메뉴<\\/b>~,\n\t\t\tlink:https:\\/\\/blog.naver.com\\
\n\t\t\tlink:https:\\/\\/blog.naver.com\\/adrianavalos\\/222987988877,\n\t\t\tdescription:<b>추운 날<\\/b>씨에 먹기 딱 좋았던 &quot;항아리 누룽지 해산물 파스타&quot; <b>추천 메뉴<\\/b>인 이유가 있더라고요. 아직 안 드셔보신 분들은 꼭 드셔보시길 바랍니다. 본 포스팅은 소정의 원고료를 받아 작성하게 되었습니다.... ,\n\t\t\tbloggername:adrianavalos님의블로그,\n\t\t\tbloggerlink:blog.naver.com\\/adrianavalos,\n\t\t\tpostdate:20230120\n\t\t},',
#  'title:경산 중산점 : 남다른 감자탕 <b>추운날<\\/b> 딱!,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/ndwor\\/222930756711,\n\t\t\tdescription:감자탕 경산점 에서 뚝배기나 감자탕뼈 전골 <b>추천<\\/b> <b>추천<\\/b>! #감자탕 #경산감자탕 #경산맛집 #정평역감자탕 #경산남다른감자탕 #정평역맛집 #정평역밥집 #중산동맛집 #남다른감자탕중산점 #경산밥집 #남다른감자탕<b>메뉴<\\/b>,\n\t\t\tbloggername:Remember pic,\n\t\t\tbloggerlink:blog.naver.com\\/ndwor,\n\t\t\tpostdate:20221117\n\t\t},',
#  'title:<b>추운 날<\\/b> 먹기 좋은 경기도 시흥 맛집 고구려 짬뽕(본점),\n\t\t\tlink:https:\\/\\/blog.naver.com\\/dmsdud7460\\/221203172408,\n\t\t\tdescription:우리가 시킨 <b>메뉴<\\/b>는 산선 짜장 7,000원 차돌박이 짬뽕 10,000원 짬뽕밥 7,500원 아침 일찍부터 움직여서... 가볍게 먹기 좋은 음식으로 <b>추천<\\/b> 하지만 점심시간에 간다면 대기가 길어질 수 있다는 것.,\n\t\t\tbloggername:오목교 미용실 리얼드살롱 부원장 가온,\n\t\t\tbloggerlink:blog.naver.com\\/dmsdud7460,\n\t\t\tpostdate:20180212\n\t\t},',
#  'title:방배동해장국 한사바리해장국 서초점 | <b>추운 날<\\/b> 생각나는... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/1000dmsrud\\/223072492584,\n\t\t\tdescription:포장 <b>추천<\\/b>드려요 : ) 국밥좋아하는 남자친구는 해장돼지국밥 ! 내장탕 좋아하는 저는 내장탕으로다가 ~ 사이드도 종류가 많길래 녹두전으로 골랐네요 ㅎㅎ 와~~ 2명이서 먹는거라 <b>메뉴<\\/b> 2개 사이드 1개인데... ,\n\t\t\tbloggername:천의 천가지 일상,\n\t\t\tbloggerlink:blog.naver.com\\/1000dmsrud,\n\t\t\tpostdate:20230412\n\t\t}\n\t]\n}']

# %%
from ckonlpy.tag import Twitter
from konlpy.tag import Okt
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
from wordcloud import WordCloud

# %%
Twitter = Twitter()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
df = pd.read_csv('foodinfo1.csv')
df
df_word = list(df['대표식품명'])
Twitter.add_dictionary(df_word, 'Noun')

# %%
#블로그 데이터 형태소 분석
an = []
for i in range(0,len(list1)) :
    nouns =  Twitter.nouns(list1[i])
    an.append(nouns)
print(an[2])
# Out:
# ['레시피', '날', '먹음', '더', '육수', '호로', '록', '캠핑', '메뉴', '추천', '꼬치', '어묵탕', '법', '레시피', '날', '먹음', '더', '오뎅', '탕', '법', '어묵탕', '육수', '호로', '록', '캠핑', '메뉴', '추천', '국물', '요리', '준비', '끼', '식사', '해', '결하', '선택', '사계절', '모두', '시크', '도도', '토깽', '살', '효']

# %%
an
# Out:
# [['날',
#   '국물',
#   '요리',
#   '메뉴',
#   '추천',
#   '풀무원',
#   '오우',
#   '종',
#   '정통',
#   '아쿠',
#   '춥다',
#   '국물',
#   '요리',
#   '절로',
#   '생각',
#   '날',
#   '뭘',
#   '살',
#   '쿵',
#   '오늘',
#   '우동',
#   '간편식',
#   '추천',
#   '유부초밥',
#   '때',
#   '김밥',
#   '때',
#   '국물',
#   '겨울',
#   '추천',
#   '음식',
#   '저녁',
#   '메뉴',
#   '추천',
#   '날',
#   '메뉴',
#   '추천',
#   '꾱꾱꾱',
#   '하루하루'],
#  ['저녁',
#   '메뉴',
#   '추천',
#   '날',
#   '저녁',
#   '순두부찌개',
#   '법',
#   '오늘',
#   '저희',
#   '부천',
#   '내비',
#   '이야기',
#   '블로그',
#   '방문',
#   '해주',
#   '셔',
#   '감사',
#   '저녁',
#   '메뉴',
#   '추천',
#   '날',
#   '저녁',
#   '순두부찌개',
#   '법',
#   '매일',
#   '저녁',
#   '상이',
#   '고민',
#   '요',
#   '사',
#   '먹기',
#   '질리',
#   '가끔',
#   '확',
#   '음식',
#   '생기',
#   '고요',
#   '부천',
#   '내비',
#   '이야기',
#   '블박',
#   '썬팅',
#   '비',
#   '매립'],
#  ['레시피',
#   '날',
#   '먹음',
#   '더',
#   '육수',
#   '호로',
#   '록',
#   '캠핑',
#   '메뉴',
#   '추천',
#   '꼬치',
#   '어묵탕',
#   '법',
#   '레시피',
#   '날',
#   '먹음',
#   '더',
#   '오뎅',
#   '탕',
#   '법',
#   '어묵탕',
#   '육수',
#   '호로',
#   '록',
#   '캠핑',
#   '메뉴',
#   '추천',
#   '국물',
#   '요리',
#   '준비',
#   '끼',
#   '식사',
#   '해',
#   '결하',
#   '선택',
#   '사계절',
#   '모두',
#   '시크',
#   '도도',
#   '토깽',
#   '살',
#   '효'],
#  ['날',
#   '추천',
#   '메뉴',
#   '초',
#   '간단',
#   '묵은지',
#   '닭볶음탕',
#   '밥위',
#   '국물',
#   '밥',
#   '개꿀맛',
#   '완성',
#   '요리',
#   '이제',
#   '저녁',
#   '숙성',
#   '날',
#   '묵은지',
#   '닭도리탕',
#   '꽤',
#   '메뉴',
#   '선택',
#   '오늘',
#   '저녁',
#   '묵은지',
#   '닭도리탕',
#   '도',
#   '전해',
#   '보시',
#   '스마트',
#   '라이프'],
#  ['날',
#   '생각',
#   '점심',
#   '메뉴',
#   '추천',
#   '사골',
#   '칼국수',
#   '맛집',
#   '전주',
#   '신',
#   '시가지',
#   '전주',
#   '사골',
#   '칼국수',
#   '전주',
#   '맛집',
#   '날',
#   '식사',
#   '메뉴',
#   '한음',
#   '식',
#   '사골',
#   '칼국수',
#   '주신',
#   '시가지',
#   '맛집',
#   '전북',
#   '경찰청',
#   '맛집',
#   '방송국',
#   '맛집',
#   '회식',
#   '장소',
#   '추천',
#   '단체',
#   '모임',
#   '장소',
#   '직장인',
#   '점심',
#   '시가지',
#   '점심',
#   '효자동',
#   '맛집',
#   '오늘',
#   '무엇',
#   '행복'],
#  ['간편',
#   '집밥',
#   '메뉴',
#   '날',
#   '감미',
#   '옥',
#   '도가니탕',
#   '방촌',
#   '떡볶이',
#   '추천',
#   '저',
#   '전',
#   '날',
#   '냉장고',
#   '빼',
#   '조리',
#   '때',
#   '찬물',
#   '면서',
#   '해동',
#   '수',
#   '어요',
#   '냄비',
#   '날',
#   '국물',
#   '메뉴',
#   '로',
#   '감미',
#   '옥',
#   '도가니탕',
#   '추천',
#   '방촌',
#   '떡볶이',
#   '저희',
#   '남편',
#   '제',
#   '대로',
#   '이루'],
#  ['메',
#   '커피',
#   '레몬차',
#   '날',
#   '마시기',
#   '메뉴',
#   '추천',
#   '해',
#   '메',
#   '커피',
#   '레몬차',
#   '날',
#   '마시기',
#   '메뉴',
#   '추천',
#   '해',
#   '저',
#   '평소',
#   '메',
#   '커피',
#   '자주',
#   '방',
#   '문하',
#   '겨울철',
#   '종종',
#   '구',
#   '매하',
#   '것',
#   '자몽차',
#   '음번',
#   '한번',
#   '요',
#   '제',
#   '매일',
#   '심슨'],
#  ['안양',
#   '명학역',
#   '현지',
#   '맛집',
#   '두꺼비',
#   '부대찌개',
#   '날',
#   '메뉴',
#   '로',
#   '추천',
#   '어요',
#   '패딩',
#   '다가',
#   '다시',
#   '날',
#   '국물',
#   '메인',
#   '메뉴',
#   '심플',
#   '요',
#   '원래',
#   '맛집',
#   '몇',
#   '가지',
#   '메뉴',
#   '집중',
#   '저희',
#   '부대찌개',
#   '소',
#   '소한',
#   '일상'],
#  ['수원',
#   '천',
#   '천동',
#   '날',
#   '추천',
#   '메뉴',
#   '만두전골',
#   '평양',
#   '손',
#   '만두',
#   '날',
#   '몸',
#   '녹',
#   '속',
#   '일단',
#   '쇠고기',
#   '부터',
#   '질',
#   '기기',
#   '전',
#   '만두',
#   '입맛',
#   '만두전골',
#   '추천',
#   '천동',
#   '맛집',
#   '천동',
#   '만두전골',
#   '평양',
#   '손',
#   '만두',
#   '입맛',
#   '때',
#   '메뉴',
#   '추천',
#   '수원',
#   '만두전골',
#   '정',
#   '삼화'],
#  ['아이',
#   '간식',
#   '메뉴',
#   '추천',
#   '날',
#   '국물',
#   '요리',
#   '풀무원',
#   '가락',
#   '유부',
#   '우동',
#   '아이',
#   '간식',
#   '메뉴',
#   '추천',
#   '날',
#   '국물',
#   '요리',
#   '풀무원',
#   '가락',
#   '유부',
#   '우동',
#   '가락',
#   '짬뽕',
#   '우동',
#   '먹방',
#   '안녕',
#   '요즘',
#   '일',
#   '교차',
#   '심해',
#   '지면',
#   '아침',
#   '저녁',
#   '고요',
#   '날',
#   '국물',
#   '요리',
#   '미거',
#   '네'],
#  ['간편식',
#   '얼',
#   '고추장',
#   '수제비',
#   '만들기',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '요즘',
#   '날',
#   '비',
#   '날',
#   '누구',
#   '별',
#   '다른',
#   '재료',
#   '준비',
#   '이도',
#   '수',
#   '점',
#   '최고',
#   '매력',
#   '었던',
#   '제품',
#   '었다',
#   '리하',
#   '간편식',
#   '롯데',
#   '상품',
#   '롯데',
#   '요리',
#   '롯데',
#   '마트',
#   '상품',
#   '고추',
#   '자',
#   '수제비'],
#  ['죽',
#   '메뉴',
#   '추천',
#   '날',
#   '뜻',
#   '끼',
#   '날',
#   '음식',
#   '그',
#   '래서',
#   '국밥',
#   '류',
#   '먹기',
#   '자',
#   '극적',
#   '죽',
#   '메뉴',
#   '추천',
#   '려고',
#   '요',
#   '죽',
#   '거나',
#   '포장',
#   '이해',
#   '직접',
#   '본적',
#   '별로',
#   '짱구',
#   '밍',
#   '일상',
#   '블로그'],
#  ['익선동',
#   '맛집',
#   '날',
#   '국물',
#   '메뉴',
#   '샤브샤브',
#   '추천',
#   '온천',
#   '집',
#   '섭',
#   '날',
#   '웨이',
#   '팅',
#   '분만',
#   '체감',
#   '한시',
#   '간',
#   '기다림',
#   '추위',
#   '샤브샤브',
#   '추천',
#   '맛집',
#   '익선동',
#   '샤브샤브',
#   '여기',
#   '꼭',
#   '가보',
#   '셔',
#   '해',
#   '껏',
#   '어서',
#   '배부',
#   '르',
#   '또',
#   '일상',
#   '여행'],
#  ['선유도역',
#   '날',
#   '먹기',
#   '설렁탕',
#   '맛집',
#   '직장인',
#   '점심',
#   '추천',
#   '점심',
#   '추천',
#   '이남',
#   '장',
#   '선유도역',
#   '생',
#   '긴지',
#   '오래',
#   '전통',
#   '이',
#   '남장',
#   '설렁탕',
#   '집',
#   '방문',
#   '점심',
#   '식사',
#   '메뉴',
#   '기도',
#   '날',
#   '더',
#   '생각',
#   '국물',
#   '요리',
#   '것',
#   '매일',
#   '여행'],
#  ['울산',
#   '정',
#   '칼국수',
#   '날',
#   '한사',
#   '바리',
#   '점심',
#   '메뉴',
#   '로',
#   '추천',
#   '해',
#   '정',
#   '칼국수',
#   '메뉴',
#   '판',
#   '정',
#   '칼국수',
#   '바지락',
#   '칼국수',
#   '엄마',
#   '들깨',
#   '칼국수',
#   '시더',
#   '들깨',
#   '아하',
#   '시',
#   '분',
#   '라면',
#   '들깨',
#   '칼국수',
#   '추천',
#   '울산',
#   '칼국수',
#   '인기',
#   '아날로그',
#   '졔졔'],
#  ['인',
#   '샤브샤브',
#   '날',
#   '혼밥',
#   '메뉴',
#   '국물',
#   '요리',
#   '추천',
#   '날',
#   '혼밥',
#   '메뉴',
#   '국물',
#   '요리',
#   '추천',
#   '인',
#   '샤브샤브',
#   '혼자',
#   '서도',
#   '어요',
#   '집밥',
#   '요리',
#   '집밥',
#   '샤브샤브',
#   '샤브샤브',
#   '만들기',
#   '메뉴',
#   '국물',
#   '요리',
#   '메뉴',
#   '추천',
#   '맘마'],
#  ['국물',
#   '요리',
#   '메뉴',
#   '추천',
#   '풀무원',
#   '가락',
#   '유부',
#   '우동',
#   '날',
#   '우동',
#   '이지',
#   '국물',
#   '요리',
#   '메뉴',
#   '추천',
#   '풀무원',
#   '가락',
#   '유부',
#   '우동',
#   '나',
#   '봄',
#   '여름',
#   '가을',
#   '겨울',
#   '상관',
#   '사계절',
#   '우동',
#   '입하',
#   '날',
#   '역시',
#   '국물',
#   '요리',
#   '면',
#   '요리',
#   '풀무원',
#   '우동',
#   '은',
#   '냉수',
#   '마찰',
#   '쫄깃',
#   '식',
#   '낭낭',
#   '일상'],
#  ['오산',
#   '맛집',
#   '개성',
#   '손',
#   '만두',
#   '날',
#   '생각',
#   '메뉴',
#   '추천',
#   '계절',
#   '개성',
#   '손',
#   '만두',
#   '국물',
#   '숫',
#   '가락',
#   '겨울',
#   '이면',
#   '더',
#   '생각',
#   '메뉴',
#   '여러분',
#   '날',
#   '더',
#   '생각',
#   '뚝배기',
#   '개',
#   '인적',
#   '아주',
#   '가족',
#   '거나',
#   '친',
#   '구들',
#   '술',
#   '한잔',
#   '비상',
#   '누수',
#   '탐지'],
#  ['옛날',
#   '곱창',
#   '마을',
#   '본점',
#   '곱창전골',
#   '맛집',
#   '저녁',
#   '메뉴',
#   '날',
#   '추천',
#   '음식',
#   '안녕',
#   '저녁',
#   '메뉴',
#   '로',
#   '것',
#   '것',
#   '생각',
#   '날',
#   '다른',
#   '거',
#   '싹',
#   '동생',
#   '추천',
#   '해달',
#   '하니',
#   '전골',
#   '이면',
#   '돼지',
#   '이',
#   '래서',
#   '옥훼이',
#   '바로',
#   '돼지',
#   '곱창전골',
#   '주문',
#   '돼지',
#   '곱창',
#   '미미',
#   '밍님',
#   '것',
#   '것',
#   '블로그'],
#  ['날',
#   '국물',
#   '메뉴',
#   '뼈',
#   '해장국',
#   '집',
#   '종로',
#   '조가',
#   '날',
#   '해장국',
#   '종로',
#   '맛집',
#   '종로',
#   '가조',
#   '뼈',
#   '해장국',
#   '종로',
#   '가점',
#   '심',
#   '메뉴',
#   '추천',
#   '종로',
#   '맛집',
#   '추천',
#   '종로',
#   '은근',
#   '국물',
#   '메뉴',
#   '곳',
#   '어서',
#   '사무실',
#   '좀',
#   '날',
#   '은'],
#  ['신림역',
#   '날',
#   '집',
#   '먹기',
#   '밀키',
#   '트',
#   '추천',
#   '밥끼',
#   '하루하루',
#   '일어',
#   '날',
#   '나',
#   '가기',
#   '오늘',
#   '추천',
#   '메뉴',
#   '를',
#   '골',
#   '라주시',
#   '요',
#   '만두',
#   '류',
#   '저',
#   '하나',
#   '확대',
#   '분',
#   '위',
#   '달'],
#  ['날',
#   '추천',
#   '메뉴',
#   '추천',
#   '음식',
#   '사골',
#   '칼국수',
#   '오늘',
#   '메뉴',
#   '사골',
#   '칼국수',
#   '메인',
#   '메뉴인',
#   '사골',
#   '칼국수',
#   '명동',
#   '명동',
#   '교자',
#   '면',
#   '처럼',
#   '면',
#   '날씨',
#   '칼국수',
#   '추천',
#   '해',
#   '날',
#   '추천',
#   '메뉴',
#   '추천',
#   '음식',
#   '사골',
#   '칼국수',
#   '본사',
#   '구내식당',
#   '아빠'],
#  ['찌개',
#   '지존',
#   '날',
#   '식사',
#   '도',
#   '술',
#   '잔',
#   '집',
#   '메뉴',
#   '오늘',
#   '요즘',
#   '한파',
#   '간단',
#   '식사',
#   '술안주',
#   '도',
#   '찌개',
#   '지존',
#   '리뷰',
#   '적극',
#   '추천',
#   '김치찌개',
#   '고추장찌개',
#   '닭',
#   '음식',
#   '이',
#   '날',
#   '간단',
#   '식사',
#   '대용',
#   '강추',
#   '움직',
#   '이지'],
#  ['점심',
#   '메뉴',
#   '추천',
#   '날',
#   '짬뽕',
#   '점심',
#   '식사',
#   '점심',
#   '메뉴',
#   '추천',
#   '날',
#   '짬뽕',
#   '점심',
#   '식사',
#   '날씨',
#   '점심',
#   '이면',
#   '음식',
#   '생각',
#   '원래',
#   '부터',
#   '짬뽕',
#   '아해',
#   '자주',
#   '요즘',
#   '더',
#   '카스',
#   '제동',
#   '사랑',
#   '와이파이',
#   '고',
#   '둥이'],
#  ['인천',
#   '혼밥',
#   '메뉴',
#   '추천',
#   '날',
#   '국밥',
#   '그릇',
#   '혼밥',
#   '메뉴',
#   '로',
#   '음식',
#   '즐겨드',
#   '시나',
#   '저',
#   '오늘',
#   '혼밥',
#   '메뉴',
#   '고민',
#   '중',
#   '동네',
#   '갈비찜',
#   '곽만근',
#   '갈비탕',
#   '집',
#   '인천광역시',
#   '서구',
#   '원',
#   '당대',
#   '완',
#   '정역',
#   '다이소',
#   '라인',
#   '위치',
#   '어요',
#   '매일'],
#  ['날',
#   '마곡',
#   '나루',
#   '전집',
#   '추천',
#   '그날',
#   '전집',
#   '업무',
#   '왕',
#   '날씨',
#   '요즘',
#   '전집',
#   '추천',
#   '요즘',
#   '날씨',
#   '일반',
#   '마곡',
#   '나루',
#   '전집',
#   '날',
#   '막걸리',
#   '한잔',
#   '때',
#   '그날',
#   '전집',
#   '방문',
#   '업',
#   '무왕',
#   '것',
#   '것'],
#  ['육',
#   '간청',
#   '디',
#   '갈비탕',
#   '날',
#   '점심',
#   '메뉴',
#   '로',
#   '추천',
#   '해',
#   '요즘',
#   '그나',
#   '마',
#   '디',
#   '만하',
#   '고',
#   '갈비탕',
#   '집',
#   '겨울',
#   '출근',
#   '몸',
#   '마음',
#   '녹',
#   '여보',
#   '요',
#   '구로',
#   '디지털',
#   '단지',
#   '겨울',
#   '점심',
#   '메뉴',
#   '로',
#   '추천',
#   '뒤뚱뒤뚱'],
#  ['날',
#   '점심',
#   '메뉴',
#   '추천',
#   '은',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '말',
#   '뭐해',
#   '시원',
#   '면서',
#   '칼칼',
#   '육수',
#   '날',
#   '점심',
#   '메뉴',
#   '고민',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '고고',
#   '또',
#   '하나',
#   '매력',
#   '바로',
#   '볶음밥',
#   '주저',
#   '설겆',
#   '필요',
#   '만큼',
#   '쌱',
#   '맛',
#   '어요',
#   '평택',
#   '피부',
#   '앤',
#   '클린'],
#  ['광화문',
#   '종로',
#   '맛집',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '영업',
#   '시간',
#   '메뉴',
#   '판',
#   '날씨',
#   '요즘',
#   '길거리',
#   '포장마차',
#   '어가',
#   '어묵국',
#   '물',
#   '매콤',
#   '떡볶이',
#   '기억',
#   '간식',
#   '메뉴',
#   '로',
#   '추천',
#   '로라',
#   '방앗간',
#   '광화문',
#   '디',
#   '타워',
#   '점',
#   '위치',
#   '서울',
#   '종로구',
#   '종로',
#   '길',
#   '디',
#   '타워',
#   '층',
#   '소호',
#   '거리',
#   '호',
#   '또박',
#   '행복',
#   '육아',
#   '여행'],
#  ['신설',
#   '맛집',
#   '제주',
#   '맛',
#   '재벌',
#   '국수',
#   '번',
#   '날',
#   '날',
#   '추천',
#   '날',
#   '낮',
#   '기온',
#   '영하',
#   '도',
#   '안팍',
#   '겨울',
#   '카페',
#   '문틈',
#   '찬',
#   '바람',
#   '정도',
#   '날씨',
#   '국물',
#   '날',
#   '토요일',
#   '오후'],
#  ['날',
#   '짬뽕',
#   '그릇',
#   '점심',
#   '메뉴',
#   '짬뽕',
#   '추천',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '짬뽕',
#   '그릇',
#   '날',
#   '짬뽕',
#   '그릇',
#   '점심',
#   '메뉴',
#   '짬뽕',
#   '추천',
#   '짬뽕',
#   '단무지',
#   '양파',
#   '적당',
#   '접시',
#   '주문',
#   '짬뽕',
#   '날',
#   '제주도',
#   '여행',
#   '관련',
#   '정보',
#   '관광지',
#   '맛집',
#   '숙소',
#   '렌트'],
#  ['날',
#   '스',
#   '어묵',
#   '전골',
#   '밀키',
#   '트',
#   '추천',
#   '해',
#   '밀',
#   '밀키',
#   '트',
#   '외식',
#   '걱정',
#   '시기',
#   '외식',
#   '지니',
#   '특별',
#   '메뉴',
#   '때',
#   '밀',
#   '밀',
#   '키트',
#   '주문',
#   '이번',
#   '주문',
#   '밀키',
#   '트',
#   '메뉴',
#   '날',
#   '스',
#   '어묵',
#   '전골',
#   '밀키',
#   '트',
#   '추천',
#   '해',
#   '밀',
#   '밀키',
#   '트',
#   '중',
#   '이웃',
#   '세상',
#   '속'],
#  ['홍대',
#   '맛집',
#   '추천',
#   '날',
#   '제격',
#   '순대',
#   '만두전골',
#   '맛집',
#   '홍대',
#   '골',
#   '추천',
#   '홍대',
#   '골',
#   '요즘',
#   '진짜',
#   '춥다',
#   '어도',
#   '몸',
#   '덜덜',
#   '날씨',
#   '날',
#   '술',
#   '술술',
#   '맛',
#   '이지',
#   '저',
#   '콜라',
#   '날',
#   '제격',
#   '었던',
#   '골',
#   '제일'],
#  ['날',
#   '김치',
#   '뚝배기',
#   '우동',
#   '수제',
#   '돈까스',
#   '마곡',
#   '직장인',
#   '추천',
#   '사장',
#   '센스',
#   '테이블',
#   '마다',
#   '종이컵',
#   '그라인더',
#   '소금',
#   '후추',
#   '준비',
#   '어요',
#   '메뉴',
#   '술',
#   '다음',
#   '날',
#   '날',
#   '매콤',
#   '게',
#   '날',
#   '무조건',
#   '김치',
#   '뚝배기',
#   '우동',
#   '추천',
#   '국물',
#   '일단',
#   '정말',
#   '시나'],
#  ['날',
#   '마포',
#   '만복',
#   '국수',
#   '집',
#   '멸치',
#   '쌀국수',
#   '추천',
#   '직장인',
#   '점심',
#   '메뉴',
#   '강력',
#   '추천',
#   '날',
#   '만복',
#   '국수',
#   '집',
#   '멸치',
#   '쌀국수',
#   '간날',
#   '구내식당',
#   '밥',
#   '질리',
#   '바람',
#   '휭휭',
#   '불어',
#   '레트로',
#   '식당',
#   '만복',
#   '국수',
#   '집',
#   '잔치국수',
#   '메뉴',
#   '잔치국수',
#   '멸치',
#   '육수',
#   '오작교',
#   '통신',
#   '라이프',
#   '스토리'],
#  ['구월동',
#   '쌀국수',
#   '날',
#   '날',
#   '추천',
#   '포',
#   '메인',
#   '레드',
#   '구월',
#   '점',
#   '미리',
#   '메뉴',
#   '를',
#   '보고',
#   '가시',
#   '메뉴',
#   '판',
#   '사진',
#   '한번',
#   '드립',
#   '포',
#   '메인',
#   '레드',
#   '구월',
#   '점',
#   '한번',
#   '방',
#   '문해',
#   '보시',
#   '길',
#   '저',
#   '날씨',
#   '날',
#   '쌀국수',
#   '자주',
#   '편',
#   '포',
#   '메인',
#   '정말',
#   '임용',
#   '동쓰'],
#  ['날',
#   '차돌',
#   '떡볶이',
#   '먹기',
#   '청년',
#   '다방',
#   '강원',
#   '인제',
#   '점',
#   '추천',
#   '메뉴',
#   '슬라이드',
#   '즉석',
#   '떡볶이',
#   '종류',
#   '아주',
#   '치킨',
#   '이나',
#   '사이드',
#   '어요',
#   '청년',
#   '다방',
#   '몇',
#   '년',
#   '전',
#   '오랜만',
#   '었는데',
#   '아주',
#   '만족',
#   '날',
#   '즉석',
#   '떡볶이',
#   '추천',
#   '체험',
#   '보고서'],
#  ['날',
#   '저절로',
#   '생각',
#   '샤브샤브',
#   '칼국수',
#   '현지',
#   '추천',
#   '맛집',
#   '날',
#   '생각',
#   '따끈따끈',
#   '동해',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '수요일',
#   '정기',
#   '휴무',
#   '고등학생',
#   '시절',
#   '부터',
#   '추천',
#   '곳',
#   '약',
#   '지나',
#   '추천',
#   '맛집',
#   '가보',
#   '나',
#   '뭐',
#   '늦',
#   '더라도',
#   '거지',
#   '라챠챠'],
#  ['소고기',
#   '수육',
#   '만들기',
#   '날',
#   '어린이',
#   '보양식',
#   '추천',
#   '메뉴',
#   '수육',
#   '육수',
#   '소스',
#   '살짝',
#   '어른',
#   '용',
#   '고기',
#   '육개장',
#   '날',
#   '온',
#   '가족',
#   '보양',
#   '코스트코',
#   '때',
#   '덩이',
#   '쟁여놨',
#   '다가',
#   '시간',
#   '때',
#   '푹',
#   '여서',
#   '추천',
#   '김',
#   '엄마',
#   '헤롱',
#   '로그'],
#  ['가디',
#   '역',
#   '맛집',
#   '추천',
#   '날',
#   '매콤',
#   '짬뽕',
#   '추천',
#   '날',
#   '매콤',
#   '짬뽕',
#   '홍콩',
#   '반점',
#   '안녕',
#   '여러분',
#   '급격',
#   '날씨',
#   '자연',
#   '게',
#   '요즘',
#   '요',
#   '저',
#   '눈',
#   '오늘',
#   '오늘',
#   '감',
#   '동료',
#   '중식',
#   '점심',
#   '메뉴',
#   '로',
#   '도서',
#   '출판',
#   '지식',
#   '과감',
#   '성',
#   '공식',
#   '블로그'],
#  ['온정',
#   '손',
#   '만두',
#   '호',
#   '매실',
#   '점',
#   '날',
#   '칼국수',
#   '만두',
#   '추천',
#   '겨울',
#   '요즘',
#   '날씨',
#   '때',
#   '방문',
#   '추천',
#   '식당',
#   '만두',
#   '살짝',
#   '국물',
#   '국물',
#   '더더',
#   '담',
#   '맛',
#   '요',
#   '날',
#   '추천',
#   '메뉴',
#   '칼국수',
#   '행복',
#   '블로그'],
#  ['성수',
#   '완당',
#   '날',
#   '더',
#   '맛',
#   '조합',
#   '추천',
#   '내',
#   '산',
#   '메뉴',
#   '어가',
#   '자마자',
#   '보이',
#   '키오',
#   '스크',
#   '간단',
#   '주문',
#   '가능',
#   '요',
#   '다른',
#   '메뉴',
#   '도',
#   '도전',
#   '볼망',
#   '항상',
#   '고정',
#   '픽',
#   '역시',
#   '당면',
#   '공간',
#   '편',
#   '니지',
#   '바',
#   '테이블',
#   '인용',
#   '인용',
#   '테이블',
#   '골',
#   '고루',
#   '어요',
#   '일상',
#   '링',
#   '더하기'],
#  ['강남',
#   '날',
#   '직딩',
#   '점심',
#   '메뉴',
#   '강남',
#   '교자',
#   '겨울',
#   '직딩',
#   '점심',
#   '메뉴',
#   '로',
#   '픽',
#   '칼국수',
#   '맛집',
#   '교자',
#   '맛집',
#   '시',
#   '그니',
#   '처',
#   '메뉴',
#   '칼국수',
#   '뿐',
#   '설렁탕',
#   '막내',
#   '님들',
#   '강남',
#   '점심',
#   '메뉴',
#   '로',
#   '남녀',
#   '노소',
#   '강남',
#   '교자',
#   '추천',
#   '돈',
#   '산',
#   '스코어'],
#  ['알탕',
#   '날',
#   '추천',
#   '메뉴',
#   '로',
#   '듯',
#   '바다',
#   '황제',
#   '알탕',
#   '점심',
#   '날씨',
#   '뭔가',
#   '끈',
#   '국물',
#   '듬북',
#   '알',
#   '어간',
#   '알탕',
#   '어서',
#   '대흥동',
#   '해물',
#   '요리',
#   '전문점',
#   '바다',
#   '황제',
#   '선택',
#   '어요',
#   '알탕',
#   '여기',
#   '알탕',
#   '정식',
#   '인분',
#   '밑반찬',
#   '붓다',
#   '붓솝'],
#  ['청라',
#   '맛집',
#   '진지',
#   '방',
#   '순대국',
#   '날',
#   '먹기',
#   '국밥',
#   '수',
#   '요즘',
#   '날',
#   '국물',
#   '생각',
#   '거',
#   '청라',
#   '맛집',
#   '순대국',
#   '집',
#   '진지',
#   '방',
#   '순대국',
#   '번',
#   '추천',
#   '청라',
#   '순대국',
#   '인천',
#   '서구',
#   '맛집',
#   '청라',
#   '맛집',
#   '서구',
#   '맛집',
#   '순대국',
#   '맛집',
#   '봄',
#   '어요'],
#  ['역삼동',
#   '점심',
#   '메뉴',
#   '추천',
#   '날',
#   '호박',
#   '불고기',
#   '쌀국수',
#   '역삼동',
#   '점심',
#   '메뉴',
#   '추천',
#   '날',
#   '호박',
#   '불고기',
#   '쌀국수',
#   '그릇',
#   '더니',
#   '점심시간',
#   '무엇',
#   '을지',
#   '항상',
#   '행복',
#   '고민',
#   '오늘',
#   '역시',
#   '저',
#   '고민',
#   '행복',
#   '덩치',
#   '거',
#   '덩'],
#  ['부산',
#   '정관',
#   '맛집',
#   '부산',
#   '옹심이',
#   '칼국수',
#   '날',
#   '직원',
#   '분',
#   '추천',
#   '메뉴',
#   '옹심이',
#   '궁금',
#   '매번',
#   '고하',
#   '다가',
#   '그냥',
#   '메뉴',
#   '어서',
#   '요즘',
#   '처럼',
#   '날',
#   '은',
#   '끈',
#   '메뉴',
#   '제일',
#   '칼국수',
#   '어가',
#   '면도',
#   '러블',
#   '리수',
#   '지니',
#   '달달',
#   '하루'],
#  ['날',
#   '만',
#   '나기',
#   '약속',
#   '장소',
#   '터',
#   '맛집',
#   '일본',
#   '가정',
#   '식',
#   '호호',
#   '식당',
#   '날',
#   '은',
#   '장소',
#   '우리',
#   '셋',
#   '만',
#   '나기',
#   '중간지점',
#   '쯤',
#   '이기',
#   '해',
#   '맛집',
#   '리스트',
#   '여러',
#   '개',
#   '셋',
#   '이서',
#   '메뉴',
#   '개',
#   '어요',
#   '우나기',
#   '명란',
#   '파스타',
#   '오므라이스',
#   '뭔가',
#   '좀',
#   '호호',
#   '식당',
#   '진짜',
#   '찍찍',
#   '부인',
#   '이야기'],
#  ['알',
#   '도루묵',
#   '구이',
#   '시',
#   '사모',
#   '구이',
#   '여기',
#   '날',
#   '생각',
#   '곳',
#   '날',
#   '낮',
#   '방문',
#   '낮',
#   '거의',
#   '만석',
#   '여전',
#   '인기',
#   '깜짝',
#   '전',
#   '문적',
#   '메뉴',
#   '도루묵',
#   '구이',
#   '시',
#   '사모',
#   '구이',
#   '수',
#   '어서',
#   '날',
#   '생각',
#   '곳',
#   '을지',
#   '오뎅',
#   '추천'],
#  ['날',
#   '짐',
#   '부대찌개',
#   '간편',
#   '햄',
#   '고기',
#   '듬뿍',
#   '부대찌개',
#   '날',
#   '짐',
#   '부대찌개',
#   '간편',
#   '햄',
#   '고기',
#   '듬뿍',
#   '부대찌개',
#   '글',
#   '사진',
#   '뚜',
#   '날씨',
#   '지고',
#   '자꾸만',
#   '국물',
#   '요리',
#   '여러',
#   '가지',
#   '아이',
#   '부대찌개',
#   '우리',
#   '집',
#   '단골',
#   '메뉴',
#   '수요일',
#   '수아',
#   '요리',
#   '일상'],
#  ['날',
#   '점심',
#   '메뉴',
#   '추천',
#   '종로',
#   '맛집',
#   '칼국수',
#   '맛집',
#   '대원',
#   '겨울',
#   '진짜',
#   '메뉴',
#   '오늘',
#   '점심',
#   '신지',
#   '김치',
#   '최고',
#   '어요',
#   '포스팅',
#   '면서',
#   '보',
#   '또',
#   '생각',
#   '데',
#   '국물',
#   '의',
#   '블로그'],
#  ['구리',
#   '갈매동',
#   '맛집',
#   '날',
#   '생각',
#   '추어탕',
#   '돈',
#   '산',
#   '날씨',
#   '날',
#   '보양식',
#   '더',
#   '별내',
#   '터',
#   '추어탕',
#   '다가',
#   '날',
#   '가시',
#   '길',
#   '추천',
#   '파서',
#   '생각',
#   '다가',
#   '추어탕',
#   '메뉴',
#   '판도',
#   '하나',
#   '여',
#   '추어탕',
#   '소',
#   '소한',
#   '일상',
#   '크리',
#   '슈어'],
#  ['레트로',
#   '감성',
#   '마포역',
#   '술집',
#   '날',
#   '애호박',
#   '칼국수',
#   '동리',
#   '장',
#   '날',
#   '애호박',
#   '칼국수',
#   '동리',
#   '장',
#   '요즘',
#   '날',
#   '국물',
#   '고요',
#   '동리',
#   '장의',
#   '메뉴',
#   '판이',
#   '주로',
#   '애',
#   '호박찌개',
#   '꼬막',
#   '비빔밥',
#   '수육',
#   '전이',
#   '애호박',
#   '칼국수',
#   '루나',
#   '나나'],
#  ['서초',
#   '칼국수',
#   '날',
#   '생각',
#   '백합',
#   '이야기',
#   '지난번',
#   '교',
#   '대쪽',
#   '약속',
#   '어서',
#   '오늘',
#   '날',
#   '생각',
#   '서초',
#   '칼국수',
#   '식',
#   '사류',
#   '대표',
#   '메뉴',
#   '인',
#   '백합',
#   '칼국수',
#   '탕',
#   '구이',
#   '볶음',
#   '분',
#   '위',
#   '가용',
#   '여행가',
#   '용'],
#  ['성남',
#   '분당',
#   '날',
#   '날',
#   '도',
#   '평가',
#   '옥',
#   '평냉',
#   '반',
#   '날',
#   '평양',
#   '냉면',
#   '날',
#   '은',
#   '반',
#   '닭고기',
#   '추천',
#   '봄',
#   '왜',
#   '요즘',
#   '저녁',
#   '으슬으',
#   '슬하',
#   '예의',
#   '상',
#   '메뉴',
#   '월급',
#   '시절',
#   '어복',
#   '쟁반',
#   '기분',
#   '젠',
#   '뭐',
#   '지도',
#   '못'],
#  ['원마운트',
#   '맛집',
#   '날',
#   '더',
#   '생각',
#   '대화동',
#   '맛집',
#   '국밥',
#   '생각',
#   '한식',
#   '메뉴',
#   '인',
#   '것',
#   '저희',
#   '조만간',
#   '한번',
#   '더',
#   '출동',
#   '예정',
#   '대화동',
#   '맛집',
#   '원마운트',
#   '맛집',
#   '계시',
#   '분',
#   '국밥',
#   '생각',
#   '원마운트',
#   '점',
#   '추천',
#   '국밥',
#   '생각',
#   '행자',
#   '쫄깃',
#   '공간'],
#  ['날',
#   '갈치조림',
#   '저녁',
#   '메뉴',
#   '추천',
#   '이웃',
#   '님들',
#   '겨울',
#   '저녁',
#   '갈치조림',
#   '저',
#   '꽤',
#   '맛',
#   '어요',
#   '갈치',
#   '고소',
#   '것',
#   '또',
#   '양념',
#   '베',
#   '어서',
#   '달달',
#   '저녁',
#   '메뉴',
#   '추천',
#   '워',
#   '너비',
#   '블링'],
#  ['오뎅',
#   '국',
#   '간단',
#   '이기',
#   '날',
#   '최고',
#   '메뉴',
#   '간단',
#   '이기',
#   '메뉴',
#   '로',
#   '추천',
#   '해',
#   '나',
#   '요즘',
#   '날',
#   '간단',
#   '뚝딱',
#   '내심',
#   '모두',
#   '메뉴',
#   '재료',
#   '어묵',
#   '봉지',
#   '멸치',
#   '다시마',
#   '육수',
#   '무',
#   '개',
#   '대파',
#   '쑥갓',
#   '약간',
#   '국',
#   '간장',
#   '술',
#   '마늘',
#   '술',
#   '그녀',
#   '이야기'],
#  ['날',
#   '점심',
#   '추천',
#   '메뉴',
#   '대전',
#   '맛집',
#   '이비가',
#   '짬뽕',
#   '원래',
#   '면',
#   '아하',
#   '기도',
#   '날',
#   '은',
#   '역시',
#   '면',
#   '생각',
#   '요',
#   '둔산동',
#   '본점',
#   '최근',
#   '속도',
#   '체인점',
#   '늘',
#   '어가',
#   '이비가',
#   '짬뽕',
#   '카레',
#   '보이',
#   '것',
#   '이비가',
#   '아로마테라피',
#   '스튜디오'],
#  ['고흥',
#   '갈비탕',
#   '맛집',
#   '날',
#   '이면',
#   '생각',
#   '국물',
#   '맛집',
#   '날',
#   '국물',
#   '생각',
#   '고흥',
#   '양산박',
#   '고흥',
#   '갈비탕',
#   '맛집',
#   '안녕',
#   '고흥',
#   '관광',
#   '청년',
#   '박',
#   '두',
#   '메뉴',
#   '모두',
#   '포장',
#   '가능',
#   '온',
#   '가족',
#   '수',
#   '갈비탕',
#   '맛집',
#   '추천',
#   '합',
#   '고흥',
#   '관광',
#   '공식',
#   '블로그',
#   '고흥',
#   '여행'],
#  ['날',
#   '추천',
#   '메뉴',
#   '범계',
#   '만두전골',
#   '성경',
#   '만두',
#   '요리',
#   '전문점',
#   '분',
#   '날',
#   '추천',
#   '메뉴',
#   '로',
#   '만두전골',
#   '택',
#   '점심시간',
#   '전부',
#   '터',
#   '예약',
#   '석도',
#   '북적',
#   '북적',
#   '동생',
#   '먼저',
#   '추천',
#   '준',
#   '곳',
#   '요',
#   '저',
#   '이',
#   '는걸',
#   '먹기',
#   '위해',
#   '이',
#   '쯔모',
#   '욧'],
#  ['맛집',
#   '바다',
#   '양푼',
#   '동태',
#   '탕',
#   '용인',
#   '점',
#   '어탕',
#   '날',
#   '날',
#   '더더',
#   '겨울',
#   '한번',
#   '만족',
#   '메뉴',
#   '수제비',
#   '면서',
#   '추천',
#   '남편',
#   '으쓱',
#   '바다',
#   '양푼',
#   '동태',
#   '탕',
#   '어요',
#   '마을',
#   '맛집',
#   '이기',
#   '냠삐공',
#   '특공대'],
#  ['날',
#   '점심',
#   '메뉴',
#   '추천',
#   '오늘',
#   '날',
#   '아주',
#   '오늘',
#   '날',
#   '씨',
#   '매콤',
#   '거나',
#   '국물',
#   '생각',
#   '날',
#   '점심',
#   '추천',
#   '드릴',
#   '메뉴',
#   '낙지볶음',
#   '매콤',
#   '피로',
#   '몸',
#   '낙지볶음',
#   '시원',
#   '냉국',
#   '연우',
#   '컴퓨터'],
#  ['여수',
#   '전집',
#   '청담',
#   '앤전',
#   '날',
#   '분위기',
#   '여수',
#   '여서동',
#   '술집',
#   '추천',
#   '안주',
#   '까지',
#   '메뉴',
#   '다양',
#   '편이',
#   '가장',
#   '부분',
#   '신기',
#   '술',
#   '점',
#   '전집',
#   '답',
#   '다양',
#   '막걸리',
#   '전통주',
#   '하이',
#   '볼',
#   '소주',
#   '종류',
#   '우리',
#   '가장',
#   '인기',
#   '메뉴',
#   '중',
#   '하나라',
#   '오늘',
#   '안녕'],
#  ['회기역',
#   '맛집',
#   '날',
#   '역시',
#   '감자탕',
#   '날',
#   '회기역',
#   '맛집',
#   '감자탕',
#   '사람',
#   '마음',
#   '모두',
#   '감자탕',
#   '만두',
#   '아라하',
#   '칼국수',
#   '아라하',
#   '저',
#   '위',
#   '메뉴',
#   '사골국',
#   '칼국수',
#   '만두',
#   '도시'],
#  ['날',
#   '점심',
#   '메뉴',
#   '추천',
#   '안녕',
#   '전자랜드',
#   '연우',
#   '컴퓨터',
#   '날씨',
#   '매우',
#   '날',
#   '데',
#   '점심',
#   '거',
#   '드',
#   '실지',
#   '연우',
#   '컴퓨터',
#   '추천',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '한국',
#   '대표',
#   '음식',
#   '중',
#   '한가지',
#   '연우',
#   '컴퓨터'],
#  ['충무로',
#   '공릉',
#   '닭',
#   '마리',
#   '충무로',
#   '점',
#   '비',
#   '날',
#   '날',
#   '슴슴',
#   '평점',
#   '및',
#   '가격',
#   '주문',
#   '메뉴',
#   '네이버',
#   '평점',
#   '가격',
#   '천원',
#   '만원',
#   '닭곰탕',
#   '천원',
#   '닭',
#   '마리',
#   '추천',
#   '비',
#   '날',
#   '날',
#   '국물',
#   '때',
#   '명',
#   '정도',
#   '먹기',
#   '것',
#   '주로',
#   '비',
#   '날',
#   '이나',
#   '땅',
#   '이의',
#   '오늘',
#   '어디'],
#  ['수원',
#   '시청',
#   '앞',
#   '칼국수',
#   '날',
#   '점심',
#   '메뉴',
#   '로',
#   '추천',
#   '수원',
#   '시청',
#   '앞',
#   '칼국수',
#   '날',
#   '점심',
#   '메뉴',
#   '로',
#   '추천',
#   '날',
#   '은',
#   '밥',
#   '나',
#   '가기',
#   '음',
#   '나',
#   '가기',
#   '대신',
#   '날씨',
#   '욕구',
#   '모두',
#   '만족',
#   '메뉴',
#   '로',
#   '우리',
#   '아들',
#   '꼬',
#   '라지',
#   '이야기'],
#  ['날',
#   '더',
#   '음식',
#   '샤브샤브',
#   '목포',
#   '월남쌈',
#   '샤브',
#   '전문점',
#   '이번',
#   '신랑',
#   '휴무',
#   '일',
#   '애',
#   '유치원',
#   '점심',
#   '자고',
#   '이야기',
#   '남편',
#   '추천',
#   '날',
#   '배',
#   '꽃',
#   '마름',
#   '남편',
#   '날',
#   '자주',
#   '식당',
#   '마름',
#   '세상',
#   '특별',
#   '존재'],
#  ['블루',
#   '보틀',
#   '여의도',
#   '카페',
#   '웨이',
#   '팅',
#   '주차',
#   '팁',
#   '플로',
#   '트',
#   '추천',
#   '메뉴',
#   '더',
#   '현대',
#   '서울',
#   '블루',
#   '보틀',
#   '여의도',
#   '카페',
#   '글',
#   '사진',
#   '쥬',
#   '제이',
#   '맘',
#   '날',
#   '비',
#   '날',
#   '날',
#   '날씨',
#   '라떼',
#   '지금',
#   '여름',
#   '아이스커피',
#   '블루',
#   '보틀',
#   '추천',
#   '메뉴',
#   '로',
#   '플루토',
#   '인기'],
#  ['상암동',
#   '맛집',
#   '날',
#   '곰탕',
#   '때',
#   '골',
#   '나주',
#   '곰탕',
#   '곰탕',
#   '상암동',
#   '골',
#   '나주',
#   '곰탕',
#   '상암',
#   '점',
#   '겨울',
#   '날',
#   '국물',
#   '어서',
#   '날',
#   '국물',
#   '돌솥밥',
#   '까지',
#   '수',
#   '곳',
#   '건강',
#   '챙',
#   '기고',
#   '식사'],
#  ['날',
#   '생각',
#   '음식',
#   '조',
#   '마루',
#   '감자탕',
#   '상동역',
#   '점',
#   '회식',
#   '장소',
#   '추천',
#   '지극',
#   '개',
#   '인적',
#   '리얼',
#   '후기',
#   '요즘',
#   '날',
#   '생각',
#   '음식',
#   '짐',
#   '양',
#   '김치',
#   '고',
#   '나위',
#   '맛',
#   '상동역',
#   '맛집',
#   '인정',
#   '외식',
#   '모임',
#   '회식',
#   '장소',
#   '추천',
#   '몸',
#   '보신',
#   '조',
#   '마루',
#   '감자탕',
#   '노리',
#   '터'],
#  ['날',
#   '만두국',
#   '일산',
#   '평양',
#   '손',
#   '만두',
#   '그것',
#   '순서대로',
#   '것',
#   '고',
#   '막',
#   '번',
#   '번',
#   '날',
#   '씨',
#   '유명',
#   '맛',
#   '집들이',
#   '그',
#   '러하',
#   '듯이',
#   '여러',
#   '가지',
#   '메뉴',
#   '그냥',
#   '만두국',
#   '맛',
#   '맛',
#   '중',
#   '주',
#   '인',
#   '모션',
#   '렌터카',
#   '보험사',
#   '고대',
#   '차',
#   '전문',
#   '기업'],
#  ['서울',
#   '하월곡동',
#   '맛집',
#   '날',
#   '밥',
#   '그릇',
#   '뚝딱',
#   '토요일',
#   '첫',
#   '해장',
#   '메뉴',
#   '인',
#   '부대찌개',
#   '성북구',
#   '주민',
#   '맛집',
#   '월곡역',
#   '번',
#   '출구',
#   '부대찌개',
#   '본점',
#   '추천',
#   '추천',
#   '내',
#   '한식',
#   '아해',
#   '건',
#   '이',
#   '집',
#   '서울',
#   '맛집',
#   '지나',
#   '온',
#   '나날',
#   '기록'],
#  ['마곡역',
#   '맛집',
#   '더왓',
#   '에버',
#   '날',
#   '서울',
#   '실내',
#   '데이트',
#   '더왓',
#   '에버',
#   '메뉴',
#   '음료',
#   '메뉴',
#   '런치',
#   '메뉴',
#   '디너',
#   '메뉴',
#   '고',
#   '와인',
#   '낮',
#   '브런치',
#   '식사',
#   '가능',
#   '저녁',
#   '때',
#   '또',
#   '오기',
#   '약속',
#   '맛집',
#   '카페',
#   '카페',
#   '추천',
#   '서울',
#   '실내',
#   '데이트',
#   '서울',
#   '데이트',
#   '앵두',
#   '로그'],
#  ['날',
#   '수제비',
#   '최고',
#   '점심',
#   '메뉴',
#   '로',
#   '추천',
#   '계속',
#   '국물',
#   '오늘',
#   '점심',
#   '사무실',
#   '수제비',
#   '점심',
#   '메뉴',
#   '로',
#   '추천',
#   '날',
#   '최고',
#   '듯',
#   '끼',
#   '이건',
#   '들깨',
#   '수제비',
#   '배달',
#   '민족',
#   '덕이',
#   '거기',
#   '고자',
#   '거',
#   '제일'],
#  ['날',
#   '용산',
#   '타파',
#   '코파',
#   '아직',
#   '때',
#   '친',
#   '구들',
#   '끼리',
#   '날',
#   '잡고',
#   '날',
#   '실컷',
#   '다가',
#   '마지막',
#   '안주',
#   '겸',
#   '요런',
#   '맛집',
#   '후기',
#   '보이',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '고',
#   '설명',
#   '취향',
#   '것',
#   '금천',
#   '연세',
#   '치과'],
#  ['추천',
#   '메뉴',
#   '날',
#   '역시',
#   '호빵',
#   '그',
#   '중',
#   '서도',
#   '추천',
#   '메뉴',
#   '친구',
#   '추천',
#   '호빵',
#   '요즘',
#   '핫',
#   '삼립',
#   '호빵',
#   '저',
#   '가격',
#   '주관',
#   '적',
#   '맛',
#   '귀',
#   '여운',
#   '호빵',
#   '적',
#   '나유',
#   '크림',
#   '치즈',
#   '카스',
#   '타드',
#   '스',
#   '위트',
#   '슈크림',
#   '계란후라이',
#   '비',
#   '주얼',
#   '으랏차',
#   '차',
#   '운',
#   '동하',
#   '뚜',
#   '레이',
#   '너'],
#  ['날',
#   '점심',
#   '메뉴',
#   '로',
#   '부대찌개',
#   '끼',
#   '해결',
#   '날',
#   '점심',
#   '메뉴',
#   '로',
#   '부대찌개',
#   '끼',
#   '해결',
#   '오늘',
#   '갑자기',
#   '어제',
#   '도나',
#   '아침',
#   '겨울',
#   '바로',
#   '포스팅',
#   '하니',
#   '벌써',
#   '두',
#   '시반',
#   '요',
#   '저녁',
#   '메뉴',
#   '로',
#   '부대찌개',
#   '추천',
#   '전',
#   '일',
#   '지안',
#   '안경',
#   '젠틀',
#   '몬스터',
#   '모스',
#   '콧',
#   '용인',
#   '공식',
#   '매장'],
#  ['점심',
#   '메뉴',
#   '추천',
#   '오늘',
#   '점심',
#   '날',
#   '뼈',
#   '귀',
#   '해장국',
#   '닷',
#   '내',
#   '워',
#   '너비',
#   '메뉴',
#   '어서',
#   '자주',
#   '날',
#   '국물',
#   '어가',
#   '행복',
#   '고요',
#   '우거지',
#   '고기',
#   '짐',
#   '하니',
#   '국물',
#   '까지',
#   '한사',
#   '발',
#   '드링킹',
#   '잠',
#   '솔솔',
#   '감성',
#   '드림',
#   '블로그'],
#  ['날',
#   '뜻',
#   '한사',
#   '케',
#   '한잔',
#   '사케',
#   '안주',
#   '추천',
#   '날',
#   '뜻',
#   '한사',
#   '케',
#   '한잔',
#   '사케',
#   '안주',
#   '추천',
#   '사케',
#   '안주',
#   '추천',
#   '날',
#   '마시기',
#   '사케',
#   '안주',
#   '겨울',
#   '날',
#   '정원',
#   '뜻',
#   '한사',
#   '케',
#   '잔',
#   '것',
#   '아하',
#   '오늘',
#   '더',
#   '청정',
#   '원',
#   '블로그'],
#  ['날',
#   '가장',
#   '애정',
#   '메뉴',
#   '남',
#   '다른',
#   '감자탕',
#   '잇님들',
#   '날',
#   '가장',
#   '아하',
#   '메뉴',
#   '뭔가',
#   '거의',
#   '모두',
#   '국물',
#   '국물',
#   '생각',
#   '듯',
#   '추천',
#   '고요',
#   '실제',
#   '가보',
#   '점심시간',
#   '사람',
#   '꽉',
#   '고요',
#   '저',
#   '제',
#   '친구',
#   '기본',
#   '감자탕',
#   '블리콩'],
#  ['대구',
#   '수성구',
#   '조조',
#   '칼국수',
#   '날',
#   '추천',
#   '메뉴',
#   '시원',
#   '대구',
#   '수성구',
#   '조조',
#   '칼국수',
#   '날',
#   '추천',
#   '메뉴',
#   '시원',
#   '조개',
#   '칼국수',
#   '낙지',
#   '해물파전',
#   '고',
#   '물총',
#   '조개',
#   '겉절이',
#   '김치',
#   '그다지',
#   '맵',
#   '청양고추',
#   '된장',
#   '초장',
#   '간장',
#   '와사비',
#   '양념',
#   '간장',
#   '막걸리',
#   '메뉴판',
#   '오감',
#   '만족도',
#   '토미'],
#  ['날',
#   '집밥',
#   '추천',
#   '메뉴',
#   '간단',
#   '버섯',
#   '순두부찌개',
#   '만들기',
#   '오늘',
#   '날',
#   '생각',
#   '집밥',
#   '중',
#   '순두부찌개',
#   '어서',
#   '집',
#   '어요',
#   '집',
#   '아빠',
#   '오시',
#   '기',
#   '전',
#   '얼른',
#   '사진',
#   '엄마',
#   '아빠',
#   '저녁',
#   '식사',
#   '눈',
#   '녹지'],
#  ['날',
#   '추천',
#   '메뉴',
#   '사당',
#   '감자탕',
#   '김',
#   '채원',
#   '감자탕',
#   '회식',
#   '장소',
#   '추천',
#   '만',
#   '사당',
#   '감자탕',
#   '새마을',
#   '식당',
#   '자리',
#   '사당역',
#   '번',
#   '출구',
#   '식사',
#   '메뉴',
#   '로',
#   '뼈',
#   '해장국',
#   '김치찜',
#   '알밥',
#   '주문',
#   '해도',
#   '준비',
#   '주문',
#   '해도',
#   '명',
#   '이상',
#   '때',
#   '메인',
#   '여행',
#   '속',
#   '맛집',
#   '체험',
#   '곳'],
#  ['점심',
#   '메뉴',
#   '추천',
#   '날',
#   '소고기',
#   '국밥',
#   '점심',
#   '메뉴',
#   '추천',
#   '날',
#   '소고기',
#   '국밥',
#   '직장',
#   '동료',
#   '점심',
#   '메뉴',
#   '소고기',
#   '국밥',
#   '날',
#   '소고기',
#   '국밥',
#   '완전',
#   '강추',
#   '직장인',
#   '점심시간',
#   '점심',
#   '메뉴',
#   '로',
#   '음식'],
#  ['시지',
#   '맛집',
#   '심옥',
#   '날',
#   '갈비탕',
#   '추천',
#   '심옥',
#   '메뉴',
#   '가격',
#   '기본',
#   '찬',
#   '간',
#   '단합',
#   '석',
#   '박지',
#   '백김치',
#   '주시',
#   '데',
#   '삼삼',
#   '하니',
#   '항상',
#   '어른',
#   '모시',
#   '식',
#   '사하',
#   '기도',
#   '날',
#   '갈비탕',
#   '추천',
#   '다른',
#   '날',
#   '사진',
#   '의',
#   '양'],
#  ['점심',
#   '메뉴',
#   '로',
#   '뭐',
#   '날',
#   '점심',
#   '추천',
#   '메뉴',
#   '가지',
#   '음식',
#   '날',
#   '점심',
#   '추천',
#   '메뉴',
#   '가지',
#   '음식',
#   '어제',
#   '주말',
#   '창문',
#   '뒤',
#   '칼',
#   '바람',
#   '치',
#   '더니',
#   '오늘',
#   '아침',
#   '목덜미',
#   '릿',
#   '기온',
#   '가을',
#   '감',
#   '것',
#   '어제',
#   '룻',
#   '동안',
#   '외출',
#   '판다'],
#  ['전골',
#   '수육',
#   '추천',
#   '날',
#   '몸',
#   '보신',
#   '복날',
#   '음식',
#   '최고',
#   '주차장',
#   '정보',
#   '날',
#   '메뉴',
#   '선택',
#   '정말',
#   '탁월',
#   '염소',
#   '고기',
#   '어가',
#   '저',
#   '양념장',
#   '완전',
#   '비법',
#   '소스',
#   '감칠맛',
#   '뿜뿜',
#   '고기',
#   '능',
#   '그냥',
#   '어도',
#   '저',
#   '양념',
#   '소스',
#   '도',
#   '완전',
#   '찰떡',
#   '었다',
#   '나중',
#   '볶음밥'],
#  ['점심',
#   '메뉴',
#   '추천',
#   '날',
#   '점심',
#   '뭐',
#   '고민',
#   '너',
#   '정',
#   '점심',
#   '메뉴',
#   '추천',
#   '날',
#   '점심',
#   '뭐',
#   '고민',
#   '너',
#   '정',
#   '점심',
#   '뭐',
#   '다가',
#   '오늘',
#   '점심',
#   '메뉴',
#   '추천',
#   '동한',
#   '그릇',
#   '뭔가',
#   '국물',
#   '그릇',
#   '요즘',
#   '분식집',
#   '아주',
#   '좌충우돌',
#   '부산',
#   '행',
#   '블로그'],
#  ['날',
#   '저녁',
#   '메뉴',
#   '로',
#   '회',
#   '배달',
#   '어요',
#   '저녁',
#   '메뉴',
#   '로',
#   '회',
#   '배달',
#   '이야기',
#   '해',
#   '날',
#   '역시',
#   '회도',
#   '굴',
#   '꼬막',
#   '등',
#   '급',
#   '날',
#   '추천',
#   '상',
#   '차려',
#   '나름',
#   '집',
#   '한잔',
#   '오늘',
#   '비',
#   '까지',
#   '남매',
#   '일상'],
#  ['요즘',
#   '날',
#   '끈',
#   '라멘',
#   '부천',
#   '맛집',
#   '추천',
#   '코',
#   '라멘',
#   '메뉴',
#   '메뉴',
#   '간단',
#   '메인',
#   '메뉴',
#   '세',
#   '가지',
#   '오리',
#   '날',
#   '매',
#   '운라',
#   '고',
#   '차슈',
#   '덮밥',
#   '진짜진짜',
#   '추천',
#   '다음',
#   '또',
#   '가야',
#   '쥐',
#   '요즘',
#   '날',
#   '코',
#   '라멘',
#   '부천역',
#   '점',
#   '라멘',
#   '그릇',
#   '오늘',
#   '여행지',
#   '수'],
#  ['오늘',
#   '뭐',
#   '날',
#   '점심',
#   '메뉴',
#   '콩나물',
#   '동태찌개',
#   '추천',
#   '오늘',
#   '뭐',
#   '날',
#   '점심',
#   '메뉴',
#   '로',
#   '몸속',
#   '까지',
#   '콩나물',
#   '동태찌개',
#   '추천',
#   '오늘',
#   '처럼',
#   '찬',
#   '바람',
#   '날',
#   '점심',
#   '메뉴',
#   '를',
#   '것',
#   '고민',
#   '밖',
#   '점심',
#   '것',
#   '또한',
#   '직장인',
#   '만만',
#   '치',
#   '울랄라',
#   '일상',
#   '리뷰'],
#  ['날',
#   '생각',
#   '음식',
#   '메뉴',
#   '추천',
#   '해',
#   '날',
#   '생각',
#   '음식',
#   '메뉴',
#   '추천',
#   '해',
#   '안녕',
#   '날씨',
#   '그',
#   '래서',
#   '준비',
#   '날',
#   '날',
#   '짬뽕',
#   '국물',
#   '만큼',
#   '것',
#   '것',
#   '향',
#   '어회',
#   '계절',
#   '수',
#   '향',
#   '어회',
#   '빵빵',
#   '이의',
#   '하루'],
#  ['날',
#   '겨울',
#   '먹거리',
#   '겨울',
#   '부산',
#   '음식점',
#   '추천',
#   '메뉴',
#   '중',
#   '하나',
#   '요',
#   '곱',
#   '도리',
#   '탕',
#   '역시',
#   '국물',
#   '때문',
#   '날',
#   '일',
#   '수록',
#   '더',
#   '생각',
#   '식사',
#   '메뉴',
#   '톡톡',
#   '터',
#   '식감',
#   '알밥',
#   '추천',
#   '옛날',
#   '도시락',
#   '통',
#   '고소',
#   '홍',
#   '다이어리'],
#  ['날',
#   '호호',
#   '불어',
#   '야채',
#   '우동',
#   '만들기',
#   '날',
#   '호호',
#   '불어',
#   '야채',
#   '우동',
#   '법',
#   '날씨',
#   '요즘',
#   '요',
#   '추위',
#   '오들오들',
#   '우동',
#   '법',
#   '그릇',
#   '요리',
#   '요리',
#   '간단',
#   '한요',
#   '리',
#   '우동',
#   '요리',
#   '점심',
#   '메뉴',
#   '추천',
#   '저녁',
#   '메뉴',
#   '추천',
#   '메뉴'],
#  ['저녁',
#   '메뉴',
#   '추천',
#   '불고기',
#   '버섯전골',
#   '날',
#   '최고',
#   '저녁',
#   '메뉴',
#   '추천',
#   '불고기',
#   '버섯전골',
#   '날',
#   '최고',
#   '안녕',
#   '파워',
#   '안시',
#   '혁팀',
#   '최근',
#   '날씨',
#   '겨울',
#   '날씨',
#   '엄',
#   '청',
#   '오늘',
#   '날씨',
#   '오늘',
#   '어제',
#   '저녁',
#   '뭔가',
#   '김팀',
#   '차량',
#   '이야기'],
#  ['나긍',
#   '명동',
#   '맛집',
#   '명동',
#   '점심',
#   '메뉴',
#   '로',
#   '안동찜닭',
#   '날',
#   '나긍',
#   '명동',
#   '맛집',
#   '명동',
#   '점심',
#   '메뉴',
#   '로',
#   '안동찜닭',
#   '날',
#   '찜닭',
#   '먹고왓슈',
#   '안녕',
#   '나긍입니',
#   '명동',
#   '안동찜닭',
#   '저녁',
#   '왓',
#   '용',
#   '왜',
#   '점심',
#   '메뉴',
#   '추천',
#   '점심때',
#   '가격',
#   '저렴',
#   '누룽지',
#   '나긍쓰',
#   '블로그'],
#  ['까치산',
#   '술집',
#   '울랄라',
#   '포차',
#   '꼬막',
#   '추천',
#   '날',
#   '간단',
#   '메뉴',
#   '대체',
#   '걸',
#   '선택',
#   '고민',
#   '순간',
#   '꼬막',
#   '눈',
#   '확',
#   '어요',
#   '까치산',
#   '술집',
#   '울랄라',
#   '포차',
#   '의',
#   '꼬막',
#   '추천',
#   '날',
#   '더욱',
#   '것',
#   '꼬막',
#   '껍데기',
#   '억수',
#   '르돈되',
#   '부동산'],
#  ['살',
#   '국물',
#   '날',
#   '점심',
#   '추천',
#   '메뉴',
#   '벌교읍',
#   '조기',
#   '매운탕',
#   '살',
#   '국물',
#   '날',
#   '점심',
#   '추천',
#   '메뉴',
#   '날씨',
#   '갑자기',
#   '춥다',
#   '집',
#   '수도',
#   '때',
#   '몸',
#   '음식',
#   '보양',
#   '해주',
#   '벌교',
#   '맛집',
#   '아가',
#   '여정'],
#  ['천안',
#   '신부동',
#   '맛집',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '요즘',
#   '처럼',
#   '날',
#   '천안',
#   '맛집',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '메뉴',
#   '판',
#   '인',
#   '이상',
#   '실',
#   '경우',
#   '대표',
#   '메뉴',
#   '인',
#   '버섯',
#   '칼국수',
#   '것',
#   '천안',
#   '맛집',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '꼭',
#   '한번',
#   '방문',
#   '보시',
#   '길',
#   '추천',
#   '드립',
#   '날',
#   '감기',
#   '독감',
#   '몸살',
#   '부',
#   '천지인',
#   '한의원',
#   '정성'],
#  ['당감동',
#   '맛집',
#   '수백',
#   '당',
#   '날',
#   '곱새',
#   '전골',
#   '호로',
#   '록',
#   '간단',
#   '혼밥',
#   '분도',
#   '계',
#   '시더',
#   '포장',
#   '가능',
#   '작',
#   '늑한',
#   '매장',
#   '메뉴',
#   '강력',
#   '추천',
#   '당감동',
#   '맛집',
#   '날',
#   '전골',
#   '배부',
#   '르',
#   '자알',
#   '가오',
#   '겨울',
#   '수백',
#   '당하',
#   '살림',
#   '육',
#   '아하',
#   '둥이'],
#  ['광주',
#   '맛집',
#   '날',
#   '은',
#   '샤브샤브',
#   '맛집',
#   '유유',
#   '샤브',
#   '동천',
#   '점',
#   '추천',
#   '유난',
#   '이번',
#   '겨울',
#   '유',
#   '니스',
#   '메뉴',
#   '바로',
#   '바로',
#   '샤브샤브',
#   '개',
#   '인적',
#   '저',
#   '날',
#   '샤브샤브',
#   '친절',
#   '더',
#   '유유',
#   '샤브',
#   '동천',
#   '점',
#   '왕',
#   '추천',
#   '근처'],
#  ['시장',
#   '맛집',
#   '장호',
#   '덕',
#   '손',
#   '만두',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '맛집',
#   '추천',
#   '날',
#   '가장',
#   '음식',
#   '중',
#   '게',
#   '생각',
#   '나시',
#   '요',
#   '저',
#   '호빵',
#   '붕어빵',
#   '만두',
#   '종류',
#   '가장',
#   '먼저',
#   '국물',
#   '이따',
#   '생각',
#   '일단',
#   '면서',
#   '가성',
#   '비',
#   '메뉴',
#   '란',
#   '멘션'],
#  ['가경동',
#   '날',
#   '점심',
#   '메뉴',
#   '뼈',
#   '해장국',
#   '여기',
#   '양',
#   '느낌',
#   '고',
#   '고기',
#   '툼',
#   '날',
#   '점심',
#   '메뉴',
#   '로',
#   '가경동',
#   '뼈',
#   '해장국',
#   '점심',
#   '메뉴',
#   '고민',
#   '중이',
#   '면',
#   '해장',
#   '필',
#   '요하',
#   '면',
#   '한번',
#   '쯤',
#   '가보',
#   '길',
#   '추천',
#   '해'],
#  ['용봉동',
#   '맛집',
#   '날',
#   '생각',
#   '착',
#   '한해',
#   '물',
#   '우리',
#   '주문',
#   '메뉴',
#   '세',
#   '사람',
#   '해물전골',
#   '중',
#   '인',
#   '주문',
#   '해물',
#   '진심',
#   '날',
#   '포장마차',
#   '분위기',
#   '물씬',
#   '풍기',
#   '해물',
#   '추천',
#   '드레스',
#   '집',
#   '화',
#   '웨딩'],
#  ['고속',
#   '터미널',
#   '점',
#   '굴국밥',
#   '생',
#   '굴국밥',
#   '날',
#   '추천',
#   '메뉴',
#   '메뉴',
#   '판',
#   '여',
#   '기오',
#   '그냥',
#   '굴국밥',
#   '이나',
#   '생',
#   '굴굴밥',
#   '굴국밥',
#   '생',
#   '굴국밥',
#   '진짜',
#   '사람',
#   '항상',
#   '것',
#   '굴국밥',
#   '생',
#   '굴국밥',
#   '주',
#   '문하',
#   '금방',
#   '굴',
#   '해',
#   '맑은'],
#  ['화성',
#   '봉담',
#   '맛집',
#   '추천',
#   '연남',
#   '물',
#   '갈비',
#   '날',
#   '국물',
#   '날',
#   '제',
#   '픽',
#   '곳',
#   '연남',
#   '물',
#   '갈비',
#   '운영',
#   '시간',
#   '일요일',
#   '정기',
#   '휴무',
#   '주차',
#   '가능',
#   '산',
#   '산이',
#   '물',
#   '물이',
#   '고기',
#   '산더미',
#   '연남',
#   '물',
#   '갈비',
#   '찰떡',
#   '비유',
#   '유명',
#   '메뉴',
#   '욘',
#   '집사',
#   '리아',
#   '리'],
#  ['부산',
#   '사상',
#   '맛집',
#   '추천',
#   '오늘',
#   '날',
#   '최뼈',
#   '구',
#   '해장국',
#   '오늘',
#   '날',
#   '은',
#   '생각',
#   '이나',
#   '음식',
#   '국물',
#   '음식',
#   '오늘',
#   '점심',
#   '메뉴',
#   '추천',
#   '부산',
#   '사상',
#   '최뼈',
#   '구',
#   '해장국',
#   '집',
#   '소개',
#   '드릴',
#   '려고',
#   '해',
#   '위',
#   '세팅',
#   '기본',
#   '세팅',
#   '이구',
#   '근접',
#   '사진',
#   '밀',
#   '리언',
#   '모찌',
#   '경제',
#   '이야기'],
#  ['의정부',
#   '맛집',
#   '의정부',
#   '교동',
#   '짬뽕',
#   '의정부',
#   '점심',
#   '메뉴',
#   '추천',
#   '날',
#   '아이',
#   '날',
#   '짬뽕',
#   '생각',
#   '네',
#   '짬뽕',
#   '출처',
#   '네이버',
#   '거리',
#   '뷰',
#   '의정부',
#   '교동',
#   '짬뽕',
#   '의정부',
#   '점심',
#   '추천',
#   '의정부',
#   '짬뽕',
#   '집',
#   '의정부',
#   '교동',
#   '짬뽕',
#   '교동',
#   '짬뽕',
#   '짜장밥',
#   '의정부',
#   '백년',
#   '교동',
#   '짬뽕',
#   '교동',
#   '짬뽕',
#   '메뉴',
#   '드림',
#   '나',
#   '행복'],
#  ['날',
#   '점심',
#   '추천',
#   '메뉴',
#   '카레돈까스',
#   '나베',
#   '면',
#   '연어',
#   '초밥',
#   '핑거',
#   '돈까스',
#   '튀김',
#   '류',
#   '등등',
#   '아주',
#   '다양',
#   '맛',
#   '즐',
#   '수',
#   '어요',
#   '오늘',
#   '하루',
#   '마무리',
#   '모두',
#   '건강',
#   '병점',
#   '맛집',
#   '병점',
#   '멘스',
#   '애부',
#   '멘스',
#   '애부',
#   '카레돈까스',
#   '나베',
#   '병점',
#   '맛집',
#   '추천',
#   '웰',
#   '포스',
#   '처'],
#  ['날',
#   '메뉴',
#   '강추',
#   '북한',
#   '산',
#   '온천',
#   '칼국수',
#   '삼송',
#   '은희',
#   '해장국',
#   '겨울',
#   '날',
#   '은',
#   '지축',
#   '까운',
#   '온천',
#   '칼국수',
#   '삼송',
#   '까운',
#   '제주',
#   '은희',
#   '해장국',
#   '점심',
#   '저녁',
#   '한번',
#   '이조',
#   '합',
#   '추천',
#   '닼',
#   '쿄쿄',
#   '온천',
#   '옆',
#   '벽돌',
#   '집',
#   '안쪽',
#   '쑥',
#   '온천',
#   '쪽',
#   '나',
#   '안',
#   '물',
#   '안',
#   '궁',
#   '노트'],
#  ['레드',
#   '버튼',
#   '노원',
#   '놀',
#   '거리',
#   '날',
#   '실내',
#   '데이트',
#   '추천',
#   '노원역',
#   '보드게임',
#   '카페',
#   '레드',
#   '버튼',
#   '노원',
#   '놀',
#   '거리',
#   '날',
#   '실내',
#   '데이트',
#   '추천',
#   '인',
#   '보드게임',
#   '추천',
#   '쥐',
#   '메뉴',
#   '판',
#   '추천',
#   '메뉴',
#   '보드게임',
#   '식',
#   '후경',
#   '카운터',
#   '것',
#   '것',
#   '말',
#   '필요',
#   '개별',
#   '룸',
#   '마다'],
#  ['송리단길',
#   '날',
#   '베트남',
#   '쌀국수',
#   '맛집',
#   '추천',
#   '메뉴',
#   '결정',
#   '어려움',
#   '편이',
#   '오늘',
#   '또',
#   '가야',
#   '하나',
#   '고민',
#   '역시',
#   '날',
#   '쌀국수',
#   '출하',
#   '때',
#   '잠실',
#   '추천',
#   '오늘',
#   '후기',
#   '게',
#   '일상'],
#  ['갈산동',
#   '날',
#   '추천',
#   '불고기전골',
#   '맛집',
#   '불고기',
#   '회관',
#   '선',
#   '선하',
#   '거나',
#   '날',
#   '추천',
#   '불고기',
#   '전골',
#   '어요',
#   '고기',
#   '오랫동안',
#   '보관',
#   '식',
#   '쫄깃했',
#   '야채',
#   '양하',
#   '어요',
#   '직화',
#   '제육볶음',
#   '고기',
#   '메뉴',
#   '연킴',
#   '일상',
#   '맛집',
#   '기록'],
#  ['날',
#   '날',
#   '도',
#   '살얼음',
#   '동동',
#   '메밀국수',
#   '성수동',
#   '소바',
#   '식당',
#   '추천',
#   '메뉴',
#   '전복',
#   '단',
#   '새우',
#   '냉소',
#   '바',
#   '연어',
#   '덮밥',
#   '타',
#   '마고',
#   '멘치',
#   '카츠',
#   '개',
#   '인적',
#   '성수동',
#   '좀',
#   '매장',
#   '언제',
#   '가도',
#   '편안',
#   '분위기',
#   '늘',
#   '웨이',
#   '팅',
#   '어요',
#   '테이블',
#   '간',
#   '간격',
#   '접객',
#   '해주시',
#   '판',
#   '기획',
#   '자의',
#   '세상'],
#  ['학',
#   '정동',
#   '날',
#   '국물',
#   '때',
#   '샤브샤브',
#   '맛집',
#   '추천',
#   '날',
#   '진짜',
#   '샤브샤브',
#   '온몸',
#   '풀',
#   '리더',
#   '날',
#   '게',
#   '외식',
#   '추천',
#   '저녁',
#   '메뉴',
#   '추천',
#   '만두전골',
#   '칠곡',
#   '맛집',
#   '겨울',
#   '메뉴',
#   '추천',
#   '다이어트',
#   '샐러드',
#   '월남쌈',
#   '쌀국수',
#   '칼국수',
#   '영',
#   '발자국',
#   '이야기'],
#  ['날',
#   '점심',
#   '울산',
#   '곰탕',
#   '맛집',
#   '정담',
#   '곰탕',
#   '어요',
#   '정성',
#   '곰탕',
#   '호계동',
#   '곰탕',
#   '집',
#   '정담',
#   '곰탕',
#   '오늘',
#   '진짜',
#   '날',
#   '어요',
#   '오',
#   '토요일',
#   '오후',
#   '추위',
#   '기대',
#   '메뉴',
#   '판',
#   '서치',
#   '진',
#   '곰탕',
#   '맑은',
#   '곰탕',
#   '크게',
#   '두',
#   '가지',
#   '타입',
#   '초이스',
#   '수',
#   '어요',
#   '말',
#   '아내'],
#  ['맛집',
#   '또',
#   '집',
#   '떡',
#   '도리',
#   '탕',
#   '강남',
#   '점',
#   '날',
#   '줄',
#   '식당',
#   '탐방',
#   '추천',
#   '강남역',
#   '맛집',
#   '또',
#   '집',
#   '떡',
#   '도리',
#   '탕',
#   '날',
#   '줄',
#   '식당',
#   '탐방',
#   '추천',
#   '요즘',
#   '핫',
#   '강남역',
#   '맛집',
#   '또',
#   '집',
#   '이',
#   '내',
#   '당신',
#   '번호',
#   '수',
#   '습',
#   '이',
#   '치킨',
#   '도리',
#   '탕',
#   '명소',
#   '메인',
#   '메뉴',
#   '유명',
#   '치킨',
#   '도리',
#   '탕',
#   '요리',
#   '인터스텔라'],
#  ['노원역',
#   '맛집',
#   '날',
#   '후기',
#   '자매',
#   '추천',
#   '농',
#   '차례',
#   '습',
#   '닷',
#   '오랜만',
#   '자매',
#   '소개',
#   '드릴',
#   '맛집',
#   '요새',
#   '처럼',
#   '날',
#   '메인',
#   '메뉴',
#   '다양',
#   '찌개',
#   '종류',
#   '생선',
#   '탕',
#   '이나',
#   '닭볶음탕',
#   '오삼',
#   '불고기',
#   '등',
#   '추가',
#   '메뉴',
#   '로',
#   '상계',
#   '별내',
#   '당고',
#   '개',
#   '네일',
#   '샵',
#   '나나',
#   '양',
#   '네일'],
#  ['포장',
#   '메뉴',
#   '추천',
#   '역전',
#   '우동',
#   '날',
#   '우동',
#   '국물',
#   '최고',
#   '적',
#   '겨울',
#   '날',
#   '엄마',
#   '포장마차',
#   '우동',
#   '기억',
#   '어서',
#   '갑자기',
#   '추억',
#   '역전',
#   '우동',
#   '역전',
#   '우동',
#   '역전',
#   '우동',
#   '메뉴',
#   '추천',
#   '역전',
#   '우동',
#   '메뉴',
#   '매콤',
#   '치킨',
#   '마',
#   '덮밥',
#   '옛날',
#   '우동',
#   '찌'],
#  ['메뉴',
#   '추천',
#   '날',
#   '더',
#   '메뉴',
#   '요즘',
#   '날',
#   '더',
#   '메뉴',
#   '를',
#   '준비',
#   '어요',
#   '날',
#   '더',
#   '메뉴',
#   '첫',
#   '찹쌀',
#   '수제비',
#   '찹쌀',
#   '수제비',
#   '쫀득쫀득',
#   '생각',
#   '이나',
#   '건강',
#   '음식',
#   '밥',
#   '국물',
#   '파머',
#   '스티'],
#  ['점심',
#   '메뉴',
#   '추천',
#   '날',
#   '갈비탕',
#   '아무',
#   '도',
#   '저',
#   '겨울',
#   '날',
#   '이면',
#   '국물',
#   '음식',
#   '자주',
#   '갈비탕',
#   '점심',
#   '메뉴',
#   '추천',
#   '이해',
#   '해주',
#   '오늘',
#   '처럼',
#   '날',
#   '은',
#   '국물',
#   '밥',
#   '숟가락',
#   '몸',
#   '따땃',
#   '해지',
#   '행복',
#   '공잉',
#   '일상',
#   '이야기'],
#  ['경기도',
#   '광주',
#   '배재',
#   '맛집',
#   '날',
#   '명물',
#   '옹심이',
#   '메밀',
#   '칼국수',
#   '추천',
#   '오늘',
#   '영하',
#   '도',
#   '날',
#   '데',
#   '외출',
#   '국물',
#   '부모님',
#   '우리',
#   '아기',
#   '식사',
#   '메뉴',
#   '감자',
#   '옹심이',
#   '메밀',
#   '칼국수',
#   '감자',
#   '만두',
#   '메인',
#   '듯',
#   '가게',
#   '내부',
#   '하진',
#   '오래',
#   '맛집',
#   '용이',
#   '님',
#   '블로그'],
#  ['날',
#   '국물',
#   '개성',
#   '토종',
#   '상황버섯',
#   '삼계탕',
#   '재',
#   '방문',
#   '안성',
#   '맛집',
#   '개성',
#   '토종',
#   '상황버섯',
#   '삼계탕',
#   '메뉴',
#   '가격',
#   '참고',
#   '날',
#   '국물',
#   '개성',
#   '토종',
#   '상황버섯',
#   '삼계탕',
#   '재',
#   '방문',
#   '안성',
#   '맛집',
#   '국물',
#   '추천',
#   '몸'],
#  ['날',
#   '포',
#   '메인',
#   '포',
#   '메인',
#   '직원',
#   '추천',
#   '메뉴',
#   '쌀국수',
#   '어서',
#   '포',
#   '메인',
#   '바',
#   '매장',
#   '사진',
#   '메뉴',
#   '판도',
#   '어서',
#   '그',
#   '만큼',
#   '맛',
#   '세',
#   '가지',
#   '추천',
#   '날',
#   '감기',
#   '조심',
#   '유니'],
#  ['날',
#   '실내',
#   '데이트',
#   '추천',
#   '인천',
#   '초대형',
#   '베이커리',
#   '식물원',
#   '카페',
#   '다양',
#   '음료',
#   '커피',
#   '베이커리',
#   '푸드',
#   '등',
#   '메뉴',
#   '곳',
#   '이구',
#   '가격',
#   '편이',
#   '맛',
#   '날',
#   '곳',
#   '푸릇푸릇',
#   '식물',
#   '가득',
#   '포레스트',
#   '아웃팅',
#   '스',
#   '송도',
#   '점',
#   '추천',
#   '돈',
#   '산',
#   '케이',
#   '공감',
#   '디자인'],
#  ['연산역',
#   '점심',
#   '추천',
#   '마라탕',
#   '날',
#   '감',
#   '화끈',
#   '연산역',
#   '인근',
#   '점심',
#   '메뉴',
#   '추천',
#   '날',
#   '마라탕',
#   '감',
#   '화끈',
#   '아침',
#   '날씨',
#   '정말',
#   '역시',
#   '겨울',
#   '국물',
#   '화끈',
#   '분명',
#   '춥다',
#   '웅',
#   '크리',
#   '땀',
#   '님',
#   '블로그'],
#  ['점심식사',
#   '저녁',
#   '메뉴',
#   '추천',
#   '날',
#   '음식',
#   '나니',
#   '로움',
#   '식물',
#   '화분',
#   '덕',
#   '느낌',
#   '더',
#   '아지',
#   '요',
#   '메뉴',
#   '판',
#   '순대국',
#   '주문',
#   '후',
#   '기',
#   '다리',
#   '시간',
#   '기본',
#   '반찬',
#   '여기',
#   '셋팅',
#   '해주',
#   '실',
#   '때',
#   '간',
#   '주네',
#   '뚜기',
#   '맛',
#   '조금',
#   '김치',
#   '어요',
#   '서울',
#   '경기도',
#   '나니',
#   '로움',
#   '음속',
#   '행복찾기'],
#  ['돈',
#   '산',
#   '밀키',
#   '트',
#   '추천',
#   '날',
#   '음식',
#   '자취',
#   '생',
#   '우동',
#   '밀키',
#   '트',
#   '재료',
#   '날',
#   '먹기',
#   '게',
#   '조리법',
#   '진짜',
#   '간단',
#   '냉면',
#   '것',
#   '간단',
#   '메뉴',
#   '로',
#   '아주',
#   '적합',
#   '하하',
#   '겨울',
#   '몇',
#   '번',
#   '더',
#   '사',
#   '거',
#   '반',
#   '전제',
#   '풀무원',
#   '오우',
#   '추천',
#   '주주',
#   '살롱'],
#  ['맛집',
#   '탐방',
#   '버섯',
#   '집',
#   '날',
#   '맛집',
#   '추천',
#   '성수',
#   '서울숲',
#   '뚝섬',
#   '메뉴',
#   '매장',
#   '주문',
#   '메뉴',
#   '를',
#   '선택',
#   '후',
#   '메뉴',
#   '인원',
#   '수',
#   '메뉴',
#   '체크',
#   '후',
#   '확인',
#   '예약',
#   '겨울',
#   '날',
#   '국물',
#   '생각',
#   '날',
#   '때',
#   '다시',
#   '한번',
#   '볼',
#   '맛집',
#   '것',
#   '버섯',
#   '아하',
#   '시',
#   '소',
#   '소한',
#   '일상',
#   '기록',
#   '공간'],
#  ['날',
#   '국물',
#   '땀',
#   '뻘뻘',
#   '몸',
#   '보신',
#   '하자',
#   '명송생복집',
#   '겨울철',
#   '꼭',
#   '국물',
#   '날',
#   '국물',
#   '배',
#   '복',
#   '도감',
#   '잠시',
#   '후',
#   '메뉴',
#   '판',
#   '살피',
#   '주',
#   '인분',
#   '추천',
#   '메뉴',
#   '를',
#   '뒤',
#   '활',
#   '복',
#   '지리탕',
#   '광주',
#   '문화',
#   '관광',
#   '공식',
#   '블로그'],
#  ['날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '짬뽕밥',
#   '신가',
#   '땀',
#   '좀',
#   '날',
#   '정도',
#   '매콤',
#   '어요',
#   '때',
#   '일',
#   '에너지',
#   '소모',
#   '으슬으슬',
#   '때',
#   '부',
#   '찍',
#   '개취',
#   '논란',
#   '날',
#   '데',
#   '저녁',
#   '메뉴',
#   '짬뽕밥',
#   '추천',
#   '뭐',
#   '뭐'],
#  ['날',
#   '생각',
#   '동탄',
#   '쌀국수',
#   '끈',
#   '끈',
#   '전골',
#   '베트남',
#   '쌀국수',
#   '디너',
#   '메뉴',
#   '로만',
#   '가능',
#   '듯',
#   '야외',
#   '테라스',
#   '직접',
#   '바베큐',
#   '주어',
#   '캠핑',
#   '느낌',
#   '리얼',
#   '숯불',
#   '바베큐',
#   '수',
#   '쌀국수',
#   '바베큐',
#   '즐',
#   '기고',
#   '저녁',
#   '방문',
#   '추천',
#   '숯불',
#   '바베큐',
#   '노노',
#   '패밀리'],
#  ['대구',
#   '남산동',
#   '밥집',
#   '날',
#   '더',
#   '생각',
#   '다양',
#   '메뉴',
#   '의',
#   '제일',
#   '콩국',
#   '간단',
#   '메뉴',
#   '선택',
#   '장애인',
#   '나',
#   '간략',
#   '메뉴',
#   '를',
#   '거지',
#   '수',
#   '음식',
#   '생각',
#   '뜻',
#   '달달',
#   '콩국',
#   '추천',
#   '드립',
#   '돈',
#   '산',
#   '후기',
#   '끝'],
#  ['날',
#   '더',
#   '생각',
#   '칼국수',
#   '직장인',
#   '겨울',
#   '점심',
#   '메뉴',
#   '추천',
#   '이모',
#   '님',
#   '추천',
#   '걸',
#   '어간',
#   '그',
#   '바지락',
#   '칼국수',
#   '엄마',
#   '해주시',
#   '맛',
#   '조미료',
#   '개운',
#   '더',
#   '날',
#   '겨울',
#   '점심',
#   '메뉴',
#   '로',
#   '칼국수',
#   '완전',
#   '강력',
#   '추천',
#   '해',
#   '미싱',
#   '유',
#   '잡',
#   '아야',
#   '블로그'],
#  ['날',
#   '점심',
#   '메뉴',
#   '추천',
#   '부대찌개',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '부대찌개',
#   '한파',
#   '주의보',
#   '더니',
#   '심지어',
#   '상상',
#   '온라인',
#   '울면',
#   '출근',
#   '상상',
#   '인도',
#   '어요',
#   '찬',
#   '바람',
#   '눈물',
#   '줄줄',
#   '아시',
#   '상상',
#   '그대로'],
#  ['날',
#   '돼지고기',
#   '국밥',
#   '순대',
#   '만두국',
#   '아침',
#   '메뉴',
#   '추천',
#   '날',
#   '귀',
#   '갓길',
#   '포장',
#   '담',
#   '아주',
#   '순대',
#   '국밥집',
#   '집',
#   '거',
#   '밥',
#   '필요',
#   '순대국',
#   '순대국',
#   '밥',
#   '순대',
#   '만두국',
#   '국밥',
#   '만두국',
#   '만두',
#   '요리',
#   '그릇',
#   '요리',
#   '겨울',
#   '메뉴',
#   '점심',
#   '메뉴',
#   '저녁',
#   '추천',
#   '메뉴',
#   '샤이니',
#   '인생',
#   '아름',
#   '워'],
#  ['식당',
#   '맛',
#   '오뚜기',
#   '팥',
#   '칼국수',
#   '날',
#   '꿀맛',
#   '메뉴',
#   '날',
#   '온기',
#   '필요',
#   '날',
#   '주방',
#   '메뉴',
#   '오늘',
#   '그',
#   '오뚜기',
#   '팥',
#   '칼국수',
#   '오뚜기',
#   '라면',
#   '칼국수',
#   '라면',
#   '날',
#   '추천',
#   '음식',
#   '칼국수',
#   '칼국수',
#   '맛집',
#   '라이',
#   '트리',
#   '기억',
#   '저장',
#   '소'],
#  ['진',
#   '짬뽕',
#   '초',
#   '간단',
#   '부대찌개',
#   '만들기',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '진',
#   '짬뽕',
#   '초',
#   '간단',
#   '부대찌개',
#   '만들기',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '이웃',
#   '님들',
#   '안녕',
#   '식',
#   '오늘',
#   '정말',
#   '오랜만',
#   '요리',
#   '로그',
#   '캬캬캬',
#   '요새',
#   '집',
#   '순이',
#   '요리'],
#  ['지금껏',
#   '죽',
#   '비빔밥',
#   '카페',
#   '메뉴',
#   '추천',
#   '겨울',
#   '날',
#   '비빔밥',
#   '건강',
#   '나물',
#   '고소',
#   '밥',
#   '생각',
#   '때',
#   '전통',
#   '상',
#   '달달',
#   '단호박',
#   '죽',
#   '날',
#   '추천',
#   '단',
#   '팥죽',
#   '팥죽',
#   '생각',
#   '특별',
#   '날',
#   '추천',
#   '죽',
#   '비빔밥',
#   '메뉴',
#   '가격',
#   '죽',
#   '어린왕자',
#   '소행성'],
#  ['집밥',
#   '일기',
#   '주말',
#   '점심',
#   '날',
#   '호호',
#   '불어',
#   '바지락',
#   '홍합',
#   '숟가락',
#   '수',
#   '어요',
#   '반찬',
#   '이예',
#   '날',
#   '점심',
#   '칼국수',
#   '최고',
#   '해물칼국수',
#   '주말',
#   '점심',
#   '메뉴',
#   '점심',
#   '메뉴',
#   '추천',
#   '칼국수',
#   '만들기',
#   '날',
#   '메뉴',
#   '직장인',
#   '점심',
#   '바지락',
#   '칼국수',
#   '홍합',
#   '칼국수',
#   '현이',
#   '집밥',
#   '도시락'],
#  ['여의도',
#   '점심',
#   '맛집',
#   '가양',
#   '칼국수',
#   '버섯',
#   '매운탕',
#   '날',
#   '생각',
#   '메뉴',
#   '판',
#   '메뉴',
#   '가양',
#   '칼국수',
#   '버섯',
#   '매운탕',
#   '샤브',
#   '소고기',
#   '유료',
#   '판매',
#   '추가',
#   '버섯',
#   '채',
#   '여의도',
#   '끈',
#   '국물',
#   '맛집',
#   '배터',
#   '지게',
#   '집',
#   '날',
#   '집',
#   '돈',
#   '산',
#   '버섯',
#   '칼국수',
#   '먹기',
#   '몽시꿈',
#   '앙시',
#   '꿈',
#   '귤귤',
#   '이의',
#   '체험',
#   '삶',
#   '여행'],
#  ['달서구',
#   '날',
#   '북한',
#   '음식',
#   '어복',
#   '쟁반',
#   '맛집',
#   '형',
#   '면옥',
#   '홍시',
#   '디저트',
#   '그때',
#   '그때',
#   '달',
#   '라진',
#   '이번',
#   '홍시',
#   '디저트',
#   '날',
#   '어복',
#   '쟁반',
#   '아주',
#   '선택',
#   '었다',
#   '결론',
#   '맛',
#   '서비스',
#   '재',
#   '방문',
#   '의사',
#   '추천',
#   '메뉴',
#   '평양',
#   '냉면',
#   '초',
#   '탕',
#   '여름',
#   '어복',
#   '쟁반',
#   '귤',
#   '의',
#   '욤뇸',
#   '로그'],
#  ['국밥',
#   '맛집',
#   '김명자',
#   '굴국밥',
#   '잠실',
#   '점',
#   '솔직',
#   '후기',
#   '날',
#   '메뉴',
#   '추천',
#   '겨울',
#   '잠실',
#   '근처',
#   '국밥',
#   '맛집',
#   '계시',
#   '면',
#   '김명자',
#   '굴국밥',
#   '잠실',
#   '점',
#   '추천',
#   '잠실',
#   '맛집',
#   '잠실',
#   '밥집',
#   '잠실',
#   '국밥',
#   '맛집',
#   '굴국밥',
#   '맛집',
#   '잠실',
#   '굴국밥',
#   '김명자',
#   '굴국밥',
#   '반드시'],
#  ['날',
#   '꿀',
#   '조합',
#   '메뉴',
#   '추천',
#   '겨울',
#   '음료',
#   '샌드위치',
#   '날',
#   '꿀',
#   '조합',
#   '메뉴',
#   '추천',
#   '안녕',
#   '블로그',
#   '지기',
#   '거리',
#   '가득',
#   '낙엽',
#   '우수수',
#   '수',
#   '걸',
#   '때',
#   '마다',
#   '바스락',
#   '바스락',
#   '소리',
#   '나',
#   '요즘',
#   '요',
#   '함',
#   '몸서리',
#   '계시',
#   '분',
#   '선선',
#   '이',
#   '날씨',
#   '마저',
#   '샌드위치',
#   '공식',
#   '블로그'],
#  ['중식',
#   '대해',
#   '매우',
#   '솔직',
#   '한편',
#   '날',
#   '짬뽕',
#   '짜장',
#   '그릇',
#   '날',
#   '짬뽕',
#   '짜장',
#   '그릇',
#   '망리단',
#   '길이',
#   '망원동',
#   '여러',
#   '메뉴',
#   '음식',
#   '공존',
#   '중식',
#   '짬뽕',
#   '생각',
#   '날땐',
#   '여기',
#   '한번',
#   '꼭',
#   '한번',
#   '어보',
#   '길',
#   '추천',
#   '드립',
#   '닷',
#   '짬뽕',
#   '맛집',
#   '짜장면',
#   '맛집',
#   '블라인드',
#   '민영',
#   '버',
#   '티칼',
#   '공장',
#   '직영'],
#  ['안성',
#   '랜드',
#   '안',
#   '날',
#   '또',
#   '옴',
#   '레이싱카',
#   '전동',
#   '자전거',
#   '후기',
#   '날',
#   '안성',
#   '랜드',
#   '후기',
#   '주제',
#   '안성',
#   '랜드',
#   '푸드코트',
#   '메뉴',
#   '파서',
#   '사진',
#   '대충',
#   '메뉴',
#   '그때',
#   '그때',
#   '재료',
#   '사정',
#   '뫙뫙',
#   '이의',
#   '재미',
#   '찾기'],
#  ['날',
#   '우동',
#   '긴자',
#   '료코',
#   '마포구청역',
#   '점',
#   '메뉴',
#   '어서',
#   '고',
#   '민하',
#   '데',
#   '명란',
#   '동류',
#   '가신',
#   '고',
#   '돈가스',
#   '메뉴',
#   '메인',
#   '날',
#   '돈까스',
#   '우동',
#   '조합',
#   '강추',
#   '마포구청역',
#   '점심식사',
#   '도',
#   '추천',
#   '마포구청역',
#   '돈까스',
#   '그녕저'],
#  ['서면',
#   '추천',
#   '메뉴',
#   '날',
#   '유부',
#   '우동',
#   '서면',
#   '추천',
#   '메뉴',
#   '날',
#   '유부',
#   '우동',
#   '오늘',
#   '일요일',
#   '일찍',
#   '돈',
#   '아저씨',
#   '짱',
#   '연중',
#   '무',
#   '하루',
#   '왜',
#   '하필',
#   '왜',
#   '내',
#   '광고',
#   '임',
#   '어차피',
#   '돈',
#   '어서',
#   '계약',
#   '판타스틱'],
#  ['날',
#   '몸',
#   '보신',
#   '캠핑',
#   '요리',
#   '호반',
#   '로부터',
#   '닭곰탕',
#   '밀키',
#   '트',
#   '추천',
#   '입',
#   '속',
#   '부담',
#   '맛',
#   '철',
#   '수하',
#   '날',
#   '아침',
#   '메뉴',
#   '로',
#   '부모님',
#   '건강',
#   '식',
#   '것',
#   '건강',
#   '식',
#   '건강',
#   '밀키',
#   '트',
#   '건강',
#   '식',
#   '추천',
#   '부모님',
#   '밀키',
#   '트',
#   '국물',
#   '보이시',
#   '요',
#   '제대로',
#   '몸',
#   '보신',
#   '몸',
#   '로',
#   '세상',
#   '탐험',
#   '기'],
#  ['은평',
#   '옥',
#   '마을',
#   '카페',
#   '볼',
#   '날',
#   '밤',
#   '라떼',
#   '추천',
#   '사진',
#   '클릭',
#   '메뉴',
#   '판이',
#   '크게',
#   '은평구',
#   '도장',
#   '중이',
#   '기록',
#   '용',
#   '사진',
#   '오기',
#   '음료',
#   '추천',
#   '어요',
#   '때',
#   '밑',
#   '밤',
#   '어서',
#   '후루룩',
#   '다가',
#   '원샷',
#   '토야밍',
#   '달콤',
#   '살벌',
#   '여행',
#   '일지'],
#  ['충무로',
#   '맛집',
#   '손',
#   '칼국수',
#   '오늘',
#   '처럼',
#   '날',
#   '칼국수',
#   '메뉴',
#   '메뉴',
#   '단',
#   '두',
#   '가지',
#   '칼국수',
#   '칼',
#   '만두',
#   '만두',
#   '파시',
#   '판다',
#   '어요',
#   '만두',
#   '천원',
#   '었습니',
#   '조금',
#   '알',
#   '어요',
#   '겉절이',
#   '용',
#   '배추',
#   '요즘',
#   '날',
#   '바블',
#   '세상'],
#  ['날',
#   '옥',
#   '맑은',
#   '칼국수',
#   '추천',
#   '하필',
#   '년도',
#   '젤',
#   '날',
#   '첫',
#   '겨울',
#   '서핑',
#   '국물',
#   '속초',
#   '사진',
#   '똥꼬',
#   '발랄',
#   '감자전',
#   '추천',
#   '기전',
#   '팅',
#   '속초',
#   '금',
#   '옥',
#   '밑반찬',
#   '무난',
#   '무난',
#   '맛',
#   '초장',
#   '칼국수'],
#  ['포항',
#   '죽도동',
#   '맛집',
#   '죽도',
#   '왕생',
#   '굴',
#   '직화',
#   '구이',
#   '날',
#   '조개',
#   '전골',
#   '추천',
#   '가능',
#   '날',
#   '조개',
#   '전골',
#   '추천',
#   '조개구이',
#   '맛집',
#   '포항',
#   '죽도',
#   '왕생',
#   '굴',
#   '직화',
#   '구이',
#   '포항',
#   '오광',
#   '장',
#   '인근',
#   '전',
#   '메뉴',
#   '포장',
#   '배달',
#   '가능',
#   '전국',
#   '택배',
#   '굴',
#   '절기',
#   '어서',
#   '조개구이',
#   '조개',
#   '전골',
#   '대하',
#   '구이'],
#  ['날',
#   '국물',
#   '때',
#   '밀푀유',
#   '전골',
#   '밀푀유나베',
#   '추천',
#   '온몸',
#   '사이사이',
#   '강',
#   '추위',
#   '쏙쏙',
#   '오늘',
#   '날',
#   '저녁',
#   '메뉴',
#   '로',
#   '강',
#   '추인',
#   '밀푀유',
#   '전골',
#   '밀푀유나베',
#   '겨울',
#   '국물',
#   '생각',
#   '날',
#   '때',
#   '추천',
#   '오늘',
#   '저녁',
#   '자',
#   '알',
#   '오늘',
#   '저녁',
#   '저녁',
#   '추천',
#   '메뉴',
#   '소',
#   '소한',
#   '콩맘'],
#  ['추천',
#   '메뉴',
#   '날',
#   '떡만두국',
#   '이',
#   '코끝',
#   '날',
#   '위',
#   '시',
#   '그니',
#   '메뉴',
#   '를',
#   '소개',
#   '아마',
#   '오늘',
#   '분명',
#   '떡만두국',
#   '땡',
#   '푹',
#   '사골',
#   '국물',
#   '떡',
#   '만두',
#   '가득',
#   '분식점',
#   '퀄리티',
#   '전문',
#   '떡만두국',
#   '집',
#   '퀄리티',
#   '창업',
#   '프로파일러'],
#  ['다락방',
#   '날',
#   '데이트',
#   '부천역',
#   '만화방',
#   '힐링',
#   '느낌',
#   '회사',
#   '스트레스',
#   '풀',
#   '린다',
#   '사람과',
#   '더',
#   '시간',
#   '었',
#   '요즘',
#   '날',
#   '뜻',
#   '안락',
#   '데이트',
#   '분',
#   '부천역',
#   '만화방',
#   '다락방',
#   '추천',
#   '아름',
#   '답'],
#  ['날',
#   '음식',
#   '추천',
#   '부산',
#   '광안',
#   '리',
#   '라멘',
#   '전문점',
#   '류',
#   '오늘',
#   '날씨',
#   '겨울',
#   '가장',
#   '날',
#   '요',
#   '날씨',
#   '지니',
#   '갑자기',
#   '면',
#   '요리',
#   '자마자',
#   '위해',
#   '메뉴',
#   '판',
#   '류',
#   '광안',
#   '직영',
#   '점',
#   '메뉴',
#   '판',
#   '메뉴',
#   '판이',
#   '좀',
#   '메뉴',
#   '판',
#   '보시',
#   '취미',
#   '음악'],
#  ['토라',
#   '날',
#   '오뎅',
#   '탕',
#   '소주',
#   '한잔',
#   '등촌역',
#   '맛집',
#   '토라',
#   '메뉴',
#   '판',
#   '오픈',
#   '자마자',
#   '시반',
#   '시가',
#   '기전',
#   '테이블',
#   '어요',
#   '단골',
#   '꽤',
#   '날',
#   '호호',
#   '불어',
#   '며',
#   '일',
#   '본식',
#   '오뎅',
#   '탕',
#   '때',
#   '꼭',
#   '한번',
#   '완젼',
#   '추천',
#   '등촌역',
#   '맛집',
#   '의',
#   '취미',
#   '생활'],
#  ['날',
#   '비',
#   '날',
#   '더욱더',
#   '생각',
#   '겨울',
#   '간식',
#   '곳',
#   '메뉴',
#   '두',
#   '가지',
#   '호떡',
#   '풀빵',
#   '저',
#   '서도',
#   '곳',
#   '호떡',
#   '다른',
#   '곳',
#   '보지',
#   '날',
#   '비',
#   '날',
#   '더욱더',
#   '생각',
#   '겨울',
#   '간식',
#   '옛날',
#   '전통',
#   '쑥',
#   '붕어빵',
#   '기름',
#   '전통',
#   '호떡',
#   '찹쌀',
#   '호떡',
#   '햇살',
#   '가득',
#   '광양',
#   '공식',
#   '블로그'],
#  ['겨울철',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '순두부찌개',
#   '칼로리',
#   '겨울철',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '순두부찌개',
#   '칼로리',
#   '요즘',
#   '것',
#   '애',
#   '날',
#   '이면',
#   '국물',
#   '겨울철',
#   '점심',
#   '메뉴',
#   '로',
#   '순두부찌개',
#   '영어',
#   '동화책',
#   '공',
#   '부하',
#   '방법'],
#  ['오븐',
#   '마루',
#   '추천',
#   '날',
#   '생각',
#   '국물',
#   '역시',
#   '날',
#   '뜻',
#   '시원',
#   '오뎅',
#   '탕',
#   '제격',
#   '요',
#   '종류',
#   '오뎅',
#   '것',
#   '여러',
#   '오븐',
#   '마루',
#   '국물',
#   '메뉴',
#   '추천',
#   '이',
#   '줄',
#   '아직',
#   '떡볶이',
#   '국물',
#   '국물',
#   '오븐',
#   '마루',
#   '치킨'],
#  ['수원',
#   '인계동',
#   '맛집',
#   '날',
#   '매콤',
#   '양푼',
#   '애등',
#   '갈비',
#   '사장',
#   '추천',
#   '은',
#   '래야',
#   '수가',
#   '꼬슬꼬슬',
#   '밥',
#   '듬뿍',
#   '원래',
#   '나물',
#   '향',
#   '별로',
#   '아하',
#   '데',
#   '곤드레밥',
#   '그냥',
#   '어요',
#   '진짜',
#   '수원',
#   '인계동',
#   '맛집',
#   '또',
#   '다른',
#   '메인',
#   '메뉴',
#   '말',
#   '로그',
#   '일리',
#   '로그'],
#  ['마곡',
#   '맛집',
#   '추천',
#   '담',
#   '방담',
#   '방',
#   '날',
#   '날',
#   '자리',
#   '잡기',
#   '제일',
#   '마곡',
#   '맛집',
#   '추천',
#   '담',
#   '방담',
#   '방',
#   '날',
#   '날',
#   '자리',
#   '잡기',
#   '제일',
#   '수제비',
#   '집',
#   '안녕',
#   '다긔입니',
#   '메뉴',
#   '장',
#   '정리',
#   '자리',
#   '차서',
#   '경우',
#   '기',
#   '다리',
#   '데',
#   '그때',
#   '메뉴',
#   '판',
#   '오늘',
#   '행복',
#   '맛집',
#   '탐방'],
#  ['안국역',
#   '맛집',
#   '추천',
#   '날',
#   '뜻',
#   '인사동',
#   '라멘',
#   '안국역',
#   '맛집',
#   '추천',
#   '오레',
#   '노',
#   '라멘',
#   '안녕',
#   '찌',
#   '제',
#   '일본',
#   '식',
#   '라멘',
#   '아하',
#   '겨울',
#   '역',
#   '까운',
#   '맛집',
#   '최고',
#   '아무',
#   '리',
#   '어도',
#   '데',
#   '오래',
#   '걸',
#   '어가',
#   '건',
#   '찌',
#   '뷰티',
#   '로그'],
#  ['지금',
#   '메뉴',
#   '날',
#   '추천',
#   '음식',
#   '메뉴',
#   '얼',
#   '수제비',
#   '지금',
#   '메뉴',
#   '수제비',
#   '한국',
#   '물',
#   '날',
#   '음식',
#   '바람',
#   '차고',
#   '꽁꽁',
#   '몸',
#   '녹',
#   '일수',
#   '한국',
#   '물',
#   '입',
#   '날',
#   '음식',
#   '추천',
#   '수제비',
#   '겉절이',
#   '맛',
#   '기',
#   '가막',
#   '힘',
#   '맛점',
#   '음악',
#   '여',
#   '하루',
#   '언제',
#   '맑음'],
#  ['안산',
#   '초지동',
#   '점심',
#   '메뉴',
#   '날',
#   '끈',
#   '생태',
#   '탕',
#   '추천',
#   '안산',
#   '초지동',
#   '점심',
#   '메뉴',
#   '날',
#   '끈',
#   '생태',
#   '탕',
#   '추천',
#   '안녕',
#   '배꼽',
#   '아빠',
#   '블로그',
# ...
#   '기도',
#   '메',
#   '성형',
#   '외과'],
#  ['아산',
#   '카페',
#   '추천',
#   '실브',
#   '커피',
#   '날',
#   '도',
#   '공간',
#   '실브',
#   '커피',
#   '정원',
#   '가요',
#   '이',
#   '날',
#   '꽁꽁',
#   '날',
#   '천안시청',
#   '볼일',
#   '어서',
#   '다가',
#   '택시',
#   '타고',
#   '약',
#   '카페',
#   '추천',
#   '아산',
#   '카페',
#   '아산',
#   '카페',
#   '추천',
#   '천안',
#   '카페',
#   '커피',
#   '카페',
#   '추천',
#   '커피',
#   '메뉴'],
#  ['서울',
#   '종로',
#   '공평',
#   '미슐랭',
#   '맛집',
#   '우육',
#   '면관',
#   '날',
#   '몸',
#   '우육',
#   '면관',
#   '메뉴',
#   '우육',
#   '전골',
#   '저녁',
#   '메뉴',
#   '점심',
#   '예약',
#   '가능',
#   '고수',
#   '밥',
#   '셀프',
#   '바',
#   '이용',
#   '육수',
#   '진',
#   '날',
#   '정말',
#   '음식',
#   '양',
#   '사람',
#   '밥',
#   '셀프',
#   '바',
#   '준비',
#   '짱'],
#  ['서울숲',
#   '맛집',
#   '추천',
#   '날',
#   '강추',
#   '버섯',
#   '집',
#   '솔직',
#   '리뷰',
#   '날',
#   '씨',
#   '맛집',
#   '발견',
#   '오늘',
#   '리뷰',
#   '맛집',
#   '바로',
#   '바로',
#   '서울숲',
#   '위치',
#   '버섯',
#   '집',
#   '위치',
#   '바로',
#   '여기',
#   '제',
#   '방문',
#   '날',
#   '꽤',
#   '웨이',
#   '팅',
#   '조금',
#   '어요',
#   '메뉴',
#   '미로',
#   '꿀잼',
#   '인생'],
#  ['날',
#   '점심',
#   '추천',
#   '날',
#   '점심',
#   '추천',
#   '여름',
#   '가을',
#   '오',
#   '는가',
#   '더니',
#   '찬',
#   '바람',
#   '겨울',
#   '온',
#   '것',
#   '아기',
#   '어금니',
#   '엄마',
#   '날',
#   '날',
#   '가끔',
#   '점심',
#   '메뉴',
#   '로',
#   '컵라면',
#   '아가',
#   '타의',
#   '행복',
#   '일상'],
#  ['강진',
#   '맛집',
#   '한남동',
#   '이태원',
#   '즉석',
#   '떡볶이',
#   '반당',
#   '점심',
#   '메뉴',
#   '추천',
#   '반당',
#   '구경',
#   '입구',
#   '칠판',
#   '메뉴',
#   '반당',
#   '그림',
#   '초록색',
#   '반지하',
#   '창문',
#   '발견',
#   '바로',
#   '주',
#   '문하',
#   '시더',
#   '날',
#   '대기',
#   '고온',
#   '한남동',
#   '즉석',
#   '떡볶이',
#   '반당',
#   '후기',
#   '돈',
#   '산',
#   '파워',
#   '이지',
#   '여행',
#   '일상'],
#  ['날',
#   '생각',
#   '뜻',
#   '매콤',
#   '라멘',
#   '그릇',
#   '신촌',
#   '카',
#   '라멘',
#   '날',
#   '그릇',
#   '감기',
#   '저리',
#   '비켯',
#   '해주',
#   '라멘',
#   '그릇',
#   '어제',
#   '오늘',
#   '또',
#   '겨울',
#   '음식',
#   '한파',
#   '한파',
#   '메뉴',
#   '감기',
#   '뚝',
#   '메뉴',
#   '겨울',
#   '메뉴',
#   '추천',
#   '유튜브',
#   '맛집',
#   '풍자',
#   '신촌',
#   '편',
#   '언제',
#   '항상',
#   '늘',
#   '행복'],
#  ['날',
#   '국물',
#   '구리',
#   '맛집',
#   '강창구',
#   '찹쌀',
#   '진',
#   '순대국',
#   '순대국',
#   '밥',
#   '순대국',
#   '맛집',
#   '날',
#   '국물',
#   '남자',
#   '맛집',
#   '남자',
#   '이사',
#   '국밥',
#   '맛집',
#   '순대국',
#   '일반',
#   '이사',
#   '포장이사',
#   '포장이사',
#   '용달',
#   '이사',
#   '오피스텔',
#   '이사',
#   '원룸',
#   '이사',
#   '보관',
#   '이사',
#   '이사',
#   '이사',
#   '곳',
#   '이사',
#   '추천',
#   '이사비',
#   '교',
#   '저렴',
#   '이사',
#   '두',
#   '남자',
#   '이사',
#   '두',
#   '남자',
#   '청소'],
#  ['미국',
#   '식',
#   '샌드위치',
#   '맛집',
#   '인정',
#   '위트',
#   '앤',
#   '미트',
#   '메뉴',
#   '추천',
#   '날',
#   '심',
#   '저',
#   '날',
#   '운동',
#   '기분',
#   '금욜',
#   '도착',
#   '메뉴',
#   '조합',
#   '완전',
#   '완전',
#   '추천',
#   '합',
#   '닷',
#   '여기',
#   '오시',
#   '꼭',
#   '사이드',
#   '치폴레',
#   '제',
#   '빵',
#   '완젼',
#   '아하',
#   '데',
#   '여니',
#   '콩',
#   '일상',
#   '상자'],
#  ['구리',
#   '맛집',
#   '롯데',
#   '백화점',
#   '상하이',
#   '문',
#   '중화요리',
#   '날',
#   '생각',
#   '맛',
#   '칼칼',
#   '매콤',
#   '국물',
#   '굴짬뽕',
#   '오늘',
#   '추천',
#   '메뉴',
#   '깐쇼새우',
#   '야채',
#   '볶음밥',
#   '반찬',
#   '자주',
#   '생각',
#   '맛',
#   '오늘',
#   '처럼',
#   '날',
#   '은',
#   '국물',
#   '먹기',
#   '숙취',
#   '때',
#   '해장',
#   '추천',
#   '프로',
#   '삶'],
#  ['날',
#   '생각',
#   '나',
#   '건강',
#   '보양',
#   '국물',
#   '메뉴',
#   '추천',
#   '오래',
#   '맛집',
#   '김치',
#   '겉절이',
#   '깍두기',
#   '날',
#   '씨',
#   '찬',
#   '바람',
#   '불어',
#   '국물',
#   '아주',
#   '선택',
#   '땅',
#   '날씨',
#   '요즘',
#   '체',
#   '소화',
#   '속도',
#   '불편',
#   '성장',
#   '프로젝트'],
#  ['날',
#   '생각',
#   '고등동',
#   '부대찌개',
#   '맛집',
#   '날',
#   '더',
#   '날씨',
#   '국물',
#   '음식',
#   '땡',
#   '기신',
#   '한번',
#   '보시',
#   '게',
#   '추천',
#   '고',
#   '햄',
#   '사리',
#   '추가',
#   '양',
#   '것'],
#  ['날',
#   '오뎅',
#   '바',
#   '철길',
#   '부산집',
#   '춘천',
#   '애막골점',
#   '세트',
#   '메뉴',
#   '부터',
#   '꽤',
#   '다양',
#   '안주',
#   '준비',
#   '부산',
#   '철길',
#   '집',
#   '이름',
#   '답',
#   '세트',
#   '메뉴',
#   '광안',
#   '리',
#   '해운대',
#   '구수',
#   '국물',
#   '맛',
#   '대신',
#   '요즘',
#   '처럼',
#   '날',
#   '씨',
#   '전',
#   '체적',
#   '느낌',
#   '술집',
#   '추천',
#   '슬',
#   '트립',
#   '로그'],
#  ['경기',
#   '광주',
#   '맛집',
#   '날',
#   '장',
#   '지리',
#   '가마솥',
#   '장국',
#   '날',
#   '장',
#   '지리',
#   '가마솥',
#   '장국',
#   '저녁',
#   '날씨',
#   '그',
#   '래서',
#   '몸',
#   '겸',
#   '경기',
#   '광주',
#   '주차',
#   '추천',
#   '추천',
#   '가게',
#   '내부',
#   '가보',
#   '홀로',
#   '구성',
#   '어요',
#   '저희',
#   '도착'],
#  ['감탄',
#   '요기',
#   '날',
#   '생각',
#   '겨울',
#   '간식',
#   '추천',
#   '날',
#   '이면',
#   '김',
#   '모락모락',
#   '나',
#   '길거리',
#   '겨울',
#   '간식',
#   '마련',
#   '상상',
#   '쫄깃',
#   '식감',
#   '꿀',
#   '시럽',
#   '듬뿍',
#   '호떡',
#   '겨울',
#   '날',
#   '호호',
#   '불어',
#   '호떡',
#   '찬',
#   '바람',
#   '때',
#   '감탄',
#   '이의',
#   '행복',
#   '충전',
#   '블로그'],
#  ['천안',
#   '쌍용동',
#   '맛집',
#   '날',
#   '베트남',
#   '노상',
#   '식당',
#   '쌀국수',
#   '베트남',
#   '맛집',
#   '종종',
#   '가보',
#   '았',
#   '베트남',
#   '노상',
#   '식당',
#   '다양',
#   '메뉴',
#   '곳',
#   '처음',
#   '것',
#   '날',
#   '주니',
#   '용',
#   '천안',
#   '쌍용동',
#   '맛집',
#   '골목',
#   '안',
#   '전',
#   '안',
#   '설',
#   '공간'],
#  ['아이',
#   '간식',
#   '순수',
#   '거생',
#   '딸기',
#   '설빙',
#   '메뉴',
#   '추천',
#   '아이',
#   '간식',
#   '순수',
#   '거',
#   '생',
#   '딸기',
#   '설빙',
#   '메뉴',
#   '추천',
#   '안녕',
#   '설랑',
#   '코로나',
#   '확산',
#   '정말',
#   '최고',
#   '것',
#   '순수',
#   '거생',
#   '딸기',
#   '설빙',
#   '굳이',
#   '날',
#   '막상',
#   '거',
#   '연휴',
#   '하나',
#   '더',
#   '추가',
#   '정말',
#   '개성',
#   '만점',
#   '아이',
#   '셋'],
#  ['김치',
#   '수제비',
#   '만들기',
#   '비',
#   '날',
#   '음식',
#   '국물',
#   '요리',
#   '레시피',
#   '다양',
#   '국물',
#   '요리',
#   '레시피',
#   '중',
#   '서도',
#   '수제비',
#   '날',
#   '비',
#   '가오',
#   '또',
#   '날',
#   '국물',
#   '생각',
#   '날',
#   '때',
#   '한식',
#   '메뉴',
#   '원래',
#   '바지락',
#   '육수',
#   '감자',
#   '호박',
#   '메이플',
#   '대니얼',
#   '요리',
#   '공간',
#   '다니엘',
#   '랜드'],
#  ['미사리',
#   '밀빛초',
#   '국수',
#   '롯데',
#   '아울렛',
#   '광명',
#   '점',
#   '날',
#   '날',
#   '좀',
#   '아직',
#   '날',
#   '씨',
#   '칼국수',
#   '사람',
#   '나',
#   '초',
#   '국수',
#   '국수',
#   '집',
#   '인테리어',
#   '사람',
#   '메뉴',
#   '나',
#   '오기',
#   '조금',
#   '재미',
#   '일상',
#   '블로그'],
#  ['이색',
#   '체험',
#   '날',
#   '카페',
#   '도자기',
#   '마을',
#   '실내',
#   '데이트',
#   '요',
#   '실내',
#   '데이트',
#   '메뉴',
#   '좀',
#   '그',
#   '런가',
#   '사람',
#   '때',
#   '카페',
#   '도자기',
#   '마을',
#   '두',
#   '가지',
#   '도예',
#   '체험',
#   '해',
#   '보시',
#   '인근',
#   '다양',
#   '체험',
#   '거리',
#   '린아',
#   '것',
#   '추천'],
#  ['산호수',
#   '공원',
#   '점심',
#   '메뉴',
#   '추천',
#   '텐동',
#   '맛집',
#   '온센',
#   '서산',
#   '점',
#   '새',
#   '메뉴',
#   '우동',
#   '소바',
#   '어서',
#   '날',
#   '가기',
#   '것',
#   '나',
#   '바',
#   '테이블',
#   '바',
#   '테이블',
#   '자리',
#   '양쪽',
#   '귀',
#   '여운',
#   '피',
#   '규어',
#   '어서',
#   '구',
#   '경하',
#   '재미',
#   '자리',
#   '서도',
#   '김',
#   '입술',
#   '이야기'],
#  ['점심',
#   '저녁',
#   '메뉴',
#   '추천',
#   '해',
#   '드립',
#   '안녕',
#   '날',
#   '하루',
#   '요',
#   '봄',
#   '벌써',
#   '워',
#   '하루',
#   '요',
#   '요즘',
#   '날',
#   '오늘',
#   '처럼',
#   '날',
#   '겨울',
#   '전골',
#   '더',
#   '이웃',
#   '님들',
#   '오늘',
#   '점심',
#   '우동',
#   '요',
#   '추천',
#   '해',
#   '몸',
#   '건강'],
#  ['런치',
#   '날',
#   '수제비',
#   '때',
#   '김치',
#   '수제비',
#   '맛집',
#   '추천',
#   '날',
#   '좀',
#   '거리',
#   '체부동',
#   '옛날',
#   '국수',
#   '맛집',
#   '고고씽',
#   '함',
#   '메뉴',
#   '판',
#   '아쉬움',
#   '내',
#   '김치',
#   '수제비',
#   '포함',
#   '밀가루',
#   '메뉴',
#   '거의',
#   '판',
#   '매하',
#   '듯',
#   '내',
#   '주문',
#   '하디'],
#  ['북촌',
#   '손',
#   '만두',
#   '날',
#   '만둣국',
#   '죠',
#   '서창동',
#   '밥집',
#   '추천',
#   '왕비',
#   '돈까스',
#   '골목',
#   '동궁',
#   '찜닭',
#   '옆',
#   '주차',
#   '가능',
#   '휴무',
#   '월요일',
#   '메뉴',
#   '판',
#   '메뉴',
#   '판',
#   '셀프',
#   '간단',
#   '오기',
#   '듯',
#   '추천',
#   '저기',
#   '음식',
#   '곳',
#   '셀프',
#   '픽업',
#   '애정',
#   '가득'],
#  ['명',
#   '날',
#   '샤브샤브',
#   '맛집',
#   '토리',
#   '샤브',
#   '후기',
#   '부산',
#   '강서구',
#   '명',
#   '지국',
#   '제',
#   '로',
#   '호',
#   '포장',
#   '배달',
#   '택배',
#   '전문',
#   '카톡',
#   '배민',
#   '주문',
#   '가능',
#   '요즘',
#   '날',
#   '기전',
#   '봄',
#   '사장',
#   '메뉴',
#   '판',
#   '사진',
#   '완전',
#   '나',
#   '요게',
#   '토리',
#   '샤브',
#   '메뉴',
#   '일상',
#   '기록'],
#  ['맘',
#   '가면',
#   '꼭',
#   '주문',
#   '먹킷',
#   '리스트',
#   '맘',
#   '메뉴',
#   '추천',
#   '이벤트',
#   '맘',
#   '메뉴',
#   '대한',
#   '솔직',
#   '리뷰',
#   '가득',
#   '이번',
#   '콘텐츠',
#   '시작',
#   '한국인',
#   '아주',
#   '뼈',
#   '귀',
#   '해장국',
#   '날',
#   '살짝',
#   '날',
#   '끈',
#   '해장국',
#   '사발',
#   '들깻',
#   '가루',
#   '오늘',
#   '맘',
#   '순대국',
#   '공식',
#   '블로그'],
#  ['수원',
#   '맛집',
#   '날',
#   '더',
#   '조개찜',
#   '맛집',
#   '포항',
#   '물회',
#   '조개찜',
#   '치즈',
#   '곳도',
#   '저',
#   '여기',
#   '처음',
#   '어요',
#   '우리',
#   '주문',
#   '메뉴',
#   '조개',
#   '전골',
#   '인',
#   '확',
#   '고요',
#   '가족',
#   '회식',
#   '등',
#   '연말',
#   '연초',
#   '식사',
#   '도',
#   '안주',
#   '도',
#   '조개',
#   '전골',
#   '조심',
#   '스레',
#   '추천',
#   '해',
#   '보아',
#   '용',
#   '손소',
#   '품공',
#   '방과',
#   '일상'],
#  ['점심',
#   '메뉴',
#   '추천',
#   '떡',
#   '라면',
#   '법',
#   '그',
#   '래서',
#   '뭐',
#   '고민',
#   '휴일',
#   '날',
#   '점심',
#   '반찬',
#   '날',
#   '점심',
#   '메뉴',
#   '로',
#   '때로는',
#   '날',
#   '국물',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '해달',
#   '떡',
#   '라면',
#   '제일',
#   '먼저',
#   '생각',
#   '나',
#   '듯',
#   '꽃',
#   '산골'],
#  ['상봉역',
#   '샤브샤브',
#   '삼청동',
#   '샤브',
#   '날',
#   '인',
#   '샤브',
#   '서도',
#   '무슨',
#   '메뉴',
#   '확인',
#   '가능',
#   '요',
#   '오전',
#   '열',
#   '어서',
#   '저녁',
#   '참고',
#   '꿀',
#   '이득',
#   '겨울',
#   '땡',
#   '때',
#   '추천',
#   '합',
#   '당',
#   '삼청동',
#   '샤브',
#   '샤브샤브',
#   '겨울철',
#   '음식',
#   '추천',
#   '방',
#   '의',
#   '맛집',
#   '탐방',
#   '솔직',
#   '리뷰'],
#  ['대구',
#   '진천동',
#   '칼국수',
#   '날',
#   '자',
#   '가제',
#   '진주',
#   '손',
#   '칼국수',
#   '대구',
#   '진천동',
#   '칼국수',
#   '날',
#   '자',
#   '가제',
#   '진주',
#   '손',
#   '칼국수',
#   '요즘',
#   '갑자기',
#   '너',
#   '무',
#   '세트',
#   '메뉴',
#   '포함',
#   '알밥',
#   '날치',
#   '알',
#   '김이랑',
#   '고',
#   '세',
#   '입',
#   '컷',
#   '에피타이저',
#   '먹기',
#   '위해',
#   '하루살이',
#   '집사',
#   '블로거'],
#  ['논현역',
#   '술집',
#   '날',
#   '안주',
#   '달래',
#   '해장',
#   '회식',
#   '버너',
#   '위',
#   '메뉴',
#   '판이',
#   '어요',
#   '메뉴',
#   '진짜',
#   '모듬',
#   '수육',
#   '소',
#   '하나',
#   '해장',
#   '전골',
#   '하나',
#   '습',
#   '안주',
#   '조합',
#   '진짜',
#   '친구',
#   '추천',
#   '완전',
#   '성공',
#   '칭찬',
#   '어요',
#   '날',
#   '안주',
#   '후',
#   '우의',
#   '일상',
#   '블로그'],
#  ['을지로',
#   '맛집',
#   '날',
#   '황평집',
#   '닭곰탕',
#   '그릇',
#   '안주',
#   '메뉴',
#   '도',
#   '주문',
#   '가능',
#   '시간',
#   '대신',
#   '브레이크',
#   '타임',
#   '것',
#   '참고',
#   '마음',
#   '속',
#   '두',
#   '명',
#   '이상일',
#   '경우',
#   '추천',
#   '이지',
#   '두',
#   '명',
#   '간단',
#   '곰탕',
#   '닭',
#   '이나',
#   '닭찜',
#   '중',
#   '하나',
#   '주',
#   '문하',
#   '게',
#   '듯',
#   '쏭블리',
#   '조각',
#   '한조',
#   '각'],
#  ['포항',
#   '양덕',
#   '맛집',
#   '한양',
#   '곱창전골',
#   '날',
#   '국물',
#   '호로',
#   '록',
#   '메뉴',
#   '구성',
#   '전골',
#   '저희',
#   '아래',
#   '처럼',
#   '주문',
#   '어요',
#   '곱창전골',
#   '인분',
#   '공기밥',
#   '볶음밥',
#   '음료수',
#   '포항',
#   '양덕',
#   '맛집',
#   '맛집',
#   '추천',
#   '한양',
#   '곱창전골',
#   '곱창',
#   '대학생',
#   '일상',
#   '기록',
#   '재희',
#   '직딩',
#   '일기'],
#  ['홍대',
#   '상수',
#   '날',
#   '식사',
#   '추천',
#   '돈코츠',
#   '라멘',
#   '하카다',
#   '분코',
#   '주력',
#   '메뉴',
#   '어가',
#   '입구',
#   '완전',
#   '라멘',
#   '집',
#   '움',
#   '원래',
#   '차슈',
#   '덮밥',
#   '어보',
#   '거',
#   '오버',
#   '동맥경화',
#   '것',
#   '국물',
#   '맛',
#   '이지',
#   '진짜',
#   '매력',
#   '전혀',
#   '안남',
#   '날',
#   '라멘',
#   '드',
#   '세용',
#   '얄',
#   '맛',
#   '평가',
#   '블로그',
#   '맛챠'],
#  ['미소',
#   '서초',
#   '점',
#   '날',
#   '우삼겹',
#   '우동',
#   '강추',
#   '미소',
#   '미소',
#   '남부',
#   '터미널',
#   '소야',
#   '서초',
#   '점',
#   '남부',
#   '터미널',
#   '맛집',
#   '미소',
#   '메뉴',
#   '소야',
#   '가격',
#   '미소',
#   '메뉴',
#   '추천',
#   '우삼겹',
#   '우동',
#   '부대',
#   '라면',
#   '남부',
#   '터미널',
#   '혼밥',
#   '서초',
#   '점심',
#   '서초',
#   '맛집',
#   '곳',
#   '메뉴',
#   '맛',
#   '도리',
#   '그',
#   '제일'],
#  ['광주',
#   '첨단',
#   '맛집',
#   '쭈마담',
#   '날',
#   '매콤',
#   '게',
#   '땐',
#   '바로',
#   '여기',
#   '스페셜',
#   '메뉴',
#   '삼겹',
#   '새우',
#   '우삼겹',
#   '수',
#   '재미',
#   '첨단',
#   '맛집',
#   '첨단',
#   '지구',
#   '맛집',
#   '첨단',
#   '쭈꾸미',
#   '첨단',
#   '쭈꾸미',
#   '맛집',
#   '첨단',
#   '점심',
#   '추천',
#   '첨단',
#   '저녁',
#   '추천',
#   '첨단',
#   '점심',
#   '맛집',
#   '첨단',
#   '저녁',
#   '맛집',
#   '신용동',
#   '쭈꾸미',
#   '민경',
#   '일상',
#   '블로그'],
#  ['강릉',
#   '육',
#   '반장',
#   '주문진',
#   '육개장',
#   '맛집',
#   '해장',
#   '메뉴',
#   '추천',
#   '아침식사',
#   '가능',
#   '일반',
#   '육개장',
#   '국물',
#   '자체',
#   '녹',
#   '진해',
#   '날',
#   '국물',
#   '것',
#   '고요',
#   '처음',
#   '해장',
#   '메뉴',
#   '추천',
#   '후기',
#   '위치',
#   '상',
#   '주문진',
#   '여행',
#   '후',
#   '마지막',
#   '날',
#   '먹기',
#   '식사',
#   '오전',
#   '시부',
#   '터',
#   '영업',
#   '며',
#   '의',
#   '지도'],
#  ['등촌',
#   '샤브',
#   '칼국수',
#   '날',
#   '어요',
#   '날',
#   '근처',
#   '저녁',
#   '거리',
#   '아보',
#   '았습니',
#   '고기',
#   '종류',
#   '국물',
#   '보증',
#   '맛',
#   '저희',
#   '날',
#   '등촌',
#   '등촌',
#   '칼국수',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '메뉴',
#   '추천',
#   '먹방',
#   '저녁',
#   '메뉴',
#   '렌느',
#   '제이',
#   '가온',
#   '맘'],
#  ['원주',
#   '배달',
#   '맛집',
#   '관설',
#   '삼부',
#   '자집',
#   '날',
#   '삼계탕',
#   '끼',
#   '독특',
#   '메뉴',
#   '인',
#   '닭',
#   '만두전골',
#   '인기',
#   '메뉴',
#   '삼계탕',
#   '주',
#   '문하',
#   '메뉴',
#   '라서',
#   '주문',
#   '어요',
#   '배달',
#   '보시',
#   '길',
#   '추천',
#   '드릴',
#   '요',
#   '원주',
#   '배달',
#   '맛집',
#   '원주',
#   '배달',
#   '원주',
#   '삼부',
#   '자집',
#   '원주',
#   '삼계탕',
#   '삼부',
#   '자집',
#   '맛집',
#   '툐히',
#   '일상',
#   '블로그'],
#  ['오문',
#   '창',
#   '순대국',
#   '밥',
#   '메뉴',
#   '가격',
#   '대전',
#   '맛집',
#   '추천',
#   '돈내',
#   '날',
#   '호로',
#   '록',
#   '먹기',
#   '난',
#   '한번',
#   '걸',
#   '족함',
#   '고',
#   '밥',
#   '방식',
#   '이면',
#   '더',
#   '팔팔',
#   '여주면',
#   '더',
#   '위치'],
#  ['역전',
#   '할머니',
#   '메뉴',
#   '추천',
#   '거',
#   '거',
#   '거',
#   '어요',
#   '날',
#   '아이스',
#   '맥주',
#   '뻥',
#   '기분',
#   '고',
#   '취하',
#   '것',
#   '느낌',
#   '적',
#   '느낌',
#   '요',
#   '역전',
#   '할머니',
#   '메뉴',
#   '추천',
#   '센치',
#   '돈까스'],
#  ['날',
#   '최고',
#   '화명동',
#   '맛집',
#   '왕대',
#   '탕',
#   '테이블',
#   '마다',
#   '메뉴',
#   '판도',
#   '어요',
#   '모',
#   '생선',
#   '구이',
#   '주',
#   '문하',
#   '시더',
#   '저',
#   '국물',
#   '어서',
#   '대구',
#   '탕',
#   '주문',
#   '모',
#   '생선',
#   '구이',
#   '다음',
#   '방',
#   '문하',
#   '어요',
#   '화명동',
#   '식당',
#   '추천',
#   '주문',
#   '산홈',
#   '서비스',
#   '부산',
#   '북구',
#   '점'],
#  ['여의도',
#   '맛집',
#   '가양',
#   '칼국수',
#   '버섯',
#   '매운탕',
#   '날',
#   '무조건',
#   '생각',
#   '날',
#   '맛집',
#   '날',
#   '날',
#   '무조건',
#   '생각',
#   '날',
#   '음식',
#   '었다',
#   '겨울',
#   '지금',
#   '인기',
#   '것',
#   '메뉴',
#   '특성',
#   '상',
#   '눈',
#   '오거',
#   '비',
#   '날',
#   '직장인',
#   '인기',
#   '매운탕',
#   '약간',
#   '것',
#   '버섯',
#   '매운탕',
#   '만큼',
#   '언제',
#   '여행자'],
#  ['영통',
#   '맛집',
#   '호',
#   '면',
#   '날',
#   '생각',
#   '쌀국수',
#   '맛집',
#   '단면',
#   '사진',
#   '쉬',
#   '림프',
#   '롤',
#   '야채',
#   '면',
#   '고',
#   '통통',
#   '새우',
#   '튀김',
#   '꽉',
#   '어서',
#   '추천',
#   '사이드',
#   '메뉴',
#   '겨울',
#   '메뉴',
#   '때',
#   '사이드',
#   '까지',
#   '수',
#   '영통',
#   '호',
#   '면',
#   '콩',
#   '의',
#   '여행',
#   '로그'],
#  ['일산',
#   '맛집',
#   '날',
#   '갈비찜',
#   '조개찜',
#   '두마',
#   '리',
#   '토끼',
#   '아무',
#   '도',
#   '계절',
#   '시원',
#   '조개찜',
#   '국물',
#   '소주',
#   '잔',
#   '캬',
#   '시',
#   '그니',
#   '처',
#   '메뉴',
#   '조개',
#   '갈비찜',
#   '일명',
#   '조갈',
#   '찜',
#   '고',
#   '대표',
#   '메뉴',
#   '문어',
#   '전복',
#   '조개',
#   '갈비찜',
#   '귤떡'],
#  ['종로',
#   '익선동',
#   '라쿠',
#   '날',
#   '근사',
#   '신기하',
#   '날',
#   '이자카야',
#   '생각',
#   '절로',
#   '나',
#   '그',
#   '런가',
#   '아무',
#   '웨스',
#   '틴',
#   '조선',
#   '양송이',
#   '꼬치',
#   '품',
#   '메뉴',
#   '던데',
#   '양송이',
#   '꼭',
#   '융',
#   '고',
#   '이',
#   '날',
#   '내',
#   '마음속',
#   '위',
#   '전복',
#   '하나',
#   '뿐'],
#  ['만들기',
#   '간단',
#   '주말',
#   '점심',
#   '메뉴',
#   '추천',
#   '다이소',
#   '오뎅',
#   '티백',
#   '활용',
#   '법',
#   '초',
#   '간단',
#   '자취',
#   '생',
#   '요리',
#   '사각',
#   '어묵국',
#   '만들기',
#   '간단',
#   '주말',
#   '점심',
#   '메뉴',
#   '추천',
#   '다이소',
#   '오뎅',
#   '티백',
#   '활용',
#   '법',
#   '티',
#   '필요',
#   '때',
#   '혼술',
#   '캠핑',
#   '해외여행',
#   '야식',
#   '숙취',
#   '해소',
#   '밥',
#   '때',
#   '날',
#   '등산',
#   '과정',
#   '영상',
#   '해우',
#   '의',
#   '요리',
#   '이야기'],
#  ['뭐',
#   '고사',
#   '집밥',
#   '모음',
#   '집밥',
#   '메뉴',
#   '추천',
#   '떡갈비',
#   '정식',
#   '오늘',
#   '날',
#   '지하',
#   '주차장',
#   '주말',
#   '어제',
#   '낮',
#   '부터',
#   '만석',
#   '오늘',
#   '해장국',
#   '완전',
#   '날',
#   '아침',
#   '국',
#   '완전',
#   '완전',
#   '시원',
#   '소리',
#   '절로',
#   '현이',
#   '집밥',
#   '도시락'],
#  ['서면',
#   '날',
#   '가기',
#   '카페',
#   '추천',
#   '코타츠',
#   '카페',
#   '진짜',
#   '추천',
#   '드릴',
#   '요',
#   '녹',
#   '아들',
#   '녹',
#   '카페',
#   '서면역',
#   '번',
#   '출구',
#   '도보',
#   '분거',
#   '리',
#   '영업',
#   '시간',
#   '평일',
#   '드디어',
#   '저희',
#   '메뉴',
#   '오용',
#   '당고',
#   '세트',
#   '아메리카노',
#   '아메리카노',
#   '맘',
#   '대루'],
#  ['강남',
#   '맛집',
#   '날',
#   '모임',
#   '장소',
#   '국물',
#   '추천',
#   '닭',
#   '마리',
#   '맛',
#   '친구',
#   '추천',
#   '과',
#   '우리',
#   '모임',
#   '식사',
#   '메뉴',
#   '국물',
#   '결정',
#   '닭',
#   '마리',
#   '왜',
#   '가요',
#   '저',
#   '얼',
#   '마전',
#   '롱패딩',
#   '완전',
#   '무장',
#   '분',
#   '봄',
#   '충격',
#   '새댁',
#   '도착',
#   '우당',
#   '탕밍'],
#  ['부산',
#   '오빠',
#   '겨울',
#   '커피차',
#   '간식',
#   '차',
#   '세트',
#   '메뉴',
#   '추천',
#   '세트',
#   '메뉴',
#   '를',
#   '추천',
#   '해',
#   '겨울',
#   '간식',
#   '세트',
#   '추천',
#   '빠빰',
#   '어떡',
#   '어묵',
#   '떡볶이',
#   '겨울',
#   '간식',
#   '바로',
#   '어묵',
#   '날',
#   '몸',
#   '녹',
#   '이기',
#   '부산',
#   '오빠',
#   '솔직',
#   '부산여행',
#   '맛집',
#   '리뷰'],
#  ['서수',
#   '원',
#   '맛집',
#   '장궁',
#   '순대국',
#   '날',
#   '국물',
#   '최고',
#   '날',
#   '국밥',
#   '땡',
#   '기기',
#   '마련',
#   '장궁',
#   '순대국',
#   '메뉴',
#   '를',
#   '인삼',
#   '어간',
#   '보양식',
#   '양',
#   '분',
#   '특',
#   '주',
#   '문하',
#   '는걸',
#   '추천',
#   '고',
#   '이건',
#   '영양',
#   '순대국',
#   '인삼',
#   '헛개',
#   '대추',
#   '어서',
#   '숸댁',
#   '로그'],
#  ['날',
#   '몸',
#   '수',
#   '별내',
#   '맛집',
#   '앤',
#   '별내',
#   '점',
#   '날',
#   '씨',
#   '먹기',
#   '항아리',
#   '누룽지',
#   '해산물',
#   '파스타',
#   '추천',
#   '메뉴',
#   '인',
#   '이유',
#   '고요',
#   '아직',
#   '안',
#   '보신',
#   '분',
#   '꼭',
#   '보시',
#   '길',
#   '포스팅',
#   '소정',
#   '원고료',
#   '작',
#   '성하',
#   '님',
#   '블로그'],
#  ['경산',
#   '중산',
#   '점',
#   '남',
#   '다른',
#   '감자탕',
#   '날',
#   '감자탕',
#   '경산',
#   '점',
#   '뚝배기',
#   '감자탕',
#   '뼈',
#   '전골',
#   '추천',
#   '추천',
#   '감자탕',
#   '경산',
#   '감자탕',
#   '경산',
#   '맛집',
#   '정평역',
#   '감자탕',
#   '경산',
#   '남',
#   '다른',
#   '감자탕',
#   '정평역',
#   '맛집',
#   '정평역',
#   '밥집',
#   '중산동',
#   '맛집',
#   '다른',
#   '감자탕',
#   '중산',
#   '점',
#   '경산',
#   '밥집',
#   '다른',
#   '감자탕',
#   '메뉴'],
#  ['날',
#   '먹기',
#   '경기도',
#   '시흥',
#   '맛집',
#   '고구려',
#   '짬뽕',
#   '본점',
#   '우리',
#   '메뉴',
#   '산선',
#   '짜장',
#   '차돌박이',
#   '짬뽕',
#   '짬뽕밥',
#   '아침',
#   '일찍',
#   '부터',
#   '움직',
#   '여서',
#   '먹기',
#   '음식',
#   '추천',
#   '점심시간',
#   '간다',
#   '대기',
#   '수',
#   '것',
#   '오목',
#   '교',
#   '미용실',
#   '리얼',
#   '드',
#   '살롱',
#   '부원장',
#   '가온'],
#  ['방배동',
#   '해장국',
#   '한사',
#   '바리',
#   '해장국',
#   '서초',
#   '점',
#   '날',
#   '생각',
#   '포장',
#   '추천',
#   '국밥',
#   '아하',
#   '남자친구',
#   '해장',
#   '돼지국밥',
#   '내장탕',
#   '아하',
#   '저',
#   '내장탕',
#   '다가',
#   '사이드',
#   '종류',
#   '녹두',
#   '전',
#   '명',
#   '이서',
#   '메뉴',
#   '개',
#   '사이드',
#   '개인',
#   '데',
#   '천',
#   '천',
#   '가지',
#   '일상']]

# %%
#본문 마다 단어와 갯수 구하기 

for i in range(0,len(an)) :
    count = Counter(an[i])
    
    an[i] = count.most_common()

# %%
an
# Out:
# [[('추천', 5),
#   ('날', 3),
#   ('국물', 3),
#   ('메뉴', 3),
#   ('요리', 2),
#   ('때', 2),
#   ('풀무원', 1),
#   ('오우', 1),
#   ('종', 1),
#   ('정통', 1),
#   ('아쿠', 1),
#   ('춥다', 1),
#   ('절로', 1),
#   ('생각', 1),
#   ('뭘', 1),
#   ('살', 1),
#   ('쿵', 1),
#   ('오늘', 1),
#   ('우동', 1),
#   ('간편식', 1),
#   ('유부초밥', 1),
#   ('김밥', 1),
#   ('겨울', 1),
#   ('음식', 1),
#   ('저녁', 1),
#   ('꾱꾱꾱', 1),
#   ('하루하루', 1)],
#  [('저녁', 5),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('순두부찌개', 2),
#   ('법', 2),
#   ('부천', 2),
#   ('내비', 2),
#   ('이야기', 2),
#   ('오늘', 1),
#   ('저희', 1),
#   ('블로그', 1),
#   ('방문', 1),
#   ('해주', 1),
#   ('셔', 1),
#   ('감사', 1),
#   ('매일', 1),
#   ('상이', 1),
#   ('고민', 1),
#   ('요', 1),
#   ('사', 1),
#   ('먹기', 1),
#   ('질리', 1),
#   ('가끔', 1),
#   ('확', 1),
#   ('음식', 1),
#   ('생기', 1),
#   ('고요', 1),
#   ('블박', 1),
#   ('썬팅', 1),
#   ('비', 1),
#   ('매립', 1)],
#  [('레시피', 2),
#   ('날', 2),
#   ('먹음', 2),
#   ('더', 2),
#   ('육수', 2),
#   ('호로', 2),
#   ('록', 2),
#   ('캠핑', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('어묵탕', 2),
#   ('법', 2),
#   ('꼬치', 1),
#   ('오뎅', 1),
#   ('탕', 1),
#   ('국물', 1),
#   ('요리', 1),
#   ('준비', 1),
#   ('끼', 1),
#   ('식사', 1),
#   ('해', 1),
#   ('결하', 1),
#   ('선택', 1),
#   ('사계절', 1),
#   ('모두', 1),
#   ('시크', 1),
#   ('도도', 1),
#   ('토깽', 1),
#   ('살', 1),
#   ('효', 1)],
#  [('묵은지', 3),
#   ('날', 2),
#   ('메뉴', 2),
#   ('저녁', 2),
#   ('닭도리탕', 2),
#   ('추천', 1),
#   ('초', 1),
#   ('간단', 1),
#   ('닭볶음탕', 1),
#   ('밥위', 1),
#   ('국물', 1),
#   ('밥', 1),
#   ('개꿀맛', 1),
#   ('완성', 1),
#   ('요리', 1),
#   ('이제', 1),
#   ('숙성', 1),
#   ('꽤', 1),
#   ('선택', 1),
#   ('오늘', 1),
#   ('도', 1),
#   ('전해', 1),
#   ('보시', 1),
#   ('스마트', 1),
#   ('라이프', 1)],
#  [('맛집', 6),
#   ('점심', 3),
#   ('사골', 3),
#   ('칼국수', 3),
#   ('전주', 3),
#   ('시가지', 3),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('장소', 2),
#   ('생각', 1),
#   ('신', 1),
#   ('식사', 1),
#   ('한음', 1),
#   ('식', 1),
#   ('주신', 1),
#   ('전북', 1),
#   ('경찰청', 1),
#   ('방송국', 1),
#   ('회식', 1),
#   ('단체', 1),
#   ('모임', 1),
#   ('직장인', 1),
#   ('효자동', 1),
#   ('오늘', 1),
#   ('무엇', 1),
#   ('행복', 1)],
#  [('날', 3),
#   ('메뉴', 2),
#   ('감미', 2),
#   ('옥', 2),
#   ('도가니탕', 2),
#   ('방촌', 2),
#   ('떡볶이', 2),
#   ('추천', 2),
#   ('간편', 1),
#   ('집밥', 1),
#   ('저', 1),
#   ('전', 1),
#   ('냉장고', 1),
#   ('빼', 1),
#   ('조리', 1),
#   ('때', 1),
#   ('찬물', 1),
#   ('면서', 1),
#   ('해동', 1),
#   ('수', 1),
#   ('어요', 1),
#   ('냄비', 1),
#   ('국물', 1),
#   ('로', 1),
#   ('저희', 1),
#   ('남편', 1),
#   ('제', 1),
#   ('대로', 1),
#   ('이루', 1)],
#  [('메', 3),
#   ('커피', 3),
#   ('레몬차', 2),
#   ('날', 2),
#   ('마시기', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('해', 2),
#   ('저', 1),
#   ('평소', 1),
#   ('자주', 1),
#   ('방', 1),
#   ('문하', 1),
#   ('겨울철', 1),
#   ('종종', 1),
#   ('구', 1),
#   ('매하', 1),
#   ('것', 1),
#   ('자몽차', 1),
#   ('음번', 1),
#   ('한번', 1),
#   ('요', 1),
#   ('제', 1),
#   ('매일', 1),
#   ('심슨', 1)],
#  [('메뉴', 3),
#   ('맛집', 2),
#   ('부대찌개', 2),
#   ('날', 2),
#   ('안양', 1),
#   ('명학역', 1),
#   ('현지', 1),
#   ('두꺼비', 1),
#   ('로', 1),
#   ('추천', 1),
#   ('어요', 1),
#   ('패딩', 1),
#   ('다가', 1),
#   ('다시', 1),
#   ('국물', 1),
#   ('메인', 1),
#   ('심플', 1),
#   ('요', 1),
#   ('원래', 1),
#   ('몇', 1),
#   ('가지', 1),
#   ('집중', 1),
#   ('저희', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('일상', 1)],
#  [('만두전골', 4),
#   ('천동', 3),
#   ('추천', 3),
#   ('만두', 3),
#   ('수원', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('평양', 2),
#   ('손', 2),
#   ('입맛', 2),
#   ('천', 1),
#   ('몸', 1),
#   ('녹', 1),
#   ('속', 1),
#   ('일단', 1),
#   ('쇠고기', 1),
#   ('부터', 1),
#   ('질', 1),
#   ('기기', 1),
#   ('전', 1),
#   ('맛집', 1),
#   ('때', 1),
#   ('정', 1),
#   ('삼화', 1)],
#  [('날', 3),
#   ('국물', 3),
#   ('요리', 3),
#   ('가락', 3),
#   ('우동', 3),
#   ('아이', 2),
#   ('간식', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('풀무원', 2),
#   ('유부', 2),
#   ('짬뽕', 1),
#   ('먹방', 1),
#   ('안녕', 1),
#   ('요즘', 1),
#   ('일', 1),
#   ('교차', 1),
#   ('심해', 1),
#   ('지면', 1),
#   ('아침', 1),
#   ('저녁', 1),
#   ('고요', 1),
#   ('미거', 1),
#   ('네', 1)],
#  [('날', 3),
#   ('롯데', 3),
#   ('간편식', 2),
#   ('수제비', 2),
#   ('상품', 2),
#   ('얼', 1),
#   ('고추장', 1),
#   ('만들기', 1),
#   ('저녁', 1),
#   ('메뉴', 1),
#   ('추천', 1),
#   ('요즘', 1),
#   ('비', 1),
#   ('누구', 1),
#   ('별', 1),
#   ('다른', 1),
#   ('재료', 1),
#   ('준비', 1),
#   ('이도', 1),
#   ('수', 1),
#   ('점', 1),
#   ('최고', 1),
#   ('매력', 1),
#   ('었던', 1),
#   ('제품', 1),
#   ('었다', 1),
#   ('리하', 1),
#   ('요리', 1),
#   ('마트', 1),
#   ('고추', 1),
#   ('자', 1)],
#  [('죽', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('뜻', 1),
#   ('끼', 1),
#   ('음식', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('국밥', 1),
#   ('류', 1),
#   ('먹기', 1),
#   ('자', 1),
#   ('극적', 1),
#   ('려고', 1),
#   ('요', 1),
#   ('거나', 1),
#   ('포장', 1),
#   ('이해', 1),
#   ('직접', 1),
#   ('본적', 1),
#   ('별로', 1),
#   ('짱구', 1),
#   ('밍', 1),
#   ('일상', 1),
#   ('블로그', 1)],
#  [('샤브샤브', 3),
#   ('익선동', 2),
#   ('맛집', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('국물', 1),
#   ('메뉴', 1),
#   ('온천', 1),
#   ('집', 1),
#   ('섭', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('분만', 1),
#   ('체감', 1),
#   ('한시', 1),
#   ('간', 1),
#   ('기다림', 1),
#   ('추위', 1),
#   ('여기', 1),
#   ('꼭', 1),
#   ('가보', 1),
#   ('셔', 1),
#   ('해', 1),
#   ('껏', 1),
#   ('어서', 1),
#   ('배부', 1),
#   ('르', 1),
#   ('또', 1),
#   ('일상', 1),
#   ('여행', 1)],
#  [('점심', 3),
#   ('선유도역', 2),
#   ('날', 2),
#   ('설렁탕', 2),
#   ('추천', 2),
#   ('먹기', 1),
#   ('맛집', 1),
#   ('직장인', 1),
#   ('이남', 1),
#   ('장', 1),
#   ('생', 1),
#   ('긴지', 1),
#   ('오래', 1),
#   ('전통', 1),
#   ('이', 1),
#   ('남장', 1),
#   ('집', 1),
#   ('방문', 1),
#   ('식사', 1),
#   ('메뉴', 1),
#   ('기도', 1),
#   ('더', 1),
#   ('생각', 1),
#   ('국물', 1),
#   ('요리', 1),
#   ('것', 1),
#   ('매일', 1),
#   ('여행', 1)],
#  [('칼국수', 7),
#   ('정', 3),
#   ('들깨', 3),
#   ('울산', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('날', 1),
#   ('한사', 1),
#   ('바리', 1),
#   ('점심', 1),
#   ('로', 1),
#   ('해', 1),
#   ('판', 1),
#   ('바지락', 1),
#   ('엄마', 1),
#   ('시더', 1),
#   ('아하', 1),
#   ('시', 1),
#   ('분', 1),
#   ('라면', 1),
#   ('인기', 1),
#   ('아날로그', 1),
#   ('졔졔', 1)],
#  [('샤브샤브', 4),
#   ('메뉴', 4),
#   ('요리', 4),
#   ('국물', 3),
#   ('추천', 3),
#   ('인', 2),
#   ('날', 2),
#   ('혼밥', 2),
#   ('집밥', 2),
#   ('혼자', 1),
#   ('서도', 1),
#   ('어요', 1),
#   ('만들기', 1),
#   ('맘마', 1)],
#  [('우동', 5),
#   ('요리', 4),
#   ('국물', 3),
#   ('풀무원', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('가락', 2),
#   ('유부', 2),
#   ('날', 2),
#   ('이지', 1),
#   ('나', 1),
#   ('봄', 1),
#   ('여름', 1),
#   ('가을', 1),
#   ('겨울', 1),
#   ('상관', 1),
#   ('사계절', 1),
#   ('입하', 1),
#   ('역시', 1),
#   ('면', 1),
#   ('은', 1),
#   ('냉수', 1),
#   ('마찰', 1),
#   ('쫄깃', 1),
#   ('식', 1),
#   ('낭낭', 1),
#   ('일상', 1)],
#  [('생각', 3),
#   ('개성', 2),
#   ('손', 2),
#   ('만두', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('더', 2),
#   ('오산', 1),
#   ('맛집', 1),
#   ('추천', 1),
#   ('계절', 1),
#   ('국물', 1),
#   ('숫', 1),
#   ('가락', 1),
#   ('겨울', 1),
#   ('이면', 1),
#   ('여러분', 1),
#   ('뚝배기', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('아주', 1),
#   ('가족', 1),
#   ('거나', 1),
#   ('친', 1),
#   ('구들', 1),
#   ('술', 1),
#   ('한잔', 1),
#   ('비상', 1),
#   ('누수', 1),
#   ('탐지', 1)],
#  [('것', 4),
#   ('돼지', 3),
#   ('곱창', 2),
#   ('곱창전골', 2),
#   ('저녁', 2),
#   ('메뉴', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('옛날', 1),
#   ('마을', 1),
#   ('본점', 1),
#   ('맛집', 1),
#   ('음식', 1),
#   ('안녕', 1),
#   ('로', 1),
#   ('생각', 1),
#   ('다른', 1),
#   ('거', 1),
#   ('싹', 1),
#   ('동생', 1),
#   ('해달', 1),
#   ('하니', 1),
#   ('전골', 1),
#   ('이면', 1),
#   ('이', 1),
#   ('래서', 1),
#   ('옥훼이', 1),
#   ('바로', 1),
#   ('주문', 1),
#   ('미미', 1),
#   ('밍님', 1),
#   ('블로그', 1)],
#  [('종로', 6),
#   ('날', 3),
#   ('메뉴', 3),
#   ('해장국', 3),
#   ('국물', 2),
#   ('뼈', 2),
#   ('맛집', 2),
#   ('추천', 2),
#   ('집', 1),
#   ('조가', 1),
#   ('가조', 1),
#   ('가점', 1),
#   ('심', 1),
#   ('은근', 1),
#   ('곳', 1),
#   ('어서', 1),
#   ('사무실', 1),
#   ('좀', 1),
#   ('은', 1)],
#  [('날', 2),
#   ('추천', 2),
#   ('신림역', 1),
#   ('집', 1),
#   ('먹기', 1),
#   ('밀키', 1),
#   ('트', 1),
#   ('밥끼', 1),
#   ('하루하루', 1),
#   ('일어', 1),
#   ('나', 1),
#   ('가기', 1),
#   ('오늘', 1),
#   ('메뉴', 1),
#   ('를', 1),
#   ('골', 1),
#   ('라주시', 1),
#   ('요', 1),
#   ('만두', 1),
#   ('류', 1),
#   ('저', 1),
#   ('하나', 1),
#   ('확대', 1),
#   ('분', 1),
#   ('위', 1),
#   ('달', 1)],
#  [('추천', 5),
#   ('칼국수', 5),
#   ('사골', 4),
#   ('메뉴', 3),
#   ('날', 2),
#   ('음식', 2),
#   ('명동', 2),
#   ('면', 2),
#   ('오늘', 1),
#   ('메인', 1),
#   ('메뉴인', 1),
#   ('교자', 1),
#   ('처럼', 1),
#   ('날씨', 1),
#   ('해', 1),
#   ('본사', 1),
#   ('구내식당', 1),
#   ('아빠', 1)],
#  [('식사', 3),
#   ('찌개', 2),
#   ('지존', 2),
#   ('날', 2),
#   ('도', 2),
#   ('간단', 2),
#   ('술', 1),
#   ('잔', 1),
#   ('집', 1),
#   ('메뉴', 1),
#   ('오늘', 1),
#   ('요즘', 1),
#   ('한파', 1),
#   ('술안주', 1),
#   ('리뷰', 1),
#   ('적극', 1),
#   ('추천', 1),
#   ('김치찌개', 1),
#   ('고추장찌개', 1),
#   ('닭', 1),
#   ('음식', 1),
#   ('이', 1),
#   ('대용', 1),
#   ('강추', 1),
#   ('움직', 1),
#   ('이지', 1)],
#  [('점심', 5),
#   ('짬뽕', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('식사', 2),
#   ('날씨', 1),
#   ('이면', 1),
#   ('음식', 1),
#   ('생각', 1),
#   ('원래', 1),
#   ('부터', 1),
#   ('아해', 1),
#   ('자주', 1),
#   ('요즘', 1),
#   ('더', 1),
#   ('카스', 1),
#   ('제동', 1),
#   ('사랑', 1),
#   ('와이파이', 1),
#   ('고', 1),
#   ('둥이', 1)],
#  [('혼밥', 3),
#   ('메뉴', 3),
#   ('인천', 1),
#   ('추천', 1),
#   ('날', 1),
#   ('국밥', 1),
#   ('그릇', 1),
#   ('로', 1),
#   ('음식', 1),
#   ('즐겨드', 1),
#   ('시나', 1),
#   ('저', 1),
#   ('오늘', 1),
#   ('고민', 1),
#   ('중', 1),
#   ('동네', 1),
#   ('갈비찜', 1),
#   ('곽만근', 1),
#   ('갈비탕', 1),
#   ('집', 1),
#   ('인천광역시', 1),
#   ('서구', 1),
#   ('원', 1),
#   ('당대', 1),
#   ('완', 1),
#   ('정역', 1),
#   ('다이소', 1),
#   ('라인', 1),
#   ('위치', 1),
#   ('어요', 1),
#   ('매일', 1)],
#  [('전집', 5),
#   ('날', 2),
#   ('마곡', 2),
#   ('나루', 2),
#   ('추천', 2),
#   ('그날', 2),
#   ('날씨', 2),
#   ('요즘', 2),
#   ('것', 2),
#   ('업무', 1),
#   ('왕', 1),
#   ('일반', 1),
#   ('막걸리', 1),
#   ('한잔', 1),
#   ('때', 1),
#   ('방문', 1),
#   ('업', 1),
#   ('무왕', 1)],
#  [('디', 2),
#   ('갈비탕', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('로', 2),
#   ('추천', 2),
#   ('겨울', 2),
#   ('육', 1),
#   ('간청', 1),
#   ('날', 1),
#   ('해', 1),
#   ('요즘', 1),
#   ('그나', 1),
#   ('마', 1),
#   ('만하', 1),
#   ('고', 1),
#   ('집', 1),
#   ('출근', 1),
#   ('몸', 1),
#   ('마음', 1),
#   ('녹', 1),
#   ('여보', 1),
#   ('요', 1),
#   ('구로', 1),
#   ('디지털', 1),
#   ('단지', 1),
#   ('뒤뚱뒤뚱', 1)],
#  [('날', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('등촌', 2),
#   ('샤브', 2),
#   ('칼국수', 2),
#   ('추천', 1),
#   ('은', 1),
#   ('말', 1),
#   ('뭐해', 1),
#   ('시원', 1),
#   ('면서', 1),
#   ('칼칼', 1),
#   ('육수', 1),
#   ('고민', 1),
#   ('고고', 1),
#   ('또', 1),
#   ('하나', 1),
#   ('매력', 1),
#   ('바로', 1),
#   ('볶음밥', 1),
#   ('주저', 1),
#   ('설겆', 1),
#   ('필요', 1),
#   ('만큼', 1),
#   ('쌱', 1),
#   ('맛', 1),
#   ('어요', 1),
#   ('평택', 1),
#   ('피부', 1),
#   ('앤', 1),
#   ('클린', 1)],
#  [('메뉴', 3),
#   ('광화문', 2),
#   ('종로', 2),
#   ('추천', 2),
#   ('디', 2),
#   ('타워', 2),
#   ('맛집', 1),
#   ('날', 1),
#   ('점심', 1),
#   ('영업', 1),
#   ('시간', 1),
#   ('판', 1),
#   ('날씨', 1),
#   ('요즘', 1),
#   ('길거리', 1),
#   ('포장마차', 1),
#   ('어가', 1),
#   ('어묵국', 1),
#   ('물', 1),
#   ('매콤', 1),
#   ('떡볶이', 1),
#   ('기억', 1),
#   ('간식', 1),
#   ('로', 1),
#   ('로라', 1),
#   ('방앗간', 1),
#   ('점', 1),
#   ('위치', 1),
#   ('서울', 1),
#   ('종로구', 1),
#   ('길', 1),
#   ('층', 1),
#   ('소호', 1),
#   ('거리', 1),
#   ('호', 1),
#   ('또박', 1),
#   ('행복', 1),
#   ('육아', 1),
#   ('여행', 1)],
#  [('날', 4),
#   ('신설', 1),
#   ('맛집', 1),
#   ('제주', 1),
#   ('맛', 1),
#   ('재벌', 1),
#   ('국수', 1),
#   ('번', 1),
#   ('추천', 1),
#   ('낮', 1),
#   ('기온', 1),
#   ('영하', 1),
#   ('도', 1),
#   ('안팍', 1),
#   ('겨울', 1),
#   ('카페', 1),
#   ('문틈', 1),
#   ('찬', 1),
#   ('바람', 1),
#   ('정도', 1),
#   ('날씨', 1),
#   ('국물', 1),
#   ('토요일', 1),
#   ('오후', 1)],
#  [('짬뽕', 7),
#   ('날', 4),
#   ('그릇', 3),
#   ('점심', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('단무지', 1),
#   ('양파', 1),
#   ('적당', 1),
#   ('접시', 1),
#   ('주문', 1),
#   ('제주도', 1),
#   ('여행', 1),
#   ('관련', 1),
#   ('정보', 1),
#   ('관광지', 1),
#   ('맛집', 1),
#   ('숙소', 1),
#   ('렌트', 1)],
#  [('밀키', 5),
#   ('트', 5),
#   ('밀', 4),
#   ('날', 2),
#   ('스', 2),
#   ('어묵', 2),
#   ('전골', 2),
#   ('추천', 2),
#   ('해', 2),
#   ('외식', 2),
#   ('메뉴', 2),
#   ('주문', 2),
#   ('걱정', 1),
#   ('시기', 1),
#   ('지니', 1),
#   ('특별', 1),
#   ('때', 1),
#   ('키트', 1),
#   ('이번', 1),
#   ('중', 1),
#   ('이웃', 1),
#   ('세상', 1),
#   ('속', 1)],
#  [('홍대', 3),
#   ('날', 3),
#   ('골', 3),
#   ('맛집', 2),
#   ('추천', 2),
#   ('제격', 2),
#   ('순대', 1),
#   ('만두전골', 1),
#   ('요즘', 1),
#   ('진짜', 1),
#   ('춥다', 1),
#   ('어도', 1),
#   ('몸', 1),
#   ('덜덜', 1),
#   ('날씨', 1),
#   ('술', 1),
#   ('술술', 1),
#   ('맛', 1),
#   ('이지', 1),
#   ('저', 1),
#   ('콜라', 1),
#   ('었던', 1),
#   ('제일', 1)],
#  [('날', 4),
#   ('김치', 2),
#   ('뚝배기', 2),
#   ('우동', 2),
#   ('추천', 2),
#   ('수제', 1),
#   ('돈까스', 1),
#   ('마곡', 1),
#   ('직장인', 1),
#   ('사장', 1),
#   ('센스', 1),
#   ('테이블', 1),
#   ('마다', 1),
#   ('종이컵', 1),
#   ('그라인더', 1),
#   ('소금', 1),
#   ('후추', 1),
#   ('준비', 1),
#   ('어요', 1),
#   ('메뉴', 1),
#   ('술', 1),
#   ('다음', 1),
#   ('매콤', 1),
#   ('게', 1),
#   ('무조건', 1),
#   ('국물', 1),
#   ('일단', 1),
#   ('정말', 1),
#   ('시나', 1)],
#  [('만복', 3),
#   ('국수', 3),
#   ('집', 3),
#   ('멸치', 3),
#   ('날', 2),
#   ('쌀국수', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('잔치국수', 2),
#   ('마포', 1),
#   ('직장인', 1),
#   ('점심', 1),
#   ('강력', 1),
#   ('간날', 1),
#   ('구내식당', 1),
#   ('밥', 1),
#   ('질리', 1),
#   ('바람', 1),
#   ('휭휭', 1),
#   ('불어', 1),
#   ('레트로', 1),
#   ('식당', 1),
#   ('육수', 1),
#   ('오작교', 1),
#   ('통신', 1),
#   ('라이프', 1),
#   ('스토리', 1)],
#  [('날', 3),
#   ('포', 3),
#   ('메인', 3),
#   ('쌀국수', 2),
#   ('레드', 2),
#   ('구월', 2),
#   ('점', 2),
#   ('메뉴', 2),
#   ('한번', 2),
#   ('구월동', 1),
#   ('추천', 1),
#   ('미리', 1),
#   ('를', 1),
#   ('보고', 1),
#   ('가시', 1),
#   ('판', 1),
#   ('사진', 1),
#   ('드립', 1),
#   ('방', 1),
#   ('문해', 1),
#   ('보시', 1),
#   ('길', 1),
#   ('저', 1),
#   ('날씨', 1),
#   ('자주', 1),
#   ('편', 1),
#   ('정말', 1),
#   ('임용', 1),
#   ('동쓰', 1)],
#  [('떡볶이', 3),
#   ('날', 2),
#   ('청년', 2),
#   ('다방', 2),
#   ('추천', 2),
#   ('즉석', 2),
#   ('아주', 2),
#   ('차돌', 1),
#   ('먹기', 1),
#   ('강원', 1),
#   ('인제', 1),
#   ('점', 1),
#   ('메뉴', 1),
#   ('슬라이드', 1),
#   ('종류', 1),
#   ('치킨', 1),
#   ('이나', 1),
#   ('사이드', 1),
#   ('어요', 1),
#   ('몇', 1),
#   ('년', 1),
#   ('전', 1),
#   ('오랜만', 1),
#   ('었는데', 1),
#   ('만족', 1),
#   ('체험', 1),
#   ('보고서', 1)],
#  [('추천', 3),
#   ('날', 2),
#   ('생각', 2),
#   ('칼국수', 2),
#   ('맛집', 2),
#   ('저절로', 1),
#   ('샤브샤브', 1),
#   ('현지', 1),
#   ('따끈따끈', 1),
#   ('동해', 1),
#   ('등촌', 1),
#   ('샤브', 1),
#   ('수요일', 1),
#   ('정기', 1),
#   ('휴무', 1),
#   ('고등학생', 1),
#   ('시절', 1),
#   ('부터', 1),
#   ('곳', 1),
#   ('약', 1),
#   ('지나', 1),
#   ('가보', 1),
#   ('나', 1),
#   ('뭐', 1),
#   ('늦', 1),
#   ('더라도', 1),
#   ('거지', 1),
#   ('라챠챠', 1)],
#  [('수육', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('때', 2),
#   ('소고기', 1),
#   ('만들기', 1),
#   ('어린이', 1),
#   ('보양식', 1),
#   ('메뉴', 1),
#   ('육수', 1),
#   ('소스', 1),
#   ('살짝', 1),
#   ('어른', 1),
#   ('용', 1),
#   ('고기', 1),
#   ('육개장', 1),
#   ('온', 1),
#   ('가족', 1),
#   ('보양', 1),
#   ('코스트코', 1),
#   ('덩이', 1),
#   ('쟁여놨', 1),
#   ('다가', 1),
#   ('시간', 1),
#   ('푹', 1),
#   ('여서', 1),
#   ('김', 1),
#   ('엄마', 1),
#   ('헤롱', 1),
#   ('로그', 1)],
#  [('추천', 2),
#   ('날', 2),
#   ('매콤', 2),
#   ('짬뽕', 2),
#   ('오늘', 2),
#   ('가디', 1),
#   ('역', 1),
#   ('맛집', 1),
#   ('홍콩', 1),
#   ('반점', 1),
#   ('안녕', 1),
#   ('여러분', 1),
#   ('급격', 1),
#   ('날씨', 1),
#   ('자연', 1),
#   ('게', 1),
#   ('요즘', 1),
#   ('요', 1),
#   ('저', 1),
#   ('눈', 1),
#   ('감', 1),
#   ('동료', 1),
#   ('중식', 1),
#   ('점심', 1),
#   ('메뉴', 1),
#   ('로', 1),
#   ('도서', 1),
#   ('출판', 1),
#   ('지식', 1),
#   ('과감', 1),
#   ('성', 1),
#   ('공식', 1),
#   ('블로그', 1)],
#  [('만두', 3),
#   ('추천', 3),
#   ('날', 2),
#   ('칼국수', 2),
#   ('국물', 2),
#   ('온정', 1),
#   ('손', 1),
#   ('호', 1),
#   ('매실', 1),
#   ('점', 1),
#   ('겨울', 1),
#   ('요즘', 1),
#   ('날씨', 1),
#   ('때', 1),
#   ('방문', 1),
#   ('식당', 1),
#   ('살짝', 1),
#   ('더더', 1),
#   ('담', 1),
#   ('맛', 1),
#   ('요', 1),
#   ('메뉴', 1),
#   ('행복', 1),
#   ('블로그', 1)],
#  [('메뉴', 2),
#   ('테이블', 2),
#   ('인용', 2),
#   ('성수', 1),
#   ('완당', 1),
#   ('날', 1),
#   ('더', 1),
#   ('맛', 1),
#   ('조합', 1),
#   ('추천', 1),
#   ('내', 1),
#   ('산', 1),
#   ('어가', 1),
#   ('자마자', 1),
#   ('보이', 1),
#   ('키오', 1),
#   ('스크', 1),
#   ('간단', 1),
#   ('주문', 1),
#   ('가능', 1),
#   ('요', 1),
#   ('다른', 1),
#   ('도', 1),
#   ('도전', 1),
#   ('볼망', 1),
#   ('항상', 1),
#   ('고정', 1),
#   ('픽', 1),
#   ('역시', 1),
#   ('당면', 1),
#   ('공간', 1),
#   ('편', 1),
#   ('니지', 1),
#   ('바', 1),
#   ('골', 1),
#   ('고루', 1),
#   ('어요', 1),
#   ('일상', 1),
#   ('링', 1),
#   ('더하기', 1)],
#  [('강남', 4),
#   ('메뉴', 4),
#   ('점심', 3),
#   ('교자', 3),
#   ('직딩', 2),
#   ('로', 2),
#   ('칼국수', 2),
#   ('맛집', 2),
#   ('날', 1),
#   ('겨울', 1),
#   ('픽', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('뿐', 1),
#   ('설렁탕', 1),
#   ('막내', 1),
#   ('님들', 1),
#   ('남녀', 1),
#   ('노소', 1),
#   ('추천', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('스코어', 1)],
#  [('알탕', 5),
#   ('바다', 2),
#   ('황제', 2),
#   ('날', 1),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('로', 1),
#   ('듯', 1),
#   ('점심', 1),
#   ('날씨', 1),
#   ('뭔가', 1),
#   ('끈', 1),
#   ('국물', 1),
#   ('듬북', 1),
#   ('알', 1),
#   ('어간', 1),
#   ('어서', 1),
#   ('대흥동', 1),
#   ('해물', 1),
#   ('요리', 1),
#   ('전문점', 1),
#   ('선택', 1),
#   ('어요', 1),
#   ('여기', 1),
#   ('정식', 1),
#   ('인분', 1),
#   ('밑반찬', 1),
#   ('붓다', 1),
#   ('붓솝', 1)],
#  [('맛집', 6),
#   ('순대국', 5),
#   ('청라', 4),
#   ('진지', 2),
#   ('방', 2),
#   ('날', 2),
#   ('서구', 2),
#   ('먹기', 1),
#   ('국밥', 1),
#   ('수', 1),
#   ('요즘', 1),
#   ('국물', 1),
#   ('생각', 1),
#   ('거', 1),
#   ('집', 1),
#   ('번', 1),
#   ('추천', 1),
#   ('인천', 1),
#   ('봄', 1),
#   ('어요', 1)],
#  [('역삼동', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('호박', 2),
#   ('불고기', 2),
#   ('쌀국수', 2),
#   ('행복', 2),
#   ('고민', 2),
#   ('그릇', 1),
#   ('더니', 1),
#   ('점심시간', 1),
#   ('무엇', 1),
#   ('을지', 1),
#   ('항상', 1),
#   ('오늘', 1),
#   ('역시', 1),
#   ('저', 1),
#   ('덩치', 1),
#   ('거', 1),
#   ('덩', 1)],
#  [('메뉴', 3),
#   ('부산', 2),
#   ('옹심이', 2),
#   ('칼국수', 2),
#   ('날', 2),
#   ('정관', 1),
#   ('맛집', 1),
#   ('직원', 1),
#   ('분', 1),
#   ('추천', 1),
#   ('궁금', 1),
#   ('매번', 1),
#   ('고하', 1),
#   ('다가', 1),
#   ('그냥', 1),
#   ('어서', 1),
#   ('요즘', 1),
#   ('처럼', 1),
#   ('은', 1),
#   ('끈', 1),
#   ('제일', 1),
#   ('어가', 1),
#   ('면도', 1),
#   ('러블', 1),
#   ('리수', 1),
#   ('지니', 1),
#   ('달달', 1),
#   ('하루', 1)],
#  [('날', 2),
#   ('만', 2),
#   ('나기', 2),
#   ('장소', 2),
#   ('맛집', 2),
#   ('호호', 2),
#   ('식당', 2),
#   ('셋', 2),
#   ('개', 2),
#   ('약속', 1),
#   ('터', 1),
#   ('일본', 1),
#   ('가정', 1),
#   ('식', 1),
#   ('은', 1),
#   ('우리', 1),
#   ('중간지점', 1),
#   ('쯤', 1),
#   ('이기', 1),
#   ('해', 1),
#   ('리스트', 1),
#   ('여러', 1),
#   ('이서', 1),
#   ('메뉴', 1),
#   ('어요', 1),
#   ('우나기', 1),
#   ('명란', 1),
#   ('파스타', 1),
#   ('오므라이스', 1),
#   ('뭔가', 1),
#   ('좀', 1),
#   ('진짜', 1),
#   ('찍찍', 1),
#   ('부인', 1),
#   ('이야기', 1)],
#  [('구이', 4),
#   ('날', 3),
#   ('도루묵', 2),
#   ('시', 2),
#   ('사모', 2),
#   ('생각', 2),
#   ('곳', 2),
#   ('낮', 2),
#   ('알', 1),
#   ('여기', 1),
#   ('방문', 1),
#   ('거의', 1),
#   ('만석', 1),
#   ('여전', 1),
#   ('인기', 1),
#   ('깜짝', 1),
#   ('전', 1),
#   ('문적', 1),
#   ('메뉴', 1),
#   ('수', 1),
#   ('어서', 1),
#   ('을지', 1),
#   ('오뎅', 1),
#   ('추천', 1)],
#  [('부대찌개', 5),
#   ('날', 2),
#   ('짐', 2),
#   ('간편', 2),
#   ('햄', 2),
#   ('고기', 2),
#   ('듬뿍', 2),
#   ('요리', 2),
#   ('글', 1),
#   ('사진', 1),
#   ('뚜', 1),
#   ('날씨', 1),
#   ('지고', 1),
#   ('자꾸만', 1),
#   ('국물', 1),
#   ('여러', 1),
#   ('가지', 1),
#   ('아이', 1),
#   ('우리', 1),
#   ('집', 1),
#   ('단골', 1),
#   ('메뉴', 1),
#   ('수요일', 1),
#   ('수아', 1),
#   ('일상', 1)],
#  [('점심', 2),
#   ('메뉴', 2),
#   ('맛집', 2),
#   ('날', 1),
#   ('추천', 1),
#   ('종로', 1),
#   ('칼국수', 1),
#   ('대원', 1),
#   ('겨울', 1),
#   ('진짜', 1),
#   ('오늘', 1),
#   ('신지', 1),
#   ('김치', 1),
#   ('최고', 1),
#   ('어요', 1),
#   ('포스팅', 1),
#   ('면서', 1),
#   ('보', 1),
#   ('또', 1),
#   ('생각', 1),
#   ('데', 1),
#   ('국물', 1),
#   ('의', 1),
#   ('블로그', 1)],
#  [('추어탕', 4),
#   ('날', 3),
#   ('생각', 2),
#   ('다가', 2),
#   ('구리', 1),
#   ('갈매동', 1),
#   ('맛집', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('날씨', 1),
#   ('보양식', 1),
#   ('더', 1),
#   ('별내', 1),
#   ('터', 1),
#   ('가시', 1),
#   ('길', 1),
#   ('추천', 1),
#   ('파서', 1),
#   ('메뉴', 1),
#   ('판도', 1),
#   ('하나', 1),
#   ('여', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('일상', 1),
#   ('크리', 1),
#   ('슈어', 1)],
#  [('날', 3),
#   ('애호박', 3),
#   ('칼국수', 3),
#   ('동리', 3),
#   ('장', 2),
#   ('레트로', 1),
#   ('감성', 1),
#   ('마포역', 1),
#   ('술집', 1),
#   ('요즘', 1),
#   ('국물', 1),
#   ('고요', 1),
#   ('장의', 1),
#   ('메뉴', 1),
#   ('판이', 1),
#   ('주로', 1),
#   ('애', 1),
#   ('호박찌개', 1),
#   ('꼬막', 1),
#   ('비빔밥', 1),
#   ('수육', 1),
#   ('전이', 1),
#   ('루나', 1),
#   ('나나', 1)],
#  [('칼국수', 3),
#   ('서초', 2),
#   ('날', 2),
#   ('생각', 2),
#   ('백합', 2),
#   ('이야기', 1),
#   ('지난번', 1),
#   ('교', 1),
#   ('대쪽', 1),
#   ('약속', 1),
#   ('어서', 1),
#   ('오늘', 1),
#   ('식', 1),
#   ('사류', 1),
#   ('대표', 1),
#   ('메뉴', 1),
#   ('인', 1),
#   ('탕', 1),
#   ('구이', 1),
#   ('볶음', 1),
#   ('분', 1),
#   ('위', 1),
#   ('가용', 1),
#   ('여행가', 1),
#   ('용', 1)],
#  [('날', 4),
#   ('반', 2),
#   ('성남', 1),
#   ('분당', 1),
#   ('도', 1),
#   ('평가', 1),
#   ('옥', 1),
#   ('평냉', 1),
#   ('평양', 1),
#   ('냉면', 1),
#   ('은', 1),
#   ('닭고기', 1),
#   ('추천', 1),
#   ('봄', 1),
#   ('왜', 1),
#   ('요즘', 1),
#   ('저녁', 1),
#   ('으슬으', 1),
#   ('슬하', 1),
#   ('예의', 1),
#   ('상', 1),
#   ('메뉴', 1),
#   ('월급', 1),
#   ('시절', 1),
#   ('어복', 1),
#   ('쟁반', 1),
#   ('기분', 1),
#   ('젠', 1),
#   ('뭐', 1),
#   ('지도', 1),
#   ('못', 1)],
#  [('맛집', 4),
#   ('생각', 4),
#   ('원마운트', 3),
#   ('국밥', 3),
#   ('더', 2),
#   ('대화동', 2),
#   ('날', 1),
#   ('한식', 1),
#   ('메뉴', 1),
#   ('인', 1),
#   ('것', 1),
#   ('저희', 1),
#   ('조만간', 1),
#   ('한번', 1),
#   ('출동', 1),
#   ('예정', 1),
#   ('계시', 1),
#   ('분', 1),
#   ('점', 1),
#   ('추천', 1),
#   ('행자', 1),
#   ('쫄깃', 1),
#   ('공간', 1)],
#  [('저녁', 3),
#   ('갈치조림', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('날', 1),
#   ('이웃', 1),
#   ('님들', 1),
#   ('겨울', 1),
#   ('저', 1),
#   ('꽤', 1),
#   ('맛', 1),
#   ('어요', 1),
#   ('갈치', 1),
#   ('고소', 1),
#   ('것', 1),
#   ('또', 1),
#   ('양념', 1),
#   ('베', 1),
#   ('어서', 1),
#   ('달달', 1),
#   ('워', 1),
#   ('너비', 1),
#   ('블링', 1)],
#  [('간단', 3),
#   ('메뉴', 3),
#   ('국', 2),
#   ('이기', 2),
#   ('날', 2),
#   ('술', 2),
#   ('오뎅', 1),
#   ('최고', 1),
#   ('로', 1),
#   ('추천', 1),
#   ('해', 1),
#   ('나', 1),
#   ('요즘', 1),
#   ('뚝딱', 1),
#   ('내심', 1),
#   ('모두', 1),
#   ('재료', 1),
#   ('어묵', 1),
#   ('봉지', 1),
#   ('멸치', 1),
#   ('다시마', 1),
#   ('육수', 1),
#   ('무', 1),
#   ('개', 1),
#   ('대파', 1),
#   ('쑥갓', 1),
#   ('약간', 1),
#   ('간장', 1),
#   ('마늘', 1),
#   ('그녀', 1),
#   ('이야기', 1)],
#  [('이비가', 3),
#   ('날', 2),
#   ('짬뽕', 2),
#   ('면', 2),
#   ('점심', 1),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('대전', 1),
#   ('맛집', 1),
#   ('원래', 1),
#   ('아하', 1),
#   ('기도', 1),
#   ('은', 1),
#   ('역시', 1),
#   ('생각', 1),
#   ('요', 1),
#   ('둔산동', 1),
#   ('본점', 1),
#   ('최근', 1),
#   ('속도', 1),
#   ('체인점', 1),
#   ('늘', 1),
#   ('어가', 1),
#   ('카레', 1),
#   ('보이', 1),
#   ('것', 1),
#   ('아로마테라피', 1),
#   ('스튜디오', 1)],
#  [('고흥', 6),
#   ('맛집', 4),
#   ('갈비탕', 3),
#   ('날', 2),
#   ('생각', 2),
#   ('국물', 2),
#   ('관광', 2),
#   ('이면', 1),
#   ('양산박', 1),
#   ('안녕', 1),
#   ('청년', 1),
#   ('박', 1),
#   ('두', 1),
#   ('메뉴', 1),
#   ('모두', 1),
#   ('포장', 1),
#   ('가능', 1),
#   ('온', 1),
#   ('가족', 1),
#   ('수', 1),
#   ('추천', 1),
#   ('합', 1),
#   ('공식', 1),
#   ('블로그', 1),
#   ('여행', 1)],
#  [('추천', 3),
#   ('날', 2),
#   ('메뉴', 2),
#   ('만두전골', 2),
#   ('북적', 2),
#   ('이', 2),
#   ('범계', 1),
#   ('성경', 1),
#   ('만두', 1),
#   ('요리', 1),
#   ('전문점', 1),
#   ('분', 1),
#   ('로', 1),
#   ('택', 1),
#   ('점심시간', 1),
#   ('전부', 1),
#   ('터', 1),
#   ('예약', 1),
#   ('석도', 1),
#   ('동생', 1),
#   ('먼저', 1),
#   ('준', 1),
#   ('곳', 1),
#   ('요', 1),
#   ('저', 1),
#   ('는걸', 1),
#   ('먹기', 1),
#   ('위해', 1),
#   ('쯔모', 1),
#   ('욧', 1)],
#  [('맛집', 2),
#   ('바다', 2),
#   ('양푼', 2),
#   ('동태', 2),
#   ('탕', 2),
#   ('날', 2),
#   ('용인', 1),
#   ('점', 1),
#   ('어탕', 1),
#   ('더더', 1),
#   ('겨울', 1),
#   ('한번', 1),
#   ('만족', 1),
#   ('메뉴', 1),
#   ('수제비', 1),
#   ('면서', 1),
#   ('추천', 1),
#   ('남편', 1),
#   ('으쓱', 1),
#   ('어요', 1),
#   ('마을', 1),
#   ('이기', 1),
#   ('냠삐공', 1),
#   ('특공대', 1)],
#  [('날', 4),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('오늘', 2),
#   ('매콤', 2),
#   ('낙지볶음', 2),
#   ('아주', 1),
#   ('씨', 1),
#   ('거나', 1),
#   ('국물', 1),
#   ('생각', 1),
#   ('드릴', 1),
#   ('피로', 1),
#   ('몸', 1),
#   ('시원', 1),
#   ('냉국', 1),
#   ('연우', 1),
#   ('컴퓨터', 1)],
#  [('여수', 2),
#   ('전집', 2),
#   ('메뉴', 2),
#   ('다양', 2),
#   ('가장', 2),
#   ('청담', 1),
#   ('앤전', 1),
#   ('날', 1),
#   ('분위기', 1),
#   ('여서동', 1),
#   ('술집', 1),
#   ('추천', 1),
#   ('안주', 1),
#   ('까지', 1),
#   ('편이', 1),
#   ('부분', 1),
#   ('신기', 1),
#   ('술', 1),
#   ('점', 1),
#   ('답', 1),
#   ('막걸리', 1),
#   ('전통주', 1),
#   ('하이', 1),
#   ('볼', 1),
#   ('소주', 1),
#   ('종류', 1),
#   ('우리', 1),
#   ('인기', 1),
#   ('중', 1),
#   ('하나라', 1),
#   ('오늘', 1),
#   ('안녕', 1)],
#  [('감자탕', 3),
#   ('회기역', 2),
#   ('맛집', 2),
#   ('날', 2),
#   ('만두', 2),
#   ('아라하', 2),
#   ('칼국수', 2),
#   ('역시', 1),
#   ('사람', 1),
#   ('마음', 1),
#   ('모두', 1),
#   ('저', 1),
#   ('위', 1),
#   ('메뉴', 1),
#   ('사골국', 1),
#   ('도시', 1)],
#  [('날', 3),
#   ('점심', 3),
#   ('추천', 3),
#   ('연우', 3),
#   ('컴퓨터', 3),
#   ('메뉴', 2),
#   ('안녕', 1),
#   ('전자랜드', 1),
#   ('날씨', 1),
#   ('매우', 1),
#   ('데', 1),
#   ('거', 1),
#   ('드', 1),
#   ('실지', 1),
#   ('한국', 1),
#   ('대표', 1),
#   ('음식', 1),
#   ('중', 1),
#   ('한가지', 1)],
#  [('날', 5),
#   ('비', 3),
#   ('충무로', 2),
#   ('닭', 2),
#   ('마리', 2),
#   ('평점', 2),
#   ('가격', 2),
#   ('천원', 2),
#   ('공릉', 1),
#   ('점', 1),
#   ('슴슴', 1),
#   ('및', 1),
#   ('주문', 1),
#   ('메뉴', 1),
#   ('네이버', 1),
#   ('만원', 1),
#   ('닭곰탕', 1),
#   ('추천', 1),
#   ('국물', 1),
#   ('때', 1),
#   ('명', 1),
#   ('정도', 1),
#   ('먹기', 1),
#   ('것', 1),
#   ('주로', 1),
#   ('이나', 1),
#   ('땅', 1),
#   ('이의', 1),
#   ('오늘', 1),
#   ('어디', 1)],
#  [('날', 3),
#   ('메뉴', 3),
#   ('로', 3),
#   ('수원', 2),
#   ('시청', 2),
#   ('앞', 2),
#   ('칼국수', 2),
#   ('점심', 2),
#   ('추천', 2),
#   ('나', 2),
#   ('가기', 2),
#   ('은', 1),
#   ('밥', 1),
#   ('음', 1),
#   ('대신', 1),
#   ('날씨', 1),
#   ('욕구', 1),
#   ('모두', 1),
#   ('만족', 1),
#   ('우리', 1),
#   ('아들', 1),
#   ('꼬', 1),
#   ('라지', 1),
#   ('이야기', 1)],
#  [('날', 3),
#   ('남편', 2),
#   ('마름', 2),
#   ('더', 1),
#   ('음식', 1),
#   ('샤브샤브', 1),
#   ('목포', 1),
#   ('월남쌈', 1),
#   ('샤브', 1),
#   ('전문점', 1),
#   ('이번', 1),
#   ('신랑', 1),
#   ('휴무', 1),
#   ('일', 1),
#   ('애', 1),
#   ('유치원', 1),
#   ('점심', 1),
#   ('자고', 1),
#   ('이야기', 1),
#   ('추천', 1),
#   ('배', 1),
#   ('꽃', 1),
#   ('자주', 1),
#   ('식당', 1),
#   ('세상', 1),
#   ('특별', 1),
#   ('존재', 1)],
#  [('블루', 3),
#   ('보틀', 3),
#   ('날', 3),
#   ('여의도', 2),
#   ('카페', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('웨이', 1),
#   ('팅', 1),
#   ('주차', 1),
#   ('팁', 1),
#   ('플로', 1),
#   ('트', 1),
#   ('더', 1),
#   ('현대', 1),
#   ('서울', 1),
#   ('글', 1),
#   ('사진', 1),
#   ('쥬', 1),
#   ('제이', 1),
#   ('맘', 1),
#   ('비', 1),
#   ('날씨', 1),
#   ('라떼', 1),
#   ('지금', 1),
#   ('여름', 1),
#   ('아이스커피', 1),
#   ('로', 1),
#   ('플루토', 1),
#   ('인기', 1)],
#  [('곰탕', 4),
#   ('날', 3),
#   ('상암동', 2),
#   ('골', 2),
#   ('나주', 2),
#   ('국물', 2),
#   ('맛집', 1),
#   ('때', 1),
#   ('상암', 1),
#   ('점', 1),
#   ('겨울', 1),
#   ('어서', 1),
#   ('돌솥밥', 1),
#   ('까지', 1),
#   ('수', 1),
#   ('곳', 1),
#   ('건강', 1),
#   ('챙', 1),
#   ('기고', 1),
#   ('식사', 1)],
#  [('날', 2),
#   ('생각', 2),
#   ('음식', 2),
#   ('조', 2),
#   ('마루', 2),
#   ('감자탕', 2),
#   ('상동역', 2),
#   ('회식', 2),
#   ('장소', 2),
#   ('추천', 2),
#   ('점', 1),
#   ('지극', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('리얼', 1),
#   ('후기', 1),
#   ('요즘', 1),
#   ('짐', 1),
#   ('양', 1),
#   ('김치', 1),
#   ('고', 1),
#   ('나위', 1),
#   ('맛', 1),
#   ('맛집', 1),
#   ('인정', 1),
#   ('외식', 1),
#   ('모임', 1),
#   ('몸', 1),
#   ('보신', 1),
#   ('노리', 1),
#   ('터', 1)],
#  [('맛', 3),
#   ('날', 2),
#   ('만두국', 2),
#   ('번', 2),
#   ('일산', 1),
#   ('평양', 1),
#   ('손', 1),
#   ('만두', 1),
#   ('그것', 1),
#   ('순서대로', 1),
#   ('것', 1),
#   ('고', 1),
#   ('막', 1),
#   ('씨', 1),
#   ('유명', 1),
#   ('집들이', 1),
#   ('그', 1),
#   ('러하', 1),
#   ('듯이', 1),
#   ('여러', 1),
#   ('가지', 1),
#   ('메뉴', 1),
#   ('그냥', 1),
#   ('중', 1),
#   ('주', 1),
#   ('인', 1),
#   ('모션', 1),
#   ('렌터카', 1),
#   ('보험사', 1),
#   ('고대', 1),
#   ('차', 1),
#   ('전문', 1),
#   ('기업', 1)],
#  [('맛집', 3),
#   ('서울', 2),
#   ('부대찌개', 2),
#   ('추천', 2),
#   ('하월곡동', 1),
#   ('날', 1),
#   ('밥', 1),
#   ('그릇', 1),
#   ('뚝딱', 1),
#   ('토요일', 1),
#   ('첫', 1),
#   ('해장', 1),
#   ('메뉴', 1),
#   ('인', 1),
#   ('성북구', 1),
#   ('주민', 1),
#   ('월곡역', 1),
#   ('번', 1),
#   ('출구', 1),
#   ('본점', 1),
#   ('내', 1),
#   ('한식', 1),
#   ('아해', 1),
#   ('건', 1),
#   ('이', 1),
#   ('집', 1),
#   ('지나', 1),
#   ('온', 1),
#   ('나날', 1),
#   ('기록', 1)],
#  [('메뉴', 4),
#   ('서울', 3),
#   ('데이트', 3),
#   ('맛집', 2),
#   ('더왓', 2),
#   ('에버', 2),
#   ('실내', 2),
#   ('카페', 2),
#   ('마곡역', 1),
#   ('날', 1),
#   ('음료', 1),
#   ('런치', 1),
#   ('디너', 1),
#   ('고', 1),
#   ('와인', 1),
#   ('낮', 1),
#   ('브런치', 1),
#   ('식사', 1),
#   ('가능', 1),
#   ('저녁', 1),
#   ('때', 1),
#   ('또', 1),
#   ('오기', 1),
#   ('약속', 1),
#   ('추천', 1),
#   ('앵두', 1),
#   ('로그', 1)],
#  [('수제비', 3),
#   ('점심', 3),
#   ('날', 2),
#   ('최고', 2),
#   ('메뉴', 2),
#   ('로', 2),
#   ('추천', 2),
#   ('계속', 1),
#   ('국물', 1),
#   ('오늘', 1),
#   ('사무실', 1),
#   ('듯', 1),
#   ('끼', 1),
#   ('이건', 1),
#   ('들깨', 1),
#   ('배달', 1),
#   ('민족', 1),
#   ('덕이', 1),
#   ('거기', 1),
#   ('고자', 1),
#   ('거', 1),
#   ('제일', 1)],
#  [('날', 3),
#   ('메뉴', 2),
#   ('용산', 1),
#   ('타파', 1),
#   ('코파', 1),
#   ('아직', 1),
#   ('때', 1),
#   ('친', 1),
#   ('구들', 1),
#   ('끼리', 1),
#   ('잡고', 1),
#   ('실컷', 1),
#   ('다가', 1),
#   ('마지막', 1),
#   ('안주', 1),
#   ('겸', 1),
#   ('요런', 1),
#   ('맛집', 1),
#   ('후기', 1),
#   ('보이', 1),
#   ('추천', 1),
#   ('고', 1),
#   ('설명', 1),
#   ('취향', 1),
#   ('것', 1),
#   ('금천', 1),
#   ('연세', 1),
#   ('치과', 1)],
#  [('호빵', 4),
#   ('추천', 3),
#   ('메뉴', 2),
#   ('적', 2),
#   ('날', 1),
#   ('역시', 1),
#   ('그', 1),
#   ('중', 1),
#   ('서도', 1),
#   ('친구', 1),
#   ('요즘', 1),
#   ('핫', 1),
#   ('삼립', 1),
#   ('저', 1),
#   ('가격', 1),
#   ('주관', 1),
#   ('맛', 1),
#   ('귀', 1),
#   ('여운', 1),
#   ('나유', 1),
#   ('크림', 1),
#   ('치즈', 1),
#   ('카스', 1),
#   ('타드', 1),
#   ('스', 1),
#   ('위트', 1),
#   ('슈크림', 1),
#   ('계란후라이', 1),
#   ('비', 1),
#   ('주얼', 1),
#   ('으랏차', 1),
#   ('차', 1),
#   ('운', 1),
#   ('동하', 1),
#   ('뚜', 1),
#   ('레이', 1),
#   ('너', 1)],
#  [('메뉴', 3),
#   ('로', 3),
#   ('부대찌개', 3),
#   ('날', 2),
#   ('점심', 2),
#   ('끼', 2),
#   ('해결', 2),
#   ('오늘', 1),
#   ('갑자기', 1),
#   ('어제', 1),
#   ('도나', 1),
#   ('아침', 1),
#   ('겨울', 1),
#   ('바로', 1),
#   ('포스팅', 1),
#   ('하니', 1),
#   ('벌써', 1),
#   ('두', 1),
#   ('시반', 1),
#   ('요', 1),
#   ('저녁', 1),
#   ('추천', 1),
#   ('전', 1),
#   ('일', 1),
#   ('지안', 1),
#   ('안경', 1),
#   ('젠틀', 1),
#   ('몬스터', 1),
#   ('모스', 1),
#   ('콧', 1),
#   ('용인', 1),
#   ('공식', 1),
#   ('매장', 1)],
#  [('점심', 2),
#   ('메뉴', 2),
#   ('날', 2),
#   ('국물', 2),
#   ('추천', 1),
#   ('오늘', 1),
#   ('뼈', 1),
#   ('귀', 1),
#   ('해장국', 1),
#   ('닷', 1),
#   ('내', 1),
#   ('워', 1),
#   ('너비', 1),
#   ('어서', 1),
#   ('자주', 1),
#   ('어가', 1),
#   ('행복', 1),
#   ('고요', 1),
#   ('우거지', 1),
#   ('고기', 1),
#   ('짐', 1),
#   ('하니', 1),
#   ('까지', 1),
#   ('한사', 1),
#   ('발', 1),
#   ('드링킹', 1),
#   ('잠', 1),
#   ('솔솔', 1),
#   ('감성', 1),
#   ('드림', 1),
#   ('블로그', 1)],
#  [('날', 4),
#   ('사케', 4),
#   ('안주', 4),
#   ('뜻', 3),
#   ('한사', 3),
#   ('케', 3),
#   ('추천', 3),
#   ('한잔', 2),
#   ('마시기', 1),
#   ('겨울', 1),
#   ('정원', 1),
#   ('잔', 1),
#   ('것', 1),
#   ('아하', 1),
#   ('오늘', 1),
#   ('더', 1),
#   ('청정', 1),
#   ('원', 1),
#   ('블로그', 1)],
#  [('날', 2),
#   ('가장', 2),
#   ('메뉴', 2),
#   ('감자탕', 2),
#   ('국물', 2),
#   ('고요', 2),
#   ('애정', 1),
#   ('남', 1),
#   ('다른', 1),
#   ('잇님들', 1),
#   ('아하', 1),
#   ('뭔가', 1),
#   ('거의', 1),
#   ('모두', 1),
#   ('생각', 1),
#   ('듯', 1),
#   ('추천', 1),
#   ('실제', 1),
#   ('가보', 1),
#   ('점심시간', 1),
#   ('사람', 1),
#   ('꽉', 1),
#   ('저', 1),
#   ('제', 1),
#   ('친구', 1),
#   ('기본', 1),
#   ('블리콩', 1)],
#  [('칼국수', 3),
#   ('대구', 2),
#   ('수성구', 2),
#   ('조조', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('시원', 2),
#   ('조개', 2),
#   ('간장', 2),
#   ('낙지', 1),
#   ('해물파전', 1),
#   ('고', 1),
#   ('물총', 1),
#   ('겉절이', 1),
#   ('김치', 1),
#   ('그다지', 1),
#   ('맵', 1),
#   ('청양고추', 1),
#   ('된장', 1),
#   ('초장', 1),
#   ('와사비', 1),
#   ('양념', 1),
#   ('막걸리', 1),
#   ('메뉴판', 1),
#   ('오감', 1),
#   ('만족도', 1),
#   ('토미', 1)],
#  [('날', 2),
#   ('집밥', 2),
#   ('순두부찌개', 2),
#   ('집', 2),
#   ('아빠', 2),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('간단', 1),
#   ('버섯', 1),
#   ('만들기', 1),
#   ('오늘', 1),
#   ('생각', 1),
#   ('중', 1),
#   ('어서', 1),
#   ('어요', 1),
#   ('오시', 1),
#   ('기', 1),
#   ('전', 1),
#   ('얼른', 1),
#   ('사진', 1),
#   ('엄마', 1),
#   ('저녁', 1),
#   ('식사', 1),
#   ('눈', 1),
#   ('녹지', 1)],
#  [('감자탕', 3),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('사당', 2),
#   ('주문', 2),
#   ('해도', 2),
#   ('날', 1),
#   ('김', 1),
#   ('채원', 1),
#   ('회식', 1),
#   ('장소', 1),
#   ('만', 1),
#   ('새마을', 1),
#   ('식당', 1),
#   ('자리', 1),
#   ('사당역', 1),
#   ('번', 1),
#   ('출구', 1),
#   ('식사', 1),
#   ('로', 1),
#   ('뼈', 1),
#   ('해장국', 1),
#   ('김치찜', 1),
#   ('알밥', 1),
#   ('준비', 1),
#   ('명', 1),
#   ('이상', 1),
#   ('때', 1),
#   ('메인', 1),
#   ('여행', 1),
#   ('속', 1),
#   ('맛집', 1),
#   ('체험', 1),
#   ('곳', 1)],
#  [('점심', 4),
#   ('메뉴', 4),
#   ('소고기', 4),
#   ('국밥', 4),
#   ('날', 3),
#   ('추천', 2),
#   ('직장', 1),
#   ('동료', 1),
#   ('완전', 1),
#   ('강추', 1),
#   ('직장인', 1),
#   ('점심시간', 1),
#   ('로', 1),
#   ('음식', 1)],
#  [('날', 3),
#   ('심옥', 2),
#   ('갈비탕', 2),
#   ('추천', 2),
#   ('시지', 1),
#   ('맛집', 1),
#   ('메뉴', 1),
#   ('가격', 1),
#   ('기본', 1),
#   ('찬', 1),
#   ('간', 1),
#   ('단합', 1),
#   ('석', 1),
#   ('박지', 1),
#   ('백김치', 1),
#   ('주시', 1),
#   ('데', 1),
#   ('삼삼', 1),
#   ('하니', 1),
#   ('항상', 1),
#   ('어른', 1),
#   ('모시', 1),
#   ('식', 1),
#   ('사하', 1),
#   ('기도', 1),
#   ('다른', 1),
#   ('사진', 1),
#   ('의', 1),
#   ('양', 1)],
#  [('점심', 3),
#   ('메뉴', 3),
#   ('날', 2),
#   ('추천', 2),
#   ('가지', 2),
#   ('음식', 2),
#   ('어제', 2),
#   ('로', 1),
#   ('뭐', 1),
#   ('주말', 1),
#   ('창문', 1),
#   ('뒤', 1),
#   ('칼', 1),
#   ('바람', 1),
#   ('치', 1),
#   ('더니', 1),
#   ('오늘', 1),
#   ('아침', 1),
#   ('목덜미', 1),
#   ('릿', 1),
#   ('기온', 1),
#   ('가을', 1),
#   ('감', 1),
#   ('것', 1),
#   ('룻', 1),
#   ('동안', 1),
#   ('외출', 1),
#   ('판다', 1)],
#  [('날', 2),
#   ('고기', 2),
#   ('저', 2),
#   ('완전', 2),
#   ('소스', 2),
#   ('전골', 1),
#   ('수육', 1),
#   ('추천', 1),
#   ('몸', 1),
#   ('보신', 1),
#   ('복날', 1),
#   ('음식', 1),
#   ('최고', 1),
#   ('주차장', 1),
#   ('정보', 1),
#   ('메뉴', 1),
#   ('선택', 1),
#   ('정말', 1),
#   ('탁월', 1),
#   ('염소', 1),
#   ('어가', 1),
#   ('양념장', 1),
#   ('비법', 1),
#   ('감칠맛', 1),
#   ('뿜뿜', 1),
#   ('능', 1),
#   ('그냥', 1),
#   ('어도', 1),
#   ('양념', 1),
#   ('도', 1),
#   ('찰떡', 1),
#   ('었다', 1),
#   ('나중', 1),
#   ('볶음밥', 1)],
#  [('점심', 6),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('뭐', 3),
#   ('날', 2),
#   ('고민', 2),
#   ('너', 2),
#   ('정', 2),
#   ('그릇', 2),
#   ('다가', 1),
#   ('오늘', 1),
#   ('동한', 1),
#   ('뭔가', 1),
#   ('국물', 1),
#   ('요즘', 1),
#   ('분식집', 1),
#   ('아주', 1),
#   ('좌충우돌', 1),
#   ('부산', 1),
#   ('행', 1),
#   ('블로그', 1)],
#  [('날', 3),
#   ('저녁', 2),
#   ('메뉴', 2),
#   ('로', 2),
#   ('회', 2),
#   ('배달', 2),
#   ('어요', 1),
#   ('이야기', 1),
#   ('해', 1),
#   ('역시', 1),
#   ('회도', 1),
#   ('굴', 1),
#   ('꼬막', 1),
#   ('등', 1),
#   ('급', 1),
#   ('추천', 1),
#   ('상', 1),
#   ('차려', 1),
#   ('나름', 1),
#   ('집', 1),
#   ('한잔', 1),
#   ('오늘', 1),
#   ('비', 1),
#   ('까지', 1),
#   ('남매', 1),
#   ('일상', 1)],
#  [('라멘', 4),
#   ('날', 3),
#   ('메뉴', 3),
#   ('요즘', 2),
#   ('추천', 2),
#   ('코', 2),
#   ('끈', 1),
#   ('부천', 1),
#   ('맛집', 1),
#   ('간단', 1),
#   ('메인', 1),
#   ('세', 1),
#   ('가지', 1),
#   ('오리', 1),
#   ('매', 1),
#   ('운라', 1),
#   ('고', 1),
#   ('차슈', 1),
#   ('덮밥', 1),
#   ('진짜진짜', 1),
#   ('다음', 1),
#   ('또', 1),
#   ('가야', 1),
#   ('쥐', 1),
#   ('부천역', 1),
#   ('점', 1),
#   ('그릇', 1),
#   ('오늘', 1),
#   ('여행지', 1),
#   ('수', 1)],
#  [('점심', 4),
#   ('오늘', 3),
#   ('날', 3),
#   ('메뉴', 3),
#   ('뭐', 2),
#   ('콩나물', 2),
#   ('동태찌개', 2),
#   ('추천', 2),
#   ('것', 2),
#   ('로', 1),
#   ('몸속', 1),
#   ('까지', 1),
#   ('처럼', 1),
#   ('찬', 1),
#   ('바람', 1),
#   ('를', 1),
#   ('고민', 1),
#   ('밖', 1),
#   ('또한', 1),
#   ('직장인', 1),
#   ('만만', 1),
#   ('치', 1),
#   ('울랄라', 1),
#   ('일상', 1),
#   ('리뷰', 1)],
#  [('날', 4),
#   ('생각', 2),
#   ('음식', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('해', 2),
#   ('것', 2),
#   ('향', 2),
#   ('어회', 2),
#   ('안녕', 1),
#   ('날씨', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('준비', 1),
#   ('짬뽕', 1),
#   ('국물', 1),
#   ('만큼', 1),
#   ('계절', 1),
#   ('수', 1),
#   ('빵빵', 1),
#   ('이의', 1),
#   ('하루', 1)],
#  [('날', 2),
#   ('겨울', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('먹거리', 1),
#   ('부산', 1),
#   ('음식점', 1),
#   ('중', 1),
#   ('하나', 1),
#   ('요', 1),
#   ('곱', 1),
#   ('도리', 1),
#   ('탕', 1),
#   ('역시', 1),
#   ('국물', 1),
#   ('때문', 1),
#   ('일', 1),
#   ('수록', 1),
#   ('더', 1),
#   ('생각', 1),
#   ('식사', 1),
#   ('톡톡', 1),
#   ('터', 1),
#   ('식감', 1),
#   ('알밥', 1),
#   ('옛날', 1),
#   ('도시락', 1),
#   ('통', 1),
#   ('고소', 1),
#   ('홍', 1),
#   ('다이어리', 1)],
#  [('우동', 4),
#   ('요리', 3),
#   ('메뉴', 3),
#   ('날', 2),
#   ('호호', 2),
#   ('불어', 2),
#   ('야채', 2),
#   ('법', 2),
#   ('추천', 2),
#   ('만들기', 1),
#   ('날씨', 1),
#   ('요즘', 1),
#   ('요', 1),
#   ('추위', 1),
#   ('오들오들', 1),
#   ('그릇', 1),
#   ('간단', 1),
#   ('한요', 1),
#   ('리', 1),
#   ('점심', 1),
#   ('저녁', 1)],
#  [('저녁', 3),
#   ('날씨', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('불고기', 2),
#   ('버섯전골', 2),
#   ('날', 2),
#   ('최고', 2),
#   ('오늘', 2),
#   ('안녕', 1),
#   ('파워', 1),
#   ('안시', 1),
#   ('혁팀', 1),
#   ('최근', 1),
#   ('겨울', 1),
#   ('엄', 1),
#   ('청', 1),
#   ('어제', 1),
#   ('뭔가', 1),
#   ('김팀', 1),
#   ('차량', 1),
#   ('이야기', 1)],
#  [('명동', 5),
#   ('점심', 3),
#   ('메뉴', 3),
#   ('안동찜닭', 3),
#   ('나긍', 2),
#   ('맛집', 2),
#   ('로', 2),
#   ('날', 2),
#   ('찜닭', 1),
#   ('먹고왓슈', 1),
#   ('안녕', 1),
#   ('나긍입니', 1),
#   ('저녁', 1),
#   ('왓', 1),
#   ('용', 1),
#   ('왜', 1),
#   ('추천', 1),
#   ('점심때', 1),
#   ('가격', 1),
#   ('저렴', 1),
#   ('누룽지', 1),
#   ('나긍쓰', 1),
#   ('블로그', 1)],
#  [('꼬막', 4),
#   ('까치산', 2),
#   ('술집', 2),
#   ('울랄라', 2),
#   ('포차', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('간단', 1),
#   ('메뉴', 1),
#   ('대체', 1),
#   ('걸', 1),
#   ('선택', 1),
#   ('고민', 1),
#   ('순간', 1),
#   ('눈', 1),
#   ('확', 1),
#   ('어요', 1),
#   ('의', 1),
#   ('더욱', 1),
#   ('것', 1),
#   ('껍데기', 1),
#   ('억수', 1),
#   ('르돈되', 1),
#   ('부동산', 1)],
#  [('살', 2),
#   ('국물', 2),
#   ('날', 2),
#   ('점심', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('벌교읍', 1),
#   ('조기', 1),
#   ('매운탕', 1),
#   ('날씨', 1),
#   ('갑자기', 1),
#   ('춥다', 1),
#   ('집', 1),
#   ('수도', 1),
#   ('때', 1),
#   ('몸', 1),
#   ('음식', 1),
#   ('보양', 1),
#   ('해주', 1),
#   ('벌교', 1),
#   ('맛집', 1),
#   ('아가', 1),
#   ('여정', 1)],
#  [('칼국수', 4),
#   ('천안', 3),
#   ('맛집', 3),
#   ('등촌', 3),
#   ('샤브', 3),
#   ('날', 2),
#   ('메뉴', 2),
#   ('인', 2),
#   ('신부동', 1),
#   ('요즘', 1),
#   ('처럼', 1),
#   ('판', 1),
#   ('이상', 1),
#   ('실', 1),
#   ('경우', 1),
#   ('대표', 1),
#   ('버섯', 1),
#   ('것', 1),
#   ('꼭', 1),
#   ('한번', 1),
#   ('방문', 1),
#   ('보시', 1),
#   ('길', 1),
#   ('추천', 1),
#   ('드립', 1),
#   ('감기', 1),
#   ('독감', 1),
#   ('몸살', 1),
#   ('부', 1),
#   ('천지인', 1),
#   ('한의원', 1),
#   ('정성', 1)],
#  [('당감동', 2),
#   ('맛집', 2),
#   ('수백', 2),
#   ('날', 2),
#   ('전골', 2),
#   ('당', 1),
#   ('곱새', 1),
#   ('호로', 1),
#   ('록', 1),
#   ('간단', 1),
#   ('혼밥', 1),
#   ('분도', 1),
#   ('계', 1),
#   ('시더', 1),
#   ('포장', 1),
#   ('가능', 1),
#   ('작', 1),
#   ('늑한', 1),
#   ('매장', 1),
#   ('메뉴', 1),
#   ('강력', 1),
#   ('추천', 1),
#   ('배부', 1),
#   ('르', 1),
#   ('자알', 1),
#   ('가오', 1),
#   ('겨울', 1),
#   ('당하', 1),
#   ('살림', 1),
#   ('육', 1),
#   ('아하', 1),
#   ('둥이', 1)],
#  [('샤브샤브', 3),
#   ('맛집', 2),
#   ('날', 2),
#   ('유유', 2),
#   ('샤브', 2),
#   ('동천', 2),
#   ('점', 2),
#   ('추천', 2),
#   ('바로', 2),
#   ('광주', 1),
#   ('은', 1),
#   ('유난', 1),
#   ('이번', 1),
#   ('겨울', 1),
#   ('유', 1),
#   ('니스', 1),
#   ('메뉴', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('저', 1),
#   ('친절', 1),
#   ('더', 1),
#   ('왕', 1),
#   ('근처', 1)],
#  [('맛집', 2),
#   ('만두', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('가장', 2),
#   ('생각', 2),
#   ('시장', 1),
#   ('장호', 1),
#   ('덕', 1),
#   ('손', 1),
#   ('저녁', 1),
#   ('음식', 1),
#   ('중', 1),
#   ('게', 1),
#   ('나시', 1),
#   ('요', 1),
#   ('저', 1),
#   ('호빵', 1),
#   ('붕어빵', 1),
#   ('종류', 1),
#   ('먼저', 1),
#   ('국물', 1),
#   ('이따', 1),
#   ('일단', 1),
#   ('면서', 1),
#   ('가성', 1),
#   ('비', 1),
#   ('란', 1),
#   ('멘션', 1)],
#  [('점심', 3),
#   ('메뉴', 3),
#   ('가경동', 2),
#   ('날', 2),
#   ('뼈', 2),
#   ('해장국', 2),
#   ('면', 2),
#   ('여기', 1),
#   ('양', 1),
#   ('느낌', 1),
#   ('고', 1),
#   ('고기', 1),
#   ('툼', 1),
#   ('로', 1),
#   ('고민', 1),
#   ('중이', 1),
#   ('해장', 1),
#   ('필', 1),
#   ('요하', 1),
#   ('한번', 1),
#   ('쯤', 1),
#   ('가보', 1),
#   ('길', 1),
#   ('추천', 1),
#   ('해', 1)],
#  [('날', 2),
#   ('주문', 2),
#   ('해물', 2),
#   ('용봉동', 1),
#   ('맛집', 1),
#   ('생각', 1),
#   ('착', 1),
#   ('한해', 1),
#   ('물', 1),
#   ('우리', 1),
#   ('메뉴', 1),
#   ('세', 1),
#   ('사람', 1),
#   ('해물전골', 1),
#   ('중', 1),
#   ('인', 1),
#   ('진심', 1),
#   ('포장마차', 1),
#   ('분위기', 1),
#   ('물씬', 1),
#   ('풍기', 1),
#   ('추천', 1),
#   ('드레스', 1),
#   ('집', 1),
#   ('화', 1),
#   ('웨딩', 1)],
#  [('굴국밥', 7),
#   ('생', 4),
#   ('메뉴', 2),
#   ('고속', 1),
#   ('터미널', 1),
#   ('점', 1),
#   ('날', 1),
#   ('추천', 1),
#   ('판', 1),
#   ('여', 1),
#   ('기오', 1),
#   ('그냥', 1),
#   ('이나', 1),
#   ('굴굴밥', 1),
#   ('진짜', 1),
#   ('사람', 1),
#   ('항상', 1),
#   ('것', 1),
#   ('주', 1),
#   ('문하', 1),
#   ('금방', 1),
#   ('굴', 1),
#   ('해', 1),
#   ('맑은', 1)],
#  [('물', 4),
#   ('연남', 3),
#   ('갈비', 3),
#   ('날', 2),
#   ('화성', 1),
#   ('봉담', 1),
#   ('맛집', 1),
#   ('추천', 1),
#   ('국물', 1),
#   ('제', 1),
#   ('픽', 1),
#   ('곳', 1),
#   ('운영', 1),
#   ('시간', 1),
#   ('일요일', 1),
#   ('정기', 1),
#   ('휴무', 1),
#   ('주차', 1),
#   ('가능', 1),
#   ('산', 1),
#   ('산이', 1),
#   ('물이', 1),
#   ('고기', 1),
#   ('산더미', 1),
#   ('찰떡', 1),
#   ('비유', 1),
#   ('유명', 1),
#   ('메뉴', 1),
#   ('욘', 1),
#   ('집사', 1),
#   ('리아', 1),
#   ('리', 1)],
#  [('오늘', 3),
#   ('부산', 2),
#   ('사상', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('최뼈', 2),
#   ('구', 2),
#   ('해장국', 2),
#   ('음식', 2),
#   ('세팅', 2),
#   ('맛집', 1),
#   ('은', 1),
#   ('생각', 1),
#   ('이나', 1),
#   ('국물', 1),
#   ('점심', 1),
#   ('메뉴', 1),
#   ('집', 1),
#   ('소개', 1),
#   ('드릴', 1),
#   ('려고', 1),
#   ('해', 1),
#   ('위', 1),
#   ('기본', 1),
#   ('이구', 1),
#   ('근접', 1),
#   ('사진', 1),
#   ('밀', 1),
#   ('리언', 1),
#   ('모찌', 1),
#   ('경제', 1),
#   ('이야기', 1)],
#  [('짬뽕', 9),
#   ('의정부', 8),
#   ('교동', 6),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('맛집', 1),
#   ('아이', 1),
#   ('생각', 1),
#   ('네', 1),
#   ('출처', 1),
#   ('네이버', 1),
#   ('거리', 1),
#   ('뷰', 1),
#   ('집', 1),
#   ('짜장밥', 1),
#   ('백년', 1),
#   ('드림', 1),
#   ('나', 1),
#   ('행복', 1)],
#  [('병점', 3),
#   ('추천', 2),
#   ('카레돈까스', 2),
#   ('나베', 2),
#   ('맛집', 2),
#   ('멘스', 2),
#   ('애부', 2),
#   ('날', 1),
#   ('점심', 1),
#   ('메뉴', 1),
#   ('면', 1),
#   ('연어', 1),
#   ('초밥', 1),
#   ('핑거', 1),
#   ('돈까스', 1),
#   ('튀김', 1),
#   ('류', 1),
#   ('등등', 1),
#   ('아주', 1),
#   ('다양', 1),
#   ('맛', 1),
#   ('즐', 1),
#   ('수', 1),
#   ('어요', 1),
#   ('오늘', 1),
#   ('하루', 1),
#   ('마무리', 1),
#   ('모두', 1),
#   ('건강', 1),
#   ('웰', 1),
#   ('포스', 1),
#   ('처', 1)],
#  [('온천', 4),
#   ('날', 2),
#   ('칼국수', 2),
#   ('삼송', 2),
#   ('은희', 2),
#   ('해장국', 2),
#   ('까운', 2),
#   ('안', 2),
#   ('메뉴', 1),
#   ('강추', 1),
#   ('북한', 1),
#   ('산', 1),
#   ('겨울', 1),
#   ('은', 1),
#   ('지축', 1),
#   ('제주', 1),
#   ('점심', 1),
#   ('저녁', 1),
#   ('한번', 1),
#   ('이조', 1),
#   ('합', 1),
#   ('추천', 1),
#   ('닼', 1),
#   ('쿄쿄', 1),
#   ('옆', 1),
#   ('벽돌', 1),
#   ('집', 1),
#   ('안쪽', 1),
#   ('쑥', 1),
#   ('쪽', 1),
#   ('나', 1),
#   ('물', 1),
#   ('궁', 1),
#   ('노트', 1)],
#  [('추천', 4),
#   ('보드게임', 3),
#   ('레드', 2),
#   ('버튼', 2),
#   ('노원', 2),
#   ('놀', 2),
#   ('거리', 2),
#   ('날', 2),
#   ('실내', 2),
#   ('데이트', 2),
#   ('메뉴', 2),
#   ('것', 2),
#   ('노원역', 1),
#   ('카페', 1),
#   ('인', 1),
#   ('쥐', 1),
#   ('판', 1),
#   ('식', 1),
#   ('후경', 1),
#   ('카운터', 1),
#   ('말', 1),
#   ('필요', 1),
#   ('개별', 1),
#   ('룸', 1),
#   ('마다', 1)],
#  [('날', 2),
#   ('쌀국수', 2),
#   ('추천', 2),
#   ('오늘', 2),
#   ('송리단길', 1),
#   ('베트남', 1),
#   ('맛집', 1),
#   ('메뉴', 1),
#   ('결정', 1),
#   ('어려움', 1),
#   ('편이', 1),
#   ('또', 1),
#   ('가야', 1),
#   ('하나', 1),
#   ('고민', 1),
#   ('역시', 1),
#   ('출하', 1),
#   ('때', 1),
#   ('잠실', 1),
#   ('후기', 1),
#   ('게', 1),
#   ('일상', 1)],
#  [('날', 2),
#   ('추천', 2),
#   ('맛집', 2),
#   ('불고기', 2),
#   ('어요', 2),
#   ('고기', 2),
#   ('갈산동', 1),
#   ('불고기전골', 1),
#   ('회관', 1),
#   ('선', 1),
#   ('선하', 1),
#   ('거나', 1),
#   ('전골', 1),
#   ('오랫동안', 1),
#   ('보관', 1),
#   ('식', 1),
#   ('쫄깃했', 1),
#   ('야채', 1),
#   ('양하', 1),
#   ('직화', 1),
#   ('제육볶음', 1),
#   ('메뉴', 1),
#   ('연킴', 1),
#   ('일상', 1),
#   ('기록', 1)],
#  [('날', 2),
#   ('성수동', 2),
#   ('도', 1),
#   ('살얼음', 1),
#   ('동동', 1),
#   ('메밀국수', 1),
#   ('소바', 1),
#   ('식당', 1),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('전복', 1),
#   ('단', 1),
#   ('새우', 1),
#   ('냉소', 1),
#   ('바', 1),
#   ('연어', 1),
#   ('덮밥', 1),
#   ('타', 1),
#   ('마고', 1),
#   ('멘치', 1),
#   ('카츠', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('좀', 1),
#   ('매장', 1),
#   ('언제', 1),
#   ('가도', 1),
#   ('편안', 1),
#   ('분위기', 1),
#   ('늘', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('어요', 1),
#   ('테이블', 1),
#   ('간', 1),
#   ('간격', 1),
#   ('접객', 1),
#   ('해주시', 1),
#   ('판', 1),
#   ('기획', 1),
#   ('자의', 1),
#   ('세상', 1)],
#  [('추천', 4),
#   ('날', 3),
#   ('샤브샤브', 2),
#   ('맛집', 2),
#   ('메뉴', 2),
#   ('학', 1),
#   ('정동', 1),
#   ('국물', 1),
#   ('때', 1),
#   ('진짜', 1),
#   ('온몸', 1),
#   ('풀', 1),
#   ('리더', 1),
#   ('게', 1),
#   ('외식', 1),
#   ('저녁', 1),
#   ('만두전골', 1),
#   ('칠곡', 1),
#   ('겨울', 1),
#   ('다이어트', 1),
#   ('샐러드', 1),
#   ('월남쌈', 1),
#   ('쌀국수', 1),
#   ('칼국수', 1),
#   ('영', 1),
#   ('발자국', 1),
#   ('이야기', 1)],
#  [('곰탕', 7),
#   ('어요', 3),
#   ('날', 2),
#   ('정담', 2),
#   ('점심', 1),
#   ('울산', 1),
#   ('맛집', 1),
#   ('정성', 1),
#   ('호계동', 1),
#   ('집', 1),
#   ('오늘', 1),
#   ('진짜', 1),
#   ('오', 1),
#   ('토요일', 1),
#   ('오후', 1),
#   ('추위', 1),
#   ('기대', 1),
#   ('메뉴', 1),
#   ('판', 1),
#   ('서치', 1),
#   ('진', 1),
#   ('맑은', 1),
#   ('크게', 1),
#   ('두', 1),
#   ('가지', 1),
#   ('타입', 1),
#   ('초이스', 1),
#   ('수', 1),
#   ('말', 1),
#   ('아내', 1)],
#  [('도리', 4),
#   ('탕', 4),
#   ('맛집', 3),
#   ('또', 3),
#   ('집', 3),
#   ('떡', 2),
#   ('날', 2),
#   ('줄', 2),
#   ('식당', 2),
#   ('탐방', 2),
#   ('추천', 2),
#   ('강남역', 2),
#   ('이', 2),
#   ('치킨', 2),
#   ('강남', 1),
#   ('점', 1),
#   ('요즘', 1),
#   ('핫', 1),
#   ('내', 1),
#   ('당신', 1),
#   ('번호', 1),
#   ('수', 1),
#   ('습', 1),
#   ('명소', 1),
#   ('메인', 1),
#   ('메뉴', 1),
#   ('유명', 1),
#   ('요리', 1),
#   ('인터스텔라', 1)],
#  [('맛집', 2),
#   ('날', 2),
#   ('자매', 2),
#   ('메뉴', 2),
#   ('네일', 2),
#   ('노원역', 1),
#   ('후기', 1),
#   ('추천', 1),
#   ('농', 1),
#   ('차례', 1),
#   ('습', 1),
#   ('닷', 1),
#   ('오랜만', 1),
#   ('소개', 1),
#   ('드릴', 1),
#   ('요새', 1),
#   ('처럼', 1),
#   ('메인', 1),
#   ('다양', 1),
#   ('찌개', 1),
#   ('종류', 1),
#   ('생선', 1),
#   ('탕', 1),
#   ('이나', 1),
#   ('닭볶음탕', 1),
#   ('오삼', 1),
#   ('불고기', 1),
#   ('등', 1),
#   ('추가', 1),
#   ('로', 1),
#   ('상계', 1),
#   ('별내', 1),
#   ('당고', 1),
#   ('개', 1),
#   ('샵', 1),
#   ('나나', 1),
#   ('양', 1)],
#  [('우동', 8),
#   ('역전', 5),
#   ('메뉴', 3),
#   ('추천', 2),
#   ('날', 2),
#   ('포장', 1),
#   ('국물', 1),
#   ('최고', 1),
#   ('적', 1),
#   ('겨울', 1),
#   ('엄마', 1),
#   ('포장마차', 1),
#   ('기억', 1),
#   ('어서', 1),
#   ('갑자기', 1),
#   ('추억', 1),
#   ('매콤', 1),
#   ('치킨', 1),
#   ('마', 1),
#   ('덮밥', 1),
#   ('옛날', 1),
#   ('찌', 1)],
#  [('메뉴', 4),
#   ('날', 3),
#   ('더', 3),
#   ('찹쌀', 2),
#   ('수제비', 2),
#   ('추천', 1),
#   ('요즘', 1),
#   ('를', 1),
#   ('준비', 1),
#   ('어요', 1),
#   ('첫', 1),
#   ('쫀득쫀득', 1),
#   ('생각', 1),
#   ('이나', 1),
#   ('건강', 1),
#   ('음식', 1),
#   ('밥', 1),
#   ('국물', 1),
#   ('파머', 1),
#   ('스티', 1)],
#  [('날', 3),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('갈비탕', 2),
#   ('국물', 2),
#   ('아무', 1),
#   ('도', 1),
#   ('저', 1),
#   ('겨울', 1),
#   ('이면', 1),
#   ('음식', 1),
#   ('자주', 1),
#   ('이해', 1),
#   ('해주', 1),
#   ('오늘', 1),
#   ('처럼', 1),
#   ('은', 1),
#   ('밥', 1),
#   ('숟가락', 1),
#   ('몸', 1),
#   ('따땃', 1),
#   ('해지', 1),
#   ('행복', 1),
#   ('공잉', 1),
#   ('일상', 1),
#   ('이야기', 1)],
#  [('맛집', 2),
#   ('날', 2),
#   ('옹심이', 2),
#   ('메밀', 2),
#   ('칼국수', 2),
#   ('감자', 2),
#   ('경기도', 1),
#   ('광주', 1),
#   ('배재', 1),
#   ('명물', 1),
#   ('추천', 1),
#   ('오늘', 1),
#   ('영하', 1),
#   ('도', 1),
#   ('데', 1),
#   ('외출', 1),
#   ('국물', 1),
#   ('부모님', 1),
#   ('우리', 1),
#   ('아기', 1),
#   ('식사', 1),
#   ('메뉴', 1),
#   ('만두', 1),
#   ('메인', 1),
#   ('듯', 1),
#   ('가게', 1),
#   ('내부', 1),
#   ('하진', 1),
#   ('오래', 1),
#   ('용이', 1),
#   ('님', 1),
#   ('블로그', 1)],
#  [('국물', 3),
#   ('개성', 3),
#   ('토종', 3),
#   ('상황버섯', 3),
#   ('삼계탕', 3),
#   ('날', 2),
#   ('재', 2),
#   ('방문', 2),
#   ('안성', 2),
#   ('맛집', 2),
#   ('메뉴', 1),
#   ('가격', 1),
#   ('참고', 1),
#   ('추천', 1),
#   ('몸', 1)],
#  [('포', 3),
#   ('메인', 3),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('어서', 2),
#   ('직원', 1),
#   ('쌀국수', 1),
#   ('바', 1),
#   ('매장', 1),
#   ('사진', 1),
#   ('판도', 1),
#   ('그', 1),
#   ('만큼', 1),
#   ('맛', 1),
#   ('세', 1),
#   ('가지', 1),
#   ('감기', 1),
#   ('조심', 1),
#   ('유니', 1)],
#  [('날', 2),
#   ('추천', 2),
#   ('베이커리', 2),
#   ('곳', 2),
#   ('실내', 1),
#   ('데이트', 1),
#   ('인천', 1),
#   ('초대형', 1),
#   ('식물원', 1),
#   ('카페', 1),
#   ('다양', 1),
#   ('음료', 1),
#   ('커피', 1),
#   ('푸드', 1),
#   ('등', 1),
#   ('메뉴', 1),
#   ('이구', 1),
#   ('가격', 1),
#   ('편이', 1),
#   ('맛', 1),
#   ('푸릇푸릇', 1),
#   ('식물', 1),
#   ('가득', 1),
#   ('포레스트', 1),
#   ('아웃팅', 1),
#   ('스', 1),
#   ('송도', 1),
#   ('점', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('케이', 1),
#   ('공감', 1),
#   ('디자인', 1)],
#  [('화끈', 3),
#   ('연산역', 2),
#   ('점심', 2),
#   ('추천', 2),
#   ('마라탕', 2),
#   ('날', 2),
#   ('감', 2),
#   ('인근', 1),
#   ('메뉴', 1),
#   ('아침', 1),
#   ('날씨', 1),
#   ('정말', 1),
#   ('역시', 1),
#   ('겨울', 1),
#   ('국물', 1),
#   ('분명', 1),
#   ('춥다', 1),
#   ('웅', 1),
#   ('크리', 1),
#   ('땀', 1),
#   ('님', 1),
#   ('블로그', 1)],
#  [('메뉴', 2),
#   ('나니', 2),
#   ('로움', 2),
#   ('점심식사', 1),
#   ('저녁', 1),
#   ('추천', 1),
#   ('날', 1),
#   ('음식', 1),
#   ('식물', 1),
#   ('화분', 1),
#   ('덕', 1),
#   ('느낌', 1),
#   ('더', 1),
#   ('아지', 1),
#   ('요', 1),
#   ('판', 1),
#   ('순대국', 1),
#   ('주문', 1),
#   ('후', 1),
#   ('기', 1),
#   ('다리', 1),
#   ('시간', 1),
#   ('기본', 1),
#   ('반찬', 1),
#   ('여기', 1),
#   ('셋팅', 1),
#   ('해주', 1),
#   ('실', 1),
#   ('때', 1),
#   ('간', 1),
#   ('주네', 1),
#   ('뚜기', 1),
#   ('맛', 1),
#   ('조금', 1),
#   ('김치', 1),
#   ('어요', 1),
#   ('서울', 1),
#   ('경기도', 1),
#   ('음속', 1),
#   ('행복찾기', 1)],
#  [('밀키', 2),
#   ('트', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('간단', 2),
#   ('돈', 1),
#   ('산', 1),
#   ('음식', 1),
#   ('자취', 1),
#   ('생', 1),
#   ('우동', 1),
#   ('재료', 1),
#   ('먹기', 1),
#   ('게', 1),
#   ('조리법', 1),
#   ('진짜', 1),
#   ('냉면', 1),
#   ('것', 1),
#   ('메뉴', 1),
#   ('로', 1),
#   ('아주', 1),
#   ('적합', 1),
#   ('하하', 1),
#   ('겨울', 1),
#   ('몇', 1),
#   ('번', 1),
#   ('더', 1),
#   ('사', 1),
#   ('거', 1),
#   ('반', 1),
#   ('전제', 1),
#   ('풀무원', 1),
#   ('오우', 1),
#   ('주주', 1),
#   ('살롱', 1)],
#  [('메뉴', 4),
#   ('맛집', 3),
#   ('날', 3),
#   ('버섯', 2),
#   ('후', 2),
#   ('탐방', 1),
#   ('집', 1),
#   ('추천', 1),
#   ('성수', 1),
#   ('서울숲', 1),
#   ('뚝섬', 1),
#   ('매장', 1),
#   ('주문', 1),
#   ('를', 1),
#   ('선택', 1),
#   ('인원', 1),
#   ('수', 1),
#   ('체크', 1),
#   ('확인', 1),
#   ('예약', 1),
#   ('겨울', 1),
#   ('국물', 1),
#   ('생각', 1),
#   ('때', 1),
#   ('다시', 1),
#   ('한번', 1),
#   ('볼', 1),
#   ('것', 1),
#   ('아하', 1),
#   ('시', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('일상', 1),
#   ('기록', 1),
#   ('공간', 1)],
#  [('국물', 3),
#   ('날', 2),
#   ('복', 2),
#   ('메뉴', 2),
#   ('땀', 1),
#   ('뻘뻘', 1),
#   ('몸', 1),
#   ('보신', 1),
#   ('하자', 1),
#   ('명송생복집', 1),
#   ('겨울철', 1),
#   ('꼭', 1),
#   ('배', 1),
#   ('도감', 1),
#   ('잠시', 1),
#   ('후', 1),
#   ('판', 1),
#   ('살피', 1),
#   ('주', 1),
#   ('인분', 1),
#   ('추천', 1),
#   ('를', 1),
#   ('뒤', 1),
#   ('활', 1),
#   ('지리탕', 1),
#   ('광주', 1),
#   ('문화', 1),
#   ('관광', 1),
#   ('공식', 1),
#   ('블로그', 1)],
#  [('날', 3),
#   ('저녁', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('짬뽕밥', 2),
#   ('때', 2),
#   ('뭐', 2),
#   ('신가', 1),
#   ('땀', 1),
#   ('좀', 1),
#   ('정도', 1),
#   ('매콤', 1),
#   ('어요', 1),
#   ('일', 1),
#   ('에너지', 1),
#   ('소모', 1),
#   ('으슬으슬', 1),
#   ('부', 1),
#   ('찍', 1),
#   ('개취', 1),
#   ('논란', 1),
#   ('데', 1)],
#  [('바베큐', 4),
#   ('쌀국수', 3),
#   ('끈', 2),
#   ('숯불', 2),
#   ('날', 1),
#   ('생각', 1),
#   ('동탄', 1),
#   ('전골', 1),
#   ('베트남', 1),
#   ('디너', 1),
#   ('메뉴', 1),
#   ('로만', 1),
#   ('가능', 1),
#   ('듯', 1),
#   ('야외', 1),
#   ('테라스', 1),
#   ('직접', 1),
#   ('주어', 1),
#   ('캠핑', 1),
#   ('느낌', 1),
#   ('리얼', 1),
#   ('수', 1),
#   ('즐', 1),
#   ('기고', 1),
#   ('저녁', 1),
#   ('방문', 1),
#   ('추천', 1),
#   ('노노', 1),
#   ('패밀리', 1)],
#  [('메뉴', 3),
#   ('생각', 2),
#   ('콩국', 2),
#   ('대구', 1),
#   ('남산동', 1),
#   ('밥집', 1),
#   ('날', 1),
#   ('더', 1),
#   ('다양', 1),
#   ('의', 1),
#   ('제일', 1),
#   ('간단', 1),
#   ('선택', 1),
#   ('장애인', 1),
#   ('나', 1),
#   ('간략', 1),
#   ('를', 1),
#   ('거지', 1),
#   ('수', 1),
#   ('음식', 1),
#   ('뜻', 1),
#   ('달달', 1),
#   ('추천', 1),
#   ('드립', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('후기', 1),
#   ('끝', 1)],
#  [('칼국수', 3),
#   ('추천', 3),
#   ('날', 2),
#   ('더', 2),
#   ('겨울', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('생각', 1),
#   ('직장인', 1),
#   ('이모', 1),
#   ('님', 1),
#   ('걸', 1),
#   ('어간', 1),
#   ('그', 1),
#   ('바지락', 1),
#   ('엄마', 1),
#   ('해주시', 1),
#   ('맛', 1),
#   ('조미료', 1),
#   ('개운', 1),
#   ('로', 1),
#   ('완전', 1),
#   ('강력', 1),
#   ('해', 1),
#   ('미싱', 1),
#   ('유', 1),
#   ('잡', 1),
#   ('아야', 1),
#   ('블로그', 1)],
#  [('상상', 3),
#   ('날', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('부대찌개', 2),
#   ('한파', 1),
#   ('주의보', 1),
#   ('더니', 1),
#   ('심지어', 1),
#   ('온라인', 1),
#   ('울면', 1),
#   ('출근', 1),
#   ('인도', 1),
#   ('어요', 1),
#   ('찬', 1),
#   ('바람', 1),
#   ('눈물', 1),
#   ('줄줄', 1),
#   ('아시', 1),
#   ('그대로', 1)],
#  [('메뉴', 4),
#   ('순대', 3),
#   ('만두국', 3),
#   ('날', 2),
#   ('국밥', 2),
#   ('추천', 2),
#   ('밥', 2),
#   ('순대국', 2),
#   ('요리', 2),
#   ('돼지고기', 1),
#   ('아침', 1),
#   ('귀', 1),
#   ('갓길', 1),
#   ('포장', 1),
#   ('담', 1),
#   ('아주', 1),
#   ('국밥집', 1),
#   ('집', 1),
#   ('거', 1),
#   ('필요', 1),
#   ('만두', 1),
#   ('그릇', 1),
#   ('겨울', 1),
#   ('점심', 1),
#   ('저녁', 1),
#   ('샤이니', 1),
#   ('인생', 1),
#   ('아름', 1),
#   ('워', 1)],
#  [('칼국수', 5),
#   ('날', 4),
# ...
#   ('느낌', 1),
#   ('술집', 1),
#   ('추천', 1),
#   ('슬', 1),
#   ('트립', 1),
#   ('로그', 1)],
#  [('경기', 2),
#   ('광주', 2),
#   ('날', 2),
#   ('장', 2),
#   ('지리', 2),
#   ('가마솥', 2),
#   ('장국', 2),
#   ('추천', 2),
#   ('맛집', 1),
#   ('저녁', 1),
#   ('날씨', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('몸', 1),
#   ('겸', 1),
#   ('주차', 1),
#   ('가게', 1),
#   ('내부', 1),
#   ('가보', 1),
#   ('홀로', 1),
#   ('구성', 1),
#   ('어요', 1),
#   ('저희', 1),
#   ('도착', 1)],
#  [('날', 3),
#   ('겨울', 3),
#   ('감탄', 2),
#   ('간식', 2),
#   ('호떡', 2),
#   ('요기', 1),
#   ('생각', 1),
#   ('추천', 1),
#   ('이면', 1),
#   ('김', 1),
#   ('모락모락', 1),
#   ('나', 1),
#   ('길거리', 1),
#   ('마련', 1),
#   ('상상', 1),
#   ('쫄깃', 1),
#   ('식감', 1),
#   ('꿀', 1),
#   ('시럽', 1),
#   ('듬뿍', 1),
#   ('호호', 1),
#   ('불어', 1),
#   ('찬', 1),
#   ('바람', 1),
#   ('때', 1),
#   ('이의', 1),
#   ('행복', 1),
#   ('충전', 1),
#   ('블로그', 1)],
#  [('맛집', 3),
#   ('베트남', 3),
#   ('천안', 2),
#   ('쌍용동', 2),
#   ('날', 2),
#   ('노상', 2),
#   ('식당', 2),
#   ('안', 2),
#   ('쌀국수', 1),
#   ('종종', 1),
#   ('가보', 1),
#   ('았', 1),
#   ('다양', 1),
#   ('메뉴', 1),
#   ('곳', 1),
#   ('처음', 1),
#   ('것', 1),
#   ('주니', 1),
#   ('용', 1),
#   ('골목', 1),
#   ('전', 1),
#   ('설', 1),
#   ('공간', 1)],
#  [('아이', 3),
#   ('순수', 3),
#   ('딸기', 3),
#   ('설빙', 3),
#   ('간식', 2),
#   ('거생', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('거', 2),
#   ('정말', 2),
#   ('생', 1),
#   ('안녕', 1),
#   ('설랑', 1),
#   ('코로나', 1),
#   ('확산', 1),
#   ('최고', 1),
#   ('것', 1),
#   ('굳이', 1),
#   ('날', 1),
#   ('막상', 1),
#   ('연휴', 1),
#   ('하나', 1),
#   ('더', 1),
#   ('추가', 1),
#   ('개성', 1),
#   ('만점', 1),
#   ('셋', 1)],
#  [('날', 4),
#   ('국물', 3),
#   ('요리', 3),
#   ('수제비', 2),
#   ('비', 2),
#   ('레시피', 2),
#   ('김치', 1),
#   ('만들기', 1),
#   ('음식', 1),
#   ('다양', 1),
#   ('중', 1),
#   ('서도', 1),
#   ('가오', 1),
#   ('또', 1),
#   ('생각', 1),
#   ('때', 1),
#   ('한식', 1),
#   ('메뉴', 1),
#   ('원래', 1),
#   ('바지락', 1),
#   ('육수', 1),
#   ('감자', 1),
#   ('호박', 1),
#   ('메이플', 1),
#   ('대니얼', 1),
#   ('공간', 1),
#   ('다니엘', 1),
#   ('랜드', 1)],
#  [('국수', 3),
#   ('날', 3),
#   ('사람', 2),
#   ('나', 2),
#   ('미사리', 1),
#   ('밀빛초', 1),
#   ('롯데', 1),
#   ('아울렛', 1),
#   ('광명', 1),
#   ('점', 1),
#   ('좀', 1),
#   ('아직', 1),
#   ('씨', 1),
#   ('칼국수', 1),
#   ('초', 1),
#   ('집', 1),
#   ('인테리어', 1),
#   ('메뉴', 1),
#   ('오기', 1),
#   ('조금', 1),
#   ('재미', 1),
#   ('일상', 1),
#   ('블로그', 1)],
#  [('체험', 3),
#   ('카페', 2),
#   ('도자기', 2),
#   ('마을', 2),
#   ('실내', 2),
#   ('데이트', 2),
#   ('이색', 1),
#   ('날', 1),
#   ('요', 1),
#   ('메뉴', 1),
#   ('좀', 1),
#   ('그', 1),
#   ('런가', 1),
#   ('사람', 1),
#   ('때', 1),
#   ('두', 1),
#   ('가지', 1),
#   ('도예', 1),
#   ('해', 1),
#   ('보시', 1),
#   ('인근', 1),
#   ('다양', 1),
#   ('거리', 1),
#   ('린아', 1),
#   ('것', 1),
#   ('추천', 1)],
#  [('메뉴', 2),
#   ('어서', 2),
#   ('바', 2),
#   ('테이블', 2),
#   ('자리', 2),
#   ('산호수', 1),
#   ('공원', 1),
#   ('점심', 1),
#   ('추천', 1),
#   ('텐동', 1),
#   ('맛집', 1),
#   ('온센', 1),
#   ('서산', 1),
#   ('점', 1),
#   ('새', 1),
#   ('우동', 1),
#   ('소바', 1),
#   ('날', 1),
#   ('가기', 1),
#   ('것', 1),
#   ('나', 1),
#   ('양쪽', 1),
#   ('귀', 1),
#   ('여운', 1),
#   ('피', 1),
#   ('규어', 1),
#   ('구', 1),
#   ('경하', 1),
#   ('재미', 1),
#   ('서도', 1),
#   ('김', 1),
#   ('입술', 1),
#   ('이야기', 1)],
#  [('날', 3),
#   ('요', 3),
#   ('점심', 2),
#   ('추천', 2),
#   ('해', 2),
#   ('하루', 2),
#   ('오늘', 2),
#   ('저녁', 1),
#   ('메뉴', 1),
#   ('드립', 1),
#   ('안녕', 1),
#   ('봄', 1),
#   ('벌써', 1),
#   ('워', 1),
#   ('요즘', 1),
#   ('처럼', 1),
#   ('겨울', 1),
#   ('전골', 1),
#   ('더', 1),
#   ('이웃', 1),
#   ('님들', 1),
#   ('우동', 1),
#   ('몸', 1),
#   ('건강', 1)],
#  [('수제비', 3),
#   ('날', 2),
#   ('김치', 2),
#   ('맛집', 2),
#   ('메뉴', 2),
#   ('판', 2),
#   ('내', 2),
#   ('런치', 1),
#   ('때', 1),
#   ('추천', 1),
#   ('좀', 1),
#   ('거리', 1),
#   ('체부동', 1),
#   ('옛날', 1),
#   ('국수', 1),
#   ('고고씽', 1),
#   ('함', 1),
#   ('아쉬움', 1),
#   ('포함', 1),
#   ('밀가루', 1),
#   ('거의', 1),
#   ('매하', 1),
#   ('듯', 1),
#   ('주문', 1),
#   ('하디', 1)],
#  [('추천', 2),
#   ('메뉴', 2),
#   ('판', 2),
#   ('셀프', 2),
#   ('북촌', 1),
#   ('손', 1),
#   ('만두', 1),
#   ('날', 1),
#   ('만둣국', 1),
#   ('죠', 1),
#   ('서창동', 1),
#   ('밥집', 1),
#   ('왕비', 1),
#   ('돈까스', 1),
#   ('골목', 1),
#   ('동궁', 1),
#   ('찜닭', 1),
#   ('옆', 1),
#   ('주차', 1),
#   ('가능', 1),
#   ('휴무', 1),
#   ('월요일', 1),
#   ('간단', 1),
#   ('오기', 1),
#   ('듯', 1),
#   ('저기', 1),
#   ('음식', 1),
#   ('곳', 1),
#   ('픽업', 1),
#   ('애정', 1),
#   ('가득', 1)],
#  [('명', 2),
#   ('날', 2),
#   ('토리', 2),
#   ('샤브', 2),
#   ('메뉴', 2),
#   ('샤브샤브', 1),
#   ('맛집', 1),
#   ('후기', 1),
#   ('부산', 1),
#   ('강서구', 1),
#   ('지국', 1),
#   ('제', 1),
#   ('로', 1),
#   ('호', 1),
#   ('포장', 1),
#   ('배달', 1),
#   ('택배', 1),
#   ('전문', 1),
#   ('카톡', 1),
#   ('배민', 1),
#   ('주문', 1),
#   ('가능', 1),
#   ('요즘', 1),
#   ('기전', 1),
#   ('봄', 1),
#   ('사장', 1),
#   ('판', 1),
#   ('사진', 1),
#   ('완전', 1),
#   ('나', 1),
#   ('요게', 1),
#   ('일상', 1),
#   ('기록', 1)],
#  [('맘', 4),
#   ('메뉴', 2),
#   ('해장국', 2),
#   ('날', 2),
#   ('가면', 1),
#   ('꼭', 1),
#   ('주문', 1),
#   ('먹킷', 1),
#   ('리스트', 1),
#   ('추천', 1),
#   ('이벤트', 1),
#   ('대한', 1),
#   ('솔직', 1),
#   ('리뷰', 1),
#   ('가득', 1),
#   ('이번', 1),
#   ('콘텐츠', 1),
#   ('시작', 1),
#   ('한국인', 1),
#   ('아주', 1),
#   ('뼈', 1),
#   ('귀', 1),
#   ('살짝', 1),
#   ('끈', 1),
#   ('사발', 1),
#   ('들깻', 1),
#   ('가루', 1),
#   ('오늘', 1),
#   ('순대국', 1),
#   ('공식', 1),
#   ('블로그', 1)],
#  [('맛집', 2),
#   ('조개찜', 2),
#   ('조개', 2),
#   ('전골', 2),
#   ('도', 2),
#   ('수원', 1),
#   ('날', 1),
#   ('더', 1),
#   ('포항', 1),
#   ('물회', 1),
#   ('치즈', 1),
#   ('곳도', 1),
#   ('저', 1),
#   ('여기', 1),
#   ('처음', 1),
#   ('어요', 1),
#   ('우리', 1),
#   ('주문', 1),
#   ('메뉴', 1),
#   ('인', 1),
#   ('확', 1),
#   ('고요', 1),
#   ('가족', 1),
#   ('회식', 1),
#   ('등', 1),
#   ('연말', 1),
#   ('연초', 1),
#   ('식사', 1),
#   ('안주', 1),
#   ('조심', 1),
#   ('스레', 1),
#   ('추천', 1),
#   ('해', 1),
#   ('보아', 1),
#   ('용', 1),
#   ('손소', 1),
#   ('품공', 1),
#   ('방과', 1),
#   ('일상', 1)],
#  [('점심', 4),
#   ('날', 4),
#   ('메뉴', 3),
#   ('추천', 2),
#   ('떡', 2),
#   ('라면', 2),
#   ('법', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('뭐', 1),
#   ('고민', 1),
#   ('휴일', 1),
#   ('반찬', 1),
#   ('로', 1),
#   ('때로는', 1),
#   ('국물', 1),
#   ('해달', 1),
#   ('제일', 1),
#   ('먼저', 1),
#   ('생각', 1),
#   ('나', 1),
#   ('듯', 1),
#   ('꽃', 1),
#   ('산골', 1)],
#  [('샤브', 3),
#   ('샤브샤브', 2),
#   ('삼청동', 2),
#   ('추천', 2),
#   ('상봉역', 1),
#   ('날', 1),
#   ('인', 1),
#   ('서도', 1),
#   ('무슨', 1),
#   ('메뉴', 1),
#   ('확인', 1),
#   ('가능', 1),
#   ('요', 1),
#   ('오전', 1),
#   ('열', 1),
#   ('어서', 1),
#   ('저녁', 1),
#   ('참고', 1),
#   ('꿀', 1),
#   ('이득', 1),
#   ('겨울', 1),
#   ('땡', 1),
#   ('때', 1),
#   ('합', 1),
#   ('당', 1),
#   ('겨울철', 1),
#   ('음식', 1),
#   ('방', 1),
#   ('의', 1),
#   ('맛집', 1),
#   ('탐방', 1),
#   ('솔직', 1),
#   ('리뷰', 1)],
#  [('칼국수', 4),
#   ('대구', 2),
#   ('진천동', 2),
#   ('날', 2),
#   ('자', 2),
#   ('가제', 2),
#   ('진주', 2),
#   ('손', 2),
#   ('요즘', 1),
#   ('갑자기', 1),
#   ('너', 1),
#   ('무', 1),
#   ('세트', 1),
#   ('메뉴', 1),
#   ('포함', 1),
#   ('알밥', 1),
#   ('날치', 1),
#   ('알', 1),
#   ('김이랑', 1),
#   ('고', 1),
#   ('세', 1),
#   ('입', 1),
#   ('컷', 1),
#   ('에피타이저', 1),
#   ('먹기', 1),
#   ('위해', 1),
#   ('하루살이', 1),
#   ('집사', 1),
#   ('블로거', 1)],
#  [('안주', 3),
#   ('날', 2),
#   ('해장', 2),
#   ('메뉴', 2),
#   ('어요', 2),
#   ('진짜', 2),
#   ('하나', 2),
#   ('논현역', 1),
#   ('술집', 1),
#   ('달래', 1),
#   ('회식', 1),
#   ('버너', 1),
#   ('위', 1),
#   ('판이', 1),
#   ('모듬', 1),
#   ('수육', 1),
#   ('소', 1),
#   ('전골', 1),
#   ('습', 1),
#   ('조합', 1),
#   ('친구', 1),
#   ('추천', 1),
#   ('완전', 1),
#   ('성공', 1),
#   ('칭찬', 1),
#   ('후', 1),
#   ('우의', 1),
#   ('일상', 1),
#   ('블로그', 1)],
#  [('두', 2),
#   ('명', 2),
#   ('을지로', 1),
#   ('맛집', 1),
#   ('날', 1),
#   ('황평집', 1),
#   ('닭곰탕', 1),
#   ('그릇', 1),
#   ('안주', 1),
#   ('메뉴', 1),
#   ('도', 1),
#   ('주문', 1),
#   ('가능', 1),
#   ('시간', 1),
#   ('대신', 1),
#   ('브레이크', 1),
#   ('타임', 1),
#   ('것', 1),
#   ('참고', 1),
#   ('마음', 1),
#   ('속', 1),
#   ('이상일', 1),
#   ('경우', 1),
#   ('추천', 1),
#   ('이지', 1),
#   ('간단', 1),
#   ('곰탕', 1),
#   ('닭', 1),
#   ('이나', 1),
#   ('닭찜', 1),
#   ('중', 1),
#   ('하나', 1),
#   ('주', 1),
#   ('문하', 1),
#   ('게', 1),
#   ('듯', 1),
#   ('쏭블리', 1),
#   ('조각', 1),
#   ('한조', 1),
#   ('각', 1)],
#  [('맛집', 3),
#   ('곱창전골', 3),
#   ('포항', 2),
#   ('양덕', 2),
#   ('한양', 2),
#   ('날', 1),
#   ('국물', 1),
#   ('호로', 1),
#   ('록', 1),
#   ('메뉴', 1),
#   ('구성', 1),
#   ('전골', 1),
#   ('저희', 1),
#   ('아래', 1),
#   ('처럼', 1),
#   ('주문', 1),
#   ('어요', 1),
#   ('인분', 1),
#   ('공기밥', 1),
#   ('볶음밥', 1),
#   ('음료수', 1),
#   ('추천', 1),
#   ('곱창', 1),
#   ('대학생', 1),
#   ('일상', 1),
#   ('기록', 1),
#   ('재희', 1),
#   ('직딩', 1),
#   ('일기', 1)],
#  [('라멘', 3),
#   ('날', 2),
#   ('맛', 2),
#   ('홍대', 1),
#   ('상수', 1),
#   ('식사', 1),
#   ('추천', 1),
#   ('돈코츠', 1),
#   ('하카다', 1),
#   ('분코', 1),
#   ('주력', 1),
#   ('메뉴', 1),
#   ('어가', 1),
#   ('입구', 1),
#   ('완전', 1),
#   ('집', 1),
#   ('움', 1),
#   ('원래', 1),
#   ('차슈', 1),
#   ('덮밥', 1),
#   ('어보', 1),
#   ('거', 1),
#   ('오버', 1),
#   ('동맥경화', 1),
#   ('것', 1),
#   ('국물', 1),
#   ('이지', 1),
#   ('진짜', 1),
#   ('매력', 1),
#   ('전혀', 1),
#   ('안남', 1),
#   ('드', 1),
#   ('세용', 1),
#   ('얄', 1),
#   ('평가', 1),
#   ('블로그', 1),
#   ('맛챠', 1)],
#  [('미소', 5),
#   ('서초', 4),
#   ('남부', 3),
#   ('터미널', 3),
#   ('메뉴', 3),
#   ('점', 2),
#   ('우삼겹', 2),
#   ('우동', 2),
#   ('소야', 2),
#   ('맛집', 2),
#   ('날', 1),
#   ('강추', 1),
#   ('가격', 1),
#   ('추천', 1),
#   ('부대', 1),
#   ('라면', 1),
#   ('혼밥', 1),
#   ('점심', 1),
#   ('곳', 1),
#   ('맛', 1),
#   ('도리', 1),
#   ('그', 1),
#   ('제일', 1)],
#  [('첨단', 9),
#   ('맛집', 6),
#   ('쭈꾸미', 3),
#   ('점심', 2),
#   ('추천', 2),
#   ('저녁', 2),
#   ('광주', 1),
#   ('쭈마담', 1),
#   ('날', 1),
#   ('매콤', 1),
#   ('게', 1),
#   ('땐', 1),
#   ('바로', 1),
#   ('여기', 1),
#   ('스페셜', 1),
#   ('메뉴', 1),
#   ('삼겹', 1),
#   ('새우', 1),
#   ('우삼겹', 1),
#   ('수', 1),
#   ('재미', 1),
#   ('지구', 1),
#   ('신용동', 1),
#   ('민경', 1),
#   ('일상', 1),
#   ('블로그', 1)],
#  [('주문진', 2),
#   ('육개장', 2),
#   ('해장', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('국물', 2),
#   ('날', 2),
#   ('강릉', 1),
#   ('육', 1),
#   ('반장', 1),
#   ('맛집', 1),
#   ('아침식사', 1),
#   ('가능', 1),
#   ('일반', 1),
#   ('자체', 1),
#   ('녹', 1),
#   ('진해', 1),
#   ('것', 1),
#   ('고요', 1),
#   ('처음', 1),
#   ('후기', 1),
#   ('위치', 1),
#   ('상', 1),
#   ('여행', 1),
#   ('후', 1),
#   ('마지막', 1),
#   ('먹기', 1),
#   ('식사', 1),
#   ('오전', 1),
#   ('시부', 1),
#   ('터', 1),
#   ('영업', 1),
#   ('며', 1),
#   ('의', 1),
#   ('지도', 1)],
#  [('등촌', 4),
#   ('칼국수', 3),
#   ('날', 3),
#   ('샤브', 2),
#   ('저녁', 2),
#   ('메뉴', 2),
#   ('어요', 1),
#   ('근처', 1),
#   ('거리', 1),
#   ('아보', 1),
#   ('았습니', 1),
#   ('고기', 1),
#   ('종류', 1),
#   ('국물', 1),
#   ('보증', 1),
#   ('맛', 1),
#   ('저희', 1),
#   ('추천', 1),
#   ('먹방', 1),
#   ('렌느', 1),
#   ('제이', 1),
#   ('가온', 1),
#   ('맘', 1)],
#  [('원주', 5),
#   ('배달', 4),
#   ('맛집', 3),
#   ('삼부', 3),
#   ('자집', 3),
#   ('삼계탕', 3),
#   ('메뉴', 3),
#   ('관설', 1),
#   ('날', 1),
#   ('끼', 1),
#   ('독특', 1),
#   ('인', 1),
#   ('닭', 1),
#   ('만두전골', 1),
#   ('인기', 1),
#   ('주', 1),
#   ('문하', 1),
#   ('라서', 1),
#   ('주문', 1),
#   ('어요', 1),
#   ('보시', 1),
#   ('길', 1),
#   ('추천', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('툐히', 1),
#   ('일상', 1),
#   ('블로그', 1)],
#  [('밥', 2),
#   ('더', 2),
#   ('오문', 1),
#   ('창', 1),
#   ('순대국', 1),
#   ('메뉴', 1),
#   ('가격', 1),
#   ('대전', 1),
#   ('맛집', 1),
#   ('추천', 1),
#   ('돈내', 1),
#   ('날', 1),
#   ('호로', 1),
#   ('록', 1),
#   ('먹기', 1),
#   ('난', 1),
#   ('한번', 1),
#   ('걸', 1),
#   ('족함', 1),
#   ('고', 1),
#   ('방식', 1),
#   ('이면', 1),
#   ('팔팔', 1),
#   ('여주면', 1),
#   ('위치', 1)],
#  [('거', 3),
#   ('역전', 2),
#   ('할머니', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('느낌', 2),
#   ('어요', 1),
#   ('날', 1),
#   ('아이스', 1),
#   ('맥주', 1),
#   ('뻥', 1),
#   ('기분', 1),
#   ('고', 1),
#   ('취하', 1),
#   ('것', 1),
#   ('적', 1),
#   ('요', 1),
#   ('센치', 1),
#   ('돈까스', 1)],
#  [('화명동', 2),
#   ('탕', 2),
#   ('어요', 2),
#   ('모', 2),
#   ('생선', 2),
#   ('구이', 2),
#   ('문하', 2),
#   ('주문', 2),
#   ('날', 1),
#   ('최고', 1),
#   ('맛집', 1),
#   ('왕대', 1),
#   ('테이블', 1),
#   ('마다', 1),
#   ('메뉴', 1),
#   ('판도', 1),
#   ('주', 1),
#   ('시더', 1),
#   ('저', 1),
#   ('국물', 1),
#   ('어서', 1),
#   ('대구', 1),
#   ('다음', 1),
#   ('방', 1),
#   ('식당', 1),
#   ('추천', 1),
#   ('산홈', 1),
#   ('서비스', 1),
#   ('부산', 1),
#   ('북구', 1),
#   ('점', 1)],
#  [('날', 6),
#   ('매운탕', 3),
#   ('맛집', 2),
#   ('버섯', 2),
#   ('무조건', 2),
#   ('생각', 2),
#   ('인기', 2),
#   ('것', 2),
#   ('여의도', 1),
#   ('가양', 1),
#   ('칼국수', 1),
#   ('음식', 1),
#   ('었다', 1),
#   ('겨울', 1),
#   ('지금', 1),
#   ('메뉴', 1),
#   ('특성', 1),
#   ('상', 1),
#   ('눈', 1),
#   ('오거', 1),
#   ('비', 1),
#   ('직장인', 1),
#   ('약간', 1),
#   ('만큼', 1),
#   ('언제', 1),
#   ('여행자', 1)],
#  [('면', 3),
#   ('영통', 2),
#   ('맛집', 2),
#   ('호', 2),
#   ('사이드', 2),
#   ('메뉴', 2),
#   ('날', 1),
#   ('생각', 1),
#   ('쌀국수', 1),
#   ('단면', 1),
#   ('사진', 1),
#   ('쉬', 1),
#   ('림프', 1),
#   ('롤', 1),
#   ('야채', 1),
#   ('고', 1),
#   ('통통', 1),
#   ('새우', 1),
#   ('튀김', 1),
#   ('꽉', 1),
#   ('어서', 1),
#   ('추천', 1),
#   ('겨울', 1),
#   ('때', 1),
#   ('까지', 1),
#   ('수', 1),
#   ('콩', 1),
#   ('의', 1),
#   ('여행', 1),
#   ('로그', 1)],
#  [('갈비찜', 3),
#   ('조개찜', 2),
#   ('메뉴', 2),
#   ('조개', 2),
#   ('일산', 1),
#   ('맛집', 1),
#   ('날', 1),
#   ('두마', 1),
#   ('리', 1),
#   ('토끼', 1),
#   ('아무', 1),
#   ('도', 1),
#   ('계절', 1),
#   ('시원', 1),
#   ('국물', 1),
#   ('소주', 1),
#   ('잔', 1),
#   ('캬', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('일명', 1),
#   ('조갈', 1),
#   ('찜', 1),
#   ('고', 1),
#   ('대표', 1),
#   ('문어', 1),
#   ('전복', 1),
#   ('귤떡', 1)],
#  [('날', 3),
#   ('양송이', 2),
#   ('종로', 1),
#   ('익선동', 1),
#   ('라쿠', 1),
#   ('근사', 1),
#   ('신기하', 1),
#   ('이자카야', 1),
#   ('생각', 1),
#   ('절로', 1),
#   ('나', 1),
#   ('그', 1),
#   ('런가', 1),
#   ('아무', 1),
#   ('웨스', 1),
#   ('틴', 1),
#   ('조선', 1),
#   ('꼬치', 1),
#   ('품', 1),
#   ('메뉴', 1),
#   ('던데', 1),
#   ('꼭', 1),
#   ('융', 1),
#   ('고', 1),
#   ('이', 1),
#   ('내', 1),
#   ('마음속', 1),
#   ('위', 1),
#   ('전복', 1),
#   ('하나', 1),
#   ('뿐', 1)],
#  [('간단', 3),
#   ('만들기', 2),
#   ('주말', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('다이소', 2),
#   ('오뎅', 2),
#   ('티백', 2),
#   ('활용', 2),
#   ('법', 2),
#   ('요리', 2),
#   ('때', 2),
#   ('초', 1),
#   ('자취', 1),
#   ('생', 1),
#   ('사각', 1),
#   ('어묵국', 1),
#   ('티', 1),
#   ('필요', 1),
#   ('혼술', 1),
#   ('캠핑', 1),
#   ('해외여행', 1),
#   ('야식', 1),
#   ('숙취', 1),
#   ('해소', 1),
#   ('밥', 1),
#   ('날', 1),
#   ('등산', 1),
#   ('과정', 1),
#   ('영상', 1),
#   ('해우', 1),
#   ('의', 1),
#   ('이야기', 1)],
#  [('집밥', 3),
#   ('완전', 3),
#   ('오늘', 2),
#   ('날', 2),
#   ('뭐', 1),
#   ('고사', 1),
#   ('모음', 1),
#   ('메뉴', 1),
#   ('추천', 1),
#   ('떡갈비', 1),
#   ('정식', 1),
#   ('지하', 1),
#   ('주차장', 1),
#   ('주말', 1),
#   ('어제', 1),
#   ('낮', 1),
#   ('부터', 1),
#   ('만석', 1),
#   ('해장국', 1),
#   ('아침', 1),
#   ('국', 1),
#   ('시원', 1),
#   ('소리', 1),
#   ('절로', 1),
#   ('현이', 1),
#   ('도시락', 1)],
#  [('카페', 3),
#   ('추천', 2),
#   ('녹', 2),
#   ('아메리카노', 2),
#   ('서면', 1),
#   ('날', 1),
#   ('가기', 1),
#   ('코타츠', 1),
#   ('진짜', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('아들', 1),
#   ('서면역', 1),
#   ('번', 1),
#   ('출구', 1),
#   ('도보', 1),
#   ('분거', 1),
#   ('리', 1),
#   ('영업', 1),
#   ('시간', 1),
#   ('평일', 1),
#   ('드디어', 1),
#   ('저희', 1),
#   ('메뉴', 1),
#   ('오용', 1),
#   ('당고', 1),
#   ('세트', 1),
#   ('맘', 1),
#   ('대루', 1)],
#  [('모임', 2),
#   ('국물', 2),
#   ('추천', 2),
#   ('닭', 2),
#   ('마리', 2),
#   ('강남', 1),
#   ('맛집', 1),
#   ('날', 1),
#   ('장소', 1),
#   ('맛', 1),
#   ('친구', 1),
#   ('과', 1),
#   ('우리', 1),
#   ('식사', 1),
#   ('메뉴', 1),
#   ('결정', 1),
#   ('왜', 1),
#   ('가요', 1),
#   ('저', 1),
#   ('얼', 1),
#   ('마전', 1),
#   ('롱패딩', 1),
#   ('완전', 1),
#   ('무장', 1),
#   ('분', 1),
#   ('봄', 1),
#   ('충격', 1),
#   ('새댁', 1),
#   ('도착', 1),
#   ('우당', 1),
#   ('탕밍', 1)],
#  [('겨울', 3),
#   ('간식', 3),
#   ('세트', 3),
#   ('추천', 3),
#   ('부산', 2),
#   ('오빠', 2),
#   ('메뉴', 2),
#   ('어묵', 2),
#   ('커피차', 1),
#   ('차', 1),
#   ('를', 1),
#   ('해', 1),
#   ('빠빰', 1),
#   ('어떡', 1),
#   ('떡볶이', 1),
#   ('바로', 1),
#   ('날', 1),
#   ('몸', 1),
#   ('녹', 1),
#   ('이기', 1),
#   ('솔직', 1),
#   ('부산여행', 1),
#   ('맛집', 1),
#   ('리뷰', 1)],
#  [('순대국', 3),
#   ('장궁', 2),
#   ('날', 2),
#   ('인삼', 2),
#   ('서수', 1),
#   ('원', 1),
#   ('맛집', 1),
#   ('국물', 1),
#   ('최고', 1),
#   ('국밥', 1),
#   ('땡', 1),
#   ('기기', 1),
#   ('마련', 1),
#   ('메뉴', 1),
#   ('를', 1),
#   ('어간', 1),
#   ('보양식', 1),
#   ('양', 1),
#   ('분', 1),
#   ('특', 1),
#   ('주', 1),
#   ('문하', 1),
#   ('는걸', 1),
#   ('추천', 1),
#   ('고', 1),
#   ('이건', 1),
#   ('영양', 1),
#   ('헛개', 1),
#   ('대추', 1),
#   ('어서', 1),
#   ('숸댁', 1),
#   ('로그', 1)],
#  [('날', 2),
#   ('별내', 2),
#   ('몸', 1),
#   ('수', 1),
#   ('맛집', 1),
#   ('앤', 1),
#   ('점', 1),
#   ('씨', 1),
#   ('먹기', 1),
#   ('항아리', 1),
#   ('누룽지', 1),
#   ('해산물', 1),
#   ('파스타', 1),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('인', 1),
#   ('이유', 1),
#   ('고요', 1),
#   ('아직', 1),
#   ('안', 1),
#   ('보신', 1),
#   ('분', 1),
#   ('꼭', 1),
#   ('보시', 1),
#   ('길', 1),
#   ('포스팅', 1),
#   ('소정', 1),
#   ('원고료', 1),
#   ('작', 1),
#   ('성하', 1),
#   ('님', 1),
#   ('블로그', 1)],
#  [('감자탕', 9),
#   ('경산', 6),
#   ('다른', 4),
#   ('점', 3),
#   ('맛집', 3),
#   ('정평역', 3),
#   ('중산', 2),
#   ('남', 2),
#   ('추천', 2),
#   ('밥집', 2),
#   ('날', 1),
#   ('뚝배기', 1),
#   ('뼈', 1),
#   ('전골', 1),
#   ('중산동', 1),
#   ('메뉴', 1)],
#  [('먹기', 2),
#   ('짬뽕', 2),
#   ('날', 1),
#   ('경기도', 1),
#   ('시흥', 1),
#   ('맛집', 1),
#   ('고구려', 1),
#   ('본점', 1),
#   ('우리', 1),
#   ('메뉴', 1),
#   ('산선', 1),
#   ('짜장', 1),
#   ('차돌박이', 1),
#   ('짬뽕밥', 1),
#   ('아침', 1),
#   ('일찍', 1),
#   ('부터', 1),
#   ('움직', 1),
#   ('여서', 1),
#   ('음식', 1),
#   ('추천', 1),
#   ('점심시간', 1),
#   ('간다', 1),
#   ('대기', 1),
#   ('수', 1),
#   ('것', 1),
#   ('오목', 1),
#   ('교', 1),
#   ('미용실', 1),
#   ('리얼', 1),
#   ('드', 1),
#   ('살롱', 1),
#   ('부원장', 1),
#   ('가온', 1)],
#  [('해장국', 2),
#   ('아하', 2),
#   ('내장탕', 2),
#   ('사이드', 2),
#   ('천', 2),
#   ('방배동', 1),
#   ('한사', 1),
#   ('바리', 1),
#   ('서초', 1),
#   ('점', 1),
#   ('날', 1),
#   ('생각', 1),
#   ('포장', 1),
#   ('추천', 1),
#   ('국밥', 1),
#   ('남자친구', 1),
#   ('해장', 1),
#   ('돼지국밥', 1),
#   ('저', 1),
#   ('다가', 1),
#   ('종류', 1),
#   ('녹두', 1),
#   ('전', 1),
#   ('명', 1),
#   ('이서', 1),
#   ('메뉴', 1),
#   ('개', 1),
#   ('개인', 1),
#   ('데', 1),
#   ('가지', 1),
#   ('일상', 1)]]

# %%
#중복값을 더하기 위해 딕셔너리 형태로 만들어줌 
df = pd.DataFrame()
for i in range(0,len(an)) :
    en = dict(an[i])
    df = df.append({'sentiment' : en}, ignore_index=True)

df
# Out:
#                                              sentiment
# 0    {'추천': 5, '날': 3, '국물': 3, '메뉴': 3, '요리': 2, '...
# 1    {'저녁': 5, '메뉴': 2, '추천': 2, '날': 2, '순두부찌개': 2...
# 2    {'레시피': 2, '날': 2, '먹음': 2, '더': 2, '육수': 2, '...
# 3    {'묵은지': 3, '날': 2, '메뉴': 2, '저녁': 2, '닭도리탕': 2...
# 4    {'맛집': 6, '점심': 3, '사골': 3, '칼국수': 3, '전주': 3,...
# ..                                                 ...
# 987  {'순대국': 3, '장궁': 2, '날': 2, '인삼': 2, '서수': 1, ...
# 988  {'날': 2, '별내': 2, '몸': 1, '수': 1, '맛집': 1, '앤'...
# 989  {'감자탕': 9, '경산': 6, '다른': 4, '점': 3, '맛집': 3, ...
# 990  {'먹기': 2, '짬뽕': 2, '날': 1, '경기도': 1, '시흥': 1, ...
# 991  {'해장국': 2, '아하': 2, '내장탕': 2, '사이드': 2, '천': 2...
#
# [992 rows x 1 columns]

# %%
#중복 값을 더하는 함수 
from operator import itemgetter
def sum_sentiment(x):
    init_dict = list(x)

    result = {}
    for d in init_dict:
        for k in d.keys():
            result[k] = result.get(k, 0) + d[k]
    return result

# %%
dic_sum = df.agg({'sentiment' : lambda x : sum_sentiment(x)})
type(dic_sum)
# Out:
# pandas.core.series.Series

# %%
#더해진 값이 담긴 데이터프레임을 리스트 형태로 변경
dic_sum = dic_sum.values.tolist()
dic_sum
# Out:
# [{'추천': 1262,
#   '날': 1925,
#   '국물': 369,
#   '메뉴': 1438,
#   '요리': 146,
#   '때': 134,
#   '풀무원': 15,
#   '오우': 3,
#   '종': 2,
#   '정통': 1,
#   '아쿠': 1,
#   '춥다': 5,
#   '절로': 4,
#   '생각': 357,
#   '뭘': 6,
#   '살': 19,
#   '쿵': 1,
#   '오늘': 266,
#   '우동': 138,
#   '간편식': 3,
#   '유부초밥': 1,
#   '김밥': 17,
#   '겨울': 153,
#   '음식': 159,
#   '저녁': 166,
#   '꾱꾱꾱': 1,
#   '하루하루': 5,
#   '순두부찌개': 9,
#   '법': 39,
#   '부천': 7,
#   '내비': 3,
#   '이야기': 73,
#   '저희': 44,
#   '블로그': 75,
#   '방문': 67,
#   '해주': 21,
#   '셔': 7,
#   '감사': 9,
#   '매일': 19,
#   '상이': 1,
#   '고민': 35,
#   '요': 118,
#   '사': 16,
#   '먹기': 78,
#   '질리': 4,
#   '가끔': 11,
#   '확': 10,
#   '생기': 2,
#   '고요': 37,
#   '블박': 2,
#   '썬팅': 2,
#   '비': 66,
#   '매립': 3,
#   '레시피': 40,
#   '먹음': 9,
#   '더': 131,
#   '육수': 39,
#   '호로': 9,
#   '록': 18,
#   '캠핑': 19,
#   '어묵탕': 10,
#   '꼬치': 4,
#   '오뎅': 50,
#   '탕': 72,
#   '준비': 26,
#   '끼': 52,
#   '식사': 55,
#   '해': 100,
#   '결하': 2,
#   '선택': 32,
#   '사계절': 2,
#   '모두': 23,
#   '시크': 2,
#   '도도': 2,
#   '토깽': 3,
#   '효': 4,
#   '묵은지': 6,
#   '닭도리탕': 5,
#   '초': 11,
#   '간단': 74,
#   '닭볶음탕': 12,
#   '밥위': 1,
#   '밥': 73,
#   '개꿀맛': 1,
#   '완성': 1,
#   '이제': 9,
#   '숙성': 1,
#   '꽤': 15,
#   '도': 69,
#   '전해': 2,
#   '보시': 28,
#   '스마트': 1,
#   '라이프': 13,
#   '맛집': 876,
#   '점심': 342,
#   '사골': 21,
#   '칼국수': 349,
#   '전주': 18,
#   '시가지': 3,
#   '장소': 28,
#   '신': 10,
#   '한음': 1,
#   '식': 35,
#   '주신': 5,
#   '전북': 1,
#   '경찰청': 1,
#   '방송국': 1,
#   '회식': 17,
#   '단체': 3,
#   '모임': 15,
#   '직장인': 31,
#   '효자동': 2,
#   '무엇': 11,
#   '행복': 42,
#   '감미': 3,
#   '옥': 22,
#   '도가니탕': 5,
#   '방촌': 2,
#   '떡볶이': 37,
#   '간편': 8,
#   '집밥': 23,
#   '저': 116,
#   '전': 53,
#   '냉장고': 2,
#   '빼': 3,
#   '조리': 3,
#   '찬물': 1,
#   '면서': 40,
#   '해동': 1,
#   '수': 84,
#   '어요': 268,
#   '냄비': 3,
#   '로': 119,
#   '남편': 12,
#   '제': 48,
#   '대로': 6,
#   '이루': 4,
#   '메': 12,
#   '커피': 37,
#   '레몬차': 2,
#   '마시기': 7,
#   '평소': 3,
#   '자주': 20,
#   '방': 32,
#   '문하': 21,
#   '겨울철': 15,
#   '종종': 9,
#   '구': 13,
#   '매하': 2,
#   '것': 147,
#   '자몽차': 1,
#   '음번': 1,
#   '한번': 45,
#   '심슨': 1,
#   '부대찌개': 63,
#   '안양': 1,
#   '명학역': 1,
#   '현지': 7,
#   '두꺼비': 3,
#   '패딩': 1,
#   '다가': 34,
#   '다시': 14,
#   '메인': 37,
#   '심플': 11,
#   '원래': 11,
#   '몇': 7,
#   '가지': 37,
#   '집중': 1,
#   '소': 51,
#   '소한': 27,
#   '일상': 97,
#   '만두전골': 33,
#   '천동': 3,
#   '만두': 78,
#   '수원': 17,
#   '평양': 10,
#   '손': 37,
#   '입맛': 5,
#   '천': 5,
#   '몸': 92,
#   '녹': 20,
#   '속': 31,
#   '일단': 13,
#   '쇠고기': 2,
#   '부터': 33,
#   '질': 5,
#   '기기': 7,
#   '정': 18,
#   '삼화': 1,
#   '가락': 12,
#   '아이': 34,
#   '간식': 17,
#   '유부': 13,
#   '짬뽕': 84,
#   '먹방': 3,
#   '안녕': 56,
#   '요즘': 121,
#   '일': 18,
#   '교차': 1,
#   '심해': 1,
#   '지면': 4,
#   '아침': 28,
#   '미거': 2,
#   '네': 5,
#   '롯데': 14,
#   '수제비': 57,
#   '상품': 2,
#   '얼': 43,
#   '고추장': 5,
#   '만들기': 29,
#   '누구': 5,
#   '별': 7,
#   '다른': 41,
#   '재료': 23,
#   '이도': 5,
#   '점': 115,
#   '최고': 57,
#   '매력': 7,
#   '었던': 4,
#   '제품': 1,
#   '었다': 7,
#   '리하': 4,
#   '마트': 8,
#   '고추': 8,
#   '자': 19,
#   '죽': 30,
#   '뜻': 27,
#   '그': 69,
#   '래서': 36,
#   '국밥': 117,
#   '류': 14,
#   '극적': 3,
#   '려고': 18,
#   '거나': 16,
#   '포장': 22,
#   '이해': 3,
#   '직접': 7,
#   '본적': 1,
#   '별로': 12,
#   '짱구': 1,
#   '밍': 4,
#   '샤브샤브': 77,
#   '익선동': 4,
#   '온천': 6,
#   '집': 154,
#   '섭': 5,
#   '웨이': 25,
#   '팅': 25,
#   '분만': 1,
#   '체감': 1,
#   '한시': 1,
#   '간': 16,
#   '기다림': 2,
#   '추위': 10,
#   '여기': 39,
#   '꼭': 44,
#   '가보': 25,
#   '껏': 2,
#   '어서': 102,
#   '배부': 7,
#   '르': 4,
#   '또': 51,
#   '여행': 59,
#   '선유도역': 2,
#   '설렁탕': 27,
#   '이남': 3,
#   '장': 34,
#   '생': 25,
#   '긴지': 2,
#   '오래': 14,
#   '전통': 11,
#   '이': 78,
#   '남장': 1,
#   '기도': 14,
#   '들깨': 14,
#   '울산': 22,
#   '한사': 14,
#   '바리': 6,
#   '판': 94,
#   '바지락': 18,
#   '엄마': 21,
#   '시더': 11,
#   '아하': 50,
#   '시': 26,
#   '분': 54,
#   '라면': 27,
#   '인기': 17,
#   '아날로그': 1,
#   '졔졔': 1,
#   '인': 65,
#   '혼밥': 20,
#   '혼자': 5,
#   '서도': 15,
#   '맘마': 1,
#   '이지': 21,
#   '나': 61,
#   '봄': 15,
#   '여름': 6,
#   '가을': 13,
#   '상관': 1,
#   '입하': 3,
#   '역시': 45,
#   '면': 52,
#   '은': 57,
#   '냉수': 1,
#   '마찰': 1,
#   '쫄깃': 6,
#   '낭낭': 2,
#   '개성': 9,
#   '오산': 2,
#   '계절': 20,
#   '숫': 1,
#   '이면': 38,
#   '여러분': 16,
#   '뚝배기': 10,
#   '개': 47,
#   '인적': 11,
#   '아주': 45,
#   '가족': 24,
#   '친': 6,
#   '구들': 9,
#   '술': 31,
#   '한잔': 37,
#   '비상': 1,
#   '누수': 1,
#   '탐지': 1,
#   '돼지': 13,
#   '곱창': 19,
#   '곱창전골': 35,
#   '옛날': 16,
#   '마을': 15,
#   '본점': 23,
#   '거': 68,
#   '싹': 6,
#   '동생': 7,
#   '해달': 4,
#   '하니': 29,
#   '전골': 83,
#   '옥훼이': 1,
#   '바로': 64,
#   '주문': 101,
#   '미미': 4,
#   '밍님': 1,
#   '종로': 21,
#   '해장국': 62,
#   '뼈': 39,
#   '조가': 1,
#   '가조': 2,
#   '가점': 1,
#   '심': 7,
#   '은근': 3,
#   '곳': 108,
#   '사무실': 7,
#   '좀': 30,
#   '신림역': 1,
#   '밀키': 18,
#   '트': 20,
#   '밥끼': 1,
#   '일어': 1,
#   '가기': 23,
#   '를': 53,
#   '골': 18,
#   '라주시': 2,
#   '하나': 46,
#   '확대': 1,
#   '위': 17,
#   '달': 12,
#   '명동': 22,
#   '메뉴인': 1,
#   '교자': 9,
#   '처럼': 55,
#   '날씨': 94,
#   '본사': 1,
#   '구내식당': 2,
#   '아빠': 8,
#   '찌개': 29,
#   '지존': 2,
#   '잔': 11,
#   '한파': 9,
#   '술안주': 9,
#   '리뷰': 28,
#   '적극': 3,
#   '김치찌개': 23,
#   '고추장찌개': 1,
#   '닭': 75,
#   '대용': 2,
#   '강추': 15,
#   '움직': 2,
#   '아해': 7,
#   '카스': 3,
#   '제동': 2,
#   '사랑': 16,
#   '와이파이': 3,
#   '고': 76,
#   '둥이': 3,
#   '인천': 19,
#   '그릇': 73,
#   '즐겨드': 1,
#   '시나': 2,
#   '중': 54,
#   '동네': 11,
#   '갈비찜': 10,
#   '곽만근': 1,
#   '갈비탕': 38,
#   '인천광역시': 2,
#   '서구': 8,
#   '원': 11,
#   '당대': 1,
#   '완': 4,
#   '정역': 1,
#   '다이소': 3,
#   '라인': 2,
#   '위치': 35,
#   '전집': 7,
#   '마곡': 11,
#   '나루': 2,
#   '그날': 3,
#   '업무': 1,
#   '왕': 11,
#   '일반': 10,
#   '막걸리': 5,
#   '업': 2,
#   '무왕': 1,
#   '디': 9,
#   '육': 9,
#   '간청': 1,
#   '그나': 3,
#   '마': 12,
#   '만하': 4,
#   '출근': 6,
#   '마음': 12,
#   '여보': 2,
#   '구로': 4,
#   '디지털': 6,
#   '단지': 5,
#   '뒤뚱뒤뚱': 1,
#   '등촌': 30,
#   '샤브': 49,
#   '말': 14,
#   '뭐해': 1,
#   '시원': 25,
#   '칼칼': 5,
#   '고고': 6,
#   '볶음밥': 14,
#   '주저': 1,
#   '설겆': 1,
#   '필요': 19,
#   '만큼': 15,
#   '쌱': 1,
#   '맛': 151,
#   '평택': 2,
#   '피부': 1,
#   '앤': 6,
#   '클린': 1,
#   '광화문': 8,
#   '타워': 2,
#   '영업': 24,
#   '시간': 52,
#   '길거리': 4,
#   '포장마차': 6,
#   '어가': 36,
#   '어묵국': 3,
#   '물': 23,
#   '매콤': 39,
#   '기억': 6,
#   '로라': 1,
#   '방앗간': 1,
#   '서울': 43,
#   '종로구': 1,
#   '길': 33,
#   '층': 14,
#   '소호': 1,
#   '거리': 20,
#   '호': 16,
#   '또박': 1,
#   '육아': 6,
#   '신설': 4,
#   '제주': 14,
#   '재벌': 1,
#   '국수': 54,
#   '번': 32,
#   '낮': 6,
#   '기온': 3,
#   '영하': 3,
#   '안팍': 1,
#   '카페': 63,
#   '문틈': 1,
#   '찬': 14,
#   '바람': 24,
#   '정도': 18,
#   '토요일': 4,
#   '오후': 5,
#   '단무지': 3,
#   '양파': 5,
#   '적당': 7,
#   '접시': 7,
#   '제주도': 4,
#   '관련': 3,
#   '정보': 8,
#   '관광지': 2,
#   '숙소': 1,
#   '렌트': 1,
#   '밀': 12,
#   '스': 15,
#   '어묵': 25,
#   '외식': 20,
#   '걱정': 4,
#   '시기': 4,
#   '지니': 8,
#   '특별': 9,
#   '키트': 4,
#   '이번': 24,
#   '이웃': 9,
#   '세상': 23,
#   '홍대': 25,
#   '제격': 24,
#   '순대': 30,
#   '진짜': 62,
#   '어도': 16,
#   '덜덜': 3,
#   '술술': 2,
#   '콜라': 2,
#   '제일': 21,
#   '김치': 46,
#   '수제': 7,
#   '돈까스': 19,
#   '사장': 7,
#   '센스': 3,
#   '테이블': 27,
#   '마다': 13,
#   '종이컵': 1,
#   '그라인더': 1,
#   '소금': 6,
#   '후추': 2,
#   '다음': 18,
#   '게': 37,
#   '무조건': 10,
#   '정말': 64,
#   '만복': 3,
#   '멸치': 13,
#   '쌀국수': 66,
#   '잔치국수': 10,
#   '마포': 4,
#   '강력': 14,
#   '간날': 1,
#   '휭휭': 1,
#   '불어': 9,
#   '레트로': 3,
#   '식당': 64,
#   '오작교': 1,
#   '통신': 1,
#   '스토리': 12,
#   '포': 20,
#   '레드': 4,
#   '구월': 3,
#   '구월동': 5,
#   '미리': 8,
#   '보고': 14,
#   '가시': 14,
#   '사진': 33,
#   '드립': 37,
#   '문해': 1,
#   '편': 22,
#   '임용': 1,
#   '동쓰': 1,
#   '청년': 10,
#   '다방': 5,
#   '즉석': 6,
#   '차돌': 8,
#   '강원': 1,
#   '인제': 1,
#   '슬라이드': 2,
#   '종류': 36,
#   '치킨': 11,
#   '이나': 27,
#   '사이드': 23,
#   '년': 3,
#   '오랜만': 19,
#   '었는데': 3,
#   '만족': 10,
#   '체험': 10,
#   '보고서': 4,
#   '저절로': 1,
#   '따끈따끈': 7,
#   '동해': 1,
#   '수요일': 3,
#   '정기': 2,
#   '휴무': 6,
#   '고등학생': 1,
#   '시절': 2,
#   '약': 2,
#   '지나': 10,
#   '뭐': 49,
#   '늦': 1,
#   '더라도': 4,
#   '거지': 4,
#   '라챠챠': 1,
#   '수육': 28,
#   '소고기': 30,
#   '어린이': 5,
#   '보양식': 14,
#   '소스': 12,
#   '살짝': 15,
#   '어른': 6,
#   '용': 23,
#   '고기': 46,
#   '육개장': 30,
#   '온': 24,
#   '보양': 7,
#   '코스트코': 2,
#   '덩이': 2,
#   '쟁여놨': 1,
#   '푹': 5,
#   '여서': 12,
#   '김': 9,
#   '헤롱': 1,
#   '로그': 25,
#   '가디': 1,
#   '역': 12,
#   '홍콩': 1,
#   '반점': 3,
#   '급격': 1,
#   '자연': 5,
#   '눈': 23,
#   '감': 5,
#   '동료': 3,
#   '중식': 4,
#   '도서': 1,
#   '출판': 1,
#   '지식': 1,
#   '과감': 1,
#   '성': 3,
#   '공식': 15,
#   '온정': 1,
#   '매실': 5,
#   '더더': 8,
#   '담': 7,
#   '인용': 5,
#   '성수': 15,
#   '완당': 4,
#   '조합': 15,
#   '내': 31,
#   '산': 59,
#   '자마자': 10,
#   '보이': 13,
#   '키오': 2,
#   '스크': 2,
#   '가능': 36,
#   '도전': 4,
#   '볼망': 1,
#   '항상': 11,
#   '고정': 1,
#   '픽': 5,
#   '당면': 7,
#   '공간': 13,
#   '니지': 4,
#   '바': 31,
#   '고루': 1,
#   '링': 3,
#   '더하기': 2,
#   '강남': 12,
#   '직딩': 3,
#   '그니': 13,
#   '처': 11,
#   '뿐': 13,
#   '막내': 2,
#   '님들': 9,
#   '남녀': 1,
#   '노소': 1,
#   '돈': 52,
#   '스코어': 1,
#   '알탕': 13,
#   '바다': 14,
#   '황제': 2,
#   '듯': 21,
#   '뭔가': 12,
#   '끈': 53,
#   '듬북': 1,
#   '알': 17,
#   '어간': 6,
#   '대흥동': 3,
#   '해물': 23,
#   '전문점': 23,
#   '정식': 9,
#   '인분': 25,
#   '밑반찬': 9,
#   '붓다': 1,
#   '붓솝': 1,
#   '순대국': 78,
#   '청라': 6,
#   '진지': 2,
#   '역삼동': 5,
#   '호박': 4,
#   '불고기': 20,
#   '더니': 16,
#   '점심시간': 9,
#   '을지': 12,
#   '덩치': 1,
#   '덩': 1,
#   '부산': 47,
#   '옹심이': 17,
#   '정관': 8,
#   '직원': 7,
#   '궁금': 6,
#   '매번': 8,
#   '고하': 3,
#   '그냥': 26,
#   '면도': 1,
#   '러블': 2,
#   '리수': 2,
#   '달달': 13,
#   '하루': 32,
#   '만': 16,
#   '나기': 8,
#   '호호': 9,
#   '셋': 7,
#   '약속': 4,
#   '터': 17,
#   '일본': 9,
#   '가정': 1,
#   '우리': 52,
#   '중간지점': 1,
#   '쯤': 6,
#   '이기': 16,
#   '리스트': 3,
#   '여러': 13,
#   '이서': 5,
#   '우나기': 1,
#   '명란': 5,
#   '파스타': 7,
#   '오므라이스': 1,
#   '찍찍': 1,
#   '부인': 1,
#   '구이': 22,
#   '도루묵': 4,
#   '사모': 2,
#   '거의': 13,
#   '만석': 5,
#   '여전': 1,
#   '깜짝': 1,
#   '문적': 1,
#   '짐': 9,
#   '햄': 6,
#   '듬뿍': 10,
#   '글': 14,
#   '뚜': 2,
#   '지고': 6,
#   '자꾸만': 3,
#   '단골': 8,
#   '수아': 2,
#   '대원': 2,
#   '신지': 1,
#   '포스팅': 17,
#   '보': 24,
#   '데': 43,
#   '의': 40,
#   '추어탕': 33,
#   '구리': 9,
#   '갈매동': 1,
#   '별내': 8,
#   '파서': 4,
#   '판도': 7,
#   '여': 8,
#   '크리': 2,
#   '슈어': 1,
#   '애호박': 4,
#   '동리': 3,
#   '감성': 8,
#   '마포역': 1,
#   '술집': 32,
#   '장의': 2,
#   '판이': 19,
#   '주로': 3,
#   '애': 6,
#   '호박찌개': 1,
#   '꼬막': 8,
#   '비빔밥': 8,
#   '전이': 2,
#   '루나': 2,
#   '나나': 2,
#   '서초': 7,
#   '백합': 6,
#   '지난번': 3,
#   '교': 7,
#   '대쪽': 1,
#   '사류': 1,
#   '대표': 26,
#   '볶음': 9,
#   '가용': 1,
#   '여행가': 3,
#   '반': 13,
#   '성남': 6,
#   '분당': 7,
#   '평가': 2,
#   '평냉': 1,
#   '냉면': 14,
#   '닭고기': 5,
#   '왜': 15,
#   '으슬으': 1,
#   '슬하': 1,
#   '예의': 2,
#   '상': 13,
#   '월급': 1,
#   '어복': 7,
#   '쟁반': 9,
#   '기분': 11,
#   '젠': 4,
#   '지도': 9,
#   '못': 12,
#   '원마운트': 3,
#   '대화동': 2,
#   '한식': 11,
#   '조만간': 3,
#   '출동': 1,
#   '예정': 2,
#   '계시': 3,
#   '행자': 1,
#   '갈치조림': 2,
#   '갈치': 1,
#   '고소': 14,
#   '양념': 8,
#   '베': 2,
#   '워': 7,
#   '너비': 2,
#   '블링': 1,
#   '국': 25,
#   '뚝딱': 8,
#   '내심': 1,
#   '봉지': 1,
#   '다시마': 2,
#   '무': 15,
#   '대파': 4,
#   '쑥갓': 5,
#   '약간': 6,
#   '간장': 19,
#   '마늘': 7,
#   '그녀': 1,
#   '이비가': 7,
#   '대전': 18,
#   '둔산동': 9,
#   '최근': 7,
#   '속도': 5,
#   '체인점': 4,
#   '늘': 16,
#   '카레': 1,
#   '아로마테라피': 1,
#   '스튜디오': 3,
#   '고흥': 12,
#   '관광': 7,
#   '양산박': 1,
#   '박': 4,
#   '두': 26,
#   '합': 8,
#   '북적': 2,
#   '범계': 1,
#   '성경': 1,
#   '택': 8,
#   '전부': 7,
#   '예약': 11,
#   '석도': 1,
#   '먼저': 14,
#   '준': 2,
#   '는걸': 15,
#   '위해': 13,
#   '쯔모': 1,
#   '욧': 1,
#   '양푼': 9,
#   '동태': 24,
#   '용인': 13,
#   '어탕': 2,
#   '으쓱': 1,
#   '냠삐공': 1,
#   '특공대': 1,
#   '낙지볶음': 8,
#   '씨': 50,
#   '드릴': 20,
#   '피로': 3,
#   '냉국': 1,
#   '연우': 4,
#   '컴퓨터': 4,
#   '여수': 5,
#   '다양': 34,
#   '가장': 30,
#   '청담': 3,
#   '앤전': 1,
#   '분위기': 18,
#   '여서동': 3,
#   '안주': 31,
#   '까지': 50,
#   '편이': 7,
#   '부분': 4,
#   '신기': 3,
#   '답': 12,
#   '전통주': 2,
#   '하이': 4,
#   '볼': 9,
#   '소주': 22,
#   '하나라': 4,
#   '감자탕': 74,
#   '회기역': 3,
#   '아라하': 2,
#   '사람': 32,
#   '사골국': 1,
#   '도시': 1,
#   '전자랜드': 1,
#   '매우': 8,
#   '드': 16,
#   '실지': 1,
#   '한국': 13,
#   '한가지': 6,
#   '충무로': 3,
#   '마리': 38,
#   '평점': 3,
#   '가격': 69,
#   '천원': 9,
#   '공릉': 1,
#   '슴슴': 1,
#   '및': 16,
#   '네이버': 3,
#   '만원': 6,
#   '닭곰탕': 8,
#   '명': 18,
#   '땅': 4,
#   '이의': 24,
#   '어디': 9,
#   '시청': 3,
#   '앞': 21,
#   '음': 4,
#   '대신': 7,
#   '욕구': 1,
#   '아들': 5,
#   '꼬': 2,
#   '라지': 2,
#   '마름': 2,
#   '목포': 6,
#   '월남쌈': 4,
#   '신랑': 5,
#   '유치원': 1,
#   '자고': 5,
#   '배': 18,
#   '꽃': 8,
#   '존재': 1,
#   '블루': 4,
#   '보틀': 3,
#   '여의도': 36,
#   '주차': 22,
#   '팁': 4,
#   '플로': 1,
#   '현대': 12,
#   '쥬': 5,
#   '제이': 4,
#   '맘': 12,
#   '라떼': 25,
#   '지금': 17,
#   '아이스커피': 1,
#   '플루토': 1,
#   '곰탕': 44,
#   '상암동': 2,
#   '나주': 12,
#   '상암': 1,
#   '돌솥밥': 2,
#   '건강': 18,
#   '챙': 1,
#   '기고': 5,
#   '조': 10,
#   '마루': 17,
#   '상동역': 2,
#   '지극': 3,
#   '리얼': 6,
#   '후기': 47,
#   '양': 25,
#   '나위': 1,
#   '인정': 5,
#   '보신': 36,
#   '노리': 1,
#   '만두국': 12,
#   '일산': 26,
#   '그것': 5,
#   '순서대로': 1,
#   '막': 4,
#   '유명': 13,
#   '집들이': 6,
#   '러하': 2,
#   '듯이': 4,
#   '주': 28,
#   '모션': 1,
#   '렌터카': 1,
#   '보험사': 1,
#   '고대': 1,
#   '차': 31,
#   '전문': 10,
#   '기업': 2,
#   '하월곡동': 1,
#   '첫': 9,
#   '해장': 35,
#   '성북구': 1,
#   '주민': 1,
#   '월곡역': 1,
#   '출구': 10,
#   '건': 19,
#   ...}]

# %%
#딕셔너리 형태로 만들어 줌
df = dic_sum[0]
df
# Out:
# {'추천': 1262,
#  '날': 1925,
#  '국물': 369,
#  '메뉴': 1438,
#  '요리': 146,
#  '때': 134,
#  '풀무원': 15,
#  '오우': 3,
#  '종': 2,
#  '정통': 1,
#  '아쿠': 1,
#  '춥다': 5,
#  '절로': 4,
#  '생각': 357,
#  '뭘': 6,
#  '살': 19,
#  '쿵': 1,
#  '오늘': 266,
#  '우동': 138,
#  '간편식': 3,
#  '유부초밥': 1,
#  '김밥': 17,
#  '겨울': 153,
#  '음식': 159,
#  '저녁': 166,
#  '꾱꾱꾱': 1,
#  '하루하루': 5,
#  '순두부찌개': 9,
#  '법': 39,
#  '부천': 7,
#  '내비': 3,
#  '이야기': 73,
#  '저희': 44,
#  '블로그': 75,
#  '방문': 67,
#  '해주': 21,
#  '셔': 7,
#  '감사': 9,
#  '매일': 19,
#  '상이': 1,
#  '고민': 35,
#  '요': 118,
#  '사': 16,
#  '먹기': 78,
#  '질리': 4,
#  '가끔': 11,
#  '확': 10,
#  '생기': 2,
#  '고요': 37,
#  '블박': 2,
#  '썬팅': 2,
#  '비': 66,
#  '매립': 3,
#  '레시피': 40,
#  '먹음': 9,
#  '더': 131,
#  '육수': 39,
#  '호로': 9,
#  '록': 18,
#  '캠핑': 19,
#  '어묵탕': 10,
#  '꼬치': 4,
#  '오뎅': 50,
#  '탕': 72,
#  '준비': 26,
#  '끼': 52,
#  '식사': 55,
#  '해': 100,
#  '결하': 2,
#  '선택': 32,
#  '사계절': 2,
#  '모두': 23,
#  '시크': 2,
#  '도도': 2,
#  '토깽': 3,
#  '효': 4,
#  '묵은지': 6,
#  '닭도리탕': 5,
#  '초': 11,
#  '간단': 74,
#  '닭볶음탕': 12,
#  '밥위': 1,
#  '밥': 73,
#  '개꿀맛': 1,
#  '완성': 1,
#  '이제': 9,
#  '숙성': 1,
#  '꽤': 15,
#  '도': 69,
#  '전해': 2,
#  '보시': 28,
#  '스마트': 1,
#  '라이프': 13,
#  '맛집': 876,
#  '점심': 342,
#  '사골': 21,
#  '칼국수': 349,
#  '전주': 18,
#  '시가지': 3,
#  '장소': 28,
#  '신': 10,
#  '한음': 1,
#  '식': 35,
#  '주신': 5,
#  '전북': 1,
#  '경찰청': 1,
#  '방송국': 1,
#  '회식': 17,
#  '단체': 3,
#  '모임': 15,
#  '직장인': 31,
#  '효자동': 2,
#  '무엇': 11,
#  '행복': 42,
#  '감미': 3,
#  '옥': 22,
#  '도가니탕': 5,
#  '방촌': 2,
#  '떡볶이': 37,
#  '간편': 8,
#  '집밥': 23,
#  '저': 116,
#  '전': 53,
#  '냉장고': 2,
#  '빼': 3,
#  '조리': 3,
#  '찬물': 1,
#  '면서': 40,
#  '해동': 1,
#  '수': 84,
#  '어요': 268,
#  '냄비': 3,
#  '로': 119,
#  '남편': 12,
#  '제': 48,
#  '대로': 6,
#  '이루': 4,
#  '메': 12,
#  '커피': 37,
#  '레몬차': 2,
#  '마시기': 7,
#  '평소': 3,
#  '자주': 20,
#  '방': 32,
#  '문하': 21,
#  '겨울철': 15,
#  '종종': 9,
#  '구': 13,
#  '매하': 2,
#  '것': 147,
#  '자몽차': 1,
#  '음번': 1,
#  '한번': 45,
#  '심슨': 1,
#  '부대찌개': 63,
#  '안양': 1,
#  '명학역': 1,
#  '현지': 7,
#  '두꺼비': 3,
#  '패딩': 1,
#  '다가': 34,
#  '다시': 14,
#  '메인': 37,
#  '심플': 11,
#  '원래': 11,
#  '몇': 7,
#  '가지': 37,
#  '집중': 1,
#  '소': 51,
#  '소한': 27,
#  '일상': 97,
#  '만두전골': 33,
#  '천동': 3,
#  '만두': 78,
#  '수원': 17,
#  '평양': 10,
#  '손': 37,
#  '입맛': 5,
#  '천': 5,
#  '몸': 92,
#  '녹': 20,
#  '속': 31,
#  '일단': 13,
#  '쇠고기': 2,
#  '부터': 33,
#  '질': 5,
#  '기기': 7,
#  '정': 18,
#  '삼화': 1,
#  '가락': 12,
#  '아이': 34,
#  '간식': 17,
#  '유부': 13,
#  '짬뽕': 84,
#  '먹방': 3,
#  '안녕': 56,
#  '요즘': 121,
#  '일': 18,
#  '교차': 1,
#  '심해': 1,
#  '지면': 4,
#  '아침': 28,
#  '미거': 2,
#  '네': 5,
#  '롯데': 14,
#  '수제비': 57,
#  '상품': 2,
#  '얼': 43,
#  '고추장': 5,
#  '만들기': 29,
#  '누구': 5,
#  '별': 7,
#  '다른': 41,
#  '재료': 23,
#  '이도': 5,
#  '점': 115,
#  '최고': 57,
#  '매력': 7,
#  '었던': 4,
#  '제품': 1,
#  '었다': 7,
#  '리하': 4,
#  '마트': 8,
#  '고추': 8,
#  '자': 19,
#  '죽': 30,
#  '뜻': 27,
#  '그': 69,
#  '래서': 36,
#  '국밥': 117,
#  '류': 14,
#  '극적': 3,
#  '려고': 18,
#  '거나': 16,
#  '포장': 22,
#  '이해': 3,
#  '직접': 7,
#  '본적': 1,
#  '별로': 12,
#  '짱구': 1,
#  '밍': 4,
#  '샤브샤브': 77,
#  '익선동': 4,
#  '온천': 6,
#  '집': 154,
#  '섭': 5,
#  '웨이': 25,
#  '팅': 25,
#  '분만': 1,
#  '체감': 1,
#  '한시': 1,
#  '간': 16,
#  '기다림': 2,
#  '추위': 10,
#  '여기': 39,
#  '꼭': 44,
#  '가보': 25,
#  '껏': 2,
#  '어서': 102,
#  '배부': 7,
#  '르': 4,
#  '또': 51,
#  '여행': 59,
#  '선유도역': 2,
#  '설렁탕': 27,
#  '이남': 3,
#  '장': 34,
#  '생': 25,
#  '긴지': 2,
#  '오래': 14,
#  '전통': 11,
#  '이': 78,
#  '남장': 1,
#  '기도': 14,
#  '들깨': 14,
#  '울산': 22,
#  '한사': 14,
#  '바리': 6,
#  '판': 94,
#  '바지락': 18,
#  '엄마': 21,
#  '시더': 11,
#  '아하': 50,
#  '시': 26,
#  '분': 54,
#  '라면': 27,
#  '인기': 17,
#  '아날로그': 1,
#  '졔졔': 1,
#  '인': 65,
#  '혼밥': 20,
#  '혼자': 5,
#  '서도': 15,
#  '맘마': 1,
#  '이지': 21,
#  '나': 61,
#  '봄': 15,
#  '여름': 6,
#  '가을': 13,
#  '상관': 1,
#  '입하': 3,
#  '역시': 45,
#  '면': 52,
#  '은': 57,
#  '냉수': 1,
#  '마찰': 1,
#  '쫄깃': 6,
#  '낭낭': 2,
#  '개성': 9,
#  '오산': 2,
#  '계절': 20,
#  '숫': 1,
#  '이면': 38,
#  '여러분': 16,
#  '뚝배기': 10,
#  '개': 47,
#  '인적': 11,
#  '아주': 45,
#  '가족': 24,
#  '친': 6,
#  '구들': 9,
#  '술': 31,
#  '한잔': 37,
#  '비상': 1,
#  '누수': 1,
#  '탐지': 1,
#  '돼지': 13,
#  '곱창': 19,
#  '곱창전골': 35,
#  '옛날': 16,
#  '마을': 15,
#  '본점': 23,
#  '거': 68,
#  '싹': 6,
#  '동생': 7,
#  '해달': 4,
#  '하니': 29,
#  '전골': 83,
#  '옥훼이': 1,
#  '바로': 64,
#  '주문': 101,
#  '미미': 4,
#  '밍님': 1,
#  '종로': 21,
#  '해장국': 62,
#  '뼈': 39,
#  '조가': 1,
#  '가조': 2,
#  '가점': 1,
#  '심': 7,
#  '은근': 3,
#  '곳': 108,
#  '사무실': 7,
#  '좀': 30,
#  '신림역': 1,
#  '밀키': 18,
#  '트': 20,
#  '밥끼': 1,
#  '일어': 1,
#  '가기': 23,
#  '를': 53,
#  '골': 18,
#  '라주시': 2,
#  '하나': 46,
#  '확대': 1,
#  '위': 17,
#  '달': 12,
#  '명동': 22,
#  '메뉴인': 1,
#  '교자': 9,
#  '처럼': 55,
#  '날씨': 94,
#  '본사': 1,
#  '구내식당': 2,
#  '아빠': 8,
#  '찌개': 29,
#  '지존': 2,
#  '잔': 11,
#  '한파': 9,
#  '술안주': 9,
#  '리뷰': 28,
#  '적극': 3,
#  '김치찌개': 23,
#  '고추장찌개': 1,
#  '닭': 75,
#  '대용': 2,
#  '강추': 15,
#  '움직': 2,
#  '아해': 7,
#  '카스': 3,
#  '제동': 2,
#  '사랑': 16,
#  '와이파이': 3,
#  '고': 76,
#  '둥이': 3,
#  '인천': 19,
#  '그릇': 73,
#  '즐겨드': 1,
#  '시나': 2,
#  '중': 54,
#  '동네': 11,
#  '갈비찜': 10,
#  '곽만근': 1,
#  '갈비탕': 38,
#  '인천광역시': 2,
#  '서구': 8,
#  '원': 11,
#  '당대': 1,
#  '완': 4,
#  '정역': 1,
#  '다이소': 3,
#  '라인': 2,
#  '위치': 35,
#  '전집': 7,
#  '마곡': 11,
#  '나루': 2,
#  '그날': 3,
#  '업무': 1,
#  '왕': 11,
#  '일반': 10,
#  '막걸리': 5,
#  '업': 2,
#  '무왕': 1,
#  '디': 9,
#  '육': 9,
#  '간청': 1,
#  '그나': 3,
#  '마': 12,
#  '만하': 4,
#  '출근': 6,
#  '마음': 12,
#  '여보': 2,
#  '구로': 4,
#  '디지털': 6,
#  '단지': 5,
#  '뒤뚱뒤뚱': 1,
#  '등촌': 30,
#  '샤브': 49,
#  '말': 14,
#  '뭐해': 1,
#  '시원': 25,
#  '칼칼': 5,
#  '고고': 6,
#  '볶음밥': 14,
#  '주저': 1,
#  '설겆': 1,
#  '필요': 19,
#  '만큼': 15,
#  '쌱': 1,
#  '맛': 151,
#  '평택': 2,
#  '피부': 1,
#  '앤': 6,
#  '클린': 1,
#  '광화문': 8,
#  '타워': 2,
#  '영업': 24,
#  '시간': 52,
#  '길거리': 4,
#  '포장마차': 6,
#  '어가': 36,
#  '어묵국': 3,
#  '물': 23,
#  '매콤': 39,
#  '기억': 6,
#  '로라': 1,
#  '방앗간': 1,
#  '서울': 43,
#  '종로구': 1,
#  '길': 33,
#  '층': 14,
#  '소호': 1,
#  '거리': 20,
#  '호': 16,
#  '또박': 1,
#  '육아': 6,
#  '신설': 4,
#  '제주': 14,
#  '재벌': 1,
#  '국수': 54,
#  '번': 32,
#  '낮': 6,
#  '기온': 3,
#  '영하': 3,
#  '안팍': 1,
#  '카페': 63,
#  '문틈': 1,
#  '찬': 14,
#  '바람': 24,
#  '정도': 18,
#  '토요일': 4,
#  '오후': 5,
#  '단무지': 3,
#  '양파': 5,
#  '적당': 7,
#  '접시': 7,
#  '제주도': 4,
#  '관련': 3,
#  '정보': 8,
#  '관광지': 2,
#  '숙소': 1,
#  '렌트': 1,
#  '밀': 12,
#  '스': 15,
#  '어묵': 25,
#  '외식': 20,
#  '걱정': 4,
#  '시기': 4,
#  '지니': 8,
#  '특별': 9,
#  '키트': 4,
#  '이번': 24,
#  '이웃': 9,
#  '세상': 23,
#  '홍대': 25,
#  '제격': 24,
#  '순대': 30,
#  '진짜': 62,
#  '어도': 16,
#  '덜덜': 3,
#  '술술': 2,
#  '콜라': 2,
#  '제일': 21,
#  '김치': 46,
#  '수제': 7,
#  '돈까스': 19,
#  '사장': 7,
#  '센스': 3,
#  '테이블': 27,
#  '마다': 13,
#  '종이컵': 1,
#  '그라인더': 1,
#  '소금': 6,
#  '후추': 2,
#  '다음': 18,
#  '게': 37,
#  '무조건': 10,
#  '정말': 64,
#  '만복': 3,
#  '멸치': 13,
#  '쌀국수': 66,
#  '잔치국수': 10,
#  '마포': 4,
#  '강력': 14,
#  '간날': 1,
#  '휭휭': 1,
#  '불어': 9,
#  '레트로': 3,
#  '식당': 64,
#  '오작교': 1,
#  '통신': 1,
#  '스토리': 12,
#  '포': 20,
#  '레드': 4,
#  '구월': 3,
#  '구월동': 5,
#  '미리': 8,
#  '보고': 14,
#  '가시': 14,
#  '사진': 33,
#  '드립': 37,
#  '문해': 1,
#  '편': 22,
#  '임용': 1,
#  '동쓰': 1,
#  '청년': 10,
#  '다방': 5,
#  '즉석': 6,
#  '차돌': 8,
#  '강원': 1,
#  '인제': 1,
#  '슬라이드': 2,
#  '종류': 36,
#  '치킨': 11,
#  '이나': 27,
#  '사이드': 23,
#  '년': 3,
#  '오랜만': 19,
#  '었는데': 3,
#  '만족': 10,
#  '체험': 10,
#  '보고서': 4,
#  '저절로': 1,
#  '따끈따끈': 7,
#  '동해': 1,
#  '수요일': 3,
#  '정기': 2,
#  '휴무': 6,
#  '고등학생': 1,
#  '시절': 2,
#  '약': 2,
#  '지나': 10,
#  '뭐': 49,
#  '늦': 1,
#  '더라도': 4,
#  '거지': 4,
#  '라챠챠': 1,
#  '수육': 28,
#  '소고기': 30,
#  '어린이': 5,
#  '보양식': 14,
#  '소스': 12,
#  '살짝': 15,
#  '어른': 6,
#  '용': 23,
#  '고기': 46,
#  '육개장': 30,
#  '온': 24,
#  '보양': 7,
#  '코스트코': 2,
#  '덩이': 2,
#  '쟁여놨': 1,
#  '푹': 5,
#  '여서': 12,
#  '김': 9,
#  '헤롱': 1,
#  '로그': 25,
#  '가디': 1,
#  '역': 12,
#  '홍콩': 1,
#  '반점': 3,
#  '급격': 1,
#  '자연': 5,
#  '눈': 23,
#  '감': 5,
#  '동료': 3,
#  '중식': 4,
#  '도서': 1,
#  '출판': 1,
#  '지식': 1,
#  '과감': 1,
#  '성': 3,
#  '공식': 15,
#  '온정': 1,
#  '매실': 5,
#  '더더': 8,
#  '담': 7,
#  '인용': 5,
#  '성수': 15,
#  '완당': 4,
#  '조합': 15,
#  '내': 31,
#  '산': 59,
#  '자마자': 10,
#  '보이': 13,
#  '키오': 2,
#  '스크': 2,
#  '가능': 36,
#  '도전': 4,
#  '볼망': 1,
#  '항상': 11,
#  '고정': 1,
#  '픽': 5,
#  '당면': 7,
#  '공간': 13,
#  '니지': 4,
#  '바': 31,
#  '고루': 1,
#  '링': 3,
#  '더하기': 2,
#  '강남': 12,
#  '직딩': 3,
#  '그니': 13,
#  '처': 11,
#  '뿐': 13,
#  '막내': 2,
#  '님들': 9,
#  '남녀': 1,
#  '노소': 1,
#  '돈': 52,
#  '스코어': 1,
#  '알탕': 13,
#  '바다': 14,
#  '황제': 2,
#  '듯': 21,
#  '뭔가': 12,
#  '끈': 53,
#  '듬북': 1,
#  '알': 17,
#  '어간': 6,
#  '대흥동': 3,
#  '해물': 23,
#  '전문점': 23,
#  '정식': 9,
#  '인분': 25,
#  '밑반찬': 9,
#  '붓다': 1,
#  '붓솝': 1,
#  '순대국': 78,
#  '청라': 6,
#  '진지': 2,
#  '역삼동': 5,
#  '호박': 4,
#  '불고기': 20,
#  '더니': 16,
#  '점심시간': 9,
#  '을지': 12,
#  '덩치': 1,
#  '덩': 1,
#  '부산': 47,
#  '옹심이': 17,
#  '정관': 8,
#  '직원': 7,
#  '궁금': 6,
#  '매번': 8,
#  '고하': 3,
#  '그냥': 26,
#  '면도': 1,
#  '러블': 2,
#  '리수': 2,
#  '달달': 13,
#  '하루': 32,
#  '만': 16,
#  '나기': 8,
#  '호호': 9,
#  '셋': 7,
#  '약속': 4,
#  '터': 17,
#  '일본': 9,
#  '가정': 1,
#  '우리': 52,
#  '중간지점': 1,
#  '쯤': 6,
#  '이기': 16,
#  '리스트': 3,
#  '여러': 13,
#  '이서': 5,
#  '우나기': 1,
#  '명란': 5,
#  '파스타': 7,
#  '오므라이스': 1,
#  '찍찍': 1,
#  '부인': 1,
#  '구이': 22,
#  '도루묵': 4,
#  '사모': 2,
#  '거의': 13,
#  '만석': 5,
#  '여전': 1,
#  '깜짝': 1,
#  '문적': 1,
#  '짐': 9,
#  '햄': 6,
#  '듬뿍': 10,
#  '글': 14,
#  '뚜': 2,
#  '지고': 6,
#  '자꾸만': 3,
#  '단골': 8,
#  '수아': 2,
#  '대원': 2,
#  '신지': 1,
#  '포스팅': 17,
#  '보': 24,
#  '데': 43,
#  '의': 40,
#  '추어탕': 33,
#  '구리': 9,
#  '갈매동': 1,
#  '별내': 8,
#  '파서': 4,
#  '판도': 7,
#  '여': 8,
#  '크리': 2,
#  '슈어': 1,
#  '애호박': 4,
#  '동리': 3,
#  '감성': 8,
#  '마포역': 1,
#  '술집': 32,
#  '장의': 2,
#  '판이': 19,
#  '주로': 3,
#  '애': 6,
#  '호박찌개': 1,
#  '꼬막': 8,
#  '비빔밥': 8,
#  '전이': 2,
#  '루나': 2,
#  '나나': 2,
#  '서초': 7,
#  '백합': 6,
#  '지난번': 3,
#  '교': 7,
#  '대쪽': 1,
#  '사류': 1,
#  '대표': 26,
#  '볶음': 9,
#  '가용': 1,
#  '여행가': 3,
#  '반': 13,
#  '성남': 6,
#  '분당': 7,
#  '평가': 2,
#  '평냉': 1,
#  '냉면': 14,
#  '닭고기': 5,
#  '왜': 15,
#  '으슬으': 1,
#  '슬하': 1,
#  '예의': 2,
#  '상': 13,
#  '월급': 1,
#  '어복': 7,
#  '쟁반': 9,
#  '기분': 11,
#  '젠': 4,
#  '지도': 9,
#  '못': 12,
#  '원마운트': 3,
#  '대화동': 2,
#  '한식': 11,
#  '조만간': 3,
#  '출동': 1,
#  '예정': 2,
#  '계시': 3,
#  '행자': 1,
#  '갈치조림': 2,
#  '갈치': 1,
#  '고소': 14,
#  '양념': 8,
#  '베': 2,
#  '워': 7,
#  '너비': 2,
#  '블링': 1,
#  '국': 25,
#  '뚝딱': 8,
#  '내심': 1,
#  '봉지': 1,
#  '다시마': 2,
#  '무': 15,
#  '대파': 4,
#  '쑥갓': 5,
#  '약간': 6,
#  '간장': 19,
#  '마늘': 7,
#  '그녀': 1,
#  '이비가': 7,
#  '대전': 18,
#  '둔산동': 9,
#  '최근': 7,
#  '속도': 5,
#  '체인점': 4,
#  '늘': 16,
#  '카레': 1,
#  '아로마테라피': 1,
#  '스튜디오': 3,
#  '고흥': 12,
#  '관광': 7,
#  '양산박': 1,
#  '박': 4,
#  '두': 26,
#  '합': 8,
#  '북적': 2,
#  '범계': 1,
#  '성경': 1,
#  '택': 8,
#  '전부': 7,
#  '예약': 11,
#  '석도': 1,
#  '먼저': 14,
#  '준': 2,
#  '는걸': 15,
#  '위해': 13,
#  '쯔모': 1,
#  '욧': 1,
#  '양푼': 9,
#  '동태': 24,
#  '용인': 13,
#  '어탕': 2,
#  '으쓱': 1,
#  '냠삐공': 1,
#  '특공대': 1,
#  '낙지볶음': 8,
#  '씨': 50,
#  '드릴': 20,
#  '피로': 3,
#  '냉국': 1,
#  '연우': 4,
#  '컴퓨터': 4,
#  '여수': 5,
#  '다양': 34,
#  '가장': 30,
#  '청담': 3,
#  '앤전': 1,
#  '분위기': 18,
#  '여서동': 3,
#  '안주': 31,
#  '까지': 50,
#  '편이': 7,
#  '부분': 4,
#  '신기': 3,
#  '답': 12,
#  '전통주': 2,
#  '하이': 4,
#  '볼': 9,
#  '소주': 22,
#  '하나라': 4,
#  '감자탕': 74,
#  '회기역': 3,
#  '아라하': 2,
#  '사람': 32,
#  '사골국': 1,
#  '도시': 1,
#  '전자랜드': 1,
#  '매우': 8,
#  '드': 16,
#  '실지': 1,
#  '한국': 13,
#  '한가지': 6,
#  '충무로': 3,
#  '마리': 38,
#  '평점': 3,
#  '가격': 69,
#  '천원': 9,
#  '공릉': 1,
#  '슴슴': 1,
#  '및': 16,
#  '네이버': 3,
#  '만원': 6,
#  '닭곰탕': 8,
#  '명': 18,
#  '땅': 4,
#  '이의': 24,
#  '어디': 9,
#  '시청': 3,
#  '앞': 21,
#  '음': 4,
#  '대신': 7,
#  '욕구': 1,
#  '아들': 5,
#  '꼬': 2,
#  '라지': 2,
#  '마름': 2,
#  '목포': 6,
#  '월남쌈': 4,
#  '신랑': 5,
#  '유치원': 1,
#  '자고': 5,
#  '배': 18,
#  '꽃': 8,
#  '존재': 1,
#  '블루': 4,
#  '보틀': 3,
#  '여의도': 36,
#  '주차': 22,
#  '팁': 4,
#  '플로': 1,
#  '현대': 12,
#  '쥬': 5,
#  '제이': 4,
#  '맘': 12,
#  '라떼': 25,
#  '지금': 17,
#  '아이스커피': 1,
#  '플루토': 1,
#  '곰탕': 44,
#  '상암동': 2,
#  '나주': 12,
#  '상암': 1,
#  '돌솥밥': 2,
#  '건강': 18,
#  '챙': 1,
#  '기고': 5,
#  '조': 10,
#  '마루': 17,
#  '상동역': 2,
#  '지극': 3,
#  '리얼': 6,
#  '후기': 47,
#  '양': 25,
#  '나위': 1,
#  '인정': 5,
#  '보신': 36,
#  '노리': 1,
#  '만두국': 12,
#  '일산': 26,
#  '그것': 5,
#  '순서대로': 1,
#  '막': 4,
#  '유명': 13,
#  '집들이': 6,
#  '러하': 2,
#  '듯이': 4,
#  '주': 28,
#  '모션': 1,
#  '렌터카': 1,
#  '보험사': 1,
#  '고대': 1,
#  '차': 31,
#  '전문': 10,
#  '기업': 2,
#  '하월곡동': 1,
#  '첫': 9,
#  '해장': 35,
#  '성북구': 1,
#  '주민': 1,
#  '월곡역': 1,
#  '출구': 10,
#  '건': 19,
#  ...}

# %%
#단어와 빈도수를 열 이름으로 사용
df = pd.DataFrame(list(df.items()),
                   columns=['단어', '빈도수'])
df
# Out:
#        단어   빈도수
# 0      추천  1262
# 1       날  1925
# 2      국물   369
# 3      메뉴  1438
# 4      요리   146
# ...   ...   ...
# 5546  고구려     1
# 5547   산선     1
# 5548  부원장     1
# 5549  방배동     1
# 5550   개인     1
#
# [5551 rows x 2 columns]

# %%
#빈도수 내림차순으로 정력
df = df.sort_values(by='빈도수',ascending=False)
df
# Out:
#         단어   빈도수
# 1        날  1925
# 3       메뉴  1438
# 0       추천  1262
# 93      맛집   876
# 2       국물   369
# ...    ...   ...
# 3168    정답     1
# 3169  동대문구     1
# 3171    명칭     1
# 3172    부여     1
# 5550    개인     1
#
# [5551 rows x 2 columns]

# %%
df.to_csv('word.csv',

                 sep=',',

                 na_rep='NaN', 

                 float_format = '%.2f', # 2 decimal places

                 columns = ['단어', '빈도수'], # columns to write

                 index = False) # do not write index

# %%
df1 = pd.read_csv('foodinfo1.csv')
df1 = df1.rename(columns={'대표식품명':'단어'})
df1
# Out:
#         식품대분류명     단어  에너지(kcal)  단백질(g)
# 0    곡류, 서류 제품     팝콘        511    8.30
# 1          과일류     과일         43    0.47
# 2          구이류  가자미구이        123   18.70
# 3          구이류   갈치구이        138   21.54
# 4          구이류  고등어구이        340   23.38
# ..         ...    ...        ...     ...
# 719        튀김류    치즈볼        333    9.56
# 720        튀김류   치즈스틱        329   12.59
# 721        튀김류   치킨까스        296   13.96
# 722        튀김류   깐쇼새우        150    7.90
# 723        튀김류   동태까스        273   11.60
#
# [724 rows x 4 columns]

# %%
df2 = pd.read_csv('word.csv')

df2
# Out:
#         단어   빈도수
# 0        날  1925
# 1       메뉴  1438
# 2       추천  1262
# 3       맛집   876
# 4       국물   369
# ...    ...   ...
# 5546    정답     1
# 5547  동대문구     1
# 5548    명칭     1
# 5549    부여     1
# 5550    개인     1
#
# [5551 rows x 2 columns]

# %%
df3 = pd.merge(df1, df2)
df3
# Out:
#     식품대분류명     단어  에너지(kcal)  단백질(g)  빈도수
# 0      과일류     과일         43    0.47    5
# 1      구이류  고등어구이        340   23.38    1
# 2      구이류     곱창        184   14.89   19
# 3      구이류     꼬치        245   17.85    4
# 4      구이류     닭발        196   18.15    8
# ..     ...    ...        ...     ...  ...
# 209    튀김류     치킨        257   17.17   11
# 210    튀김류    탕수육        116    6.65    7
# 211    튀김류    깐풍기        295   13.10    1
# 212    튀김류    돈까스        262   14.46   19
# 213    튀김류   깐쇼새우        150    7.90    3
#
# [214 rows x 5 columns]

# %%
df3 = df3.sort_values(by='빈도수',ascending=False)
df3 = df3.set_index('단어')
df3
# Out:
#           식품대분류명  에너지(kcal)  단백질(g)  빈도수
# 단어
# 칼국수      면 및 만두류         77    3.30  349
# 우동       면 및 만두류        158    1.78  138
# 국밥            밥류        137    6.70  117
# 짬뽕       면 및 만두류         58    2.79   84
# 만두       면 및 만두류        159   12.38   78
# ...          ...        ...     ...  ...
# 부추전    전·적 및 부침류        167    4.63    1
# 메밀전    전·적 및 부침류        161    4.02    1
# 계란후라이  전·적 및 부침류        208   15.73    1
# 초밥            밥류        160    9.66    1
# 인절미      빵 및 과자류        242    5.64    1
#
# [214 rows x 4 columns]

# %%
df3
# Out:
#           식품대분류명  에너지(kcal)  단백질(g)  빈도수
# 단어
# 칼국수      면 및 만두류         77    3.30  349
# 우동       면 및 만두류        158    1.78  138
# 국밥            밥류        137    6.70  117
# 짬뽕       면 및 만두류         58    2.79   84
# 만두       면 및 만두류        159   12.38   78
# ...          ...        ...     ...  ...
# 부추전    전·적 및 부침류        167    4.63    1
# 메밀전    전·적 및 부침류        161    4.02    1
# 계란후라이  전·적 및 부침류        208   15.73    1
# 초밥            밥류        160    9.66    1
# 인절미      빵 및 과자류        242    5.64    1
#
# [214 rows x 4 columns]

# %%
df3 = df3.reset_index()
df3
# Out:
#         단어     식품대분류명  에너지(kcal)  단백질(g)  빈도수
# 0      칼국수    면 및 만두류         77    3.30  349
# 1       우동    면 및 만두류        158    1.78  138
# 2       국밥         밥류        137    6.70  117
# 3       짬뽕    면 및 만두류         58    2.79   84
# 4       만두    면 및 만두류        159   12.38   78
# ..     ...        ...        ...     ...  ...
# 209    부추전  전·적 및 부침류        167    4.63    1
# 210    메밀전  전·적 및 부침류        161    4.02    1
# 211  계란후라이  전·적 및 부침류        208   15.73    1
# 212     초밥         밥류        160    9.66    1
# 213    인절미    빵 및 과자류        242    5.64    1
#
# [214 rows x 5 columns]

# %%
df3['날씨구분'] = 'cold'
df3
# Out:
#         단어     식품대분류명  에너지(kcal)  단백질(g)  빈도수  날씨구분
# 0      칼국수    면 및 만두류         77    3.30  349  cold
# 1       우동    면 및 만두류        158    1.78  138  cold
# 2       국밥         밥류        137    6.70  117  cold
# 3       짬뽕    면 및 만두류         58    2.79   84  cold
# 4       만두    면 및 만두류        159   12.38   78  cold
# ..     ...        ...        ...     ...  ...   ...
# 209    부추전  전·적 및 부침류        167    4.63    1  cold
# 210    메밀전  전·적 및 부침류        161    4.02    1  cold
# 211  계란후라이  전·적 및 부침류        208   15.73    1  cold
# 212     초밥         밥류        160    9.66    1  cold
# 213    인절미    빵 및 과자류        242    5.64    1  cold
#
# [214 rows x 6 columns]

# %%
df3.to_csv('cold_food.csv',index=False)
