# %%
# 최종 코드
# 블로그 검색 api
# 한 번에 가져오는 개수인 display는 최대 100까지 가능
# start변수 값을 바꿔야 다른 값을 불러옴, 최대 1000까지
# display=100이면 start변수 값을 1, 101, 201, ..., 1000으로 바꿔주면서 해야함
# start는 최대 1000까지 제공하기 때문에, start=1일때랑 start=1001일때랑 결과가 같음


import os
import sys
import urllib.request
def naver_blog(start):
    client_id = "8kZT6kfb83vNesnBvjwj"  # 본인 클라이언트 아이디 넣기
    client_secret = "bj39JaQzAp"  # 본인 클라이언트 시크릿 넣기
    encText = urllib.parse.quote("비오는 날 추천 메뉴")

    url = "https://openapi.naver.com/v1/search/blog?query="+encText+"&display=100"+"&start=" + start # json 결과

    file=open("./naver_api_dessert11.json","w+",encoding='UTF8')  # 파일로 저장하기
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        print(response_body.decode('utf-8'))
        file.write(response_body.decode('utf-8'))
        file.close()
    else:
        print("Error Code:" + rescode)
    return response_body.decode('utf-8')

# %%
body = ""
for i in range(1,1000,100) :
    body += naver_blog(str(i))
# Out:
# {
# 	"lastBuildDate":"Wed, 30 Aug 2023 13:55:04 +0900",
# 	"total":252558,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"[오산 맛집] 등촌샤브칼국수: <b>비오는 날 추천메뉴<\/b>*",
# 			"link":"https:\/\/blog.naver.com\/juni0628\/223197033614",
# 			"description":"비오는날 진짜 추천메뉴다 이건 다음은 칼국수 넣어볼게요- 살짝 배가 불러집니다. 그래도 준건 다... 잘 먹고 갑니다. 그럼 이만 #직장인의하루 #워킹맘 #<b>비오는날추천메뉴<\/b> #비오는날추천음식",
# 			"bloggername":"동그라미의 하루:-)",
# 			"bloggerlink":"blog.naver.com\/juni0628",
# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"욘주라멘 よんじゅ 여전히 일본라멘맛집  (<b>비오는 날<\/b> <b>메뉴<\/b> <b>추천<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/live_in_clov\/223053071086",
# 			"description":"꼭 사이드로 시켜서 맛보기를 추천 - 라멘에 들어간 푸짐한 차슈 차슈는 더 원한다면 1장당 2,000원에 추가할 수 있어요. <b>비오는 날 추천 메뉴<\/b>. 울산 성남동 웨이팅 맛집 욘주라멘 생각 나는 오늘 입니다.... ",
# 			"bloggername":"만사형통 블로그",
# 			"bloggerlink":"blog.naver.com\/live_in_clov",
# 			"postdate":"20230323"
# 		},
# 		{
# 			"title":"바다수퍼해물천하조개구이 강남역점 <b>비오는 날 추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/chero25\/222862611308",
# 			"description":"메인 <b>메뉴<\/b>가 나오기 전에 양은냄비에 담겨져서 끓여준다 에피타이저로 떡볶이가 나<b>오는<\/b> 게 새로웠다!... <b>비오는날<\/b><b>메뉴<\/b> #<b>비오는날<\/b><b>메뉴<\/b><b>추천<\/b> #강남역신상식당 #바다수퍼해물천하조개구이... ",
# 			"bloggername":"쥬니뮹의 기록",
# 			"bloggerlink":"blog.naver.com\/chero25",
# 			"postdate":"20220831"
# 		},
# 		{
# 			"title":"<b>비오는 날<\/b> 점심<b>메뉴<\/b> <b>추천<\/b>, 온센 광명점 이까텐동 촉촉한 식감 굳굳",
# 			"link":"https:\/\/blog.naver.com\/bubbly421\/223152871312",

# 			"postdate":"20230419"
# 		},
# 		{
# 			"title":"감자채전 만들기 만드는법 <b>비오는날<\/b> 야식<b>메뉴<\/b><b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/yoonlove0502\/223145344793",
# 			"description":"아이들간식으로도 <b>추천<\/b>합니다&gt;&lt; 다음에 또 다른 감자요리로 돌아오겠습니다!! #감자채전 #감자채전만들기 #감자채전만드는법 #야식만드는법 #야식<b>메뉴<\/b><b>추천<\/b> #<b>비오는날<\/b><b>메뉴<\/b> #감자요리 #야식 #간식 #야식<b>메뉴<\/b>",
# 			"bloggername":"쏭스라이프의 푸드스토리",
# 			"bloggerlink":"blog.naver.com\/yoonlove0502",
# 			"postdate":"20230704"
# 		},
# 		{
# 			"title":"광명 이케아 레스토랑 <b>메뉴<\/b><b>추천<\/b>! <b>비오는날<\/b> 실내데이트... ",
# 			"link":"https:\/\/blog.naver.com\/syn0902\/223154482474",
# 			"description":"추적추적<b>오는<\/b>데 날이 쌀쌀해서 이런 날에는 어딜가서 놀면 좋을까 고민하다가 멀지않은 거리에 광명... 실내데이트<b>추천<\/b> #이케아데이트 #<b>비오는날<\/b>이케아 #<b>비오는날<\/b>데이트 #스타필드고양 #이케아놀거리 #서이추",
# 			"bloggername":"♥애나를 부탁해♥",
# 			"bloggerlink":"blog.naver.com\/syn0902",
# 			"postdate":"20230712"
# 		},
# 		{
# 			"title":"수원영통맛집, '목구멍 수원영통점' <b>비오는 날<\/b> <b>메뉴<\/b>로 <b>추천<\/b>해요",
# 			"link":"https:\/\/blog.naver.com\/yong_dudu\/223168578620",
# 			"description":"내리던 <b>날<\/b>, 고기집은 역시나 사람들이 바글바글 이번에 새로 생긴 영통고기집에 다녀왔어요 근데 정말 <b>비오는 날<\/b> 먹으니까 더 맛있는 것 같기도 하고..? 수원목살맛집 목구멍 수원영통점 직접 먹어본 후기 시~작... ",
# 			"bloggername":"하루종일 놀고싶은 요년두",
# 			"bloggerlink":"blog.naver.com\/yong_dudu",
# 			"postdate":"20230728"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 간단한 저녁<b>메뉴<\/b><b>추천<\/b> 잔치국수 만들기 고명가득... ",
# 			"link":"https:\/\/blog.naver.com\/sundoong2\/223156071693",
# 			"description":"<b>비오는날<\/b> 간단한 저녁<b>메뉴<\/b><b>추천<\/b> 잔치국수 만들기 고명가득 국수한그릇 뚝딱 말아볼까요? #간단한저녁<b>메뉴<\/b> #저녁<b>메뉴<\/b><b>추천<\/b> #잔치국수만들기 #한그릇음식 #잔치국수레시피 ▶ 잔치국수 만들기 ◀ \/ 소면 (삶을때... ",
# 			"bloggername":"안녕 다정한, 순둥작가",
# 			"bloggerlink":"blog.naver.com\/sundoong2",
# 			"postdate":"20230714"
# 		},
# 		{
# 			"title":"<b>비오는날 추천 메뉴<\/b> 울산 명촌 맛집 돗가비 불쭈철판볶음... ",
# 			"link":"https:\/\/blog.naver.com\/kiss9202\/223059262582",
# 			"description":"<b>비오는날<\/b> 생각나는 울산 명촌 맛집 돗가비 불쭈철판볶음 들깨수제비 봄비가 부슬부슬 오던날 매콤한것도 땡기고 뜨끈~한 국물도 땡기고 그럴때 딱!! 어울리는 <b>메뉴<\/b> 불쭈꾸미에 들깨수제비 맛보고 왔거든요... ",
# 			"bloggername":"욕심많은 손사장",
# 			"bloggerlink":"blog.naver.com\/kiss9202",
# 			"postdate":"20230329"
# 		},
# 		{
# 			"title":"굴 조개 칼국수 끓이는법 칼국수 육수 <b>비오는날<\/b> 점심<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/jsk3514\/222983032774",
# 			"description":"해물칼국수 칼국수 만드는법 굴 조개 칼국수 끓이는법 칼국수 육수 <b>비오는날<\/b> 점심<b>메뉴<\/b> <b>추천<\/b> 재료 해물 (가리비, 굴 , 새우 ) 적당히 멸치육수 600ml + 가리비육수 600ml 야채 (쌈배추 ,알배추, 대파, 청양고추 )... ",
# 			"bloggername":"행주치마의 정겨운 집밥",
# 			"bloggerlink":"blog.naver.com\/jsk3514",
# 			"postdate":"20230113"
# 		},
# 		{
# 			"title":"가격, <b>추천 메뉴<\/b>, 3군 가볼만한 곳, 3군 카페, <b>비오는날<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/helpful_valuable\/223180457235",
# 			"description":"한국어 <b>메뉴<\/b>를 봤을때, 대표 시그니처 <b>추천 메뉴<\/b>는 코코넛 밀크 커피입니다! 이전에 나트랑에... 더운 날씨나 <b>비오는 날<\/b> 콩카페에서 시원하게 떤딘 성당 구경하세요!!! 다들 재밌고 즐거운 호치민 여행되세요!!!... ",
# 			"bloggername":"유익한 공간",
# 			"bloggerlink":"blog.naver.com\/helpful_valuable",
# 			"postdate":"20230810"
# 		},
# 		{
# 			"title":"더북한산점 <b>비오는날<\/b> 방문후기... 스타벅스 더북한산점 <b>메뉴<\/b><b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/hiwool\/223164546000",
# 			"description":"오픈런을 <b>추천<\/b>드립니다. 왜냐면... <b>비오는<\/b> 주말인데도 이미 거의 만차였거든요 ㅋㅋㅋ 저는 오전 7시... 이 <b>날<\/b> 주문했던 허니 트리플 치즈 크루아상과 B.L.A.T 샌드위치 모두 완전 만족스러웠어요. 두 <b>메뉴<\/b> 모두... ",
# 			"bloggername":"소소하지만 특별한 것들",
# 			"bloggerlink":"blog.naver.com\/hiwool",
# 			"postdate":"20230724"
# 		},
# 		{
# 			"title":"의정부 맛집 [두부의 맛]<b>비오는날 추천 메뉴<\/b> 두부버섯 전골",
# 			"link":"https:\/\/blog.naver.com\/chi2681\/223160622945",
# 			"description":"me\/xJaS1sbL <b>메뉴<\/b>판 두부의맛 식사류 가격은 9000~12000원 으로 적당한 가격이에요. 정식이랑... <b>비 오는날<\/b>은 버섯두부전골을,날이 뜨거운 날은 콩국수를 드시는걸 <b>추천<\/b>드려요.(옆 테이블에 콩국수 드시는데... ",
# 			"bloggername":"공블리들과 행복한일상♡",
# 			"bloggerlink":"blog.naver.com\/chi2681",
# 			"postdate":"20230719"
# 		},
# 		{
# 			"title":"<b>비 오는 날<\/b> 선택한 완벽한 <b>메뉴<\/b>! 미아사거리곱창 맛집 <b>추천<\/b>!",
# 			"link":"https:\/\/blog.naver.com\/with-uu\/223142417529",
# 			"description":"대표 메뉴 * 제주 삼겹살 ** 배달 가능!** 비가 오는 날 햇빛 병원을 들렸다가 점심을 먹고 사무실로... <b>비 오는 날 추천 메뉴<\/b>로 딱이다!! 대창으로 착각할 수 있는 비주얼이라서 벽면에 설명이 걸려있다.... ",
# 			"bloggername":"꿈이 있다면, 그걸 지켜야해!",
# 			"bloggerlink":"blog.naver.com\/with-uu",
# 			"postdate":"20230630"
# 		},
# 		{
# 			"title":"밥집] <b>비오는날<\/b> 점심 <b>메뉴<\/b> “칼국수네 수제비” <b>추천<\/b> 할래요",
# 			"link":"https:\/\/blog.naver.com\/zinzuuu\/223196146952",
# 			"description":"나<b>오는<\/b>데 정말 초 대박 친절하세요 :) 기본 세팅에 샐러드라니 김치만 나올줄 알았는데 기본 찬 부터가... 이거 <b>비오는날<\/b>마다 오겠는데... 이집 <b>메뉴<\/b> 다 먹어보고 싶어졌어요 진.심 국물이 왜이리 시원하지 하고... ",
# 			"bloggername":"cherish every moment.",
# 			"bloggerlink":"blog.naver.com\/zinzuuu",
# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"[<b>비오는날 추천 메뉴<\/b> 곱창]파김치 with 곱창 경안동 신장곱창",
# 			"link":"https:\/\/blog.naver.com\/herababy12\/223084939859",
# 			"description":"<b>비 오는 날<\/b> 소곱창에 소주는 진리입니다. 잘 익은 대파김치 대파김치 정말 맛있어요. 느끼한 곱창과... <b>메뉴<\/b>판 대파김치가 워낙 맛나다 보니 사가는 사람이 많아서 별도로 판매도 하고 있어요. 이날은 소주를... ",
# 			"bloggername":"소소한 일상을 사는 여자!!",
# 			"bloggerlink":"blog.naver.com\/herababy12",
# 			"postdate":"20230425"
# 		},
# 		{
# 			"title":"<b>비오는 날 추천 메뉴<\/b> 부추장떡 만들기 부추부침개 레시피",
# 			"link":"https:\/\/blog.naver.com\/shushu219321\/223065903988",
# 			"description":"엄마가 봄에 나<b>오는<\/b> 새순은 꼭 먹어야한다며, 잘라서 챙겨줬어요! 부추는 알리신 성분이 비타민 B군의... 다른 식재료 조합으로 부추 넣은 부침개. <b>비오는 날<\/b> 한 번 만들어 보시면 어떨까요? 맛있게 만들어 드세요 :)",
# 			"bloggername":"슈슈냥의 한그릇 뚝딱!",
# 			"bloggerlink":"blog.naver.com\/shushu219321",
# 			"postdate":"20230405"
# 		},
# 		{
# 			"title":"[용산막창]삼각지역 맛집 <b>추천<\/b>, <b>비오는 날<\/b> <b>메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/mi980902\/223167943256",
# 			"description":"맛집을 <b>추천<\/b>해보려고 왔숨다 비가 추적추적 내리는 <b>날<\/b> 먹으면 좋을 것 같은 <b>메뉴<\/b>!! 바로 삼각지역... 똑같아~ <b>비오는날<\/b> 막창 보면 땡기지~~ <b>메뉴<\/b>판 찍어보았지만 너무 가까이 앉은탓에 안 보이는 <b>메뉴<\/b>는 검색해서... ",
# 			"bloggername":"앤녕의 이것 저것",
# 			"bloggerlink":"blog.naver.com\/mi980902",
# 			"postdate":"20230727"
# 		},
# 		{
# 			"title":"아이랑 <b>비오는 날<\/b>도 좋은 남해... 시골할매막걸리 아이 <b>추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/narugarden\/223122483008",
# 			"description":"바깥자리도 <b>비오는 날<\/b>이라 운치 있었겠지만 안개가 많이 껴서 크게 아쉽진 않더라고요. 저희는 해물된장찌개 \/ 해물파전 \/ 유자막걸리 \/공깃밥 추가 주문했고 어린 아이들이 있기 때문에 전 <b>메뉴<\/b> 고추 빼달라고... ",
# 			"bloggername":"엄마와 두 딸의 성장기록",
# 			"bloggerlink":"blog.naver.com\/narugarden",
# 			"postdate":"20230607"
# 		},
# 		{
# 			"title":"고깃집 삼겹살 맛집 하남돼지집(<b>비오는날<\/b> <b>메뉴<\/b><b>추천<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/kkj7770\/223122141002",
# 			"description":"오픈런을 해서 차지할 수 있었던 자리ㅎㅎ 뷰가 초록초록해서 이쁠뿐더러 <b>비 오는<\/b> 소리와 고기 굽는... 앞으로 돼지고기는 하남돼지집ㅋㅋ 특히 <b>비오는날 추천<\/b>하는 <b>메뉴<\/b> 도시락 김치볶음밥 김치양은 얼마... ",
# 			"bloggername":"단방향소통 생활기록부",
# 			"bloggerlink":"blog.naver.com\/kkj7770",
# 			"postdate":"20230607"
# 		},
# 		{
# 			"title":"<b>비오는날 추천 메뉴<\/b> 손질 통 오징어 넣은 해물부추전... ",
# 			"link":"https:\/\/blog.naver.com\/sobongg\/223180237739",
# 			"description":"통오징어 모양이 그대로 살아있어 다양한 오징어 요리에 활용하기 좋은 손질 통오징어 ~ <b>비오는 날<\/b>이니... 오징어가 통으로 가득 들어있으니까 씹는맛도 좋고, 바삭한 전이 맛있어서 <b>비오는날<\/b> 너무 잘... ",
# 			"bloggername":"소봉이의 데일리 달링♥",
# 			"bloggerlink":"blog.naver.com\/sobongg",
# 			"postdate":"20230810"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 음식 <b>비오는날<\/b> <b>메뉴<\/b> <b>비오는날<\/b> 저녁<b>메뉴<\/b> <b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/kyungm2001\/223065571200",
# 			"description":"☔️ <b>비오는날<\/b> <b>비오는날<\/b> <b>메뉴<\/b> <b>비오는날<\/b> 저녁 #<b>비오는날<\/b>음식 #비올때음식 #<b>비오는날<\/b><b>메뉴<\/b>... #저녁<b>메뉴<\/b><b>추천<\/b> #오늘저녁<b>메뉴<\/b> 오늘 저녁 <b>메뉴<\/b> 저녁<b>메뉴<\/b> <b>추천<\/b>은  순두부찌개 끓이는법 https... ",
# 			"bloggername":"달타냥하우스",
# 			"bloggerlink":"blog.naver.com\/kyungm2001",
# 			"postdate":"20230405"
# 		},
# 		{
# 			"title":"온천 손칼국수, 동학사에 간다면 또갈집(<b>비 오는 날 추천 메뉴<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/janny60218\/223139275446",
# 			"description":"비가 오는 주말이다. 용씨와 나는 한 번쯤 어딜 가지 않으면 안 되는 나 때문에 우리 둘에게 미지의... 공주온천손칼국수 #공주온천칼국수 #<b>비오는날추천메뉴<\/b> #공주여행맛집 #온천손칼국수 #휘연 #공주휘연",
# 			"bloggername":"세상으로 걸어나가는",
# 			"bloggerlink":"blog.naver.com\/janny60218",
# 			"postdate":"20230626"
# 		},
# 		{
# 			"title":"[수원\/행궁동 맛집]<b>비오는 날<\/b>... 뮤지엄”(<b>메뉴<\/b><b>추천<\/b>, 예약, 주차)",
# 			"link":"https:\/\/blog.naver.com\/ha_1203\/223160423304",
# 			"description":"지난 주말 남자친구랑 수원데이트를 했어요 ☔️<b>비 오는 날<\/b>이라 날씨는 습하고 더운데 한끼를 중하게... 나눠먹어보기 - <b>메뉴<\/b><b>추천<\/b> 분보싸오 쌀국수를 좋아해도 따뜻한 쌀국수만 먹어봤지 이런 비빔은 처음... ",
# 			"bloggername":"인천러_먹짱이의 하루",
# 			"bloggerlink":"blog.naver.com\/ha_1203",
# 			"postdate":"20230719"
# 		},
# 		{
# 			"title":"간단 자취생 밥도둑 집밥요리 \/ 한끼뚝딱 <b>비오는날 추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\

# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"수유 부대찌개\/수유역 맛집 \/ <b>비 오는 날<\/b> 점심 <b>추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/with-uu\/223155473151",
# 			"description":"수유에서 비 오는 날 메뉴가 고민된다면 수유역 맛집을 검색한다면 무조건 추천 추천!! 안 가본 사람은... #수유맛집 #수유역맛집 #수유cgv맛집 #번동맛집 #수유역맛집 #<b>비오는날추천메뉴<\/b> #수유점심추천메뉴... ",
# 			"bloggername":"꿈이 있다면, 그걸 지켜야해!",
# 			"bloggerlink":"blog.naver.com\/with-uu",
# 			"postdate":"20230713"
# 		},
# 		{
# 			"title":"「내돈내산」<b>비오는날 추천 메뉴<\/b> 간편조리 제천빨간오뎅... ",
# 			"link":"https:\/\/blog.naver.com\/gnangel\/223163830087",
# 			"description":"여름철 별미로 이열치열한번 도전해보시는건 <b>추천<\/b>드려요! 그리고 너무나 간단합니다! 제가 하면 누구나 다 할수 있어요~ <b>비오는날<\/b> 전이 지겨우시다면 집에서 매운오뎅 한번 조리해서 드셔보시는건 어떨까요? ^^",
# 			"bloggername":"리안REC",
# 			"bloggerlink":"blog.naver.com\/gnangel",
# 			"postdate":"20230723"
# 		},
# 		{
# 			"title":"점심<b>메뉴<\/b> <b>추천<\/b> ! 감자수제비... 수제비반죽 만들기 (<b>비오는날<\/b>음식 )",
# 			"link":"https:\/\/blog.naver.com\/jsk3514\/222671216347",
# 			"description":"시원하게 퍼 부었으면 가뭄 해갈도 되고 좋으련만 오기 싫은 것 억지로 <b>오는<\/b> 것 같네요. 어제부터... <b>비오는날<\/b>음식 점심<b>메뉴<\/b>로 <b>추천<\/b> ! 감자수제비 만드는법 소개해보았는데요. 삼시세끼에 점심 한끼는 수제비... ",
# 			"bloggername":"행주치마의 정겨운 집밥",
# 			"bloggerlink":"blog.naver.com\/jsk3514",
# 			"postdate":"20220313"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 음식 얼큰수제비 만드는법, 점심<b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/loveis8199\/222794838457",
# 			"description":"<b>비오는날<\/b> 먹고 싶은 음식 벌써 몇일째 비가 지속되고 있죠~ 그래도 다행인건 하루 종일 비가 <b>오는<\/b>건... <b>비오는날<\/b> 점심<b>메뉴<\/b> <b>추천<\/b>하고 싶은 얼큰수제비 만드는법 끝! 바지락육수로 맑~게 끓여낸 수제비와 또 다른... ",
# 			"bloggername":"언니소의 건강한 푸드스토리",
# 			"bloggerlink":"blog.naver.com\/loveis8199",
# 			"postdate":"20220630"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> <b>메뉴<\/b> GS밀키트 홍게꼬치어묵탕 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/lnj1114\/223159851434",
# 			"description":"요즘입니다 <b>비<\/b> 피해가 더이상 없길 바래봅니다 <b>비오는<\/b> 저녁으로 선택된 오늘 <b>메뉴<\/b>는... 오늘같이 <b>비오는날<\/b> 뜨끈한 어묵탕 너무 좋잖아요 다음번에도 행사하면 몇개 더 쟁여놔야겠어요 <b>비오는날<\/b> <b>메뉴<\/b>로... ",
# 			"bloggername":"엄마의 또다른 취미",
# 			"bloggerlink":"blog.naver.com\/lnj1114",
# 			"postdate":"20230718"
# 		},
# 		{
# 			"title":"얼큰한~ 해장 짬뽕 짬뽕 양념 레시피 저녁<b>메뉴<\/b> <b>추천<\/b> <b>비오는날<\/b> 음식",
# 			"link":"https:\/\/blog.naver.com\/kyungm2001\/223094206333",
# 			"description":"설정하지않았습니다 * 레시피만 사랑해 주세요~ #짬뽕만들기 #짬뽕국물만들기 #해물짬뽕만들기 #해장짬뽕 #짬뽕양념 #해장음식 #짬뽕레시피 #저녁<b>메뉴<\/b><b>추천<\/b> #<b>비오는날<\/b>음식 #한그릇요리 #중식 #집밥<b>메뉴<\/b>",
# 			"bloggername":"달타냥하우스",
# 			"bloggerlink":"blog.naver.com\/kyungm2001",
# 			"postdate":"20230505"
# 		},
# 		{
# 			"title":"광화문 직장인 <b>비 오는 날<\/b> 점심 <b>메뉴<\/b> <b>추천<\/b>, 일본 라멘... ",
# 			"link":"https:\/\/blog.naver.com\/dkwhffk\/223195914130",
# 			"description":"<b>비 오는<\/b>데 파전 안 시키면 완전 바보. 칼국수만 먹기 심심할 때 곁들이기 좋은 해물파전도 먹을 수 있다. &lt;안암&gt; 광화문 직장인 <b>비 오는 날<\/b> 점심 <b>메뉴<\/b> <b>추천<\/b> 처음 먹어보는 맑은 국물의 돼지국밥. 무려 미쉐린... ",
# 			"bloggername":"BEATITUDO",
# 			"bloggerlink":"blog.naver.com\/dkwhffk",
# 			"postdate":"20230828"
# 		},
# 		{
# 			"title":"방촌동국수맛집 수면옥 고기쌀칼국수 <b>비오는날 추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/smy9245\/223156742665",
# 			"description":"ㅎ 지인의 #방촌동맛집 <b>추천<\/b>을 받고 #<b>비오는날<\/b> 특히 더 생각나는 칼국수를 먹으러 갔다. 뭔지는... 소스가 나온걸 보니 고기는 찍어 먹나보다^^ 잠시후 큰양푼이 같은 그릇에 국수가 나<b>오는<\/b>데 육수 많다.... ",
# 			"bloggername":"모모네 집",
# 			"bloggerlink":"blog.naver.com\/smy9245",
# 			"postdate":"20230715"
# 		},
# 		{
# 			"title":"왕십리 전집 동래파전 <b>비오는 날 추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/bluezzzing\/223152088984",
# 			"description":"왕십리 전집 <b>비오는 날<\/b> <b>메뉴<\/b><b>추천<\/b> <b>비오는날<\/b> 파전은 국룰 술안주 왕십리 전집 중에 <b>비오는 날<\/b> <b>비오는<\/b> 소리 들으면서 막걸리에 파전 먹을 수 있는 동래파전 <b>추천메뉴<\/b> 적어본다 동래파전 왕십리점 매일 14:30 ~ 04:00... ",
# 			"bloggername":"폭주기관차",
# 			"bloggerlink":"blog.naver.com\/bluezzzing",
# 			"postdate":"20230710"
# 		},
# 		{
# 			"title":"천안 두정동 밥도둑 의정부 부대찌개 <b>비오는날<\/b> 음식 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/shyhjin\/223180204417",
# 			"description":"<b>비오는날<\/b> 음식 <b>메뉴<\/b> <b>추천<\/b> 원래 계획은 다른 곳 리뷰였으나 오늘 먹은 점심 <b>메뉴<\/b>가 너무 맛있어서 먼저 포스팅 해봅니다. 뜨끈한 국물이 땡겨서 비를 뚫고 달려간 곳은 상호명처럼 밥도둑이었는데...! <b>비<\/b>... ",
# 			"bloggername":"진매료의 핫플레이스 : )",
# 			"bloggerlink":"blog.naver.com\/shyhjin",
# 			"postdate":"20230810"
# 		},
# 		{
# 			"title":

# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 간단한 캠핑요리 <b>추천<\/b> \/ 캠핑<b>메뉴<\/b> 사옹원 부침개... ",
# 			"link":"https:\/\/blog.naver.com\/moon_i20\/223078952333",
# 			"description":"<b>비오는날<\/b> 간단한 캠핑요리 <b>추천<\/b> \/ 캠핑<b>메뉴<\/b> 사옹원 부침개 3종세트(feat.호떡) 우중캠핑날에는 꼭 부침개를 먹었던 것 같다. 물론 직접 재료 넣고 반죽해서 먹으면 더 맛있지만 캠핑에서는 편한게 최고! 평소에도... ",
# 			"bloggername":"달로그",
# 			"bloggerlink":"blog.naver.com\/moon_i20",
# 			"postdate":"20230419"
# 		},
# 		{
# 			"title":"동래맛집\/<b>비 오는 날<\/b> 더 좋은 술집\/<b>추천메뉴<\/b> 산장전골\/동래... ",
# 			"link":"https:\/\/blog.naver.com\/sooring22\/223187622559",
# 			"description":"대체로 오리주물럭을 많이 먹던데 <b>비 오는 날<\/b> 방문해서 그런지 국물이 땡겨서 산장전골을 주문했다. 산장1988 <b>메뉴<\/b> <b>메뉴<\/b>와 잘 어울리는 막걸리와 소주, 젊은이 취향을 저격한 하이볼도 있었다. 산장1988... ",
# 			"bloggername":"수진 흔적 blog",
# 			"bloggerlink":"blog.naver.com\/sooring22",
# 			"postdate":"20230819"
# 		},
# 		{
# 			"title":"먹짱 김대리 #<b>비오는 날<\/b> <b>메뉴<\/b> <b>추천<\/b>, 가산디지털단지역 불맛나는... ",
# 			"link":"https:\/\/blog.naver.com\/fiveavenue_\/223180180004",
# 			"description":"<b>비오는 날<\/b> <b>메뉴<\/b> 하나 <b>추천<\/b>드리겠습니다 짬뽕의 제왕 주소 : 서울 금천구 가산디지털2로 101 한라원앤원타워 2층 215호 전화번호 : 02-9840-7555 영업시간 : 월- 금 11:00 - 14:00 가산디지털단지역 부근에 있는 짬뽕의... ",
# 			"bloggername":"파이브에비뉴",
# 			"bloggerlink":"blog.naver.com\/fiveavenue_",
# 			"postdate":"20230810"
# 		},
# 		{
# 			"title":"감자수제비 만드는법 <b>비오는날<\/b>... 점심<b>메뉴<\/b> <b>추천<\/b> 수제비 만들기",
# 			"link":"https:\/\/blog.naver.com\/rldhrl23\/223003146877",
# 			"description":"● 뜨끈하고 든든하게 즐기기 좋은 감자수제비 만드는법 <b>비오는날<\/b> <b>메뉴<\/b>로 좋은 점심<b>메뉴<\/b> <b>추천<\/b> 수제비 만들기 만나보세요. ● 가끔 <b>비오는날<\/b>이 되면 특정 음식이 생각 날때가 있는데요. 그중에서도 <b>비오는날<\/b>... ",
# 			"bloggername":"지혜로운사자 감성 더한 현실집밥",
# 			"bloggerlink":"blog.naver.com\/rldhrl23",
# 			"postdate":"20230202"
# 		},
# 		{
# 			"title":"[제주여행] <b>비오는날<\/b> 좋은... 무로이! 주차,<b>메뉴<\/b>,베이커리 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/cutty_julia\/223114475998",
# 			"description":"힙한 감성이라 포토스팟이 많아보였고 <b>날<\/b> 좋으면 테라스도 강추! 대신 베이커리 종류가 많지 않은 편이라 디저트,베이커리 카페 찾는 분은 참고하세욥! 이런 분들께 <b>추천<\/b>해요 서귀포 주차하기 좋은 대형카페... ",
# 			"bloggername":"파워J 쏘이지의 여행일상",
# 			"bloggerlink":"blog.naver.com\/cutty_julia",
# 			"postdate":"20230529"
# 		},
# 		{
# 			"title":"여름<b>메뉴<\/b> 가지탕수와 감자전 만들기 <b>비오는날<\/b> 음식 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/woandos\/223156181212",
# 			"description":"제철 여름<b>메뉴<\/b> 맛있게 즐기기 아이도 어른도 잘먹는 가지탕수랍니다 <b>비오는날<\/b> <b>메뉴<\/b>로 <b>추천<\/b>하는 전! 오랜만에 감자전을 구웠어요 담백고소한 감자전은 우리집 막내도 너무 좋아하는 요리랍니다 감자 네개... ",
# 			"bloggername":"쓰리맘마",
# 			"bloggerlink":"blog.naver.com\/woandos",
# 			"postdate":"20230714"
# 		},
# 		{
# 			"title":"비올때음식 <b>비오는날<\/b> <b>메뉴<\/b> <b>비오는날<\/b> 저녁<b>메뉴<\/b> <b>추천<\/b> 한그릇 요리",
# 			"link":"https:\/\/blog.naver.com\/kyungm2001\/223156012506",
# 			"description":"#<b>비오는날<\/b>음식 #비올때음식 #<b>비오는날<\/b><b>메뉴<\/b> #<b>비오는날<\/b>저녁 #한그릇요리 #저녁<b>메뉴<\/b> #저녁<b>메뉴<\/b><b>추천<\/b>  <b>비오는날<\/b> 뭐 드실껀가요? 오늘 저녁<b>메뉴<\/b>는? <b>비오는날<\/b> 음식 <b>비오는날<\/b> 먹기좋은... ",
# 			"bloggername":"달타냥하우스",
# 			"bloggerlink":"blog.naver.com\/kyungm2001",
# 			"postdate":"20230714"
# 		},
# 		{
# 			"title":"안동 경북도청 <b>비오는날<\/b> <b>메뉴<\/b>는 고기국수 칼국수죠 ~ 이수옥",
# 			"link":"https:\/\/blog.naver.com\/neverup1002\/223085257439",
# 			"description":"<b>추천<\/b>해 봅니다. 오래 된 집이지만 아는 사람만 아는 그런 맛집이죠. <b>비오는 날<\/b>은 역시 뜨끈한 국물 <b>메뉴<\/b>... 경북 도청에 근무하는 직원들도 단골로 많이<b>오는<\/b> 음식점이라 점심 시간에는 자리가 없을 수 있지만 평소... ",
# 			"bloggername":"♥️성공설비♥️누수.하수구해결사♥️설비의 모든것",
# 			"bloggerlink":"blog.naver.com\/neverup1002",
# 			"postdate":"20230426"
# 		},
# 		{
# 			"title":"강서구 맛집 \/ 유림 닭도리탕  , <b>비오는 날 추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/bin-na0507\/222890832743",
# 			"description":"찐하게 <b>오는 날<\/b> 막걸리 못 참지~ 우리는 한마음 한 통속 ㅋㅋㅋㅋㅋㅋㅋㅋ 강서구까지 왔는데 비가 너무 내리네 ㅠ_ㅠ 매운 음식도 넘 먹고싶어 <b>비<\/b> 오니까 생각나는 막걸리 유림 닭도리탕으로 <b>메뉴<\/b> 정했다! 도착... ",
# 			"bloggername":"빛나는 오늘도 나에게✨",
# 			"bloggerlink":"blog.naver.com\/bin-na0507",
# 			"postdate":"20221003"
# 		},
# 		{
# 			"title":"쑥갓전 쑥갓요리 건새우 부추전 <b>비오는날<\/b>음식 <b>메뉴<\/b> 막걸리... ",
# 			"link":"https:\/\/blog.naver.com\/naya399\/223138836725",
# 			"description":"쑥갓요리 쑥갓전 쑥갓부추전 <b>비오는날<\/b>음식 막걸리 안주 <b>추천<\/b> 바삭바삭 전요리가 생각나는 <b>비오는날<\/b> <b>메뉴<\/b>로 남은 쑥갓에 부추 썰어 넣고 건새우 한 줌 섞어서 쑥갓 부추전 만들었어요 <b>비오는날<\/b>음식은 역시 전이... ",
# 			"bloggername":"♥칼라의푸드테라피",
# 			"bloggerlink":"blog.naver.com\/naya399",
# 			"postdate":"20230626"
# 		},
# 		{
# 			"title":"<b>비오는날 추천메뉴<\/b> 스벅 카페라떼 커스텀 그리고 엽떡?ㅋㅋ",
# 			"link":"https:\/\/blog.naver.com\/qhswktjsdud\/223180639772",
# 			"description":"어제부터 재난알림 문자가 엄청 많이 오고 방송에서도 태풍 대비하라는 방송이 많이 나오는등 이번... 제맛이에요 #<b>비오는날추천메뉴<\/b> #비오는날라떼 #비오는날커피 #비오는날스타벅스 #카페라떼... ",
# 			"bloggername":"하루하루 달콤하게",
# 			"bloggerlink":"blog.naver.com\/qhswktjsdud",
# 			"postdate":"20230811"
# 		},
# 		{
# 			"title":"상추전 만들기 튀김가루 상추 부침개 반죽 <b>비오는날<\/b> 술안주 <b>메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/clarclar\/223114089907",
# 			"description":"돼요 키친타올에 기름기 빼줬어요 예쁘게 담아 맛나게 상추부침개 드시면 됩니다 전간장 곁들여 찍어 먹으면 더 맛있어요 상추의 맛이 더 잘 느껴지네요 <b>비오는날<\/b> 술안주 <b>메뉴<\/b>로 이영자 상추전 <b>추천<\/b> 드려요",
# 			"bloggername":"꿀라's Drurken Life",
# 			"bloggerlink":"blog.naver.com\/clarclar",
# 			"postdate":"20230528"
# 		},
# 		{
# 			"title":"<b>비오는날 추천메뉴<\/b> 유미카츠로 가자!",
# 			"link":"https:\/\/blog.naver.com\/solackjn1\/223153122498",
# 			"description":"안녕하세요~ <b>비오는날 추천메뉴<\/b>로 먹기 좋은 음식이 가득한곳 유미카츠입니다~! 본격적으로 장마가... 있는 비오는날의 최고추천메뉴입니다~! 비오는날 뿐만 아니라 항상 많은분들께서 유미카츠 매력을... ",
# 			"bloggername":"돈카츠 전문점 유미카츠 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/solackjn1",
# 			"postdate":"20230711"
# 		},
# 		{
# 			"title":"[동천역]찐한국물!<b>비오는 날<\/b>엔? 명동칼국수 - 점심<b>메뉴<\/b><b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/maronkim\/223192010977",
# 			"description":"[동천역]찐한국물!<b>비오는 날<\/b>엔? 명동칼국수 - 점심<b>메뉴<\/b><b>추천<\/b>,내돈내산 #동천역칼국수 #수지구칼국수 #동천역맛집 동천역 명동칼국수 평일 10:00~21:00 토요일 10:00~16:00 일요일 휴무 주차가능 오늘은 비가 억수같이... ",
# 			"bloggername":"마론킴",
# 			"bloggerlink":"blog.naver.com\/maronkim",
# 			"postdate":"20230824"
# 		},
# 		{
# 			"title":"광교 아브뉴프랑 맛집 - 정남옥순대국 - <b>비오는 날 추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/clbi3879\/222983695804",
# 			"description":"이용시간 매일 10시30~10:00 (라스트오더 9시30분) #광교맛집#광교순대국#아브뉴프랑#광교순대국#아브뉴프랑순대국#<b>비오는날추천메뉴<\/b>#순대국맛집#정남옥순대국#아브뉴프랑맛집#비오는날#새로오픈#비오는날맛집",
# 			"bloggername":"별별감초의 내일을 여는 일상",
# 			"bloggerlink":"blog.naver.com\/clbi3879",
# 			"postdate":"20230113"
# 		},
# 		{
# 			"title":"#인천 맛집 - <b>비오는 날 추천메뉴<\/b> 양꼬치 작전동 맛집 (feat.온면)",
# 			"link":"https:\/\/blog.naver.com\/urban_girls\/222527236629",
# 			"description":"포차 <b>메뉴<\/b>에요~ 양꼬치 10개에 12,000원이면 적당한거 같죠? 일단 가볍게 양꼬치 2인분으로 시작할게요... 분들도 <b>추천<\/b>하는 맛집입니다 소주도 1잔 필수구요 양꼬치엔 칭따오지만 맥주는 배가 불러서 ㅎㅎㅎ 술... ",
# 			"bloggername":"미미의 사는 이야기",
# 			"bloggerlink":"blog.naver.com\/urban_girls",
# 			"postdate":"20211005"
# 		},
# 		{
# 			"title":"집콕러들을 위한 오덕이의 <b>비오는 날<\/b> <b>메뉴<\/b> <b>추천<\/b>(feat. 오덕쌀... ",
# 			"link":"https:\/\/blog.naver.com\/oduck0811\/223185103310",
# 			"description":"오덕이가 <b>비오는 날<\/b> 집콕러들을 위한 <b>추천 메뉴<\/b>들을 가져왔어요!! 1. 해물파전비가<b>오는날<\/b>에는 빗소리는 들으며 전을 지져 보는건 어떠세요?? 저는 개인적으로 어렷을적에 초등학교를 마치고 <b>비오는날<\/b> 우산을... ",
# 			"bloggername":"오덕청년",
# 			"bloggerlink":"blog.naver.com\/oduck0811",
# 			"postdate":"20230817"
# 		},
# 		{
# 			"title":"7월(오늘의 <b>추천메뉴<\/b>) <b>비오는 날<\/b> 음식 해물파전 어묵탕... ",
# 			"link":"https:\/\/blog.naver.com\/minilee1223\/223146673068",
# 			"description":"암만~암만 비가 <b>오는<\/b> 흐린 <b>날<\/b> 자향네호 출발합니다~~ 어묵탕 치즈닭갈비 해물파전\/소세지전... 역시 여름이지만 비가 와서 인기가 많은 <b>메뉴<\/b>였습니다. <b>비 오는 날<\/b> 음식으로 오늘 영양쟁이는 강력 <b>추천<\/b>합니... ",
# 			"bloggername":"미니힐링푸드",
# 			"bloggerlink":"blog.naver.com\/minilee1223",
# 			"postdate":"20230704"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 저녁<b>메뉴<\/b>로 땡기는 음식:: 메기매운탕 맛집 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/kkp5742\/223155787251",
# 			"description":"<b>비오는날<\/b> 저녁<b>메뉴<\/b>로 땡기는 음식 메기매운탕 맛집 <b>추천<\/b> 올해는 장마 기간에 비가 많이 온다고 계속 TV에서 나오긴 했지만 7월이 시작 되면서 계속 비소식 이번주는 <b>비<\/b> 때문에 그런지 한가한 시간이 많아서... ",
# 			"bloggername":"남양주다이어트 찜질카페",
# 			"bloggerlink":"blog.naver.com\/kkp5742",
# 			"postdate":"20230714"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 음식 <b>메뉴<\/b> <b>비오는날<\/b> 생각나는 땡기는 음식 술안주 전... ",
# 			"link":"https:\/\/blog.naver.com\/ellymom81\/223143869444",
# 			"description":"<b>비오는날<\/b> 음식 <b>메뉴<\/b> <b>비오는날<\/b> 생각나는 땡기는 음식 술안주 전 종류 레시피 7월의 첫주 즐겁게... 안주로도 좋지만 다음날의 해장음식으로도 <b>추천<\/b>하는 국물요리예요 . 레시피출처 나혼산 코쿤 바지락탕 레시피 3.... ",
# 			"bloggername":"엘리맘의 지금 이 순간",
# 			"bloggerlink":"blog.naver.com\/ellymom81",
# 			"postdate":"20230703"
# 		},
# 		{
# 			"title":"쌀국수부터 깐풍기까지,, <b>비오는 날<\/b> 단짝! 포메인 <b>메뉴<\/b> 3",
# 			"link":"https:\/\/blog.naver.com\/dk_phomein\/223156086126",
# 			"description":"바랄게요  #포메인 #포메인레드 #쌀국수맛집 #<b>메뉴<\/b><b>추천<\/b> #오늘뭐먹지 #베트남 #배달 #배달음식 #포메인<b>메뉴<\/b> #맛집후기 #베스트<b>메뉴<\/b> 포메인 깐풍기 \/ Fried Cashew Nuts Chicken <b>비오는 날<\/b> 단짝 <b>메뉴<\/b>, 포메인 깐풍기를... ",
# 			"bloggername":"쌀국수는 포메인",
# 			"bloggerlink":"blog.naver.com\/dk_phomein",
# 			"postdate":"20230714"
# 		},
# 		{
# 			"title":"<b>비오는날 추천메뉴<\/b> 부추전 만들기 부추요리 레시피 건새우... ",
# 			"link":"https:\/\/blog.naver.com\/applepiejo\/223113665569",
# 			"description":"<b>비오는 날<\/b> 생각나는 부침개입니다. 새우랑 멸치가 들어가서 간은 딱! 맞지만 초간장이나 매콤한 청양고추절임 곁들이면 훨씬 감칠맛 나게 먹을 수 있습니다. 아직도 비가 오나요? 그렇다면 점심 <b>메뉴<\/b>로... ",
# 			"bloggername":"빛나는 하루",
# 			"bloggerlink":"blog.naver.com\/applepiejo",
# 			"postdate":"20230528"
# 		},
# 		{
# 			"title":"갑오징어무침과 감자부침개, <b>비오는날<\/b> 집밥<b>메뉴<\/b> <b>추천<\/b>~",
# 			"link":"https:\/\/blog.naver.com\/sodanamoo\/222794699018",
# 			"description":"[ &quot; 동네방네 - 소다트리 &quot; ] 갑오징어무침과 감자부침개, <b>비오는날<\/b> 집밥<b>메뉴<\/b> <b>추천<\/b>~ 장마철 몇일째 비가 주룩주룩 하네요~ 비가 너무 와서 밖을 돌아다니기가 싫어지고, 몸이 축축쳐지고, 기분까지 다운되는... ",
# 			"bloggername":":D 소다한 소다트리",
# 			"bloggerlink":"blog.naver.com\/sodanamoo",
# 			"postdate":"20220630"
# 		},
# 		{
# 			"title":"구미산동맛집 <b>비오는 날<\/b> <b>메뉴<\/b> <b>추천<\/b> 도토리전이랑 쭈꾸미 전문... ",
# 			"link":"https:\/\/blog.naver.com\/lmk8401\/223159976116",
# 			"description":"안전하게 보내세요 <b>비오는 날<\/b> 먹었던 쭈꾸미예요 세트<b>메뉴<\/b>에 도토리전 구성도 있는데 <b>비오는 날<\/b>... 세트구성 #구미점심 #구미점심<b>메뉴<\/b><b>추천<\/b> 계산하는 곳 맞은 편에 아메 or 믹스 커피 먹을 수 있도록... ",
# 			"bloggername":"프로설비 토탈 인테리어",
# 			"bloggerlink":"blog.naver.com\/lmk8401",
# 			"postdate":"20230718"
# 		},
# 		{
# 			"title":"우이며녹 <b>비오는 날 추천메뉴<\/b> 새우수제비 , 백합칼국수... ",
# 			"link":"https:\/\/blog.naver.com\/suooona\/223169150522",
# 			"description":"송도칼국수 #<b>비오는날<\/b><b>메뉴<\/b> #왕새우수제비 #우이며녹수제비 지난주말 볼일이 있어 다녀온 송도 센트럴파크 오전에는 할일을 하고 #송도맛집 찾아보니 새우수제비집이 있더란 - 마침 비가 <b>오는 날<\/b>이었어서... ",
# 			"bloggername":"김썸머 블로그",
# 			"bloggerlink":"blog.naver.com\/suooona",
# 			"postdate":"20230729"
# 		},
# 		{
# 			"title":"[<b>비오는날<\/b>] <b>추천메뉴<\/b> 들깨수제비",
# 			"link":"https:\/\/blog.naver.com\/only_lhj1201\/223155726206",
# 			"description":"퇴근하고 항상 고민하는 저녁<b>메뉴<\/b>... 오늘은 무얼 먹음 좋을까? 고민하다가 비도 오고, 오랜만에 들깨... 끓어오르고 예쁘게 그릇에 담아 한그릇하면 최고예요 <b>비오는 날<\/b>. '들깨수제비' 한그릇 어떠세요?",
# 			"bloggername":"Ra.ei의 평범한일상❤️",
# 			"bloggerlink":"blog.naver.com\/only_lhj1201",
# 			"postdate":"20230714"
# 		},
# 		{
# 			"title":"장떡 만드는 법 <b>비오는날<\/b> 술안주 <b>메뉴<\/b> 고추장장떡 부추장떡",
# 			"link":"https:\/\/blog.naver.com\/misoo0612\/223080670808",
# 			"description":"장떡 만드는 법 <b>비오는날<\/b> 술안주 <b>메뉴<\/b> 고추장장떡 부추장떡 <b>비오는날<\/b> <b>메뉴<\/b> 부침개 생각이 절로 나죠!... <b>비오는날<\/b> 술안주 <b>추천<\/b>으로 준비한 장떡 만드는 법 진짜 쉬워요. 냉장고 속에 있는 야채와 맛있는 고추장만... ",
# 			"bloggername":"시크하고 도도한 토깽이가 살아효 。 。",
# 			"bloggerlink":"blog.naver.com\/misoo0612",
# 			"postdate":"20230420"
# 		},
# 		{
# 			"title":"<b>비오는 날<\/b> <b>메뉴<\/b> <b>추천<\/b>! 소곱창전골, 소곱창 효능",
# 			"link":"https:\/\/blog.naver.com\/oanl8559\/223152807280",
# 			"description":"먹었네요ㅎㅎ <b>비오는 날<\/b> <b>메뉴<\/b> <b>추천<\/b>! 소곱창전골, 소곱창 효능 보통 소곱창이라함은 곱이 가득하고 겉에는 기름지고 그러잖아요? 근데 전골이라 그런지 곱이 다 빠졌네요ㅎㅎ 곱창구이를 먹을때는 온통 기름이라... ",
# 			"bloggername":"하얀마음님의 블로그",
# 			"bloggerlink":"blog.naver.com\/oanl8559",
# 			"postdate":"20230711"
# 		},
# 		{
# 			"title":"<b>비 오는 날 추천 메뉴<\/b> 해물파전 초간단 레시피 ( feat 국순당... ",
# 			"link":"https:\/\/blog.naver.com\/girls_7\/223134409698",
# 			"description":"앞으로 <b>비<\/b> 내리는 <b>날<\/b> 많을 텐데 그때마다 막걸리와 어울리는 <b>메뉴<\/b>로 만나요; #파전초간단레시피 #해물파전레시피 #해물파전초간단레시피 #파전에막걸리 #해물파전맛집 #막걸리<b>추천<\/b> #우국생 #국순당 #쌀막걸리... ",
# 			"bloggername":"jiny daily link",
# 			"bloggerlink":"blog.naver.com\/girls_7",
# 			"postdate":"20230621"
# 		},
# 		{
# 			"title":"제주 원더아일랜드, 아기랑 <b>비오는날<\/b> 서귀포가볼만한곳 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/kallilogue\/223188328461",
# 			"description":"제주 원더아일랜드, 아기랑 <b>비오는날<\/b> 서귀포가볼만한곳 <b>추천<\/b> 이번 제주여행에서 기억에 남는 몇 개의... 진심 <b>비오는 날<\/b>이나 너무 더운 <b>날<\/b>, 야외에서 놀기 여의치 않은 날은 서귀포 제주 원더아일랜드 강추다!... ",
# 			"bloggername":"캘 리 로 그 ♩",
# 			"bloggerlink":"blog.naver.com\/kallilogue",
# 			"postdate":"20230821"
# 		},
# 		{
# 			"title":"79대포 <b>메뉴<\/b> <b>추천<\/b> <b>비오는 날<\/b>엔 빠삭파전 광영동 술집",
# 			"link":"https:\/\/blog.naver.com\/gkak840\/223120191300",
# 			"description":"79대포 <b>메뉴<\/b> <b>추천<\/b> 빠삭파전 광영동 술집 파전 <b>비오는 날<\/b>엔 막걸리에 파전이 최고죠. 바삭한 튀김을 맛볼 수 있는 빠사파전 <b>메뉴<\/b>를 <b>추천<\/b>할게요. 첫방문할 때부터 파전이랑 떡볶이 먹고 반해서 <b>비오는 날<\/b>... ",
# 			"bloggername":"보름달의 일상로그",
# 			"bloggerlink":"blog.naver.com\/gkak840",
# 			"postdate":"20230604"
# 		},
# 		{
# 			"title":"상도동 점심<b>메뉴<\/b> <b>추천<\/b> 낙지한마리수제비 !<b>비오는 날<\/b> 생각나는... ",
# 			"link":"https:\/\/blog.naver.com\/joore1015\/223143627716",
# 			"description":"나왔어요 ~ #상도동수제비<b>메뉴<\/b> 저는 낙지한마리수제비 ! 남편은 낙지덮밥 !이렇게 주문했어요 ㅎㅎ... <b>비오는 날<\/b> 뜨끈한 국물에 쫄깃한 수제비 한그릇! 최고의 점심이었습니당 #상도동맛집 #상도동맛집<b>추천<\/b>... ",
# 			"bloggername":"일상, 정보를 공유하는 블로그 ♡",
# 			"bloggerlink":"blog.naver.com\/joore1015",
# 			"postdate":"20230702"
# 		},
# 		{
# 			"title":"신촌카페 보드게임카페 레드버튼 <b>추천<\/b> :: <b>비오는 날<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/alreadydone_\/223196796624",
# 			"description":"더운날, <b>비오는날<\/b> 특히 가기 좋은 신촌놀거리로 보드게임카페 레드버튼을 <b>추천<\/b>해보기로!  신촌... 신촌보드게임카페 레드버튼 <b>메뉴<\/b>판. 방마다 놓여진 어플을 통해 비대면으로 주문을 할 수 있어 편했다. 음료... ",
# 			"bloggername":"이미, 했다.",
# 			"bloggerlink":"blog.naver.com\/alreadydone_",
# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"부어치킨 <b>비오는날<\/b> 치킨치맥 그릴후라이드통치킨 <b>추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/sy2-mom\/223114319445",
# 			"description":"<b>비오는<\/b>연휴?! 주말!. 배민 배달의민족에 부어치킨 6000원 할인쿠폰이!! 이런 <b>비오는 날<\/b>! 치킨이 생각나는... 부어치킨_그릴후라이드순살과 그릴후라이드통치킨 부어치킨 그릴후라이드통치킨 <b>추천메뉴<\/b>!... ",
# 			"bloggername":"소소한 이야기",
# 			"bloggerlink":"blog.naver.com\/sy2-mom",
# 			"postdate":"20230529"
# 		},
# 		{
# 			"title":"서울 <b>비 오는 날<\/b> 오붓하게... 즐긴 어반가든 (데이트, 모임 <b>추천<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/j_5959_sy\/223155233518",
# 			"description":"아삭한 샐러드 식감과 부드러운 스프는 입맛을 돋구기엔 제격인 <b>메뉴<\/b>였다. 거기다 더해 서울 <b>비오는날<\/b>... 서울 <b>비오는날<\/b> 실내데이트 맛집으로 <b>추천<\/b>드리고 싶다. 다음엔 화창한 날에 야외 테이블에서 즐겨보려고... ",
# 			"bloggername":"♡Inner Peace♡",
# 			"bloggerlink":"blog.naver.com\/j_5959_sy",
# 			"postdate":"20230713"
# 		},
# 		{
# 			"title":"사당 맛있는 녀석들 술집 추천 [마케집] <b>비오는날 추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/sora5242\/223113515946",
# 			"description":"주말에 비 온다길래 비 오는 날 먹은 메뉴를 가져온 오늘의 센스 쏠라 되시겠습니당♀️ 사당역 술집... 태블릿 메뉴판으로 편리하게! 조개도 야무지게 까 먹었습니당ㅋㅋ 사당 <b>비오는날 추천 메뉴<\/b>에요!... ",
# 			"bloggername":"쏠라C 먹로그",
# 			"bloggerlink":"blog.naver.com\/sora5242",
# 			"postdate":"20230527"
# 		},
# 		{
# 			"title":"부천 ㅣ 전자방 현대백화점 중동점 ㅣ <b>비오는 날<\/b> 찰떡<b>메뉴<\/b>선택",
# 			"link":"https:\/\/blog.naver.com\/lovery_daro\/223196691363",
# 			"description":"해당할듯 <b>비오는 날<\/b> 자주 방문예상 ㅡ 총점 ⭐️⭐️⭐️⭐️ 셋이 3만5천원돈 친절 ⭐️⭐️⭐️ 분위기 ⭐️⭐️⭐️ #현대백화점중동점중식<b>추천<\/b> #현대백화점중동점짬뽕맛집... ",
# 			"bloggername":"킴풔집구석",
# 			"bloggerlink":"blog.naver.com\/lovery_daro",
# 			"postdate":"20230829"
# 		},
# 		{
# 			"title":"바삭한 해물파전과 동동주 <b>비오는 날 추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/monglolo\/223191944893",
# 			"description":"하늘이 좀 우중충하죠??? 여러분 우울해할 필요가 없습니다 우리에겐 전통문화가? 있으니까요 오늘은 모임에서 파전을 먹으러 갔어요! 수제비도 시켜서 먼저 위를 보호해 줍니다 참기름? 을 많이 넣었는지 엄청... ",
# 			"bloggername":"몽고의 덕질 블로그",
# 			"bloggerlink":"blog.naver.com\/monglolo",
# 			"postdate":"20230824"
# 		},
# 		{
# 			"title":"휴게소 - <b>비오는 날 추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/lingguru\/222040925549",
# 			"description":"쉼터 비 오는 날 성남 나들이 -- 남한산성 드라이브 코스 -- <b>비오는 날 추천메뉴<\/b> -- 오후 5시가 넘어 동생과 저녁을 먹을겸 산공기 맡으러 조용히 나서본 길~ 요즘 해가 8시가 넘어야 지니 흐리고 비 오는... ",
# 			"bloggername":"LING Guru 영어 도른자",
# 			"bloggerlink":"blog.naver.com\/lingguru",
# 			"postdate":"20200725"
# 		},
# 		{
# 			"title":"삼시세끼 차승원 수제비 감자수제비 <b>비오는 날<\/b> 저녁<b>메뉴<\/b> <b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/wjddbs317\/222352462495",
# 			"description":"삼시세끼 차승원 수제비 감자수제비 <b>비오는날<\/b> 저녁<b>메뉴<\/b> <b>추천<\/b> (feat.수제비반죽 숙성과 보관) 얼마전부터 수제비가 너무 많이 먹고 싶었다. 딱히 수제비를 맛있게 먹었던 곳이 기억 나지 않았고 음식점 출입도... ",
# 			"bloggername":"파인",
# 			"bloggerlink":"blog.naver.com\/wjddbs317",
# 			"postdate":"20210515"
# 		},
# 		{
# 			"title":"with <b>비 오는 날 추천메뉴<\/b> 김치찜 ♪",
# 			"link":"https:\/\/blog.naver.com\/u_purekiss\/222383422620",
# 			"description":"저는 집에만 있는 <b>날<\/b>, 안 나가는 게 억울할 정도로 날씨가 맑은 것보다 흐린 게 더 싫더라고요. 그나마... 김치찜이야말로 <b>비 오는 날<\/b>이면 또 생각날 것 같은, 한국인 입맛에 딱 맞는 <b>추천메뉴<\/b>가 아닐까!",
# 			"bloggername":"치느님 가라사대",
# 			"bloggerlink":"blog.naver.com\/u_purekiss",
# 			"postdate":"20210603"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> <b>메뉴<\/b> <b>추천<\/b> * 시원한 김치콩나물국 맛있게 끓이는법♩",
# 			"link":"https:\/\/blog.naver.com\/syungran80\/220136181658",
# 			"description":"<b>비오는날<\/b> <b>메뉴<\/b> <b>추천<\/b> * 시원한 김치콩나물국 맛있게 끓이는법♩ 하루종일 비가 부슬부슬 내려요,, 이런 날엔 뜨끈한 국물이 떠오른다죠~~ 전 비가 와서 시원하게 김치넣고 김치콩나물국 끓였더니 너무 좋았어요.... ",
# 			"bloggername":"꿈꾸는그녀 이야기♥",
# 			"bloggerlink":"blog.naver.com\/syungran80",
# 			"postdate":"20140929"
# 		},
# 		{
# 			"title":"[의왕\/군포] <b>비오는 날 추천메뉴<\/b> 짬뽕! :: 교동반점",
# 			"link":"https:\/\/blog.naver.com\/cml10016356\/220788082188",
# 			"description":"<b>비오는 날 추천메뉴<\/b> :: 비오는 날엔 짬뽕이죠&gt;&lt;ㅋㅋㅋㅋ 뜨끈하고 매콤한 국물을 후루루룹 캬!... 짬뽕하고 짜장면하고 가격차이가 있어요 근데 그만큼 짬뽕이 더 맛있어요 ㅎㅎ 짬뽕추천!! 양파나 단무지는... ",
# 			"bloggername":"최꾸럭이 블로그",
# 			"bloggerlink":"blog.naver.com\/cml10016356",
# 			"postdate":"20160815"
# 		},
# 		{
# 			"title":"<b>비오는 날<\/b>에 뜨끈뜨끈한 피자와 함께, 피자<b>메뉴<\/b> <b>추천<\/b>!",
# 			"link":"https:\/\/blog.naver.com\/eeekong\/221023430722",
# 			"description":"이렇게 비오는날 메뉴 추천은 어떤 걸로 하는 게 좋을까? 고심 끝에 특별한 피자 메뉴를 선정했답니다.... <b>비오는날 추천 메뉴<\/b>로 딱! 토핑을 살펴보면 파인애플과 방울토마토도 함께 들어가 있는데요.... ",
# 			"bloggername":"피자에땅 공식블로그",
# 			"bloggerlink":"blog.naver.com\/eeekong",
# 			"postdate":"20170607"
# 		},
# 		{
# 			"title":"[감자수제비] <b>비오는날추천메뉴<\/b>\/점심메뉴추천\/수제비",
# 			"link":"https:\/\/blog.naver.com\/sh0307p\/150172458821",
# 			"description":"<b>비오는날추천메뉴<\/b> 수제비\/점심메뉴추천\/밀가루요리 가시는길 키친업 감사합니다!! 수제비반죽 , 감자 , 애호박 , 양파 , 대파 , 국간장1숟가락반 , 후추조금 육수 - 물 , 다시마2장 감자수제비 냄비에 물과... ",
# 			"bloggername":"멍공쥬의 소소한 이야기",
# 			"bloggerlink":"blog.naver.com\/sh0307p",
# 			"postdate":"20130723"
# 		},
# 		{
# 			"title":"<b>비 오는 날 추천 메뉴<\/b> 바지락 듬뿍 넣고 고추장 칼국수 끓이는... ",
# 			"link":"https:\/\/blog.naver.com\/loveiskook\/222393905713",
# 			"description":"저희 딸은 이 칼국수 면이 맛있다고 하더라고요~ 오늘 장 칼국수는 애들도 만족하는 <b>메뉴<\/b>였다는 사실! 이게 제일 좋네요~ 냉정하게 평가해 주는 남매라서~ <b>비 오는 날<\/b> 칼칼하고 뜨끈하게 한 끼 해결했네요~",
# 			"bloggername":"까칠감성 워킹맘의 Fun한 놀이터",
# 			"bloggerlink":"blog.naver.com\/loveiskook",
# 			"postdate":"20210611"
# 		},
# 		{
# 			"title":"[사당역 맛집] 부산어묵 - 오뎅탕(어묵탕) <b>비오는날 추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/ireya\/222353313436",
# 			"description":"돌아다니기 가장 좋은 달이 5월인데 올 봄은 거의 매주 주말마다 비가 <b>오는<\/b> 것 같네요~ <b>비오는날<\/b> 에는... 사당역 맛집 부산오뎅 어묵탕 드디어 부산오뎅의 시그니처 <b>메뉴<\/b> 오뎅탕 등장! 계란, 당면, 미나리, 부추가... ",
# 			"bloggername":"책과 산에서 길을 잃다",
# 			"bloggerlink":"blog.naver.com\/ireya",
# 			"postdate":"20210516"
# 		},
# 		{
# 			"title":"<b>비오는 날<\/b> 점심 <b>추천메뉴<\/b> : 일산 짬뽕지존 얼큰한 수제비 짬뽕... ",
# 			"link":"https:\/\/blog.naver.com\/nelo30\/222016545932",
# 			"description":"비가<b>오는 날<\/b>은 밀가루 음식이나 기름기 도는 지지미(부침개)가 땡기지 않나요. 모듬 전에 동동주 한 잔이 딱이다 싶지만, 아직은 근무시간. 동동주대신 이런날 잘 어울리는 매콤한 짬뽕을 점심<b>메뉴<\/b>로 <b>추천<\/b>해... ",
# 			"bloggername":"델마의 소소한 일상 소소한 이야기",
# 			"bloggerlink":"blog.naver.com\/nelo30",
# 			"postdate":"20200630"
# 		},
# 		{
# 			"title":"홍콩반점 0410 ▶ 성대시장맛집 <b>비오는날 추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/kkaigee\/220645324003",
# 			"description":"ㅎㅎㅎ 전 예전에는 칼국수가 많이 생각났는데 요즘 비오는날 추천 하는 메뉴는 짬뽕이에요 이미... 그리고 <b>비오는날 추천 메뉴<\/b>인 짬뽕! 대학교 3학년때 짬뽕의 매력에 빠진뒤로 거의 짬뽕만 먹고있는거같아요... ",
# 			"bloggername":"케이지의 기록",
# 			"bloggerlink":"blog.naver.com\/kkaigee",
# 			"postdate":"20160304"
# 		},
# 		{
# 			"title":"대전 김치찌개 맛집 - <b>비오는날 추천메뉴<\/b> 오모리찌개",
# 			"link":"https:\/\/blog.naver.com\/rlachqkd\/221574912290",
# 			"description":"들어가있고 <b>비오는날<\/b> 따끈한 한그릇<b>메뉴<\/b>로 넘나 마음에 든다 ★ 으슬으슬 비오고 쌀쌀한날 팔팔 끓는 뚝배기 한그릇....정말 소소하지만 확실한 행복! 이거 먹고 카페에서 커피에 디저트먹으면서 <b>비오는<\/b> 창밖을... ",
# 			"bloggername":"제리의 뷰티로그",
# 			"bloggerlink":"blog.naver.com\/rlachqkd",
# 			"postdate":"20190701"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> <b>메뉴<\/b>로 파전대신 간단술안주 <b>추천<\/b>: 골뱅이무침 + 양념... ",
# 			"link":"https:\/\/blog.naver.com\/coky3\/222433116946",
# 			"description":"코로나로 인해 밖에 돌아다닐 수 없지만 ㅠㅠ 그래도 <b>비오는 날<\/b>하면 한잔 해줘야 하는 것이 인지상정(?) 아니겠습니깡 ㅋㅋㅋ <b>비오는날<\/b> 빠르고 간편한 안주 <b>메뉴<\/b>로 살포시 <b>추천<\/b>드릴게요 ㅋㅋㅋ (집들이 메인 요리... ",
# 			"bloggername":"볼보맘이 되어버린 이작가네 이야기",
# 			"bloggerlink":"blog.naver.com\/coky3",
# 			"postdate":"20210715"
# 		},
# 		{
# 			"title":"장마철 <b>비오는날<\/b> 저녁<b>메뉴<\/b><b>추천<\/b> 사골 수제비",
# 			"link":"https:\/\/blog.naver.com\/chefzzong_\/220032760175",
# 			"description":"한국인의 힘은 밥힘에서 나<b>오는<\/b>게 맞는데... 밥 보다는 다른 것에 자꾸 눈길이 가더라구요. 장마철에... 이웃님들 <b>메뉴<\/b>로 어떠세요?! 10분안에 뚝딱 뚝딱 요리해 보세요~ 장마철 <b>비오는날<\/b> 저녁<b>메뉴<\/b><b>추천<\/b> 사골 수제비",
# 			"bloggername":"맛의 중심, 종가집",
# 			"bloggerlink":"blog.naver.com\/chefzzong_",
# 			"postdate":"20140617"
# 		}
# 	]
# }
# {
# 	"lastBuildDate":"Wed, 30 Aug 2023 13:55:05 +0900",
# 	"total":252558,
# 	"start":101,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"꼬치 어묵탕 끓이는법 꼬치어묵 <b>비오는날<\/b> 음식 <b>메뉴<\/b> 어묵탕... ",
# 			"link":"https:\/\/blog.naver.com\/misoo0612\/223105757307",
# 			"description":"할지 <b>메뉴<\/b> 생각이 1도 안 나는.... 시간은 다가<b>오는<\/b>데 반찬도 마땅치 않고 나 혼자 해결하는 거면 대충... 금방이니 <b>비오는날<\/b> <b>메뉴<\/b> <b>추천<\/b>으로 괜찮다 싶어요. 국물도 좋고, 탱글 하게 씹히는 어묵도 맛있고 입이... ",
# 			"bloggername":"시크하고 도도한 토깽이가 살아효 。 。",
# 			"bloggerlink":"blog.naver.com\/misoo0612",
# 			"postdate":"20230518"
# 		},
# 		{
# 			"title":"삼송]동화같은 감성 디저트카페 엔담 endam(<b>비오는날<\/b>도 <b>추천<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/kkj7770\/223189985875",
# 			"description":"주문한 <b>메뉴<\/b> 등장! 커피는 나도 일행도 아메리카노 디저트 먹을때는 아메리카노! 커피맛도 좋았다! 카페 알아볼때부터 궁금했던 블루베리 치즈케이크 꼭 선물 받은거마냥 보자기 모양으로 나<b>오는<\/b>것도 마음에... ",
# 			"bloggername":"단방향소통 생활기록부",
# 			"bloggerlink":"blog.naver.com\/kkj7770",
# 			"postdate":"20230822"
# 		},
# 		{
# 			"title":"미미사500원양꼬치 <b>비오는날 추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/epic_study\/222903918024",
# 			"description":"세트<b>메뉴<\/b>가 있었지만 저희는 생양꼬치와 양갈비살을 시켰어요. 요리로는 가지요리를 시켰습니다.... 특히, <b>비오는날<\/b> 미미사500원양꼬치에서 칭다오 한잔~ 강력하게 <b>추천<\/b>합니다. 내돈내산 리얼후기였습니다.... ",
# 			"bloggername":"에픽스터디학원",
# 			"bloggerlink":"blog.naver.com\/epic_study",
# 			"postdate":"20221018"
# 		},
# 		{
# 			"title":"야채전 만드는법  해물  버섯 모둠전   <b>비오는 날<\/b>   <b>메뉴<\/b> <b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/lover4333\/223131313786",
# 			"description":"야채전 만드는법 해물 버섯 모둠전 비 오는 날 메뉴 추천 냉털 요리 글\/사진 요래요래 쿡 [재료]... 피로를 풀어보세요~♡ 야채 전 만드는법 <b>비 오는 날 추천 메뉴<\/b>로 알아 보았습니다. 맛있는 주말 보내세요 ~^^",
# 			"bloggername":"호기심부자 요래언니. 오늘은 머하노? ?",
# 			"bloggerlink":"blog.naver.com\/lover4333",
# 			"postdate":"20230617"
# 		},
# 		{
# 			"title":"앞산대구손칼국수 <b>비오는날 추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/luv_virus_\/221180174804",
# 			"description":"비가 <b>오는 날<\/b>이면 기분이 뭔가 차분해지는건 어쩔 수 없나봐요 그저께 다녀온 대구 앞산순환도로... 다른 가게에 주차하고 가는건 매너가 아니니까요~ 오늘처럼 <b>비 오는 날<\/b>에 뜨끈한 국물이 있는 식사는 어떨까요?^^",
# 			"bloggername":"하루 한걸음씩",
# 			"bloggerlink":"blog.naver.com\/luv_virus_",
# 			"postdate":"20180108"
# 		},
# 		{
# 			"title":"저녁<b>메뉴<\/b> <b>추천<\/b> <b>비오는날<\/b> 음식 제 장바구니 목록",
# 			"link":"https:\/\/blog.naver.com\/kyungm2001\/222760364164",
# 			"description":"내일 <b>비<\/b>  가 오락가락~ <b>비오는날<\/b> 음식 #<b>비오는날<\/b>음식 https:\/\/m.blog.naver.com\/kyungm2001\/222281676248 #<b>비오는날<\/b>먹는음식 #<b>비오는날<\/b><b>메뉴<\/b> #<b>비오는날<\/b>뭐먹지 #<b>비오는날<\/b>음식<b>추천<\/b>... ",
# 			"bloggername":"달타냥하우스",
# 			"bloggerlink":"blog.naver.com\/kyungm2001",
# 			"postdate":"20220605"
# 		},
# 		{
# 			"title":"부추미나리장떡 <b>비오는날 추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/ykkim9500\/221906004343",
# 			"description":"전 부침개 완전 <b>추천<\/b>이요... 조금씩 남은 재료들 사실 활용해서 하나 요리 만들기 쉽지 않은데 부침개는... 부침개로 점심 맛있게 먹었어요...ㅎ <b>비오는날<\/b> 먹으면 정말 더 맛있을듯 싶네요...ㅎㅎ",
# 			"bloggername":"손 끝으로 완성되는 따스함",
# 			"bloggerlink":"blog.naver.com\/ykkim9500",
# 			"postdate":"20200509"
# 		},
# 		{
# 			"title":"\/샤브칼국수맛집\/산내마을맛집\/<b>비오는날<\/b><b>메뉴<\/b><b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\
# 			"link":"https:\/\/blog.naver.com\/luv_virus_\/220822156529",
# 			"description":"<b>비오는날 추천메뉴<\/b> 아나고막창에 맥주한잔 그리고 수제만두랑 맥주한잔 어제는 퇴근시간부터 비가... 급 메뉴변경!! 아나고를 포기할 순 없죠 가볍게 아나고를 쌈에 싸서.... 비오는 날이라 그런지 아나고에... ",
# 			"bloggername":"하루 한걸음씩",
# 			"bloggerlink":"blog.naver.com\/luv_virus_",
# 			"postdate":"20160927"
# 		},
# 		{
# 			"title":"칼국수밀키트 <b>비오는날<\/b><b>메뉴<\/b> <b>추천<\/b> 입장정원칼국수",
# 			"link":"https:\/\/blog.naver.com\/itnamu\/222521274996",
# 			"description":"#칼국수밀키트 #칼국수택배 #입장정원칼국수 #입장정원칼국수택배 #칼국수택배 #캠핑<b>메뉴<\/b> #<b>비오는날<\/b> #<b>비오는날<\/b><b>메뉴<\/b> #<b>비오는날<\/b><b>메뉴<\/b><b>추천<\/b> #면요리 #면요리맛집 #칼국수맛집 #칼국수만드는법 #캠핑요리<b>추천<\/b>... ",
# 			"bloggername":"itnamu의 포토로그",
# 			"bloggerlink":"blog.naver.com\/itnamu",
# 			"postdate":"20210929"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> <b>메뉴<\/b>로 강추 정원... 캠핑요리<b>추천<\/b>, 캠핑<b>메뉴<\/b> )",
# 			"link":"https:\/\/blog.naver.com\/bmclub27\/222547142805",
# 			"description":"naver.com\/jungwon1914\/products\/5441773486 #국수밀키트 #칼국수밀키트 #칼국수맛집 #칼국수택배 #캠핑<b>메뉴<\/b> #<b>비오는날<\/b><b>메뉴<\/b> #바지락칼국수 #칼국수만드는법 #캠핑요리<b>추천<\/b> #입장정원칼국수 #정원칼국수 #밀키트<b>추천<\/b>",
# 			"bloggername":"Hong Kong Diary:)",
# 			"bloggerlink":"blog.naver.com\/bmclub27",
# 			"postdate":"20211025"
# 		},
# 		{
# 			"title":"일산 맛집 | <b>비 오는 날<\/b> <b>메뉴<\/b><b>추천<\/b> 일산 칼국수 웨이팅 주차",
# 			"link":"https:\/\/blog.naver.com\/100folktales\/223161809276",
# 			"description":"진짜 <b>비오는 날<\/b> 좋은 <b>메뉴<\/b> 선택이었던 것 같습니다!! 일산에서 뭘 먹을까 고민 되실 때 한번 드셔보세요! 뱃골이 크시다면 완칼 하시고 공기밥 추가해서 말아 드시는 거 <b>추천<\/b>드립니다!!! 제가 그렇게 먹고싶었어요... ",
# 			"bloggername":"꽉 찬 행복",
# 			"bloggerlink":"blog.naver.com\/100folktales",
# 			"postdate":"20230720"
# 		},
# 		{
# 			"title":"감자수제비만들기, <b>비오는날<\/b><b>메뉴<\/b><b>추천<\/b>, 저녁<b>메뉴<\/b><b>추천<\/b>(저메추)... ",
# 			"link":"https:\/\/blog.naver.com\/ssmj0730\/223139586910",
# 			"description":"마트에서 수제비 사리 보이면 꼭 한번 만들어보세요. 오늘은 <b>비 오는 날<\/b> 어울리는 <b>메뉴<\/b> <b>추천<\/b>해 드렸습니다. 여러분은 비가 오면 어떤 <b>메뉴<\/b>가 먹고 싶으세요? 그럼 오늘도 맛있고 건강한 하루 보내시길 바랍니다.",
# 			"bloggername":"옆집 영양사 언니",
# 			"bloggerlink":"blog.naver.com\/ssmj0730",
# 			"postdate":"20230627"
# 		},
# 		{
# 			"title":"동구 일산지 <b>비 오는 날<\/b> 순두부 맛집 점심 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/cellosj\/223142382457",
# 			"description":"점심 <b>메뉴<\/b> 고르실 때 맛집으로 <b>추천<\/b>할 만한 집이 있어서 글을 써 봅니다 지금은 비가 많이 오고 있는데 낮에는 비가 안 왔어요 ㅎ 그래도 <b>비 오는 날<\/b> 순두부 먹으면 더 맛있을 거 같지 않나요? 전 원래... ",
# 			"bloggername":"다핸즈",
# 			"bloggerlink":"blog.naver.com\/cellosj",
# 			"postdate":"20230629"
# 		},
# 		{
# ...
# 			"postdate":"20201215"
# 		},
# 		{
# 			"title":"VALDOS COFFEE 안산선부점 <b>비오는날 추천메뉴<\/b>☔️",
# 			"link":"https:\/\/blog.naver.com\/durug10\/222837886860",
# 			"description":"안녕하세요 발도스커피 안산선부점에서 <b>비오는날<\/b>과 어울리는 <b>메뉴<\/b> <b>추천<\/b>드립니다:) 비도오고 그래서 니 생각이나서~~☔️ <b>비오는날<\/b>은 달달한 발도스커피로 함께해요❤️",
# 			"bloggername":"발도스커피 안산선부점",
# 			"bloggerlink":"blog.naver.com\/durug10",
# 			"postdate":"20220802"
# 		},
# 		{
# 			"title":"[천호 맛집] 닭한마리, <b>비오는날<\/b> 저녁<b>메뉴<\/b>로 어떠세요-",
# 			"link":"https:\/\/blog.naver.com\/dbstnal\/20188525199",
# 			"description":"친구 썬양의 <b>추천<\/b>으로 닭한마리로 고고씽합니다 천호동 쭈꾸미골목으로 들어서면, 독도쭈꾸미1호점 옆에 바로 보여요. <b>메뉴<\/b>는 닭과 칼국수, 사리뿐이 없지만, 또 요렇게 한<b>메뉴<\/b>만 하는곳이 진국아니겠어요... ",
# 			"bloggername":"초록기린숲 by ㄹi프",
# 			"bloggerlink":"blog.naver.com\/dbstnal",
# 			"postdate":"20130528"
# 		},
# 		{
# 			"title":"유강맛집 <b>비오는 날<\/b> 파전에 막걸리는 유강파전에서",
# 			"link":"https:\/\/blog.naver.com\/moda3\/223041991382",
# 			"description":"포장 주문 시 미리 주문하고 방문하시는 것을 <b>추천<\/b> 4. 매장이 바쁘다보니 친절하진 않지만, 파전과 육전이 맛있었던 곳 (약간 츤데레) (개인적인 견해이니 오해 금지) <b>비오는 날<\/b>은 역시 전이나 부침개 만한 게... ",
# 			"bloggername":"송모다의 리뷰로그",
# 			"bloggerlink":"blog.naver.com\/moda3",
# 			"postdate":"20230312"
# 		},
# 		{
# 			"title":"<b>비오는 날<\/b>의 <b>메뉴<\/b>! 수제비와 고기완자전 &lt;그래! 이집&gt; 행신동... ",
# 			"link":"https:\/\/blog.naver.com\/dwlyl\/222799760608",
# 			"description":"#행신동숨은맛집 #그래이집수제비 #수제비맛집 #고기완자전맛집 #수제비 #고기완자전 #행신동점심<b>메뉴<\/b> #행신동맛집 #행신동<b>추천<\/b> #그래이집칼제비 #얼큰수제비 #<b>비오는날<\/b><b>메뉴<\/b> #내돈내먹 #솔직리뷰 #맛있음",
# 			"bloggername":"Il y aura des jours meilleurs",
# 			"bloggerlink":"blog.naver.com\/dwlyl",
# 			"postdate":"20220704"
# 		},
# 		{
# 			"title":"칼국수 맛집\/왕만두 맛집\/<b>비오는날<\/b> <b>메뉴<\/b><b>추천<\/b>: 【남촌칼국수】",
# 			"link":"https:\/\/blog.naver.com\/tnwls5903\/223157366234",
# 			"description":"최애 <b>메뉴<\/b>가 칼국수여서 포스팅은 처음이지만 한달에 몇번씩은 꼭 먹으러 <b>오는<\/b>거같아요 ㅋㅋㅋ 들어오면 바로 보이는 홀에는 식탁 테이블이 있고 안쪽으로 더 들어가면 좌식 룸도 있어요 :) 룸 이름이 랍스타... ",
# 			"bloggername":"우당탕탕➿",
# 			"bloggerlink":"blog.naver.com\/tnwls5903",
# 			"postdate":"20230716"
# 		},
# 		{
# 			"title":"삿포로 후라노 비에이 <b>비오는날<\/b>, 버스투어 <b>추천<\/b>(훗카이도랩... ",
# 			"link":"https:\/\/blog.naver.com\/youare-good\/223185032005",
# 			"description":"<b>메뉴<\/b>와 함께 나<b>오는<\/b> 우유가 진짜 맛있어요. 별도로 포스팅 해보려고 해요 :) 2. 사계채의 언덕 가장 먼저 방문한 곳은 사계채의 언덕이었어요. 이 <b>날<\/b> 날씨가 흐리고 비가 조금씩 와서 본래 투어 일정을 약간... ",
# 			"bloggername":"어른이 성장 일지",
# 			"bloggerlink":"blog.naver.com\/youare-good",
# 			"postdate":"20230816"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 땡기는 막걸리 맛집 미사술집 금복주류",
# 			"link":"https:\/\/blog.naver.com\/melchisedech91\/223188124358",
# 			"description":"미사술집 금복주류 맛난 막걸리와 파전이 있는 <b>비오는 날<\/b> 찾기 좋은 주점 안녕하세요 잇님들 오늘은... 직원분 호출도 태블릿으로 하더라구요 d_d 금복주류 <b>메뉴<\/b> <b>추천<\/b> 금복주류 <b>메뉴<\/b>를 간단히 살펴볼게요! 일단... ",
# 			"bloggername":"매르의 리뷰월드",
# 			"bloggerlink":"blog.naver.com\/melchisedech91",
# 			"postdate":"20230819"
# 		},
# 		{
# 			"title":"양주 카페 <b>추천<\/b>, <b>비오는날<\/b>도 예쁜 양주 통창 카페 : 브루다 양주",
# 			"link":"https:\/\/blog.naver.com\/1007eui\/223169773513",
# 			"description":"날이 흐리고 비가<b>오는<\/b>데 어디 카페 가지 하다가 브루다 양주 발견 통창 때문에 트여보이고 예쁠것... #양주카페 #장흥카페 #양주브루다 #통창카페 #양주카페<b>추천<\/b> #양주예쁜카페 #양주<b>비오는날<\/b> #통창카페",
# 			"bloggername":"루루는 쩝쩝박사",
# 			"bloggerlink":"blog.naver.com\/1007eui",
# 			"postdate":"20230730"
# 		},
# 		{
# 			"title":"카페거리 닭발구역 포장 후기 <b>비오는날<\/b> 막걸리 <b>추천메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/chobani9\/222039033132",
# 			"description":"담에 또 먹으러 갈예정입니다 #용인죽전닭발 #닭발구역 #죽전카페거리 #카페거리맛집 #죽전맛집 #<b>비오는날<\/b><b>메뉴<\/b><b>추천<\/b> #<b>비오는날<\/b>닭발 #닭발조합 #닭발막걸리 #닭발소주 #느린마을막걸리 #한라산17도",
# 			"bloggername":"린지의 여행과일상",
# 			"bloggerlink":"blog.naver.com\/chobani9",
# 			"postdate":"20200723"
# 		},
# 		{
# 			"title":"길음동 맛집 두메골 마늘보쌈 칼국수까지 <b>비 오는 날<\/b> 찰떡 <b>메뉴<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/mj_4819\/222867499974",
# 			"description":"#삼양사거리역맛집 #길음동맛집 #미아맛집 #두메골 #두메골마늘보쌈 #<b>비오는날추천메뉴<\/b>... 어제 비도 왔는데 메뉴가 완전 비 오는 날에 찰떡이었다 테이블이 만석인데 어르신들이 많았고 다들 막걸리 한잔씩... ",
# 			"bloggername":"나는야 김만조잉",
# 			"bloggerlink":"blog.naver.com\/mj_4819",
# 			"postdate":"20220905"
# 		},
# 		{
# 			"title":"부산자갈치꼼장어 :: 대방역 <b>비오는날 추천 메뉴<\/b>_ 꼬들꼬들한... ",
# 			"link":"https:\/\/blog.naver.com\/hi_shayla\/221598603107",
# 			"description":"오래 올려두면 탄다 고로, 빨리 먹어야지 ㅋㅋㅋㅋ 다 먹을때쯤 이렇게 누룽지도 주시니 닭발을 시킬수가 없다 배부름. ㅎㅎ 특히 꼼장어는 <b>비오는날<\/b> 생각나는 <b>메뉴<\/b>이므로 다음에 <b>비오는날<\/b> 한번 더 가봐야겠다",
# 			"bloggername":"셰일라의 즐거운생활♡",
# 			"bloggerlink":"blog.naver.com\/hi_shayla",
# 			"postdate":"20190729"
# 		},
# 		{
# 			"title":"퓨전짬뽕 맛집 뽕신인더가든 천호점 : <b>비오는 날<\/b> 점심<b>메뉴<\/b> 초이스!",
# 			"link":"https:\/\/blog.naver.com\/adsl224\/220721633235",
# 			"description":"안말린 점원이 밉더라구요ㅠㅠ 테이크아웃 해달라고 할 뻔... <b>비오는 날<\/b>, 국물 땡기는 <b>날<\/b>, 특별하지 않은데 부담없이 맛난거 먹고싶을 때 천호동 맛집 뽕신인더가든 <b>추천<\/b>해요! 여기까지 쾡쾡이었습니다!",
# 			"bloggername":"Day to day",
# 			"bloggerlink":"blog.naver.com\/adsl224",
# 			"postdate":"20160528"
# 		},
# 		{
# 			"title":"김치전 만들기\/<b>비오는날<\/b> <b>메뉴<\/b><b>추천<\/b>\/주말<b>메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/ssun0113\/222290376053",
# 			"description":"김치전 만들기\/<b>비오는날<\/b> <b>메뉴<\/b><b>추천<\/b>\/주말<b>메뉴<\/b> 오늘은 일요일, 하루종일 촉촉한 봄비가 내리네요. <b>비오는날<\/b>은 부침개^^ 진리입니다ㅎㅎ 냉장고에 묵은지랑 해물이 좀 있어서 바로 꺼내서 김치전 만들었어요... ",
# 			"bloggername":"써니쿡의 힐링푸드스토리",
# 			"bloggerlink":"blog.naver.com\/ssun0113",
# 			"postdate":"20210328"
# 		},
# 		{
# 			"title":"제주도 <b>비오는날<\/b> 가볼만한곳* 오설록티뮤지엄... ",
# 			"link":"https:\/\/blog.naver.com\/sseossun\/223134946880",
# 			"description":"제주도 <b>비오는날<\/b>에도 가기 좋은 카페나 장소를 잘 찾아가면 그 분위기를 즐기게 된답니다 :) 제주도여행 넷째 <b>날<\/b> 코스는 &lt;제주 오설록티뮤지엄- 신라 더파크뷰뷔페 롯데아트빌라스 체크인 - 호텔수영 포도호텔... ",
# 			"bloggername":"인생은 여행처럼",
# 			"bloggerlink":"blog.naver.com\/sseossun",
# 			"postdate":"20230621"
# 		},
# 		{
# 			"title":"바삭하게 만드는법 밀가루 부침개 간장소스 <b>비오는날<\/b> 음식 <b>메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/my-dailylife\/223142346971",
# 			"description":"글 사진 \/푸드쿡 김치 부침개 바삭하게 만드는법 밀가루 부침개 간장소스 <b>비오는날<\/b> 음심 <b>메뉴<\/b> 비데이 ~ 빗소리와 닮은 소리를 내는 #부침개 가 생각이나서. 부지런히 #간식요리 로 한장 부쳐봤습니다.... ",
# 			"bloggername":"푸드쿡 & 맛집여행",
# 			"bloggerlink":"blog.naver.com\/my-dailylife",
# 			"postdate":"20230629"
# 		},
# 		{
# 			"title":"<b>비오는날 추천메뉴<\/b> 화순 능주삼거리식당의 소머리국밥 맛있게... ",
# 			"link":"https:\/\/blog.naver.com\/blogking77\/220412715688",
# 			"description":"단골식당이랍니다 메뉴와 가격은 다른곳에 비해 큰차이는 없어요 쟁반에 담아온 소머리국밥 침이... 제가 추천하는국밥 맛있게 먹는법이지요 화순 능주가시는분은 이곳에서 국밥드셔보세요 <b>비오는날 추천메뉴<\/b>... ",
# 			"bloggername":"밤을잊은농부들의 밤농프리마켓 안전한 농산물",
# 			"bloggerlink":"blog.naver.com\/blogking77",
# 			"postdate":"20150707"
# 		},
# 		{
# 			"title":"<b>비오는 날<\/b> 아침 공덕)아이엠베이글- 전<b>메뉴<\/b> 가격\/ 무료 러스크랑... ",
# 			"link":"https:\/\/blog.naver.com\/demianincanada\/223044044957",
# 			"description":"이런 <b>비오는 날<\/b>엔 창가 좋은데 등장 두손 모으고 사진 다 찍기 대기 여전히 다소곳 베이글에 이번 달... 가지러 <b>오는<\/b> 동안 <b>메뉴<\/b>도 찍어 보고.. 시간도 이르고 비도 와서 인지 매장이 오랜만에 여유가 있어서... ",
# 			"bloggername":"소소소한 일상",
# 			"bloggerlink":"blog.naver.com\/demianincanada",
# 			"postdate":"20230314"
# 		},
# 		{
# 			"title":"사월역 카페 <b>비오는 날<\/b>도 좋아 [켑트베이커스]",
# 			"link":"https:\/\/blog.naver.com\/sil6789\/223110413164",
# 			"description":"친구들이 저번부터 맛있다고 유명한 베이커리 카페를 <b>추천<\/b>받아왔다면서 가보자고 했었거든요. 한... <b>비 오는 날<\/b>은 역시 따뜻한 커피죠. 촉촉하게 <b>오는<\/b> <b>비<\/b> 구경하면서 따뜻한 라떼 한잔 해주니까 괜히 감성이 막... ",
# 			"bloggername":"현명한 경제 이야기",
# 			"bloggerlink":"blog.naver.com\/sil6789",
# 			"postdate":"20230524"
# 		},
# 		{
# 			"title":"서울 <b>비 오는 날<\/b> 갈만한 곳. 잠실 브런치가 맛있는 집 <b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/kimdoeun0729\/223194279502",
# 			"description":"중 <b>메뉴<\/b>가 당겼던 건 아니었는데 한 번 와보고 싶었던 곳으로 택했다. 세상의 모든 아침 롯데월드... 서울 <b>비 오는 날<\/b> 가볼 만한 곳으로 너무 괜찮은 이곳. 도도 역시 이날 비가 와서 옴짝달싹 못한 <b>날<\/b>.... ",
# 			"bloggername":"맛집•여행•일상을 기록하는 도도의 블로그",
# 			"bloggerlink":"blog.naver.com\/kimdoeun0729",
# 			"postdate":"20230826"
# 		},
# 		{
# 			"title":"칼국수밀키트 <b>추천<\/b> 진지알곤이칼국수로 <b>비오는 날<\/b> 시원하고... ",
# 			"link":"https:\/\/blog.naver.com\/muybien45\/222843272620",
# 			"description":"알곤이칼국수에 계란 솔솔 풀고 청양고추 살짝 때려박아 먹으면 <b>비오는 날<\/b> 캬- 임창정 오라버니의... 시그니처 <b>메뉴<\/b>인 알곤이칼국수를 집에서 밀키트로 먹을 수 있는 제품이다. 캬, 우리 김쉐프님의 완성 작품!... ",
# 			"bloggername":"다섯개의 별",
# 			"bloggerlink":"blog.naver.com\/muybien45",
# 			"postdate":"20220809"
# 		},
# 		{
# 			"title":"가산디지털 맛집 | 달빛주막, 막걸리와 모듬 전 <b>비오는 날 추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/awesomejin_\/222875724934",
# 			"description":"이번에 달빛주막 생각나서 갔어요 거의 10시 다돼서 갔더니 사람이 별로 없어서 좋았어요 전류 <b>메뉴<\/b>... <b>비오는 날<\/b>에 여기는 난리날거같아요 회식이나 모임장소로도 좋아보이구요 가벼운 2차로도 <b>추천<\/b>합니다 -",
# 			"bloggername":"Awesome day :)",
# 			"bloggerlink":"blog.naver.com\/awesomejin_",
# 			"postdate":"20220915"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 아이랑갈만한곳, 이케아 데이트 어린이장난감 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/j_u_n_t_a\/223142928820",
# 			"description":"<b>비오는날<\/b> 아이랑갈만한곳 이케아 데이트 어린이장난감 <b>추천<\/b> 딸과 주말에 삼송역으로 데이트를... 김치볶음밥과 어린이<b>메뉴<\/b> 베지볼1개 초코빵1개 주문했어요! 엄마랑 단둘이 나와서 그저 행복한 어린이 ㅋㅋ... ",
# 			"bloggername":"애들아 놀러가자",
# 			"bloggerlink":"blog.naver.com\/j_u_n_t_a",
# 			"postdate":"20230702"
# 		},
# 		{
# 			"title":"가포카페 다녀왔어요!! <b>비오는 날<\/b>에 더 <b>추천<\/b>합니다 #내돈내산후기",
# 			"link":"https:\/\/blog.naver.com\/twobinee\/223092338095",
# 			"description":"기록 <b>비오는 날<\/b> 좋을 것 같다~ 했는데 진짜 좋더라고요!! 주차하고 매장 들어가기까지 우산쓰고 이동하는 것만 빼면 완벽했어요 (<b>비<\/b> 맞는 거 안 좋아함..) 메르칼므 분위기 좋아서 데이트 장소로도 <b>추천<\/b>합니당!... ",
# 			"bloggername":"집수빈의 탈출기록",
# 			"bloggerlink":"blog.naver.com\/twobinee",
# 			"postdate":"20230503"
# 		},
# 		{
# 			"title":"경기도 실내데이트 카페, 눈<b>오는날<\/b> <b>비오는날<\/b>데이트 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/dmgk32\/222570819512",
# 			"description":"눈<b>오는날<\/b>, <b>비오는날<\/b> 데이트 <b>추천<\/b> 카페 경기도 실내데이트<b>추천<\/b> 서울 근교 경기도에는 눈<b>오는날<\/b>이나... 음료나 베이커리 이용시 1시간으로 이용 시간 제한이 있어서, 두세시간 놀다 오실 분들은 브런치 <b>메뉴<\/b>... ",
# 			"bloggername":"@유징유",
# 			"bloggerlink":"blog.naver.com\/dmgk32",
# 			"postdate":"20211117"
# 		},
# 		{
# 			"title":"<b>비오는 날<\/b>에는연탄구이집에서 소금구이 <b>메뉴<\/b>를 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/yogolmok\/222055035512",
# 			"description":"<b>비오는 날<\/b>에 <b>추천 메뉴<\/b>로 근처 연탄구이집에서 소금구이가 좋습니다. 고기집에 가면 고기굽느라 별로... 비가 <b>오는 날<\/b> 점심이나 저녁 <b>메뉴<\/b>로 연탄구이집은 왠지 정감이 있어 좋습니다. 요즘 뉴스를 보면 비피해가... ",
# 			"bloggername":"요! 골목",
# 			"bloggerlink":"blog.naver.com\/yogolmok",
# 			"postdate":"20200808"
# 		},
# 		{
# 			"title":"사용하는 표선 닭해장국 \/ 위치 및 운영시간 \/ <b>비오는 날 추천 메뉴<\/b>",
# 			"link":"https:\/\/blog.naver.com\/jessiemonkey\/222482892990",
# 			"description":"봤었는데 <b>비<\/b> 덕분(?)에 조용하게 식사할 수 있었어요 ㅎㅎ <b>메뉴<\/b>와 가격표는 요렇습니다 ! 요즘 한 끼에 9천원, 만 원 하는 곳도 많은데 제주산 닭고기 + 매일 새로 우려내는 육수에 이 정도 가격이면 딱 적당하지유... ",
# 			"bloggername":"여행하는 쩨씨몽키",
# 			"bloggerlink":"blog.naver.com\/jessiemonkey",
# 			"postdate":"20210825"
# 		},
# 		{
# 			"title":"가평 글램핑 하늘숲캠핑장 <b>비오는날<\/b> 단체글램핑 <b>추천<\/b>(ft. 장어)",
# 			"link":"https:\/\/blog.naver.com\/supermandaddy\/223162470921",
# 			"description":"가평 글램핑 하늘숲캠핑장 <b>비오는날<\/b> 단체글램핑 <b>추천<\/b>(ft. 장어) <b>비오는날<\/b> 캠핑 어떠신가요? 싫어하는... 오늘 메인 <b>메뉴<\/b>는 장어구이입니다. 캠핑장 장어 생각보다 맛있고요. 배부르게 잘 먹고 보드게임하다... ",
# 			"bloggername":"아빠만세",
# 			"bloggerlink":"blog.naver.com\/supermandaddy",
# 			"postdate":"20230721"
# 		},
# 		{
# 			"title":"가평 아기랑 갈만한 곳 <b>비 오는 날<\/b> 1박 2일",
# 			"link":"https:\/\/blog.naver.com\/lovetjsgnl\/223159381211",
# 			"description":"가평 <b>비 오는 날<\/b> 아기랑 1박 2일 코스 카페 어텐디드가든카페 - 가평 키즈 풀빌라- 언덕마루 가평 잣... 어텐디드가든카페 <b>추천<\/b>받은 소금빵이 정말 너무 맛있었다. 빗길에 2시간 넘게 운전해서 너무나... ",
# 			"bloggername":"honey HANI[하니 하니]",
# 			"bloggerlink":"blog.naver.com\/lovetjsgnl",
# 			"postdate":"20230718"
# 		},
# 		{
# 			"title":"[망원\/성산동 맛집] 호호라멘 \/ <b>비오는 날 추천 메뉴<\/b> \/ 망원... ",
# 			"link":"https:\/\/blog.naver.com\/y__hh\/222546631820",
# 			"description":"<b>메뉴<\/b>가 없어 짠 ㅋㅋㅋㅋㅋ 내가 언니들 보는 시선.. 카와이 우리가 시킨 <b>메뉴<\/b>는 #카라이돈코츠 (매콤한 맛) *2 #돈코츠 (순한맛) 흰밥 교자5p 주문은 키오스크로 : ) 너무 늦게 발견해버인 리뷰작성 가게... ",
# 			"bloggername":"La vita è bella",
# 			"bloggerlink":"blog.naver.com\/y__hh",
# 			"postdate":"20211024"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 막걸리안주 바삭하고 고소한 문현 동래허파전 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/goindol71\/222859037133",
# 			"description":"<b>비오는날<\/b> 먹고 싶은 <b>메뉴<\/b> 중 하나인 파전 이제는 문현 동래허파전 생각이 먼저 <b>날<\/b> 거 같아요. 우삼겹이나 새우를 넣어서 식감이나 풍미를 더 좋게 먹는 것도 좋을 거 같네요. 파전 많이 먹어보지 않은 와이프도... ",
# 			"bloggername":"캠핑하는 쭈니네",
# 			"bloggerlink":"blog.naver.com\/goindol71",
# 			"postdate":"20220826"
# 		},
# 		{
# 			"title":"힙한곳 <b>비오는날<\/b> 분위기 좋은곳 안주 <b>메뉴<\/b> 전 막걸리 전통주... ",
# 			"link":"https:\/\/blog.naver.com\/1004jeh1004\/223134627045",
# 			"description":"오늘처럼 비가 <b>오는날<\/b> 생각나는 <b>메뉴<\/b> 대한민국 사람이라면 70%는 파전+막걸리 생각하실텐데요. <b>비오는날<\/b> 퇴근길 가고 싶은 곳 부치곰 노량진본점 입니다. 주소 : 서울시 동작구 만양로16길 8 영업시간 : 일-목... ",
# 			"bloggername":"안나의 맛집 투어☆",
# 			"bloggerlink":"blog.naver.com\/1004jeh1004",
# 			"postdate":"20230621"
# 		},
# 		{
# 			"title":"경기도 <b>비오는날<\/b> 아이와... 맛집 8곳 <b>추천<\/b> 주차 <b>메뉴<\/b> 가격 정보포함",
# 			"link":"https:\/\/blog.naver.com\/afternoon_garden\/223093995949",
# 			"description":"메이트버거는 모든 <b>메뉴<\/b>가 맛있었지만 커피는 별로였어요. 음료와 함께 드시는 것을 <b>추천<\/b>합니다.... 우육면 샤오롱바오 가지만두 꿔바로우 엉클브룩스쥬 맛집 샤오바<b>오는<\/b> 현지의 맛이면서도 한국인에게... ",
# 			"bloggername":"오후의 정원",
# 			"bloggerlink":"blog.naver.com\/afternoon_garden",
# 			"postdate":"20230505"
# 		},
# 		{
# 			"title":"요리하는 마술사 서울 <b>비오는 날<\/b> 아이와 대학로 공연 <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/yukjeonghee7\/223159007444",
# 			"description":"햄버거 마술 요리하는 마술사에는 다양한 <b>메뉴<\/b>가 등장하는데요. 햄버거 안의 내용물 중 가장 중요한... 여름방학은 다가<b>오는<\/b>데 <b>비오는 날<\/b> 서울 아이와 가볼만한 곳 대학로 공연 요리하는 마술사 <b>추천<\/b>합니다. 두... ",
# 			"bloggername":"화성에서 온 여자★여섯쩡",
# 			"bloggerlink":"blog.naver.com\/yukjeonghee7",
# 			"postdate":"20230717"
# 		},
# 		{
# 			"title":"<b>비오는날<\/b> 분위기 있는 밀양 한옥 느낌 카페 <b>추천<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/is__rain\/222835549477",
# 			"description":"때 <b>메뉴<\/b>판 22년 7월 방문 했을 때 <b>메뉴<\/b>판 입니다 <b>메뉴<\/b>가 더 많아졌어요 디저트도 준비되어 있어요... 꾸덕꾸덕해서 맛있는 치즈케이크 <b>추천<\/b>합니다 특히 <b>비오는 날<\/b> 오면 운치 있고 더 좋은... ",
# 			"bloggername":"나는 당근주황",
# 			"bloggerlink":"blog.naver.com\/is__rain",
# 			"postdate":"20220731"
# 		},
# 		{
# 			"title":"봉천점 | 선선하니 <b>비 오는 날 추천<\/b>하는 곳 (<b>메뉴<\/b> <b>추천<\/b>)",
# 			"link":"https:\/\/blog.naver.com\/j50149\/222857176667",
# 			"description":"다양해서 <b>비 오는 날<\/b> 가볍게 들려서 먹기 딱 좋은 곳!!! 참고로 매장 안이 막 깨끗한 느낌이 아니니, 평소에 포차 느낌을 좋아하는 분들께 <b>추천<\/b>! 서울 전집 원탑은 바로 이곳!! https:\/\/blog.naver.com\/j50149... ",
# 			"bloggername":"다은의 맛있는 일상",
# 			"bloggerlink":"blog.naver.com\/j50149",
# 			"postdate":"20220828"
# 		},
# 		{
# 			"title":"<b>비 오는 날<\/b> 더 생각나는 맛집 \/ 충북혁신도시 쌈국수 <b>메뉴<\/b> <b>추천<\/b>",
# 			"link":"https:\/\/blog.naver.com\/dearhye_\/222371464525",
# 			"description":"<b>비 오는 날<\/b> 더 생각나는 맛집, 충북혁신도시 쌈국수 :) 올해는 정말 비가 많이 내리는 것 같다. 오늘같이 폭우처럼 쏟아지는 날은 차도 깨끗해져서 좋다 대신 난 실내에 있어야 좋음 무튼, <b>비<\/b> 오니까 생각나는... ",
# 			"bloggername":"dear, moments",
# 			"bloggerlink":"blog.naver.com\/dearhye_",
# 			"postdate":"20210528"
# 		},
# 		{
# 			"title":"[일산 본점] 등촌샤브칼국수 <b>비오는 날<\/b> 저녁 <b>메뉴<\/b>로 <b>추천<\/b>해요",
# 			"link":"https:\/\/blog.naver.com\/happytourshare\/222826121655",
# 			"description":"안녕하세요, 행복한여행나눔입니다. 다들 토요일 주말 잘 보내고 계신가요? 오후부터 떨어진 비로 상쾌함이 덤으로 왔습니다. 오늘은 고양 일산에 있는 등촌샤브칼국수 일산 본점에 다녀온 후기를 들려드리고자... ",
# 			"bloggername":"행복한여행나눔",
# 			"bloggerlink":"blog.naver.com\/happytourshare",
# 			"postdate":"20220723"
# 		},
# 		{
# 			"title":"수원 행궁동 놀 거리, 볼거리, 데이트 <b>추천<\/b>, <b>비 오는 날<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/tjrwls7575\/223197008814",
# 			"description":"<b>추천<\/b> 장소들을 알려드리려고합니다!! 그럼 <b>비 오는 날<\/b>의 행궁동은 어떤 모습일지??? 방화수류정 (<b>비 오는<\/b>... <b>비 오는<\/b> 구름만 하염없이 바라보고 있었습니다 ㅋㅋㅋㅋㅋㅋ 그래도 은근 비가 <b>오는<\/b> 호수의 풍경도... ",
# 			"bloggername":"꿈같은 일상을 이야기하는 몽상가",
# 			"bloggerlink":"blog.naver.com\/tjrwls7575",
# 			"postdate":"20230830"
# 		},
# 		{
# 			"title":"스프카레 그리울 때? 강남역 맛집 '히쿠마' <b>비오는 날<\/b> 딱 좋네!",
# 			"link":"https:\/\/blog.naver.com\/v_holic\/223100677817",
# 			"description":"히쿠마 <b>추천 메뉴<\/b> 비교! 치킨 토마토 스프커리 vs. 치킨 스프커리 닭다리 하나가 통째로 들어간 치킨... 강남역 맛집 찾을 때, 특히 뜨끈한 국물 땡기는 <b>비오는 날<\/b>에 히쿠마 한 번 들러보시길!! ▼ 히쿠마 전체 <b>메뉴<\/b>... ",
# 			"bloggername":"ENFP × 프로덕질러",
# 			"bloggerlink":"blog.naver.com\/v_holic",
# 			"postdate":"20230512"
# 		},
# 		{
# 			"title":"우리동네 맛집 _ 다원국수 _ <b>비오는날<\/b> 오픈런",
# 			"link":"https:\/\/blog.naver.com\/maminjung0\/223153187964",
# 			"description":"거의 매일 비가<b>오는<\/b> 장마기간이라 그런지 멀리 외식가기도 쉽지않고 뜨거운 주방 불앞에 서는것도... <b>비오는날<\/b> 오픈런해서 먹는 와중에도 손님분들 오시는걸 봐서 손님분들께 사랑받는 맛집 맞구요. 국수는... ",
# 			"bloggername":"항동 부동산 중개맛집 우남부동산",
# 			"bloggerlink":"blog.naver.com\/maminjung0",
# 			"postdate":"20230711"
# 		}
# 	]
# }

# %%
type(body)
# Out:
# str

# %%
body = body.replace('"','')
body
# Out:
# "{\n\tlastBuildDate:Wed, 30 Aug 2023 13:55:04 +0900,\n\ttotal:252558,\n\tstart:1,\n\tdisplay:100,\n\titems:[\n\t\t{\n\t\t\ttitle:[오산 맛집] 등촌샤브칼국수: <b>비오는 날 추천메뉴<\\/b>*,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/juni0628\\/223197033614,\n\t\t\tdescription:비오는날 진짜 추천메뉴다 이건 다음은 칼국수 넣어볼게요- 살짝 배가 불러집니다. 그래도 준건 다... 잘 먹고 갑니다. 그럼 이만 #직장인의하루 #워킹맘 #<b>비오는날추천메뉴<\\/b> #비오는날추천음식,\n\t\t\tbloggername:동그라미의 하루:-),\n\t\t\tbloggerlink:blog.naver.com\\/juni0628,\n\t\t\tpostdate:20230829\n\t\t},\n\t\t{\n\t\t\ttitle:욘주라멘 よんじゅ 여전히 일본라멘맛집  (<b>비오는 날<\\/b> <b>메뉴<\\/b> <b>추천<\\/b>),\n\t\t\tlink:https:\\/\\/blog.naver.com\\/live_in_clov\\/223053071086,\n\t\t\tdescription:꼭 사이드로 시켜서 맛보기를 추천 - 라멘에 들어간 푸짐한 차슈 차슈는 더 원한다면 1장당 2,000원에 추가할 수 있어요. <b>비오는 날 추천 메뉴<\\/b>. 울산 성남동 웨이팅 맛집 욘주라멘 생각 나는 오늘 입니다.... ,\n\t\t\tbloggername:만사형통 블로그,\n\t\t\tbloggerlink:blog.naver.com\\/live_in_clov,\n\t\t\tpostdate:20230323\n\t\t},\n\t\t{\n\t\t\ttitle:바다수퍼해물천하조개구이 강남역점 <b>비오는 날 추천 메뉴<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/chero25\\/222862611308,\n\t\t\tdescription:메인 <b>메뉴<\\/b>가 나오기 전에 양은냄비에 담겨져서 끓여준다 에피타이저로 떡볶이가 나<b>오는<\\/b> 게 새로웠다!... <b>비오는날<\\/b><b>메뉴<\\/b> #<b>비오는날<\\/b><b>메뉴<\\/b><b>추천<\\/b> #강남역신상식당 #바다수퍼해물천하조개구이... ,\n\t\t\tbloggername:쥬니뮹의 기록,\n\t\t\tbloggerlink:blog.naver.com\\/chero25,\n\t\t\tpostdate:20220831\n\t\t},\n\t\t{\n\t\t\ttitle:<b>비오는 날<\\/b> 점심<b>메뉴<\\/b> <b>추천<\\/
\n\t\t\tlink:https:\\/\\/blog.naver.com\\/shushu219321\\/223078973110,\n\t\t\tdescription:비가 오는 날에는 왜?! 수제비나 칼국수가 먹고 싶을까요? 저녁에는 되도록이면 밀가루를 먹으려고 하지... 만들면, 요런 느낌의 수제비가 만들어 집니다! <b>비 오는 날 추천 메뉴<\\/b> 감자수제비 맛있게 만들어 드세요!,\n\t\t\tbloggername:슈슈냥의 한그릇 뚝딱!,\n\t\t\tbloggerlink:blog.naver.com\\/shushu219321,\n\t\t\tpostdate:20230419\n\t\t},\n\t\t{\n\t\t\ttitle:감자채전 만들기 만드는법 <b>비오는날<\\/b> 야식<b>메뉴<\\/b><b>추천<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/yoonlove0502\\/223145344793,\n\t\t\tdescription:아이들간식으로도 <b>추천<\\/b>합니다&gt;&lt; 다음에 또 다른 감자요리로 돌아오겠습니다!! #감자채전 #감자채전만들기 #감자채전만드는법 #야식만드는법 #야식<b>메뉴<\\/b><b>추천<\\/b> #<b>비오는날<\\/b><b>메뉴<\\/b> #감자요리 #야식 #간식 #야식<b>메뉴<\\/b>,\n\t\t\tbloggername:쏭스라이프의 푸드스토리,\n\t\t\tbloggerlink:blog.naver.com\\/yoonlove0502,\n\t\t\tpostdate:20230704\n\t\t},\n\t\t{\n\t\t\ttitle:광명 이케아 레스토랑 <b>메뉴<\\/b><b>추천<\\/b>! <b>비오는날<\\/b> 실내데이트... ,\n\t\t\tlink:https:\\/\\/blog.nave ...

# %%
list1 = body.split('\n\t\t{\n\t\t\t')
#naver블로그 글만 가져오기
list1 = [i for i in list1 if 'naver' in i]
list1
# Out:
# ['title:[오산 맛집] 등촌샤브칼국수: <b>비오는 날 추천메뉴<\\/b>*,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/juni0628\\/223197033614,\n\t\t\tdescription:비오는날 진짜 추천메뉴다 이건 다음은 칼국수 넣어볼게요- 살짝 배가 불러집니다. 그래도 준건 다... 잘 먹고 갑니다. 그럼 이만 #직장인의하루 #워킹맘 #<b>비오는날추천메뉴<\\/b> #비오는날추천음식,\n\t\t\tbloggername:동그라미의 하루:-),\n\t\t\tbloggerlink:blog.naver.com\\/juni0628,\n\t\t\tpostdate:20230829\n\t\t},',
#  'title:욘주라멘 よんじゅ 여전히 일본라멘맛집  (<b>비오는 날<\\/b> <b>메뉴<\\/b> <b>추천<\\/b>),\n\t\t\tlink:https:\\/\\/blog.naver.com\\/live_in_clov\\/223053071086,\n\t\t\tdescription:꼭 사이드로 시켜서 맛보기를 추천 - 라멘에 들어간 푸짐한 차슈 차슈는 더 원한다면 1장당 2,000원에 추가할 수 있어요. <b>비오는 날 추천 메뉴<\\/b>. 울산 성남동 웨이팅 맛집 욘주라멘 생각 나는 오늘 입니다.... ,\n\t\t\tbloggername:만사형통 블로그,\n\t\t\tbloggerlink:blog.naver.com\\/live_in_clov,\n\t\t\tpostdate:20230323\n\t\t},',
#  'title:바다수퍼해물천하조개구이 강남역점 <b>비오는 날 추천 메뉴<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/chero25\\/222862611308,\n\t\t\tdescription:메인 <b>메뉴<\\/b>가 나오기 전에 양은냄비에 담겨져서 끓여준다 에피타이저로 떡볶이가 나<b>오는<\\/b> 게 새로웠다!... <b>비오는날<\\/b><b>메뉴<\\/b> #<b>비오는날<\\/b><b>메뉴<\\/b><b>추천<\\/b> #강남역신상식당 #바다수퍼해물천하조개구이... ,\n\t\t\tbloggername:쥬니뮹의 기록,\n\t\t\tbloggerlink:blog.naver.com\\/chero25,\n\t\t\tpostdate:20220831\n\t\t},',
#  'title:<b>비오는 날<\\/b> 점심<b>메뉴<\\/b> <b>추천<\\/
이야기,\n\t\t\tbloggerlink:blog.naver.com\\/nelo30,\n\t\t\tpostdate:20200630\n\t\t},',
#  'title:홍콩반점 0410 ▶ 성대시장맛집 <b>비오는날 추천 메뉴<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/kkaigee\\/220645324003,\n\t\t\tdescription:ㅎㅎㅎ 전 예전에는 칼국수가 많이 생각났는데 요즘 비오는날 추천 하는 메뉴는 짬뽕이에요 이미... 그리고 <b>비오는날 추천 메뉴<\\/b>인 짬뽕! 대학교 3학년때 짬뽕의 매력에 빠진뒤로 거의 짬뽕만 먹고있는거같아요... ,\n\t\t\tbloggername:케이지의 기록,\n\t\t\tbloggerlink:blog.naver.com\\/kkaigee,\n\t\t\tpostdate:20160304\n\t\t},',
#  'title:대전 김치찌개 맛집 - <b>비오는날 추천메뉴<\\/b> 오모리찌개,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/rlachqkd\\/221574912290,\n\t\t\tdescription:들어가있고 <b>비오는날<\\/b> 따끈한 한그릇<b>메뉴<\\/b>로 넘나 마음에 든다 ★ 으슬으슬 비오고 쌀쌀한날 팔팔 끓는 뚝배기 한그릇....정말 소소하지만 확실한 행복! 이거 먹고 카페에서 커피에 디저트먹으면서 <b>비오는<\\/b> 창밖을... ,\n\t\t\tbloggername:제리의 뷰티로그,\n\t\t\tbloggerlink:blog.naver.com\\/rlachqkd,\n\t\t\tpostdate:20190701\n\t\t},',
#  'title:<b>비오는날<\\/b> <b>메뉴<\\/b>로 파전대신 간단술안주 <b>추천<\\/b>: 골뱅이무침 + 양념... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/coky3\\/222433116946,\n\t\t\tdescription:코로나로 인해 밖에 돌아다닐 수 없지만 ㅠㅠ 그래도 <b>비오는 날<\\/b>하면 한잔 해줘야 하는 것이 인지상정(?) 아니겠습니깡 ㅋㅋㅋ <b>비오는날<\\/b> 빠르고 간편한 안주 <b>메뉴<\\/b>로 살포시 <b>추천<\\/b>드릴게요 ㅋㅋㅋ (집들이 메인 요리... ,\n\t\t\tbloggername:볼보맘이 되어버린 이작가네 이야기,\n\t\t\tbloggerlink:blog.naver.com\\/coky3,\n\t\t\tpostdate:20210715\n\t\t},',
#  'title:장마철 <b>비오는날<\\/b> 저녁<b>메뉴<\\/b><b>추천<\\/b> 사골 수제비,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/chefzzong_\\/220032760175,\n\t\t\tdescription:한국인의 힘은 밥힘에서 나<b>오는<\\/b>게 맞는데... 밥 보다는 다른 것에 자꾸 눈길이 가더라구요. 장마철에... 이웃님들 <b>메뉴<\\/b>로 어떠세요?! 10분안에 뚝딱 뚝딱 요리해 보세요~ 장마철 <b>비오는날<\\/b> 저녁<b>메뉴<\\/b><b>추천<\\/b> 사골 수제비,\n\t\t\tbloggername:맛의 중심, 종가집,\n\t\t\tbloggerlink:blog.naver.com\\/chefzzong_,\n\t\t\tpostdate:20140617\n\t\t}\n\t]\n}{\n\tlastBuildDate:Wed, 30 Aug 2023 13:55:05 +0900,\n\ttotal:252558,\n\tstart:101,\n\tdisplay:100,\n\titems:[',
#  'title:꼬치 어묵탕 끓이는법 꼬치어묵 <b>비오는날<\\/b> 음식 <b>메뉴<\\/b> 어묵탕... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\
\n\t\t\tlink:https:\\/\\/blog.naver.com\\/100folktales\\/223161809276,\n\t\t\tdescription:진짜 <b>비오는 날<\\/b> 좋은 <b>메뉴<\\/b> 선택이었던 것 같습니다!! 일산에서 뭘 먹을까 고민 되실 때 한번 드셔보세요! 뱃골이 크시다면 완칼 하시고 공기밥 추가해서 말아 드시는 거 <b>추천<\\/b>드립니다!!! 제가 그렇게 먹고싶었어요... ,\n\t\t\tbloggername:꽉 찬 행복,\n\t\t\tbloggerlink:blog.naver.com\\/100folktales,\n\t\t\tpostdate:20230720\n\t\t},',
# ...
#  'title:[천호 맛집] 닭한마리, <b>비오는날<\\/b> 저녁<b>메뉴<\\/b>로 어떠세요-,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/dbstnal\\/20188525199,\n\t\t\tdescription:친구 썬양의 <b>추천<\\/b>으로 닭한마리로 고고씽합니다 천호동 쭈꾸미골목으로 들어서면, 독도쭈꾸미1호점 옆에 바로 보여요. <b>메뉴<\\/b>는 닭과 칼국수, 사리뿐이 없지만, 또 요렇게 한<b>메뉴<\\/b>만 하는곳이 진국아니겠어요... ,\n\t\t\tbloggername:초록기린숲 by ㄹi프,\n\t\t\tbloggerlink:blog.naver.com\\/dbstnal,\n\t\t\tpostdate:20130528\n\t\t},',
#  'title:유강맛집 <b>비오는 날<\\/b> 파전에 막걸리는 유강파전에서,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/moda3\\/223041991382,\n\t\t\tdescription:포장 주문 시 미리 주문하고 방문하시는 것을 <b>추천<\\/b> 4. 매장이 바쁘다보니 친절하진 않지만, 파전과 육전이 맛있었던 곳 (약간 츤데레) (개인적인 견해이니 오해 금지) <b>비오는 날<\\/b>은 역시 전이나 부침개 만한 게... ,\n\t\t\tbloggername:송모다의 리뷰로그,\n\t\t\tbloggerlink:blog.naver.com\\/moda3,\n\t\t\tpostdate:20230312\n\t\t},',
#  'title:<b>비오는 날<\\/b>의 <b>메뉴<\\/b>! 수제비와 고기완자전 &lt;그래! 이집&gt; 행신동... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/dwlyl\\/222799760608,\n\t\t\tdescription:#행신동숨은맛집 #그래이집수제비 #수제비맛집 #고기완자전맛집 #수제비 #고기완자전 #행신동점심<b>메뉴<\\/b> #행신동맛집 #행신동<b>추천<\\/b> #그래이집칼제비 #얼큰수제비 #<b>비오는날<\\/b><b>메뉴<\\/b> #내돈내먹 #솔직리뷰 #맛있음,\n\t\t\tbloggername:Il y aura des jours meilleurs,\n\t\t\tbloggerlink:blog.naver.com\\/dwlyl,\n\t\t\tpostdate:20220704\n\t\t},',
#  'title:칼국수 맛집\\/왕만두 맛집\\/<b>비오는날<\\/b> <b>메뉴<\\/b><b>추천<\\/b>: 【남촌칼국수】,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/tnwls5903\\/223157366234,\n\t\t\tdescription:최애 <b>메뉴<\\/b>가 칼국수여서 포스팅은 처음이지만 한달에 몇번씩은 꼭 먹으러 <b>오는<\\/b>거같아요 ㅋㅋㅋ 들어오면 바로 보이는 홀에는 식탁 테이블이 있고 안쪽으로 더 들어가면 좌식 룸도 있어요 :) 룸 이름이 랍스타... ,\n\t\t\tbloggername:우당탕탕➿,\n\t\t\tbloggerlink:blog.naver.com\\/tnwls5903,\n\t\t\tpostdate:20230716\n\t\t},',
#  'title:삿포로 후라노 비에이 <b>비오는날<\\/b>, 버스투어 <b>추천<\\/b>(훗카이도랩... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\
,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/hi_shayla\\/221598603107,\n\t\t\tdescription:오래 올려두면 탄다 고로, 빨리 먹어야지 ㅋㅋㅋㅋ 다 먹을때쯤 이렇게 누룽지도 주시니 닭발을 시킬수가 없다 배부름. ㅎㅎ 특히 꼼장어는 <b>비오는날<\\/b> 생각나는 <b>메뉴<\\/b>이므로 다음에 <b>비오는날<\\/b> 한번 더 가봐야겠다,\n\t\t\tbloggername:셰일라의 즐거운생활♡,\n\t\t\tbloggerlink:blog.naver.com\\/hi_shayla,\n\t\t\tpostdate:20190729\n\t\t},',
#  'title:퓨전짬뽕 맛집 뽕신인더가든 천호점 : <b>비오는 날<\\/b> 점심<b>메뉴<\\/b> 초이스!,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/adsl224\\/220721633235,\n\t\t\tdescription:안말린 점원이 밉더라구요ㅠㅠ 테이크아웃 해달라고 할 뻔... <b>비오는 날<\\/b>, 국물 땡기는 <b>날<\\/b>, 특별하지 않은데 부담없이 맛난거 먹고싶을 때 천호동 맛집 뽕신인더가든 <b>추천<\\/b>해요! 여기까지 쾡쾡이었습니다!,\n\t\t\tbloggername:Day to day,\n\t\t\tbloggerlink:blog.naver.com\\/adsl224,\n\t\t\tpostdate:20160528\n\t\t},',
#  'title:김치전 만들기\\/<b>비오는날<\\/b> <b>메뉴<\\/b><b>추천<\\/b>\\/주말<b>메뉴<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/ssun0113\\/222290376053,\n\t\t\tdescription:김치전 만들기\\/<b>비오는날<\\/b> <b>메뉴<\\/b><b>추천<\\/b>\\/주말<b>메뉴<\\/b> 오늘은 일요일, 하루종일 촉촉한 봄비가 내리네요. <b>비오는날<\\/b>은 부침개^^ 진리입니다ㅎㅎ 냉장고에 묵은지랑 해물이 좀 있어서 바로 꺼내서 김치전 만들었어요... ,\n\t\t\tbloggername:써니쿡의 힐링푸드스토리,\n\t\t\tbloggerlink:blog.naver.com\\/ssun0113,\n\t\t\tpostdate:20210328\n\t\t},',
#  'title:제주도 <b>비오는날<\\/b> 가볼만한곳* 오설록티뮤지엄... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/sseossun\\/223134946880,\n\t\t\tdescription:제주도 <b>비오는날<\\/b>에도 가기 좋은 카페나 장소를 잘 찾아가면 그 분위기를 즐기게 된답니다 :) 제주도여행 넷째 <b>날<\\/b> 코스는 &lt;제주 오설록티뮤지엄- 신라 더파크뷰뷔페 롯데아트빌라스 체크인 - 호텔수영 포도호텔... ,\n\t\t\tbloggername:인생은 여행처럼,\n\t\t\tbloggerlink:blog.naver.com\\/sseossun,\n\t\t\tpostdate:20230621\n\t\t},',
#  'title:바삭하게 만드는법 밀가루 부침개 간장소스 <b>비오는날<\\/b> 음식 <b>메뉴<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\
,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/muybien45\\/222843272620,\n\t\t\tdescription:알곤이칼국수에 계란 솔솔 풀고 청양고추 살짝 때려박아 먹으면 <b>비오는 날<\\/b> 캬- 임창정 오라버니의... 시그니처 <b>메뉴<\\/b>인 알곤이칼국수를 집에서 밀키트로 먹을 수 있는 제품이다. 캬, 우리 김쉐프님의 완성 작품!... ,\n\t\t\tbloggername:다섯개의 별,\n\t\t\tbloggerlink:blog.naver.com\\/muybien45,\n\t\t\tpostdate:20220809\n\t\t},',
#  'title:가산디지털 맛집 | 달빛주막, 막걸리와 모듬 전 <b>비오는 날 추천<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/awesomejin_\\/222875724934,\n\t\t\tdescription:이번에 달빛주막 생각나서 갔어요 거의 10시 다돼서 갔더니 사람이 별로 없어서 좋았어요 전류 <b>메뉴<\\/b>... <b>비오는 날<\\/b>에 여기는 난리날거같아요 회식이나 모임장소로도 좋아보이구요 가벼운 2차로도 <b>추천<\\/b>합니다 -,\n\t\t\tbloggername:Awesome day :),\n\t\t\tbloggerlink:blog.naver.com\\/awesomejin_,\n\t\t\tpostdate:20220915\n\t\t},',
#  'title:<b>비오는날<\\/b> 아이랑갈만한곳, 이케아 데이트 어린이장난감 <b>추천<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/j_u_n_t_a\\/223142928820,\n\t\t\tdescription:<b>비오는날<\\/b> 아이랑갈만한곳 이케아 데이트 어린이장난감 <b>추천<\\/b> 딸과 주말에 삼송역으로 데이트를... 김치볶음밥과 어린이<b>메뉴<\\/b> 베지볼1개 초코빵1개 주문했어요! 엄마랑 단둘이 나와서 그저 행복한 어린이 ㅋㅋ... ,\n\t\t\tbloggername:애들아 놀러가자,\n\t\t\tbloggerlink:blog.naver.com\\/j_u_n_t_a,\n\t\t\tpostdate:20230702\n\t\t},',
#  'title:가포카페 다녀왔어요!! <b>비오는 날<\\/b>에 더 <b>추천<\\/b>합니다 #내돈내산후기,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/twobinee\\/223092338095,\n\t\t\tdescription:기록 <b>비오는 날<\\/b> 좋을 것 같다~ 했는데 진짜 좋더라고요!! 주차하고 매장 들어가기까지 우산쓰고 이동하는 것만 빼면 완벽했어요 (<b>비<\\/b> 맞는 거 안 좋아함..) 메르칼므 분위기 좋아서 데이트 장소로도 <b>추천<\\/b>합니당!... ,\n\t\t\tbloggername:집수빈의 탈출기록,\n\t\t\tbloggerlink:blog.naver.com\\/twobinee,\n\t\t\tpostdate:20230503\n\t\t},',
#  'title:경기도 실내데이트 카페, 눈<b>오는날<\\/b> <b>비오는날<\\/b>데이트 <b>추천<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/dmgk32\\/222570819512,\n\t\t\tdescription:눈<b>오는날<\\/b>, <b>비오는날<\\/b> 데이트 <b>추천<\\/b> 카페 경기도 실내데이트<b>추천<\\/b> 서울 근교 경기도에는 눈<b>오는날<\\/b>이나... 음료나 베이커리 이용시 1시간으로 이용 시간 제한이 있어서, 두세시간 놀다 오실 분들은 브런치 <b>메뉴<\\/b>... ,\n\t\t\tbloggername:@유징유,\n\t\t\tbloggerlink:blog.naver.com\\/dmgk32,\n\t\t\tpostdate:20211117\n\t\t},',
#  'title:<b>비오는 날<\\/b>에는연탄구이집에서 소금구이 <b>메뉴<\\/b>를 <b>추천<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/
>추천<\\/b>),\n\t\t\tlink:https:\\/\\/blog.naver.com\\/j50149\\/222857176667,\n\t\t\tdescription:다양해서 <b>비 오는 날<\\/b> 가볍게 들려서 먹기 딱 좋은 곳!!! 참고로 매장 안이 막 깨끗한 느낌이 아니니, 평소에 포차 느낌을 좋아하는 분들께 <b>추천<\\/b>! 서울 전집 원탑은 바로 이곳!! https:\\/\\/blog.naver.com\\/j50149... ,\n\t\t\tbloggername:다은의 맛있는 일상,\n\t\t\tbloggerlink:blog.naver.com\\/j50149,\n\t\t\tpostdate:20220828\n\t\t},',
#  'title:<b>비 오는 날<\\/b> 더 생각나는 맛집 \\/ 충북혁신도시 쌈국수 <b>메뉴<\\/b> <b>추천<\\/b>,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/dearhye_\\/222371464525,\n\t\t\tdescription:<b>비 오는 날<\\/b> 더 생각나는 맛집, 충북혁신도시 쌈국수 :) 올해는 정말 비가 많이 내리는 것 같다. 오늘같이 폭우처럼 쏟아지는 날은 차도 깨끗해져서 좋다 대신 난 실내에 있어야 좋음 무튼, <b>비<\\/b> 오니까 생각나는... ,\n\t\t\tbloggername:dear, moments,\n\t\t\tbloggerlink:blog.naver.com\\/dearhye_,\n\t\t\tpostdate:20210528\n\t\t},',
#  'title:[일산 본점] 등촌샤브칼국수 <b>비오는 날<\\/b> 저녁 <b>메뉴<\\/b>로 <b>추천<\\/b>해요,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/happytourshare\\/222826121655,\n\t\t\tdescription:안녕하세요, 행복한여행나눔입니다. 다들 토요일 주말 잘 보내고 계신가요? 오후부터 떨어진 비로 상쾌함이 덤으로 왔습니다. 오늘은 고양 일산에 있는 등촌샤브칼국수 일산 본점에 다녀온 후기를 들려드리고자... ,\n\t\t\tbloggername:행복한여행나눔,\n\t\t\tbloggerlink:blog.naver.com\\/happytourshare,\n\t\t\tpostdate:20220723\n\t\t},',
#  'title:수원 행궁동 놀 거리, 볼거리, 데이트 <b>추천<\\/b>, <b>비 오는 날<\\/b>... ,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/tjrwls7575\\/223197008814,\n\t\t\tdescription:<b>추천<\\/b> 장소들을 알려드리려고합니다!! 그럼 <b>비 오는 날<\\/b>의 행궁동은 어떤 모습일지??? 방화수류정 (<b>비 오는<\\/b>... <b>비 오는<\\/b> 구름만 하염없이 바라보고 있었습니다 ㅋㅋㅋㅋㅋㅋ 그래도 은근 비가 <b>오는<\\/b> 호수의 풍경도... ,\n\t\t\tbloggername:꿈같은 일상을 이야기하는 몽상가,\n\t\t\tbloggerlink:blog.naver.com\\/tjrwls7575,\n\t\t\tpostdate:20230830\n\t\t},',
#  "title:스프카레 그리울 때? 강남역 맛집 '히쿠마' <b>비오는 날<\\/b> 딱 좋네!,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/v_holic\\/223100677817,\n\t\t\tdescription:히쿠마 <b>추천 메뉴<\\/b> 비교! 치킨 토마토 스프커리 vs. 치킨 스프커리 닭다리 하나가 통째로 들어간 치킨... 강남역 맛집 찾을 때, 특히 뜨끈한 국물 땡기는 <b>비오는 날<\\/b>에 히쿠마 한 번 들러보시길!! ▼ 히쿠마 전체 <b>메뉴<\\/b>... ,\n\t\t\tbloggername:ENFP × 프로덕질러,\n\t\t\tbloggerlink:blog.naver.com\\/v_holic,\n\t\t\tpostdate:20230512\n\t\t},",
#  'title:우리동네 맛집 _ 다원국수 _ <b>비오는날<\\/b> 오픈런,\n\t\t\tlink:https:\\/\\/blog.naver.com\\/maminjung0\\/223153187964,\n\t\t\tdescription:거의 매일 비가<b>오는<\\/b> 장마기간이라 그런지 멀리 외식가기도 쉽지않고 뜨거운 주방 불앞에 서는것도... <b>비오는날<\\/b> 오픈런해서 먹는 와중에도 손님분들 오시는걸 봐서 손님분들께 사랑받는 맛집 맞구요. 국수는... ,\n\t\t\tbloggername:항동 부동산 중개맛집 우남부동산,\n\t\t\tbloggerlink:blog.naver.com\\/maminjung0,\n\t\t\tpostdate:20230711\n\t\t}\n\t]\n}']

# %%
from ckonlpy.tag import Twitter
from konlpy.tag import Okt
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
from wordcloud import WordCloud

# %%
Twitter = Twitter()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
df = pd.read_csv('foodinfo1.csv')
df
df_word = list(df['대표식품명'])
Twitter.add_dictionary(df_word, 'Noun')

# %%
#블로그 데이터 형태소 분석
an = []
for i in range(0,len(list1)) :
    nouns =  Twitter.nouns(list1[i])
    an.append(nouns)
print(an[2])
# Out:
# ['바다', '수퍼', '물', '천하', '조개구이', '강남역', '점', '날', '추천', '메뉴', '메인', '메뉴', '나', '오기', '전', '양은', '냄비', '여준', '에피타이저', '떡볶이', '나', '게', '비', '날', '메뉴', '비', '날', '메뉴', '추천', '강남역', '신상식', '당', '바다', '수퍼', '물', '천하', '조개구이', '쥬니', '뮹', '기록']

# %%
an
# Out:
# [['오산',
#   '맛집',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '날',
#   '추천',
#   '메뉴',
#   '비',
#   '날',
#   '진짜',
#   '추천',
#   '메뉴',
#   '이건',
#   '다음',
#   '칼국수',
#   '살짝',
#   '배',
#   '직장인',
#   '하루',
#   '워킹맘',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '추천',
#   '음식',
#   '동그라미',
#   '하루'],
#  ['욘주',
#   '라멘',
#   '여전',
#   '일본',
#   '라멘',
#   '맛집',
#   '날',
#   '메뉴',
#   '추천',
#   '꼭',
#   '사이드',
#   '맛보기',
#   '추천',
#   '라멘',
#   '어간',
#   '짐',
#   '차슈',
#   '차슈',
#   '더',
#   '원한',
#   '면',
#   '장',
#   '추가',
#   '수',
#   '어요',
#   '날',
#   '추천',
#   '메뉴',
#   '울산',
#   '성남동',
#   '웨이',
#   '팅',
#   '맛집',
#   '욘주',
#   '라멘',
#   '생각',
#   '나',
#   '오늘',
#   '만사',
#   '형통',
#   '블로그'],
#  ['바다',
#   '수퍼',
#   '물',
#   '천하',
#   '조개구이',
#   '강남역',
#   '점',
#   '날',
#   '추천',
#   '메뉴',
#   '메인',
#   '메뉴',
#   '나',
#   '오기',
#   '전',
#   '양은',
#   '냄비',
#   '여준',
#   '에피타이저',
#   '떡볶이',
#   '나',
#   '게',
#   '비',
#   '날',
#   '메뉴',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '강남역',
#   '신상식',
#   '당',
#   '바다',
#   '수퍼',
#   '물',
#   '천하',
#   '조개구이',
#   '쥬니',
#   '뮹',
#   '기록'],
#  ['날',
#   '점심',
#   '메뉴',
#   '추천',
#   '온센',
#   '광명',
#   '점',
#   '텐동',
#   '식감',
#   '비',
#   '하루',
#   '등원',
#   '길',
#   '아침',
#   '부터',
#   '문',
#   '연',
#   '전집',
#   '기름',
#   '냄새',
#   '식욕',
#   '하루',
#   '시작',
#   '다이어터',
#   '마제',
#   '우동',
#   '양념',
#   '밥',
#   '어도',
#   '날',
#   '기름',
#   '진',
#   '거',
#   '때',
#   '전보',
#   '푸딩',
#   '육아',
#   '탐구생활'],
#  ['비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '부침개',
#   '바삭',
#   '부침개',
#   '법',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '부침개',
#   '파전',
#   '김치전',
#   '두릅',
#   '전',
#   '야채',
#   '전',
#   '모듬전',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '김치전',
#   '야채',
#   '전',
#   '두릅',
#   '전',
#   '불닭볶음면',
#   '오늘',
#   '저녁',
#   '비도',
#   '이번',
#   '주',
#   '금요일',
#   '일요일',
#   '까지',
#   '계획',
#   '여수',
#   '여행',
#   '전',
#   '야채',
#   '소진',
#   '위해',
#   '소',
#   '소한'],
#  ['수원',
#   '행궁',
#   '솔솥',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '행궁동',
#   '한식',
#   '돌솥밥',
#   '요즘',
#   '처럼',
#   '비',
#   '날',
#   '점심',
#   '솔솥',
#   '행궁점',
#   '후기',
#   '입구',
#   '일본',
#   '골목',
#   '추천',
#   '메뉴',
#   '간판',
#   '입구',
#   '일본',
#   '골목',
#   '온',
#   '느낌',
#   '비',
#   '오니',
#   '더',
#   '너낌있돠',
#   '뱅',
#   '기타',
#   '일본',
#   '해신',
#   '비츠로',
#   '캠핑카',
#   '반'],
#  ['카페',
#   '안도',
#   '르',
#   '송',
#   '당무',
#   '끈',
#   '모루',
#   '포토',
#   '존',
#   '핫',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '카페',
#   '케이크',
#   '메뉴',
#   '를',
#   '추천',
#   '한라산',
#   '케이크',
#   '좀',
#   '녹차',
#   '맛',
#   '어서',
#   '조화',
#   '힐링',
#   '비',
#   '날',
#   '경치',
#   '힐링',
#   '수',
#   '거',
#   '제주',
#   '여행',
#   '중',
#   '비',
#   '날',
#   '거',
#   '아이',
#   '국내',
#   '해외',
#   '여행'],
#  ['감자',
#   '수제비',
#   '레시피',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '수제비',
#   '반죽',
#   '감자',
#   '요리',
#   '비',
#   '날',
#   '왜',
#   '수제비',
#   '칼국수',
#   '저녁',
#   '도록',
#   '이면',
#   '밀가루',
#   '려고',
#   '요런',
#   '느낌',
#   '수제비',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '감자',
#   '수제비',
#   '슈슈냥',
#   '그릇',
#   '뚝딱'],
#  ['감자',
#   '만들기',
#   '법',
#   '비',
#   '날',
#   '야식',
#   '메뉴',
#   '추천',
#   '아이',
#   '간식',
#   '추천',
#   '다음',
#   '또',
#   '다른',
#   '감자',
#   '요리',
#   '감자',
#   '감자',
#   '만들기',
#   '감자',
#   '채',
#   '전만',
#   '법',
#   '야식',
#   '법',
#   '야식',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '메뉴',
#   '감자',
#   '요리',
#   '야식',
#   '간식',
#   '야식',
#   '메뉴',
#   '쏭스',
#   '라이프',
#   '푸드',
#   '스토리'],
#  ['광명',
#   '이케아',
#   '레스토랑',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '실내',
#   '데이트',
#   '추적',
#   '추적',
#   '데',
#   '날',
#   '날',
#   '고',
#   '민하',
#   '다가',
#   '거리',
#   '광명',
#   '실내',
#   '데이트',
#   '추천',
#   '이케아',
#   '데이트',
#   '비',
#   '날',
#   '이케아',
#   '비',
#   '날',
#   '데이트',
#   '스타',
#   '필드',
#   '양',
#   '이케아',
#   '놀',
#   '거리',
#   '서이추',
#   '애나',
#   '부탁'],
#  ['수원',
#   '영통',
#   '맛집',
#   '목구멍',
#   '수원',
#   '영통',
#   '점',
#   '날',
#   '메뉴',
#   '로',
#   '추천',
#   '해',
#   '날',
#   '고기',
#   '역시',
#   '사람',
#   '이번',
#   '영통',
#   '고기',
#   '집',
#   '어요',
#   '정말',
#   '날',
#   '더',
#   '것',
#   '기도',
#   '수',
#   '원목',
#   '살맛',
#   '집',
#   '목구멍',
#   '수원',
#   '영통',
#   '점',
#   '직접',
#   '후기',
#   '시',
#   '작',
#   '하루',
#   '종일',
#   '년'],
#  ['비',
#   '날',
#   '간단',
#   '저녁',
#   '메뉴',
#   '추천',
#   '잔치국수',
#   '만들기',
#   '고명',
#   '가득',
#   '비',
#   '날',
#   '간단',
#   '저녁',
#   '메뉴',
#   '추천',
#   '잔치국수',
#   '만들기',
#   '고명',
#   '가득',
#   '국수',
#   '그릇',
#   '뚝딱',
#   '말',
#   '요',
#   '간단',
#   '저녁',
#   '메뉴',
#   '저녁',
#   '메뉴',
#   '추천',
#   '잔치국수',
#   '만들기',
#   '그릇',
#   '음식',
#   '잔치국수',
#   '레시피',
#   '잔치국수',
#   '만들기',
#   '소면',
#   '삶',
#   '때',
#   '안녕',
#   '다정',
#   '순둥',
#   '작가'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '울산',
#   '명촌',
#   '맛집',
#   '돗',
#   '가비',
#   '불쭈',
#   '철판',
#   '볶음',
#   '비',
#   '날',
#   '생각',
#   '울산',
#   '명촌',
#   '맛집',
#   '돗',
#   '가비',
#   '불쭈',
#   '철판',
#   '볶음',
#   '들깨',
#   '수제비',
#   '봄비',
#   '부슬부슬',
#   '날',
#   '매콤',
#   '것',
#   '땡',
#   '기고',
#   '끈',
#   '국물',
#   '땡',
#   '기고',
#   '때',
#   '메뉴',
#   '불',
#   '쭈꾸미',
#   '들깨',
#   '수제비',
#   '맛',
#   '보고',
#   '욕심',
#   '손',
#   '사장'],
#  ['굴',
#   '조개',
#   '칼국수',
#   '법',
#   '칼국수',
#   '육수',
#   '비',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '해물칼국수',
#   '칼국수',
#   '법',
#   '굴',
#   '조개',
#   '칼국수',
#   '법',
#   '칼국수',
#   '육수',
#   '비',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '재료',
#   '해물',
#   '가리비',
#   '굴',
#   '새우',
#   '적당',
#   '멸치',
#   '육수',
#   '가리비',
#   '육수',
#   '야채',
#   '쌈',
#   '배추',
#   '알',
#   '배추',
#   '대파',
#   '청양고추',
#   '행주치마',
#   '정겨운',
#   '집밥'],
#  ['가격',
#   '추천',
#   '메뉴',
#   '군',
#   '곳',
#   '군',
#   '카페',
#   '비',
#   '날',
#   '한국어',
#   '메뉴',
#   '를',
#   '때',
#   '대표',
#   '시',
#   '그니',
#   '처',
#   '추천',
#   '메뉴',
#   '코코넛',
#   '밀크',
#   '커피',
#   '이전',
#   '나트랑',
#   '날씨',
#   '날',
#   '콩',
#   '카페',
#   '시원',
#   '떤딘',
#   '성당',
#   '구경',
#   '호치민',
#   '여행',
#   '유익',
#   '공간'],
#  ['더',
#   '북한',
#   '산점',
#   '비',
#   '날',
#   '방문',
#   '후기',
#   '스타벅스',
#   '더',
#   '북한',
#   '산점',
#   '메뉴',
#   '추천',
#   '오픈',
#   '런',
#   '추천',
#   '드립',
#   '왜냐면',
#   '주말',
#   '도',
#   '거의',
#   '만',
#   '저',
#   '오전',
#   '이',
#   '날',
#   '주문',
#   '허니',
#   '트리플',
#   '치즈',
#   '크루아상',
#   '샌드위치',
#   '모두',
#   '완전',
#   '만족',
#   '어요',
#   '두',
#   '메뉴',
#   '모두',
#   '소',
#   '소하',
#   '특별',
#   '것'],
#  ['의정부',
#   '맛집',
#   '두부',
#   '맛',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '두부',
#   '버섯',
#   '전골',
#   '메뉴',
#   '판',
#   '두부',
#   '맛',
#   '식사',
#   '류',
#   '가격',
#   '적당',
#   '가격',
#   '정식',
#   '비',
#   '날',
#   '은',
#   '버섯',
#   '두부전골',
#   '날',
#   '날',
#   '콩국수',
#   '는걸',
#   '추천',
#   '옆',
#   '테이블',
#   '콩국수',
#   '블리',
#   '행복',
#   '한일',
#   '상'],
#  ['비',
#   '날',
#   '선택',
#   '완벽',
#   '메뉴',
#   '미아사거리',
#   '곱창',
#   '맛집',
#   '추천',
#   '대표',
#   '메뉴',
#   '제주',
#   '삼겹살',
#   '배달',
#   '가능',
#   '비',
#   '날',
#   '햇빛',
#   '병원',
#   '다가',
#   '점심',
#   '사무실',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '로',
#   '대창',
#   '착각',
#   '수',
#   '비',
#   '주얼',
#   '벽면',
#   '설명',
#   '꿈'],
#  ['밥집',
#   '비',
#   '날',
#   '점심',
#   '메뉴',
#   '칼국수',
#   '수제비',
#   '추천',
#   '나',
#   '데',
#   '정말',
#   '초',
#   '대박',
#   '친절',
#   '기본',
#   '세팅',
#   '샐러드',
#   '김치',
#   '기본',
#   '찬',
#   '부터',
#   '거',
#   '비',
#   '날',
#   '마다',
#   '이집',
#   '메뉴',
#   '어보',
#   '어요',
#   '진',
#   '심',
#   '국물',
#   '왜',
#   '시원'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '곱창',
#   '파김치',
#   '곱창',
#   '경안동',
#   '신장',
#   '곱창',
#   '비',
#   '날',
#   '소',
#   '곱창',
#   '소주',
#   '진리',
#   '파김치',
#   '파김치',
#   '정말',
#   '어요',
#   '곱창',
#   '메뉴',
#   '판',
#   '파김치',
#   '워낙',
#   '맛',
#   '사가',
#   '사람',
#   '별도',
#   '판매',
#   '어요',
#   '날',
#   '소주',
#   '소',
#   '소한',
#   '일상',
#   '여자'],
#  ['날',
#   '추천',
#   '메뉴',
#   '부추',
#   '장떡',
#   '만들기',
#   '부추',
#   '부침개',
#   '레시피',
#   '엄마',
#   '봄',
#   '나',
#   '새',
#   '순은',
#   '꼭',
#   '라서',
#   '어요',
#   '부추',
#   '알리',
#   '신',
#   '성분',
#   '비타민',
#   '군',
#   '다른',
#   '식',
#   '재료',
#   '조합',
#   '부추',
#   '부침개',
#   '날',
#   '번',
#   '보시',
#   '요',
#   '슈슈냥',
#   '그릇',
#   '뚝딱'],
#  ['용산',
#   '막창',
#   '삼각지역',
#   '맛집',
#   '추천',
#   '날',
#   '메뉴',
#   '맛집',
#   '추천',
#   '려고',
#   '비',
#   '추적',
#   '추적',
#   '날',
#   '것',
#   '메뉴',
#   '바로',
#   '삼각지역',
#   '비',
#   '날',
#   '막창',
#   '땡',
#   '기지',
#   '메뉴',
#   '판',
#   '찍',
#   '어보',
#   '았',
#   '가까이',
#   '탓',
#   '안',
#   '보이',
#   '메뉴',
#   '검색',
#   '앤녕',
#   '것',
#   '것'],
#  ['아이',
#   '날',
#   '도',
#   '남해',
#   '시골',
#   '막걸리',
#   '아이',
#   '추천',
#   '메뉴',
#   '바깥',
#   '자리',
#   '날',
#   '운치',
#   '안개',
#   '크게',
#   '고요',
#   '저희',
#   '해물',
#   '된장찌개',
#   '해물파전',
#   '유자',
#   '막걸리',
#   '깃밥',
#   '추가',
#   '주문',
#   '아이',
#   '때문',
#   '전',
#   '메뉴',
#   '고추',
#   '빼',
#   '달라',
#   '엄마',
#   '두',
#   '딸',
#   '성장기',
#   '록'],
#  ['고깃집',
#   '삼겹살',
#   '맛집',
#   '하남',
#   '돼지',
#   '집',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '오픈',
#   '런',
#   '차지',
#   '수',
#   '자리',
#   '뷰',
#   '초록',
#   '초록',
#   '뿐더러',
#   '비',
#   '소리',
#   '고기',
#   '앞',
#   '돼지고기',
#   '하남',
#   '돼지',
#   '집',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '도시락',
#   '김치볶음밥',
#   '김치양',
#   '얼마',
#   '단방',
#   '향소',
#   '통',
#   '생활기록부'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '손질',
#   '통',
#   '오징어',
#   '해물',
#   '부추전',
#   '통오징어',
#   '모양',
#   '그대로',
#   '다양',
#   '오징어',
#   '요리',
#   '활용',
#   '손질',
#   '통오징어',
#   '날',
#   '오징어',
#   '통',
#   '가득',
#   '맛',
#   '바삭',
#   '전이',
#   '어서',
#   '비',
#   '날',
#   '봉',
#   '이의',
#   '데일',
#   '리',
#   '달링'],
#  ['비',
#   '날',
#   '음식',
#   '비',
#   '날',
#   '메뉴',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '비',
#   '날',
#   '메뉴',
#   '비',
#   '날',
#   '저녁',
#   '비',
#   '날',
#   '음식',
#   '비올',
#   '때',
#   '음식',
#   '비',
#   '날',
#   '메뉴',
#   '저녁',
#   '메뉴',
#   '추천',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '저녁',
#   '메뉴',
#   '추천',
#   '은',
#   '순두부찌개',
#   '법',
#   '달타냥',
#   '하우스'],
#  ['온천',
#   '손',
#   '칼국수',
#   '동학사',
#   '간다',
#   '또',
#   '집',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '비',
#   '주말',
#   '용씨',
#   '나',
#   '번',
#   '가지',
#   '안',
#   '나',
#   '때문',
#   '우리',
#   '둘',
#   '미지',
#   '공주',
#   '온천',
#   '손',
#   '칼국수',
#   '공주',
#   '온천',
#   '칼국수',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '공주',
#   '여행',
#   '맛집',
#   '온천',
#   '손',
#   '칼국수',
#   '공주',
#   '휘연',
#   '세상'],
#  ['수원',
#   '행궁동',
#   '맛집',
#   '날',
#   '뮤지',
#   '엄',
#   '메뉴',
#   '추천',
#   '예약',
#   '주차',
#   '지난',
#   '주말',
#   '남자친구',
#   '수원',
#   '데이트',
#   '어요',
#   '비',
#   '날',
#   '날씨',
#   '습',
#   '끼',
#   '중하',
#   '어보',
#   '기',
#   '메뉴',
#   '추천',
#   '분보',
#   '쌀국수',
#   '아해',
#   '쌀국수',
#   '비빔',
#   '처음',
#   '인천',
#   '짱',
#   '이의',
#   '하루'],
#  ['간단',
#   '자취',
#   '생',
#   '밥',
#   '도둑',
#   '집밥',
#   '요리',
#   '끼',
#   '뚝딱',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '뚝딱',
#   '양념',
#   '갈치',
#   '무조림',
#   '식탁',
#   '위',
#   '보시',
#   '건',
#   '오늘',
#   '습',
#   '꾸벅',
#   '주말',
#   '집밥',
#   '메뉴',
#   '자취',
#   '생',
#   '집밥',
#   '점심',
#   '메뉴',
#   '저녁',
#   '메뉴',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '뚝딱',
#   '집밥',
#   '요리',
#   '클쑤똴',
#   '라이프'],
#  ['비',
#   '날',
#   '음식',
#   '메뉴',
#   '추천',
#   '홍천',
#   '시내',
#   '맛집',
#   '등촌',
#   '역시',
#   '비',
#   '날',
#   '메뉴',
#   '칼국수',
#   '최고',
#   '여러분',
#   '칼국수',
#   '홍천',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '세트',
#   '메뉴',
#   '전',
#   '안녕',
#   '비',
#   '날',
#   '음식',
#   '메뉴',
#   '추천',
#   '야채',
#   '미나리',
#   '법',
#   '김주',
#   '부의',
#   '하루하루'],
#  ['비',
#   '날',
#   '점심',
#   '메뉴',
#   '로',
#   '닭도리탕',
#   '송강',
#   '맛집',
#   '추천',
#   '정식',
#   '당',
#   '당첨',
#   '메뉴',
#   '바로',
#   '닭도리탕',
#   '얼마',
#   '전',
#   '동네',
#   '맘',
#   '카페',
#   '추천',
#   '닭도리탕',
#   '그',
#   '아쉬움',
#   '마저',
#   '맛',
#   '닭도리탕',
#   '바로',
#   '요기',
#   '담',
#   '또',
#   '날',
#   '징',
#   '서문',
#   '원',
#   '강사',
#   '일상',
#   '독서',
#   '기록',
#   '강의',
#   '노트'],
#  ['천안',
#   '직산',
#   '꼬막',
#   '짬뽕',
#   '산더미',
#   '탕수육',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '맛',
#   '비불',
#   '꼬막',
#   '짬뽕',
#   '천안',
#   '직산',
#   '꼬막',
#   '짬뽕',
#   '산더미',
#   '탕수육',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '천안',
#   '직산',
#   '위치',
#   '통',
#   '유리',
#   '창',
#   '비',
#   '모습',
#   '식사',
#   '하니',
#   '운치',
#   '고요',
#   '주방',
#   '옆',
#   '바로',
#   '셀프',
#   '바',
#   '여행'],
#  ['청당',
#   '맛집',
#   '곱',
#   '비',
#   '날',
#   '회식',
#   '메뉴',
#   '추천',
#   '영업',
#   '시간',
#   '까지',
#   '영업',
#   '청당',
#   '맛집',
#   '곱',
#   '비',
#   '날',
#   '회식',
#   '메뉴',
#   '로',
#   '추천',
#   '메뉴',
#   '메뉴',
#   '모듬',
#   '구이',
#   '기본',
#   '찬',
#   '선지국',
#   '나',
#   '데',
#   '거',
#   '한번',
#   '맛',
#   '이면',
#   '다른',
#   '선지국',
#   '거',
#   '소주',
#   '병각',
#   '제이',
#   '러브',
#   '제이'],
#  ['수유',
#   '부대찌개',
#   '수유역',
#   '맛집',
#   '비',
#   '날',
#   '점심',
#   '추천',
#   '메뉴',
#   '수유',
#   '비',
#   '날',
#   '메뉴',
#   '고민',
#   '수유역',
#   '맛집',
#   '검색',
#   '무조건',
#   '추천',
#   '추천',
#   '안',
#   '사람',
#   '수유',
#   '맛집',
#   '수유역',
#   '맛집',
#   '수유',
#   '맛집',
#   '번동',
#   '맛집',
#   '수유역',
#   '맛집',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '수유',
#   '점심',
#   '추천',
#   '메뉴',
#   '꿈'],
#  ['돈',
#   '산',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '간편',
#   '조리',
#   '제천',
#   '오뎅',
#   '여름철',
#   '별미',
#   '이열치열',
#   '한번',
#   '도',
#   '전해',
#   '보시',
#   '건',
#   '추천',
#   '고',
#   '간',
#   '단합',
#   '제',
#   '누구',
#   '어요',
#   '비',
#   '날',
#   '전이',
#   '우시',
#   '면',
#   '집',
#   '매',
#   '운오',
#   '뎅',
#   '한번',
#   '조리',
#   '보시',
#   '건',
#   '요',
#   '리안'],
#  ['점심',
#   '메뉴',
#   '추천',
#   '감자',
#   '수제비',
#   '수제비',
#   '반죽',
#   '만들기',
#   '비',
#   '날',
#   '음식',
#   '시원',
#   '가뭄',
#   '해갈',
#   '오기',
#   '것',
#   '억지로',
#   '것',
#   '어제',
#   '부터',
#   '비',
#   '날',
#   '음식',
#   '점심',
#   '메뉴',
#   '로',
#   '추천',
#   '감자',
#   '수제비',
#   '법',
#   '소개',
#   '삼시',
#   '끼',
#   '점심',
#   '끼',
#   '수제비',
#   '행주치마',
#   '정겨운',
#   '집밥'],
#  ['비',
#   '날',
#   '음식',
#   '얼',
#   '수제비',
#   '법',
#   '점심',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '음식',
#   '벌써',
#   '일',
#   '비',
#   '지속',
#   '다행',
#   '건',
#   '하루',
#   '종일',
#   '비',
#   '건',
#   '비',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '얼',
#   '수제비',
#   '법',
#   '끝',
#   '바지락',
#   '육수',
#   '게',
#   '수제비',
#   '또',
#   '다른',
#   '언니',
#   '소의',
#   '건강',
#   '푸드',
#   '스토리'],
#  ['비',
#   '날',
#   '메뉴',
#   '밀키',
#   '트',
#   '홍게',
#   '꼬치',
#   '어묵탕',
#   '추천',
#   '요즘',
#   '비',
#   '피해',
#   '더',
#   '이상',
#   '바',
#   '저녁',
#   '선택',
#   '오늘',
#   '메뉴',
#   '오늘',
#   '비',
#   '날',
#   '어묵탕',
#   '음번',
#   '행',
#   '사하',
#   '몇개',
#   '더',
#   '쟁',
#   '어요',
#   '비',
#   '날',
#   '메뉴',
#   '로',
#   '엄마',
#   '또',
#   '다른',
#   '취미'],
#  ['해장',
#   '짬뽕',
#   '짬뽕',
#   '양념',
#   '레시피',
#   '저녁',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '음식',
#   '설정',
#   '레시피',
#   '사랑',
#   '짬뽕',
#   '만들기',
#   '짬뽕',
#   '국물',
#   '만들기',
#   '해물짬뽕',
#   '만들기',
#   '해장',
#   '짬뽕',
#   '짬뽕',
#   '양념',
#   '해장',
#   '음식',
#   '짬뽕',
#   '레시피',
#   '저녁',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '음식',
#   '그릇',
#   '요리',
#   '중식',
#   '집밥',
#   '메뉴',
#   '달타냥',
#   '하우스'],
#  ['광화문',
#   '직장인',
#   '비',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '일본',
#   '라멘',
#   '비',
#   '데',
#   '파전',
#   '안',
#   '완전',
#   '바보',
#   '칼국수',
#   '먹기',
#   '심심',
#   '때',
#   '곁',
#   '이기',
#   '해물파전',
#   '수',
#   '안암',
#   '광화문',
#   '직장인',
#   '비',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '처음',
#   '어보',
#   '맑은',
#   '국물',
#   '돼지국밥',
#   '무려',
#   '미쉐린'],
#  ['방촌동',
#   '국수',
#   '맛집',
#   '수면',
#   '옥',
#   '고기',
#   '쌀',
#   '칼국수',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '지인',
#   '방촌동',
#   '맛집',
#   '추천',
#   '비',
#   '날',
#   '더',
#   '생각',
#   '칼국수',
#   '소스',
#   '걸',
#   '고기',
#   '잠시',
#   '후',
#   '양푼',
#   '그릇',
#   '국수',
#   '나',
#   '데',
#   '육수',
#   '모모',
#   '집'],
#  ['왕십리',
#   '전집',
#   '동래',
#   '파전',
#   '날',
#   '추천',
#   '메뉴',
#   '왕십리',
#   '전집',
#   '날',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '파전',
#   '국룰',
#   '술안주',
#   '왕십리',
#   '전집',
#   '중',
#   '날',
#   '소리',
#   '면서',
#   '막걸리',
#   '파전',
#   '수',
#   '동래',
#   '파전',
#   '추천',
#   '메뉴',
#   '동래',
#   '파전',
#   '왕십리',
#   '점',
#   '매일',
#   '폭주기관차'],
#  ['천안',
#   '두',
#   '정동',
#   '밥',
#   '도둑',
#   '의정부',
#   '부대찌개',
#   '비',
#   '날',
#   '음식',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '음식',
#   '메뉴',
#   '추천',
#   '원래',
#   '계획',
#   '다른',
#   '곳',
#   '리뷰',
#   '오늘',
#   '점심',
#   '메뉴',
#   '어서',
#   '먼저',
#   '포스팅',
#   '국물',
#   '비',
#   '곳',
#   '상',
#   '호명',
#   '처럼',
#   '밥',
#   '도둑',
#   '었는데',
#   '비',
#   '진',
#   '매료',
#   '핫',
#   '플레이',
#   '스'],
#  ['매운갈비찜',
#   '맛집',
#   '신사',
#   '매운갈비찜',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '위치',
#   '수유역',
#   '번',
#   '출구',
#   '골목',
#   '안',
#   '오늘',
#   '메뉴',
#   '비도',
#   '그',
#   '래서',
#   '매운갈비찜',
#   '어요',
#   '날',
#   '한잔',
#   '수가',
#   '막걸리',
#   '병',
#   '신',
#   '사랑',
#   '갈비찜',
#   '하루',
#   '이야기'],
#  ['법',
#   '삭',
#   '촉촉',
#   '야채',
#   '전',
#   '레시피',
#   '비',
#   '날',
#   '음식',
#   '전',
#   '점심',
#   '메뉴',
#   '추천',
#   '다이어트',
#   '레시피',
#   '식사',
#   '대용',
#   '등',
#   '야채',
#   '전이',
#   '오늘',
#   '건강',
#   '집밥',
#   '양배추',
#   '전',
#   '점심',
#   '메뉴',
#   '추천',
#   '야채',
#   '전',
#   '간식',
#   '비',
#   '날',
#   '음식',
#   '식사',
#   '대용',
#   '다이어트',
#   '레시피',
#   '간단',
#   '점심',
#   '아이',
#   '반찬',
#   '반찬',
#   '집밥',
#   '가시',
#   '장미',
#   '수다'],
#  ['나루',
#   '동태',
#   '탕',
#   '마곡',
#   '비',
#   '날',
#   '동태',
#   '탕',
#   '맛집',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '추천',
#   '안녕하십니까',
#   '국밥',
#   '맨입',
#   '이번',
#   '마곡',
#   '나루',
#   '맛집',
#   '포스팅',
#   '마곡',
#   '비',
#   '날',
#   '동태',
#   '탕',
#   '맛집',
#   '마곡',
#   '나루',
#   '나루',
#   '동태',
#   '탕',
#   '포스팅',
#   '와이프',
#   '날씨',
#   '때',
#   '마다',
#   '비',
#   '날',
#   '마다',
#   '국밥',
#   '맨',
#   '모험'],
#  ['비',
#   '날',
#   '메뉴',
#   '감자전',
#   '만들기',
#   '아이',
#   '간식',
#   '추천',
#   '고소',
#   '감자',
#   '홈',
#   '홈스토리',
#   '비',
#   '날',
#   '메뉴',
#   '아이',
#   '간식',
#   '추천',
#   '감자전',
#   '감자',
#   '만들기',
#   '감자',
#   '싹',
#   '독성',
#   '때문',
#   '박스',
#   '단위',
#   '조금',
#   '사서',
#   '도록',
#   '려고',
#   '편',
#   '요',
#   '봉지',
#   '홈',
#   '홈스토리'],
#  ['비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '오늘',
#   '뭐',
#   '식단',
#   '표',
#   '일주일',
#   '주간',
#   '밥상',
#   '오늘',
#   '뭐',
#   '식단',
#   '표',
#   '일주일',
#   '주간',
#   '밥상',
#   '식단',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '안녕',
#   '벌써',
#   '일요일',
#   '밤',
#   '요',
#   '저',
#   '금요일',
#   '양양',
#   '여행',
#   '다가',
#   '어제',
#   '집',
#   '오늘',
#   '친정',
#   '부모님',
#   '저녁',
#   '더니',
#   '금요일',
#   '부터',
#   '평범',
#   '듯',
#   '특별',
#   '꽃',
#   '길이'],
#  ['비',
#   '날',
#   '간단',
#   '캠핑',
#   '요리',
#   '추천',
#   '캠핑',
#   '메뉴',
#   '사옹원',
#   '부침개',
#   '비',
#   '날',
#   '간단',
#   '캠핑',
#   '요리',
#   '추천',
#   '캠핑',
#   '메뉴',
#   '사옹원',
#   '부침개',
#   '종',
#   '세트',
#   '호떡',
#   '우중',
#   '캠핑',
#   '날',
#   '꼭',
#   '부침개',
#   '것',
#   '직접',
#   '재료',
#   '반죽',
#   '더',
#   '캠핑',
#   '최고',
#   '평소',
#   '달',
#   '로그'],
#  ['동래',
#   '맛집',
#   '비',
#   '날',
#   '더',
#   '술집',
#   '추천',
#   '메뉴',
#   '산장',
#   '전골',
#   '동래',
#   '대체로',
#   '오리',
#   '주물',
#   '럭',
#   '던데',
#   '비',
#   '날',
#   '방문',
#   '국물',
#   '산장',
#   '전골',
#   '주문',
#   '산장',
#   '메뉴',
#   '메뉴',
#   '막걸리',
#   '소주',
#   '젊은이',
#   '취향',
#   '저격',
#   '하이',
#   '볼',
#   '산장',
#   '수진',
#   '흔적'],
#  ['짱',
#   '김대',
#   '리',
#   '날',
#   '메뉴',
#   '추천',
#   '가산디지털단지역',
#   '불맛나',
#   '날',
#   '메뉴',
#   '하나',
#   '추천',
#   '짬뽕',
#   '제왕',
#   '주소',
#   '서울',
#   '금천구',
#   '가산',
#   '디지털',
#   '로',
#   '한라',
#   '앤',
#   '타워',
#   '층',
#   '호',
#   '전화번호',
#   '영업',
#   '시간',
#   '월',
#   '금',
#   '가산디지털단지역',
#   '부근',
#   '짬뽕',
#   '파이브',
#   '비뉴'],
#  ['감자',
#   '수제비',
#   '법',
#   '비',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '수제비',
#   '만들기',
#   '끈',
#   '즐',
#   '기기',
#   '감자',
#   '수제비',
#   '법',
#   '비',
#   '날',
#   '메뉴',
#   '로',
#   '점심',
#   '메뉴',
#   '추천',
#   '수제비',
#   '만들기',
#   '가끔',
#   '비',
#   '날',
#   '이',
#   '특정',
#   '음식',
#   '생각',
#   '날때',
#   '서도',
#   '비',
#   '날',
#   '지혜',
#   '사자',
#   '감성',
#   '현실',
#   '집밥'],
#  ['제주',
#   '여행',
#   '비',
#   '날',
#   '무',
#   '로이',
#   '주차',
#   '메뉴',
#   '베이커리',
#   '추천',
#   '힙',
#   '감성',
#   '포토',
#   '스팟',
#   '아보',
#   '날',
#   '테라스',
#   '강추',
#   '대신',
#   '베이커리',
#   '종류',
#   '편이',
#   '디저트',
#   '베이커리',
#   '카페',
#   '분',
#   '참고',
#   '욥',
#   '분',
#   '추천',
#   '해',
#   '서귀포',
#   '주차',
#   '대형',
#   '카페',
#   '파워',
#   '이지',
#   '여행',
#   '일상'],
#  ['여름',
#   '메뉴',
#   '가지',
#   '탕수',
#   '감자전',
#   '만들기',
#   '비',
#   '날',
#   '음식',
#   '추천',
#   '제철',
#   '여름',
#   '메뉴',
#   '즐',
#   '기기',
#   '아이',
#   '어른',
#   '가지',
#   '탕수랍니',
#   '비',
#   '날',
#   '메뉴',
#   '로',
#   '추천',
#   '전',
#   '오랜만',
#   '감자전',
#   '어요',
#   '담',
#   '백고',
#   '소한',
#   '감자전',
#   '우리',
#   '집',
#   '막내',
#   '아하',
#   '요리',
#   '감자',
#   '개',
#   '맘마'],
#  ['비올',
#   '때',
#   '음식',
#   '비',
#   '날',
#   '메뉴',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '그릇',
#   '요리',
#   '비',
#   '날',
#   '음식',
#   '비올',
#   '때',
#   '음식',
#   '비',
#   '날',
#   '메뉴',
#   '비',
#   '날',
#   '저녁',
#   '그릇',
#   '요리',
#   '저녁',
#   '메뉴',
#   '저녁',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '뭐',
#   '드실껀',
#   '가요',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '비',
#   '날',
#   '음식',
#   '비',
#   '날',
#   '먹기',
#   '달타냥',
#   '하우스'],
#  ['안동',
#   '경북',
#   '도청',
#   '비',
#   '날',
#   '메뉴',
#   '고기국수',
#   '칼국수',
#   '이수',
#   '옥',
#   '추천',
#   '해',
#   '오래',
#   '집',
#   '이지',
#   '사람',
#   '맛집',
#   '날',
#   '은',
#   '역시',
#   '국물',
#   '메뉴',
#   '경북',
#   '도청',
#   '무하',
#   '직원',
#   '단골',
#   '음식점',
#   '점심',
#   '시간',
#   '자리',
#   '수',
#   '평소',
#   '성공',
#   '설비',
#   '누수',
#   '수구',
#   '해결사',
#   '설비',
#   '모든',
#   '것'],
#  ['강서구',
#   '맛집',
#   '유림',
#   '닭도리탕',
#   '날',
#   '추천',
#   '메뉴',
#   '날',
#   '막걸리',
#   '못',
#   '우리',
#   '한마음',
#   '통속',
#   '강서구',
#   '까지',
#   '비',
#   '음식',
#   '비',
#   '오니',
#   '생각',
#   '막걸리',
#   '유림',
#   '닭도리탕',
#   '메뉴',
#   '정',
#   '도착',
#   '오늘',
#   '나'],
#  ['쑥갓',
#   '전',
#   '쑥갓',
#   '요리',
#   '건',
#   '새우',
#   '부추전',
#   '비',
#   '날',
#   '음식',
#   '메뉴',
#   '막걸리',
#   '쑥갓',
#   '요리',
#   '쑥갓',
#   '전',
#   '쑥갓',
#   '부추전',
#   '비',
#   '날',
#   '음식',
#   '막걸리',
#   '안주',
#   '추천',
#   '바삭',
#   '바삭',
#   '전요',
#   '리가',
#   '생각',
#   '비',
#   '날',
#   '메뉴',
#   '로',
#   '쑥갓',
#   '부추',
#   '건',
#   '새우',
#   '줌',
#   '어서',
#   '쑥갓',
#   '부추전',
#   '어요',
#   '비',
#   '날',
#   '음식',
#   '역시',
#   '전이',
#   '칼라',
#   '푸드',
#   '테라',
#   '피'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '스벅',
#   '카페라떼',
#   '스텀',
#   '고',
#   '엽떡',
#   '어제',
#   '부터',
#   '재난',
#   '알림',
#   '문자',
#   '방송',
#   '태풍',
#   '대비',
#   '하라',
#   '방송',
#   '등',
#   '이번',
#   '맛',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '라떼',
#   '커피',
#   '스타벅스',
#   '카페라떼',
#   '하루하루'],
#  ['상추',
#   '전',
#   '만들기',
#   '튀김',
#   '가루',
#   '상추',
#   '부침개',
#   '반죽',
#   '비',
#   '날',
#   '술안주',
#   '메뉴',
#   '키친',
#   '타',
#   '기름기',
#   '빼',
#   '어요',
#   '맛',
#   '상추',
#   '부침개',
#   '전간',
#   '장',
#   '더',
#   '어요',
#   '상추',
#   '맛',
#   '더',
#   '지네',
#   '비',
#   '날',
#   '술안주',
#   '메뉴',
#   '로',
#   '이영자',
#   '상추',
#   '전',
#   '추천',
#   '꿀'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '유미',
#   '카츠',
#   '안녕',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '로',
#   '먹기',
#   '음식',
#   '가득',
#   '곳',
#   '유미',
#   '카츠',
#   '본격',
#   '적',
#   '장마',
#   '비',
#   '날',
#   '최고',
#   '추천',
#   '메뉴',
#   '비',
#   '날',
#   '뿐',
#   '항상',
#   '분',
#   '유미',
#   '카츠',
#   '매력',
#   '돈카츠',
#   '전문점',
#   '유미',
#   '카츠',
#   '공식',
#   '블로그'],
#  ['동천역',
#   '한국',
#   '물',
#   '날',
#   '명동',
#   '칼국수',
#   '점심',
#   '메뉴',
#   '추천',
#   '동천역',
#   '한국',
#   '물',
#   '날',
#   '명동',
#   '칼국수',
#   '점심',
#   '메뉴',
#   '추천',
#   '돈',
#   '산',
#   '동천역',
#   '칼국수',
#   '수지구',
#   '칼국수',
#   '동천역',
#   '맛집',
#   '동천역',
#   '명동',
#   '칼국수',
#   '평일',
#   '토요일',
#   '일요일',
#   '휴무',
#   '주차',
#   '가능',
#   '오늘',
#   '비',
#   '억수',
#   '마론킴'],
#  ['광교',
#   '아브뉴',
#   '프랑',
#   '맛집',
#   '정',
#   '남옥',
#   '순대국',
#   '날',
#   '추천',
#   '메뉴',
#   '이용',
#   '시간',
#   '매일',
#   '라스트',
#   '광교',
#   '맛집',
#   '광교',
#   '순대국',
#   '프랑',
#   '광교',
#   '순대국',
#   '프랑',
#   '순대국',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '순대국',
#   '맛집',
#   '남옥',
#   '순대국',
#   '프랑',
#   '맛집',
#   '오픈',
#   '맛집',
#   '별별',
#   '감초',
#   '내일',
#   '여',
#   '일상'],
#  ['인천',
#   '맛집',
#   '날',
#   '추천',
#   '메뉴',
#   '양',
#   '꼬치',
#   '작전동',
#   '맛집',
#   '온면',
#   '포차',
#   '메뉴',
#   '양',
#   '꼬치',
#   '개',
#   '이면',
#   '적당',
#   '거',
#   '일단',
#   '양',
#   '꼬치',
#   '인분',
#   '시작',
#   '분',
#   '추천',
#   '맛집',
#   '소주',
#   '잔',
#   '필',
#   '수구',
#   '양',
#   '꼬치',
#   '칭따오',
#   '맥주',
#   '배',
#   '술',
#   '미미',
#   '이야기'],
#  ['집콕러들',
#   '위',
#   '오덕',
#   '이의',
#   '날',
#   '메뉴',
#   '추천',
#   '오덕',
#   '쌀',
#   '오덕',
#   '날',
#   '집콕러들',
#   '위',
#   '추천',
#   '메뉴',
#   '어요',
#   '해물파전',
#   '비',
#   '날',
#   '빗',
#   '소리',
#   '전',
#   '저',
#   '개',
#   '인적',
#   '어렷을적',
#   '초등학교',
#   '마치',
#   '비',
#   '날',
#   '우산',
#   '오덕',
#   '청년'],
#  ['오늘',
#   '추천',
#   '메뉴',
#   '날',
#   '음식',
#   '해물파전',
#   '어묵탕',
#   '암만',
#   '암만',
#   '비',
#   '날',
#   '자향',
#   '호',
#   '출발',
#   '어묵탕',
#   '치즈',
#   '닭갈비',
#   '해물파전',
#   '소세지',
#   '전',
#   '역시',
#   '여름',
#   '비',
#   '인기',
#   '메뉴',
#   '비',
#   '날',
#   '음식',
#   '오늘',
#   '영양',
#   '쟁이',
#   '강력',
#   '추천',
#   '합',
#   '미니',
#   '힐링',
#   '푸드'],
#  ['비',
#   '날',
#   '저녁',
#   '메뉴',
#   '로',
#   '음식',
#   '메기',
#   '매운탕',
#   '맛집',
#   '추천',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '로',
#   '음식',
#   '메기',
#   '매운탕',
#   '맛집',
#   '추천',
#   '올해',
#   '장마',
#   '기간',
#   '비',
#   '계속',
#   '시작',
#   '면서',
#   '계속',
#   '비소',
#   '식',
#   '이번',
#   '비',
#   '때문',
#   '시간',
#   '남양주',
#   '다이어트',
#   '찜질',
#   '카페'],
#  ['비',
#   '날',
#   '음식',
#   '메뉴',
#   '비',
#   '날',
#   '생각',
#   '음식',
#   '술안주',
#   '전',
#   '비',
#   '날',
#   '음식',
#   '메뉴',
#   '비',
#   '날',
#   '생각',
#   '음식',
#   '술안주',
#   '전',
#   '종류',
#   '레시피',
#   '주',
#   '안주',
#   '도',
#   '다음',
#   '날',
#   '해장',
#   '음식',
#   '추천',
#   '국물',
#   '요리',
#   '레시피',
#   '출처',
#   '나혼산',
#   '코쿤',
#   '바지락',
#   '탕',
#   '레시피',
#   '엘리',
#   '맘',
#   '지금',
#   '이',
#   '순간'],
#  ['쌀국수',
#   '부터',
#   '깐풍기',
#   '까지',
#   '날',
#   '단짝',
#   '포',
#   '메인',
#   '메뉴',
#   '메인',
#   '메인',
#   '레드',
#   '쌀국수',
#   '맛집',
#   '메뉴',
#   '추천',
#   '오늘',
#   '뭐',
#   '베트남',
#   '배달',
#   '배달',
#   '음식',
#   '메인',
#   '메뉴',
#   '맛집',
#   '후기',
#   '베스트',
#   '메뉴',
#   '포',
#   '메인',
#   '깐풍기',
#   '날',
#   '단짝',
#   '메뉴',
#   '포',
#   '메인',
#   '깐풍기',
#   '쌀국수',
#   '포',
#   '메인'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '부추전',
#   '만들기',
#   '부추',
#   '요리',
#   '레시피',
#   '건',
#   '새우',
#   '날',
#   '생각',
#   '부침개',
#   '새우',
#   '멸치',
#   '어가',
#   '간',
#   '초',
#   '간장',
#   '이나',
#   '매콤',
#   '청양고추',
#   '절임',
#   '곁',
#   '이면',
#   '감칠맛',
#   '수',
#   '아직',
#   '비',
#   '점심',
#   '메뉴',
#   '로',
#   '하루'],
#  ['갑오징어무침',
#   '감자',
#   '부침개',
#   '비',
#   '날',
#   '집밥',
#   '메뉴',
#   '추천',
#   '동네',
#   '방',
#   '소',
#   '다트',
#   '리',
#   '갑오징어무침',
#   '감자',
#   '부침개',
#   '비',
#   '날',
#   '집밥',
#   '메뉴',
#   '추천',
#   '장마철',
#   '일',
#   '비',
#   '주룩주룩',
#   '비',
#   '밖',
#   '기',
#   '지고',
#   '몸',
#   '지고',
#   '기분',
#   '까지',
#   '다운',
#   '소',
#   '다한',
#   '소',
#   '다트',
#   '리'],
#  ['구',
#   '미산동',
#   '맛집',
#   '날',
#   '메뉴',
#   '추천',
#   '도토리',
#   '전이',
#   '쭈꾸미',
#   '전문',
#   '안',
#   '전하',
#   '보',
#   '내세',
#   '날',
#   '쭈꾸미',
#   '세트',
#   '메뉴',
#   '도토리',
#   '전',
#   '구성',
#   '날',
#   '세트',
#   '구성',
#   '구미',
#   '점심',
#   '구미',
#   '점심',
#   '메뉴',
#   '추천',
#   '계산',
#   '곳',
#   '편',
#   '아메',
#   '믹스',
#   '커피',
#   '수',
#   '도록',
#   '프로',
#   '설비',
#   '토탈',
#   '인테리어'],
#  ['우이',
#   '녹',
#   '날',
#   '추천',
#   '메뉴',
#   '새우',
#   '수제비',
#   '백합',
#   '칼국수',
#   '송도',
#   '칼국수',
#   '비',
#   '날',
#   '메뉴',
#   '왕새우',
#   '수제비',
#   '우이',
#   '녹',
#   '수제비',
#   '지난주',
#   '말',
#   '볼일',
#   '송도',
#   '센트럴',
#   '파크',
#   '오전',
#   '일',
#   '송도',
#   '맛집',
#   '아보',
#   '새',
#   '우수',
#   '제비집',
#   '마침',
#   '비',
#   '날',
#   '어서',
#   '김',
#   '썸머',
#   '블로그'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '들깨',
#   '수제비',
#   '퇴근',
#   '항상',
#   '고',
#   '민하',
#   '저녁',
#   '메뉴',
#   '오늘',
#   '무얼',
#   '먹음',
#   '고',
#   '민하',
#   '다가',
#   '비도',
#   '오랜만',
#   '들깨',
#   '그릇',
#   '그릇',
#   '최고',
#   '날',
#   '들깨',
#   '수제비',
#   '그릇',
#   '의',
#   '평범',
#   '한일',
#   '상'],
#  ['장떡',
#   '법',
#   '비',
#   '날',
#   '술안주',
#   '메뉴',
#   '고추장',
#   '장떡',
#   '부추',
#   '장떡',
#   '장떡',
#   '법',
#   '비',
#   '날',
#   '술안주',
#   '메뉴',
#   '고추장',
#   '장떡',
#   '부추',
#   '장떡',
#   '비',
#   '날',
#   '메뉴',
#   '부침개',
#   '생각',
#   '절로',
#   '비',
#   '날',
#   '술안주',
#   '추천',
#   '준비',
#   '장떡',
#   '법',
#   '진짜',
#   '냉장고',
#   '속',
#   '야채',
#   '고추장',
#   '시크',
#   '도도',
#   '토깽',
#   '살',
#   '효'],
#  ['날',
#   '메뉴',
#   '추천',
#   '소',
#   '곱창전골',
#   '소',
#   '곱창',
#   '효능',
#   '날',
#   '메뉴',
#   '추천',
#   '소',
#   '곱창전골',
#   '소',
#   '곱창',
#   '효능',
#   '보통',
#   '소',
#   '곱창',
#   '함',
#   '곱',
#   '가득',
#   '겉',
#   '기름',
#   '지고',
#   '전골',
#   '곱',
#   '곱창',
#   '구이',
#   '때',
#   '온통',
#   '기름',
#   '얀마',
#   '음',
#   '블로그'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '해물파전',
#   '초',
#   '간단',
#   '레시피',
#   '국순당',
#   '앞',
#   '비',
#   '날',
#   '그때',
#   '마다',
#   '막걸리',
#   '메뉴',
#   '로',
#   '파전',
#   '초',
#   '간단',
#   '레시피',
#   '해물파전',
#   '레시피',
#   '해물파전',
#   '초',
#   '간단',
#   '레시피',
#   '파전',
#   '막걸리',
#   '해물파전',
#   '맛집',
#   '막걸리',
#   '추천',
#   '우국생',
#   '국순당',
#   '막걸리'],
#  ['제주',
#   '원더',
#   '아일랜드',
#   '아기',
#   '비',
#   '날',
#   '서귀포',
#   '볼',
#   '곳',
#   '추천',
#   '제주',
#   '원더',
#   '아일랜드',
#   '아기',
#   '비',
#   '날',
#   '서귀포',
#   '볼',
#   '곳',
#   '추천',
#   '이번',
#   '제주',
#   '여행',
#   '기억',
#   '몇',
#   '개',
#   '진심',
#   '날',
#   '이나',
#   '날',
#   '야외',
#   '여의',
#   '치',
#   '날',
#   '서귀포',
#   '제주',
#   '원더',
#   '아일랜드',
#   '강',
#   '리',
#   '로',
#   '그'],
#  ['대포',
#   '메뉴',
#   '추천',
#   '날',
#   '빠삭',
#   '파전',
#   '광영동',
#   '술집',
#   '대포',
#   '메뉴',
#   '추천',
#   '빠삭',
#   '파전',
#   '광영동',
#   '술집',
#   '파전',
#   '날',
#   '막걸리',
#   '파전',
#   '최고',
#   '바삭',
#   '튀김',
#   '수',
#   '빠사',
#   '파전',
#   '메뉴',
#   '를',
#   '추천',
#   '첫',
#   '방문',
#   '때',
#   '부터',
#   '파전',
#   '떡볶이',
#   '반',
#   '날',
#   '보름달',
#   '일상',
#   '로그'],
#  ['상도동',
#   '점심',
#   '메뉴',
#   '추천',
#   '낙지',
#   '마리',
#   '수제비',
#   '날',
#   '생각',
#   '어요',
#   '상도동',
#   '수제비',
#   '메뉴',
#   '저',
#   '낙지',
#   '마리',
#   '수제비',
#   '남편',
#   '낙지',
#   '덮밥',
#   '주문',
#   '어요',
#   '날',
#   '국물',
#   '쫄깃',
#   '수제비',
#   '그릇',
#   '최고',
#   '점심',
#   '었습니당',
#   '상도동',
#   '맛집',
#   '상도동',
#   '맛집',
#   '추천',
#   '일상',
#   '정보',
#   '공',
#   '유하',
#   '블로그'],
#  ['신촌',
#   '카페',
#   '보드게임',
#   '카페',
#   '레드',
#   '버튼',
#   '추천',
#   '날',
#   '날',
#   '비',
#   '날',
#   '가기',
#   '신촌',
#   '놀',
#   '거리',
#   '보드게임',
#   '카페',
#   '레드',
#   '버튼',
#   '추천',
#   '해',
#   '보기',
#   '신촌',
#   '신촌',
#   '보드게임',
#   '카페',
#   '레드',
#   '버튼',
#   '메뉴',
#   '판',
#   '방',
#   '마다',
#   '여진',
#   '어플',
#   '통해',
#   '비',
#   '대면',
#   '주문',
#   '수',
#   '음료'],
#  ['부어',
#   '치킨',
#   '비',
#   '날',
#   '치킨',
#   '치맥',
#   '그릴',
#   '후라이드',
#   '통치',
#   '킨',
#   '추천',
#   '메뉴',
#   '연휴',
#   '주말',
#   '배민',
#   '배달',
#   '민족',
#   '부어',
#   '치킨',
#   '할인',
#   '쿠폰',
#   '날',
#   '치킨',
#   '생각',
#   '부어',
#   '치킨',
#   '그릴',
#   '후라이드',
#   '살',
#   '그릴',
#   '후라이드',
#   '통치',
#   '킨',
#   '부어',
#   '치킨',
#   '그릴',
#   '후라이드',
#   '통치',
#   '킨',
#   '추천',
#   '메뉴',
#   '소',
#   '소한',
#   '이야기'],
#  ['서울',
#   '비',
#   '날',
#   '어반',
#   '가든',
#   '데이트',
#   '모임',
#   '추천',
#   '삭',
#   '샐러드',
#   '식감',
#   '스프',
#   '입맛',
#   '구기',
#   '제격',
#   '메뉴',
#   '거기',
#   '서울',
#   '비',
#   '날',
#   '서울',
#   '비',
#   '날',
#   '실내',
#   '데이트',
#   '맛집',
#   '추천',
#   '다음',
#   '화창',
#   '날',
#   '야외',
#   '테이블',
#   '보',
#   '려고'],
#  ['사당',
#   '녀석',
#   '술집',
#   '추천',
#   '마케집',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '주말',
#   '비',
#   '비',
#   '날',
#   '메뉴',
#   '오늘',
#   '센스',
#   '쏠',
#   '습',
#   '사당역',
#   '술집',
#   '태블릿',
#   '메뉴판',
#   '편',
#   '리하',
#   '조개',
#   '무지',
#   '습',
#   '사당',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '쏠',
#   '로그'],
#  ['부천',
#   '전자',
#   '방',
#   '현대',
#   '백화점',
#   '중동',
#   '점',
#   '날',
#   '찰떡',
#   '메뉴',
#   '선택',
#   '해당',
#   '날',
#   '자주',
#   '방문',
#   '예상',
#   '점',
#   '셋',
#   '천원',
#   '돈',
#   '친절',
#   '분위기',
#   '현대',
#   '백화점',
#   '중',
#   '동점',
#   '중식',
#   '추천',
#   '현대',
#   '백화점',
#   '중',
#   '동점',
#   '짬뽕',
#   '맛집',
#   '킴풔집',
#   '구석'],
#  ['바삭',
#   '해물파전',
#   '동동주',
#   '날',
#   '추천',
#   '메뉴',
#   '하늘',
#   '좀',
#   '우중',
#   '충',
#   '여러분',
#   '우울',
#   '필요',
#   '우리',
#   '전통문화',
#   '요',
#   '오늘',
#   '모임',
#   '파전',
#   '어요',
#   '수제비',
#   '먼저',
#   '위',
#   '보호',
#   '참기름',
#   '몽고',
#   '덕질',
#   '블로그'],
#  ['휴게소',
#   '날',
#   '추천',
#   '메뉴',
#   '터',
#   '비',
#   '날',
#   '성남',
#   '나들이',
#   '남한',
#   '산성',
#   '드라이브',
#   '코스',
#   '날',
#   '추천',
#   '메뉴',
#   '오후',
#   '시가',
#   '동생',
#   '저녁',
#   '겸',
#   '산',
#   '공기',
#   '길',
#   '요즘',
#   '해',
#   '시가',
#   '지니',
#   '비',
#   '영어'],
#  ['삼시',
#   '끼',
#   '차승원',
#   '수제비',
#   '감자',
#   '수제비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '삼시',
#   '끼',
#   '차승원',
#   '수제비',
#   '감자',
#   '수제비',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '수제비',
#   '반죽',
#   '숙성',
#   '보관',
#   '얼마',
#   '전부',
#   '터',
#   '수제비',
#   '수제비',
#   '곳',
#   '기억',
#   '음식점',
#   '출입'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '김치찜',
#   '저',
#   '집',
#   '날',
#   '안',
#   '게',
#   '억울',
#   '정도',
#   '날씨',
#   '맑은',
#   '것',
#   '게',
#   '더',
#   '고요',
#   '그나',
#   '마',
#   '김치찜',
#   '비',
#   '날',
#   '이면',
#   '또',
#   '생각',
#   '날',
#   '것',
#   '한국인',
#   '입맛',
#   '추천',
#   '메뉴',
#   '치',
#   '느님',
#   '가라사대'],
#  ['비',
#   '날',
#   '메뉴',
#   '추천',
#   '시원',
#   '김치',
#   '콩나물국',
#   '법',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '시원',
#   '김치',
#   '콩나물국',
#   '법',
#   '하루',
#   '종일',
#   '비',
#   '부슬부슬',
#   '날',
#   '국물',
#   '오른',
#   '전',
#   '비',
#   '시원',
#   '김치',
#   '김치',
#   '콩나물국',
#   '더니',
#   '어요',
#   '그녀',
#   '이야기'],
#  ['의왕',
#   '군포',
#   '날',
#   '추천',
#   '메뉴',
#   '짬뽕',
#   '교동',
#   '반점',
#   '날',
#   '추천',
#   '메뉴',
#   '날',
#   '짬뽕',
#   '끈',
#   '매콤',
#   '국물',
#   '후루루',
#   '룹',
#   '캬',
#   '짬뽕',
#   '짜장면',
#   '가격',
#   '차이',
#   '어요',
#   '그',
#   '만큼',
#   '짬뽕',
#   '더',
#   '어요',
#   '짬뽕',
#   '추천',
#   '양파',
#   '단무지',
#   '최꾸럭',
#   '블로그'],
#  ['날',
#   '끈',
#   '피자',
#   '피자',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '걸',
#   '게',
#   '고심',
#   '끝',
#   '특별',
#   '피자',
#   '메뉴',
#   '선정',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '로',
#   '토핑',
#   '파인애플',
#   '방울토마토',
#   '어가',
#   '피자',
#   '땅',
#   '공식',
#   '블로그'],
#  ['감자',
#   '수제비',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '점심',
#   '메뉴',
#   '추천',
#   '수제비',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '수제비',
#   '점심',
#   '메뉴',
#   '추천',
#   '밀가루',
#   '요리',
#   '가시',
#   '길',
#   '키친',
#   '업',
#   '감사',
#   '수제비',
#   '반죽',
#   '감자',
#   '애호박',
#   '양파',
#   '대파',
#   '국',
#   '간장',
#   '숟가락',
#   '반',
#   '후추',
#   '조금',
#   '육수',
#   '물',
#   '다시마',
#   '장',
#   '감자',
#   '수제비',
#   '냄비',
#   '물',
#   '멍공쥬',
#   '소',
#   '소한',
#   '이야기'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '바지락',
#   '듬뿍',
#   '고추장',
#   '칼국수',
#   '저희',
#   '딸',
#   '이',
#   '칼국수',
#   '면',
#   '고요',
#   '오늘',
#   '장',
#   '칼국수',
#   '애',
#   '만',
#   '족하',
#   '메뉴',
#   '사실',
#   '이',
#   '제일',
#   '냉정',
#   '평가',
#   '남매',
#   '라서',
#   '비',
#   '날',
#   '칼칼',
#   '끼',
#   '해결',
#   '칠',
#   '감성',
#   '워킹맘',
#   '놀이터'],
#  ['사당역',
#   '맛집',
#   '부산',
#   '어묵',
#   '오뎅',
#   '탕',
#   '어묵탕',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '가장',
#   '달이',
#   '봄',
#   '거의',
#   '주말',
#   '마다',
#   '비',
#   '것',
#   '비',
#   '날',
#   '사당역',
#   '맛집',
#   '부산',
#   '오뎅',
#   '어묵탕',
#   '드디어',
#   '부산',
#   '오뎅',
#   '시',
#   '그니',
#   '처',
#   '메뉴',
#   '오뎅',
#   '탕',
#   '등장',
#   '계란',
#   '당면',
#   '미나리',
#   '부추',
#   '책',
#   '산',
#   '길'],
#  ['날',
#   '점심',
#   '추천',
#   '메뉴',
#   '일산',
#   '짬뽕',
#   '지존',
#   '수제비',
#   '짬뽕',
#   '비',
#   '날',
#   '은',
#   '밀가루',
#   '음식',
#   '이나',
#   '기름기',
#   '도',
#   '지지',
#   '부침개',
#   '땡',
#   '기지',
#   '모듬',
#   '전',
#   '동동주',
#   '잔',
#   '아직',
#   '근무시간',
#   '동동주',
#   '대신',
#   '날',
#   '매콤',
#   '짬뽕',
#   '점심',
#   '메뉴',
#   '로',
#   '추천',
#   '해',
#   '델마',
#   '소',
#   '소한',
#   '일상',
#   '소',
#   '소한',
#   '이야기'],
#  ['홍콩',
#   '반점',
#   '성대',
#   '시장',
#   '맛집',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '전',
#   '예전',
#   '칼국수',
#   '생각',
#   '요즘',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '짬뽕',
#   '고',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '인',
#   '짬뽕',
#   '대학교',
#   '학년',
#   '때',
#   '짬뽕',
#   '매력',
#   '뒤',
#   '거의',
#   '짬뽕',
#   '케이',
#   '의',
#   '기록'],
#  ['대전',
#   '김치찌개',
#   '맛집',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '오',
#   '모리',
#   '찌개',
#   '어가',
#   '비',
#   '날',
#   '그릇',
#   '메뉴',
#   '로',
#   '마음',
#   '으슬으슬',
#   '날',
#   '팔팔',
#   '뚝배기',
#   '그릇',
#   '정말',
#   '소',
#   '소하',
#   '확실',
#   '행복',
#   '거',
#   '카페',
#   '커피',
#   '디저트',
#   '면서',
#   '창밖',
#   '제리',
#   '뷰티',
#   '로그'],
#  ['비',
#   '날',
#   '메뉴',
#   '로',
#   '파전',
#   '대신',
#   '간단',
#   '술안주',
#   '추천',
#   '골뱅이무침',
#   '양념',
#   '코로나',
#   '수',
#   '날',
#   '한잔',
#   '것',
#   '인지상정',
#   '습',
#   '깡',
#   '비',
#   '날',
#   '간편',
#   '안주',
#   '메뉴',
#   '로',
#   '살포시',
#   '추천',
#   '드릴',
#   '요',
#   '집들이',
#   '메인',
#   '요리',
#   '볼보',
#   '맘',
#   '이',
#   '작가',
#   '이야기'],
#  ['장마철',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '사골',
#   '수제비',
#   '한국인',
#   '힘',
#   '밥힘',
#   '나',
#   '게',
#   '밥',
#   '다른',
#   '것',
#   '자꾸',
#   '눈길',
#   '장마철',
#   '이웃',
#   '님들',
#   '메뉴',
#   '로',
#   '분안',
#   '뚝딱',
#   '뚝딱',
#   '요리',
#   '장마철',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '사골',
#   '수제비',
#   '맛',
#   '중심',
#   '종가',
#   '집'],
#  ['꼬치',
#   '어묵탕',
#   '법',
#   '꼬치',
#   '어묵',
#   '비',
#   '날',
#   '음식',
#   '메뉴',
#   '어묵탕',
#   '메뉴',
#   '생각',
#   '도',
#   '안',
#   '나',
#   '시간',
#   '다가',
#   '데',
#   '반찬',
#   '마땅치',
#   '나',
#   '혼자',
#   '해',
#   '결하',
#   '거',
#   '대충',
#   '금방',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '어요',
#   '국물',
#   '글',
#   '어묵',
#   '입',
#   '시크',
#   '도도',
#   '토깽',
#   '살',
#   '효'],
#  ['삼송',
#   '동화',
#   '감성',
#   '디저트',
#   '카페',
#   '담',
#   '비',
#   '날',
#   '도',
#   '추천',
#   '주문',
#   '메뉴',
#   '등장',
#   '커피',
#   '일행',
#   '아메리카노',
#   '디저트',
#   '때',
#   '아메리카노',
#   '커피',
#   '맛',
#   '카페',
#   '때',
#   '부터',
#   '블루베리',
#   '치즈케이크',
#   '꼭',
#   '선물',
#   '거마',
#   '보자기',
#   '모',
#   '양으로',
#   '나',
#   '것',
#   '마음',
#   '단방',
#   '향소',
#   '통',
#   '생활기록부'],
#  ['미미',
#   '사',
#   '원양',
#   '꼬치',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '세트',
#   '메뉴',
#   '저희',
#   '생',
#   '꼬치',
#   '양',
#   '갈비살',
#   '어요',
#   '요리',
#   '가지',
#   '요리',
#   '비',
#   '날',
#   '미미',
#   '사',
#   '원양',
#   '꼬치',
#   '칭다오',
#   '한잔',
#   '강력',
#   '추천',
#   '돈',
#   '산',
#   '리얼',
#   '후기',
#   '에픽',
#   '스터디',
#   '학원'],
#  ['야채',
#   '전',
#   '법',
#   '해물',
#   '버섯',
#   '모',
#   '날',
#   '메뉴',
#   '추천',
#   '야채',
#   '전',
#   '법',
#   '해물',
#   '버섯',
#   '모',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '냉털',
#   '요리',
#   '글',
#   '사진',
#   '요',
#   '요',
#   '쿡',
#   '재료',
#   '피로',
#   '풀',
#   '어보',
#   '야채',
#   '전',
#   '법',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '로',
#   '알',
#   '주말',
#   '보',
#   '내세',
#   '호기심',
#   '부자',
#   '요',
#   '언니',
#   '오늘',
#   '머',
#   '하노'],
#  ['앞산',
#   '대구',
#   '손',
#   '칼국수',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '비',
#   '날',
#   '이면',
#   '기분',
#   '뭔가',
#   '차',
#   '분해',
#   '건',
#   '수',
#   '그저께',
#   '대구',
#   '앞산',
#   '순환도로',
#   '다른',
#   '가게',
#   '주차',
#   '매너',
#   '니니',
#   '오늘',
#   '처럼',
#   '비',
#   '날',
#   '국물',
#   '식사',
#   '요',
#   '하루',
#   '한걸음씩'],
#  ['저녁',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '음식',
#   '제',
#   '장바구니',
#   '목록',
#   '내일',
#   '비',
#   '오락가락',
#   '비',
#   '날',
#   '음식',
#   '비',
#   '날',
#   '음식',
#   '비',
#   '날',
#   '음식',
#   '비',
#   '날',
#   '메뉴',
#   '비',
#   '날',
#   '뭐',
#   '비',
#   '날',
#   '음식',
#   '추천',
#   '달타냥',
#   '하우스'],
#  ['부추',
#   '미나리',
#   '장떡',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '전',
#   '부침개',
#   '완전',
#   '추천',
#   '이요',
#   '조금',
#   '재료',
#   '사실',
#   '활용',
#   '하나',
#   '요리',
#   '만들기',
#   '부침개',
#   '부침개',
#   '점심',
#   '어요',
#   '비',
#   '날',
#   '정말',
#   '더',
#   '손',
#   '끝',
#   '완성'],
#  ['샤브',
#   '칼국수',
#   '맛집',
#   '산내',
#   '마을',
#   '맛집',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '안녕',
#   '자주',
#   '비',
#   '요즘',
#   '칼국수',
#   '종종',
#   '생각',
#   '마침',
#   '날',
#   '돈',
#   '산',
#   '오름',
#   '마을',
#   '점심',
#   '추천',
#   '점심',
#   '메뉴',
#   '추천',
#   '운정',
#   '칼국수',
#   '맛집',
#   '산내',
#   '마을',
#   '맛집',
#   '산내',
#   '마을',
#   '샤브',
#   '칼국수',
#   '추천',
#   '평범',
#   '비범',
#   '그',
#   '사이',
#   '어디',
#   '쯤'],
#  ['비',
#   '날',
#   '청당',
#   '소문',
#   '모듬',
#   '조개',
#   '칼국수',
#   '추천',
#   '점심',
#   '메뉴',
#   '사진',
#   '보시',
#   '것',
#   '처럼',
#   '모듬',
#   '조개',
#   '칼국수',
#   '바로',
#   '비',
#   '날',
#   '오늘',
#   '점심',
#   '추천',
#   '메뉴',
#   '모듬',
#   '조개',
#   '칼국수',
#   '여기',
#   '청양고추',
#   '어서',
#   '매콤',
#   '나',
#   '게',
#   '기본',
#   '주문',
#   '진희',
#   '비숑',
#   '하동',
#   '동이',
#   '일상'],
#  ['오덕',
#   '이의',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '오덕',
#   '이의',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '쭈꾸미',
#   '볶음',
#   '그',
#   '두번째',
#   '메뉴',
#   '쭈꾸미',
#   '볶음',
#   '쭈꾸미',
#   '볶음',
#   '비',
#   '왕창',
#   '장마',
#   '예고',
#   '예상',
#   '만큼',
#   '쭈꾸미',
#   '볶음',
#   '그',
#   '래서',
#   '비',
#   '오덕',
#   '청년'],
#  ['노티',
#   '드',
#   '부산',
#   '해운대',
#   '카페',
#   '비',
#   '날',
#   '웨이',
#   '팅',
#   '핫',
#   '메뉴',
#   '추천',
#   '소식',
#   '자마자',
#   '오픈',
#   '런',
#   '맛집',
#   '곳',
#   '워낙',
#   '웨이',
#   '팅',
#   '맛집',
#   '비',
#   '날',
#   '비',
#   '날',
#   '하나',
#   '추천',
#   '메뉴',
#   '크림',
#   '고',
#   '소하',
#   '면서',
#   '빵',
#   '오',
#   '또',
#   '생각',
#   '맛'],
#  ['날',
#   '점심',
#   '메뉴',
#   '부평',
#   '신',
#   '간',
#   '짬뽕',
#   '입맛',
#   '거나',
#   '날',
#   '부평',
#   '점심',
#   '메뉴',
#   '를',
#   '고민',
#   '추천',
#   '남성',
#   '여성',
#   '분',
#   '더',
#   '것',
#   '생각',
#   '오픈',
#   '저녁',
#   '중간',
#   '브레이크',
#   '타임',
#   '유',
#   '홈',
#   '부동산',
#   '대표',
#   '이현종'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '아나고',
#   '막창',
#   '맥주',
#   '한잔',
#   '고',
#   '수제',
#   '만두',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '아나고',
#   '막창',
#   '맥주',
#   '한잔',
#   '고',
#   '수제',
#   '만두',
#   '맥주',
#   '한잔',
#   '어제',
#   '퇴근',
#   '시간',
#   '비',
#   '급',
#   '메뉴',
#   '변경',
#   '아나고',
#   '포기',
#   '순',
#   '아나고',
#   '쌈',
#   '날',
#   '아나고',
#   '하루',
#   '한걸음씩'],
#  ['칼국수',
#   '밀키',
#   '트',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '입',
#   '장정원',
#   '칼국수',
#   '칼국수',
#   '밀키',
#   '트',
#   '칼국수',
#   '택배',
#   '장정원',
#   '칼국수',
#   '장정원',
#   '칼국수',
#   '택배',
#   '칼국수',
#   '택배',
#   '캠핑',
#   '메뉴',
#   '비',
#   '날',
#   '비',
#   '날',
#   '메뉴',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '요리',
#   '요리',
#   '맛집',
#   '칼국수',
#   '맛집',
#   '칼국수',
#   '법',
#   '캠핑',
#   '요리',
#   '추천',
#   '의',
#   '포토',
#   '로그'],
#  ['비',
#   '날',
#   '메뉴',
#   '로',
#   '강추',
#   '정원',
#   '캠핑',
#   '요리',
#   '추천',
#   '캠핑',
#   '메뉴',
#   '국수',
#   '밀키',
#   '트',
#   '칼국수',
#   '밀키',
#   '트',
#   '칼국수',
#   '맛집',
#   '칼국수',
#   '택배',
#   '캠핑',
#   '메뉴',
#   '비',
#   '날',
#   '메뉴',
#   '바지락',
#   '칼국수',
#   '칼국수',
#   '법',
#   '캠핑',
#   '요리',
#   '추천',
#   '장정원',
#   '칼국수',
#   '정원',
#   '칼국수',
#   '밀키',
#   '트',
#   '추천'],
#  ['일산',
#   '맛집',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '일산',
#   '칼국수',
#   '웨이',
#   '팅',
#   '주차',
#   '진짜',
#   '날',
#   '메뉴',
#   '선택',
#   '었던',
#   '것',
#   '일산',
#   '뭘',
#   '고민',
#   '때',
#   '한번',
#   '뱃골',
#   '크시',
#   '면',
#   '완칼',
#   '공기밥',
#   '추가',
#   '말',
#   '거',
#   '추천',
#   '드립',
#   '제',
#   '어요',
#   '꽉',
#   '찬',
#   '행복'],
#  ['감자',
#   '수제비',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '저녁',
#   '메뉴',
#   '추천',
#   '메추',
#   '마트',
#   '수제비',
#   '사리',
#   '보이',
#   '꼭',
#   '한번',
#   '어보',
#   '오늘',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '해',
#   '여러분',
#   '비',
#   '메뉴',
#   '오늘',
#   '건강',
#   '하루',
#   '보',
#   '내시',
#   '길',
#   '옆집',
#   '영양사',
#   '언니'],
#  ['동구',
#   '일산',
#   '비',
#   '날',
#   '순두부',
#   '맛집',
#   '점심',
#   '메뉴',
#   '추천',
#   '점심',
#   '메뉴',
#   '때',
#   '맛집',
#   '추천',
#   '만',
#   '집',
#   '어서',
#   '글',
#   '지금',
#   '비',
#   '낮',
#   '비',
#   '안',
#   '어요',
#   '비',
#   '날',
#   '순두부',
#   '더',
#   '거',
#   '전',
#   '원래',
#   '다핸즈'],
#  ['신내동',
#   '점심',
#   '맛집',
#   '호강',
#   '불',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '알',
#   '아보',
#   '메뉴',
#   '추천',
#   '해드',
#   '리도',
#   '록',
#   '여러분',
#   '비',
#   '날',
#   '이면',
#   '메뉴',
#   '가장',
#   '먼저',
#   '참숯',
#   '석쇠',
#   '불고기',
#   '날',
#   '김치찌개',
#   '더욱',
#   '더',
#   '감칠맛',
#   '수',
#   '호강',
#   '불',
#   '백의',
#   '호강',
#   '불'],
#  ['비',
#   '날',
#   '메뉴',
#   '추천',
#   '바지락',
#   '칼국수',
#   '방법',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '바지락',
#   '칼국수',
#   '방법',
#   '오늘',
#   '소아과',
#   '길',
#   '마트',
#   '오늘',
#   '날',
#   '칼국수',
#   '가용',
#   '가장',
#   '먼저',
#   '일',
#   '바지락',
#   '해감',
#   '해주',
#   '기',
#   '손',
#   '바락바락',
#   '그녀',
#   '이야기'],
#  ['비',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '빗',
#   '소리',
#   '면서',
#   '더',
#   '비',
#   '날',
#   '점심',
#   '메뉴',
#   '추천',
#   '지금',
#   '부터',
#   '알',
#   '아보',
#   '비',
#   '날',
#   '점심',
#   '메뉴',
#   '야채',
#   '김우동',
#   '비',
#   '날',
#   '가장',
#   '먼저',
#   '생각',
#   '메뉴',
#   '무엇',
#   '저',
#   '바삭',
#   '분식',
#   '김밥',
#   '창업',
#   '연구소'],
#  ['남양주',
#   '카페',
#   '추천',
#   '인생',
#   '커피',
#   '날',
#   '언니',
#   '수다',
#   '떨기',
#   '남양주',
#   '카페',
#   '추천',
#   '인생',
#   '커피',
#   '날',
#   '언니',
#   '수다',
#   '떨기',
#   '안녕',
#   '유진',
#   '어뭉',
#   '이입',
#   '다음',
#   '비',
#   '안',
#   '날',
#   '꼭',
#   '방문',
#   '실외',
#   '구경',
#   '마음껏',
#   '어요',
#   '실내',
#   '구경',
#   '마지막',
#   '화장실',
#   '화장실',
#   '똑똑',
#   '일',
#   '상속',
#   '드가즈'],
#  ['카페인',
#   '리',
#   '추천',
#   '메뉴',
#   '서울',
#   '날',
#   '데이트',
#   '데이트',
#   '추천',
#   '추천',
#   '메뉴',
#   '요',
#   '두',
#   '개',
#   '새우',
#   '버거',
#   '소고기',
#   '파스타',
#   '이름',
#   '이',
#   '었는데',
#   '기억',
#   '안남',
#   '진짜',
#   '어요',
#   '날',
#   '데이트',
#   '기도',
#   '날',
#   '데이트',
#   '헤드윅',
#   '스튜디오',
#   '전시',
#   '추천'],
#  ['대전',
#   '신탄진',
#   '현지',
#   '맛집',
#   '부추',
#   '칼국수',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '충청도',
#   '권',
#   '아지',
#   '비',
#   '피해',
#   '요즘',
#   '비',
#   '날',
#   '칼국수',
#   '바지락',
#   '칼국수',
#   '대전',
#   '칼국수',
#   '맛집',
#   '칼국수',
#   '맛집',
#   '메뉴',
#   '비',
#   '날',
#   '메뉴',
#   '칼국수',
#   '해물칼국수',
#   '신탄진',
#   '현지',
#   '맛집',
#   '뜸'],
#  ['창원',
#   '맛집',
#   '날',
#   '메뉴',
#   '추천',
#   '용호동',
#   '가로수길',
#   '샤브',
#   '노도',
#   '태',
#   '비',
#   '날',
#   '뭐',
#   '뭐',
#   '해도',
#   '국물',
#   '생각',
#   '그',
#   '래서',
#   '요즘',
#   '핫',
#   '가로수길',
#   '샤브노',
#   '도태',
#   '추천',
#   '날',
#   '뭐',
#   '얼',
#   '미나리',
#   '샤브',
#   '추천',
#   '창원',
#   '맛집',
#   '가로수길'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '전주현',
#   '대옥',
#   '콩나물국밥',
#   '주차',
#   '가능',
#   '시원',
#   '하니',
#   '해장국',
#   '추천',
#   '메뉴',
#   '콩나물국밥',
#   '전주현',
#   '대옥',
#   '가지',
#   '종류',
#   '콩나물국밥',
#   '밥',
#   '숫',
#   '가락',
#   '더니',
#   '두두',
#   '오징어젓',
#   '어요',
#   '캬',
#   '콩나물국밥',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '미미',
#   '두두',
#   '리뷰',
#   '월드'],
#  ['의정부',
#   '의정부역',
#   '날',
#   '후기',
#   '메뉴',
#   '판',
#   '및',
#   '메뉴',
#   '추천',
#   '해리포터',
#   '편',
#   '카',
#   '반의',
#   '죄수',
#   '나',
#   '그',
#   '괴물',
#   '책',
#   '메뉴',
#   '판',
#   '열',
#   '어보',
#   '메뉴',
#   '비',
#   '날',
#   '부엉이',
#   '산장',
#   '항',
#   '정수',
#   '육',
#   '보쌈김치',
#   '또',
#   '그',
#   '래서',
#   '그냥',
#   '놈'],
#  ['오덕',
#   '이의',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '오덕',
#   '쌀',
#   '오덕',
#   '이의',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '그',
#   '첫',
#   '메뉴',
#   '순두부',
#   '짬뽕밥',
#   '이예',
#   '몇',
#   '일전',
#   '까지',
#   '장마',
#   '태풍',
#   '지나',
#   '피해',
#   '기원',
#   '또',
#   '기원',
#   '장마철',
#   '더라도',
#   '비',
#   '오덕',
#   '청년'],
#  ['비',
#   '날',
#   '음식',
#   '깻잎',
#   '고추전',
#   '법',
#   '간단',
#   '점심',
#   '메뉴',
#   '깻잎전',
#   '오늘',
#   '비',
#   '날',
#   '음식',
#   '야채',
#   '전',
#   '바삭',
#   '내면',
#   '간단',
#   '점심',
#   '메뉴',
#   '로',
#   '비',
#   '날',
#   '음식',
#   '점심',
#   '메뉴',
#   '추천',
#   '깻잎',
#   '고추전',
#   '깻잎전',
#   '막걸리',
#   '안주',
#   '야채',
#   '전',
#   '간단',
#   '요리',
#   '집밥',
#   '야채',
#   '반찬',
#   '가시',
#   '장미',
#   '수다'],
#  ['대구',
#   '비',
#   '날',
#   '데이트',
#   '핸즈',
#   '커피',
#   '대구',
#   '미술관',
#   '점',
#   '메뉴',
#   '단체',
#   '석',
#   '그',
#   '외',
#   '케이크',
#   '쿠키',
#   '메뉴',
#   '비',
#   '날',
#   '이',
#   '라서',
#   '말차',
#   '어요',
#   '대구',
#   '미술관',
#   '핸즈',
#   '커피',
#   '대구',
#   '카페',
#   '추천',
#   '핸즈',
#   '커피',
#   '대구',
#   '미술관',
#   '점',
#   '센스',
#   '거',
#   '가요'],
#  ['구미',
#   '공단',
#   '동락',
#   '공원',
#   '짬뽕',
#   '맛집',
#   '만리',
#   '향',
#   '날',
#   '메뉴',
#   '추천',
#   '중국집',
#   '메',
#   '니아',
#   '친구',
#   '구미',
#   '최애라',
#   '추천',
#   '만리',
#   '향',
#   '투데이',
#   '메뉴',
#   '어요',
#   '주문',
#   '날',
#   '짬뽕',
#   '주문',
#   '시',
#   '인하',
#   '이벤트',
#   '어요',
#   '마침',
#   '비',
#   '짬뽕',
#   '호호',
#   '라이프'],
#  ['파주',
#   '조개구이',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '무한리필',
#   '고기',
#   '까지',
#   '가성',
#   '비',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '조개구이',
#   '오늘',
#   '우리동네',
#   '파주',
#   '조개구이',
#   '고기',
#   '까지',
#   '무한리필',
#   '집',
#   '비',
#   '날',
#   '시원',
#   '맥주',
#   '한잔',
#   '신선',
#   '조개구이',
#   '캬',
#   '정말',
#   '운치',
#   '사실',
#   '조개',
#   '자칫',
#   '베이비',
#   '슈',
#   '맛집',
#   '기행'],
#  ['바지락',
#   '술찜',
#   '레시피',
#   '바지락',
#   '해감',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '지난주',
#   '비',
#   '날',
#   '메뉴',
#   '바지락',
#   '술찜',
#   '소개',
#   '보',
#   '려고',
#   '국물',
#   '살짝',
#   '바지락',
#   '탕',
#   '처럼',
#   '어요',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '국물',
#   '양은',
#   '선택',
#   '조금',
#   '비자',
#   '락탕',
#   '처럼',
#   '의후다닥',
#   '레시피'],
#  ['메뉴',
#   '추천',
#   '비',
#   '날',
#   '음식',
#   '시나',
#   '비',
#   '모두',
#   '낼',
#   '수',
#   '습',
#   '닷',
#   '잔치국수',
#   '잔치국수',
#   '비',
#   '날',
#   '절대',
#   '수',
#   '가격',
#   '수',
#   '누구',
#   '아하',
#   '요',
#   '메뉴',
#   '지금',
#   '까지',
#   '에이스',
#   '대림',
#   '추천',
#   '대림',
#   '대학교',
#   '공식',
#   '블로그'],
#  ['쫄면',
#   '순두부',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '점심',
#   '겸',
#   '저녁식사',
#   '메뉴',
#   '쫄면',
#   '순두부',
#   '선택',
#   '아내',
#   '쫄면',
#   '유난',
#   '아하',
#   '저',
#   '순두부',
#   '아하',
#   '생각',
#   '김',
#   '얘',
#   '기하',
#   '통닭',
#   '아내',
#   '닭',
#   '날개',
#   '저',
#   '닭다리',
#   '시금치',
#   '미소',
#   '된장',
#   '쫄면',
#   '순두부',
#   '코리아',
#   '롱비치'],
#  ['파스타',
#   '다른',
#   '메뉴',
#   '생각',
#   '날때',
#   '날',
#   '추천',
#   '메뉴',
#   '매번',
#   '가로수길',
#   '맛집',
#   '검색',
#   '메뉴',
#   '파스타',
#   '파스타',
#   '또',
#   '파스타',
#   '브런치',
#   '메뉴',
#   '원',
#   '정말',
#   '날',
#   '추천',
#   '메뉴',
#   '오늘',
#   '메뉴',
#   '선택',
#   '개',
#   '인적',
#   '취향',
#   '하나',
#   '케잇',
#   '음식'],
#  ['평촌',
#   '롯데',
#   '백화점',
#   '맛집',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '용호동',
#   '낙지',
#   '평촌',
#   '롯데',
#   '백화점',
#   '맛집',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '용호동',
#   '낙지',
#   '오늘',
#   '룰루',
#   '도',
#   '데리',
#   '엄마',
#   '모시',
#   '평촌',
#   '롯데',
#   '백화점',
#   '맛집',
#   '용호동',
#   '낙지',
#   '집',
#   '어요',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '로',
#   '매콤',
#   '낙지전골',
#   '최고',
#   '짱',
#   '언니',
#   '여행',
#   '일기'],
#  ['요즘',
#   '처럼',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '백설',
#   '오꼬',
#   '노미',
#   '끼',
#   '믹스',
#   '요즘',
#   '처럼',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '백설',
#   '오꼬',
#   '노미',
#   '끼',
#   '믹스',
#   '언제',
#   '까지',
#   '올런',
#   '장마',
#   '계속',
#   '비',
#   '날',
#   '오코노미야키',
#   '맥주',
#   '한잔',
#   '모습',
#   '어가',
#   '재료',
#   '따라서',
#   '종류',
#   '염',
#   '이의',
#   '소',
#   '소한',
#   '일상',
#   '노트'],
#  ['비',
#   '날',
#   '데이트',
#   '삼정',
#   '타워',
#   '카페',
#   '유동',
#   '커피',
#   '메뉴',
#   '추천',
#   '제',
#   '방문',
#   '날',
#   '비',
#   '건물',
#   '안',
#   '완전',
#   '비',
#   '지도',
#   '어요',
#   '비',
#   '날',
#   '이나',
#   '여름',
#   '삼정',
#   '타워',
#   '데이트',
#   '식사',
#   '유동',
#   '커피',
#   '추천',
#   '드',
#   '오늘',
#   '우리'],
#  ['추천',
#   '상품',
#   '믹스',
#   '김치부침개',
#   '법',
#   '비',
#   '날',
#   '음식',
#   '메뉴',
#   '노',
#   '브랜드',
#   '추천',
#   '상품',
#   '믹스',
#   '김치부침개',
#   '법',
#   '추적',
#   '추적',
#   '비',
#   '날',
#   '생각',
#   '음식',
#   '밀가루',
#   '반죽',
#   '야식',
#   '이나',
#   '비',
#   '날',
#   '드',
#   '시기',
#   '음식',
#   '메뉴',
#   '김치전',
#   '노',
#   '브랜드',
#   '간편',
#   '믹스',
#   '법',
#   '소개',
#   '살림',
#   '후반전',
#   '푸드',
#   '플루'],
#  ['비',
#   '날',
#   '가기',
#   '라멘',
#   '맛집',
#   '하나비',
#   '메뉴',
#   '추천',
#   '어간',
#   '쇼유라멘',
#   '칭찬',
#   '창가',
#   '쇼유라멘',
#   '그릇',
#   '면서',
#   '비',
#   '날',
#   '먹기',
#   '메뉴',
#   '추천',
#   '추천',
#   '메뉴',
#   '외',
#   '다양',
#   '메뉴',
#   '준비',
#   '맑은',
#   '날',
#   '마제',
#   '소바',
#   '원조',
#   '하나비',
#   '공식',
#   '블로그'],
#  ['베트남',
#   '쌀국수',
#   '현지',
#   '맛집',
#   '추천',
#   '중마동',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '메뉴',
#   '나',
#   '동안',
#   '한번',
#   '어보',
#   '셔',
#   '것',
#   '포',
#   '쌀국수',
#   '비',
#   '날',
#   '곳',
#   '추천',
#   '제',
#   '최애',
#   '리스트',
#   '등',
#   '근처',
#   '방문',
#   '일',
#   '꼭꼭',
#   '꼭',
#   '보시',
#   '거',
#   '강추',
#   '드릴',
#   '요',
#   '핫또',
#   '의',
#   '핫',
#   '기록'],
#  ['장마철',
#   '비',
#   '날',
#   '초록',
#   '마을',
#   '추천',
#   '메뉴',
#   '시원',
#   '어묵탕',
#   '비',
#   '날',
#   '의',
#   '포장마차',
#   '제법',
#   '운치',
#   '포장마차',
#   '감성',
#   '비',
#   '장마철',
#   '초록',
#   '마을',
#   '추천',
#   '메뉴',
#   '로',
#   '꿀꿀',
#   '기분',
#   '보아',
#   '가장',
#   '까운',
#   '곳',
#   '친환경',
#   '라이프',
#   '친환경',
#   '유기농',
#   '브랜드',
#   '초록',
#   '마을'],
#  ['비',
#   '날',
#   '추천',
#   '음식',
#   '돼지',
#   '앞다리',
#   '살',
#   '요리',
#   '집밥',
#   '메뉴',
#   '비',
#   '날',
#   '추천',
#   '음식',
#   '얼',
#   '큰칼',
#   '칼',
#   '돼지고기',
#   '김치찌개',
#   '비',
#   '날',
#   '면서',
#   '국물',
#   '요리',
#   '집밥',
#   '메뉴',
#   '로',
#   '강추',
#   '김치찌개',
#   '하나',
#   '요리',
#   '폭풍',
#   '칭찬',
#   '신나요',
#   '집밥',
#   '꽃',
#   '선생',
#   '블로그'],
#  ['경남대',
#   '맛집',
#   '류',
#   '라멘',
#   '날',
#   '메뉴',
#   '추천',
#   '단골',
#   '오늘',
#   '멋',
#   '지게',
#   '배',
#   '창원',
#   '라멘',
#   '경남대',
#   '맛집',
#   '날',
#   '메뉴',
#   '추천',
#   '류',
#   '경남대',
#   '점',
#   '라멘',
#   '맛집',
#   '분위기',
#   '맛집',
#   '경남대',
#   '맛집',
#   '창원',
#   '라멘',
#   '마산',
#   '맛집',
#   '경남대',
#   '점',
#   '경남대',
#   '혼밥',
#   '추천',
#   '여기저기',
#   '사람'],
#  ['대구',
#   '비',
#   '날',
#   '데이트',
#   '추천',
#   '송현동',
#   '술집',
#   '투',
#   '다리',
#   '투',
#   '다리',
#   '메뉴',
#   '연휴',
#   '내내',
#   '비',
#   '데',
#   '비',
#   '날',
#   '데이트',
#   '장소',
#   '도',
#   '투',
#   '다리',
#   '학생',
#   '때',
#   '안주',
#   '저렴',
#   '어서',
#   '칵테일',
#   '맥주',
#   '봉봉',
#   '칵테일',
#   '느낌',
#   '닭',
#   '껍질',
#   '튀김',
#   '투',
#   '다리',
#   '메뉴',
#   '추천',
#   '팽이버섯',
#   '말'],
#  ['산방산',
#   '카페',
#   '날',
#   '제주',
#   '브런치',
#   '메뉴',
#   '개',
#   '디저트',
#   '개',
#   '산방산',
#   '카페',
#   '날',
#   '제주',
#   '산방산',
#   '경치',
#   '앤',
#   '제주',
#   '둘이서',
#   '브런치',
#   '메뉴',
#   '개',
#   '디저트',
#   '개',
#   '먹방',
#   '비',
#   '소식',
#   '유난',
#   '제주',
#   '여행',
#   '경치',
#   '너',
#   '무',
#   '멋',
#   '지다',
#   '방문',
#   '앤'],
#  ['비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '요',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '해',
#   '요',
#   '오늘',
#   '비',
#   '날',
#   '은',
#   '몬',
#   '음식',
#   '날인',
#   '오늘',
#   '날',
#   '저녁',
#   '메뉴',
#   '것',
#   '분',
#   '날',
#   '김치전',
#   '비롯',
#   '수제비',
#   '및',
#   '징징',
#   '징징',
#   '징'],
#  ['집밥',
#   '메뉴',
#   '추천',
#   '날',
#   '오늘',
#   '뭐',
#   '비',
#   '날',
#   '나이스',
#   '메뉴',
#   '단연',
#   '코',
#   '우동',
#   '그릇',
#   '소',
#   '소한',
#   '일',
#   '상속',
#   '감사',
#   '행복',
#   '남편',
#   '날',
#   '순',
#   '오늘',
#   '집밥',
#   '아침',
#   '우동',
#   '비',
#   '주룩주룩',
#   '아침',
#   '띠',
#   '소',
#   '소한',
#   '일상'],
#  ['수제비',
#   '법',
#   '날',
#   '메뉴',
#   '추천',
#   '수제비',
#   '법',
#   '여름',
#   '다가',
#   '수록',
#   '비',
#   '소식',
#   '비',
#   '날',
#   '이면',
#   '즐',
#   '기기',
#   '메뉴',
#   '로',
#   '수제비',
#   '수',
#   '간단',
#   '수',
#   '방법',
#   '소개',
#   '요',
#   '국물',
#   '건더기',
#   '향',
#   '요',
#   '리하',
#   '김비',
#   '버'],
#  ['날',
#   '추천',
#   '메뉴',
#   '쌀국수',
#   '마라탕',
#   '이',
#   '조합',
#   '추천',
#   '날',
#   '메뉴',
#   '무공',
#   '돈까스',
#   '꼭',
#   '저녁',
#   '귀가',
#   '돈까스',
#   '쯔양',
#   '맛집',
#   '복희',
#   '돈까스',
#   '맛집',
#   '쯔양',
#   '돈까스',
#   '무공',
#   '돈까스',
#   '무공',
#   '돈까스',
#   '공식',
#   '블로그'],
#  ['장마철',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '은',
#   '맛집',
#   '원',
#   '카츠',
#   '장마철',
#   '메뉴',
#   '추천',
#   '콤달콤',
#   '상큼',
#   '냉',
#   '모밀',
#   '기분',
#   '전환',
#   '판',
#   '모밀',
#   '카츠',
#   '첫',
#   '추천',
#   '메뉴',
#   '판',
#   '모밀',
#   '카츠',
#   '오늘',
#   '메뉴',
#   '도',
#   '성',
#   '공적',
#   '었다',
#   '우동',
#   '더',
#   '특별',
#   '우동',
#   '카레',
#   '우동',
#   '비',
#   '날',
#   '우동',
#   '원',
#   '카츠',
#   '공식',
#   '블로그'],
#  ['망우동',
#   '맛집',
#   '등촌동',
#   '샤브',
#   '칼국수',
#   '날',
#   '외식',
#   '메뉴',
#   '추천',
#   '망우동',
#   '절친',
#   '제',
#   '자주',
#   '날',
#   '실패',
#   '부림',
#   '소',
#   '개드립',
#   '매장',
#   '등촌동',
#   '샤브',
#   '칼국수',
#   '망우',
#   '본점',
#   '영업',
#   '시간',
#   '강력',
#   '추천',
#   '메뉴',
#   '버섯',
#   '칼국수',
#   '인분',
#   '소고기',
#   '사리',
#   '추가'],
#  ['비',
#   '날',
#   '점심',
#   '메뉴',
#   '중식',
#   '추천',
#   '해',
#   '비',
#   '날',
#   '고추',
#   '짬뽕',
#   '먹기',
#   '날',
#   '이기',
#   '때문',
#   '미리',
#   '주문',
#   '매장',
#   '거',
#   '언제',
#   '비',
#   '날',
#   '점심시간',
#   '배달',
#   '전화',
#   '문의',
#   '후',
#   '미리',
#   '주문',
#   '시간',
#   '수',
#   '어요',
#   '김블리',
#   '블로그'],
#  ['수원역',
#   '맛집',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '매콤',
#   '양념',
#   '돼지',
#   '막창',
#   '달달',
#   '그녀',
#   '비',
#   '날',
#   '안녕',
#   '달달',
#   '그녀',
#   '어제',
#   '휴일',
#   '월요병',
#   '대신',
#   '수요',
#   '병',
#   '날씨',
#   '무리',
#   '오늘',
#   '날',
#   '지짐',
#   '막걸리',
#   '생각',
#   '오늘',
#   '저녁',
#   '메뉴',
#   '정',
#   '달달',
#   '그녀',
#   '이야기'],
#  ['비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '황태',
#   '칼국수',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '추천',
#   '황태',
#   '칼국수',
#   '어제',
#   '부터',
#   '꽤',
#   '비',
#   '지고',
#   '어요',
#   '신',
#   '선혜',
#   '빗',
#   '소리',
#   '여러',
#   '번',
#   '잠',
#   '오늘',
#   '아침',
#   '비',
#   '때문',
#   '신랑',
#   '꼬마',
#   '걱정',
#   '가뭄',
#   '해갈',
#   '도움',
#   '만큼',
#   '맛',
#   '중심',
#   '종가',
#   '집'],
#  ['하남',
#   '미사',
#   '날',
#   '추천',
#   '메뉴',
#   '라멘',
#   '온도',
#   '요즘',
#   '비',
#   '날',
#   '면',
#   '땡기쥬',
#   '리뷰',
#   '레고',
#   '라멘',
#   '온도',
#   '헤리',
#   '움',
#   '건물',
#   '층',
#   '지하',
#   '주차장',
#   '입구',
#   '반대편',
#   '위치',
#   '어요',
#   '시',
#   '그니',
#   '처',
#   '메뉴',
#   '소개',
#   '입',
#   '간판',
#   '어가',
#   '일본',
#   '이자카야',
#   '도옹'],
#  ['안길',
#   '두산동',
#   '전복',
#   '칼국수',
#   '비',
#   '날',
#   '메뉴',
#   '로',
#   '추천',
#   '해',
#   '안길',
#   '두산동',
#   '전복',
#   '칼국수',
#   '비',
#   '날',
#   '메뉴',
#   '로',
#   '추천',
#   '해',
#   '기대',
#   '두산동',
#   '전복',
#   '칼국수',
#   '어보',
#   '어요',
#   '날씨',
#   '급',
#   '으슬한날',
#   '꼭',
#   '건강',
#   '해지',
#   '맛',
#   '기운',
#   '사이즈'],
#  ['등촌',
#   '맛집',
#   '날',
#   '메뉴',
#   '추천',
#   '솥',
#   '고집',
#   '등촌역',
#   '점',
#   '나',
#   '지고',
#   '쫄깃쫄깃',
#   '어요',
#   '뻔',
#   '솥',
# ...
#   '시간',
#   '기록'],
#  ['비',
#   '날',
#   '서면',
#   '삼정',
#   '타워',
#   '밥집',
#   '추천',
#   '한식',
#   '솥밥',
#   '여기',
#   '솥',
#   '추천',
#   '음식',
#   '아하',
#   '시',
#   '호불호',
#   '거',
#   '가족',
#   '분',
#   '외식',
#   '외식',
#   '메뉴',
#   '로',
#   '꼭',
#   '한번',
#   '보시',
#   '길',
#   '이',
#   '글',
#   '리뷰',
#   '노트',
#   '통',
#   '업체',
#   '제품',
#   '서비스',
#   '오늘',
#   '우리'],
#  ['오징어',
#   '부추전',
#   '포차',
#   '날',
#   '추천',
#   '맛집',
#   '포차',
#   '답',
#   '다양',
#   '메뉴',
#   '어요',
#   '저희',
#   '이천',
#   '소문',
#   '칼국수',
#   '고',
#   '비',
#   '오니',
#   '생각',
#   '비',
#   '날',
#   '의',
#   '힘',
#   '영',
#   '숙마',
#   '차',
#   '손맛',
#   '오징어',
#   '부',
#   '추천',
#   '완전',
#   '완전',
#   '추천',
#   '해',
#   '부추전',
#   '뿌시',
#   '칼국수',
#   '아하',
#   '것',
#   '가득'],
#  ['비',
#   '날',
#   '메뉴',
#   '추천',
#   '가성',
#   '비',
#   '갑',
#   '끈',
#   '갈비탕',
#   '워',
#   '맛',
#   '국물',
#   '숟가락',
#   '명치',
#   '오',
#   '먹이',
#   '중요시',
#   '아래',
#   '링크',
#   '네이버',
#   '톡톡',
#   '보아',
#   '갈비탕',
#   '갈비탕',
#   '비',
#   '날',
#   '자취',
#   '생',
#   '가구',
#   '추천',
#   '메뉴',
#   '파트너',
#   '스',
#   '오늘',
#   '오'],
#  ['권선동',
#   '비',
#   '날',
#   '막걸리',
#   '모듬전',
#   '전집',
#   '추천',
#   '링',
#   '고',
#   '옆',
#   '후라잌',
#   '곧',
#   '기본',
#   '찬',
#   '메뉴',
#   '판',
#   '메뉴',
#   '세트',
#   '부터',
#   '찌개',
#   '전',
#   '왜',
#   '날',
#   '더',
#   '요',
#   '핫',
#   '권선동',
#   '전',
#   '곳',
#   '고민',
#   '추천',
#   '재',
#   '방문',
#   '의사',
#   '천방지축',
#   '비숑',
#   '연두',
#   '일상'],
#  ['분당',
#   '금',
#   '맛집',
#   '추천',
#   '행',
#   '령',
#   '얼',
#   '수제비',
#   '날',
#   '수제비',
#   '맛집',
#   '수제비',
#   '날',
#   '생각',
#   '국물',
#   '수제비',
#   '칼국수',
#   '금',
#   '인기',
#   '맛집',
#   '답',
#   '주말',
#   '점심',
#   '방문',
#   '하니',
#   '웨이',
#   '팅',
#   '장난',
#   '니',
#   '맛집',
#   '인증',
#   '완료',
#   '메뉴',
#   '행',
#   '령',
#   '수제비',
#   '윤윤윤'],
#  ['비',
#   '날',
#   '메뉴',
#   '추천',
#   '파주',
#   '봉',
#   '일천',
#   '짬뽕',
#   '선경',
#   '중화요리',
#   '잇님들',
#   '안녕',
#   '흠',
#   '윰',
#   '주말',
#   '비',
#   '건',
#   '국룰',
#   '가요',
#   '왜',
#   '주말',
#   '날씨',
#   '제일',
#   '사람',
#   '날',
#   '투',
#   '두둑',
#   '빗',
#   '소리',
#   '넷플릭스',
#   '하나',
#   '배',
#   '안고',
#   '파서',
#   '저녁',
#   '안',
#   '천방지축',
#   '유미',
#   '일상'],
#  ['대구',
#   '동성로',
#   '약',
#   '전골',
#   '목',
#   '맛집',
#   '추천',
#   '소선',
#   '샤브',
#   '비',
#   '날',
#   '비',
#   '저녁',
#   '샤브샤브',
#   '비',
#   '날',
#   '국물',
#   '생각',
#   '나',
#   '거',
#   '식사',
#   '메뉴',
#   '종류',
#   '꽤',
#   '어서',
#   '조합',
#   '맛',
#   '것',
#   '비',
#   '또',
#   '다른',
#   '날',
#   '다시',
#   '방문',
#   '맛집',
#   '기록',
#   '오리'],
#  ['묵은지',
#   '닭고기',
#   '찜',
#   '국물',
#   '닭고기',
#   '김치찜',
#   '묵은지',
#   '찜',
#   '저녁',
#   '메뉴',
#   '추천',
#   '날',
#   '은',
#   '전',
#   '요리',
#   '김치',
#   '부침개',
#   '구울',
#   '다가',
#   '김치',
#   '밥',
#   '말',
#   '수',
#   '부들부들',
#   '김치',
#   '살코기',
#   '국물',
#   '까지',
#   '짐',
#   '저녁',
#   '메뉴',
#   '고요',
#   '평소',
#   '볶음',
#   '탕용',
#   '스',
#   '위트',
#   '카렌',
#   '달달',
#   '작업실'],
#  ['비',
#   '날',
#   '메뉴',
#   '칼국수',
#   '법',
#   '백합',
#   '칼국수',
#   '만들기',
#   '국물',
#   '오늘',
#   '처럼',
#   '비',
#   '날',
#   '이면',
#   '더욱',
#   '생각',
#   '메뉴',
#   '칼국수',
#   '수제비',
#   '김치전',
#   '감자전',
#   '해물파전',
#   '먹기',
#   '비',
#   '날',
#   '더욱',
#   '생각',
#   '국물',
#   '시원',
#   '끝',
#   '내주',
#   '백합',
#   '칼국수',
#   '완성',
#   '전업',
#   '주부',
#   '스펙'],
#  ['대구',
#   '포케',
#   '맛집',
#   '둔산동',
#   '포케',
#   '건강',
#   '맛집',
#   '비',
#   '날',
#   '우산',
#   '미소',
#   '행',
#   '그릇',
#   '싹싹',
#   '먹음',
#   '후문',
#   '쪽',
#   '고요',
#   '날',
#   '우산',
#   '포켑집이댜',
#   '건강',
#   '포케',
#   '맛집',
#   '포케',
#   '추천',
#   '늘',
#   '하루',
#   '소',
#   '소한',
#   '행복'],
#  ['비',
#   '가오',
#   '생각',
#   '그',
#   '메뉴',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '비',
#   '생각',
#   '그',
#   '메뉴',
#   '비',
#   '날',
#   '더',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '제',
#   '기준',
#   '정',
#   '하자',
#   '단연',
#   '김치부침개',
#   '위',
#   '내',
#   '마음속',
#   '위',
#   '테두리',
#   '살짝',
#   '바삭',
#   '진정',
#   '메르',
#   '제니'],
#  ['군자',
#   '오',
#   '사사',
#   '오뎅',
#   '바',
#   '비',
#   '날',
#   '오뎅',
#   '바',
#   '추천',
#   '군자',
#   '오',
#   '사사',
#   '오',
#   '사사',
#   '메뉴',
#   '오',
#   '사사',
#   '오뎅',
#   '오뎅',
#   '꼬치',
#   '주문',
#   '친',
#   '절하',
#   '오뎅',
#   '날씨',
#   '비',
#   '날',
#   '다시',
#   '가야',
#   '징',
#   '군자',
#   '오뎅',
#   '바',
#   '군자',
#   '오',
#   '사사',
#   '오뎅',
#   '탕',
#   '오뎅',
#   '바',
#   '추천',
#   '군자',
#   '술집',
#   '군자',
#   '타코야끼',
#   '민뎅',
#   '블로그'],
#  ['무민',
#   '랜드',
#   '제주',
#   '곳',
#   '추가',
#   '비',
#   '날',
#   '추천',
#   '생각',
#   '규모',
#   '무민',
#   '랜드',
#   '비',
#   '날',
#   '추천',
#   '제주',
#   '곳',
#   '추천',
#   '이유',
#   '팬케이크',
#   '부터',
#   '피자',
#   '파스타',
#   '등',
#   '푸드',
#   '메뉴',
#   '다양',
#   '메뉴',
#   '무민',
#   '카페',
#   '이용',
#   '시간'],
#  ['안산선',
#   '부점',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '안녕',
#   '발',
#   '도스',
#   '커피',
#   '안산선',
#   '부점',
#   '비',
#   '날',
#   '과',
#   '메뉴',
#   '추천',
#   '드립',
#   '비',
#   '도오',
#   '그',
#   '래서',
#   '니',
#   '생각',
#   '이나',
#   '비',
#   '날',
#   '은',
#   '달달',
#   '발',
#   '도스',
#   '커피',
#   '해',
#   '발',
#   '도스',
#   '커피',
#   '안산선',
#   '부점'],
#  ['호',
#   '맛집',
#   '닭',
#   '마리',
#   '비',
#   '날',
#   '저녁',
#   '메뉴',
#   '로',
#   '친구',
#   '양',
#   '추천',
#   '닭',
#   '마리',
#   '고고씽',
#   '천호동',
#   '쭈꾸미',
#   '골목',
#   '어서',
#   '독도',
#   '쭈꾸미',
#   '호점',
#   '옆',
#   '바로',
#   '보',
#   '여요',
#   '메뉴',
#   '닭',
#   '칼국수',
#   '사리',
#   '또',
#   '메뉴',
#   '만',
#   '곳',
#   '진국',
#   '니',
#   '어요',
#   '초록',
#   '기린',
#   '숲',
#   '프'],
#  ['유강',
#   '맛집',
#   '날',
#   '파전',
#   '막걸리',
#   '유강',
#   '파전',
#   '포장',
#   '주문',
#   '시',
#   '미리',
#   '주문',
#   '방문',
#   '것',
#   '추천',
#   '매장',
#   '친절',
#   '하진',
#   '파전',
#   '육전',
#   '곳',
#   '약간',
#   '츤데레',
#   '개',
#   '인적',
#   '견해',
#   '오해',
#   '금지',
#   '날',
#   '은',
#   '역시',
#   '전이',
#   '부침개',
#   '만',
#   '게',
#   '송모다',
#   '리뷰',
#   '로그'],
#  ['날',
#   '의',
#   '메뉴',
#   '수제비',
#   '고기',
#   '완자전',
#   '이집',
#   '행신동',
#   '행신동',
#   '맛집',
#   '이집',
#   '수제비',
#   '수제비',
#   '맛집',
#   '고기',
#   '완자전',
#   '맛집',
#   '수제비',
#   '고기',
#   '완자전',
#   '행신동',
#   '점심',
#   '메뉴',
#   '행신동',
#   '맛집',
#   '행신동',
#   '추천',
#   '이집',
#   '칼제비',
#   '수제비',
#   '비',
#   '날',
#   '메뉴',
#   '솔직',
#   '리뷰'],
#  ['칼국수',
#   '맛집',
#   '왕만',
#   '맛집',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '남촌',
#   '칼국수',
#   '최애',
#   '메뉴',
#   '칼국수',
#   '여서',
#   '포스팅',
#   '처음',
#   '달',
#   '몇번',
#   '씩',
#   '꼭',
#   '거',
#   '바로',
#   '보이',
#   '홀',
#   '식탁',
#   '테이블',
#   '안쪽',
#   '더',
#   '어가',
#   '좌',
#   '룸',
#   '어요',
#   '룸',
#   '이름',
#   '랍',
#   '스타',
#   '우당'],
#  ['삿포로',
#   '후',
#   '노',
#   '비',
#   '에이',
#   '비',
#   '날',
#   '버스',
#   '투어',
#   '추천',
#   '훗카이도',
#   '랩',
#   '메뉴',
#   '나',
#   '우유',
#   '진짜',
#   '어요',
#   '별도',
#   '포스팅',
#   '려고',
#   '해',
#   '사계',
#   '채',
#   '언덕',
#   '가장',
#   '먼저',
#   '방문',
#   '곳',
#   '사계',
#   '채',
#   '언덕',
#   '어요',
#   '이',
#   '날',
#   '날씨',
#   '비',
#   '조금',
#   '본래',
#   '투어',
#   '일정',
#   '약간',
#   '어른',
#   '성장',
#   '일지'],
#  ['비',
#   '날',
#   '막걸리',
#   '맛집',
#   '미사',
#   '술집',
#   '금복주',
#   '류',
#   '미사',
#   '술집',
#   '금복주',
#   '류',
#   '맛',
#   '막걸리',
#   '파전',
#   '날',
#   '찾기',
#   '주점',
#   '안녕',
#   '잇님들',
#   '오늘',
#   '직원',
#   '분',
#   '호출',
#   '태블릿',
#   '금복주',
#   '류',
#   '메뉴',
#   '추천',
#   '금복주',
#   '류',
#   '메뉴',
#   '를',
#   '간단',
#   '일단',
#   '매르',
#   '리뷰',
#   '월드'],
#  ['양주',
#   '카페',
#   '추천',
#   '비',
#   '날',
#   '도',
#   '양주',
#   '통창',
#   '카페',
#   '브루',
#   '양주',
#   '날',
#   '비',
#   '데',
#   '어디',
#   '카페',
#   '가지',
#   '다가',
#   '브루',
#   '양주',
#   '발견',
#   '통창',
#   '때문',
#   '트',
#   '여보',
#   '양주',
#   '카페',
#   '장흥',
#   '카페',
#   '양주',
#   '브루',
#   '카페',
#   '양주',
#   '카페',
#   '추천',
#   '양주',
#   '카페',
#   '양주',
#   '비',
#   '날',
#   '카페',
#   '루루',
#   '박사'],
#  ['카페',
#   '거리',
#   '닭발',
#   '구역',
#   '포장',
#   '후기',
#   '비',
#   '날',
#   '막걸리',
#   '추천',
#   '메뉴',
#   '담',
#   '또',
#   '예정',
#   '용인',
#   '닭발',
#   '닭발',
#   '구역',
#   '카페',
#   '거리',
#   '카페',
#   '거리',
#   '맛집',
#   '맛집',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '닭발',
#   '닭발',
#   '조합',
#   '닭발',
#   '막걸리',
#   '닭발',
#   '소주',
#   '마을',
#   '막걸리',
#   '한라산',
#   '도',
#   '린지',
#   '여행',
#   '과일',
#   '상'],
#  ['길음동',
#   '맛집',
#   '두메',
#   '골',
#   '마늘',
#   '보쌈',
#   '칼국수',
#   '까지',
#   '비',
#   '날',
#   '찰떡',
#   '메뉴',
#   '삼양',
#   '사거리역',
#   '맛집',
#   '길음동',
#   '맛집',
#   '미아',
#   '맛집',
#   '두메',
#   '골',
#   '두메',
#   '골',
#   '마늘',
#   '보쌈',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '어제',
#   '비도',
#   '메뉴',
#   '완전',
#   '비',
#   '날',
#   '찰떡',
#   '었다',
#   '테이블',
#   '만석',
#   '어르신',
#   '막걸리',
#   '한잔',
#   '나',
#   '김만',
#   '조잉'],
#  ['부산',
#   '자갈치',
#   '꼼장어',
#   '대방역',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '꼬들꼬들',
#   '오래',
#   '고로',
#   '때',
#   '누룽지',
#   '주시',
#   '닭발',
#   '수가',
#   '배부',
#   '름',
#   '꼼장어',
#   '비',
#   '날',
#   '생각',
#   '메뉴',
#   '다음',
#   '비',
#   '날',
#   '한번',
#   '더',
#   '셰일',
#   '의',
#   '생활'],
#  ['퓨전',
#   '짬뽕',
#   '맛집',
#   '뽕',
#   '신인',
#   '더',
#   '가든',
#   '호점',
#   '날',
#   '점심',
#   '메뉴',
#   '초이스',
#   '점원',
#   '테이크아웃',
#   '해달',
#   '뻔',
#   '날',
#   '국물',
#   '날',
#   '특별',
#   '부담',
#   '맛',
#   '거',
#   '때',
#   '천호동',
#   '맛집',
#   '뽕',
#   '신인',
#   '더',
#   '가든',
#   '추천',
#   '해',
#   '여기',
#   '까지',
#   '쾡쾡'],
#  ['김치전',
#   '만들기',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '주말',
#   '메뉴',
#   '김치전',
#   '만들기',
#   '비',
#   '날',
#   '메뉴',
#   '추천',
#   '주말',
#   '메뉴',
#   '오늘',
#   '일요일',
#   '하루',
#   '종일',
#   '봄비',
#   '비',
#   '날',
#   '은',
#   '부침개',
#   '진리',
#   '냉장고',
#   '묵은지',
#   '해물',
#   '좀',
#   '어서',
#   '바로',
#   '김치전',
#   '어요',
#   '써니',
#   '쿡',
#   '힐링',
#   '푸드',
#   '스토리'],
#  ['제주도',
#   '비',
#   '날',
#   '곳',
#   '오설록티뮤지엄',
#   '제주도',
#   '비',
#   '날',
#   '가기',
#   '카페나',
#   '장소',
#   '아가',
#   '그',
#   '분위기',
#   '제주도',
#   '여행',
#   '넷째',
#   '날',
#   '코스',
#   '제주',
#   '오설록티뮤지엄',
#   '신라',
#   '더',
#   '파크',
#   '뷰',
#   '뷔페',
#   '롯데',
#   '아트',
#   '빌라',
#   '스',
#   '체크',
#   '호텔',
#   '수영',
#   '포도',
#   '호텔',
#   '인생',
#   '여행',
#   '처럼'],
#  ['바삭',
#   '법',
#   '밀가루',
#   '부침개',
#   '간장',
#   '소스',
#   '비',
#   '날',
#   '음식',
#   '메뉴',
#   '글',
#   '사진',
#   '푸드',
#   '쿡',
#   '김치',
#   '부침개',
#   '바삭',
#   '법',
#   '밀가루',
#   '부침개',
#   '간장',
#   '소스',
#   '비',
#   '날',
#   '음심',
#   '메뉴',
#   '비데',
#   '빗',
#   '소리',
#   '소리',
#   '부침개',
#   '생각',
#   '이나',
#   '부지런',
#   '간식',
#   '요리',
#   '로',
#   '한장',
#   '푸드',
#   '쿡',
#   '맛집',
#   '여행'],
#  ['비',
#   '날',
#   '추천',
#   '메뉴',
#   '화순',
#   '능주',
#   '삼거리',
#   '식당',
#   '소머리국밥',
#   '단골',
#   '식당',
#   '메뉴',
#   '가격',
#   '다른',
#   '곳',
#   '차이',
#   '어요',
#   '쟁반',
#   '온',
#   '소머리국밥',
#   '침',
#   '제',
#   '추',
#   '천하',
#   '국밥',
#   '법',
#   '이지',
#   '화순',
#   '능주',
#   '가시',
#   '분',
#   '곳',
#   '국밥',
#   '비',
#   '날',
#   '추천',
#   '메뉴',
#   '밤',
#   '농',
#   '부들',
#   '밤농',
#   '프리',
#   '마켓',
#   '안전',
#   '농산물'],
#  ['날',
#   '아침',
#   '공덕',
#   '아이엠',
#   '베이글',
#   '전',
#   '메뉴',
#   '가격',
#   '무료',
#   '러스크',
#   '날',
#   '창가',
#   '등장',
#   '손',
#   '사진',
#   '찍기',
#   '대기',
#   '여전',
#   '다소곳',
#   '베이글',
#   '이번',
#   '달',
#   '가지',
#   '동안',
#   '메뉴',
#   '도',
#   '보고',
#   '시간',
#   '비도',
#   '인지',
#   '매장',
#   '오랜만',
#   '여유',
#   '어서',
#   '소',
#   '소한',
#   '일상'],
#  ['사월역',
#   '카페',
#   '날',
#   '도',
#   '켑트',
#   '베이커',
#   '스',
#   '친',
#   '구들',
#   '저번',
#   '부터',
#   '유명',
#   '베이커리',
#   '카페',
#   '추천',
#   '면서',
#   '가보',
#   '자고',
#   '비',
#   '날',
#   '은',
#   '역시',
#   '커피',
#   '비',
#   '구',
#   '경하',
#   '면서',
#   '라떼',
#   '한잔',
#   '해주',
#   '감성',
#   '막',
#   '현명',
#   '경제',
#   '이야기'],
#  ['서울',
#   '비',
#   '날',
#   '곳',
#   '잠실',
#   '브런치',
#   '집',
#   '추천',
#   '중',
#   '메뉴',
#   '건',
#   '었는데',
#   '번',
#   '보고',
#   '곳',
#   '택했다',
#   '세상',
#   '모든',
#   '아침',
#   '롯데',
#   '월드',
#   '서울',
#   '비',
#   '날',
#   '만',
#   '곳',
#   '곳',
#   '도도',
#   '역시',
#   '날',
#   '비',
#   '옴짝',
#   '달싹',
#   '못',
#   '날',
#   '맛집',
#   '여행',
#   '일상',
#   '기록',
#   '도도',
#   '블로그'],
#  ['칼국수',
#   '밀키',
#   '트',
#   '추천',
#   '진지',
#   '알곤',
#   '칼국수',
#   '날',
#   '시원',
#   '알곤',
#   '칼국수',
#   '계란',
#   '솔솔',
#   '풀',
#   '청양고추',
#   '살짝',
#   '박아',
#   '날',
#   '캬',
#   '임창정',
#   '오라버니',
#   '시',
#   '그니',
#   '처',
#   '메뉴',
#   '인',
#   '알곤',
#   '칼국수',
#   '집',
#   '밀',
#   '키트',
#   '수',
#   '제품',
#   '캬',
#   '우리',
#   '김쉐프',
#   '님',
#   '완성',
#   '작품',
#   '다섯',
#   '개',
#   '별'],
#  ['가산',
#   '디지털',
#   '맛집',
#   '달빛',
#   '주막',
#   '막걸리',
#   '모듬',
#   '전',
#   '날',
#   '추천',
#   '이번',
#   '달빛',
#   '주막',
#   '생각',
#   '어요',
#   '거의',
#   '더니',
#   '사람',
#   '별로',
#   '어서',
#   '어요',
#   '전류',
#   '메뉴',
#   '날',
#   '여기',
#   '난리',
#   '회식',
#   '이나',
#   '모임',
#   '장소',
#   '도',
#   '아보',
#   '이구',
#   '차로',
#   '추천'],
#  ['비',
#   '날',
#   '아이',
#   '곳',
#   '이케아',
#   '데이트',
#   '어린이',
#   '장난감',
#   '추천',
#   '비',
#   '날',
#   '아이',
#   '곳',
#   '이케아',
#   '데이트',
#   '어린이',
#   '장난감',
#   '추천',
#   '딸',
#   '주말',
#   '삼송역',
#   '데이트',
#   '김치볶음밥',
#   '어린이',
#   '메뉴',
#   '볼',
#   '개',
#   '초코',
#   '빵',
#   '개',
#   '주문',
#   '어요',
#   '엄마',
#   '단둘',
#   '행복',
#   '어린이',
#   '애'],
#  ['가포',
#   '카페',
#   '어요',
#   '날',
#   '더',
#   '추천',
#   '산후',
#   '기',
#   '기록',
#   '날',
#   '것',
#   '진짜',
#   '고요',
#   '주차',
#   '매장',
#   '가기',
#   '까지',
#   '우산',
#   '이',
#   '동하',
#   '것',
#   '완벽',
#   '어요',
#   '비',
#   '거',
#   '안',
#   '아함',
#   '메르',
#   '칼므',
#   '분위기',
#   '데이트',
#   '장소',
#   '도',
#   '추천',
#   '집',
#   '수빈',
#   '탈출',
#   '기록'],
#  ['경기도',
#   '실내',
#   '데이트',
#   '카페',
#   '눈',
#   '날',
#   '비',
#   '날',
#   '데이트',
#   '추천',
#   '눈',
#   '날',
#   '비',
#   '날',
#   '데이트',
#   '추천',
#   '카페',
#   '경기도',
#   '실내',
#   '데이트',
#   '추천',
#   '서울',
#   '근교',
#   '경기도',
#   '눈',
#   '날',
#   '이나',
#   '음료',
#   '베이커리',
#   '이용',
#   '시',
#   '시간',
#   '이용',
#   '시간',
#   '제한',
#   '어서',
#   '두',
#   '세시',
#   '간',
#   '분',
#   '브런치',
#   '메뉴',
#   '유',
#   '징유'],
#  ['날',
#   '연탄구이',
#   '집',
#   '소금',
#   '구이',
#   '메뉴',
#   '를',
#   '추천',
#   '날',
#   '추천',
#   '메뉴',
#   '로',
#   '근처',
#   '연탄구이',
#   '집',
#   '소금',
#   '구이',
#   '고기',
#   '집',
#   '가면',
#   '고기',
#   '별로',
#   '비',
#   '날',
#   '점심',
#   '이나',
#   '저녁',
#   '메뉴',
#   '로',
#   '연탄구이',
#   '정감',
#   '요즘',
#   '뉴스',
#   '비',
#   '피해',
#   '요',
#   '골목'],
#  ['사용',
#   '표선',
#   '닭',
#   '해장국',
#   '위치',
#   '및',
#   '운영',
#   '시간',
#   '날',
#   '추천',
#   '메뉴',
#   '비',
#   '덕분',
#   '식사',
#   '수',
#   '어요',
#   '메뉴',
#   '가격표',
#   '요렇습니',
#   '요즘',
#   '끼',
#   '천원',
#   '만',
#   '원',
#   '곳도',
#   '제주',
#   '산',
#   '닭고기',
#   '매일',
#   '우려',
#   '육수',
#   '이',
#   '정도',
#   '가격',
#   '이면',
#   '적',
#   '당하',
#   '유',
#   '여행',
#   '쩨',
#   '씨몽키'],
#  ['가평',
#   '글램핑',
#   '하늘',
#   '숲',
#   '캠핑장',
#   '비',
#   '날',
#   '단체',
#   '글램핑',
#   '추천',
#   '장어',
#   '가평',
#   '글램핑',
#   '하늘',
#   '숲',
#   '캠핑장',
#   '비',
#   '날',
#   '단체',
#   '글램핑',
#   '추천',
#   '장어',
#   '비',
#   '날',
#   '캠핑',
#   '신가',
#   '오늘',
#   '메인',
#   '메뉴',
#   '장어구이',
#   '캠핑장',
#   '장어',
#   '생각',
#   '고요',
#   '배부',
#   '르',
#   '보드게임',
#   '아빠',
#   '만세'],
#  ['가평',
#   '아기',
#   '곳',
#   '비',
#   '날',
#   '박',
#   '가평',
#   '비',
#   '날',
#   '아기',
#   '박',
#   '코스',
#   '카페',
#   '어텐디드',
#   '가든',
#   '카페',
#   '가평',
#   '키즈',
#   '풀',
#   '빌라',
#   '언덕',
#   '마루',
#   '가평',
#   '잣',
#   '어텐디드',
#   '가든',
#   '카페',
#   '추천',
#   '소금',
#   '빵',
#   '정말',
#   '시간',
#   '운전',
#   '하니',
#   '하니'],
#  ['망원',
#   '성산동',
#   '맛집',
#   '호호',
#   '라멘',
#   '날',
#   '추천',
#   '메뉴',
#   '망원',
#   '메뉴',
#   '내',
#   '언니',
#   '시선',
#   '카와이',
#   '우리',
#   '메뉴',
#   '카라',
#   '이돈',
#   '코츠',
#   '매콤',
#   '맛',
#   '맛',
#   '흰밥',
#   '교자',
#   '주문',
#   '키오',
#   '스크',
#   '발견',
#   '버',
#   '리뷰',
#   '작성',
#   '가게'],
#  ['비',
#   '날',
#   '막걸리',
#   '안주',
#   '바삭',
#   '고소',
#   '현',
#   '동래',
#   '허파',
#   '전',
#   '추천',
#   '비',
#   '날',
#   '메뉴',
#   '중',
#   '하나',
#   '파전',
#   '이제',
#   '현',
#   '동래',
#   '허파',
#   '전',
#   '생각',
#   '먼저',
#   '날',
#   '거',
#   '우삼겹',
#   '이나',
#   '새우',
#   '어서',
#   '식감',
#   '이나',
#   '더',
#   '것',
#   '거',
#   '파전',
#   '어보',
#   '와이프',
#   '캠핑',
#   '쭈니'],
#  ['힙한곳',
#   '비',
#   '날',
#   '분위기',
#   '곳',
#   '안주',
#   '메뉴',
#   '전',
#   '막걸리',
#   '전통주',
#   '오늘',
#   '처럼',
#   '비',
#   '날',
#   '생각',
#   '메뉴',
#   '대한민국',
#   '사람',
#   '면',
#   '파전',
#   '막걸리',
#   '생각',
#   '비',
#   '날',
#   '퇴근길',
#   '곳',
#   '곰',
#   '노량진',
#   '본점',
#   '주소',
#   '서울시',
#   '동작구',
#   '만양',
#   '길',
#   '영업',
#   '시간',
#   '일',
#   '목',
#   '안나',
#   '맛집',
#   '투어'],
#  ['경기도',
#   '비',
#   '날',
#   '아이',
#   '맛집',
#   '곳',
#   '추천',
#   '주차',
#   '메뉴',
#   '가격',
#   '정보',
#   '포함',
#   '메이트',
#   '버거',
#   '모든',
#   '메뉴',
#   '커피',
#   '별로',
#   '어요',
#   '음료',
#   '것',
#   '추천',
#   '우육',
#   '샤오롱바오',
#   '가지',
#   '만두',
#   '바로',
#   '브룩스',
#   '쥬',
#   '맛집',
#   '샤오바',
#   '현지',
#   '맛',
#   '이면',
#   '서도',
#   '한국인',
#   '오후',
#   '정원'],
#  ['요',
#   '리하',
#   '마술사',
#   '서울',
#   '날',
#   '아이',
#   '대학로',
#   '공연',
#   '추천',
#   '햄버거',
#   '마술',
#   '요',
#   '리하',
#   '마술사',
#   '다양',
#   '메뉴',
#   '등',
#   '장하',
#   '햄버거',
#   '안',
#   '내용물',
#   '중',
#   '가장',
#   '중요',
#   '여름방학',
#   '다가',
#   '데',
#   '날',
#   '서울',
#   '아이',
#   '곳',
#   '대학로',
#   '공연',
#   '요',
#   '리하',
#   '마술사',
#   '추천',
#   '두',
#   '화성',
#   '온',
#   '여자',
#   '여섯',
#   '쩡'],
#  ['비',
#   '날',
#   '분위기',
#   '밀양',
#   '옥',
#   '느낌',
#   '카페',
#   '추천',
#   '때',
#   '메뉴',
#   '판',
#   '방문',
#   '때',
#   '메뉴',
#   '판',
#   '메뉴',
#   '더',
#   '어요',
#   '디저트',
#   '준비',
#   '어요',
#   '치즈케이크',
#   '추천',
#   '날',
#   '운치',
#   '더',
#   '나',
#   '당근',
#   '주황'],
#  ['봉천',
#   '점',
#   '선선',
#   '하니',
#   '비',
#   '날',
#   '추천',
#   '곳',
#   '메뉴',
#   '추천',
#   '다양',
#   '비',
#   '날',
#   '먹기',
#   '곳',
#   '참고',
#   '매장',
#   '안이',
#   '막',
#   '느낌',
#   '니니',
#   '평소',
#   '포차',
#   '느낌',
#   '아하',
#   '분',
#   '추천',
#   '서울',
#   '전집',
#   '탑',
#   '바로',
#   '곳',
#   '은',
#   '일상'],
#  ['비',
#   '날',
#   '더',
#   '생각',
#   '맛집',
#   '충북',
#   '혁신도시',
#   '쌈',
#   '국수',
#   '메뉴',
#   '추천',
#   '비',
#   '날',
#   '더',
#   '생각',
#   '맛집',
#   '충북',
#   '혁신도시',
#   '쌈',
#   '국수',
#   '올해',
#   '정말',
#   '비',
#   '것',
#   '오늘',
#   '폭우',
#   '처럼',
#   '아지',
#   '날',
#   '차도',
#   '대신',
#   '난',
#   '실내',
#   '무',
#   '비',
#   '오니',
#   '생각'],
#  ['일산',
#   '본점',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '날',
#   '저녁',
#   '메뉴',
#   '로',
#   '추천',
#   '해',
#   '안녕',
#   '행복',
#   '여행',
#   '나눔',
#   '토요일',
#   '주말',
#   '계',
#   '신가',
#   '오후',
#   '부터',
#   '어진',
#   '비',
#   '상쾌',
#   '함',
#   '덤',
#   '오늘',
#   '고양',
#   '일산',
#   '등촌',
#   '샤브',
#   '칼국수',
#   '일산',
#   '본점',
#   '후기',
#   '고자',
#   '행복',
#   '여행',
#   '나눔'],
#  ['수원',
#   '행궁동',
#   '놀',
#   '거리',
#   '볼거리',
#   '데이트',
#   '추천',
#   '비',
#   '날',
#   '추천',
#   '장소',
#   '고합',
#   '비',
#   '날',
#   '의',
#   '행궁동',
#   '모습',
#   '일지',
#   '방화',
#   '수류',
#   '정',
#   '비',
#   '비',
#   '구름',
#   '바',
#   '라보',
#   '은근',
#   '비',
#   '호수',
#   '풍경',
#   '꿈',
#   '일상',
#   '이야기',
#   '몽상가'],
#  ['스프',
#   '카레',
#   '울',
#   '때',
#   '강남역',
#   '맛집',
#   '히쿠마',
#   '날',
#   '히쿠마',
#   '추천',
#   '메뉴',
#   '비교',
#   '치킨',
#   '토마토',
#   '스프',
#   '커리',
#   '치킨',
#   '스프',
#   '커리',
#   '닭다리',
#   '하나',
#   '통째',
#   '어간',
#   '치킨',
#   '강남역',
#   '맛집',
#   '때',
#   '국물',
#   '날',
#   '히쿠마',
#   '번',
#   '보시',
#   '길',
#   '히쿠마',
#   '전체',
#   '메뉴',
#   '프로',
#   '덕질'],
#  ['우리동네',
#   '맛집',
#   '원',
#   '국수',
#   '비',
#   '날',
#   '오픈',
#   '런',
#   '거의',
#   '매일',
#   '비',
#   '장마',
#   '기간',
#   '멀리',
#   '외식',
#   '가기',
#   '주방',
#   '불앞',
#   '비',
#   '날',
#   '오픈',
#   '런',
#   '와중',
#   '손님',
#   '오시',
#   '는걸',
#   '손님',
#   '분',
#   '사랑',
#   '맛집',
#   '국수',
#   '항동',
#   '부동산',
#   '중개',
#   '맛집',
#   '우남',
#   '부동산']]

# %%
#본문 마다 단어와 갯수 구하기 

for i in range(0,len(an)) :
    count = Counter(an[i])
    
    an[i] = count.most_common()

# %%
an
# Out:
# [[('추천', 4),
#   ('날', 3),
#   ('메뉴', 3),
#   ('칼국수', 2),
#   ('비', 2),
#   ('하루', 2),
#   ('오산', 1),
#   ('맛집', 1),
#   ('등촌', 1),
#   ('샤브', 1),
#   ('진짜', 1),
#   ('이건', 1),
#   ('다음', 1),
#   ('살짝', 1),
#   ('배', 1),
#   ('직장인', 1),
#   ('워킹맘', 1),
#   ('음식', 1),
#   ('동그라미', 1)],
#  [('라멘', 4),
#   ('추천', 3),
#   ('욘주', 2),
#   ('맛집', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('차슈', 2),
#   ('여전', 1),
#   ('일본', 1),
#   ('꼭', 1),
#   ('사이드', 1),
#   ('맛보기', 1),
#   ('어간', 1),
#   ('짐', 1),
#   ('더', 1),
#   ('원한', 1),
#   ('면', 1),
#   ('장', 1),
#   ('추가', 1),
#   ('수', 1),
#   ('어요', 1),
#   ('울산', 1),
#   ('성남동', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('생각', 1),
#   ('나', 1),
#   ('오늘', 1),
#   ('만사', 1),
#   ('형통', 1),
#   ('블로그', 1)],
#  [('메뉴', 4),
#   ('날', 3),
#   ('바다', 2),
#   ('수퍼', 2),
#   ('물', 2),
#   ('천하', 2),
#   ('조개구이', 2),
#   ('강남역', 2),
#   ('추천', 2),
#   ('나', 2),
#   ('비', 2),
#   ('점', 1),
#   ('메인', 1),
#   ('오기', 1),
#   ('전', 1),
#   ('양은', 1),
#   ('냄비', 1),
#   ('여준', 1),
#   ('에피타이저', 1),
#   ('떡볶이', 1),
#   ('게', 1),
#   ('신상식', 1),
#   ('당', 1),
#   ('쥬니', 1),
#   ('뮹', 1),
#   ('기록', 1)],
#  [('날', 2),
#   ('하루', 2),
#   ('기름', 2),
#   ('점심', 1),
#   ('메뉴', 1),
#   ('추천', 1),
#   ('온센', 1),
#   ('광명', 1),
#   ('점', 1),
#   ('텐동', 1),
#   ('식감', 1),
#   ('비', 1),
#   ('등원', 1),
#   ('길', 1),
#   ('아침', 1),
#   ('부터', 1),
#   ('문', 1),
#   ('연', 1),
#   ('전집', 1),
#   ('냄새', 1),
#   ('식욕', 1),
#   ('시작', 1),
#   ('다이어터', 1),
#   ('마제', 1),
#   ('우동', 1),
#   ('양념', 1),
#   ('밥', 1),
#   ('어도', 1),
#   ('진', 1),
#   ('거', 1),
#   ('때', 1),
#   ('전보', 1),
#   ('푸딩', 1),
#   ('육아', 1),
#   ('탐구생활', 1)],
#  [('전', 5),
#   ('저녁', 3),
#   ('메뉴', 3),
#   ('부침개', 3),
#   ('야채', 3),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('김치전', 2),
#   ('두릅', 2),
#   ('오늘', 2),
#   ('바삭', 1),
#   ('법', 1),
#   ('파전', 1),
#   ('모듬전', 1),
#   ('불닭볶음면', 1),
#   ('비도', 1),
#   ('이번', 1),
#   ('주', 1),
#   ('금요일', 1),
#   ('일요일', 1),
#   ('까지', 1),
#   ('계획', 1),
#   ('여수', 1),
#   ('여행', 1),
#   ('소진', 1),
#   ('위해', 1),
#   ('소', 1),
#   ('소한', 1)],
#  [('비', 3),
#   ('일본', 3),
#   ('솔솥', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('입구', 2),
#   ('골목', 2),
#   ('수원', 1),
#   ('행궁', 1),
#   ('행궁동', 1),
#   ('한식', 1),
#   ('돌솥밥', 1),
#   ('요즘', 1),
#   ('처럼', 1),
#   ('점심', 1),
#   ('행궁점', 1),
#   ('후기', 1),
#   ('간판', 1),
#   ('온', 1),
#   ('느낌', 1),
#   ('오니', 1),
#   ('더', 1),
#   ('너낌있돠', 1),
#   ('뱅', 1),
#   ('기타', 1),
#   ('해신', 1),
#   ('비츠로', 1),
#   ('캠핑카', 1),
#   ('반', 1)],
#  [('비', 3),
#   ('날', 3),
#   ('카페', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('케이크', 2),
#   ('힐링', 2),
#   ('거', 2),
#   ('여행', 2),
#   ('안도', 1),
#   ('르', 1),
#   ('송', 1),
#   ('당무', 1),
#   ('끈', 1),
#   ('모루', 1),
#   ('포토', 1),
#   ('존', 1),
#   ('핫', 1),
#   ('를', 1),
#   ('한라산', 1),
#   ('좀', 1),
#   ('녹차', 1),
#   ('맛', 1),
#   ('어서', 1),
#   ('조화', 1),
#   ('경치', 1),
#   ('수', 1),
#   ('제주', 1),
#   ('중', 1),
#   ('아이', 1),
#   ('국내', 1),
#   ('해외', 1)],
#  [('수제비', 5),
#   ('감자', 3),
#   ('비', 3),
#   ('날', 3),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('레시피', 1),
#   ('반죽', 1),
#   ('요리', 1),
#   ('왜', 1),
#   ('칼국수', 1),
#   ('저녁', 1),
#   ('도록', 1),
#   ('이면', 1),
#   ('밀가루', 1),
#   ('려고', 1),
#   ('요런', 1),
#   ('느낌', 1),
#   ('슈슈냥', 1),
#   ('그릇', 1),
#   ('뚝딱', 1)],
#  [('감자', 6),
#   ('야식', 5),
#   ('메뉴', 4),
#   ('법', 3),
#   ('추천', 3),
#   ('만들기', 2),
#   ('비', 2),
#   ('날', 2),
#   ('간식', 2),
#   ('요리', 2),
#   ('아이', 1),
#   ('다음', 1),
#   ('또', 1),
#   ('다른', 1),
#   ('채', 1),
#   ('전만', 1),
#   ('쏭스', 1),
#   ('라이프', 1),
#   ('푸드', 1),
#   ('스토리', 1)],
#  [('날', 5),
#   ('이케아', 4),
#   ('데이트', 4),
#   ('비', 3),
#   ('광명', 2),
#   ('추천', 2),
#   ('실내', 2),
#   ('추적', 2),
#   ('거리', 2),
#   ('레스토랑', 1),
#   ('메뉴', 1),
#   ('데', 1),
#   ('고', 1),
#   ('민하', 1),
#   ('다가', 1),
#   ('스타', 1),
#   ('필드', 1),
#   ('양', 1),
#   ('놀', 1),
#   ('서이추', 1),
#   ('애나', 1),
#   ('부탁', 1)],
#  [('영통', 4),
#   ('수원', 3),
#   ('날', 3),
#   ('목구멍', 2),
#   ('점', 2),
#   ('고기', 2),
#   ('집', 2),
#   ('맛집', 1),
#   ('메뉴', 1),
#   ('로', 1),
#   ('추천', 1),
#   ('해', 1),
#   ('역시', 1),
#   ('사람', 1),
#   ('이번', 1),
#   ('어요', 1),
#   ('정말', 1),
#   ('더', 1),
#   ('것', 1),
#   ('기도', 1),
#   ('수', 1),
#   ('원목', 1),
#   ('살맛', 1),
#   ('직접', 1),
#   ('후기', 1),
#   ('시', 1),
#   ('작', 1),
#   ('하루', 1),
#   ('종일', 1),
#   ('년', 1)],
#  [('잔치국수', 5),
#   ('저녁', 4),
#   ('메뉴', 4),
#   ('만들기', 4),
#   ('간단', 3),
#   ('추천', 3),
#   ('비', 2),
#   ('날', 2),
#   ('고명', 2),
#   ('가득', 2),
#   ('그릇', 2),
#   ('국수', 1),
#   ('뚝딱', 1),
#   ('말', 1),
#   ('요', 1),
#   ('음식', 1),
#   ('레시피', 1),
#   ('소면', 1),
#   ('삶', 1),
#   ('때', 1),
#   ('안녕', 1),
#   ('다정', 1),
#   ('순둥', 1),
#   ('작가', 1)],
#  [('날', 3),
#   ('비', 2),
#   ('메뉴', 2),
#   ('울산', 2),
#   ('명촌', 2),
#   ('맛집', 2),
#   ('돗', 2),
#   ('가비', 2),
#   ('불쭈', 2),
#   ('철판', 2),
#   ('볶음', 2),
#   ('들깨', 2),
#   ('수제비', 2),
#   ('땡', 2),
#   ('기고', 2),
#   ('추천', 1),
#   ('생각', 1),
#   ('봄비', 1),
#   ('부슬부슬', 1),
#   ('매콤', 1),
#   ('것', 1),
#   ('끈', 1),
#   ('국물', 1),
#   ('때', 1),
#   ('불', 1),
#   ('쭈꾸미', 1),
#   ('맛', 1),
#   ('보고', 1),
#   ('욕심', 1),
#   ('손', 1),
#   ('사장', 1)],
#  [('칼국수', 5),
#   ('육수', 4),
#   ('굴', 3),
#   ('법', 3),
#   ('조개', 2),
#   ('비', 2),
#   ('날', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('가리비', 2),
#   ('배추', 2),
#   ('해물칼국수', 1),
#   ('재료', 1),
#   ('해물', 1),
#   ('새우', 1),
#   ('적당', 1),
#   ('멸치', 1),
#   ('야채', 1),
#   ('쌈', 1),
#   ('알', 1),
#   ('대파', 1),
#   ('청양고추', 1),
#   ('행주치마', 1),
#   ('정겨운', 1),
#   ('집밥', 1)],
#  [('메뉴', 3),
#   ('추천', 2),
#   ('군', 2),
#   ('카페', 2),
#   ('날', 2),
#   ('가격', 1),
#   ('곳', 1),
#   ('비', 1),
#   ('한국어', 1),
#   ('를', 1),
#   ('때', 1),
#   ('대표', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('코코넛', 1),
#   ('밀크', 1),
#   ('커피', 1),
#   ('이전', 1),
#   ('나트랑', 1),
#   ('날씨', 1),
#   ('콩', 1),
#   ('시원', 1),
#   ('떤딘', 1),
#   ('성당', 1),
#   ('구경', 1),
#   ('호치민', 1),
#   ('여행', 1),
#   ('유익', 1),
#   ('공간', 1)],
#  [('더', 2),
#   ('북한', 2),
#   ('산점', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('모두', 2),
#   ('비', 1),
#   ('방문', 1),
#   ('후기', 1),
#   ('스타벅스', 1),
#   ('오픈', 1),
#   ('런', 1),
#   ('드립', 1),
#   ('왜냐면', 1),
#   ('주말', 1),
#   ('도', 1),
#   ('거의', 1),
#   ('만', 1),
#   ('저', 1),
#   ('오전', 1),
#   ('이', 1),
#   ('주문', 1),
#   ('허니', 1),
#   ('트리플', 1),
#   ('치즈', 1),
#   ('크루아상', 1),
#   ('샌드위치', 1),
#   ('완전', 1),
#   ('만족', 1),
#   ('어요', 1),
#   ('두', 1),
#   ('소', 1),
#   ('소하', 1),
#   ('특별', 1),
#   ('것', 1)],
#  [('날', 4),
#   ('두부', 3),
#   ('맛', 2),
#   ('비', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('버섯', 2),
#   ('가격', 2),
#   ('콩국수', 2),
#   ('의정부', 1),
#   ('맛집', 1),
#   ('전골', 1),
#   ('판', 1),
#   ('식사', 1),
#   ('류', 1),
#   ('적당', 1),
#   ('정식', 1),
#   ('은', 1),
#   ('두부전골', 1),
#   ('는걸', 1),
#   ('옆', 1),
#   ('테이블', 1),
#   ('블리', 1),
#   ('행복', 1),
#   ('한일', 1),
#   ('상', 1)],
#  [('비', 4),
#   ('날', 3),
#   ('메뉴', 3),
#   ('추천', 2),
#   ('선택', 1),
#   ('완벽', 1),
#   ('미아사거리', 1),
#   ('곱창', 1),
#   ('맛집', 1),
#   ('대표', 1),
#   ('제주', 1),
#   ('삼겹살', 1),
#   ('배달', 1),
#   ('가능', 1),
#   ('햇빛', 1),
#   ('병원', 1),
#   ('다가', 1),
#   ('점심', 1),
#   ('사무실', 1),
#   ('로', 1),
#   ('대창', 1),
#   ('착각', 1),
#   ('수', 1),
#   ('주얼', 1),
#   ('벽면', 1),
#   ('설명', 1),
#   ('꿈', 1)],
#  [('비', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('기본', 2),
#   ('밥집', 1),
#   ('점심', 1),
#   ('칼국수', 1),
#   ('수제비', 1),
#   ('추천', 1),
#   ('나', 1),
#   ('데', 1),
#   ('정말', 1),
#   ('초', 1),
#   ('대박', 1),
#   ('친절', 1),
#   ('세팅', 1),
#   ('샐러드', 1),
#   ('김치', 1),
#   ('찬', 1),
#   ('부터', 1),
#   ('거', 1),
#   ('마다', 1),
#   ('이집', 1),
#   ('어보', 1),
#   ('어요', 1),
#   ('진', 1),
#   ('심', 1),
#   ('국물', 1),
#   ('왜', 1),
#   ('시원', 1)],
#  [('곱창', 5),
#   ('파김치', 4),
#   ('날', 3),
#   ('비', 2),
#   ('메뉴', 2),
#   ('소', 2),
#   ('소주', 2),
#   ('어요', 2),
#   ('추천', 1),
#   ('경안동', 1),
#   ('신장', 1),
#   ('진리', 1),
#   ('정말', 1),
#   ('판', 1),
#   ('워낙', 1),
#   ('맛', 1),
#   ('사가', 1),
#   ('사람', 1),
#   ('별도', 1),
#   ('판매', 1),
#   ('소한', 1),
#   ('일상', 1),
#   ('여자', 1)],
#  [('부추', 4),
#   ('날', 2),
#   ('부침개', 2),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('장떡', 1),
#   ('만들기', 1),
#   ('레시피', 1),
#   ('엄마', 1),
#   ('봄', 1),
#   ('나', 1),
#   ('새', 1),
#   ('순은', 1),
#   ('꼭', 1),
#   ('라서', 1),
#   ('어요', 1),
#   ('알리', 1),
#   ('신', 1),
#   ('성분', 1),
#   ('비타민', 1),
#   ('군', 1),
#   ('다른', 1),
#   ('식', 1),
#   ('재료', 1),
#   ('조합', 1),
#   ('번', 1),
#   ('보시', 1),
#   ('요', 1),
#   ('슈슈냥', 1),
#   ('그릇', 1),
#   ('뚝딱', 1)],
#  [('메뉴', 4),
#   ('날', 3),
#   ('것', 3),
#   ('막창', 2),
#   ('삼각지역', 2),
#   ('맛집', 2),
#   ('추천', 2),
#   ('비', 2),
#   ('추적', 2),
#   ('용산', 1),
#   ('려고', 1),
#   ('바로', 1),
#   ('땡', 1),
#   ('기지', 1),
#   ('판', 1),
#   ('찍', 1),
#   ('어보', 1),
#   ('았', 1),
#   ('가까이', 1),
#   ('탓', 1),
#   ('안', 1),
#   ('보이', 1),
#   ('검색', 1),
#   ('앤녕', 1)],
#  [('아이', 3),
#   ('날', 2),
#   ('막걸리', 2),
#   ('메뉴', 2),
#   ('도', 1),
#   ('남해', 1),
#   ('시골', 1),
#   ('추천', 1),
#   ('바깥', 1),
#   ('자리', 1),
#   ('운치', 1),
#   ('안개', 1),
#   ('크게', 1),
#   ('고요', 1),
#   ('저희', 1),
#   ('해물', 1),
#   ('된장찌개', 1),
#   ('해물파전', 1),
#   ('유자', 1),
#   ('깃밥', 1),
#   ('추가', 1),
#   ('주문', 1),
#   ('때문', 1),
#   ('전', 1),
#   ('고추', 1),
#   ('빼', 1),
#   ('달라', 1),
#   ('엄마', 1),
#   ('두', 1),
#   ('딸', 1),
#   ('성장기', 1),
#   ('록', 1)],
#  [('비', 3),
#   ('하남', 2),
#   ('돼지', 2),
#   ('집', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('초록', 2),
#   ('고깃집', 1),
#   ('삼겹살', 1),
#   ('맛집', 1),
#   ('오픈', 1),
#   ('런', 1),
#   ('차지', 1),
#   ('수', 1),
#   ('자리', 1),
#   ('뷰', 1),
#   ('뿐더러', 1),
#   ('소리', 1),
#   ('고기', 1),
#   ('앞', 1),
#   ('돼지고기', 1),
#   ('도시락', 1),
#   ('김치볶음밥', 1),
#   ('김치양', 1),
#   ('얼마', 1),
#   ('단방', 1),
#   ('향소', 1),
#   ('통', 1),
#   ('생활기록부', 1)],
#  [('날', 3),
#   ('오징어', 3),
#   ('비', 2),
#   ('손질', 2),
#   ('통', 2),
#   ('통오징어', 2),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('해물', 1),
#   ('부추전', 1),
#   ('모양', 1),
#   ('그대로', 1),
#   ('다양', 1),
#   ('요리', 1),
#   ('활용', 1),
#   ('가득', 1),
#   ('맛', 1),
#   ('바삭', 1),
#   ('전이', 1),
#   ('어서', 1),
#   ('봉', 1),
#   ('이의', 1),
#   ('데일', 1),
#   ('리', 1),
#   ('달링', 1)],
#  [('비', 8),
#   ('날', 8),
#   ('메뉴', 8),
#   ('저녁', 6),
#   ('음식', 3),
#   ('추천', 3),
#   ('오늘', 2),
#   ('비올', 1),
#   ('때', 1),
#   ('은', 1),
#   ('순두부찌개', 1),
#   ('법', 1),
#   ('달타냥', 1),
#   ('하우스', 1)],
#  [('온천', 4),
#   ('칼국수', 4),
#   ('공주', 4),
#   ('손', 3),
#   ('비', 3),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('나', 2),
#   ('동학사', 1),
#   ('간다', 1),
#   ('또', 1),
#   ('집', 1),
#   ('주말', 1),
#   ('용씨', 1),
#   ('번', 1),
#   ('가지', 1),
#   ('안', 1),
#   ('때문', 1),
#   ('우리', 1),
#   ('둘', 1),
#   ('미지', 1),
#   ('여행', 1),
#   ('맛집', 1),
#   ('휘연', 1),
#   ('세상', 1)],
#  [('수원', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('쌀국수', 2),
#   ('행궁동', 1),
#   ('맛집', 1),
#   ('뮤지', 1),
#   ('엄', 1),
#   ('예약', 1),
#   ('주차', 1),
#   ('지난', 1),
#   ('주말', 1),
#   ('남자친구', 1),
#   ('데이트', 1),
#   ('어요', 1),
#   ('비', 1),
#   ('날씨', 1),
#   ('습', 1),
#   ('끼', 1),
#   ('중하', 1),
#   ('어보', 1),
#   ('기', 1),
#   ('분보', 1),
#   ('아해', 1),
#   ('비빔', 1),
#   ('처음', 1),
#   ('인천', 1),
#   ('짱', 1),
#   ('이의', 1),
#   ('하루', 1)],
#  [('메뉴', 5),
#   ('집밥', 4),
#   ('뚝딱', 3),
#   ('자취', 2),
#   ('생', 2),
#   ('요리', 2),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('간단', 1),
#   ('밥', 1),
#   ('도둑', 1),
#   ('끼', 1),
#   ('양념', 1),
#   ('갈치', 1),
#   ('무조림', 1),
#   ('식탁', 1),
#   ('위', 1),
#   ('보시', 1),
#   ('건', 1),
#   ('오늘', 1),
#   ('습', 1),
#   ('꾸벅', 1),
#   ('주말', 1),
#   ('점심', 1),
#   ('저녁', 1),
#   ('클쑤똴', 1),
#   ('라이프', 1)],
#  [('메뉴', 4),
#   ('비', 3),
#   ('날', 3),
#   ('칼국수', 3),
#   ('음식', 2),
#   ('추천', 2),
#   ('홍천', 2),
#   ('등촌', 2),
#   ('시내', 1),
#   ('맛집', 1),
#   ('역시', 1),
#   ('최고', 1),
#   ('여러분', 1),
#   ('샤브', 1),
#   ('세트', 1),
#   ('전', 1),
#   ('안녕', 1),
#   ('야채', 1),
#   ('미나리', 1),
#   ('법', 1),
#   ('김주', 1),
#   ('부의', 1),
#   ('하루하루', 1)],
#  [('닭도리탕', 4),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('바로', 2),
#   ('비', 1),
#   ('점심', 1),
#   ('로', 1),
#   ('송강', 1),
#   ('맛집', 1),
#   ('정식', 1),
#   ('당', 1),
#   ('당첨', 1),
#   ('얼마', 1),
#   ('전', 1),
#   ('동네', 1),
#   ('맘', 1),
#   ('카페', 1),
#   ('그', 1),
#   ('아쉬움', 1),
#   ('마저', 1),
#   ('맛', 1),
#   ('요기', 1),
#   ('담', 1),
#   ('또', 1),
#   ('징', 1),
#   ('서문', 1),
#   ('원', 1),
#   ('강사', 1),
#   ('일상', 1),
#   ('독서', 1),
#   ('기록', 1),
#   ('강의', 1),
#   ('노트', 1)],
#  [('천안', 3),
#   ('직산', 3),
#   ('꼬막', 3),
#   ('짬뽕', 3),
#   ('비', 3),
#   ('산더미', 2),
#   ('탕수육', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('맛', 1),
#   ('비불', 1),
#   ('위치', 1),
#   ('통', 1),
#   ('유리', 1),
#   ('창', 1),
#   ('모습', 1),
#   ('식사', 1),
#   ('하니', 1),
#   ('운치', 1),
#   ('고요', 1),
#   ('주방', 1),
#   ('옆', 1),
#   ('바로', 1),
#   ('셀프', 1),
#   ('바', 1),
#   ('여행', 1)],
#  [('메뉴', 4),
#   ('청당', 2),
#   ('맛집', 2),
#   ('곱', 2),
#   ('비', 2),
#   ('날', 2),
#   ('회식', 2),
#   ('추천', 2),
#   ('영업', 2),
#   ('선지국', 2),
#   ('거', 2),
#   ('제이', 2),
#   ('시간', 1),
#   ('까지', 1),
#   ('로', 1),
#   ('모듬', 1),
#   ('구이', 1),
#   ('기본', 1),
#   ('찬', 1),
#   ('나', 1),
#   ('데', 1),
#   ('한번', 1),
#   ('맛', 1),
#   ('이면', 1),
#   ('다른', 1),
#   ('소주', 1),
#   ('병각', 1),
#   ('러브', 1)],
#  [('맛집', 7),
#   ('수유', 5),
#   ('추천', 5),
#   ('수유역', 4),
#   ('메뉴', 4),
#   ('비', 3),
#   ('날', 3),
#   ('점심', 2),
#   ('부대찌개', 1),
#   ('고민', 1),
#   ('검색', 1),
#   ('무조건', 1),
#   ('안', 1),
#   ('사람', 1),
#   ('번동', 1),
#   ('꿈', 1)],
#  [('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('조리', 2),
#   ('한번', 2),
#   ('보시', 2),
#   ('건', 2),
#   ('돈', 1),
#   ('산', 1),
#   ('메뉴', 1),
#   ('간편', 1),
#   ('제천', 1),
#   ('오뎅', 1),
#   ('여름철', 1),
#   ('별미', 1),
#   ('이열치열', 1),
#   ('도', 1),
#   ('전해', 1),
#   ('고', 1),
#   ('간', 1),
#   ('단합', 1),
#   ('제', 1),
#   ('누구', 1),
#   ('어요', 1),
#   ('전이', 1),
#   ('우시', 1),
#   ('면', 1),
#   ('집', 1),
#   ('매', 1),
#   ('운오', 1),
#   ('뎅', 1),
#   ('요', 1),
#   ('리안', 1)],
#  [('수제비', 4),
#   ('점심', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('감자', 2),
#   ('비', 2),
#   ('날', 2),
#   ('음식', 2),
#   ('것', 2),
#   ('끼', 2),
#   ('반죽', 1),
#   ('만들기', 1),
#   ('시원', 1),
#   ('가뭄', 1),
#   ('해갈', 1),
#   ('오기', 1),
#   ('억지로', 1),
#   ('어제', 1),
#   ('부터', 1),
#   ('로', 1),
#   ('법', 1),
#   ('소개', 1),
#   ('삼시', 1),
#   ('행주치마', 1),
#   ('정겨운', 1),
#   ('집밥', 1)],
#  [('비', 5),
#   ('날', 3),
#   ('수제비', 3),
#   ('음식', 2),
#   ('얼', 2),
#   ('법', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('건', 2),
#   ('벌써', 1),
#   ('일', 1),
#   ('지속', 1),
#   ('다행', 1),
#   ('하루', 1),
#   ('종일', 1),
#   ('끝', 1),
#   ('바지락', 1),
#   ('육수', 1),
#   ('게', 1),
#   ('또', 1),
#   ('다른', 1),
#   ('언니', 1),
#   ('소의', 1),
#   ('건강', 1),
#   ('푸드', 1),
#   ('스토리', 1)],
#  [('비', 4),
#   ('날', 3),
#   ('메뉴', 3),
#   ('어묵탕', 2),
#   ('더', 2),
#   ('오늘', 2),
#   ('밀키', 1),
#   ('트', 1),
#   ('홍게', 1),
#   ('꼬치', 1),
#   ('추천', 1),
#   ('요즘', 1),
#   ('피해', 1),
#   ('이상', 1),
#   ('바', 1),
#   ('저녁', 1),
#   ('선택', 1),
#   ('음번', 1),
#   ('행', 1),
#   ('사하', 1),
#   ('몇개', 1),
#   ('쟁', 1),
#   ('어요', 1),
#   ('로', 1),
#   ('엄마', 1),
#   ('또', 1),
#   ('다른', 1),
#   ('취미', 1)],
#  [('짬뽕', 7),
#   ('해장', 3),
#   ('레시피', 3),
#   ('메뉴', 3),
#   ('음식', 3),
#   ('만들기', 3),
#   ('양념', 2),
#   ('저녁', 2),
#   ('추천', 2),
#   ('비', 2),
#   ('날', 2),
#   ('설정', 1),
#   ('사랑', 1),
#   ('국물', 1),
#   ('해물짬뽕', 1),
#   ('그릇', 1),
#   ('요리', 1),
#   ('중식', 1),
#   ('집밥', 1),
#   ('달타냥', 1),
#   ('하우스', 1)],
#  [('비', 3),
#   ('광화문', 2),
#   ('직장인', 2),
#   ('날', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('일본', 1),
#   ('라멘', 1),
#   ('데', 1),
#   ('파전', 1),
#   ('안', 1),
#   ('완전', 1),
#   ('바보', 1),
#   ('칼국수', 1),
#   ('먹기', 1),
#   ('심심', 1),
#   ('때', 1),
#   ('곁', 1),
#   ('이기', 1),
#   ('해물파전', 1),
#   ('수', 1),
#   ('안암', 1),
#   ('처음', 1),
#   ('어보', 1),
#   ('맑은', 1),
#   ('국물', 1),
#   ('돼지국밥', 1),
#   ('무려', 1),
#   ('미쉐린', 1)],
#  [('방촌동', 2),
#   ('국수', 2),
#   ('맛집', 2),
#   ('고기', 2),
#   ('칼국수', 2),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('수면', 1),
#   ('옥', 1),
#   ('쌀', 1),
#   ('메뉴', 1),
#   ('지인', 1),
#   ('더', 1),
#   ('생각', 1),
#   ('소스', 1),
#   ('걸', 1),
#   ('잠시', 1),
#   ('후', 1),
#   ('양푼', 1),
#   ('그릇', 1),
#   ('나', 1),
#   ('데', 1),
#   ('육수', 1),
#   ('모모', 1),
#   ('집', 1)],
#  [('파전', 5),
#   ('왕십리', 4),
#   ('날', 4),
#   ('전집', 3),
#   ('동래', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('비', 1),
#   ('국룰', 1),
#   ('술안주', 1),
#   ('중', 1),
#   ('소리', 1),
#   ('면서', 1),
#   ('막걸리', 1),
#   ('수', 1),
#   ('점', 1),
#   ('매일', 1),
#   ('폭주기관차', 1)],
#  [('비', 4),
#   ('메뉴', 3),
#   ('밥', 2),
#   ('도둑', 2),
#   ('날', 2),
#   ('음식', 2),
#   ('추천', 2),
#   ('곳', 2),
#   ('천안', 1),
#   ('두', 1),
#   ('정동', 1),
#   ('의정부', 1),
#   ('부대찌개', 1),
#   ('원래', 1),
#   ('계획', 1),
#   ('다른', 1),
#   ('리뷰', 1),
#   ('오늘', 1),
#   ('점심', 1),
#   ('어서', 1),
#   ('먼저', 1),
#   ('포스팅', 1),
#   ('국물', 1),
#   ('상', 1),
#   ('호명', 1),
#   ('처럼', 1),
#   ('었는데', 1),
#   ('진', 1),
#   ('매료', 1),
#   ('핫', 1),
#   ('플레이', 1),
#   ('스', 1)],
#  [('매운갈비찜', 3),
#   ('날', 2),
#   ('메뉴', 2),
#   ('맛집', 1),
#   ('신사', 1),
#   ('비', 1),
#   ('추천', 1),
#   ('위치', 1),
#   ('수유역', 1),
#   ('번', 1),
#   ('출구', 1),
#   ('골목', 1),
#   ('안', 1),
#   ('오늘', 1),
#   ('비도', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('어요', 1),
#   ('한잔', 1),
#   ('수가', 1),
#   ('막걸리', 1),
#   ('병', 1),
#   ('신', 1),
#   ('사랑', 1),
#   ('갈비찜', 1),
#   ('하루', 1),
#   ('이야기', 1)],
#  [('전', 4),
#   ('야채', 3),
#   ('레시피', 3),
#   ('점심', 3),
#   ('비', 2),
#   ('날', 2),
#   ('음식', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('다이어트', 2),
#   ('식사', 2),
#   ('대용', 2),
#   ('집밥', 2),
#   ('반찬', 2),
#   ('법', 1),
#   ('삭', 1),
#   ('촉촉', 1),
#   ('등', 1),
#   ('전이', 1),
#   ('오늘', 1),
#   ('건강', 1),
#   ('양배추', 1),
#   ('간식', 1),
#   ('간단', 1),
#   ('아이', 1),
#   ('가시', 1),
#   ('장미', 1),
#   ('수다', 1)],
#  [('나루', 4),
#   ('동태', 4),
#   ('탕', 4),
#   ('마곡', 4),
#   ('비', 3),
#   ('날', 3),
#   ('맛집', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('국밥', 2),
#   ('포스팅', 2),
#   ('마다', 2),
#   ('안녕하십니까', 1),
#   ('맨입', 1),
#   ('이번', 1),
#   ('와이프', 1),
#   ('날씨', 1),
#   ('때', 1),
#   ('맨', 1),
#   ('모험', 1)],
#  [('감자', 3),
#   ('비', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('감자전', 2),
#   ('만들기', 2),
#   ('아이', 2),
#   ('간식', 2),
#   ('추천', 2),
#   ('홈', 2),
#   ('홈스토리', 2),
#   ('고소', 1),
#   ('싹', 1),
#   ('독성', 1),
#   ('때문', 1),
#   ('박스', 1),
#   ('단위', 1),
#   ('조금', 1),
#   ('사서', 1),
#   ('도록', 1),
#   ('려고', 1),
#   ('편', 1),
#   ('요', 1),
#   ('봉지', 1)],
#  [('저녁', 3),
#   ('오늘', 3),
#   ('식단', 3),
#   ('비', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('뭐', 2),
#   ('표', 2),
#   ('일주일', 2),
#   ('주간', 2),
#   ('밥상', 2),
#   ('금요일', 2),
#   ('안녕', 1),
#   ('벌써', 1),
#   ('일요일', 1),
#   ('밤', 1),
#   ('요', 1),
#   ('저', 1),
#   ('양양', 1),
#   ('여행', 1),
#   ('다가', 1),
#   ('어제', 1),
#   ('집', 1),
#   ('친정', 1),
#   ('부모님', 1),
#   ('더니', 1),
#   ('부터', 1),
#   ('평범', 1),
#   ('듯', 1),
#   ('특별', 1),
#   ('꽃', 1),
#   ('길이', 1)],
#  [('캠핑', 6),
#   ('날', 3),
#   ('부침개', 3),
#   ('비', 2),
#   ('간단', 2),
#   ('요리', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('사옹원', 2),
#   ('종', 1),
#   ('세트', 1),
#   ('호떡', 1),
#   ('우중', 1),
#   ('꼭', 1),
#   ('것', 1),
#   ('직접', 1),
#   ('재료', 1),
#   ('반죽', 1),
#   ('더', 1),
#   ('최고', 1),
#   ('평소', 1),
#   ('달', 1),
#   ('로그', 1)],
#  [('산장', 4),
#   ('메뉴', 3),
#   ('동래', 2),
#   ('비', 2),
#   ('날', 2),
#   ('전골', 2),
#   ('맛집', 1),
#   ('더', 1),
#   ('술집', 1),
#   ('추천', 1),
#   ('대체로', 1),
#   ('오리', 1),
#   ('주물', 1),
#   ('럭', 1),
#   ('던데', 1),
#   ('방문', 1),
#   ('국물', 1),
#   ('주문', 1),
#   ('막걸리', 1),
#   ('소주', 1),
#   ('젊은이', 1),
#   ('취향', 1),
#   ('저격', 1),
#   ('하이', 1),
#   ('볼', 1),
#   ('수진', 1),
#   ('흔적', 1)],
#  [('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('가산디지털단지역', 2),
#   ('짬뽕', 2),
#   ('짱', 1),
#   ('김대', 1),
#   ('리', 1),
#   ('불맛나', 1),
#   ('하나', 1),
#   ('제왕', 1),
#   ('주소', 1),
#   ('서울', 1),
#   ('금천구', 1),
#   ('가산', 1),
#   ('디지털', 1),
#   ('로', 1),
#   ('한라', 1),
#   ('앤', 1),
#   ('타워', 1),
#   ('층', 1),
#   ('호', 1),
#   ('전화번호', 1),
#   ('영업', 1),
#   ('시간', 1),
#   ('월', 1),
#   ('금', 1),
#   ('부근', 1),
#   ('파이브', 1),
#   ('비뉴', 1)],
#  [('수제비', 4),
#   ('비', 4),
#   ('날', 4),
#   ('메뉴', 3),
#   ('감자', 2),
#   ('법', 2),
#   ('점심', 2),
#   ('추천', 2),
#   ('만들기', 2),
#   ('끈', 1),
#   ('즐', 1),
#   ('기기', 1),
#   ('로', 1),
#   ('가끔', 1),
#   ('이', 1),
#   ('특정', 1),
#   ('음식', 1),
#   ('생각', 1),
#   ('날때', 1),
#   ('서도', 1),
#   ('지혜', 1),
#   ('사자', 1),
#   ('감성', 1),
#   ('현실', 1),
#   ('집밥', 1)],
#  [('베이커리', 3),
#   ('여행', 2),
#   ('날', 2),
#   ('주차', 2),
#   ('추천', 2),
#   ('카페', 2),
#   ('분', 2),
#   ('제주', 1),
#   ('비', 1),
#   ('무', 1),
#   ('로이', 1),
#   ('메뉴', 1),
#   ('힙', 1),
#   ('감성', 1),
#   ('포토', 1),
#   ('스팟', 1),
#   ('아보', 1),
#   ('테라스', 1),
#   ('강추', 1),
#   ('대신', 1),
#   ('종류', 1),
#   ('편이', 1),
#   ('디저트', 1),
#   ('참고', 1),
#   ('욥', 1),
#   ('해', 1),
#   ('서귀포', 1),
#   ('대형', 1),
#   ('파워', 1),
#   ('이지', 1),
#   ('일상', 1)],
#  [('메뉴', 3),
#   ('감자전', 3),
#   ('여름', 2),
#   ('가지', 2),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('탕수', 1),
#   ('만들기', 1),
#   ('음식', 1),
#   ('제철', 1),
#   ('즐', 1),
#   ('기기', 1),
#   ('아이', 1),
#   ('어른', 1),
#   ('탕수랍니', 1),
#   ('로', 1),
#   ('전', 1),
#   ('오랜만', 1),
#   ('어요', 1),
#   ('담', 1),
#   ('백고', 1),
#   ('소한', 1),
#   ('우리', 1),
#   ('집', 1),
#   ('막내', 1),
#   ('아하', 1),
#   ('요리', 1),
#   ('감자', 1),
#   ('개', 1),
#   ('맘마', 1)],
#  [('비', 8),
#   ('날', 8),
#   ('메뉴', 6),
#   ('저녁', 5),
#   ('음식', 4),
#   ('비올', 2),
#   ('때', 2),
#   ('추천', 2),
#   ('그릇', 2),
#   ('요리', 2),
#   ('뭐', 1),
#   ('드실껀', 1),
#   ('가요', 1),
#   ('오늘', 1),
#   ('먹기', 1),
#   ('달타냥', 1),
#   ('하우스', 1)],
#  [('경북', 2),
#   ('도청', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('설비', 2),
#   ('안동', 1),
#   ('비', 1),
#   ('고기국수', 1),
#   ('칼국수', 1),
#   ('이수', 1),
#   ('옥', 1),
#   ('추천', 1),
#   ('해', 1),
#   ('오래', 1),
#   ('집', 1),
#   ('이지', 1),
#   ('사람', 1),
#   ('맛집', 1),
#   ('은', 1),
#   ('역시', 1),
#   ('국물', 1),
#   ('무하', 1),
#   ('직원', 1),
#   ('단골', 1),
#   ('음식점', 1),
#   ('점심', 1),
#   ('시간', 1),
#   ('자리', 1),
#   ('수', 1),
#   ('평소', 1),
#   ('성공', 1),
#   ('누수', 1),
#   ('수구', 1),
#   ('해결사', 1),
#   ('모든', 1),
#   ('것', 1)],
#  [('강서구', 2),
#   ('유림', 2),
#   ('닭도리탕', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('막걸리', 2),
#   ('비', 2),
#   ('맛집', 1),
#   ('추천', 1),
#   ('못', 1),
#   ('우리', 1),
#   ('한마음', 1),
#   ('통속', 1),
#   ('까지', 1),
#   ('음식', 1),
#   ('오니', 1),
#   ('생각', 1),
#   ('정', 1),
#   ('도착', 1),
#   ('오늘', 1),
#   ('나', 1)],
#  [('쑥갓', 7),
#   ('비', 4),
#   ('날', 4),
#   ('부추전', 3),
#   ('음식', 3),
#   ('전', 2),
#   ('요리', 2),
#   ('건', 2),
#   ('새우', 2),
#   ('메뉴', 2),
#   ('막걸리', 2),
#   ('바삭', 2),
#   ('안주', 1),
#   ('추천', 1),
#   ('전요', 1),
#   ('리가', 1),
#   ('생각', 1),
#   ('로', 1),
#   ('부추', 1),
#   ('줌', 1),
#   ('어서', 1),
#   ('어요', 1),
#   ('역시', 1),
#   ('전이', 1),
#   ('칼라', 1),
#   ('푸드', 1),
#   ('테라', 1),
#   ('피', 1)],
#  [('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('카페라떼', 2),
#   ('방송', 2),
#   ('스벅', 1),
#   ('스텀', 1),
#   ('고', 1),
#   ('엽떡', 1),
#   ('어제', 1),
#   ('부터', 1),
#   ('재난', 1),
#   ('알림', 1),
#   ('문자', 1),
#   ('태풍', 1),
#   ('대비', 1),
#   ('하라', 1),
#   ('등', 1),
#   ('이번', 1),
#   ('맛', 1),
#   ('라떼', 1),
#   ('커피', 1),
#   ('스타벅스', 1),
#   ('하루하루', 1)],
#  [('상추', 5),
#   ('전', 2),
#   ('부침개', 2),
#   ('비', 2),
#   ('날', 2),
#   ('술안주', 2),
#   ('메뉴', 2),
#   ('어요', 2),
#   ('맛', 2),
#   ('더', 2),
#   ('만들기', 1),
#   ('튀김', 1),
#   ('가루', 1),
#   ('반죽', 1),
#   ('키친', 1),
#   ('타', 1),
#   ('기름기', 1),
#   ('빼', 1),
#   ('전간', 1),
#   ('장', 1),
#   ('지네', 1),
#   ('로', 1),
#   ('이영자', 1),
#   ('추천', 1),
#   ('꿀', 1)],
#  [('비', 4),
#   ('날', 4),
#   ('유미', 4),
#   ('카츠', 4),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('안녕', 1),
#   ('로', 1),
#   ('먹기', 1),
#   ('음식', 1),
#   ('가득', 1),
#   ('곳', 1),
#   ('본격', 1),
#   ('적', 1),
#   ('장마', 1),
#   ('최고', 1),
#   ('뿐', 1),
#   ('항상', 1),
#   ('분', 1),
#   ('매력', 1),
#   ('돈카츠', 1),
#   ('전문점', 1),
#   ('공식', 1),
#   ('블로그', 1)],
#  [('동천역', 5),
#   ('칼국수', 5),
#   ('명동', 3),
#   ('한국', 2),
#   ('물', 2),
#   ('날', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('돈', 1),
#   ('산', 1),
#   ('수지구', 1),
#   ('맛집', 1),
#   ('평일', 1),
#   ('토요일', 1),
#   ('일요일', 1),
#   ('휴무', 1),
#   ('주차', 1),
#   ('가능', 1),
#   ('오늘', 1),
#   ('비', 1),
#   ('억수', 1),
#   ('마론킴', 1)],
#  [('순대국', 6),
#   ('맛집', 5),
#   ('광교', 4),
#   ('프랑', 4),
#   ('남옥', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('아브뉴', 1),
#   ('정', 1),
#   ('이용', 1),
#   ('시간', 1),
#   ('매일', 1),
#   ('라스트', 1),
#   ('비', 1),
#   ('오픈', 1),
#   ('별별', 1),
#   ('감초', 1),
#   ('내일', 1),
#   ('여', 1),
#   ('일상', 1)],
#  [('양', 4),
#   ('꼬치', 4),
#   ('맛집', 3),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('인천', 1),
#   ('날', 1),
#   ('작전동', 1),
#   ('온면', 1),
#   ('포차', 1),
#   ('개', 1),
#   ('이면', 1),
#   ('적당', 1),
#   ('거', 1),
#   ('일단', 1),
#   ('인분', 1),
#   ('시작', 1),
#   ('분', 1),
#   ('소주', 1),
#   ('잔', 1),
#   ('필', 1),
#   ('수구', 1),
#   ('칭따오', 1),
#   ('맥주', 1),
#   ('배', 1),
#   ('술', 1),
#   ('미미', 1),
#   ('이야기', 1)],
#  [('오덕', 4),
#   ('날', 4),
#   ('집콕러들', 2),
#   ('위', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('비', 2),
#   ('이의', 1),
#   ('쌀', 1),
#   ('어요', 1),
#   ('해물파전', 1),
#   ('빗', 1),
#   ('소리', 1),
#   ('전', 1),
#   ('저', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('어렷을적', 1),
#   ('초등학교', 1),
#   ('마치', 1),
#   ('우산', 1),
#   ('청년', 1)],
#  [('날', 3),
#   ('비', 3),
#   ('오늘', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('음식', 2),
#   ('해물파전', 2),
#   ('어묵탕', 2),
#   ('암만', 2),
#   ('자향', 1),
#   ('호', 1),
#   ('출발', 1),
#   ('치즈', 1),
#   ('닭갈비', 1),
#   ('소세지', 1),
#   ('전', 1),
#   ('역시', 1),
#   ('여름', 1),
#   ('인기', 1),
#   ('영양', 1),
#   ('쟁이', 1),
#   ('강력', 1),
#   ('합', 1),
#   ('미니', 1),
#   ('힐링', 1),
#   ('푸드', 1)],
#  [('비', 4),
#   ('날', 2),
#   ('저녁', 2),
#   ('메뉴', 2),
#   ('로', 2),
#   ('음식', 2),
#   ('메기', 2),
#   ('매운탕', 2),
#   ('맛집', 2),
#   ('추천', 2),
#   ('계속', 2),
#   ('올해', 1),
#   ('장마', 1),
#   ('기간', 1),
#   ('시작', 1),
#   ('면서', 1),
#   ('비소', 1),
#   ('식', 1),
#   ('이번', 1),
#   ('때문', 1),
#   ('시간', 1),
#   ('남양주', 1),
#   ('다이어트', 1),
#   ('찜질', 1),
#   ('카페', 1)],
#  [('날', 5),
#   ('음식', 5),
#   ('비', 4),
#   ('레시피', 3),
#   ('메뉴', 2),
#   ('생각', 2),
#   ('술안주', 2),
#   ('전', 2),
#   ('종류', 1),
#   ('주', 1),
#   ('안주', 1),
#   ('도', 1),
#   ('다음', 1),
#   ('해장', 1),
#   ('추천', 1),
#   ('국물', 1),
#   ('요리', 1),
#   ('출처', 1),
#   ('나혼산', 1),
#   ('코쿤', 1),
#   ('바지락', 1),
#   ('탕', 1),
#   ('엘리', 1),
#   ('맘', 1),
#   ('지금', 1),
#   ('이', 1),
#   ('순간', 1)],
#  [('메인', 7),
#   ('메뉴', 5),
#   ('포', 4),
#   ('쌀국수', 3),
#   ('깐풍기', 3),
#   ('날', 2),
#   ('단짝', 2),
#   ('맛집', 2),
#   ('배달', 2),
#   ('부터', 1),
#   ('까지', 1),
#   ('레드', 1),
#   ('추천', 1),
#   ('오늘', 1),
#   ('뭐', 1),
#   ('베트남', 1),
#   ('음식', 1),
#   ('후기', 1),
#   ('베스트', 1)],
#  [('비', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('새우', 2),
#   ('추천', 1),
#   ('부추전', 1),
#   ('만들기', 1),
#   ('부추', 1),
#   ('요리', 1),
#   ('레시피', 1),
#   ('건', 1),
#   ('생각', 1),
#   ('부침개', 1),
#   ('멸치', 1),
#   ('어가', 1),
#   ('간', 1),
#   ('초', 1),
#   ('간장', 1),
#   ('이나', 1),
#   ('매콤', 1),
#   ('청양고추', 1),
#   ('절임', 1),
#   ('곁', 1),
#   ('이면', 1),
#   ('감칠맛', 1),
#   ('수', 1),
#   ('아직', 1),
#   ('점심', 1),
#   ('로', 1),
#   ('하루', 1)],
#  [('비', 4),
#   ('소', 3),
#   ('갑오징어무침', 2),
#   ('감자', 2),
#   ('부침개', 2),
#   ('날', 2),
#   ('집밥', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('다트', 2),
#   ('리', 2),
#   ('지고', 2),
#   ('동네', 1),
#   ('방', 1),
#   ('장마철', 1),
#   ('일', 1),
#   ('주룩주룩', 1),
#   ('밖', 1),
#   ('기', 1),
#   ('몸', 1),
#   ('기분', 1),
#   ('까지', 1),
#   ('다운', 1),
#   ('다한', 1)],
#  [('날', 3),
#   ('메뉴', 3),
#   ('추천', 2),
#   ('도토리', 2),
#   ('쭈꾸미', 2),
#   ('세트', 2),
#   ('구성', 2),
#   ('구미', 2),
#   ('점심', 2),
#   ('구', 1),
#   ('미산동', 1),
#   ('맛집', 1),
#   ('전이', 1),
#   ('전문', 1),
#   ('안', 1),
#   ('전하', 1),
#   ('보', 1),
#   ('내세', 1),
#   ('전', 1),
#   ('계산', 1),
#   ('곳', 1),
#   ('편', 1),
#   ('아메', 1),
#   ('믹스', 1),
#   ('커피', 1),
#   ('수', 1),
#   ('도록', 1),
#   ('프로', 1),
#   ('설비', 1),
#   ('토탈', 1),
#   ('인테리어', 1)],
#  [('날', 3),
#   ('수제비', 3),
#   ('송도', 3),
#   ('우이', 2),
#   ('녹', 2),
#   ('메뉴', 2),
#   ('칼국수', 2),
#   ('비', 2),
#   ('추천', 1),
#   ('새우', 1),
#   ('백합', 1),
#   ('왕새우', 1),
#   ('지난주', 1),
#   ('말', 1),
#   ('볼일', 1),
#   ('센트럴', 1),
#   ('파크', 1),
#   ('오전', 1),
#   ('일', 1),
#   ('맛집', 1),
#   ('아보', 1),
#   ('새', 1),
#   ('우수', 1),
#   ('제비집', 1),
#   ('마침', 1),
#   ('어서', 1),
#   ('김', 1),
#   ('썸머', 1),
#   ('블로그', 1)],
#  [('들깨', 3),
#   ('그릇', 3),
#   ('날', 2),
#   ('메뉴', 2),
#   ('수제비', 2),
#   ('고', 2),
#   ('민하', 2),
#   ('비', 1),
#   ('추천', 1),
#   ('퇴근', 1),
#   ('항상', 1),
#   ('저녁', 1),
#   ('오늘', 1),
#   ('무얼', 1),
#   ('먹음', 1),
#   ('다가', 1),
#   ('비도', 1),
#   ('오랜만', 1),
#   ('최고', 1),
#   ('의', 1),
#   ('평범', 1),
#   ('한일', 1),
#   ('상', 1)],
#  [('장떡', 7),
#   ('비', 4),
#   ('날', 4),
#   ('법', 3),
#   ('술안주', 3),
#   ('메뉴', 3),
#   ('고추장', 3),
#   ('부추', 2),
#   ('부침개', 1),
#   ('생각', 1),
#   ('절로', 1),
#   ('추천', 1),
#   ('준비', 1),
#   ('진짜', 1),
#   ('냉장고', 1),
#   ('속', 1),
#   ('야채', 1),
#   ('시크', 1),
#   ('도도', 1),
#   ('토깽', 1),
#   ('살', 1),
#   ('효', 1)],
#  [('소', 5),
#   ('곱창', 4),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('곱창전골', 2),
#   ('효능', 2),
#   ('곱', 2),
#   ('기름', 2),
#   ('보통', 1),
#   ('함', 1),
#   ('가득', 1),
#   ('겉', 1),
#   ('지고', 1),
#   ('전골', 1),
#   ('구이', 1),
#   ('때', 1),
#   ('온통', 1),
#   ('얀마', 1),
#   ('음', 1),
#   ('블로그', 1)],
#  [('해물파전', 4),
#   ('레시피', 4),
#   ('막걸리', 4),
#   ('초', 3),
#   ('간단', 3),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('국순당', 2),
#   ('파전', 2),
#   ('앞', 1),
#   ('그때', 1),
#   ('마다', 1),
#   ('로', 1),
#   ('맛집', 1),
#   ('우국생', 1)],
#  [('날', 5),
#   ('제주', 4),
#   ('원더', 3),
#   ('아일랜드', 3),
#   ('서귀포', 3),
#   ('아기', 2),
#   ('비', 2),
#   ('볼', 2),
#   ('곳', 2),
#   ('추천', 2),
#   ('이번', 1),
#   ('여행', 1),
#   ('기억', 1),
#   ('몇', 1),
#   ('개', 1),
#   ('진심', 1),
#   ('이나', 1),
#   ('야외', 1),
#   ('여의', 1),
#   ('치', 1),
#   ('강', 1),
#   ('리', 1),
#   ('로', 1),
#   ('그', 1)],
#  [('파전', 6),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('날', 3),
#   ('대포', 2),
#   ('빠삭', 2),
#   ('광영동', 2),
#   ('술집', 2),
#   ('막걸리', 1),
#   ('최고', 1),
#   ('바삭', 1),
#   ('튀김', 1),
#   ('수', 1),
#   ('빠사', 1),
#   ('를', 1),
#   ('첫', 1),
#   ('방문', 1),
#   ('때', 1),
#   ('부터', 1),
#   ('떡볶이', 1),
#   ('반', 1),
#   ('보름달', 1),
#   ('일상', 1),
#   ('로그', 1)],
#  [('상도동', 4),
#   ('수제비', 4),
#   ('낙지', 3),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('마리', 2),
#   ('날', 2),
#   ('어요', 2),
#   ('맛집', 2),
#   ('생각', 1),
#   ('저', 1),
#   ('남편', 1),
#   ('덮밥', 1),
#   ('주문', 1),
#   ('국물', 1),
#   ('쫄깃', 1),
#   ('그릇', 1),
#   ('최고', 1),
#   ('었습니당', 1),
#   ('일상', 1),
#   ('정보', 1),
#   ('공', 1),
#   ('유하', 1),
#   ('블로그', 1)],
#  [('신촌', 4),
#   ('카페', 4),
#   ('보드게임', 3),
#   ('레드', 3),
#   ('버튼', 3),
#   ('날', 3),
#   ('추천', 2),
#   ('비', 2),
#   ('가기', 1),
#   ('놀', 1),
#   ('거리', 1),
#   ('해', 1),
#   ('보기', 1),
#   ('메뉴', 1),
#   ('판', 1),
#   ('방', 1),
#   ('마다', 1),
#   ('여진', 1),
#   ('어플', 1),
#   ('통해', 1),
#   ('대면', 1),
#   ('주문', 1),
#   ('수', 1),
#   ('음료', 1)],
#  [('치킨', 6),
#   ('부어', 4),
#   ('그릴', 4),
#   ('후라이드', 4),
#   ('통치', 3),
#   ('킨', 3),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('비', 1),
#   ('치맥', 1),
#   ('연휴', 1),
#   ('주말', 1),
#   ('배민', 1),
#   ('배달', 1),
#   ('민족', 1),
#   ('할인', 1),
#   ('쿠폰', 1),
#   ('생각', 1),
#   ('살', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('이야기', 1)],
#  [('날', 4),
#   ('서울', 3),
#   ('비', 3),
#   ('데이트', 2),
#   ('추천', 2),
#   ('어반', 1),
#   ('가든', 1),
#   ('모임', 1),
#   ('삭', 1),
#   ('샐러드', 1),
#   ('식감', 1),
#   ('스프', 1),
#   ('입맛', 1),
#   ('구기', 1),
#   ('제격', 1),
#   ('메뉴', 1),
#   ('거기', 1),
#   ('실내', 1),
#   ('맛집', 1),
#   ('다음', 1),
#   ('화창', 1),
#   ('야외', 1),
#   ('테이블', 1),
#   ('보', 1),
#   ('려고', 1)],
#  [('비', 4),
#   ('추천', 3),
#   ('날', 3),
#   ('메뉴', 3),
#   ('사당', 2),
#   ('술집', 2),
#   ('쏠', 2),
#   ('습', 2),
#   ('녀석', 1),
#   ('마케집', 1),
#   ('주말', 1),
#   ('오늘', 1),
#   ('센스', 1),
#   ('사당역', 1),
#   ('태블릿', 1),
#   ('메뉴판', 1),
#   ('편', 1),
#   ('리하', 1),
#   ('조개', 1),
#   ('무지', 1),
#   ('로그', 1)],
#  [('현대', 3),
#   ('백화점', 3),
#   ('점', 2),
#   ('날', 2),
#   ('중', 2),
#   ('동점', 2),
#   ('부천', 1),
#   ('전자', 1),
#   ('방', 1),
#   ('중동', 1),
#   ('찰떡', 1),
#   ('메뉴', 1),
#   ('선택', 1),
#   ('해당', 1),
#   ('자주', 1),
#   ('방문', 1),
#   ('예상', 1),
#   ('셋', 1),
#   ('천원', 1),
#   ('돈', 1),
#   ('친절', 1),
#   ('분위기', 1),
#   ('중식', 1),
#   ('추천', 1),
#   ('짬뽕', 1),
#   ('맛집', 1),
#   ('킴풔집', 1),
#   ('구석', 1)],
#  [('바삭', 1),
#   ('해물파전', 1),
#   ('동동주', 1),
#   ('날', 1),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('하늘', 1),
#   ('좀', 1),
#   ('우중', 1),
#   ('충', 1),
#   ('여러분', 1),
#   ('우울', 1),
#   ('필요', 1),
#   ('우리', 1),
#   ('전통문화', 1),
#   ('요', 1),
#   ('오늘', 1),
#   ('모임', 1),
#   ('파전', 1),
#   ('어요', 1),
#   ('수제비', 1),
#   ('먼저', 1),
#   ('위', 1),
#   ('보호', 1),
#   ('참기름', 1),
#   ('몽고', 1),
#   ('덕질', 1),
#   ('블로그', 1)],
#  [('날', 3),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('비', 2),
#   ('시가', 2),
#   ('휴게소', 1),
#   ('터', 1),
#   ('성남', 1),
#   ('나들이', 1),
#   ('남한', 1),
#   ('산성', 1),
#   ('드라이브', 1),
#   ('코스', 1),
#   ('오후', 1),
#   ('동생', 1),
#   ('저녁', 1),
#   ('겸', 1),
#   ('산', 1),
#   ('공기', 1),
#   ('길', 1),
#   ('요즘', 1),
#   ('해', 1),
#   ('지니', 1),
#   ('영어', 1)],
#  [('수제비', 7),
#   ('삼시', 2),
#   ('끼', 2),
#   ('차승원', 2),
#   ('감자', 2),
#   ('날', 2),
#   ('저녁', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('비', 1),
#   ('반죽', 1),
#   ('숙성', 1),
#   ('보관', 1),
#   ('얼마', 1),
#   ('전부', 1),
#   ('터', 1),
#   ('곳', 1),
#   ('기억', 1),
#   ('음식점', 1),
#   ('출입', 1)],
#  [('날', 4),
#   ('비', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('김치찜', 2),
#   ('게', 2),
#   ('것', 2),
#   ('저', 1),
#   ('집', 1),
#   ('안', 1),
#   ('억울', 1),
#   ('정도', 1),
#   ('날씨', 1),
#   ('맑은', 1),
#   ('더', 1),
#   ('고요', 1),
#   ('그나', 1),
#   ('마', 1),
#   ('이면', 1),
#   ('또', 1),
#   ('생각', 1),
#   ('한국인', 1),
#   ('입맛', 1),
#   ('치', 1),
#   ('느님', 1),
#   ('가라사대', 1)],
#  [('비', 4),
#   ('김치', 4),
#   ('날', 3),
#   ('시원', 3),
#   ('콩나물국', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('법', 2),
#   ('하루', 1),
#   ('종일', 1),
#   ('부슬부슬', 1),
#   ('국물', 1),
#   ('오른', 1),
#   ('전', 1),
#   ('더니', 1),
#   ('어요', 1),
#   ('그녀', 1),
#   ('이야기', 1)],
#  [('짬뽕', 5),
#   ('날', 3),
#   ('추천', 3),
#   ('메뉴', 2),
#   ('어요', 2),
#   ('의왕', 1),
#   ('군포', 1),
#   ('교동', 1),
#   ('반점', 1),
#   ('끈', 1),
#   ('매콤', 1),
#   ('국물', 1),
#   ('후루루', 1),
#   ('룹', 1),
#   ('캬', 1),
#   ('짜장면', 1),
#   ('가격', 1),
#   ('차이', 1),
#   ('그', 1),
#   ('만큼', 1),
#   ('더', 1),
#   ('양파', 1),
#   ('단무지', 1),
#   ('최꾸럭', 1),
#   ('블로그', 1)],
#  [('피자', 4),
#   ('메뉴', 4),
#   ('날', 3),
#   ('추천', 3),
#   ('비', 2),
#   ('끈', 1),
#   ('걸', 1),
#   ('게', 1),
#   ('고심', 1),
#   ('끝', 1),
#   ('특별', 1),
#   ('선정', 1),
#   ('로', 1),
#   ('토핑', 1),
#   ('파인애플', 1),
#   ('방울토마토', 1),
#   ('어가', 1),
#   ('땅', 1),
#   ('공식', 1),
#   ('블로그', 1)],
#  [('수제비', 5),
#   ('추천', 4),
#   ('메뉴', 4),
#   ('감자', 3),
#   ('비', 2),
#   ('날', 2),
#   ('점심', 2),
#   ('물', 2),
#   ('밀가루', 1),
#   ('요리', 1),
#   ('가시', 1),
#   ('길', 1),
#   ('키친', 1),
#   ('업', 1),
#   ('감사', 1),
#   ('반죽', 1),
#   ('애호박', 1),
#   ('양파', 1),
#   ('대파', 1),
#   ('국', 1),
#   ('간장', 1),
#   ('숟가락', 1),
#   ('반', 1),
#   ('후추', 1),
#   ('조금', 1),
#   ('육수', 1),
#   ('다시마', 1),
#   ('장', 1),
#   ('냄비', 1),
#   ('멍공쥬', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('이야기', 1)],
#  [('칼국수', 3),
#   ('비', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('이', 2),
#   ('추천', 1),
#   ('바지락', 1),
#   ('듬뿍', 1),
#   ('고추장', 1),
#   ('저희', 1),
#   ('딸', 1),
#   ('면', 1),
#   ('고요', 1),
#   ('오늘', 1),
#   ('장', 1),
#   ('애', 1),
#   ('만', 1),
#   ('족하', 1),
#   ('사실', 1),
#   ('제일', 1),
#   ('냉정', 1),
#   ('평가', 1),
#   ('남매', 1),
#   ('라서', 1),
#   ('칼칼', 1),
#   ('끼', 1),
#   ('해결', 1),
#   ('칠', 1),
#   ('감성', 1),
#   ('워킹맘', 1),
#   ('놀이터', 1)],
#  [('오뎅', 4),
#   ('부산', 3),
#   ('비', 3),
#   ('사당역', 2),
#   ('맛집', 2),
#   ('탕', 2),
#   ('어묵탕', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('어묵', 1),
#   ('추천', 1),
#   ('가장', 1),
#   ('달이', 1),
#   ('봄', 1),
#   ('거의', 1),
#   ('주말', 1),
#   ('마다', 1),
#   ('것', 1),
#   ('드디어', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('등장', 1),
#   ('계란', 1),
#   ('당면', 1),
#   ('미나리', 1),
#   ('부추', 1),
#   ('책', 1),
#   ('산', 1),
#   ('길', 1)],
#  [('날', 3),
#   ('짬뽕', 3),
#   ('점심', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('동동주', 2),
#   ('소', 2),
#   ('소한', 2),
#   ('일산', 1),
#   ('지존', 1),
#   ('수제비', 1),
#   ('비', 1),
#   ('은', 1),
#   ('밀가루', 1),
#   ('음식', 1),
#   ('이나', 1),
#   ('기름기', 1),
#   ('도', 1),
#   ('지지', 1),
#   ('부침개', 1),
#   ('땡', 1),
#   ('기지', 1),
#   ('모듬', 1),
#   ('전', 1),
#   ('잔', 1),
#   ('아직', 1),
#   ('근무시간', 1),
#   ('대신', 1),
#   ('매콤', 1),
#   ('로', 1),
#   ('해', 1),
#   ('델마', 1),
#   ('일상', 1),
#   ('이야기', 1)],
#  [('짬뽕', 4),
#   ('비', 3),
#   ('날', 3),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('홍콩', 1),
#   ('반점', 1),
#   ('성대', 1),
#   ('시장', 1),
#   ('맛집', 1),
#   ('전', 1),
#   ('예전', 1),
#   ('칼국수', 1),
#   ('생각', 1),
#   ('요즘', 1),
#   ('고', 1),
#   ('인', 1),
#   ('대학교', 1),
#   ('학년', 1),
#   ('때', 1),
#   ('매력', 1),
#   ('뒤', 1),
#   ('거의', 1),
#   ('케이', 1),
#   ('의', 1),
#   ('기록', 1)],
#  [('날', 3),
#   ('비', 2),
#   ('메뉴', 2),
#   ('그릇', 2),
#   ('대전', 1),
#   ('김치찌개', 1),
#   ('맛집', 1),
#   ('추천', 1),
#   ('오', 1),
#   ('모리', 1),
#   ('찌개', 1),
#   ('어가', 1),
#   ('로', 1),
#   ('마음', 1),
#   ('으슬으슬', 1),
#   ('팔팔', 1),
#   ('뚝배기', 1),
#   ('정말', 1),
#   ('소', 1),
#   ('소하', 1),
#   ('확실', 1),
#   ('행복', 1),
#   ('거', 1),
#   ('카페', 1),
#   ('커피', 1),
#   ('디저트', 1),
#   ('면서', 1),
#   ('창밖', 1),
#   ('제리', 1),
#   ('뷰티', 1),
#   ('로그', 1)],
#  [('날', 3),
#   ('비', 2),
#   ('메뉴', 2),
#   ('로', 2),
#   ('추천', 2),
#   ('파전', 1),
#   ('대신', 1),
#   ('간단', 1),
#   ('술안주', 1),
#   ('골뱅이무침', 1),
#   ('양념', 1),
#   ('코로나', 1),
#   ('수', 1),
#   ('한잔', 1),
#   ('것', 1),
#   ('인지상정', 1),
#   ('습', 1),
#   ('깡', 1),
#   ('간편', 1),
#   ('안주', 1),
#   ('살포시', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('집들이', 1),
#   ('메인', 1),
#   ('요리', 1),
#   ('볼보', 1),
#   ('맘', 1),
#   ('이', 1),
#   ('작가', 1),
#   ('이야기', 1)],
#  [('장마철', 3),
#   ('메뉴', 3),
#   ('비', 2),
#   ('날', 2),
#   ('저녁', 2),
#   ('추천', 2),
#   ('사골', 2),
#   ('수제비', 2),
#   ('뚝딱', 2),
#   ('한국인', 1),
#   ('힘', 1),
#   ('밥힘', 1),
#   ('나', 1),
#   ('게', 1),
#   ('밥', 1),
#   ('다른', 1),
#   ('것', 1),
#   ('자꾸', 1),
#   ('눈길', 1),
#   ('이웃', 1),
#   ('님들', 1),
#   ('로', 1),
#   ('분안', 1),
#   ('요리', 1),
#   ('맛', 1),
#   ('중심', 1),
#   ('종가', 1),
#   ('집', 1)],
#  [('메뉴', 3),
#   ('꼬치', 2),
#   ('어묵탕', 2),
#   ('어묵', 2),
#   ('비', 2),
#   ('날', 2),
#   ('나', 2),
#   ('법', 1),
#   ('음식', 1),
#   ('생각', 1),
#   ('도', 1),
#   ('안', 1),
#   ('시간', 1),
#   ('다가', 1),
#   ('데', 1),
#   ('반찬', 1),
#   ('마땅치', 1),
#   ('혼자', 1),
#   ('해', 1),
#   ('결하', 1),
#   ('거', 1),
#   ('대충', 1),
#   ('금방', 1),
#   ('추천', 1),
#   ('어요', 1),
#   ('국물', 1),
#   ('글', 1),
#   ('입', 1),
#   ('시크', 1),
#   ('도도', 1),
#   ('토깽', 1),
#   ('살', 1),
#   ('효', 1)],
#  [('디저트', 2),
#   ('카페', 2),
#   ('커피', 2),
#   ('아메리카노', 2),
#   ('때', 2),
#   ('삼송', 1),
#   ('동화', 1),
#   ('감성', 1),
#   ('담', 1),
#   ('비', 1),
#   ('날', 1),
#   ('도', 1),
#   ('추천', 1),
#   ('주문', 1),
#   ('메뉴', 1),
#   ('등장', 1),
#   ('일행', 1),
#   ('맛', 1),
#   ('부터', 1),
#   ('블루베리', 1),
#   ('치즈케이크', 1),
#   ('꼭', 1),
#   ('선물', 1),
#   ('거마', 1),
#   ('보자기', 1),
#   ('모', 1),
#   ('양으로', 1),
#   ('나', 1),
#   ('것', 1),
#   ('마음', 1),
#   ('단방', 1),
#   ('향소', 1),
#   ('통', 1),
#   ('생활기록부', 1)],
#  [('꼬치', 3),
#   ('미미', 2),
#   ('사', 2),
#   ('원양', 2),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('요리', 2),
#   ('세트', 1),
#   ('저희', 1),
#   ('생', 1),
#   ('양', 1),
#   ('갈비살', 1),
#   ('어요', 1),
#   ('가지', 1),
#   ('칭다오', 1),
#   ('한잔', 1),
#   ('강력', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('리얼', 1),
#   ('후기', 1),
#   ('에픽', 1),
#   ('스터디', 1),
#   ('학원', 1)],
#  [('야채', 3),
#   ('전', 3),
#   ('법', 3),
#   ('날', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('요', 3),
#   ('해물', 2),
#   ('버섯', 2),
#   ('모', 2),
#   ('비', 2),
#   ('냉털', 1),
#   ('요리', 1),
#   ('글', 1),
#   ('사진', 1),
#   ('쿡', 1),
#   ('재료', 1),
#   ('피로', 1),
#   ('풀', 1),
#   ('어보', 1),
#   ('로', 1),
#   ('알', 1),
#   ('주말', 1),
#   ('보', 1),
#   ('내세', 1),
#   ('호기심', 1),
#   ('부자', 1),
#   ('언니', 1),
#   ('오늘', 1),
#   ('머', 1),
#   ('하노', 1)],
#  [('비', 3),
#   ('날', 3),
#   ('앞산', 2),
#   ('대구', 2),
#   ('손', 1),
#   ('칼국수', 1),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('이면', 1),
#   ('기분', 1),
#   ('뭔가', 1),
#   ('차', 1),
#   ('분해', 1),
#   ('건', 1),
#   ('수', 1),
#   ('그저께', 1),
#   ('순환도로', 1),
#   ('다른', 1),
#   ('가게', 1),
#   ('주차', 1),
#   ('매너', 1),
#   ('니니', 1),
#   ('오늘', 1),
#   ('처럼', 1),
#   ('국물', 1),
#   ('식사', 1),
#   ('요', 1),
#   ('하루', 1),
#   ('한걸음씩', 1)],
#  [('비', 8),
#   ('날', 7),
#   ('음식', 5),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('저녁', 1),
#   ('제', 1),
#   ('장바구니', 1),
#   ('목록', 1),
#   ('내일', 1),
#   ('오락가락', 1),
#   ('뭐', 1),
#   ('달타냥', 1),
#   ('하우스', 1)],
#  [('부침개', 3),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('부추', 1),
#   ('미나리', 1),
#   ('장떡', 1),
#   ('메뉴', 1),
#   ('전', 1),
#   ('완전', 1),
#   ('이요', 1),
#   ('조금', 1),
#   ('재료', 1),
#   ('사실', 1),
#   ('활용', 1),
#   ('하나', 1),
#   ('요리', 1),
#   ('만들기', 1),
#   ('점심', 1),
#   ('어요', 1),
#   ('정말', 1),
#   ('더', 1),
#   ('손', 1),
#   ('끝', 1),
#   ('완성', 1)],
#  [('칼국수', 4),
#   ('맛집', 4),
#   ('마을', 4),
#   ('추천', 4),
#   ('산내', 3),
#   ('샤브', 2),
#   ('비', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('점심', 2),
#   ('안녕', 1),
#   ('자주', 1),
#   ('요즘', 1),
#   ('종종', 1),
#   ('생각', 1),
#   ('마침', 1),
#   ('돈', 1),
#   ('산', 1),
#   ('오름', 1),
#   ('운정', 1),
#   ('평범', 1),
#   ('비범', 1),
#   ('그', 1),
#   ('사이', 1),
#   ('어디', 1),
#   ('쯤', 1)],
#  [('모듬', 3),
#   ('조개', 3),
#   ('칼국수', 3),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('청당', 1),
#   ('소문', 1),
#   ('사진', 1),
#   ('보시', 1),
#   ('것', 1),
#   ('처럼', 1),
#   ('바로', 1),
#   ('오늘', 1),
#   ('여기', 1),
#   ('청양고추', 1),
#   ('어서', 1),
#   ('매콤', 1),
#   ('나', 1),
#   ('게', 1),
#   ('기본', 1),
#   ('주문', 1),
#   ('진희', 1),
#   ('비숑', 1),
#   ('하동', 1),
#   ('동이', 1),
#   ('일상', 1)],
#  [('비', 4),
#   ('쭈꾸미', 4),
#   ('볶음', 4),
#   ('오덕', 3),
#   ('메뉴', 3),
#   ('이의', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('그', 2),
#   ('두번째', 1),
#   ('왕창', 1),
#   ('장마', 1),
#   ('예고', 1),
#   ('예상', 1),
#   ('만큼', 1),
#   ('래서', 1),
#   ('청년', 1)],
#  [('비', 3),
#   ('날', 3),
#   ('웨이', 2),
#   ('팅', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('맛집', 2),
#   ('노티', 1),
#   ('드', 1),
#   ('부산', 1),
#   ('해운대', 1),
#   ('카페', 1),
#   ('핫', 1),
#   ('소식', 1),
#   ('자마자', 1),
#   ('오픈', 1),
#   ('런', 1),
#   ('곳', 1),
#   ('워낙', 1),
#   ('하나', 1),
#   ('크림', 1),
#   ('고', 1),
#   ('소하', 1),
#   ('면서', 1),
#   ('빵', 1),
#   ('오', 1),
#   ('또', 1),
#   ('생각', 1),
#   ('맛', 1)],
#  [('날', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('부평', 2),
#   ('신', 1),
#   ('간', 1),
#   ('짬뽕', 1),
#   ('입맛', 1),
#   ('거나', 1),
#   ('를', 1),
#   ('고민', 1),
#   ('추천', 1),
#   ('남성', 1),
#   ('여성', 1),
#   ('분', 1),
#   ('더', 1),
#   ('것', 1),
#   ('생각', 1),
#   ('오픈', 1),
#   ('저녁', 1),
#   ('중간', 1),
#   ('브레이크', 1),
#   ('타임', 1),
#   ('유', 1),
#   ('홈', 1),
#   ('부동산', 1),
#   ('대표', 1),
#   ('이현종', 1)],
#  [('아나고', 5),
#   ('비', 3),
#   ('날', 3),
#   ('메뉴', 3),
#   ('맥주', 3),
#   ('한잔', 3),
#   ('추천', 2),
#   ('막창', 2),
#   ('고', 2),
#   ('수제', 2),
#   ('만두', 2),
#   ('어제', 1),
#   ('퇴근', 1),
#   ('시간', 1),
#   ('급', 1),
#   ('변경', 1),
#   ('포기', 1),
#   ('순', 1),
#   ('쌈', 1),
#   ('하루', 1),
#   ('한걸음씩', 1)],
#  [('칼국수', 9),
#   ('비', 4),
#   ('날', 4),
#   ('메뉴', 4),
#   ('추천', 3),
#   ('장정원', 3),
#   ('택배', 3),
#   ('요리', 3),
#   ('밀키', 2),
#   ('트', 2),
#   ('캠핑', 2),
#   ('맛집', 2),
#   ('입', 1),
#   ('법', 1),
#   ('의', 1),
#   ('포토', 1),
#   ('로그', 1)],
#  [('칼국수', 7),
#   ('메뉴', 4),
#   ('캠핑', 4),
#   ('추천', 3),
#   ('밀키', 3),
#   ('트', 3),
#   ('비', 2),
#   ('날', 2),
#   ('정원', 2),
#   ('요리', 2),
#   ('로', 1),
#   ('강추', 1),
#   ('국수', 1),
#   ('맛집', 1),
#   ('택배', 1),
#   ('바지락', 1),
#   ('법', 1),
#   ('장정원', 1)],
#  [('일산', 3),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('맛집', 1),
#   ('비', 1),
#   ('칼국수', 1),
#   ('웨이', 1),
#   ('팅', 1),
#   ('주차', 1),
#   ('진짜', 1),
#   ('선택', 1),
#   ('었던', 1),
#   ('것', 1),
#   ('뭘', 1),
#   ('고민', 1),
#   ('때', 1),
#   ('한번', 1),
#   ('뱃골', 1),
#   ('크시', 1),
#   ('면', 1),
#   ('완칼', 1),
#   ('공기밥', 1),
#   ('추가', 1),
#   ('말', 1),
#   ('거', 1),
#   ('드립', 1),
#   ('제', 1),
#   ('어요', 1),
#   ('꽉', 1),
#   ('찬', 1),
#   ('행복', 1)],
#  [('메뉴', 4),
#   ('비', 3),
#   ('추천', 3),
#   ('수제비', 2),
#   ('날', 2),
#   ('오늘', 2),
#   ('감자', 1),
#   ('저녁', 1),
#   ('메추', 1),
#   ('마트', 1),
#   ('사리', 1),
#   ('보이', 1),
#   ('꼭', 1),
#   ('한번', 1),
#   ('어보', 1),
#   ('해', 1),
#   ('여러분', 1),
#   ('건강', 1),
#   ('하루', 1),
#   ('보', 1),
#   ('내시', 1),
#   ('길', 1),
#   ('옆집', 1),
#   ('영양사', 1),
#   ('언니', 1)],
#  [('비', 4),
#   ('날', 2),
#   ('순두부', 2),
#   ('맛집', 2),
#   ('점심', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('동구', 1),
#   ('일산', 1),
#   ('때', 1),
#   ('만', 1),
#   ('집', 1),
#   ('어서', 1),
#   ('글', 1),
#   ('지금', 1),
#   ('낮', 1),
#   ('안', 1),
#   ('어요', 1),
#   ('더', 1),
#   ('거', 1),
#   ('전', 1),
#   ('원래', 1),
#   ('다핸즈', 1)],
#  [('호강', 3),
#   ('불', 3),
#   ('날', 3),
#   ('메뉴', 3),
#   ('비', 2),
#   ('추천', 2),
#   ('신내동', 1),
#   ('점심', 1),
#   ('맛집', 1),
#   ('알', 1),
#   ('아보', 1),
#   ('해드', 1),
#   ('리도', 1),
#   ('록', 1),
#   ('여러분', 1),
#   ('이면', 1),
#   ('가장', 1),
#   ('먼저', 1),
#   ('참숯', 1),
#   ('석쇠', 1),
#   ('불고기', 1),
#   ('김치찌개', 1),
#   ('더욱', 1),
#   ('더', 1),
#   ('감칠맛', 1),
#   ('수', 1),
#   ('백의', 1)],
#  [('날', 3),
#   ('바지락', 3),
#   ('칼국수', 3),
#   ('비', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('방법', 2),
#   ('오늘', 2),
#   ('소아과', 1),
#   ('길', 1),
#   ('마트', 1),
#   ('가용', 1),
#   ('가장', 1),
#   ('먼저', 1),
#   ('일', 1),
#   ('해감', 1),
#   ('해주', 1),
#   ('기', 1),
#   ('손', 1),
#   ('바락바락', 1),
#   ('그녀', 1),
#   ('이야기', 1)],
#  [('비', 4),
#   ('날', 4),
#   ('메뉴', 4),
#   ('점심', 3),
#   ('추천', 2),
#   ('빗', 1),
#   ('소리', 1),
#   ('면서', 1),
#   ('더', 1),
#   ('지금', 1),
#   ('부터', 1),
#   ('알', 1),
#   ('아보', 1),
#   ('야채', 1),
#   ('김우동', 1),
#   ('가장', 1),
#   ('먼저', 1),
#   ('생각', 1),
#   ('무엇', 1),
#   ('저', 1),
#   ('바삭', 1),
#   ('분식', 1),
#   ('김밥', 1),
#   ('창업', 1),
#   ('연구소', 1)],
#  [('날', 3),
#   ('남양주', 2),
#   ('카페', 2),
#   ('추천', 2),
#   ('인생', 2),
#   ('커피', 2),
#   ('언니', 2),
#   ('수다', 2),
#   ('떨기', 2),
#   ('구경', 2),
#   ('화장실', 2),
#   ('안녕', 1),
#   ('유진', 1),
#   ('어뭉', 1),
#   ('이입', 1),
#   ('다음', 1),
#   ('비', 1),
#   ('안', 1),
#   ('꼭', 1),
#   ('방문', 1),
#   ('실외', 1),
#   ('마음껏', 1),
#   ('어요', 1),
#   ('실내', 1),
#   ('마지막', 1),
#   ('똑똑', 1),
#   ('일', 1),
#   ('상속', 1),
#   ('드가즈', 1)],
#  [('추천', 4),
#   ('데이트', 4),
#   ('날', 3),
#   ('메뉴', 2),
#   ('카페인', 1),
#   ('리', 1),
#   ('서울', 1),
#   ('요', 1),
#   ('두', 1),
#   ('개', 1),
#   ('새우', 1),
#   ('버거', 1),
#   ('소고기', 1),
#   ('파스타', 1),
#   ('이름', 1),
#   ('이', 1),
#   ('었는데', 1),
#   ('기억', 1),
#   ('안남', 1),
#   ('진짜', 1),
#   ('어요', 1),
#   ('기도', 1),
#   ('헤드윅', 1),
#   ('스튜디오', 1),
#   ('전시', 1)],
#  [('칼국수', 6),
#   ('맛집', 4),
#   ('비', 4),
#   ('날', 3),
#   ('메뉴', 3),
#   ('대전', 2),
#   ('신탄진', 2),
#   ('현지', 2),
#   ('부추', 1),
#   ('추천', 1),
#   ('충청도', 1),
#   ('권', 1),
#   ('아지', 1),
#   ('피해', 1),
#   ('요즘', 1),
#   ('바지락', 1),
#   ('해물칼국수', 1),
#   ('뜸', 1)],
#  [('날', 3),
#   ('추천', 3),
#   ('가로수길', 3),
#   ('뭐', 3),
#   ('창원', 2),
#   ('맛집', 2),
#   ('샤브', 2),
#   ('메뉴', 1),
#   ('용호동', 1),
#   ('노도', 1),
#   ('태', 1),
#   ('비', 1),
#   ('해도', 1),
#   ('국물', 1),
#   ('생각', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('요즘', 1),
#   ('핫', 1),
#   ('샤브노', 1),
#   ('도태', 1),
#   ('얼', 1),
#   ('미나리', 1)],
#  [('콩나물국밥', 4),
#   ('추천', 3),
#   ('메뉴', 3),
#   ('비', 2),
#   ('날', 2),
#   ('전주현', 2),
#   ('대옥', 2),
#   ('두두', 2),
#   ('주차', 1),
#   ('가능', 1),
#   ('시원', 1),
#   ('하니', 1),
#   ('해장국', 1),
#   ('가지', 1),
#   ('종류', 1),
#   ('밥', 1),
#   ('숫', 1),
#   ('가락', 1),
#   ('더니', 1),
#   ('오징어젓', 1),
#   ('어요', 1),
#   ('캬', 1),
#   ('미미', 1),
#   ('리뷰', 1),
#   ('월드', 1)],
#  [('메뉴', 4),
#   ('날', 2),
#   ('판', 2),
#   ('그', 2),
#   ('의정부', 1),
#   ('의정부역', 1),
#   ('후기', 1),
#   ('및', 1),
#   ('추천', 1),
#   ('해리포터', 1),
#   ('편', 1),
#   ('카', 1),
#   ('반의', 1),
#   ('죄수', 1),
#   ('나', 1),
#   ('괴물', 1),
#   ('책', 1),
#   ('열', 1),
#   ('어보', 1),
#   ('비', 1),
#   ('부엉이', 1),
#   ('산장', 1),
#   ('항', 1),
#   ('정수', 1),
#   ('육', 1),
#   ('보쌈김치', 1),
#   ('또', 1),
#   ('래서', 1),
#   ('그냥', 1),
#   ('놈', 1)],
#  [('오덕', 4),
#   ('비', 3),
#   ('메뉴', 3),
#   ('이의', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('기원', 2),
#   ('쌀', 1),
#   ('그', 1),
#   ('첫', 1),
#   ('순두부', 1),
#   ('짬뽕밥', 1),
#   ('이예', 1),
#   ('몇', 1),
#   ('일전', 1),
#   ('까지', 1),
#   ('장마', 1),
#   ('태풍', 1),
#   ('지나', 1),
#   ('피해', 1),
#   ('또', 1),
#   ('장마철', 1),
#   ('더라도', 1),
#   ('청년', 1)],
#  [('비', 3),
#   ('날', 3),
#   ('음식', 3),
#   ('간단', 3),
#   ('점심', 3),
#   ('메뉴', 3),
#   ('야채', 3),
#   ('깻잎', 2),
#   ('고추전', 2),
#   ('깻잎전', 2),
#   ('전', 2),
#   ('법', 1),
#   ('오늘', 1),
#   ('바삭', 1),
#   ('내면', 1),
#   ('로', 1),
#   ('추천', 1),
#   ('막걸리', 1),
#   ('안주', 1),
#   ('요리', 1),
#   ('집밥', 1),
#   ('반찬', 1),
#   ('가시', 1),
#   ('장미', 1),
#   ('수다', 1)],
#  [('대구', 5),
#   ('핸즈', 3),
#   ('커피', 3),
#   ('미술관', 3),
#   ('비', 2),
#   ('날', 2),
#   ('점', 2),
#   ('메뉴', 2),
#   ('데이트', 1),
#   ('단체', 1),
#   ('석', 1),
#   ('그', 1),
#   ('외', 1),
#   ('케이크', 1),
#   ('쿠키', 1),
#   ('이', 1),
#   ('라서', 1),
#   ('말차', 1),
#   ('어요', 1),
#   ('카페', 1),
#   ('추천', 1),
#   ('센스', 1),
#   ('거', 1),
#   ('가요', 1)],
#  [('짬뽕', 3),
#   ('구미', 2),
#   ('만리', 2),
#   ('향', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('어요', 2),
#   ('주문', 2),
#   ('공단', 1),
#   ('동락', 1),
#   ('공원', 1),
#   ('맛집', 1),
#   ('중국집', 1),
#   ('메', 1),
#   ('니아', 1),
#   ('친구', 1),
#   ('최애라', 1),
#   ('투데이', 1),
#   ('시', 1),
#   ('인하', 1),
#   ('이벤트', 1),
#   ('마침', 1),
#   ('비', 1),
#   ('호호', 1),
#   ('라이프', 1)],
#  [('조개구이', 4),
#   ('비', 4),
#   ('날', 3),
#   ('파주', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('무한리필', 2),
#   ('고기', 2),
#   ('까지', 2),
#   ('가성', 1),
#   ('오늘', 1),
#   ('우리동네', 1),
#   ('집', 1),
#   ('시원', 1),
#   ('맥주', 1),
#   ('한잔', 1),
#   ('신선', 1),
#   ('캬', 1),
#   ('정말', 1),
#   ('운치', 1),
#   ('사실', 1),
#   ('조개', 1),
#   ('자칫', 1),
#   ('베이비', 1),
#   ('슈', 1),
#   ('맛집', 1),
#   ('기행', 1)],
#  [('바지락', 4),
#   ('날', 3),
#   ('메뉴', 3),
#   ('술찜', 2),
#   ('레시피', 2),
#   ('저녁', 2),
#   ('추천', 2),
#   ('비', 2),
#   ('국물', 2),
#   ('처럼', 2),
#   ('해감', 1),
#   ('지난주', 1),
#   ('소개', 1),
#   ('보', 1),
#   ('려고', 1),
#   ('살짝', 1),
#   ('탕', 1),
#   ('어요', 1),
#   ('양은', 1),
#   ('선택', 1),
#   ('조금', 1),
#   ('비자', 1),
#   ('락탕', 1),
#   ('의후다닥', 1)],
#  [('비', 3),
#   ('수', 3),
#   ('메뉴', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('잔치국수', 2),
#   ('대림', 2),
#   ('음식', 1),
#   ('시나', 1),
#   ('모두', 1),
#   ('낼', 1),
#   ('습', 1),
#   ('닷', 1),
#   ('절대', 1),
#   ('가격', 1),
#   ('누구', 1),
#   ('아하', 1),
#   ('요', 1),
#   ('지금', 1),
#   ('까지', 1),
#   ('에이스', 1),
#   ('대학교', 1),
#   ('공식', 1),
#   ('블로그', 1)],
#  [('쫄면', 4),
#   ('순두부', 4),
#   ('메뉴', 2),
#   ('아내', 2),
#   ('아하', 2),
#   ('저', 2),
#   ('비', 1),
#   ('날', 1),
#   ('추천', 1),
#   ('점심', 1),
#   ('겸', 1),
#   ('저녁식사', 1),
#   ('선택', 1),
#   ('유난', 1),
#   ('생각', 1),
#   ('김', 1),
#   ('얘', 1),
#   ('기하', 1),
#   ('통닭', 1),
#   ('닭', 1),
#   ('날개', 1),
#   ('닭다리', 1),
#   ('시금치', 1),
#   ('미소', 1),
#   ('된장', 1),
#   ('코리아', 1),
#   ('롱비치', 1)],
#  [('메뉴', 6),
#   ('파스타', 4),
#   ('날', 2),
#   ('추천', 2),
#   ('다른', 1),
#   ('생각', 1),
#   ('날때', 1),
#   ('매번', 1),
#   ('가로수길', 1),
#   ('맛집', 1),
#   ('검색', 1),
#   ('또', 1),
#   ('브런치', 1),
#   ('원', 1),
#   ('정말', 1),
#   ('오늘', 1),
#   ('선택', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('취향', 1),
#   ('하나', 1),
#   ('케잇', 1),
#   ('음식', 1)],
#  [('평촌', 3),
#   ('롯데', 3),
#   ('백화점', 3),
#   ('맛집', 3),
#   ('비', 3),
#   ('날', 3),
#   ('메뉴', 3),
#   ('추천', 3),
#   ('용호동', 3),
#   ('낙지', 3),
#   ('오늘', 1),
#   ('룰루', 1),
#   ('도', 1),
#   ('데리', 1),
#   ('엄마', 1),
#   ('모시', 1),
#   ('집', 1),
#   ('어요', 1),
#   ('로', 1),
#   ('매콤', 1),
#   ('낙지전골', 1),
#   ('최고', 1),
#   ('짱', 1),
#   ('언니', 1),
#   ('여행', 1),
#   ('일기', 1)],
#  [('비', 3),
#   ('날', 3),
#   ('요즘', 2),
#   ('처럼', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('백설', 2),
#   ('오꼬', 2),
#   ('노미', 2),
#   ('끼', 2),
#   ('믹스', 2),
#   ('언제', 1),
#   ('까지', 1),
#   ('올런', 1),
#   ('장마', 1),
#   ('계속', 1),
#   ('오코노미야키', 1),
#   ('맥주', 1),
#   ('한잔', 1),
#   ('모습', 1),
#   ('어가', 1),
#   ('재료', 1),
#   ('따라서', 1),
#   ('종류', 1),
#   ('염', 1),
#   ('이의', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('일상', 1),
#   ('노트', 1)],
#  [('비', 4),
#   ('날', 3),
#   ('데이트', 2),
#   ('삼정', 2),
#   ('타워', 2),
#   ('유동', 2),
#   ('커피', 2),
#   ('추천', 2),
#   ('카페', 1),
#   ('메뉴', 1),
#   ('제', 1),
#   ('방문', 1),
#   ('건물', 1),
#   ('안', 1),
#   ('완전', 1),
#   ('지도', 1),
#   ('어요', 1),
#   ('이나', 1),
#   ('여름', 1),
#   ('식사', 1),
#   ('드', 1),
#   ('오늘', 1),
#   ('우리', 1)],
#  [('믹스', 3),
#   ('법', 3),
#   ('비', 3),
#   ('날', 3),
#   ('음식', 3),
#   ('추천', 2),
#   ('상품', 2),
#   ('김치부침개', 2),
#   ('메뉴', 2),
#   ('노', 2),
#   ('브랜드', 2),
#   ('추적', 2),
#   ('생각', 1),
#   ('밀가루', 1),
#   ('반죽', 1),
#   ('야식', 1),
#   ('이나', 1),
#   ('드', 1),
#   ('시기', 1),
#   ('김치전', 1),
#   ('간편', 1),
#   ('소개', 1),
#   ('살림', 1),
#   ('후반전', 1),
#   ('푸드', 1),
#   ('플루', 1)],
#  [('메뉴', 4),
#   ('날', 3),
#   ('추천', 3),
#   ('비', 2),
#   ('하나비', 2),
#   ('쇼유라멘', 2),
#   ('가기', 1),
#   ('라멘', 1),
#   ('맛집', 1),
#   ('어간', 1),
#   ('칭찬', 1),
#   ('창가', 1),
#   ('그릇', 1),
#   ('면서', 1),
#   ('먹기', 1),
#   ('외', 1),
#   ('다양', 1),
#   ('준비', 1),
#   ('맑은', 1),
#   ('마제', 1),
#   ('소바', 1),
#   ('원조', 1),
#   ('공식', 1),
#   ('블로그', 1)],
#  [('추천', 3),
#   ('쌀국수', 2),
#   ('비', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('베트남', 1),
#   ('현지', 1),
#   ('맛집', 1),
#   ('중마동', 1),
#   ('나', 1),
#   ('동안', 1),
#   ('한번', 1),
#   ('어보', 1),
#   ('셔', 1),
#   ('것', 1),
#   ('포', 1),
#   ('곳', 1),
#   ('제', 1),
#   ('최애', 1),
#   ('리스트', 1),
#   ('등', 1),
#   ('근처', 1),
#   ('방문', 1),
#   ('일', 1),
#   ('꼭꼭', 1),
#   ('꼭', 1),
#   ('보시', 1),
#   ('거', 1),
#   ('강추', 1),
#   ('드릴', 1),
#   ('요', 1),
#   ('핫또', 1),
#   ('의', 1),
#   ('핫', 1),
#   ('기록', 1)],
#  [('비', 3),
#   ('초록', 3),
#   ('마을', 3),
#   ('장마철', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('포장마차', 2),
#   ('친환경', 2),
#   ('시원', 1),
#   ('어묵탕', 1),
#   ('의', 1),
#   ('제법', 1),
#   ('운치', 1),
#   ('감성', 1),
#   ('로', 1),
#   ('꿀꿀', 1),
#   ('기분', 1),
#   ('보아', 1),
# ...
#   ('처럼', 1),
#   ('이면', 1),
#   ('수제비', 1),
#   ('김치전', 1),
#   ('감자전', 1),
#   ('해물파전', 1),
#   ('먹기', 1),
#   ('시원', 1),
#   ('끝', 1),
#   ('내주', 1),
#   ('완성', 1),
#   ('전업', 1),
#   ('주부', 1),
#   ('스펙', 1)],
#  [('포케', 4),
#   ('맛집', 3),
#   ('건강', 2),
#   ('날', 2),
#   ('우산', 2),
#   ('대구', 1),
#   ('둔산동', 1),
#   ('비', 1),
#   ('미소', 1),
#   ('행', 1),
#   ('그릇', 1),
#   ('싹싹', 1),
#   ('먹음', 1),
#   ('후문', 1),
#   ('쪽', 1),
#   ('고요', 1),
#   ('포켑집이댜', 1),
#   ('추천', 1),
#   ('늘', 1),
#   ('하루', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('행복', 1)],
#  [('비', 5),
#   ('메뉴', 4),
#   ('날', 3),
#   ('생각', 2),
#   ('그', 2),
#   ('추천', 2),
#   ('위', 2),
#   ('가오', 1),
#   ('더', 1),
#   ('제', 1),
#   ('기준', 1),
#   ('정', 1),
#   ('하자', 1),
#   ('단연', 1),
#   ('김치부침개', 1),
#   ('내', 1),
#   ('마음속', 1),
#   ('테두리', 1),
#   ('살짝', 1),
#   ('바삭', 1),
#   ('진정', 1),
#   ('메르', 1),
#   ('제니', 1)],
#  [('오뎅', 8),
#   ('군자', 6),
#   ('오', 5),
#   ('사사', 5),
#   ('바', 4),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('메뉴', 1),
#   ('꼬치', 1),
#   ('주문', 1),
#   ('친', 1),
#   ('절하', 1),
#   ('날씨', 1),
#   ('다시', 1),
#   ('가야', 1),
#   ('징', 1),
#   ('탕', 1),
#   ('술집', 1),
#   ('타코야끼', 1),
#   ('민뎅', 1),
#   ('블로그', 1)],
#  [('무민', 3),
#   ('추천', 3),
#   ('랜드', 2),
#   ('제주', 2),
#   ('곳', 2),
#   ('비', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('추가', 1),
#   ('생각', 1),
#   ('규모', 1),
#   ('이유', 1),
#   ('팬케이크', 1),
#   ('부터', 1),
#   ('피자', 1),
#   ('파스타', 1),
#   ('등', 1),
#   ('푸드', 1),
#   ('다양', 1),
#   ('카페', 1),
#   ('이용', 1),
#   ('시간', 1)],
#  [('비', 4),
#   ('안산선', 3),
#   ('부점', 3),
#   ('날', 3),
#   ('발', 3),
#   ('도스', 3),
#   ('커피', 3),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('안녕', 1),
#   ('과', 1),
#   ('드립', 1),
#   ('도오', 1),
#   ('그', 1),
#   ('래서', 1),
#   ('니', 1),
#   ('생각', 1),
#   ('이나', 1),
#   ('은', 1),
#   ('달달', 1),
#   ('해', 1)],
#  [('닭', 3),
#   ('메뉴', 3),
#   ('마리', 2),
#   ('쭈꾸미', 2),
#   ('호', 1),
#   ('맛집', 1),
#   ('비', 1),
#   ('날', 1),
#   ('저녁', 1),
#   ('로', 1),
#   ('친구', 1),
#   ('양', 1),
#   ('추천', 1),
#   ('고고씽', 1),
#   ('천호동', 1),
#   ('골목', 1),
#   ('어서', 1),
#   ('독도', 1),
#   ('호점', 1),
#   ('옆', 1),
#   ('바로', 1),
#   ('보', 1),
#   ('여요', 1),
#   ('칼국수', 1),
#   ('사리', 1),
#   ('또', 1),
#   ('만', 1),
#   ('곳', 1),
#   ('진국', 1),
#   ('니', 1),
#   ('어요', 1),
#   ('초록', 1),
#   ('기린', 1),
#   ('숲', 1),
#   ('프', 1)],
#  [('파전', 3),
#   ('유강', 2),
#   ('날', 2),
#   ('주문', 2),
#   ('맛집', 1),
#   ('막걸리', 1),
#   ('포장', 1),
#   ('시', 1),
#   ('미리', 1),
#   ('방문', 1),
#   ('것', 1),
#   ('추천', 1),
#   ('매장', 1),
#   ('친절', 1),
#   ('하진', 1),
#   ('육전', 1),
#   ('곳', 1),
#   ('약간', 1),
#   ('츤데레', 1),
#   ('개', 1),
#   ('인적', 1),
#   ('견해', 1),
#   ('오해', 1),
#   ('금지', 1),
#   ('은', 1),
#   ('역시', 1),
#   ('전이', 1),
#   ('부침개', 1),
#   ('만', 1),
#   ('게', 1),
#   ('송모다', 1),
#   ('리뷰', 1),
#   ('로그', 1)],
#  [('수제비', 5),
#   ('행신동', 5),
#   ('맛집', 4),
#   ('메뉴', 3),
#   ('고기', 3),
#   ('완자전', 3),
#   ('이집', 3),
#   ('날', 2),
#   ('의', 1),
#   ('점심', 1),
#   ('추천', 1),
#   ('칼제비', 1),
#   ('비', 1),
#   ('솔직', 1),
#   ('리뷰', 1)],
#  [('칼국수', 3),
#   ('맛집', 2),
#   ('메뉴', 2),
#   ('룸', 2),
#   ('왕만', 1),
#   ('비', 1),
#   ('날', 1),
#   ('추천', 1),
#   ('남촌', 1),
#   ('최애', 1),
#   ('여서', 1),
#   ('포스팅', 1),
#   ('처음', 1),
#   ('달', 1),
#   ('몇번', 1),
#   ('씩', 1),
#   ('꼭', 1),
#   ('거', 1),
#   ('바로', 1),
#   ('보이', 1),
#   ('홀', 1),
#   ('식탁', 1),
#   ('테이블', 1),
#   ('안쪽', 1),
#   ('더', 1),
#   ('어가', 1),
#   ('좌', 1),
#   ('어요', 1),
#   ('이름', 1),
#   ('랍', 1),
#   ('스타', 1),
#   ('우당', 1)],
#  [('비', 3),
#   ('날', 2),
#   ('투어', 2),
#   ('어요', 2),
#   ('사계', 2),
#   ('채', 2),
#   ('언덕', 2),
#   ('삿포로', 1),
#   ('후', 1),
#   ('노', 1),
#   ('에이', 1),
#   ('버스', 1),
#   ('추천', 1),
#   ('훗카이도', 1),
#   ('랩', 1),
#   ('메뉴', 1),
#   ('나', 1),
#   ('우유', 1),
#   ('진짜', 1),
#   ('별도', 1),
#   ('포스팅', 1),
#   ('려고', 1),
#   ('해', 1),
#   ('가장', 1),
#   ('먼저', 1),
#   ('방문', 1),
#   ('곳', 1),
#   ('이', 1),
#   ('날씨', 1),
#   ('조금', 1),
#   ('본래', 1),
#   ('일정', 1),
#   ('약간', 1),
#   ('어른', 1),
#   ('성장', 1),
#   ('일지', 1)],
#  [('금복주', 4),
#   ('류', 4),
#   ('날', 2),
#   ('막걸리', 2),
#   ('미사', 2),
#   ('술집', 2),
#   ('메뉴', 2),
#   ('비', 1),
#   ('맛집', 1),
#   ('맛', 1),
#   ('파전', 1),
#   ('찾기', 1),
#   ('주점', 1),
#   ('안녕', 1),
#   ('잇님들', 1),
#   ('오늘', 1),
#   ('직원', 1),
#   ('분', 1),
#   ('호출', 1),
#   ('태블릿', 1),
#   ('추천', 1),
#   ('를', 1),
#   ('간단', 1),
#   ('일단', 1),
#   ('매르', 1),
#   ('리뷰', 1),
#   ('월드', 1)],
#  [('양주', 9),
#   ('카페', 9),
#   ('비', 3),
#   ('날', 3),
#   ('브루', 3),
#   ('추천', 2),
#   ('통창', 2),
#   ('도', 1),
#   ('데', 1),
#   ('어디', 1),
#   ('가지', 1),
#   ('다가', 1),
#   ('발견', 1),
#   ('때문', 1),
#   ('트', 1),
#   ('여보', 1),
#   ('장흥', 1),
#   ('루루', 1),
#   ('박사', 1)],
#  [('닭발', 7),
#   ('카페', 3),
#   ('거리', 3),
#   ('비', 3),
#   ('날', 3),
#   ('막걸리', 3),
#   ('구역', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('맛집', 2),
#   ('포장', 1),
#   ('후기', 1),
#   ('담', 1),
#   ('또', 1),
#   ('예정', 1),
#   ('용인', 1),
#   ('조합', 1),
#   ('소주', 1),
#   ('마을', 1),
#   ('한라산', 1),
#   ('도', 1),
#   ('린지', 1),
#   ('여행', 1),
#   ('과일', 1),
#   ('상', 1)],
#  [('맛집', 4),
#   ('두메', 3),
#   ('골', 3),
#   ('비', 3),
#   ('날', 3),
#   ('메뉴', 3),
#   ('길음동', 2),
#   ('마늘', 2),
#   ('보쌈', 2),
#   ('찰떡', 2),
#   ('칼국수', 1),
#   ('까지', 1),
#   ('삼양', 1),
#   ('사거리역', 1),
#   ('미아', 1),
#   ('추천', 1),
#   ('어제', 1),
#   ('비도', 1),
#   ('완전', 1),
#   ('었다', 1),
#   ('테이블', 1),
#   ('만석', 1),
#   ('어르신', 1),
#   ('막걸리', 1),
#   ('한잔', 1),
#   ('나', 1),
#   ('김만', 1),
#   ('조잉', 1)],
#  [('비', 3),
#   ('날', 3),
#   ('꼼장어', 2),
#   ('메뉴', 2),
#   ('부산', 1),
#   ('자갈치', 1),
#   ('대방역', 1),
#   ('추천', 1),
#   ('꼬들꼬들', 1),
#   ('오래', 1),
#   ('고로', 1),
#   ('때', 1),
#   ('누룽지', 1),
#   ('주시', 1),
#   ('닭발', 1),
#   ('수가', 1),
#   ('배부', 1),
#   ('름', 1),
#   ('생각', 1),
#   ('다음', 1),
#   ('한번', 1),
#   ('더', 1),
#   ('셰일', 1),
#   ('의', 1),
#   ('생활', 1)],
#  [('날', 3),
#   ('맛집', 2),
#   ('뽕', 2),
#   ('신인', 2),
#   ('더', 2),
#   ('가든', 2),
#   ('퓨전', 1),
#   ('짬뽕', 1),
#   ('호점', 1),
#   ('점심', 1),
#   ('메뉴', 1),
#   ('초이스', 1),
#   ('점원', 1),
#   ('테이크아웃', 1),
#   ('해달', 1),
#   ('뻔', 1),
#   ('국물', 1),
#   ('특별', 1),
#   ('부담', 1),
#   ('맛', 1),
#   ('거', 1),
#   ('때', 1),
#   ('천호동', 1),
#   ('추천', 1),
#   ('해', 1),
#   ('여기', 1),
#   ('까지', 1),
#   ('쾡쾡', 1)],
#  [('메뉴', 4),
#   ('김치전', 3),
#   ('비', 3),
#   ('날', 3),
#   ('만들기', 2),
#   ('추천', 2),
#   ('주말', 2),
#   ('오늘', 1),
#   ('일요일', 1),
#   ('하루', 1),
#   ('종일', 1),
#   ('봄비', 1),
#   ('은', 1),
#   ('부침개', 1),
#   ('진리', 1),
#   ('냉장고', 1),
#   ('묵은지', 1),
#   ('해물', 1),
#   ('좀', 1),
#   ('어서', 1),
#   ('바로', 1),
#   ('어요', 1),
#   ('써니', 1),
#   ('쿡', 1),
#   ('힐링', 1),
#   ('푸드', 1),
#   ('스토리', 1)],
#  [('제주도', 3),
#   ('날', 3),
#   ('비', 2),
#   ('오설록티뮤지엄', 2),
#   ('여행', 2),
#   ('호텔', 2),
#   ('곳', 1),
#   ('가기', 1),
#   ('카페나', 1),
#   ('장소', 1),
#   ('아가', 1),
#   ('그', 1),
#   ('분위기', 1),
#   ('넷째', 1),
#   ('코스', 1),
#   ('제주', 1),
#   ('신라', 1),
#   ('더', 1),
#   ('파크', 1),
#   ('뷰', 1),
#   ('뷔페', 1),
#   ('롯데', 1),
#   ('아트', 1),
#   ('빌라', 1),
#   ('스', 1),
#   ('체크', 1),
#   ('수영', 1),
#   ('포도', 1),
#   ('인생', 1),
#   ('처럼', 1)],
#  [('부침개', 4),
#   ('바삭', 2),
#   ('법', 2),
#   ('밀가루', 2),
#   ('간장', 2),
#   ('소스', 2),
#   ('비', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('푸드', 2),
#   ('쿡', 2),
#   ('소리', 2),
#   ('음식', 1),
#   ('글', 1),
#   ('사진', 1),
#   ('김치', 1),
#   ('음심', 1),
#   ('비데', 1),
#   ('빗', 1),
#   ('생각', 1),
#   ('이나', 1),
#   ('부지런', 1),
#   ('간식', 1),
#   ('요리', 1),
#   ('로', 1),
#   ('한장', 1),
#   ('맛집', 1),
#   ('여행', 1)],
#  [('메뉴', 3),
#   ('비', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('화순', 2),
#   ('능주', 2),
#   ('식당', 2),
#   ('소머리국밥', 2),
#   ('곳', 2),
#   ('국밥', 2),
#   ('삼거리', 1),
#   ('단골', 1),
#   ('가격', 1),
#   ('다른', 1),
#   ('차이', 1),
#   ('어요', 1),
#   ('쟁반', 1),
#   ('온', 1),
#   ('침', 1),
#   ('제', 1),
#   ('추', 1),
#   ('천하', 1),
#   ('법', 1),
#   ('이지', 1),
#   ('가시', 1),
#   ('분', 1),
#   ('밤', 1),
#   ('농', 1),
#   ('부들', 1),
#   ('밤농', 1),
#   ('프리', 1),
#   ('마켓', 1),
#   ('안전', 1),
#   ('농산물', 1)],
#  [('날', 2),
#   ('베이글', 2),
#   ('메뉴', 2),
#   ('아침', 1),
#   ('공덕', 1),
#   ('아이엠', 1),
#   ('전', 1),
#   ('가격', 1),
#   ('무료', 1),
#   ('러스크', 1),
#   ('창가', 1),
#   ('등장', 1),
#   ('손', 1),
#   ('사진', 1),
#   ('찍기', 1),
#   ('대기', 1),
#   ('여전', 1),
#   ('다소곳', 1),
#   ('이번', 1),
#   ('달', 1),
#   ('가지', 1),
#   ('동안', 1),
#   ('도', 1),
#   ('보고', 1),
#   ('시간', 1),
#   ('비도', 1),
#   ('인지', 1),
#   ('매장', 1),
#   ('오랜만', 1),
#   ('여유', 1),
#   ('어서', 1),
#   ('소', 1),
#   ('소한', 1),
#   ('일상', 1)],
#  [('카페', 2),
#   ('날', 2),
#   ('면서', 2),
#   ('비', 2),
#   ('사월역', 1),
#   ('도', 1),
#   ('켑트', 1),
#   ('베이커', 1),
#   ('스', 1),
#   ('친', 1),
#   ('구들', 1),
#   ('저번', 1),
#   ('부터', 1),
#   ('유명', 1),
#   ('베이커리', 1),
#   ('추천', 1),
#   ('가보', 1),
#   ('자고', 1),
#   ('은', 1),
#   ('역시', 1),
#   ('커피', 1),
#   ('구', 1),
#   ('경하', 1),
#   ('라떼', 1),
#   ('한잔', 1),
#   ('해주', 1),
#   ('감성', 1),
#   ('막', 1),
#   ('현명', 1),
#   ('경제', 1),
#   ('이야기', 1)],
#  [('날', 4),
#   ('곳', 4),
#   ('비', 3),
#   ('서울', 2),
#   ('도도', 2),
#   ('잠실', 1),
#   ('브런치', 1),
#   ('집', 1),
#   ('추천', 1),
#   ('중', 1),
#   ('메뉴', 1),
#   ('건', 1),
#   ('었는데', 1),
#   ('번', 1),
#   ('보고', 1),
#   ('택했다', 1),
#   ('세상', 1),
#   ('모든', 1),
#   ('아침', 1),
#   ('롯데', 1),
#   ('월드', 1),
#   ('만', 1),
#   ('역시', 1),
#   ('옴짝', 1),
#   ('달싹', 1),
#   ('못', 1),
#   ('맛집', 1),
#   ('여행', 1),
#   ('일상', 1),
#   ('기록', 1),
#   ('블로그', 1)],
#  [('칼국수', 4),
#   ('알곤', 3),
#   ('날', 2),
#   ('캬', 2),
#   ('밀키', 1),
#   ('트', 1),
#   ('추천', 1),
#   ('진지', 1),
#   ('시원', 1),
#   ('계란', 1),
#   ('솔솔', 1),
#   ('풀', 1),
#   ('청양고추', 1),
#   ('살짝', 1),
#   ('박아', 1),
#   ('임창정', 1),
#   ('오라버니', 1),
#   ('시', 1),
#   ('그니', 1),
#   ('처', 1),
#   ('메뉴', 1),
#   ('인', 1),
#   ('집', 1),
#   ('밀', 1),
#   ('키트', 1),
#   ('수', 1),
#   ('제품', 1),
#   ('우리', 1),
#   ('김쉐프', 1),
#   ('님', 1),
#   ('완성', 1),
#   ('작품', 1),
#   ('다섯', 1),
#   ('개', 1),
#   ('별', 1)],
#  [('달빛', 2),
#   ('주막', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('어요', 2),
#   ('가산', 1),
#   ('디지털', 1),
#   ('맛집', 1),
#   ('막걸리', 1),
#   ('모듬', 1),
#   ('전', 1),
#   ('이번', 1),
#   ('생각', 1),
#   ('거의', 1),
#   ('더니', 1),
#   ('사람', 1),
#   ('별로', 1),
#   ('어서', 1),
#   ('전류', 1),
#   ('메뉴', 1),
#   ('여기', 1),
#   ('난리', 1),
#   ('회식', 1),
#   ('이나', 1),
#   ('모임', 1),
#   ('장소', 1),
#   ('도', 1),
#   ('아보', 1),
#   ('이구', 1),
#   ('차로', 1)],
#  [('어린이', 4),
#   ('데이트', 3),
#   ('비', 2),
#   ('날', 2),
#   ('아이', 2),
#   ('곳', 2),
#   ('이케아', 2),
#   ('장난감', 2),
#   ('추천', 2),
#   ('개', 2),
#   ('딸', 1),
#   ('주말', 1),
#   ('삼송역', 1),
#   ('김치볶음밥', 1),
#   ('메뉴', 1),
#   ('볼', 1),
#   ('초코', 1),
#   ('빵', 1),
#   ('주문', 1),
#   ('어요', 1),
#   ('엄마', 1),
#   ('단둘', 1),
#   ('행복', 1),
#   ('애', 1)],
#  [('어요', 2),
#   ('날', 2),
#   ('추천', 2),
#   ('기록', 2),
#   ('것', 2),
#   ('가포', 1),
#   ('카페', 1),
#   ('더', 1),
#   ('산후', 1),
#   ('기', 1),
#   ('진짜', 1),
#   ('고요', 1),
#   ('주차', 1),
#   ('매장', 1),
#   ('가기', 1),
#   ('까지', 1),
#   ('우산', 1),
#   ('이', 1),
#   ('동하', 1),
#   ('완벽', 1),
#   ('비', 1),
#   ('거', 1),
#   ('안', 1),
#   ('아함', 1),
#   ('메르', 1),
#   ('칼므', 1),
#   ('분위기', 1),
#   ('데이트', 1),
#   ('장소', 1),
#   ('도', 1),
#   ('집', 1),
#   ('수빈', 1),
#   ('탈출', 1)],
#  [('날', 5),
#   ('데이트', 4),
#   ('경기도', 3),
#   ('눈', 3),
#   ('추천', 3),
#   ('실내', 2),
#   ('카페', 2),
#   ('비', 2),
#   ('이용', 2),
#   ('시간', 2),
#   ('서울', 1),
#   ('근교', 1),
#   ('이나', 1),
#   ('음료', 1),
#   ('베이커리', 1),
#   ('시', 1),
#   ('제한', 1),
#   ('어서', 1),
#   ('두', 1),
#   ('세시', 1),
#   ('간', 1),
#   ('분', 1),
#   ('브런치', 1),
#   ('메뉴', 1),
#   ('유', 1),
#   ('징유', 1)],
#  [('날', 3),
#   ('연탄구이', 3),
#   ('집', 3),
#   ('메뉴', 3),
#   ('소금', 2),
#   ('구이', 2),
#   ('추천', 2),
#   ('로', 2),
#   ('고기', 2),
#   ('비', 2),
#   ('를', 1),
#   ('근처', 1),
#   ('가면', 1),
#   ('별로', 1),
#   ('점심', 1),
#   ('이나', 1),
#   ('저녁', 1),
#   ('정감', 1),
#   ('요즘', 1),
#   ('뉴스', 1),
#   ('피해', 1),
#   ('요', 1),
#   ('골목', 1)],
#  [('메뉴', 2),
#   ('사용', 1),
#   ('표선', 1),
#   ('닭', 1),
#   ('해장국', 1),
#   ('위치', 1),
#   ('및', 1),
#   ('운영', 1),
#   ('시간', 1),
#   ('날', 1),
#   ('추천', 1),
#   ('비', 1),
#   ('덕분', 1),
#   ('식사', 1),
#   ('수', 1),
#   ('어요', 1),
#   ('가격표', 1),
#   ('요렇습니', 1),
#   ('요즘', 1),
#   ('끼', 1),
#   ('천원', 1),
#   ('만', 1),
#   ('원', 1),
#   ('곳도', 1),
#   ('제주', 1),
#   ('산', 1),
#   ('닭고기', 1),
#   ('매일', 1),
#   ('우려', 1),
#   ('육수', 1),
#   ('이', 1),
#   ('정도', 1),
#   ('가격', 1),
#   ('이면', 1),
#   ('적', 1),
#   ('당하', 1),
#   ('유', 1),
#   ('여행', 1),
#   ('쩨', 1),
#   ('씨몽키', 1)],
#  [('글램핑', 4),
#   ('캠핑장', 3),
#   ('비', 3),
#   ('날', 3),
#   ('장어', 3),
#   ('가평', 2),
#   ('하늘', 2),
#   ('숲', 2),
#   ('단체', 2),
#   ('추천', 2),
#   ('캠핑', 1),
#   ('신가', 1),
#   ('오늘', 1),
#   ('메인', 1),
#   ('메뉴', 1),
#   ('장어구이', 1),
#   ('생각', 1),
#   ('고요', 1),
#   ('배부', 1),
#   ('르', 1),
#   ('보드게임', 1),
#   ('아빠', 1),
#   ('만세', 1)],
#  [('가평', 4),
#   ('카페', 3),
#   ('아기', 2),
#   ('비', 2),
#   ('날', 2),
#   ('박', 2),
#   ('어텐디드', 2),
#   ('가든', 2),
#   ('하니', 2),
#   ('곳', 1),
#   ('코스', 1),
#   ('키즈', 1),
#   ('풀', 1),
#   ('빌라', 1),
#   ('언덕', 1),
#   ('마루', 1),
#   ('잣', 1),
#   ('추천', 1),
#   ('소금', 1),
#   ('빵', 1),
#   ('정말', 1),
#   ('시간', 1),
#   ('운전', 1)],
#  [('메뉴', 3),
#   ('망원', 2),
#   ('맛', 2),
#   ('성산동', 1),
#   ('맛집', 1),
#   ('호호', 1),
#   ('라멘', 1),
#   ('날', 1),
#   ('추천', 1),
#   ('내', 1),
#   ('언니', 1),
#   ('시선', 1),
#   ('카와이', 1),
#   ('우리', 1),
#   ('카라', 1),
#   ('이돈', 1),
#   ('코츠', 1),
#   ('매콤', 1),
#   ('흰밥', 1),
#   ('교자', 1),
#   ('주문', 1),
#   ('키오', 1),
#   ('스크', 1),
#   ('발견', 1),
#   ('버', 1),
#   ('리뷰', 1),
#   ('작성', 1),
#   ('가게', 1)],
#  [('날', 3),
#   ('비', 2),
#   ('현', 2),
#   ('동래', 2),
#   ('허파', 2),
#   ('전', 2),
#   ('파전', 2),
#   ('거', 2),
#   ('이나', 2),
#   ('막걸리', 1),
#   ('안주', 1),
#   ('바삭', 1),
#   ('고소', 1),
#   ('추천', 1),
#   ('메뉴', 1),
#   ('중', 1),
#   ('하나', 1),
#   ('이제', 1),
#   ('생각', 1),
#   ('먼저', 1),
#   ('우삼겹', 1),
#   ('새우', 1),
#   ('어서', 1),
#   ('식감', 1),
#   ('더', 1),
#   ('것', 1),
#   ('어보', 1),
#   ('와이프', 1),
#   ('캠핑', 1),
#   ('쭈니', 1)],
#  [('비', 3),
#   ('날', 3),
#   ('곳', 2),
#   ('메뉴', 2),
#   ('막걸리', 2),
#   ('생각', 2),
#   ('힙한곳', 1),
#   ('분위기', 1),
#   ('안주', 1),
#   ('전', 1),
#   ('전통주', 1),
#   ('오늘', 1),
#   ('처럼', 1),
#   ('대한민국', 1),
#   ('사람', 1),
#   ('면', 1),
#   ('파전', 1),
#   ('퇴근길', 1),
#   ('곰', 1),
#   ('노량진', 1),
#   ('본점', 1),
#   ('주소', 1),
#   ('서울시', 1),
#   ('동작구', 1),
#   ('만양', 1),
#   ('길', 1),
#   ('영업', 1),
#   ('시간', 1),
#   ('일', 1),
#   ('목', 1),
#   ('안나', 1),
#   ('맛집', 1),
#   ('투어', 1)],
#  [('맛집', 2),
#   ('추천', 2),
#   ('메뉴', 2),
#   ('경기도', 1),
#   ('비', 1),
#   ('날', 1),
#   ('아이', 1),
#   ('곳', 1),
#   ('주차', 1),
#   ('가격', 1),
#   ('정보', 1),
#   ('포함', 1),
#   ('메이트', 1),
#   ('버거', 1),
#   ('모든', 1),
#   ('커피', 1),
#   ('별로', 1),
#   ('어요', 1),
#   ('음료', 1),
#   ('것', 1),
#   ('우육', 1),
#   ('샤오롱바오', 1),
#   ('가지', 1),
#   ('만두', 1),
#   ('바로', 1),
#   ('브룩스', 1),
#   ('쥬', 1),
#   ('샤오바', 1),
#   ('현지', 1),
#   ('맛', 1),
#   ('이면', 1),
#   ('서도', 1),
#   ('한국인', 1),
#   ('오후', 1),
#   ('정원', 1)],
#  [('요', 3),
#   ('리하', 3),
#   ('마술사', 3),
#   ('서울', 2),
#   ('날', 2),
#   ('아이', 2),
#   ('대학로', 2),
#   ('공연', 2),
#   ('추천', 2),
#   ('햄버거', 2),
#   ('마술', 1),
#   ('다양', 1),
#   ('메뉴', 1),
#   ('등', 1),
#   ('장하', 1),
#   ('안', 1),
#   ('내용물', 1),
#   ('중', 1),
#   ('가장', 1),
#   ('중요', 1),
#   ('여름방학', 1),
#   ('다가', 1),
#   ('데', 1),
#   ('곳', 1),
#   ('두', 1),
#   ('화성', 1),
#   ('온', 1),
#   ('여자', 1),
#   ('여섯', 1),
#   ('쩡', 1)],
#  [('메뉴', 3),
#   ('날', 2),
#   ('추천', 2),
#   ('때', 2),
#   ('판', 2),
#   ('더', 2),
#   ('어요', 2),
#   ('비', 1),
#   ('분위기', 1),
#   ('밀양', 1),
#   ('옥', 1),
#   ('느낌', 1),
#   ('카페', 1),
#   ('방문', 1),
#   ('디저트', 1),
#   ('준비', 1),
#   ('치즈케이크', 1),
#   ('운치', 1),
#   ('나', 1),
#   ('당근', 1),
#   ('주황', 1)],
#  [('추천', 3),
#   ('곳', 3),
#   ('비', 2),
#   ('날', 2),
#   ('느낌', 2),
#   ('봉천', 1),
#   ('점', 1),
#   ('선선', 1),
#   ('하니', 1),
#   ('메뉴', 1),
#   ('다양', 1),
#   ('먹기', 1),
#   ('참고', 1),
#   ('매장', 1),
#   ('안이', 1),
#   ('막', 1),
#   ('니니', 1),
#   ('평소', 1),
#   ('포차', 1),
#   ('아하', 1),
#   ('분', 1),
#   ('서울', 1),
#   ('전집', 1),
#   ('탑', 1),
#   ('바로', 1),
#   ('은', 1),
#   ('일상', 1)],
#  [('비', 4),
#   ('날', 3),
#   ('생각', 3),
#   ('더', 2),
#   ('맛집', 2),
#   ('충북', 2),
#   ('혁신도시', 2),
#   ('쌈', 2),
#   ('국수', 2),
#   ('메뉴', 1),
#   ('추천', 1),
#   ('올해', 1),
#   ('정말', 1),
#   ('것', 1),
#   ('오늘', 1),
#   ('폭우', 1),
#   ('처럼', 1),
#   ('아지', 1),
#   ('차도', 1),
#   ('대신', 1),
#   ('난', 1),
#   ('실내', 1),
#   ('무', 1),
#   ('오니', 1)],
#  [('일산', 3),
#   ('본점', 2),
#   ('등촌', 2),
#   ('샤브', 2),
#   ('칼국수', 2),
#   ('행복', 2),
#   ('여행', 2),
#   ('나눔', 2),
#   ('날', 1),
#   ('저녁', 1),
#   ('메뉴', 1),
#   ('로', 1),
#   ('추천', 1),
#   ('해', 1),
#   ('안녕', 1),
#   ('토요일', 1),
#   ('주말', 1),
#   ('계', 1),
#   ('신가', 1),
#   ('오후', 1),
#   ('부터', 1),
#   ('어진', 1),
#   ('비', 1),
#   ('상쾌', 1),
#   ('함', 1),
#   ('덤', 1),
#   ('오늘', 1),
#   ('고양', 1),
#   ('후기', 1),
#   ('고자', 1)],
#  [('비', 5),
#   ('행궁동', 2),
#   ('추천', 2),
#   ('날', 2),
#   ('수원', 1),
#   ('놀', 1),
#   ('거리', 1),
#   ('볼거리', 1),
#   ('데이트', 1),
#   ('장소', 1),
#   ('고합', 1),
#   ('의', 1),
#   ('모습', 1),
#   ('일지', 1),
#   ('방화', 1),
#   ('수류', 1),
#   ('정', 1),
#   ('구름', 1),
#   ('바', 1),
#   ('라보', 1),
#   ('은근', 1),
#   ('호수', 1),
#   ('풍경', 1),
#   ('꿈', 1),
#   ('일상', 1),
#   ('이야기', 1),
#   ('몽상가', 1)],
#  [('히쿠마', 4),
#   ('스프', 3),
#   ('치킨', 3),
#   ('때', 2),
#   ('강남역', 2),
#   ('맛집', 2),
#   ('날', 2),
#   ('메뉴', 2),
#   ('커리', 2),
#   ('카레', 1),
#   ('울', 1),
#   ('추천', 1),
#   ('비교', 1),
#   ('토마토', 1),
#   ('닭다리', 1),
#   ('하나', 1),
#   ('통째', 1),
#   ('어간', 1),
#   ('국물', 1),
#   ('번', 1),
#   ('보시', 1),
#   ('길', 1),
#   ('전체', 1),
#   ('프로', 1),
#   ('덕질', 1)],
#  [('맛집', 3),
#   ('비', 3),
#   ('국수', 2),
#   ('날', 2),
#   ('오픈', 2),
#   ('런', 2),
#   ('손님', 2),
#   ('부동산', 2),
#   ('우리동네', 1),
#   ('원', 1),
#   ('거의', 1),
#   ('매일', 1),
#   ('장마', 1),
#   ('기간', 1),
#   ('멀리', 1),
#   ('외식', 1),
#   ('가기', 1),
#   ('주방', 1),
#   ('불앞', 1),
#   ('와중', 1),
#   ('오시', 1),
#   ('는걸', 1),
#   ('분', 1),
#   ('사랑', 1),
#   ('항동', 1),
#   ('중개', 1),
#   ('우남', 1)]]

# %%
#중복값을 더하기 위해 딕셔너리 형태로 만들어줌 
df = pd.DataFrame()
for i in range(0,len(an)) :
    en = dict(an[i])
    df = df.append({'sentiment' : en}, ignore_index=True)

df
# Out:
#                                              sentiment
# 0    {'추천': 4, '날': 3, '메뉴': 3, '칼국수': 2, '비': 2, '...
# 1    {'라멘': 4, '추천': 3, '욘주': 2, '맛집': 2, '날': 2, '...
# 2    {'메뉴': 4, '날': 3, '바다': 2, '수퍼': 2, '물': 2, '천...
# 3    {'날': 2, '하루': 2, '기름': 2, '점심': 1, '메뉴': 1, '...
# 4    {'전': 5, '저녁': 3, '메뉴': 3, '부침개': 3, '야채': 3, ...
# ..                                                 ...
# 990  {'비': 4, '날': 3, '생각': 3, '더': 2, '맛집': 2, '충북...
# 991  {'일산': 3, '본점': 2, '등촌': 2, '샤브': 2, '칼국수': 2,...
# 992  {'비': 5, '행궁동': 2, '추천': 2, '날': 2, '수원': 1, '...
# 993  {'히쿠마': 4, '스프': 3, '치킨': 3, '때': 2, '강남역': 2,...
# 994  {'맛집': 3, '비': 3, '국수': 2, '날': 2, '오픈': 2, '런...
#
# [995 rows x 1 columns]

# %%
#중복 값을 더하는 함수 
from operator import itemgetter
def sum_sentiment(x):
    init_dict = list(x)

    result = {}
    for d in init_dict:
        for k in d.keys():
            result[k] = result.get(k, 0) + d[k]
    return result

# %%
dic_sum = df.agg({'sentiment' : lambda x : sum_sentiment(x)})
type(dic_sum)
# Out:
# pandas.core.series.Series

# %%
#더해진 값이 담긴 데이터프레임을 리스트 형태로 변경
dic_sum = dic_sum.values.tolist()
dic_sum
# Out:
# [{'추천': 1593,
#   '날': 2397,
#   '메뉴': 1734,
#   '칼국수': 399,
#   '비': 1833,
#   '하루': 48,
#   '오산': 1,
#   '맛집': 646,
#   '등촌': 19,
#   '샤브': 35,
#   '진짜': 22,
#   '이건': 4,
#   '다음': 28,
#   '살짝': 14,
#   '배': 13,
#   '직장인': 17,
#   '워킹맘': 3,
#   '음식': 253,
#   '동그라미': 1,
#   '라멘': 26,
#   '욘주': 2,
#   '차슈': 4,
#   '여전': 2,
#   '일본': 18,
#   '꼭': 38,
#   '사이드': 6,
#   '맛보기': 1,
#   '어간': 9,
#   '짐': 9,
#   '더': 135,
#   '원한': 3,
#   '면': 42,
#   '장': 23,
#   '추가': 12,
#   '수': 105,
#   '어요': 254,
#   '울산': 19,
#   '성남동': 1,
#   '웨이': 25,
#   '팅': 28,
#   '생각': 213,
#   '나': 121,
#   '오늘': 226,
#   '만사': 2,
#   '형통': 2,
#   '블로그': 72,
#   '바다': 10,
#   '수퍼': 2,
#   '물': 27,
#   '천하': 3,
#   '조개구이': 6,
#   '강남역': 26,
#   '점': 92,
#   '메인': 24,
#   '오기': 9,
#   '전': 157,
#   '양은': 2,
#   '냄비': 4,
#   '여준': 2,
#   '에피타이저': 2,
#   '떡볶이': 35,
#   '게': 23,
#   '신상식': 1,
#   '당': 18,
#   '쥬니': 1,
#   '뮹': 1,
#   '기록': 37,
#   '기름': 19,
#   '점심': 243,
#   '온센': 1,
#   '광명': 11,
#   '텐동': 1,
#   '식감': 7,
#   '등원': 1,
#   '길': 47,
#   '아침': 15,
#   '부터': 45,
#   '문': 6,
#   '연': 4,
#   '전집': 53,
#   '냄새': 9,
#   '식욕': 2,
#   '시작': 24,
#   '다이어터': 1,
#   '마제': 3,
#   '우동': 50,
#   '양념': 13,
#   '밥': 36,
#   '어도': 12,
#   '진': 11,
#   '거': 75,
#   '때': 108,
#   '전보': 1,
#   '푸딩': 1,
#   '육아': 6,
#   '탐구생활': 1,
#   '저녁': 182,
#   '부침개': 55,
#   '야채': 27,
#   '김치전': 53,
#   '두릅': 2,
#   '바삭': 57,
#   '법': 76,
#   '파전': 79,
#   '모듬전': 8,
#   '불닭볶음면': 1,
#   '비도': 17,
#   '이번': 27,
#   '주': 22,
#   '금요일': 6,
#   '일요일': 8,
#   '까지': 58,
#   '계획': 3,
#   '여수': 2,
#   '여행': 112,
#   '소진': 1,
#   '위해': 14,
#   '소': 55,
#   '소한': 27,
#   '솔솥': 2,
#   '입구': 13,
#   '골목': 11,
#   '수원': 14,
#   '행궁': 1,
#   '행궁동': 4,
#   '한식': 17,
#   '돌솥밥': 2,
#   '요즘': 62,
#   '처럼': 37,
#   '행궁점': 1,
#   '후기': 60,
#   '간판': 7,
#   '온': 25,
#   '느낌': 29,
#   '오니': 9,
#   '너낌있돠': 1,
#   '뱅': 1,
#   '기타': 2,
#   '해신': 1,
#   '비츠로': 1,
#   '캠핑카': 1,
#   '반': 19,
#   '카페': 285,
#   '케이크': 6,
#   '힐링': 13,
#   '안도': 1,
#   '르': 5,
#   '송': 1,
#   '당무': 1,
#   '끈': 20,
#   '모루': 1,
#   '포토': 3,
#   '존': 4,
#   '핫': 19,
#   '를': 58,
#   '한라산': 2,
#   '좀': 25,
#   '녹차': 1,
#   '맛': 127,
#   '어서': 100,
#   '조화': 1,
#   '경치': 3,
#   '제주': 88,
#   '중': 51,
#   '아이': 62,
#   '국내': 4,
#   '해외': 2,
#   '수제비': 126,
#   '감자': 52,
#   '레시피': 59,
#   '반죽': 25,
#   '요리': 116,
#   '왜': 15,
#   '도록': 7,
#   '이면': 30,
#   '밀가루': 12,
#   '려고': 24,
#   '요런': 3,
#   '슈슈냥': 3,
#   '그릇': 37,
#   '뚝딱': 10,
#   '야식': 24,
#   '만들기': 68,
#   '간식': 15,
#   '또': 49,
#   '다른': 24,
#   '채': 10,
#   '전만': 1,
#   '쏭스': 1,
#   '라이프': 13,
#   '푸드': 14,
#   '스토리': 11,
#   '이케아': 23,
#   '데이트': 139,
#   '실내': 70,
#   '추적': 44,
#   '거리': 23,
#   '레스토랑': 13,
#   '데': 64,
#   '고': 65,
#   '민하': 12,
#   '다가': 48,
#   '스타': 8,
#   '필드': 5,
#   '양': 18,
#   '놀': 12,
#   '서이추': 5,
#   '애나': 1,
#   '부탁': 1,
#   '영통': 4,
#   '목구멍': 2,
#   '고기': 51,
#   '집': 164,
#   '로': 137,
#   '해': 76,
#   '역시': 43,
#   '사람': 35,
#   '정말': 59,
#   '것': 135,
#   '기도': 13,
#   '원목': 1,
#   '살맛': 1,
#   '직접': 6,
#   '시': 46,
#   '작': 3,
#   '종일': 8,
#   '년': 2,
#   '잔치국수': 20,
#   '간단': 59,
#   '고명': 2,
#   '가득': 22,
#   '국수': 33,
#   '말': 22,
#   '요': 112,
#   '소면': 6,
#   '삶': 5,
#   '안녕': 49,
#   '다정': 2,
#   '순둥': 1,
#   '작가': 3,
#   '명촌': 2,
#   '돗': 2,
#   '가비': 2,
#   '불쭈': 2,
#   '철판': 3,
#   '볶음': 12,
#   '들깨': 27,
#   '땡': 11,
#   '기고': 13,
#   '봄비': 4,
#   '부슬부슬': 7,
#   '매콤': 27,
#   '국물': 116,
#   '불': 9,
#   '쭈꾸미': 13,
#   '보고': 21,
#   '욕심': 1,
#   '손': 31,
#   '사장': 7,
#   '육수': 32,
#   '굴': 6,
#   '조개': 21,
#   '가리비': 3,
#   '배추': 3,
#   '해물칼국수': 15,
#   '재료': 27,
#   '해물': 32,
#   '새우': 22,
#   '적당': 7,
#   '멸치': 16,
#   '쌈': 7,
#   '알': 16,
#   '대파': 6,
#   '청양고추': 6,
#   '행주치마': 2,
#   '정겨운': 2,
#   '집밥': 51,
#   '군': 5,
#   '가격': 56,
#   '곳': 200,
#   '한국어': 1,
#   '대표': 25,
#   '그니': 16,
#   '처': 17,
#   '코코넛': 1,
#   '밀크': 1,
#   '커피': 69,
#   '이전': 3,
#   '나트랑': 1,
#   '날씨': 59,
#   '콩': 6,
#   '시원': 40,
#   '떤딘': 1,
#   '성당': 1,
#   '구경': 7,
#   '호치민': 1,
#   '유익': 1,
#   '공간': 23,
#   '북한': 8,
#   '산점': 5,
#   '모두': 20,
#   '방문': 70,
#   '스타벅스': 15,
#   '오픈': 17,
#   '런': 13,
#   '드립': 29,
#   '왜냐면': 1,
#   '주말': 59,
#   '도': 76,
#   '거의': 10,
#   '만': 18,
#   '저': 77,
#   '오전': 7,
#   '이': 80,
#   '주문': 89,
#   '허니': 4,
#   '트리플': 1,
#   '치즈': 12,
#   '크루아상': 2,
#   '샌드위치': 1,
#   '완전': 20,
#   '만족': 13,
#   '두': 14,
#   '소하': 6,
#   '특별': 12,
#   '두부': 15,
#   '버섯': 16,
#   '콩국수': 5,
#   '의정부': 13,
#   '전골': 28,
#   '판': 80,
#   '식사': 36,
#   '류': 13,
#   '정식': 6,
#   '은': 53,
#   '두부전골': 2,
#   '는걸': 8,
#   '옆': 9,
#   '테이블': 21,
#   '블리': 1,
#   '행복': 43,
#   '한일': 3,
#   '상': 13,
#   '선택': 22,
#   '완벽': 10,
#   '미아사거리': 3,
#   '곱창': 27,
#   '삼겹살': 24,
#   '배달': 35,
#   '가능': 26,
#   '햇빛': 2,
#   '병원': 3,
#   '사무실': 6,
#   '대창': 6,
#   '착각': 1,
#   '주얼': 4,
#   '벽면': 2,
#   '설명': 4,
#   '꿈': 11,
#   '기본': 24,
#   '밥집': 10,
#   '초': 10,
#   '대박': 4,
#   '친절': 9,
#   '세팅': 4,
#   '샐러드': 6,
#   '김치': 58,
#   '찬': 8,
#   '마다': 16,
#   '이집': 4,
#   '어보': 26,
#   '심': 9,
#   '파김치': 4,
#   '소주': 27,
#   '경안동': 2,
#   '신장': 1,
#   '진리': 6,
#   '워낙': 6,
#   '사가': 1,
#   '별도': 3,
#   '판매': 11,
#   '일상': 98,
#   '여자': 6,
#   '부추': 35,
#   '장떡': 12,
#   '엄마': 27,
#   '봄': 10,
#   '새': 7,
#   '순은': 1,
#   '라서': 13,
#   '알리': 2,
#   '신': 11,
#   '성분': 1,
#   '비타민': 1,
#   '식': 15,
#   '조합': 28,
#   '번': 30,
#   '보시': 19,
#   '막창': 8,
#   '삼각지역': 2,
#   '용산': 7,
#   '바로': 55,
#   '기지': 2,
#   '찍': 9,
#   '았': 4,
#   '가까이': 2,
#   '탓': 1,
#   '안': 57,
#   '보이': 23,
#   '검색': 3,
#   '앤녕': 1,
#   '막걸리': 160,
#   '남해': 3,
#   '시골': 2,
#   '바깥': 2,
#   '자리': 33,
#   '운치': 26,
#   '안개': 3,
#   '크게': 7,
#   '고요': 31,
#   '저희': 28,
#   '된장찌개': 5,
#   '해물파전': 36,
#   '유자': 1,
#   '깃밥': 1,
#   '때문': 24,
#   '고추': 10,
#   '빼': 2,
#   '달라': 4,
#   '딸': 3,
#   '성장기': 2,
#   '록': 7,
#   '하남': 7,
#   '돼지': 12,
#   '초록': 10,
#   '고깃집': 1,
#   '차지': 3,
#   '뷰': 23,
#   '뿐더러': 1,
#   '소리': 31,
#   '앞': 21,
#   '돼지고기': 7,
#   '도시락': 1,
#   '김치볶음밥': 2,
#   '김치양': 1,
#   '얼마': 9,
#   '단방': 2,
#   '향소': 2,
#   '통': 13,
#   '생활기록부': 2,
#   '오징어': 34,
#   '손질': 4,
#   '통오징어': 2,
#   '부추전': 49,
#   '모양': 1,
#   '그대로': 1,
#   '다양': 39,
#   '활용': 3,
#   '전이': 35,
#   '봉': 2,
#   '이의': 17,
#   '데일': 2,
#   '리': 39,
#   '달링': 4,
#   '비올': 17,
#   '순두부찌개': 4,
#   '달타냥': 5,
#   '하우스': 16,
#   '온천': 10,
#   '공주': 12,
#   '동학사': 1,
#   '간다': 2,
#   '용씨': 1,
#   '가지': 27,
#   '우리': 40,
#   '둘': 7,
#   '미지': 1,
#   '휘연': 1,
#   '세상': 14,
#   '쌀국수': 36,
#   '뮤지': 5,
#   '엄': 7,
#   '예약': 16,
#   '주차': 43,
#   '지난': 3,
#   '남자친구': 4,
#   '습': 13,
#   '끼': 36,
#   '중하': 2,
#   '기': 32,
#   '분보': 1,
#   '아해': 5,
#   '비빔': 2,
#   '처음': 8,
#   '인천': 11,
#   '짱': 11,
#   '자취': 8,
#   '생': 21,
#   '도둑': 5,
#   '갈치': 1,
#   '무조림': 1,
#   '식탁': 3,
#   '위': 25,
#   '건': 23,
#   '꾸벅': 1,
#   '클쑤똴': 1,
#   '홍천': 5,
#   '시내': 2,
#   '최고': 28,
#   '여러분': 17,
#   '세트': 26,
#   '미나리': 11,
#   '김주': 2,
#   '부의': 3,
#   '하루하루': 9,
#   '닭도리탕': 11,
#   '송강': 1,
#   '당첨': 1,
#   '동네': 11,
#   '맘': 18,
#   '그': 72,
#   '아쉬움': 1,
#   '마저': 2,
#   '요기': 7,
#   '담': 12,
#   '징': 5,
#   '서문': 1,
#   '원': 20,
#   '강사': 1,
#   '독서': 2,
#   '강의': 2,
#   '노트': 3,
#   '천안': 8,
#   '직산': 3,
#   '꼬막': 4,
#   '짬뽕': 81,
#   '산더미': 2,
#   '탕수육': 9,
#   '비불': 1,
#   '위치': 25,
#   '유리': 1,
#   '창': 5,
#   '모습': 7,
#   '하니': 18,
#   '주방': 4,
#   '셀프': 3,
#   '바': 28,
#   '청당': 3,
#   '곱': 12,
#   '회식': 10,
#   '영업': 20,
#   '선지국': 2,
#   '제이': 3,
#   '시간': 78,
#   '모듬': 12,
#   '구이': 12,
#   '한번': 33,
#   '병각': 1,
#   '러브': 3,
#   '수유': 5,
#   '수유역': 7,
#   '부대찌개': 30,
#   '고민': 33,
#   '무조건': 17,
#   '번동': 1,
#   '조리': 5,
#   '돈': 37,
#   '산': 43,
#   '간편': 10,
#   '제천': 1,
#   '오뎅': 25,
#   '여름철': 1,
#   '별미': 5,
#   '이열치열': 4,
#   '전해': 1,
#   '간': 14,
#   '단합': 2,
#   '제': 36,
#   '누구': 4,
#   '우시': 1,
#   '매': 6,
#   '운오': 1,
#   '뎅': 1,
#   '리안': 1,
#   '가뭄': 2,
#   '해갈': 2,
#   '억지로': 1,
#   '어제': 22,
#   '소개': 38,
#   '삼시': 4,
#   '얼': 26,
#   '벌써': 6,
#   '일': 21,
#   '지속': 2,
#   '다행': 9,
#   '끝': 15,
#   '바지락': 38,
#   '언니': 19,
#   '소의': 3,
#   '건강': 14,
#   '어묵탕': 16,
#   '밀키': 26,
#   '트': 31,
#   '홍게': 7,
#   '꼬치': 15,
#   '피해': 11,
#   '이상': 7,
#   '음번': 1,
#   '행': 8,
#   '사하': 2,
#   '몇개': 1,
#   '쟁': 1,
#   '취미': 3,
#   '해장': 17,
#   '설정': 1,
#   '사랑': 15,
#   '해물짬뽕': 4,
#   '중식': 8,
#   '광화문': 2,
#   '바보': 3,
#   '먹기': 54,
#   '심심': 1,
#   '곁': 3,
#   '이기': 10,
#   '안암': 2,
#   '맑은': 11,
#   '돼지국밥': 6,
#   '무려': 1,
#   '미쉐린': 1,
#   '방촌동': 2,
#   '수면': 1,
#   '옥': 17,
#   '쌀': 4,
#   '지인': 9,
#   '소스': 16,
#   '걸': 26,
#   '잠시': 5,
#   '후': 25,
#   '양푼': 1,
#   '모모': 3,
#   '왕십리': 8,
#   '동래': 11,
#   '국룰': 8,
#   '술안주': 37,
#   '면서': 35,
#   '매일': 20,
#   '폭주기관차': 1,
#   '정동': 1,
#   '원래': 13,
#   '리뷰': 29,
#   '먼저': 16,
#   '포스팅': 20,
#   '호명': 2,
#   '었는데': 5,
#   '매료': 1,
#   '플레이': 11,
#   '스': 18,
#   '매운갈비찜': 4,
#   '신사': 4,
#   '출구': 7,
#   '래서': 37,
#   '한잔': 44,
#   '수가': 3,
#   '병': 6,
#   '갈비찜': 4,
#   '이야기': 39,
#   '다이어트': 7,
#   '대용': 2,
#   '반찬': 15,
#   '삭': 2,
#   '촉촉': 3,
#   '등': 27,
#   '양배추': 5,
#   '가시': 9,
#   '장미': 2,
#   '수다': 8,
#   '나루': 6,
#   '동태': 22,
#   '탕': 53,
#   '마곡': 4,
#   '국밥': 30,
#   '안녕하십니까': 1,
#   '맨입': 1,
#   '와이프': 3,
#   '맨': 2,
#   '모험': 2,
#   '감자전': 21,
#   '홈': 7,
#   '홈스토리': 3,
#   '고소': 8,
#   '싹': 5,
#   '독성': 1,
#   '박스': 3,
#   '단위': 3,
#   '조금': 19,
#   '사서': 2,
#   '편': 14,
#   '봉지': 4,
#   '식단': 9,
#   '뭐': 45,
#   '표': 9,
#   '일주일': 2,
#   '주간': 2,
#   '밥상': 3,
#   '밤': 8,
#   '양양': 1,
#   '친정': 3,
#   '부모님': 8,
#   '더니': 16,
#   '평범': 5,
#   '듯': 17,
#   '꽃': 7,
#   '길이': 2,
#   '캠핑': 28,
#   '사옹원': 2,
#   '종': 4,
#   '호떡': 9,
#   '우중': 10,
#   '평소': 5,
#   '달': 7,
#   '로그': 22,
#   '산장': 7,
#   '술집': 76,
#   '대체로': 1,
#   '오리': 4,
#   '주물': 1,
#   '럭': 1,
#   '던데': 6,
#   '젊은이': 1,
#   '취향': 6,
#   '저격': 3,
#   '하이': 8,
#   '볼': 16,
#   '수진': 1,
#   '흔적': 2,
#   '가산디지털단지역': 2,
#   '김대': 2,
#   '불맛나': 1,
#   '하나': 35,
#   '제왕': 1,
#   '주소': 9,
#   '서울': 72,
#   '금천구': 1,
#   '가산': 3,
#   '디지털': 3,
#   '한라': 1,
#   '앤': 7,
#   '타워': 5,
#   '층': 23,
#   '호': 9,
#   '전화번호': 2,
#   '월': 5,
#   '금': 6,
#   '부근': 1,
#   '파이브': 1,
#   '비뉴': 1,
#   '즐': 20,
#   '기기': 9,
#   '가끔': 5,
#   '특정': 1,
#   '날때': 4,
#   '서도': 9,
#   '지혜': 3,
#   '사자': 3,
#   '감성': 31,
#   '현실': 3,
#   '베이커리': 13,
#   '분': 53,
#   '무': 10,
#   '로이': 1,
#   '힙': 3,
#   '스팟': 1,
#   '아보': 12,
#   '테라스': 6,
#   '강추': 11,
#   '대신': 11,
#   '종류': 28,
#   '편이': 3,
#   '디저트': 30,
#   '참고': 15,
#   '욥': 1,
#   '서귀포': 18,
#   '대형': 12,
#   '파워': 1,
#   '이지': 22,
#   '여름': 16,
#   '탕수': 1,
#   '제철': 6,
#   '어른': 6,
#   '탕수랍니': 1,
#   '오랜만': 19,
#   '백고': 1,
#   '막내': 2,
#   '아하': 38,
#   '개': 46,
#   '맘마': 2,
#   '드실껀': 1,
#   '가요': 6,
#   '경북': 3,
#   '도청': 2,
#   '설비': 4,
#   '안동': 1,
#   '고기국수': 2,
#   '이수': 1,
#   '오래': 9,
#   '무하': 1,
#   '직원': 11,
#   '단골': 8,
#   '음식점': 3,
#   '성공': 7,
#   '누수': 2,
#   '수구': 2,
#   '해결사': 1,
#   '모든': 20,
#   '강서구': 2,
#   '유림': 2,
#   '못': 18,
#   '한마음': 1,
#   '통속': 1,
#   '정': 14,
#   '도착': 7,
#   '쑥갓': 7,
#   '안주': 46,
#   '전요': 5,
#   '리가': 1,
#   '줌': 5,
#   '칼라': 1,
#   '테라': 2,
#   '피': 8,
#   '카페라떼': 3,
#   '방송': 2,
#   '스벅': 1,
#   '스텀': 4,
#   '엽떡': 2,
#   '재난': 1,
#   '알림': 2,
#   '문자': 2,
#   '태풍': 10,
#   '대비': 3,
#   '하라': 3,
#   '라떼': 17,
#   '상추': 6,
#   '튀김': 21,
#   '가루': 20,
#   '키친': 7,
#   '타': 8,
#   '기름기': 2,
#   '전간': 1,
#   '지네': 2,
#   '이영자': 1,
#   '꿀': 10,
#   '유미': 16,
#   '카츠': 24,
#   '본격': 4,
#   '적': 25,
#   '장마': 29,
#   '뿐': 10,
#   '항상': 3,
#   '매력': 9,
#   '돈카츠': 3,
#   '전문점': 8,
#   '공식': 11,
#   '동천역': 5,
#   '명동': 16,
#   '한국': 10,
#   '수지구': 1,
#   '평일': 7,
#   '토요일': 4,
#   '휴무': 10,
#   '억수': 3,
#   '마론킴': 1,
#   '순대국': 21,
#   '광교': 6,
#   '프랑': 7,
#   '남옥': 2,
#   '아브뉴': 4,
#   '이용': 15,
#   '라스트': 3,
#   '별별': 2,
#   '감초': 2,
#   '내일': 10,
#   '여': 6,
#   '작전동': 1,
#   '온면': 1,
#   '포차': 13,
#   '일단': 11,
#   '인분': 13,
#   '잔': 14,
#   '필': 3,
#   '칭따오': 1,
#   '맥주': 29,
#   '술': 18,
#   '미미': 7,
#   '오덕': 11,
#   '집콕러들': 2,
#   '빗': 13,
#   '인적': 11,
#   '어렷을적': 1,
#   '초등학교': 1,
#   '마치': 4,
#   '우산': 6,
#   '청년': 3,
#   '암만': 2,
#   '자향': 1,
#   '출발': 2,
#   '닭갈비': 2,
#   '소세지': 2,
#   '인기': 14,
#   '영양': 7,
#   '쟁이': 1,
#   '강력': 12,
#   '합': 8,
#   '미니': 2,
#   '메기': 4,
#   '매운탕': 12,
#   '계속': 14,
#   '올해': 2,
#   '기간': 3,
#   '비소': 4,
#   '남양주': 8,
#   '찜질': 1,
#   '출처': 3,
#   '나혼산': 1,
#   '코쿤': 1,
#   '엘리': 1,
#   '지금': 16,
#   '순간': 5,
#   '포': 11,
#   '깐풍기': 3,
#   '단짝': 2,
#   '레드': 6,
#   '베트남': 4,
#   '베스트': 6,
#   '어가': 23,
#   '간장': 10,
#   '이나': 30,
#   '절임': 2,
#   '감칠맛': 5,
#   '아직': 8,
#   '갑오징어무침': 2,
#   '다트': 2,
#   '지고': 9,
#   '방': 23,
#   '장마철': 21,
#   '주룩주룩': 9,
#   '밖': 7,
#   '몸': 12,
#   '기분': 28,
#   '다운': 7,
#   '다한': 1,
#   '도토리': 3,
#   '구성': 10,
#   '구미': 14,
#   '구': 12,
#   '미산동': 1,
#   '전문': 5,
#   '전하': 1,
#   '보': 26,
#   '내세': 3,
#   '계산': 3,
#   '아메': 1,
#   '믹스': 8,
#   '프로': 3,
#   '토탈': 1,
#   '인테리어': 8,
#   '송도': 8,
#   '우이': 3,
#   '녹': 3,
#   '백합': 7,
#   '왕새우': 1,
#   '지난주': 4,
#   '볼일': 1,
#   '센트럴': 1,
#   '파크': 8,
#   '우수': 1,
#   '제비집': 2,
#   '마침': 6,
#   '김': 7,
#   '썸머': 3,
#   '퇴근': 8,
#   '무얼': 1,
#   '먹음': 8,
#   '의': 45,
#   '고추장': 8,
#   '절로': 1,
#   '준비': 17,
#   '냉장고': 5,
#   '속': 12,
#   '시크': 4,
#   '도도': 4,
#   '토깽': 2,
#   '살': 22,
#   '효': 4,
#   '곱창전골': 13,
#   '효능': 2,
#   '보통': 4,
#   '함': 12,
#   '겉': 2,
#   '온통': 2,
#   '얀마': 1,
#   ...}]

# %%
#딕셔너리 형태로 만들어 줌
df = dic_sum[0]
df
# Out:
# {'추천': 1593,
#  '날': 2397,
#  '메뉴': 1734,
#  '칼국수': 399,
#  '비': 1833,
#  '하루': 48,
#  '오산': 1,
#  '맛집': 646,
#  '등촌': 19,
#  '샤브': 35,
#  '진짜': 22,
#  '이건': 4,
#  '다음': 28,
#  '살짝': 14,
#  '배': 13,
#  '직장인': 17,
#  '워킹맘': 3,
#  '음식': 253,
#  '동그라미': 1,
#  '라멘': 26,
#  '욘주': 2,
#  '차슈': 4,
#  '여전': 2,
#  '일본': 18,
#  '꼭': 38,
#  '사이드': 6,
#  '맛보기': 1,
#  '어간': 9,
#  '짐': 9,
#  '더': 135,
#  '원한': 3,
#  '면': 42,
#  '장': 23,
#  '추가': 12,
#  '수': 105,
#  '어요': 254,
#  '울산': 19,
#  '성남동': 1,
#  '웨이': 25,
#  '팅': 28,
#  '생각': 213,
#  '나': 121,
#  '오늘': 226,
#  '만사': 2,
#  '형통': 2,
#  '블로그': 72,
#  '바다': 10,
#  '수퍼': 2,
#  '물': 27,
#  '천하': 3,
#  '조개구이': 6,
#  '강남역': 26,
#  '점': 92,
#  '메인': 24,
#  '오기': 9,
#  '전': 157,
#  '양은': 2,
#  '냄비': 4,
#  '여준': 2,
#  '에피타이저': 2,
#  '떡볶이': 35,
#  '게': 23,
#  '신상식': 1,
#  '당': 18,
#  '쥬니': 1,
#  '뮹': 1,
#  '기록': 37,
#  '기름': 19,
#  '점심': 243,
#  '온센': 1,
#  '광명': 11,
#  '텐동': 1,
#  '식감': 7,
#  '등원': 1,
#  '길': 47,
#  '아침': 15,
#  '부터': 45,
#  '문': 6,
#  '연': 4,
#  '전집': 53,
#  '냄새': 9,
#  '식욕': 2,
#  '시작': 24,
#  '다이어터': 1,
#  '마제': 3,
#  '우동': 50,
#  '양념': 13,
#  '밥': 36,
#  '어도': 12,
#  '진': 11,
#  '거': 75,
#  '때': 108,
#  '전보': 1,
#  '푸딩': 1,
#  '육아': 6,
#  '탐구생활': 1,
#  '저녁': 182,
#  '부침개': 55,
#  '야채': 27,
#  '김치전': 53,
#  '두릅': 2,
#  '바삭': 57,
#  '법': 76,
#  '파전': 79,
#  '모듬전': 8,
#  '불닭볶음면': 1,
#  '비도': 17,
#  '이번': 27,
#  '주': 22,
#  '금요일': 6,
#  '일요일': 8,
#  '까지': 58,
#  '계획': 3,
#  '여수': 2,
#  '여행': 112,
#  '소진': 1,
#  '위해': 14,
#  '소': 55,
#  '소한': 27,
#  '솔솥': 2,
#  '입구': 13,
#  '골목': 11,
#  '수원': 14,
#  '행궁': 1,
#  '행궁동': 4,
#  '한식': 17,
#  '돌솥밥': 2,
#  '요즘': 62,
#  '처럼': 37,
#  '행궁점': 1,
#  '후기': 60,
#  '간판': 7,
#  '온': 25,
#  '느낌': 29,
#  '오니': 9,
#  '너낌있돠': 1,
#  '뱅': 1,
#  '기타': 2,
#  '해신': 1,
#  '비츠로': 1,
#  '캠핑카': 1,
#  '반': 19,
#  '카페': 285,
#  '케이크': 6,
#  '힐링': 13,
#  '안도': 1,
#  '르': 5,
#  '송': 1,
#  '당무': 1,
#  '끈': 20,
#  '모루': 1,
#  '포토': 3,
#  '존': 4,
#  '핫': 19,
#  '를': 58,
#  '한라산': 2,
#  '좀': 25,
#  '녹차': 1,
#  '맛': 127,
#  '어서': 100,
#  '조화': 1,
#  '경치': 3,
#  '제주': 88,
#  '중': 51,
#  '아이': 62,
#  '국내': 4,
#  '해외': 2,
#  '수제비': 126,
#  '감자': 52,
#  '레시피': 59,
#  '반죽': 25,
#  '요리': 116,
#  '왜': 15,
#  '도록': 7,
#  '이면': 30,
#  '밀가루': 12,
#  '려고': 24,
#  '요런': 3,
#  '슈슈냥': 3,
#  '그릇': 37,
#  '뚝딱': 10,
#  '야식': 24,
#  '만들기': 68,
#  '간식': 15,
#  '또': 49,
#  '다른': 24,
#  '채': 10,
#  '전만': 1,
#  '쏭스': 1,
#  '라이프': 13,
#  '푸드': 14,
#  '스토리': 11,
#  '이케아': 23,
#  '데이트': 139,
#  '실내': 70,
#  '추적': 44,
#  '거리': 23,
#  '레스토랑': 13,
#  '데': 64,
#  '고': 65,
#  '민하': 12,
#  '다가': 48,
#  '스타': 8,
#  '필드': 5,
#  '양': 18,
#  '놀': 12,
#  '서이추': 5,
#  '애나': 1,
#  '부탁': 1,
#  '영통': 4,
#  '목구멍': 2,
#  '고기': 51,
#  '집': 164,
#  '로': 137,
#  '해': 76,
#  '역시': 43,
#  '사람': 35,
#  '정말': 59,
#  '것': 135,
#  '기도': 13,
#  '원목': 1,
#  '살맛': 1,
#  '직접': 6,
#  '시': 46,
#  '작': 3,
#  '종일': 8,
#  '년': 2,
#  '잔치국수': 20,
#  '간단': 59,
#  '고명': 2,
#  '가득': 22,
#  '국수': 33,
#  '말': 22,
#  '요': 112,
#  '소면': 6,
#  '삶': 5,
#  '안녕': 49,
#  '다정': 2,
#  '순둥': 1,
#  '작가': 3,
#  '명촌': 2,
#  '돗': 2,
#  '가비': 2,
#  '불쭈': 2,
#  '철판': 3,
#  '볶음': 12,
#  '들깨': 27,
#  '땡': 11,
#  '기고': 13,
#  '봄비': 4,
#  '부슬부슬': 7,
#  '매콤': 27,
#  '국물': 116,
#  '불': 9,
#  '쭈꾸미': 13,
#  '보고': 21,
#  '욕심': 1,
#  '손': 31,
#  '사장': 7,
#  '육수': 32,
#  '굴': 6,
#  '조개': 21,
#  '가리비': 3,
#  '배추': 3,
#  '해물칼국수': 15,
#  '재료': 27,
#  '해물': 32,
#  '새우': 22,
#  '적당': 7,
#  '멸치': 16,
#  '쌈': 7,
#  '알': 16,
#  '대파': 6,
#  '청양고추': 6,
#  '행주치마': 2,
#  '정겨운': 2,
#  '집밥': 51,
#  '군': 5,
#  '가격': 56,
#  '곳': 200,
#  '한국어': 1,
#  '대표': 25,
#  '그니': 16,
#  '처': 17,
#  '코코넛': 1,
#  '밀크': 1,
#  '커피': 69,
#  '이전': 3,
#  '나트랑': 1,
#  '날씨': 59,
#  '콩': 6,
#  '시원': 40,
#  '떤딘': 1,
#  '성당': 1,
#  '구경': 7,
#  '호치민': 1,
#  '유익': 1,
#  '공간': 23,
#  '북한': 8,
#  '산점': 5,
#  '모두': 20,
#  '방문': 70,
#  '스타벅스': 15,
#  '오픈': 17,
#  '런': 13,
#  '드립': 29,
#  '왜냐면': 1,
#  '주말': 59,
#  '도': 76,
#  '거의': 10,
#  '만': 18,
#  '저': 77,
#  '오전': 7,
#  '이': 80,
#  '주문': 89,
#  '허니': 4,
#  '트리플': 1,
#  '치즈': 12,
#  '크루아상': 2,
#  '샌드위치': 1,
#  '완전': 20,
#  '만족': 13,
#  '두': 14,
#  '소하': 6,
#  '특별': 12,
#  '두부': 15,
#  '버섯': 16,
#  '콩국수': 5,
#  '의정부': 13,
#  '전골': 28,
#  '판': 80,
#  '식사': 36,
#  '류': 13,
#  '정식': 6,
#  '은': 53,
#  '두부전골': 2,
#  '는걸': 8,
#  '옆': 9,
#  '테이블': 21,
#  '블리': 1,
#  '행복': 43,
#  '한일': 3,
#  '상': 13,
#  '선택': 22,
#  '완벽': 10,
#  '미아사거리': 3,
#  '곱창': 27,
#  '삼겹살': 24,
#  '배달': 35,
#  '가능': 26,
#  '햇빛': 2,
#  '병원': 3,
#  '사무실': 6,
#  '대창': 6,
#  '착각': 1,
#  '주얼': 4,
#  '벽면': 2,
#  '설명': 4,
#  '꿈': 11,
#  '기본': 24,
#  '밥집': 10,
#  '초': 10,
#  '대박': 4,
#  '친절': 9,
#  '세팅': 4,
#  '샐러드': 6,
#  '김치': 58,
#  '찬': 8,
#  '마다': 16,
#  '이집': 4,
#  '어보': 26,
#  '심': 9,
#  '파김치': 4,
#  '소주': 27,
#  '경안동': 2,
#  '신장': 1,
#  '진리': 6,
#  '워낙': 6,
#  '사가': 1,
#  '별도': 3,
#  '판매': 11,
#  '일상': 98,
#  '여자': 6,
#  '부추': 35,
#  '장떡': 12,
#  '엄마': 27,
#  '봄': 10,
#  '새': 7,
#  '순은': 1,
#  '라서': 13,
#  '알리': 2,
#  '신': 11,
#  '성분': 1,
#  '비타민': 1,
#  '식': 15,
#  '조합': 28,
#  '번': 30,
#  '보시': 19,
#  '막창': 8,
#  '삼각지역': 2,
#  '용산': 7,
#  '바로': 55,
#  '기지': 2,
#  '찍': 9,
#  '았': 4,
#  '가까이': 2,
#  '탓': 1,
#  '안': 57,
#  '보이': 23,
#  '검색': 3,
#  '앤녕': 1,
#  '막걸리': 160,
#  '남해': 3,
#  '시골': 2,
#  '바깥': 2,
#  '자리': 33,
#  '운치': 26,
#  '안개': 3,
#  '크게': 7,
#  '고요': 31,
#  '저희': 28,
#  '된장찌개': 5,
#  '해물파전': 36,
#  '유자': 1,
#  '깃밥': 1,
#  '때문': 24,
#  '고추': 10,
#  '빼': 2,
#  '달라': 4,
#  '딸': 3,
#  '성장기': 2,
#  '록': 7,
#  '하남': 7,
#  '돼지': 12,
#  '초록': 10,
#  '고깃집': 1,
#  '차지': 3,
#  '뷰': 23,
#  '뿐더러': 1,
#  '소리': 31,
#  '앞': 21,
#  '돼지고기': 7,
#  '도시락': 1,
#  '김치볶음밥': 2,
#  '김치양': 1,
#  '얼마': 9,
#  '단방': 2,
#  '향소': 2,
#  '통': 13,
#  '생활기록부': 2,
#  '오징어': 34,
#  '손질': 4,
#  '통오징어': 2,
#  '부추전': 49,
#  '모양': 1,
#  '그대로': 1,
#  '다양': 39,
#  '활용': 3,
#  '전이': 35,
#  '봉': 2,
#  '이의': 17,
#  '데일': 2,
#  '리': 39,
#  '달링': 4,
#  '비올': 17,
#  '순두부찌개': 4,
#  '달타냥': 5,
#  '하우스': 16,
#  '온천': 10,
#  '공주': 12,
#  '동학사': 1,
#  '간다': 2,
#  '용씨': 1,
#  '가지': 27,
#  '우리': 40,
#  '둘': 7,
#  '미지': 1,
#  '휘연': 1,
#  '세상': 14,
#  '쌀국수': 36,
#  '뮤지': 5,
#  '엄': 7,
#  '예약': 16,
#  '주차': 43,
#  '지난': 3,
#  '남자친구': 4,
#  '습': 13,
#  '끼': 36,
#  '중하': 2,
#  '기': 32,
#  '분보': 1,
#  '아해': 5,
#  '비빔': 2,
#  '처음': 8,
#  '인천': 11,
#  '짱': 11,
#  '자취': 8,
#  '생': 21,
#  '도둑': 5,
#  '갈치': 1,
#  '무조림': 1,
#  '식탁': 3,
#  '위': 25,
#  '건': 23,
#  '꾸벅': 1,
#  '클쑤똴': 1,
#  '홍천': 5,
#  '시내': 2,
#  '최고': 28,
#  '여러분': 17,
#  '세트': 26,
#  '미나리': 11,
#  '김주': 2,
#  '부의': 3,
#  '하루하루': 9,
#  '닭도리탕': 11,
#  '송강': 1,
#  '당첨': 1,
#  '동네': 11,
#  '맘': 18,
#  '그': 72,
#  '아쉬움': 1,
#  '마저': 2,
#  '요기': 7,
#  '담': 12,
#  '징': 5,
#  '서문': 1,
#  '원': 20,
#  '강사': 1,
#  '독서': 2,
#  '강의': 2,
#  '노트': 3,
#  '천안': 8,
#  '직산': 3,
#  '꼬막': 4,
#  '짬뽕': 81,
#  '산더미': 2,
#  '탕수육': 9,
#  '비불': 1,
#  '위치': 25,
#  '유리': 1,
#  '창': 5,
#  '모습': 7,
#  '하니': 18,
#  '주방': 4,
#  '셀프': 3,
#  '바': 28,
#  '청당': 3,
#  '곱': 12,
#  '회식': 10,
#  '영업': 20,
#  '선지국': 2,
#  '제이': 3,
#  '시간': 78,
#  '모듬': 12,
#  '구이': 12,
#  '한번': 33,
#  '병각': 1,
#  '러브': 3,
#  '수유': 5,
#  '수유역': 7,
#  '부대찌개': 30,
#  '고민': 33,
#  '무조건': 17,
#  '번동': 1,
#  '조리': 5,
#  '돈': 37,
#  '산': 43,
#  '간편': 10,
#  '제천': 1,
#  '오뎅': 25,
#  '여름철': 1,
#  '별미': 5,
#  '이열치열': 4,
#  '전해': 1,
#  '간': 14,
#  '단합': 2,
#  '제': 36,
#  '누구': 4,
#  '우시': 1,
#  '매': 6,
#  '운오': 1,
#  '뎅': 1,
#  '리안': 1,
#  '가뭄': 2,
#  '해갈': 2,
#  '억지로': 1,
#  '어제': 22,
#  '소개': 38,
#  '삼시': 4,
#  '얼': 26,
#  '벌써': 6,
#  '일': 21,
#  '지속': 2,
#  '다행': 9,
#  '끝': 15,
#  '바지락': 38,
#  '언니': 19,
#  '소의': 3,
#  '건강': 14,
#  '어묵탕': 16,
#  '밀키': 26,
#  '트': 31,
#  '홍게': 7,
#  '꼬치': 15,
#  '피해': 11,
#  '이상': 7,
#  '음번': 1,
#  '행': 8,
#  '사하': 2,
#  '몇개': 1,
#  '쟁': 1,
#  '취미': 3,
#  '해장': 17,
#  '설정': 1,
#  '사랑': 15,
#  '해물짬뽕': 4,
#  '중식': 8,
#  '광화문': 2,
#  '바보': 3,
#  '먹기': 54,
#  '심심': 1,
#  '곁': 3,
#  '이기': 10,
#  '안암': 2,
#  '맑은': 11,
#  '돼지국밥': 6,
#  '무려': 1,
#  '미쉐린': 1,
#  '방촌동': 2,
#  '수면': 1,
#  '옥': 17,
#  '쌀': 4,
#  '지인': 9,
#  '소스': 16,
#  '걸': 26,
#  '잠시': 5,
#  '후': 25,
#  '양푼': 1,
#  '모모': 3,
#  '왕십리': 8,
#  '동래': 11,
#  '국룰': 8,
#  '술안주': 37,
#  '면서': 35,
#  '매일': 20,
#  '폭주기관차': 1,
#  '정동': 1,
#  '원래': 13,
#  '리뷰': 29,
#  '먼저': 16,
#  '포스팅': 20,
#  '호명': 2,
#  '었는데': 5,
#  '매료': 1,
#  '플레이': 11,
#  '스': 18,
#  '매운갈비찜': 4,
#  '신사': 4,
#  '출구': 7,
#  '래서': 37,
#  '한잔': 44,
#  '수가': 3,
#  '병': 6,
#  '갈비찜': 4,
#  '이야기': 39,
#  '다이어트': 7,
#  '대용': 2,
#  '반찬': 15,
#  '삭': 2,
#  '촉촉': 3,
#  '등': 27,
#  '양배추': 5,
#  '가시': 9,
#  '장미': 2,
#  '수다': 8,
#  '나루': 6,
#  '동태': 22,
#  '탕': 53,
#  '마곡': 4,
#  '국밥': 30,
#  '안녕하십니까': 1,
#  '맨입': 1,
#  '와이프': 3,
#  '맨': 2,
#  '모험': 2,
#  '감자전': 21,
#  '홈': 7,
#  '홈스토리': 3,
#  '고소': 8,
#  '싹': 5,
#  '독성': 1,
#  '박스': 3,
#  '단위': 3,
#  '조금': 19,
#  '사서': 2,
#  '편': 14,
#  '봉지': 4,
#  '식단': 9,
#  '뭐': 45,
#  '표': 9,
#  '일주일': 2,
#  '주간': 2,
#  '밥상': 3,
#  '밤': 8,
#  '양양': 1,
#  '친정': 3,
#  '부모님': 8,
#  '더니': 16,
#  '평범': 5,
#  '듯': 17,
#  '꽃': 7,
#  '길이': 2,
#  '캠핑': 28,
#  '사옹원': 2,
#  '종': 4,
#  '호떡': 9,
#  '우중': 10,
#  '평소': 5,
#  '달': 7,
#  '로그': 22,
#  '산장': 7,
#  '술집': 76,
#  '대체로': 1,
#  '오리': 4,
#  '주물': 1,
#  '럭': 1,
#  '던데': 6,
#  '젊은이': 1,
#  '취향': 6,
#  '저격': 3,
#  '하이': 8,
#  '볼': 16,
#  '수진': 1,
#  '흔적': 2,
#  '가산디지털단지역': 2,
#  '김대': 2,
#  '불맛나': 1,
#  '하나': 35,
#  '제왕': 1,
#  '주소': 9,
#  '서울': 72,
#  '금천구': 1,
#  '가산': 3,
#  '디지털': 3,
#  '한라': 1,
#  '앤': 7,
#  '타워': 5,
#  '층': 23,
#  '호': 9,
#  '전화번호': 2,
#  '월': 5,
#  '금': 6,
#  '부근': 1,
#  '파이브': 1,
#  '비뉴': 1,
#  '즐': 20,
#  '기기': 9,
#  '가끔': 5,
#  '특정': 1,
#  '날때': 4,
#  '서도': 9,
#  '지혜': 3,
#  '사자': 3,
#  '감성': 31,
#  '현실': 3,
#  '베이커리': 13,
#  '분': 53,
#  '무': 10,
#  '로이': 1,
#  '힙': 3,
#  '스팟': 1,
#  '아보': 12,
#  '테라스': 6,
#  '강추': 11,
#  '대신': 11,
#  '종류': 28,
#  '편이': 3,
#  '디저트': 30,
#  '참고': 15,
#  '욥': 1,
#  '서귀포': 18,
#  '대형': 12,
#  '파워': 1,
#  '이지': 22,
#  '여름': 16,
#  '탕수': 1,
#  '제철': 6,
#  '어른': 6,
#  '탕수랍니': 1,
#  '오랜만': 19,
#  '백고': 1,
#  '막내': 2,
#  '아하': 38,
#  '개': 46,
#  '맘마': 2,
#  '드실껀': 1,
#  '가요': 6,
#  '경북': 3,
#  '도청': 2,
#  '설비': 4,
#  '안동': 1,
#  '고기국수': 2,
#  '이수': 1,
#  '오래': 9,
#  '무하': 1,
#  '직원': 11,
#  '단골': 8,
#  '음식점': 3,
#  '성공': 7,
#  '누수': 2,
#  '수구': 2,
#  '해결사': 1,
#  '모든': 20,
#  '강서구': 2,
#  '유림': 2,
#  '못': 18,
#  '한마음': 1,
#  '통속': 1,
#  '정': 14,
#  '도착': 7,
#  '쑥갓': 7,
#  '안주': 46,
#  '전요': 5,
#  '리가': 1,
#  '줌': 5,
#  '칼라': 1,
#  '테라': 2,
#  '피': 8,
#  '카페라떼': 3,
#  '방송': 2,
#  '스벅': 1,
#  '스텀': 4,
#  '엽떡': 2,
#  '재난': 1,
#  '알림': 2,
#  '문자': 2,
#  '태풍': 10,
#  '대비': 3,
#  '하라': 3,
#  '라떼': 17,
#  '상추': 6,
#  '튀김': 21,
#  '가루': 20,
#  '키친': 7,
#  '타': 8,
#  '기름기': 2,
#  '전간': 1,
#  '지네': 2,
#  '이영자': 1,
#  '꿀': 10,
#  '유미': 16,
#  '카츠': 24,
#  '본격': 4,
#  '적': 25,
#  '장마': 29,
#  '뿐': 10,
#  '항상': 3,
#  '매력': 9,
#  '돈카츠': 3,
#  '전문점': 8,
#  '공식': 11,
#  '동천역': 5,
#  '명동': 16,
#  '한국': 10,
#  '수지구': 1,
#  '평일': 7,
#  '토요일': 4,
#  '휴무': 10,
#  '억수': 3,
#  '마론킴': 1,
#  '순대국': 21,
#  '광교': 6,
#  '프랑': 7,
#  '남옥': 2,
#  '아브뉴': 4,
#  '이용': 15,
#  '라스트': 3,
#  '별별': 2,
#  '감초': 2,
#  '내일': 10,
#  '여': 6,
#  '작전동': 1,
#  '온면': 1,
#  '포차': 13,
#  '일단': 11,
#  '인분': 13,
#  '잔': 14,
#  '필': 3,
#  '칭따오': 1,
#  '맥주': 29,
#  '술': 18,
#  '미미': 7,
#  '오덕': 11,
#  '집콕러들': 2,
#  '빗': 13,
#  '인적': 11,
#  '어렷을적': 1,
#  '초등학교': 1,
#  '마치': 4,
#  '우산': 6,
#  '청년': 3,
#  '암만': 2,
#  '자향': 1,
#  '출발': 2,
#  '닭갈비': 2,
#  '소세지': 2,
#  '인기': 14,
#  '영양': 7,
#  '쟁이': 1,
#  '강력': 12,
#  '합': 8,
#  '미니': 2,
#  '메기': 4,
#  '매운탕': 12,
#  '계속': 14,
#  '올해': 2,
#  '기간': 3,
#  '비소': 4,
#  '남양주': 8,
#  '찜질': 1,
#  '출처': 3,
#  '나혼산': 1,
#  '코쿤': 1,
#  '엘리': 1,
#  '지금': 16,
#  '순간': 5,
#  '포': 11,
#  '깐풍기': 3,
#  '단짝': 2,
#  '레드': 6,
#  '베트남': 4,
#  '베스트': 6,
#  '어가': 23,
#  '간장': 10,
#  '이나': 30,
#  '절임': 2,
#  '감칠맛': 5,
#  '아직': 8,
#  '갑오징어무침': 2,
#  '다트': 2,
#  '지고': 9,
#  '방': 23,
#  '장마철': 21,
#  '주룩주룩': 9,
#  '밖': 7,
#  '몸': 12,
#  '기분': 28,
#  '다운': 7,
#  '다한': 1,
#  '도토리': 3,
#  '구성': 10,
#  '구미': 14,
#  '구': 12,
#  '미산동': 1,
#  '전문': 5,
#  '전하': 1,
#  '보': 26,
#  '내세': 3,
#  '계산': 3,
#  '아메': 1,
#  '믹스': 8,
#  '프로': 3,
#  '토탈': 1,
#  '인테리어': 8,
#  '송도': 8,
#  '우이': 3,
#  '녹': 3,
#  '백합': 7,
#  '왕새우': 1,
#  '지난주': 4,
#  '볼일': 1,
#  '센트럴': 1,
#  '파크': 8,
#  '우수': 1,
#  '제비집': 2,
#  '마침': 6,
#  '김': 7,
#  '썸머': 3,
#  '퇴근': 8,
#  '무얼': 1,
#  '먹음': 8,
#  '의': 45,
#  '고추장': 8,
#  '절로': 1,
#  '준비': 17,
#  '냉장고': 5,
#  '속': 12,
#  '시크': 4,
#  '도도': 4,
#  '토깽': 2,
#  '살': 22,
#  '효': 4,
#  '곱창전골': 13,
#  '효능': 2,
#  '보통': 4,
#  '함': 12,
#  '겉': 2,
#  '온통': 2,
#  '얀마': 1,
#  ...}

# %%
#단어와 빈도수를 열 이름으로 사용
df = pd.DataFrame(list(df.items()),
                   columns=['단어', '빈도수'])
df
# Out:
#        단어   빈도수
# 0      추천  1593
# 1       날  2397
# 2      메뉴  1734
# 3     칼국수   399
# 4       비  1833
# ...   ...   ...
# 5657   비교     1
# 5658   통째     1
# 5659   불앞     1
# 5660   항동     1
# 5661   우남     1
#
# [5662 rows x 2 columns]

# %%
#빈도수 내림차순으로 정력
df = df.sort_values(by='빈도수',ascending=False)
df
# Out:
#         단어   빈도수
# 1        날  2397
# 4        비  1833
# 2       메뉴  1734
# 0       추천  1593
# 7       맛집   646
# ...    ...   ...
# 3210   유성구     1
# 3211  한밭대로     1
# 3213    지번     1
# 3216    천순     1
# 5661    우남     1
#
# [5662 rows x 2 columns]

# %%
df.to_csv('word.csv',

                 sep=',',

                 na_rep='NaN', 

                 float_format = '%.2f', # 2 decimal places

                 columns = ['단어', '빈도수'], # columns to write

                 index = False) # do not write index

# %%
df1 = pd.read_csv('foodinfo1.csv')
df1 = df1.rename(columns={'대표식품명':'단어'})
df1
# Out:
#         식품대분류명     단어  에너지(kcal)  단백질(g)
# 0    곡류, 서류 제품     팝콘        511    8.30
# 1          과일류     과일         43    0.47
# 2          구이류  가자미구이        123   18.70
# 3          구이류   갈치구이        138   21.54
# 4          구이류  고등어구이        340   23.38
# ..         ...    ...        ...     ...
# 719        튀김류    치즈볼        333    9.56
# 720        튀김류   치즈스틱        329   12.59
# 721        튀김류   치킨까스        296   13.96
# 722        튀김류   깐쇼새우        150    7.90
# 723        튀김류   동태까스        273   11.60
#
# [724 rows x 4 columns]

# %%
df2 = pd.read_csv('word.csv')

df2
# Out:
#         단어   빈도수
# 0        날  2397
# 1        비  1833
# 2       메뉴  1734
# 3       추천  1593
# 4       맛집   646
# ...    ...   ...
# 5657   유성구     1
# 5658  한밭대로     1
# 5659    지번     1
# 5660    천순     1
# 5661    우남     1
#
# [5662 rows x 2 columns]

# %%
df3 = pd.merge(df1, df2)
df3
# Out:
#     식품대분류명    단어  에너지(kcal)  단백질(g)  빈도수
# 0      과일류    과일         43    0.47    3
# 1      구이류    곱창        184   14.89   27
# 2      구이류    꼬치        245   17.85   15
# 3      구이류    닭발        196   18.15   17
# 4      구이류   떡갈비        202   21.38    1
# ..     ...   ...        ...     ...  ...
# 192    튀김류    치킨        257   17.17   35
# 193    튀김류   탕수육        116    6.65    9
# 194    튀김류  고추튀김        202    7.60    2
# 195    튀김류   깐풍기        295   13.10    3
# 196    튀김류   돈까스        262   14.46   14
#
# [197 rows x 5 columns]

# %%
df3 = df3.sort_values(by='빈도수',ascending=False)
df3 = df3.set_index('단어')
df3
# Out:
#          식품대분류명  에너지(kcal)  단백질(g)  빈도수
# 단어
# 칼국수     면 및 만두류         77    3.30  399
# 수제비     면 및 만두류         58    2.31  126
# 짬뽕      면 및 만두류         58    2.79   81
# 파전    전·적 및 부침류        171    5.50   79
# 커피      음료 및 차류          3    0.33   69
# ...         ...        ...     ...  ...
# 무조림         조림류         48    2.26    1
# 비빔면     면 및 만두류        153    5.70    1
# 비빔국수    면 및 만두류        113    3.40    1
# 팥죽      죽 및 스프류         81    3.17    1
# 쿠키      빵 및 과자류        309    3.36    1
#
# [197 rows x 4 columns]

# %%
df3
# Out:
#          식품대분류명  에너지(kcal)  단백질(g)  빈도수
# 단어
# 칼국수     면 및 만두류         77    3.30  399
# 수제비     면 및 만두류         58    2.31  126
# 짬뽕      면 및 만두류         58    2.79   81
# 파전    전·적 및 부침류        171    5.50   79
# 커피      음료 및 차류          3    0.33   69
# ...         ...        ...     ...  ...
# 무조림         조림류         48    2.26    1
# 비빔면     면 및 만두류        153    5.70    1
# 비빔국수    면 및 만두류        113    3.40    1
# 팥죽      죽 및 스프류         81    3.17    1
# 쿠키      빵 및 과자류        309    3.36    1
#
# [197 rows x 4 columns]

# %%
df3 = df3.reset_index()
df3
# Out:
#        단어     식품대분류명  에너지(kcal)  단백질(g)  빈도수
# 0     칼국수    면 및 만두류         77    3.30  399
# 1     수제비    면 및 만두류         58    2.31  126
# 2      짬뽕    면 및 만두류         58    2.79   81
# 3      파전  전·적 및 부침류        171    5.50   79
# 4      커피    음료 및 차류          3    0.33   69
# ..    ...        ...        ...     ...  ...
# 192   무조림        조림류         48    2.26    1
# 193   비빔면    면 및 만두류        153    5.70    1
# 194  비빔국수    면 및 만두류        113    3.40    1
# 195    팥죽    죽 및 스프류         81    3.17    1
# 196    쿠키    빵 및 과자류        309    3.36    1
#
# [197 rows x 5 columns]

# %%
df3['날씨구분'] = 'rain'
df3
# Out:
#        단어     식품대분류명  에너지(kcal)  단백질(g)  빈도수  날씨구분
# 0     칼국수    면 및 만두류         77    3.30  399  rain
# 1     수제비    면 및 만두류         58    2.31  126  rain
# 2      짬뽕    면 및 만두류         58    2.79   81  rain
# 3      파전  전·적 및 부침류        171    5.50   79  rain
# 4      커피    음료 및 차류          3    0.33   69  rain
# ..    ...        ...        ...     ...  ...   ...
# 192   무조림        조림류         48    2.26    1  rain
# 193   비빔면    면 및 만두류        153    5.70    1  rain
# 194  비빔국수    면 및 만두류        113    3.40    1  rain
# 195    팥죽    죽 및 스프류         81    3.17    1  rain
# 196    쿠키    빵 및 과자류        309    3.36    1  rain
#
# [197 rows x 6 columns]

# %%
df3.to_csv('rain_food.csv',index=False)
